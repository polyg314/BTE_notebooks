# %% [markdown]
# # BTE -- Question #2 -- Use Case Workflow

# %%
import pandas as pd
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %% [markdown]
# ## 1. Get Disease Symptoms and Symptom Information

# %% [markdown]
# ### 1.1 Get Disease

# %%
disease_name = 'xeroderma pigmentosum'
disease = ht.query('MONDO:0019600')['Disease'][0]
print(disease)
# Out:
# {'MONDO': 'MONDO:0019600', 'DOID': 'DOID:0050427', 'UMLS': 'C0043346', 'name': 'xeroderma pigmentosum', 'MESH': 'D014983', 'ORPHANET': '910', 'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'MONDO:0019600'}, 'display': 'MONDO(MONDO:0019600) DOID(DOID:0050427) ORPHANET(910) UMLS(C0043346) MESH(D014983) name(xeroderma pigmentosum)', 'type': 'Disease'}

# %% [markdown]
# ### 1.2 Get 'PhenotypicFeatures' Related to Disease

# %%
fc = FindConnection(input_obj=disease, output_obj='PhenotypicFeature', intermediate_nodes=None)
fc.connect(verbose=False)
disease_to_phenotypicFeature = fc.display_table_view()

# %% [markdown]
# Note: all equivalent names for the disease input are as follows:

# %%
for name in fc.fc.display_node_info(disease_name)['equivalent_ids']['name']: print(name)
# Out:
# ANGIOMA PIGMENTOSUM ATROPHICUM
# ATROPHODERMA PIGMENTOSUM
# KAPOSI DERMATOSIS
# KAPOSI DISEASE
# MELANOSIS LENTICULARIS PROGRESSIVA
# PIGMENTED EPITHELIOMATOSIS
# XERODERMA OF KAPOSI
# XERODERMA PIGMENTOSA
# XERODERMA PIGMENTOSUM
# XERODERMA PIGMENTOSUM SYNDROME
# XP

# %%
symptom_dict = {}
for index, row in disease_to_phenotypicFeature.iterrows(): 
    output_name = row["output_name"]
    freq = [_item['info']['frequency'] for _item in fc.fc.G[disease_name][output_name].values() if "frequency" in _item["info"]][0][0]
    freq_value = ht.query(freq)['PhenotypicFeature'][0]['name']
    symptom_dict[fc.fc.display_node_info(output_name)['equivalent_ids']['HP'][0]] = {
        "names": fc.fc.display_node_info(output_name)['equivalent_ids']['name'],
        "frequency": freq_value,
    }
# print(symptom_dict)

# %%
all_node_types = ['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature']

for key in symptom_dict:
    print(str(key) + ' is running')
    edges_out_count = 0
    UMLS = ''
    # a sign or symptom may show up as a phenotypic feature, a disease, or biological process
    for y in ['PhenotypicFeature','Disease','BiologicalProcess']:
        if y == 'PhenotypicFeature':
            a = ht.query(key)[y]
            if len(a) > 0: 
                b = a[0]
                if 'UMLS' in b: 
                    UMLS = b['UMLS']
                for node_intermediate in all_node_types:
                    try: 
                        fc = FindConnection(input_obj=b, output_obj=node_intermediate, intermediate_nodes=None)
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        if(df.shape[0] > 0):
                            df = df[df["output_name"] != disease_name]
                            edges_out_count = edges_out_count + df.shape[0]
                    except: 
                         print(str(y) + " input to " + node_intermediate + " output for " + str(key) + ' failed')
        if(y =='Disease') | (y == 'BiologicalProcess'):
            for z in symptom_dict[key]["names"]:
                if((y == 'Disease') & (len(UMLS) > 0)): 
                    try: 
                        a = ht.query(UMLS)[y]
                    except: 
                        a = []
                else:
                    try: 
                        a = ht.query(z)[y]
                    except: 
                        a = []
                for b in a: 
                    if b['name'].lower() == z.lower():
                        for node_intermediate in all_node_types:
                            try: 
                                fc = FindConnection(input_obj=b, output_obj=node_intermediate, intermediate_nodes=None)
                                fc.connect(verbose=False)
                                df = fc.display_table_view()
                                if(df.shape[0] > 0):
                                    df = df[df["output_name"] != disease_name]
                                    edges_out_count = edges_out_count + df.shape[0]

                            except: 
                                print(str(y) + " input to " + node_intermediate + " output for " + str(key) + ' failed')
    symptom_dict[key]["edges_out_count"] = edges_out_count
# Out:
# HP:0012733 is running
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0004493 is running
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# HP:0004334 is running
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 5.1 pharos failed
# HP:0004322 is running
# API 3.2 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0009830 is running
# API 3.8 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# HP:0009755 is running
# API 3.1 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0002861 is running
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# HP:0002829 is running
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# HP:0002750 is running
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# HP:0002664 is running
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 5.1 pharos failed
# Disease input to Disease output for HP:0002664 failed
# HP:0012740 is running
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 5.1 pharos failed
# Disease input to Disease output for HP:0012740 failed
# HP:0002376 is running
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0002353 is running
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0002120 is running
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# HP:0000992 is running
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0012378 is running
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0000963 is running
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0000962 is running
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0000958 is running
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# HP:0002071 is running
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0010783 is running
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# HP:0000524 is running
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# ...
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0001009 is running
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0000518 is running
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0000613 is running
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0000621 is running
# API 3.6 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0000656 is running
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# HP:0000995 is running
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# HP:0007759 is running
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed

# %%
disease_symptom_df = pd.DataFrame.from_dict(symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptom_df = pd.concat([disease_symptom_df[disease_symptom_df["frequency"] == "Very frequent"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Frequent"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Occasional"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Rare"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Unknown"]
              ])
disease_symptom_df
# Out:
#                                                         names      frequency  \
# HP:0000524  [CONJUNCTIVAL TELANGIECTASES, CONJUNCTIVAL TEL...  Very frequent
# HP:0001029                                     [POIKILODERMA]  Very frequent
# HP:0001480                                        [FRECKLING]  Very frequent
# HP:0100585  [TELANGIECTASIA OF THE SKIN, TELEANGIECTASIA O...  Very frequent
# HP:0001009  [CUTANEOUS TELANGIECTASIA, SPIDER VEINS, TELAN...  Very frequent
# HP:0001072  [DIFFUSELY THICKENED SKIN, PACHYDERMIA, THICK ...  Very frequent
# HP:0000992  [CUTANEOUS PHOTOSENSITIVITY, PHOTOSENSITIVE SK...  Very frequent
# HP:0006887  [INTELLECTUAL DISABILITY, PROGRESSIVE, MENTAL ...  Very frequent
# HP:0000963                                        [THIN SKIN]  Very frequent
# HP:0000958                                [DRY SKIN, XEROSIS]  Very frequent
# HP:0100543  [ABNORMALITY OF COGNITION, COGNITIVE ABNORMALI...  Very frequent
# HP:0002376  [DEVELOPMENTAL REGRESSION, LOSS OF DEVELOPMENT...  Very frequent
# HP:0002353  [ABNORMAL EEG, ABNORMAL ELECTROENCEPHALOGRAM, ...  Very frequent
# HP:0000164  [ABNORMAL DENTITION, ABNORMAL TEETH, ABNORMALI...  Very frequent
# HP:0001508  [FAILURE TO THRIVE, FALTERING WEIGHT, POOR WEI...  Very frequent
# HP:0002829  [ARTHRALGIA, ARTHRALGIAS, ARTHRITIC PAIN, JOIN...  Very frequent
# HP:0012378               [FATIGUE, MALAISE, TIRED, TIREDNESS]  Very frequent
# HP:0000648  [OPTIC ATROPHY, OPTIC NERVE ATROPHY, OPTIC-NER...  Very frequent
# HP:0000135       [DECREASED ACTIVITY OF GONADS, HYPOGONADISM]  Very frequent
# HP:0001945                     [FEVER, HYPERTHERMIA, PYREXIA]  Very frequent
# HP:0002861  [CANCER OF SKIN PIGMENT CELLS, MALIGNANT MELAN...       Frequent
# HP:0001034  [HYPERMELANOTIC MACULE, HYPERPIGMENTED MACULES...       Frequent
# HP:0001053  [HYPOPIGMENTED SKIN PATCHES, PATCHY LOSS OF SK...       Frequent
# HP:0010783     [ERYTHEMA, REDNESS OF SKIN OR MUCOUS MEMBRANE]       Frequent
# HP:0012733            [FLAT, DISCOLORED AREA OF SKIN, MACULE]       Frequent
# HP:0000407  [HEARING LOSS, SENSORINEURAL, SENSORINEURAL DE...       Frequent
# HP:0000028  [CRYPTORCHIDISM, CRYPTORCHISM, UNDESCENDED TES...       Frequent
# HP:0004334  [ATROPHIC SKIN, DERMAL ATROPHY, SKIN ATROPHY, ...       Frequent
# HP:0000962                                   [HYPERKERATOSIS]       Frequent
# HP:0000491                  [CORNEAL INFLAMMATION, KERATITIS]       Frequent
# HP:0000486      [CROSS-EYED, SQUINT, SQUINT EYES, STRABISMUS]       Frequent
# HP:0012740                                        [PAPILLOMA]       Frequent
# HP:0000518  [CATARACT, CATARACTS, CLOUDING OF THE LENS OF ...       Frequent
# HP:0100012  [EYE TUMOR, NEOPLASIA OF THE EYE, NEOPLASM OF ...     Occasional
# HP:0010649            [DEPRESSED NASAL ALAE, FLAT NASAL ALAE]     Occasional
# HP:0009755  [ADHESION OF EYELIDS, ANKYLOBLEPHARON, ANKYLOB...     Occasional
# HP:0004493  [CRANIOFACIAL HYPEROSTOSIS, ENLARGEMENT OF CRA...     Occasional
# HP:0000621  [ENTROPION, EYELID FOLDED IN, EYELID TURNED IN...     Occasional
# HP:0000656  [ECTROPION, EVERTED EYELID, EYELID FOLDED OUT,...     Occasional
# HP:0000995  [BEAUTY MARK, MELANOCYTIC NAEVUS, MELANOCYTIC ...     Occasional
# HP:0007759  [CLOUDY CORNEA, CLOUDY CORNEAS, CORNEAL STROMA...     Occasional
# HP:0002071  [ABNORMALITY OF EXTRAPYRAMIDAL MOTOR FUNCTION,...     Occasional
# HP:0003355  [ABNORMAL URINARY AMINO-ACID FINDINGS, AMINOAC...     Occasional
# HP:0001315  [ABSENT OR DECREASED DEEP TENDON REFLEXES, DEC...     Occasional
# HP:0008734  [DECREASED TESTICULAR SIZE, HYPOPLASTIC TESTES...     Occasional
# HP:0002750  [DELAYED BONE AGE, DELAYED BONE AGE BEFORE PUB...     Occasional
# HP:0000498  [BLEPHARITIS, CELLULITIS OF EYELIDS, INFLAMMAT...     Occasional
# HP:0001257  [INVOLUNTARY MUSCLE STIFFNESS, CONTRACTION, OR...     Occasional
# HP:0001059                              [PTERYGIA, PTERYGIUM]     Occasional
# HP:0000365  [CONGENITAL DEAFNESS, CONGENITAL HEARING LOSS,...     Occasional
# HP:0000613  [EXTREME SENSITIVITY OF THE EYES TO LIGHT, LIG...     Occasional
# HP:0001251                        [ATAXIA, CEREBELLAR ATAXIA]     Occasional
# HP:0000252  [ABNORMALLY SMALL CRANIUM, ABNORMALLY SMALL HE...     Occasional
# HP:0001250   [EPILEPSY, EPILEPTIC SEIZURE, SEIZURE, SEIZURES]     Occasional
# HP:0002120  [CEREBRAL CORTEX ATROPHY, CEREBRAL CORTICAL AT...     Occasional
# HP:0004322  [DECREASED BODY HEIGHT, HEIGHT LESS THAN 3RD P...     Occasional
# HP:0009830  [NEUROPATHY, PERIPHERAL NERVE DAMAGE, PERIPHER...     Occasional
# HP:0001596                              [ALOPECIA, HAIR LOSS]     Occasional
# HP:0002664  [ABNORMAL TISSUE MASS, CANCER, NEOPLASIA, NEOP...     Occasional
#
#             edges_out_count
# HP:0000524               52
# HP:0001029               59
# HP:0001480               78
# HP:0100585              103
# HP:0001009              136
# HP:0001072              166
# HP:0000992              221
# HP:0006887              235
# HP:0000963              420
# HP:0000958              531
# HP:0100543              538
# HP:0002376              548
# HP:0002353              735
# HP:0000164              862
# HP:0001508              871
# HP:0002829             1151
# HP:0012378             2658
# HP:0000648             2735
# HP:0000135             3187
# HP:0001945             4350
# HP:0002861              117
# HP:0001034              119
# HP:0001053              183
# HP:0010783              398
# HP:0012733              634
# HP:0000407              679
# HP:0000028              750
# HP:0004334              837
# HP:0000962              973
# HP:0000491             2030
# HP:0000486             2053
# HP:0012740             2421
# HP:0000518             3265
# HP:0100012               11
# HP:0010649               12
# HP:0009755               41
# HP:0004493               55
# HP:0000621               60
# HP:0000656              122
# HP:0000995              192
# HP:0007759              231
# HP:0002071              235
# HP:0003355              243
# HP:0001315              253
# HP:0008734              524
# HP:0002750              624
# HP:0000498              649
# HP:0001257              759
# HP:0001059              801
# HP:0000365              840
# HP:0000613              878
# HP:0001251              885
# HP:0000252             1088
# HP:0001250             1148
# HP:0002120             1311
# HP:0004322             1335
# HP:0009830             2732
# HP:0001596             3870
# HP:0002664            40255

# %% [markdown]
# ## 2. Get Genes Directly Related to Disease

# %%
def get_disease_to_gene_results(disease_input):

    # keep track of number of occurrences from direct disease -> gene connection
    print("running disease -> gene")
    disease_to_gene_results = {}
    #directly related
    fc = FindConnection(input_obj=disease_input, output_obj='Gene', intermediate_nodes=None)
    fc.connect(verbose=False)
    disease_to_genes = fc.display_table_view()
    print(disease_to_genes.shape)

    disease_to_genes = disease_to_genes[~disease_to_genes['output_id'].str.contains('UMLS')]


    i = list(disease_to_genes["output_name"])
    d = {x:i.count(x) for x in i}
    sorted_disease_to_genes = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
    disease_to_gene_results["sorted_disease_to_genes"] = sorted_disease_to_genes
    # print("occurences of genes directly related to genes")
    # print(disease_to_gene_results["sorted_disease_to_genes"])

    one_step_genes_pub_counts = {}
    for index, row in disease_to_genes.iterrows():
        current_pubcount = 0
        if(row["pred1_pubmed"] != None):
            current_pubcount = current_pubcount + row["pred1_pubmed"].count(",") + 1
        if row["output_name"] in one_step_genes_pub_counts:
            one_step_genes_pub_counts[row["output_name"]] = one_step_genes_pub_counts[row["output_name"]] + current_pubcount
        else: 
            one_step_genes_pub_counts[row["output_name"]] = current_pubcount
    disease_to_gene_results["one_step_genes_pub_counts"] =  one_step_genes_pub_counts

    disease_to_genes_list = list(reversed(list(sorted_disease_to_genes.keys())))
    disease_to_gene_results["disease_to_genes_list"] = disease_to_genes_list

    return(disease_to_gene_results)

# %%
disease_to_gene_results = get_disease_to_gene_results(disease)
disease_to_gene_results
# Out:
# running disease -> gene
# (2045, 9)
# {'sorted_disease_to_genes': {'MGI:6258233': 1,
#   'MGI:6258236': 1,
#   'MGI:1195972': 1,
#   '18S_rRNA': 1,
#   '28S_rRNA': 1,
#   '45S_rRNA': 1,
#   '7SK': 1,
#   'CASC15': 1,
#   'CYP26B1': 1,
#   'CFTR': 1,
#   'USP28': 1,
#   'CRY1': 1,
#   'CD4': 1,
#   'UBR7': 1,
#   'CDH17': 1,
#   'GABARAPL2': 1,
#   'RFC2': 1,
#   'KIAA2022': 1,
#   'GNA11': 1,
#   'AQR': 1,
#   'ST6GALNAC1': 1,
#   'NOX3': 1,
#   'TNFRSF1A': 1,
#   'PIGB': 1,
#   'TRIP13': 1,
#   'KRT14': 1,
#   'FGF4': 1,
#   'KEAP1': 1,
#   'TNS1': 1,
#   'RRN3': 1,
#   'PPP1R15A': 1,
#   'PPP1R13B': 1,
#   'SIRT4': 1,
#   'OTUB2': 1,
#   'OSGEP': 1,
#   'ADH1A': 1,
#   'CDC6': 1,
#   'CBX5': 1,
#   'VCL': 1,
#   'SIRT1': 1,
#   'CDC34': 1,
#   'GADD45B': 1,
#   'MAPK1': 1,
#   'DMC1': 1,
#   'HSCB': 1,
#   'XBP1': 1,
#   'HMOX1': 1,
#   'MCM5': 1,
#   'TXN2': 1,
#   'RBX1': 1,
#   'ACO2': 1,
#   'BRD1': 1,
#   'SUPT16H': 1,
#   'POLE2': 1,
#   'ALKBH1': 1,
#   'MTHFD1': 1,
#   'APEX1': 1,
#   'EFS': 1,
#   'NFKBIA': 1,
#   'CYP24A1': 1,
#   'AURKA': 1,
#   'EEF1A2': 1,
#   'CSNK2A1': 1,
#   'FERMT1': 1,
#   'TBL1X': 1,
#   'USP11': 1,
#   'TIMP1': 1,
#   'NTHL1': 1,
#   'MMP2': 1,
#   'POLR2C': 1,
#   'USB1': 1,
#   'MPG': 1,
#   'TSC2': 1,
#   'STUB1': 1,
#   'TGM5': 1,
#   'AGO2': 1,
#   'SFRP1': 1,
#   'CHRAC1': 1,
#   'GML': 1,
#   'GSR': 1,
#   'TNFRSF10A': 1,
#   'RNASEH2A': 1,
#   'FBL': 1,
#   'CLC': 1,
#   'POLR2I': 1,
#   'TGFB1': 1,
#   'CRX': 1,
#   'HGF': 1,
#   'NAMPT': 1,
#   'CYP3A5': 1,
#   'SERPINE1': 1,
#   'RPA3': 1,
#   'SETX': 1,
#   'CYP26A1': 1,
#   'OBFC1': 1,
#   'PPIF': 1,
#   'MPO': 1,
#   'CSF3': 1,
#   'SUPT4H1': 1,
#   'RPS6KB1': 1,
#   'MED31': 1,
#   'DDX5': 1,
#   'CCL2': 1,
#   'CCL1': 1,
#   'KAT2A': 1,
#   'COL1A1': 1,
#   'CD38': 1,
#   'AFM': 1,
#   'PHOX2B': 1,
#   'NFKB1': 1,
#   'IL2': 1,
#   'GAR1': 1,
#   'CCND1': 1,
#   'PRPF19': 1,
#   'KITLG': 1,
#   'CYP27B1': 1,
#   'GLI1': 1,
#   'RAD51AP1': 1,
#   'CDKN1B': 1,
#   'IFNG': 1,
#   'NUP107': 1,
#   'CNOT2': 1,
#   'GAPDH': 1,
#   'USP5': 1,
#   'TPI1': 1,
#   'APOBEC1': 1,
#   'NANOG': 1,
#   'AICDA': 1,
#   'GCLC': 1,
#   'ASF1A': 1,
#   'FBXO5': 1,
#   'FANCE': 1,
#   'MAPK14': 1,
#   'B3GAT2': 1,
#   'GMNN': 1,
#   'SKIV2L2': 1,
#   'PAPD7': 1,
#   'LOX': 1,
#   'IL4': 1,
#   'SKP1': 1,
#   'NR3C1': 1,
#   'RARS': 1,
#   'MLH1': 1,
#   'UBE3A': 1,
#   'RBP2': 1,
#   'RBP1': 1,
#   'NPRL2': 1,
#   'UMPS': 1,
#   'MSH2': 1,
#   'TFPI': 1,
#   'TLX2': 1,
#   'ID2': 1,
#   'ODC1': 1,
#   'PLEK': 1,
#   'MSH6': 1,
#   'MAD2L2': 1,
#   'PRDM2': 1,
#   'A4GNT': 1,
#   'TTR': 1,
#   'TBPL1': 1,
#   'PKD2': 1,
#   'ABCG2': 1,
#   'CPSF3': 1,
#   'DDX55': 1,
#   'FKBP15': 1,
#   'VPS4B': 1,
#   'DUSP1': 1,
#   'CCDC170': 1,
#   'EGR1': 1,
#   'COIL': 1,
#   'CAT': 1,
#   'POLK': 1,
#   'FLT3': 1,
#   'AHR': 1,
#   'EEPD1': 1,
#   'INHBA': 1,
#   'UNG': 1,
#   'BHLHE41': 1,
#   'ATP7B': 1,
#   'RIF1': 1,
#   'ZNF350': 1,
#   'PI3': 1,
#   'SNAI1': 1,
#   'MOCS3': 1,
#   'IL17C': 1,
#   'SNRPC': 1,
#   'HIST1H4F': 1,
#   'MT2A': 1,
#   'PIWIL1': 1,
#   'MRPS7': 1,
#   'THOC2': 1,
#   'FOSB': 1,
#   'VASP': 1,
#   'SYMPK': 1,
#   'CDC25B': 1,
#   'UBA2': 1,
#   'NR1D1': 1,
#   'SUGP1': 1,
#   'DDX49': 1,
#   'HELB': 1,
#   'PIN1': 1,
#   'GFER': 1,
#   'HSPB1': 1,
#   'CCDC117': 1,
#   'LIF': 1,
#   'SIRT2': 1,
#   'PIAS1': 1,
#   'MBD4': 1,
#   'MYOD1': 1,
#   'BCL2L2': 1,
#   'PARP2': 1,
#   'NEDD8': 1,
#   'SLX1A': 1,
#   'TUBG2': 1,
#   'NARFL': 1,
#   'KRT31': 1,
#   'RAF1': 1,
#   'MED17': 1,
#   'TRPC4AP': 1,
#   'CUL9': 1,
#   'KRT5': 1,
#   'KRT75': 1,
#   'KRT6B': 1,
#   'APOE': 1,
#   'GADD45G': 1,
#   'JUND': 1,
#   'TAF4': 1,
#   'UBE2M': 1,
#   'TRIM28': 1,
#   'ACSS2': 1,
#   'ABCB7': 1,
#   'RARA': 1,
#   'FUS': 1,
#   'SNRPA1': 1,
#   'DNAJB1': 1,
#   'PER2': 1,
#   'H3F3B': 1,
#   'ERAL1': 1,
#   'IGHMBP2': 1,
#   'MTL5': 1,
#   'PEMT': 1,
#   'CCNA1': 1,
#   'KRAS': 1,
#   'EIF2S1': 1,
#   'ELP3': 1,
#   'MBD2': 1,
#   'CCNB1': 1,
#   'CDK7': 1,
#   'GSTM3': 1,
#   'SLCO1B1': 1,
#   'SPX': 1,
#   'PHC2': 1,
#   'PDGFRA': 1,
#   'APC': 1,
#   'RINT1': 1,
#   'NT5E': 1,
#   'CDK4': 1,
#   'ESPL1': 1,
#   'MDM2': 1,
#   'REV1': 1,
#   'DDX56': 1,
#   'HUS1': 1,
#   'IREB2': 1,
#   'SRSF1': 1,
#   'BRIP1': 1,
#   'KAT7': 1,
#   'SLC31A2': 1,
#   'PSORS1C2': 1,
#   'C6orf15': 1,
#   'POU5F1': 1,
#   'GGH': 1,
#   'MMP20': 1,
#   'FDX1': 1,
#   'ADAM10': 1,
#   'CCBL2': 1,
#   'LRPPRC': 1,
#   'CYP2C9': 1,
#   'KIF11': 1,
#   'TOPBP1': 1,
#   'BARD1': 1,
#   'PPIG': 1,
#   'COX17': 1,
#   'MNAT1': 1,
#   'CCND2': 1,
#   'LMNB1': 1,
#   'VWF': 1,
#   'UBE2K': 1,
#   'LIAS': 1,
#   'N4BP2': 1,
#   'SNW1': 1,
#   'PALB2': 1,
#   'NDC80': 1,
#   'KPNA3': 1,
#   'ALDH2': 1,
#   'CDH1': 1,
#   'TIPIN': 1,
#   'CCNT1': 1,
#   'PIK3C3': 1,
#   'MCM4': 1,
#   'RBL2': 1,
#   'SMAD2': 1,
#   'YY1': 1,
#   'NUBP2': 1,
#   'TCEB2': 1,
#   'CHTF18': 1,
#   'AXIN1': 1,
#   'CREBBP': 1,
#   'DHX8': 1,
#   'CSNK2A2': 1,
#   'SRCAP': 1,
#   'SETD1A': 1,
#   'ZNF629': 1,
#   'CCNE1': 1,
#   'CDKN2C': 1,
#   'ACIN1': 1,
#   'ELL': 1,
#   'MAU2': 1,
#   'SAMHD1': 1,
#   'XRCC1': 1,
#   'E2F3': 1,
#   'PIAS4': 1,
#   'MAPK3': 1,
#   'SMARCB1': 1,
#   'MSH4': 1,
#   'UFD1L': 1,
#   'EP300': 1,
#   'LIG1': 1,
#   'TYR': 1,
#   'IL1A': 1,
#   'IL1B': 1,
#   'BRD4': 1,
#   'ASF1B': 1,
#   'MED26': 1,
#   'BIRC3': 1,
#   'TAF1B': 1,
#   'POLD3': 1,
#   'SNRNP40': 1,
#   'SGOL1': 1,
#   'KAT2B': 1,
#   'WDR76': 1,
#   'AKT3': 1,
#   'POLR1A': 1,
#   'KDR': 1,
#   'PIK3CA': 1,
#   'TAF12': 1,
#   'CTCF': 1,
#   'TUBB4A': 1,
#   'HAT1': 1,
#   'MCM6': 1,
#   'CCNT2': 1,
#   'ZRANB3': 1,
#   'PPAT': 1,
#   'CHST10': 1,
#   'NOP58': 1,
#   'HERC5': 1,
#   'COPS4': 1,
#   'CUL3': 1,
#   'ADD2': 1,
#   'FGF2': 1,
#   'RBBP5': 1,
#   'UBE2S': 1,
#   'GZMM': 1,
#   'NEIL3': 1,
#   'WNT5A': 1,
#   'STAT3': 1,
#   'MTRR': 1,
#   'DNMT3A': 1,
#   'FOSL2': 1,
#   'GPN1': 1,
#   'TP63': 1,
#   'ADD1': 1,
#   'GPBP1': 1,
#   'ICAM1': 1,
#   'KLF1': 1,
#   'SIDT1': 1,
#   'PPARGC1A': 1,
#   'RAD18': 1,
#   'SDHA': 1,
#   'XRN1': 1,
#   'BST1': 1,
#   'MCM2': 1,
#   'GOLPH3': 1,
#   'SUB1': 1,
#   'MSH3': 1,
#   'CENPE': 1,
#   'LEF1': 1,
#   'EGF': 1,
#   'VDAC1': 1,
#   'UBE2B': 1,
#   'AFF4': 1,
#   'MED20': 1,
#   'TNPO3': 1,
#   'POLB': 1,
#   'CALB1': 1,
#   'NBN': 1,
#   'ADH4': 1,
#   'FBXO3': 1,
#   'DBF4': 1,
#   'CDK6': 1,
#   'SMARCA2': 1,
#   'PMS2': 1,
#   'BTAF1': 1,
#   'GABARAPL1': 1,
#   'LGR5': 1,
#   'CDK2': 1,
#   'DHH': 1,
#   'BIN2': 1,
#   'SMARCC2': 1,
#   'ERBB3': 1,
#   'RB1': 1,
#   'TINF2': 1,
#   'FANCM': 1,
#   'FGF7': 1,
#   'UBE2Q2': 1,
#   'BCL2A1': 1,
#   'WDR61': 1,
#   'IGF1R': 1,
#   'PML': 1,
#   'POLG': 1,
#   'TICRR': 1,
#   'DEF8': 1,
#   'NCOR1': 1,
#   'CDH2': 1,
#   'ESCO1': 1,
#   'EIF4A3': 1,
#   'ERBB2': 1,
#   'KRT10': 1,
#   'SMG9': 1,
#   'SOD1': 1,
#   'DNMT3L': 1,
#   'SAE1': 1,
#   'RNPEPL1': 1,
#   'ACPT': 1,
#   'PGD': 1,
#   'SETDB1': 1,
#   'RPS27A': 1,
#   'ETAA1': 1,
#   'SFXN5': 1,
#   'SULT1C4': 1,
#   'SLC25A38': 1,
#   'RNF7': 1,
#   'FTH1': 1,
#   'CCNA2': 1,
#   'SETD7': 1,
#   'SKP2': 1,
#   'NHP2': 1,
#   'MUT': 1,
#   'TAAR8': 1,
#   'CCT6A': 1,
#   'NONO': 1,
#   'GINS4': 1,
#   'TERF1': 1,
#   'NDUFB9': 1,
#   'CDKN2B': 1,
#   'NOTCH1': 1,
#   'PPRC1': 1,
#   'SSRP1': 1,
#   'RPS3': 1,
#   'ATM': 1,
#   'MTA2': 1,
#   'MYRF': 1,
#   'CEP164': 1,
#   'TM7SF2': 1,
#   'PPP4C': 1,
#   'MMP10': 1,
#   'HNMT': 1,
#   'IL18': 1,
#   'NGLY1': 1,
#   'OXSM': 1,
#   'MYCN': 1,
#   'NUBPL': 1,
#   'FBXW7': 1,
#   'GRID2': 1,
#   'CRYGC': 1,
#   'FLT1': 1,
#   'NIPBL': 1,
#   'GJA1': 1,
#   'NUBP1': 1,
#   'RIOK2': 1,
#   'SMARCA5': 1,
#   'HNRNPU': 1,
#   'RANBP2': 1,
#   'GTF2E1': 1,
#   'CEBPG': 1,
#   'NEIL2': 1,
#   'DHX32': 1,
#   'APP': 1,
#   'ABCC3': 1,
#   'HSPA13': 1,
#   'PDIA4': 1,
#   'CASP10': 1,
#   'MED7': 1,
#   'NAT2': 1,
#   'GNAQ': 1,
#   'DCK': 1,
#   'UBE2L6': 1,
#   'NSMCE2': 1,
#   'BUB1B': 1,
#   'FANCD2': 1,
#   'EXOG': 1,
#   'PPARG': 1,
#   'DDX19B': 1,
#   'KIT': 1,
#   'ERCC6L2': 1,
#   'FANCC': 1,
#   'EIF5B': 1,
#   'HOXB13': 1,
#   'UBR1': 1,
#   'MED8': 1,
#   'GSTT2B': 1,
#   'SSU72': 1,
#   'TFF2': 1,
#   'TFF1': 1,
#   'SHKBP1': 1,
#   'CCR5': 1,
#   'FGFR4': 1,
#   'ALKBH4': 1,
#   'POLR2J': 1,
#   'STAT5B': 1,
#   'WNT1': 1,
#   'MED11': 1,
#   'EIF4A1': 1,
#   'SLX4': 1,
#   'USP24': 1,
#   'FAM71A': 1,
#   'REL': 1,
#   'SPRTN': 1,
#   'HPGDS': 1,
#   'HELQ': 1,
#   'MITF': 1,
#   'IHH': 1,
#   'CHCHD4': 1,
#   'ALB': 1,
#   'SNRK': 1,
#   'RHO': 1,
#   'MASP1': 1,
#   'UBXN7': 1,
#   'H2AFZ': 1,
#   'SAP30': 1,
#   'MAD2L1': 1,
#   'ANXA5': 1,
#   'ABCE1': 1,
#   'SLC45A2': 1,
#   'RICTOR': 1,
#   'TNFRSF21': 1,
#   'IL3': 1,
#   'CSF2': 1,
#   'NPM1': 1,
#   'SHH': 1,
#   'RAD21': 1,
#   'ORC5': 1,
#   'NOS3': 1,
#   'ALDH1A1': 1,
#   'WRN': 1,
#   'PCF11': 1,
#   'HPRT1': 1,
#   'WAPAL': 1,
#   'LRRK2': 1,
#   'PIWIL4': 1,
#   'COPS2': 1,
#   'TAF10': 1,
#   'RAG1': 1,
#   'ATMIN': 1,
#   'POLR2M': 1,
#   'HSP90B1': 1,
#   'MMP3': 1,
#   'PPIB': 1,
#   'FAM96A': 1,
#   'KIAA0101': 1,
#   'TERF2IP': 1,
#   'PLK1': 1,
#   'XRCC6BP1': 1,
#   'MED1': 1,
#   'RRM1': 1,
#   'CDT1': 1,
#   'KMT2D': 1,
#   'CYP2A6': 1,
#   'PSCA': 1,
#   'CHAF1A': 1,
#   'ICT1': 1,
#   'EVPL': 1,
#   'DDB1': 1,
#   'POLR2G': 1,
#   'FADD': 1,
#   'LGALS4': 1,
#   'MGMT': 1,
#   'ALKBH3': 1,
#   'HEXIM2': 1,
#   'HSPB2': 1,
#   'POLR1D': 1,
#   'MAP2K1': 1,
#   'BUB1': 1,
#   'BCL2L1': 1,
#   'AGXT': 1,
#   'UBTF': 1,
#   'IGF1': 1,
#   'PAIP1': 1,
#   'DDI1': 1,
#   'RPS9': 1,
#   'HSPA4': 1,
#   'HDAC3': 1,
#   'TMEM37': 1,
#   'UGT1A6': 1,
#   'HSPB3': 1,
#   'CDC25A': 1,
#   'UBE2E1': 1,
#   'CTLA4': 1,
#   'C7orf33': 1,
#   'PYDC1': 1,
#   'MPLKIP': 1,
#   'UGT1A8': 1,
#   'IRS1': 1,
#   'IL13': 1,
#   'ADRB2': 1,
#   'CEBPB': 1,
#   'TUB': 1,
#   'FEN1': 1,
#   'PCBP1': 1,
#   'SF3B3': 1,
#   'CXCL8': 1,
#   'OGG1': 1,
#   'ADH1B': 1,
#   'PPM1D': 1,
#   'BOLA2B': 1,
#   'ESCO2': 1,
#   'APLF': 1,
#   'TEX37': 1,
#   'ING2': 1,
#   'EIF2AK3': 1,
#   'RPTOR': 1,
#   'MCM7': 1,
#   'DDIT4': 1,
#   'TADA3': 1,
#   'HIST1H1E': 1,
#   'CYCS': 1,
#   'MUS81': 1,
#   'U2AF2': 1,
#   'EEF2': 1,
#   'RNASEH2C': 1,
#   'LEMD3': 1,
#   'H2AFV': 1,
#   'APITD1': 1,
#   'GLE1': 1,
#   'CLOCK': 1,
#   'SLC19A1': 1,
#   'PLG': 1,
#   'HLTF': 1,
#   'CATSPER1': 1,
#   'ACO1': 1,
#   'KLF7': 1,
#   'TERT': 1,
#   'C10orf2': 1,
#   'ADAT1': 1,
#   'CD34': 1,
#   'FOSL1': 1,
#   'BANF1': 1,
#   'RMI2': 1,
#   'PSMC5': 1,
#   'MAP9': 1,
#   'ISCU': 1,
#   'FBXW8': 1,
#   'DDX23': 1,
#   'FANCI': 1,
#   'CASP3': 1,
#   'DNAH7': 1,
#   'RAD9A': 1,
#   'POLD4': 1,
#   'GSTM1': 1,
#   'TNKS': 1,
#   'PPP1R8': 1,
#   'UCP2': 1,
#   'TPMT': 1,
#   'AOC3': 1,
#   'CFLAR': 1,
#   'LEP': 1,
#   'TAF7': 1,
#   'HNF4A': 1,
#   'CLSPN': 1,
#   'PABPC1': 1,
#   'FBXW5': 1,
#   'ATAD5': 1,
#   'RNASEH1': 1,
#   'PRKDC': 1,
#   'LGALS7B': 1,
#   'ZNF436': 1,
#   'ABCF1': 1,
#   'SSNA1': 1,
#   'CTC1': 1,
#   'PRIMPOL': 1,
#   'AURKB': 1,
#   'SENP3': 1,
#   'HIC1': 1,
#   'CHRNA3': 1,
#   'TYMS': 1,
#   'STAT2': 1,
#   'NUP98': 1,
#   'CCDC101': 1,
#   'UBE2N': 1,
#   'SFXN1': 1,
#   'RMI1': 1,
#   'SNRNP200': 1,
#   'SAMD4B': 1,
#   'MET': 1,
#   'RECQL5': 1,
#   'PRR15': 1,
#   'RBBP6': 1,
#   'DUOX1': 1,
#   'FUBP3': 1,
#   'NCL': 1,
#   'RUVBL1': 1,
#   'INTS3': 1,
#   'SF3B2': 1,
#   'GEN1': 1,
#   'CETN1': 1,
#   'SUPT6H': 1,
#   'PRMT5': 1,
#   'SULT1C2': 1,
#   'CXCR2': 1,
#   'NQO1': 1,
#   'ZNF687': 1,
#   'TMEM11': 1,
#   'EZH2': 1,
#   'PKM': 1,
#   'ARID1A': 1,
#   'ING3': 1,
#   'CALR': 1,
#   'RNF168': 1,
#   'CNOT1': 1,
#   'RCHY1': 1,
#   'TALDO1': 1,
#   'CDC25C': 1,
#   'DSCC1': 1,
#   'RPLP2': 1,
#   'TUFM': 1,
#   'POLE': 1,
#   'MMP1': 1,
#   'NDUFAF3': 1,
#   'ATRIP': 1,
#   'E2F7': 1,
#   'SMC1A': 1,
#   'PNKP': 1,
#   'SOX2': 1,
#   'POLR2L': 1,
#   'HSPA5': 1,
#   'WRAP53': 1,
#   'TCHP': 1,
#   'BAIAP3': 1,
#   'ULK1': 1,
#   'GSK3B': 1,
#   'STK11': 1,
#   'ZNF569': 1,
#   'PGR': 1,
#   'METAP2': 1,
#   'KIR3DL2': 1,
#   'TMC8': 1,
#   'PARP10': 1,
#   'RNF40': 1,
#   'MRE11A': 1,
#   'PPP1CA': 1,
#   'TUBA3D': 1,
#   'PSEN1': 1,
#   'EIF4A2': 1,
#   'CWF19L1': 1,
#   'CUL1': 1,
#   'MAF': 1,
#   'LMNB2': 1,
#   'NOS2': 1,
#   'NPTXR': 1,
#   'NKX2-5': 1,
#   'JAG2': 1,
#   'PIF1': 1,
#   'TRAIP': 1,
#   'RNF135': 1,
#   'DNMT3B': 1,
#   'GLRX5': 1,
#   'HEXIM1': 1,
#   'EFNA5': 1,
#   'GTF2H2': 1,
#   'SLX1B': 1,
#   'SIVA1': 1,
#   'SP1': 1,
#   'SIRT7': 1,
#   'CADM1': 1,
#   'TBK1': 1,
#   'UPP1': 1,
#   'CASP9': 1,
#   'NDNL2': 1,
#   'FANCF': 1,
#   'RPS27L': 1,
#   'BOLA2': 1,
#   'HGS': 1,
#   'MORF4L1': 1,
#   'WT1': 1,
#   'BOLA3': 1,
#   'NPLOC4': 1,
#   'CYLC1': 1,
#   'OR2T29': 1,
#   'IDH2': 1,
#   'HIST2H2AC': 1,
#   'NOP10': 1,
#   'ATP6V0A2': 1,
#   'RARB': 1,
#   'COL7A1': 1,
#   'NDN': 1,
#   'SMAD3': 1,
#   'ACTRT3': 1,
#   'UBA7': 1,
#   'C17orf70': 1,
#   'USP45': 1,
#   'MTA1': 1,
#   'TTF1': 1,
#   'ABCC5': 1,
#   'RPS19BP1': 1,
#   'HBB': 1,
#   'TAC4': 1,
#   'HDAC6': 1,
#   'GATA4': 1,
#   'POLR3C': 1,
#   'TMPRSS11A': 1,
#   'ARID2': 1,
#   'PDCD1': 1,
#   'HSP90AA1': 1,
#   'SF3B1': 1,
#   'CDKN3': 1,
#   'GSTA1': 1,
#   'KRTAP19-2': 1,
#   'RAD54B': 1,
#   'CBX3': 1,
#   'RAD51C': 1,
#   'DHX15': 1,
#   'SUPT7L': 1,
#   'ATF4': 1,
#   'CENPA': 1,
#   'UNC119': 1,
#   'ZNF354A': 1,
#   'SIRT6': 1,
#   'MED19': 1,
#   'TDP1': 1,
#   'DACT1': 1,
#   'RNASEH2B': 1,
#   'MAPK15': 1,
#   'LCK': 1,
#   'CYP3A4': 1,
#   'SUV39H1': 1,
#   'LMO1': 1,
#   'NPAS2': 1,
#   'SNCA': 1,
#   'UBA1': 1,
#   'EEF1A1': 1,
#   'RPS7': 1,
#   'NELFB': 1,
#   'DFFB': 1,
#   'HIST1H1C': 1,
#   'FGFR3': 1,
#   'LBR': 1,
#   'TAF1A': 1,
#   'C7orf26': 1,
#   'UBE2V1': 1,
#   'KAT5': 1,
#   'SENP8': 1,
#   'NMNAT3': 1,
#   'HUWE1': 1,
#   'ELSPBP1': 1,
#   'MAOA': 1,
#   'EIF4EBP1': 1,
#   'MAPT': 1,
#   'GTF2F2': 1,
#   'ZC3H12B': 1,
#   'STAT5A': 1,
#   'RANBP3': 1,
#   'SLC24A5': 1,
#   'SMAD4': 1,
#   'FAM111B': 1,
#   'HNRNPA1': 1,
#   'CYP1A2': 1,
#   'SLPI': 1,
#   'SLC25A15': 1,
#   'FOXM1': 1,
#   'BAZ1B': 1,
#   'EYA1': 1,
#   'PPM1G': 1,
#   'POLR2K': 1,
#   'MCPH1': 1,
#   'UBE4B': 1,
#   'BRE': 1,
#   'TCEA2': 1,
#   'USP1': 1,
#   'USP7': 1,
#   'HOXA9': 1,
#   'FOXN2': 1,
#   'ATR': 1,
#   'ESR2': 1,
#   'IL17A': 1,
#   'TP53INP1': 1,
#   'ATF3': 1,
#   'LIN28B': 1,
#   'CTNNB1': 1,
#   'NR4A2': 1,
#   'H1F0': 1,
#   'NF2': 1,
#   'DHRS2': 1,
#   'FBXL5': 1,
#   'GSTO2': 1,
#   'UBQLN2': 1,
#   'HMGB1': 1,
#   'PCDHB13': 1,
#   'E2F1': 1,
#   'ATP7A': 1,
#   'DPY30': 1,
#   'RPS21': 1,
#   'RPL3': 1,
#   'RPS3A': 1,
#   'DDX21': 1,
#   'PRKAA1': 1,
#   'TAP1': 1,
#   'ATG7': 1,
#   'OR5H1': 1,
#   'THRAP3': 1,
#   'OCA2': 1,
#   'FN1': 1,
#   'SERF1A': 1,
#   'HIST1H4J': 1,
#   'NEIL1': 1,
#   'HTT': 1,
#   'ANO1': 1,
#   'ARID4A': 1,
#   'RET': 1,
#   'MLH3': 1,
#   'UBE2I': 1,
#   'SREBF1': 1,
#   'C1D': 1,
#   'GTF2E2': 1,
#   'SPEF2': 1,
#   'ZNF44': 1,
#   'UVRAG': 1,
#   'GTF3C1': 1,
#   'TMEM259': 1,
#   'PPP4R2': 1,
#   'NHEJ1': 1,
#   'SCRIB': 1,
#   'CHD4': 1,
#   'RASSF1': 1,
#   'DCTD': 1,
#   'XPNPEP3': 1,
#   'UBE2D3': 1,
#   'SMARCAL1': 1,
#   'ACTB': 1,
#   'POTEF': 1,
#   'POT1': 1,
#   'PRIM1': 1,
#   'COPS5': 1,
#   'PHF8': 1,
#   'RAD23B': 1,
#   'NF1': 1,
#   'XAB2': 1,
#   'DCAF4': 1,
#   'CNOT3': 1,
#   'DNA2': 1,
#   'EPHA2': 1,
#   'CASP8': 1,
#   'RAD52': 1,
#   'WDR5': 1,
#   'HELZ': 1,
#   'BDP1': 1,
#   'REV3L': 1,
#   'VCP': 1,
#   'ELN': 1,
#   'TGFBR2': 1,
#   'MAP3K5': 1,
#   'SMARCAD1': 1,
#   'NAE1': 1,
#   'HIST1H3J': 1,
#   'XRCC6': 1,
#   'XRCC2': 1,
#   'OR51A7': 1,
#   'BABAM1': 1,
#   'DNMT1': 1,
#   'ATP6V1H': 1,
#   'PCNT': 1,
#   'ELF3': 1,
#   'SUPV3L1': 1,
#   'TRRAP': 1,
#   'DHDDS': 1,
#   'TFRC': 1,
#   'RTEL1': 1,
#   'MAGEA4': 1,
#   'BAZ1A': 1,
#   'CASS4': 1,
#   'RRM2': 1,
#   'WDHD1': 1,
#   'CYP2D6': 1,
#   'GYPA': 1,
#   'RFWD3': 1,
#   'NMRK1': 1,
#   'STAT1': 1,
#   'ZEB1': 1,
#   'FAN1': 1,
#   'MT-CO1': 1,
#   'COMT': 1,
#   'ZNF830': 1,
#   ...},
#  'one_step_genes_pub_counts': {'MGI:6258233': 0,
#   'MGI:6258236': 0,
#   'MGI:1195972': 0,
#   '18S_rRNA': 0,
#   '28S_rRNA': 0,
#   '45S_rRNA': 0,
#   '7SK': 0,
#   'CASC15': 0,
#   'CYP26B1': 0,
#   'CFTR': 0,
#   'USP28': 0,
#   'CRY1': 0,
#   'CD4': 0,
#   'UBR7': 0,
#   'ERCC1': 2,
#   'CDH17': 0,
#   'GABARAPL2': 0,
#   'RFC2': 0,
#   'KIAA2022': 0,
#   'GNA11': 0,
#   'AQR': 0,
#   'ST6GALNAC1': 0,
#   'NOX3': 0,
#   'TNFRSF1A': 0,
#   'PIGB': 0,
#   'TRIP13': 0,
#   'KRT14': 0,
#   'FGF4': 0,
#   'KEAP1': 0,
#   'TNS1': 0,
#   'RRN3': 0,
#   'PPP1R15A': 0,
#   'PPP1R13B': 0,
#   'SIRT4': 0,
#   'OTUB2': 0,
#   'OSGEP': 0,
#   'ADH1A': 0,
#   'CDC6': 0,
#   'CBX5': 0,
#   'VCL': 0,
#   'SIRT1': 0,
#   'CDC34': 0,
#   'GADD45B': 0,
#   'MAPK1': 0,
#   'DMC1': 0,
#   'HSCB': 0,
#   'XBP1': 0,
#   'HMOX1': 0,
#   'MCM5': 0,
#   'TXN2': 0,
#   'RBX1': 0,
#   'ACO2': 0,
#   'BRD1': 0,
#   'SUPT16H': 0,
#   'POLE2': 0,
#   'ALKBH1': 0,
#   'MTHFD1': 0,
#   'APEX1': 0,
#   'EFS': 0,
#   'NFKBIA': 0,
#   'CYP24A1': 0,
#   'AURKA': 0,
#   'EEF1A2': 0,
#   'CSNK2A1': 0,
#   'FERMT1': 0,
#   'TBL1X': 0,
#   'USP11': 0,
#   'TIMP1': 0,
#   'NTHL1': 0,
#   'MMP2': 0,
#   'POLR2C': 0,
#   'USB1': 0,
#   'MPG': 0,
#   'TSC2': 0,
#   'STUB1': 0,
#   'TGM5': 0,
#   'AGO2': 0,
#   'SFRP1': 0,
#   'CHRAC1': 0,
#   'GML': 0,
#   'GSR': 0,
#   'TNFRSF10A': 0,
#   'RNASEH2A': 0,
#   'FBL': 0,
#   'CLC': 0,
#   'POLR2I': 0,
#   'TGFB1': 0,
#   'CRX': 0,
#   'HGF': 0,
#   'NAMPT': 0,
#   'CYP3A5': 0,
#   'SERPINE1': 0,
#   'RPA3': 0,
#   'SETX': 0,
#   'CYP26A1': 0,
#   'OBFC1': 0,
#   'PPIF': 0,
#   'MPO': 0,
#   'CSF3': 0,
#   'SUPT4H1': 0,
#   'RPS6KB1': 0,
#   'MED31': 0,
#   'DDX5': 0,
#   'CCL2': 0,
#   'CCL1': 0,
#   'KAT2A': 0,
#   'COL1A1': 0,
#   'CD38': 0,
#   'AFM': 0,
#   'PHOX2B': 0,
#   'NFKB1': 0,
#   'IL2': 0,
#   'GAR1': 0,
#   'CCND1': 0,
#   'PRPF19': 0,
#   'KITLG': 0,
#   'CYP27B1': 0,
#   'GLI1': 0,
#   'RAD51AP1': 0,
#   'CDKN1B': 0,
#   'IFNG': 0,
#   'NUP107': 0,
#   'CNOT2': 0,
#   'GAPDH': 0,
#   'USP5': 0,
#   'TPI1': 0,
#   'APOBEC1': 0,
#   'NANOG': 0,
#   'AICDA': 0,
#   'GCLC': 0,
#   'ASF1A': 0,
#   'FBXO5': 0,
#   'FANCE': 0,
#   'MAPK14': 0,
#   'B3GAT2': 0,
#   'GMNN': 0,
#   'SKIV2L2': 0,
#   'PAPD7': 0,
#   'LOX': 0,
#   'IL4': 0,
#   'SKP1': 0,
#   'NR3C1': 0,
#   'RARS': 0,
#   'MLH1': 0,
#   'UBE3A': 0,
#   'RBP2': 0,
#   'RBP1': 0,
#   'NPRL2': 0,
#   'UMPS': 0,
#   'MSH2': 0,
#   'TFPI': 0,
#   'TLX2': 0,
#   'ID2': 0,
#   'ODC1': 0,
#   'PLEK': 0,
#   'MSH6': 0,
#   'MAD2L2': 0,
#   'PRDM2': 0,
#   'A4GNT': 0,
#   'TTR': 0,
#   'TBPL1': 0,
#   'PKD2': 0,
#   'ABCG2': 0,
#   'CPSF3': 0,
#   'DDX55': 0,
#   'FKBP15': 0,
#   'VPS4B': 0,
#   'DUSP1': 0,
#   'CCDC170': 0,
#   'EGR1': 0,
#   'COIL': 0,
#   'CAT': 0,
#   'POLK': 0,
#   'FLT3': 0,
#   'AHR': 0,
#   'EEPD1': 0,
#   'INHBA': 0,
#   'UNG': 0,
#   'BHLHE41': 0,
#   'ATP7B': 0,
#   'RIF1': 0,
#   'ZNF350': 0,
#   'PI3': 0,
#   'SNAI1': 0,
#   'MOCS3': 0,
#   'IL17C': 0,
#   'SNRPC': 0,
#   'HIST1H4F': 0,
#   'MT2A': 0,
#   'PIWIL1': 0,
#   'MRPS7': 0,
#   'THOC2': 0,
#   'FOSB': 0,
#   'VASP': 0,
#   'SYMPK': 0,
#   'CDC25B': 0,
#   'UBA2': 0,
#   'NR1D1': 0,
#   'SUGP1': 0,
#   'DDX49': 0,
#   'HELB': 0,
#   'PIN1': 0,
#   'GFER': 0,
#   'HSPB1': 0,
#   'CCDC117': 0,
#   'LIF': 0,
#   'SIRT2': 0,
#   'PIAS1': 0,
#   'MBD4': 0,
#   'MYOD1': 0,
#   'BCL2L2': 0,
#   'PARP2': 0,
#   'NEDD8': 0,
#   'SLX1A': 0,
#   'TUBG2': 0,
#   'NARFL': 0,
#   'KRT31': 0,
#   'RRM2B': 0,
#   'RAF1': 0,
#   'MED17': 0,
#   'TRPC4AP': 0,
#   'CUL9': 0,
#   'KRT5': 0,
#   'KRT75': 0,
#   'KRT6B': 0,
#   'APOE': 0,
#   'GADD45G': 0,
#   'JUND': 0,
#   'TAF4': 0,
#   'UBE2M': 0,
#   'TRIM28': 0,
#   'ACSS2': 0,
#   'ABCB7': 0,
#   'NR1H2': 1,
#   'RARA': 0,
#   'FUS': 0,
#   'SNRPA1': 0,
#   'DNAJB1': 0,
#   'PER2': 0,
#   'RPA1': 0,
#   'H3F3B': 0,
#   'ERAL1': 0,
#   'TERF2': 1,
#   'IGHMBP2': 0,
#   'MTL5': 0,
#   'PEMT': 0,
#   'CCNA1': 0,
#   'KRAS': 0,
#   'EIF2S1': 0,
#   'ELP3': 0,
#   'MBD2': 0,
#   'CCNB1': 0,
#   'CDK7': 0,
#   'GSTM3': 0,
#   'CCNH': 1,
#   'SLCO1B1': 0,
#   'SPX': 0,
#   'DDB2': 0,
#   'PHC2': 0,
#   'PDGFRA': 0,
#   'APC': 0,
#   'RINT1': 0,
#   'NT5E': 0,
#   'CDK4': 0,
#   'ESPL1': 0,
#   'MDM2': 0,
#   'REV1': 0,
#   'DDX56': 0,
#   'HUS1': 0,
#   'IREB2': 0,
#   'SRSF1': 0,
#   'BRIP1': 0,
#   'KAT7': 0,
#   'SLC31A2': 0,
#   'PSORS1C2': 0,
#   'C6orf15': 0,
#   'GTF2H4': 2,
#   'POU5F1': 0,
#   'GGH': 0,
#   'MMP20': 0,
#   'FDX1': 0,
#   'ADAM10': 0,
#   'CCBL2': 0,
#   'LRPPRC': 0,
#   'CYP2C9': 0,
#   'KIF11': 0,
#   'TOPBP1': 0,
#   'BARD1': 0,
#   'PPIG': 0,
#   'COX17': 0,
#   'MNAT1': 0,
#   'CCND2': 0,
#   'LMNB1': 0,
#   'VWF': 0,
#   'UBE2K': 0,
#   'LIAS': 0,
#   'N4BP2': 0,
#   'SNW1': 0,
#   'PALB2': 0,
#   'NDC80': 0,
#   'KPNA3': 0,
#   'ALDH2': 0,
#   'CDH1': 0,
#   'TIPIN': 0,
#   'CCNT1': 0,
#   'PIK3C3': 0,
#   'MCM4': 0,
#   'RBL2': 0,
#   'SMAD2': 0,
#   'YY1': 0,
#   'NUBP2': 0,
#   'TCEB2': 0,
#   'CHTF18': 0,
#   'AXIN1': 0,
#   'CREBBP': 0,
#   'DHX8': 0,
#   'CSNK2A2': 0,
#   'SRCAP': 0,
#   'SETD1A': 0,
#   'ZNF629': 0,
#   'CCNE1': 0,
#   'CDKN2C': 0,
#   'ACIN1': 0,
#   'ELL': 0,
#   'MAU2': 0,
#   'SAMHD1': 0,
#   'XRCC1': 0,
#   'E2F3': 0,
#   'PIAS4': 0,
#   'MAPK3': 0,
#   'SMARCB1': 0,
#   'MSH4': 0,
#   'UFD1L': 0,
#   'EP300': 0,
#   'LIG1': 0,
#   'TYR': 0,
#   'IL1A': 0,
#   'IL1B': 0,
#   'BRD4': 0,
#   'ASF1B': 0,
#   'MED26': 0,
#   'BIRC3': 0,
#   'TAF1B': 0,
#   'POLD3': 0,
#   'SNRNP40': 0,
#   'SGOL1': 0,
#   'KAT2B': 0,
#   'WDR76': 0,
#   'AKT3': 0,
#   'POLR1A': 0,
#   'KDR': 0,
#   'PIK3CA': 0,
#   'TAF12': 0,
#   'CTCF': 0,
#   'TUBB4A': 0,
#   'HAT1': 0,
#   'MCM6': 0,
#   'CCNT2': 0,
#   'ZRANB3': 0,
#   'PPAT': 0,
#   'POLQ': 0,
#   'CHST10': 0,
#   'NOP58': 0,
#   'HERC5': 0,
#   'COPS4': 0,
#   'CUL3': 0,
#   'ADD2': 0,
#   'FGF2': 0,
#   'RBBP5': 0,
#   'UBE2S': 0,
#   'GZMM': 0,
#   'NEIL3': 0,
#   'WNT5A': 0,
#   'STAT3': 0,
#   'MTRR': 0,
#   'DNMT3A': 0,
#   'FOSL2': 0,
#   'GPN1': 0,
#   'TP63': 0,
#   'ADD1': 0,
#   'GPBP1': 0,
#   'ICAM1': 0,
#   'KLF1': 0,
#   'SIDT1': 0,
#   'PPARGC1A': 0,
#   'RAD18': 0,
#   'SDHA': 0,
#   'XRN1': 0,
#   'BST1': 0,
#   'ERCC8': 1,
#   'MCM2': 0,
#   'GOLPH3': 0,
#   'SUB1': 0,
#   'MSH3': 0,
#   'CENPE': 0,
#   'LEF1': 0,
#   'EGF': 0,
#   'VDAC1': 0,
#   'UBE2B': 0,
#   'AFF4': 0,
#   'MED20': 0,
#   'TNPO3': 0,
#   'POLB': 0,
#   'CALB1': 0,
#   'NBN': 0,
#   'ADH4': 0,
#   'FBXO3': 0,
#   'DBF4': 0,
#   'CDK6': 0,
#   'SMARCA2': 0,
#   'PMS2': 0,
#   'GTF2H1': 0,
#   'BTAF1': 0,
#   'GABARAPL1': 0,
#   'LGR5': 0,
#   'CDK2': 0,
#   'DHH': 0,
#   'BIN2': 0,
#   'SMARCC2': 0,
#   'ERBB3': 0,
#   'RB1': 0,
#   'TINF2': 0,
#   'FANCM': 0,
#   'FGF7': 0,
#   'UBE2Q2': 0,
#   'BCL2A1': 0,
#   'WDR61': 0,
#   'IGF1R': 0,
#   'PML': 0,
#   'POLG': 0,
#   'TICRR': 0,
#   'DEF8': 0,
#   'NCOR1': 0,
#   'CDH2': 0,
#   'ESCO1': 0,
#   'TP53': 1,
#   'EIF4A3': 0,
#   'ERBB2': 0,
#   'KRT10': 0,
#   'SMG9': 0,
#   'SOD1': 0,
#   'DNMT3L': 0,
#   'SAE1': 0,
#   'RNPEPL1': 0,
#   'ACPT': 0,
#   'PGD': 0,
#   'SETDB1': 0,
#   'RPS27A': 0,
#   'ETAA1': 0,
#   'SFXN5': 0,
#   'SULT1C4': 0,
#   'SLC25A38': 0,
#   'RNF7': 0,
#   'FTH1': 0,
#   'CCNA2': 0,
#   'SETD7': 0,
#   'SKP2': 0,
#   'NHP2': 0,
#   'MUT': 0,
#   'TAAR8': 0,
#   'EGFR': 1,
#   'CCT6A': 0,
#   'NONO': 0,
#   'TNFRSF10B': 1,
#   'GINS4': 0,
#   'TERF1': 0,
#   'NDUFB9': 0,
#   'CDKN2B': 0,
#   'IFNA1': 1,
#   'NOTCH1': 0,
#   'PPRC1': 0,
#   'SSRP1': 0,
#   'RPS3': 0,
#   'ATM': 0,
#   'MTA2': 0,
#   'MYRF': 0,
#   'CEP164': 0,
#   'TM7SF2': 0,
#   'PPP4C': 0,
#   'MMP10': 0,
#   'HNMT': 0,
#   'IL18': 0,
#   'NGLY1': 0,
#   'OXSM': 0,
#   'MYCN': 0,
#   'NUBPL': 0,
#   'FBXW7': 0,
#   'GRID2': 0,
#   'CRYGC': 0,
#   'FLT1': 0,
#   'NIPBL': 0,
#   'GJA1': 0,
#   'NUBP1': 0,
#   'RIOK2': 0,
#   'SMARCA5': 0,
#   'HNRNPU': 0,
#   'RANBP2': 0,
#   'GTF2E1': 0,
#   'CEBPG': 0,
#   'NEIL2': 0,
#   'DHX32': 0,
#   'APP': 0,
#   'XPC': 0,
#   'ABCC3': 0,
#   'ERCC3': 13,
#   'HSPA13': 0,
#   'PDIA4': 0,
#   'CASP10': 0,
#   'MED7': 0,
#   'NAT2': 0,
#   'GNAQ': 0,
#   'DCK': 0,
#   'UBE2L6': 0,
#   'NSMCE2': 0,
#   'BUB1B': 0,
#   'FANCD2': 0,
#   'EXOG': 0,
#   'PPARG': 0,
#   'DDX19B': 0,
#   'KIT': 0,
#   'ERCC6L2': 0,
#   'FANCC': 0,
#   'EIF5B': 0,
#   'HOXB13': 0,
#   'BTG2': 0,
#   'UBR1': 0,
#   'MED8': 0,
#   'GSTT2B': 0,
#   'SSU72': 0,
#   'TFF2': 0,
#   'TFF1': 0,
#   'SHKBP1': 0,
#   'CCR5': 0,
#   'FGFR4': 0,
#   'ALKBH4': 0,
#   'POLR2J': 0,
#   'STAT5B': 0,
#   'WNT1': 0,
#   'MED11': 0,
#   'EIF4A1': 0,
#   'SLX4': 0,
#   'USP24': 0,
#   'FAM71A': 0,
#   'REL': 0,
#   'SPRTN': 0,
#   'HPGDS': 0,
#   'HELQ': 0,
#   'MITF': 0,
#   'IHH': 0,
#   'CHCHD4': 0,
#   'ALB': 0,
#   'SNRK': 0,
#   'RHO': 0,
#   'MASP1': 0,
#   'UBXN7': 0,
#   'H2AFZ': 0,
#   'SAP30': 0,
#   'MAD2L1': 0,
#   'ANXA5': 0,
#   'ABCE1': 0,
#   'SLC45A2': 0,
#   'RICTOR': 0,
#   'TNFRSF21': 0,
#   'IL3': 0,
#   'CSF2': 0,
#   'NPM1': 0,
#   'HSPA9': 1,
#   'SHH': 0,
#   'RAD21': 0,
#   'ORC5': 0,
#   'NOS3': 0,
#   'ALDH1A1': 0,
#   'WRN': 0,
#   'PCF11': 0,
#   'HPRT1': 0,
#   'WAPAL': 0,
#   'LRRK2': 0,
#   'PIWIL4': 0,
#   'COPS2': 0,
#   'TAF10': 0,
#   'RAG1': 0,
#   'ATMIN': 0,
#   'POLR2M': 0,
#   'HSP90B1': 0,
#   'MMP3': 0,
#   'PPIB': 0,
#   'FAM96A': 0,
#   'KIAA0101': 0,
#   'TERF2IP': 0,
#   'PLK1': 0,
#   'XRCC6BP1': 0,
#   'MED1': 0,
#   'RRM1': 0,
#   'CDT1': 0,
#   'KMT2D': 0,
#   'CYP2A6': 0,
#   'PSCA': 0,
#   'CHAF1A': 0,
#   'ICT1': 0,
#   'EVPL': 0,
#   'DDB1': 0,
#   'POLR2G': 0,
#   'FADD': 0,
#   'LGALS4': 0,
#   'MGMT': 0,
#   'ALKBH3': 0,
#   'HEXIM2': 0,
#   'HSPB2': 0,
#   'POLR1D': 0,
#   'MAP2K1': 0,
#   'BUB1': 0,
#   'BCL2L1': 0,
#   'AGXT': 0,
#   'UBTF': 0,
#   'IGF1': 0,
#   'PAIP1': 0,
#   'DDI1': 0,
#   'RPS9': 0,
#   'HSPA4': 0,
#   'HDAC3': 0,
#   'TMEM37': 0,
#   'UGT1A6': 0,
#   'HSPB3': 0,
#   'CDC25A': 0,
#   'UBE2E1': 0,
#   'CTLA4': 0,
#   'C7orf33': 0,
#   'PYDC1': 0,
#   'MPLKIP': 0,
#   'UGT1A8': 0,
#   'IRS1': 0,
#   'IL13': 0,
#   'ADRB2': 0,
#   'CEBPB': 0,
#   'TUB': 0,
#   'FEN1': 0,
#   'PCBP1': 0,
#   'SF3B3': 0,
#   'FOS': 1,
#   'CXCL8': 0,
#   'OGG1': 0,
#   'ADH1B': 0,
#   'PPM1D': 0,
#   'BOLA2B': 0,
#   'ESCO2': 0,
#   'APLF': 0,
#   'TEX37': 0,
#   'ING2': 0,
#   'EIF2AK3': 0,
#   'RPTOR': 0,
#   'MCM7': 0,
#   'DDIT4': 0,
#   'WDR48': 1,
#   'TADA3': 0,
#   'HIST1H1E': 0,
#   'CYCS': 0,
#   'MUS81': 0,
#   'U2AF2': 0,
#   'EEF2': 0,
#   'RNASEH2C': 0,
#   'LEMD3': 0,
#   'H2AFV': 0,
#   'APITD1': 0,
#   'GLE1': 0,
#   'CLOCK': 0,
#   'SLC19A1': 0,
#   'PLG': 0,
#   'HLTF': 0,
#   'CATSPER1': 0,
#   'ACO1': 0,
#   'KLF7': 0,
#   'TERT': 0,
#   'C10orf2': 0,
#   'ADAT1': 0,
#   'CD34': 0,
#   'FOSL1': 0,
#   'BANF1': 0,
#   'RMI2': 0,
#   'ERCC4': 5,
#   'PSMC5': 0,
#   'MAP9': 0,
#   'ISCU': 0,
#   'FBXW8': 0,
#   'DDX23': 0,
#   'FANCI': 0,
#   'CASP3': 0,
#   'DNAH7': 0,
#   'RAD9A': 0,
#   'POLD4': 0,
#   'GSTM1': 0,
#   'TNKS': 0,
#   'PPP1R8': 0,
#   'UCP2': 0,
#   'TPMT': 0,
#   'AOC3': 0,
#   'CFLAR': 0,
#   'LEP': 0,
#   'TAF7': 0,
#   'HNF4A': 0,
#   'CLSPN': 0,
#   'PABPC1': 0,
#   'FBXW5': 0,
#   'ATAD5': 0,
#   'RNASEH1': 0,
#   'PRKDC': 0,
#   'LGALS7B': 0,
#   'ZNF436': 0,
#   'ABCF1': 0,
#   'SSNA1': 0,
#   'CTC1': 0,
#   'PRIMPOL': 0,
#   'AURKB': 0,
#   'SENP3': 0,
#   'HIC1': 0,
#   'CHRNA3': 0,
#   'TYMS': 0,
#   'STAT2': 0,
#   'NUP98': 0,
#   'CCDC101': 0,
#   'UBE2N': 0,
#   'SFXN1': 0,
#   'RMI1': 0,
#   'SNRNP200': 0,
#   'SAMD4B': 0,
#   'MET': 0,
#   'RECQL5': 0,
#   'PRR15': 0,
#   'RBBP6': 0,
#   'DUOX1': 0,
#   'FUBP3': 0,
#   'NCL': 0,
#   'RUVBL1': 0,
#   'INTS3': 0,
#   'SF3B2': 0,
#   'GEN1': 0,
#   'CETN1': 0,
#   'SUPT6H': 0,
#   'PRMT5': 0,
#   'SULT1C2': 0,
#   'CXCR2': 0,
#   'NQO1': 0,
#   'ZNF687': 0,
#   'TMEM11': 0,
#   'EZH2': 0,
#   'PKM': 0,
#   'ARID1A': 0,
#   'ING3': 0,
#   'CALR': 0,
#   'RNF168': 0,
#   'CNOT1': 0,
#   'RCHY1': 0,
#   'TALDO1': 0,
#   'CDC25C': 0,
#   'DSCC1': 0,
#   'RPLP2': 0,
#   'TUFM': 0,
#   'DCTPP1': 0,
#   'POLE': 0,
#   'MMP1': 0,
#   'NDUFAF3': 0,
#   'ATRIP': 0,
#   'E2F7': 0,
#   'SMC1A': 0,
#   'PNKP': 0,
#   'SOX2': 0,
#   'POLR2L': 0,
#   'HSPA5': 0,
#   'WRAP53': 0,
#   'TCHP': 0,
#   'BAIAP3': 0,
#   'ULK1': 0,
#   'GSK3B': 0,
#   'STK11': 0,
#   'ZNF569': 0,
#   'PGR': 0,
#   'METAP2': 0,
#   'KIR3DL2': 0,
#   'TMC8': 0,
#   'PARP10': 0,
#   'RNF40': 0,
#   'MRE11A': 0,
#   'PPP1CA': 0,
#   'TUBA3D': 0,
#   'PMAIP1': 0,
#   'PSEN1': 0,
#   'EIF4A2': 0,
#   'CWF19L1': 0,
#   'CUL1': 0,
#   'MAF': 0,
#   'LMNB2': 0,
#   'NOS2': 0,
#   'NPTXR': 0,
#   'NKX2-5': 0,
#   'JAG2': 0,
#   'PIF1': 0,
#   'TRAIP': 0,
#   'RNF135': 0,
#   'DNMT3B': 0,
#   'GLRX5': 0,
#   'HEXIM1': 0,
#   'EFNA5': 0,
#   'GTF2H2': 0,
#   'SLX1B': 0,
#   'SIVA1': 0,
#   'SP1': 0,
#   'SIRT7': 0,
#   'CADM1': 0,
#   'TBK1': 0,
#   'UPP1': 0,
#   'CASP9': 0,
#   'NDNL2': 0,
#   'FANCF': 0,
#   'RPS27L': 0,
#   'BOLA2': 0,
#   'HGS': 0,
#   'MORF4L1': 0,
#   'WT1': 0,
#   'BOLA3': 0,
#   'NPLOC4': 0,
#   'CYLC1': 0,
#   'OR2T29': 0,
#   'IDH2': 0,
#   'HIST2H2AC': 0,
#   'NOP10': 0,
#   'ATP6V0A2': 0,
#   'RARB': 0,
#   'PTCH1': 1,
#   'COL7A1': 0,
#   'NDN': 0,
#   'SMAD3': 0,
#   'ACTRT3': 0,
#   'UBA7': 0,
#   'C17orf70': 0,
#   'USP45': 0,
#   'MTA1': 0,
#   'TTF1': 0,
#   'ABCC5': 0,
#   'RPS19BP1': 0,
#   'HBB': 0,
#   'TAC4': 0,
#   'HDAC6': 0,
#   'GATA4': 0,
#   'POLR3C': 0,
#   'TMPRSS11A': 0,
#   'ARID2': 0,
#   'PDCD1': 0,
#   'HSP90AA1': 0,
#   'SF3B1': 0,
#   'CDKN3': 0,
#   'GSTA1': 0,
#   'KRTAP19-2': 0,
#   'RAD54B': 0,
#   'CBX3': 0,
#   'RAD51C': 0,
#   'DHX15': 0,
#   'SUPT7L': 0,
#   'ATF4': 0,
#   'CENPA': 0,
#   'UNC119': 0,
#   'ZNF354A': 0,
#   'SIRT6': 0,
#   'MED19': 0,
#   'TDP1': 0,
#   'DACT1': 0,
#   'RNASEH2B': 0,
#   'MAPK15': 0,
#   'LCK': 0,
#   'CYP3A4': 0,
#   'SUV39H1': 0,
#   'LMO1': 0,
#   'NPAS2': 0,
#   'SNCA': 0,
#   'UBA1': 0,
#   'EEF1A1': 0,
#   'RPS7': 0,
#   'NELFB': 0,
#   'DFFB': 0,
#   'HIST1H1C': 0,
#   'FGFR3': 0,
#   'LBR': 0,
#   'TAF1A': 0,
#   'C7orf26': 0,
#   'UBE2V1': 0,
#   'KAT5': 0,
#   'SENP8': 0,
#   'NMNAT3': 0,
#   'HUWE1': 0,
#   'ELSPBP1': 0,
#   'MAOA': 0,
#   'EIF4EBP1': 0,
#   'MAPT': 0,
#   'GTF2F2': 0,
#   'ZC3H12B': 0,
#   'SFN': 0,
#   'STAT5A': 0,
#   'RANBP3': 0,
#   'SLC24A5': 0,
#   'SMAD4': 0,
#   'FAM111B': 0,
#   'HNRNPA1': 0,
#   'CYP1A2': 0,
#   'SLPI': 0,
#   'SLC25A15': 0,
#   'FOXM1': 0,
#   'BAZ1B': 0,
#   'EYA1': 0,
#   'PPM1G': 0,
#   'POLR2K': 0,
#   'MCPH1': 0,
#   'UBE4B': 0,
#   'BRE': 0,
#   'TCEA2': 0,
#   'USP1': 0,
#   'USP7': 0,
#   'HOXA9': 0,
#   'FOXN2': 0,
#   'ATR': 0,
#   'ESR2': 0,
#   'IL17A': 0,
#   'TP53INP1': 0,
#   'ATF3': 0,
#   'LIN28B': 0,
#   'CTNNB1': 0,
#   'NR4A2': 0,
#   'H1F0': 0,
#   'NF2': 0,
#   'DHRS2': 0,
#   'FBXL5': 0,
#   'GSTO2': 0,
#   'UBQLN2': 0,
#   'HMGB1': 0,
#   'PCDHB13': 0,
#   'E2F1': 0,
#   'ATP7A': 0,
#   'DPY30': 0,
#   'RPS21': 0,
#   'RPL3': 0,
#   'RPS3A': 0,
#   'DDX21': 0,
#   'PRKAA1': 0,
#   'TAP1': 0,
#   'ATG7': 0,
#   'OR5H1': 0,
#   'THRAP3': 0,
#   'OCA2': 0,
#   'FN1': 0,
#   'SERF1A': 0,
#   'HIST1H4J': 0,
#   'NEIL1': 0,
#   'HTT': 0,
#   'BLM': 2,
#   'ANO1': 0,
#   'ARID4A': 0,
#   'RET': 0,
#   'ERCC5': 10,
#   'FAS': 0,
#   'MLH3': 0,
#   'UBE2I': 0,
#   'SREBF1': 0,
#   'ERCC6': 1,
#   'C1D': 0,
#   'GTF2E2': 0,
#   'SPEF2': 0,
#   'ZNF44': 0,
#   'UVRAG': 0,
#   'GTF3C1': 0,
#   'TMEM259': 0,
#   'PPP4R2': 0,
#   'NHEJ1': 0,
#   'SCRIB': 0,
#   'CHD4': 0,
#   'RASSF1': 0,
#   'DCTD': 0,
#   'XPNPEP3': 0,
#   'UBE2D3': 0,
#   'SMARCAL1': 0,
#   'ACTB': 0,
#   'POTEF': 0,
#   'POT1': 0,
#   'PRIM1': 0,
#   'COPS5': 0,
#   'PHF8': 0,
#   'RAD23B': 0,
#   'NF1': 0,
#   'XAB2': 0,
#   'DCAF4': 0,
#   'CNOT3': 0,
#   'DNA2': 0,
#   'EPHA2': 0,
#   'CASP8': 0,
#   'RAD52': 0,
#   'WDR5': 0,
#   'HELZ': 0,
#   'BDP1': 0,
#   'REV3L': 0,
#   'VCP': 0,
#   'ELN': 0,
#   'TGFBR2': 0,
#   'MAP3K5': 0,
#   'SMARCAD1': 0,
#   ...},
#  'disease_to_genes_list': ['ERCC3',
#   'ERCC2',
#   'XPA',
#   'POLH',
#   'ERCC5',
#   'ERCC4',
#   'XPC',
#   'DDB2',
#   'EDNRA',
#   'HFM1',
#   'GTF2H4',
#   'ERCC1',
#   'MYC',
#   'APAF1',
#   'DDX11',
#   'ENDOV',
#   'MMS19',
#   'BBC3',
#   'ZC3H12D',
#   'CDKN1A',
#   'BCL2',
#   'POLM',
#   'MAPK8',
#   'PCNA',
#   'FXN',
#   'HSPA1A',
#   'GADD45A',
#   'CETN2',
#   'NRAS',
#   'ERCC6',
#   'FAS',
#   'BLM',
#   'SFN',
#   'PTCH1',
#   'PMAIP1',
#   'DCTPP1',
#   'WDR48',
#   'FOS',
#   'HSPA9',
#   'BTG2',
#   'IFNA1',
#   'TNFRSF10B',
#   'EGFR',
#   'TP53',
#   'GTF2H1',
#   'ERCC8',
#   'POLQ',
#   'CCNH',
#   'TERF2',
#   'RPA1',
#   'NR1H2',
#   'RRM2B',
#   'AAGAB',
#   'WDR77',
#   'PSMC6',
#   'LRRC59',
#   'CSH1',
#   'CPD',
#   'ERVK-11',
#   'ERVK-19',
#   'ERVK-9',
#   'FASTK',
#   'REXO2',
#   'PERP',
#   'FASN',
#   'TRIAP1',
#   'SUSD6',
#   'AEN',
#   'BAX',
#   'hsa_circ_000559',
#   'MIR890',
#   'MIR744',
#   'MIR6771',
#   'MIR6732',
#   'MIR373',
#   'MIR346',
#   'MIR21',
#   'U2',
#   'U12',
#   'U11',
#   'TERC',
#   'TARID',
#   'SCAANT1',
#   'RNR3',
#   'RN5S1@',
#   'Pinc',
#   'MEG8',
#   'LINC01197',
#   'LINC00302',
#   'HCG14',
#   'FAM230A',
#   'FAM157B',
#   'MUC13',
#   'HIST1H3B',
#   'MUC1',
#   'HIST1H4E',
#   'HIST1H3C',
#   'HIST1H3G',
#   'LIG4',
#   'PRIM2',
#   'HIST1H3F',
#   'CD24',
#   'IKBKG',
#   'CHD1',
#   'RDM1',
#   'HAO2',
#   'NTMT1',
#   'HIST1H3I',
#   'HNRNPDL',
#   'ACD',
#   'CRABP2',
#   'C9orf72',
#   'ZNF501',
#   'MED22',
#   'RECQL4',
#   'HIST1H3E',
#   'CGA',
#   'PER3',
#   'PCGF2',
#   'IP6K1',
#   'MED6',
#   'C18orf25',
#   'HIST1H4I',
#   'SLC38A3',
#   'E2F8',
#   'TADA2A',
#   'SHFM1',
#   'MCM3',
#   'HIST1H4L',
#   'HIST1H3A',
#   'FGF1',
#   'GRIP2',
#   'WBSCR16',
#   'POLD2',
#   'POLR2A',
#   'EPHX1',
#   'ALOX5AP',
#   'CIB1',
#   'HIST1H4K',
#   'UHRF1',
#   'RHNO1',
#   'KIZ',
#   'PCID2',
#   'HIST1H4D',
#   'HNRNPCL1',
#   'HIST1H4A',
#   'LTN1',
#   'RAG2',
#   'LEPREL2',
#   'VEGFA',
#   'CYP1B1',
#   'ATXN3',
#   'POLR2E',
#   'IGHV4-38-2',
#   'ABCB1',
#   'CRY2',
#   'ANXA8',
#   'SRD5A2',
#   'NAP1L1',
#   'APBB1',
#   'FRRS1L',
#   'HIST2H3PS2',
#   'RPAP2',
#   'SIRT5',
#   'GTF2H5',
#   'POLDIP2',
#   'HIST2H2AA3',
#   'COMMD3-BMI1',
#   'BIVM-ERCC5',
#   'RUVBL2',
#   'RPS5',
#   'IRF3',
#   'SUPT5H',
#   'UPF1',
#   'TTN',
#   'MUM1',
#   'RAD23A',
#   'AC004223.3',
#   'LSM12',
#   'RAD51D',
#   'C19orf40',
#   'GALK1',
#   'POLRMT',
#   'PIAS2',
#   'TMC6',
#   'CD3EAP',
#   'MFSD11',
#   'RPL26',
#   'RBFOX3',
#   'KLF14',
#   'RBM8A',
#   'HIST2H4A',
#   'POLI',
#   'HIST2H4B',
#   'ZP2',
#   'CTRL',
#   'ACTG1',
#   'TGFBR3L',
#   'COX4I1',
#   'PECAM1',
#   'EME2',
#   'WWOX',
#   'DET1',
#   'MRC1',
#   'TAF1C',
#   'C16orf52',
#   'ASIP',
#   'RNF111',
#   'B2M',
#   'BCL2L2-PABPN1',
#   'ISCA2',
#   'XRCC3',
#   'AKT1',
#   'NDRG2',
#   'MC1R',
#   'AC092143.1',
#   'HNRNPC',
#   'H326',
#   'ZBTB1',
#   'SMEK1',
#   'TIMELESS',
#   'MRPL42',
#   'DDIT3',
#   'BRF1',
#   'VDR',
#   'SOD2',
#   'GTF2H3',
#   'CUL2',
#   'CYFIP2',
#   'SCO2',
#   'OTUB1',
#   'CITED2',
#   'POLR1B',
#   'NAT1',
#   'HIST4H4',
#   'TET2',
#   'GPN3',
#   'HTATSF1',
#   'TOP3A',
#   'CAND1',
#   'ITGAM',
#   'UBC',
#   'NNMT',
#   'CYP2E1',
#   'PHC1',
#   'PSMD9',
#   'ATXN7',
#   'DMXL1',
#   'RIMS4',
#   'NFE2',
#   'AL139300.1',
#   'CUL7',
#   'TIMM8B',
#   'KLRF2',
#   'MDH1',
#   'HIF1A',
#   'CD19',
#   'HMGA2',
#   'TNKS1BP1',
#   'DICER1',
#   'MUC5B',
#   'NXF1',
#   'EIF3M',
#   'POLN',
#   'FAU',
#   'FAM111A',
#   'PUF60',
#   'H2AFX',
#   'C11orf30',
#   'CASP1',
#   'HSPA8',
#   'HSF1',
#   'NTRK1',
#   'IKBKB',
#   'HDAC2',
#   'RNF130',
#   'LYRM2',
#   'ENY2',
#   'ERI1',
#   'SLC25A37',
#   'CCNC',
#   'TCEA1',
#   'CETN3',
#   'UBE2V2',
#   'RPL30',
#   'NACA2',
#   'CEBPA',
#   'PROM1',
#   'RNF4',
#   'RNASET2',
#   'ASTE1',
#   'RAD17',
#   'ADH1C',
#   'DROSHA',
#   'EIF4E',
#   'NEDD4',
#   'PLRG1',
#   'SMUG1',
#   'FBXL7',
#   'CSB-PGBD3',
#   'MRPL36',
#   'PAQR3',
#   'XRCC4',
#   'TIPARP',
#   'TFAM',
#   'BAG1',
#   'LAT2',
#   'PHC3',
#   'ADH7',
#   'NR6A1',
#   'POLE4',
#   'ZMYND8',
#   'LYRM4',
#   'POR',
#   'CDK5',
#   'SSBP1',
#   'NUDT5',
#   'RAD51B',
#   'BRCA1',
#   'CDKN2A',
#   'NDUFA6',
#   'FTO',
#   'UBN2',
#   'TAF1L',
#   'CIAO1',
#   'MCM10',
#   'RPL37A',
#   'FHIT',
#   'BAP1',
#   'DHX36',
#   'PHACTR2',
#   'RECQL',
#   'FDXR',
#   'SLC2A1',
#   'EIF4G1',
#   'TRANK1',
#   'SLC35A2',
#   'CTCFL',
#   'DCAF11',
#   'POLR2H',
#   'INTS12',
#   'KLC1',
#   'RPS24',
#   'BDNF',
#   'INTS2',
#   'CDKN1C',
#   'C7orf25',
#   'IL10',
#   'TOP2A',
#   'PTPRC',
#   'TLK1',
#   'STMN1',
#   'MAP2K4',
#   'POC5',
#   'SUMO3',
#   'OTUD4',
#   'CHTF8',
#   'RFC5',
#   'FBP1',
#   'HRAS',
#   'GPX1',
#   'TAF1',
#   'PMS1',
#   'TCEA3',
#   'SLC13A5',
#   'POLD1',
#   'KAT8',
#   'SUMO2',
#   'CDC45',
#   'CLMP',
#   'ESR1',
#   'SMC6',
#   'PPP1R13L',
#   'BRAP',
#   'LTA',
#   'PMEL',
#   'SENP6',
#   'SMG1',
#   'WEE1',
#   'RANGAP1',
#   'ERN1',
#   'APTX',
#   'PNPT1',
#   'RHOA',
#   'EWSR1',
#   'TAF6',
#   'HMGA1',
#   'CDK12',
#   'TNF',
#   'CD44',
#   'L3MBTL1',
#   'DIABLO',
#   'ALKBH2',
#   'E2F5',
#   'NFIC',
#   'TOP2B',
#   'DHFR',
#   'CLEC2A',
#   'SMARCA4',
#   'TCEB3',
#   'MECP2',
#   'BTBD19',
#   'SENP1',
#   'SESN1',
#   'FGFR1',
#   'VPRBP',
#   'CDC7',
#   'HTATIP2',
#   'DCT',
#   'CHFR',
#   'PPP6C',
#   'CHD7',
#   'IGF2',
#   'TKT',
#   'CYB561D2',
#   'SLC16A5',
#   'GLI2',
#   'IDH1',
#   'RNF212',
#   'CHEK1',
#   'PARN',
#   'CREB1',
#   'FAM96B',
#   'UBE4A',
#   'LRRC29',
#   'IMMT',
#   'NFU1',
#   'ALDH7A1',
#   'CXCR4',
#   'TET3',
#   'SETD2',
#   'CD8A',
#   'TONSL',
#   'MCC',
#   'DAPK1',
#   'FOXO3',
#   'RPAIN',
#   'MARK2',
#   'SMS',
#   'HERC3',
#   'IL6',
#   'HIPK2',
#   'PPARA',
#   'ELAVL1',
#   'ZNF792',
#   'APOBEC3G',
#   'C1S',
#   'FANCL',
#   'XPO1',
#   'SETD8',
#   'AKAP12',
#   'ARNTL',
#   'TFIP11',
#   'PARG',
#   'APOBEC3A',
#   'RELA',
#   'CUL4B',
#   'POMC',
#   'PAXIP1',
#   'NCOR2',
#   'SUN1',
#   'NHP2L1',
#   'C1orf86',
#   'NEDD4L',
#   'SFI1',
#   'CDC42',
#   'KDM1A',
#   'TUBA3C',
#   'DDX3X',
#   'RUNX3',
#   'RBBP8',
#   'PAICS',
#   'MAP3K1',
#   'NEURL4',
#   'ABCC1',
#   'PARP3',
#   'UBE2D2',
#   'DOT1L',
#   'GSTP1',
#   'TMPRSS2',
#   'FANCB',
#   'CABIN1',
#   'LONRF1',
#   'CRYBB2',
#   'CBSL',
#   'CBS',
#   'KHSRP',
#   'MAP2K7',
#   'RNASE1',
#   'MED13',
#   'PGBD4',
#   'TEN1',
#   'MYCL',
#   'INS',
#   'DEK',
#   'SMU1',
#   'CCNF',
#   'NFE2L2',
#   'NUDT1',
#   'SOX10',
#   'CSNK1E',
#   'DKK3',
#   'CYP19A1',
#   'DDX39B',
#   'EDA2R',
#   'ELP4',
#   'GLI3',
#   'RAE1',
#   'CXCL12',
#   'CXCL1',
#   'TYMP',
#   'SULT1A1',
#   'QPRT',
#   'CDK1',
#   'FZR1',
#   'SPP1',
#   'MATK',
#   'PBRM1',
#   'PRKCD',
#   'ACYP2',
#   'FKBP2',
#   'GTF2F1',
#   'CIAPIN1',
#   'RPL24',
#   'HELLS',
#   'PTTG1',
#   'SLC29A1',
#   'FDX1L',
#   'CDKN2D',
#   'G6PD',
#   'CBX1',
#   'PPP2R4',
#   'EME1',
#   'BCL2L11',
#   'NRF1',
#   'NME2',
#   'NME1-NME2',
#   'CUL5',
#   'DBH',
#   'TDG',
#   'ETS1',
#   'GRB2',
#   'TAOK3',
#   'SRSF2',
#   'RFC4',
#   'STRA13',
#   'SUMO1',
#   'MAP3K4',
#   'XRCC5',
#   'TBP',
#   'PAX3',
#   'AKT2',
#   'HNRNPUL1',
#   'CCNK',
#   'UVSSA',
#   'SQSTM1',
#   'TSN',
#   'RTF1',
#   'EP400',
#   'FANCA',
#   'RNF20',
#   'ALK',
#   'TYRP1',
#   'GPX3',
#   'SETMAR',
#   'NEK11',
#   'RNMT',
#   'STAG1',
#   'WHSC1',
#   'FECH',
#   'SIRT3',
#   'DEFA1',
#   'DEFA1B',
#   'RAD51',
#   'CHEK2',
#   'FBXL18',
#   'SACS',
#   'SOD3',
#   'TP53BP1',
#   'PARP4',
#   'SRXN1',
#   'TNK2',
#   'RFC1',
#   'GART',
#   'JAK2',
#   'CD274',
#   'CDK8',
#   'E2F6',
#   'MLANA',
#   'TGM3',
#   'SLC25A6',
#   'CCP110',
#   'MBD3L2',
#   'LYRM5',
#   'DDX1',
#   'POLR2B',
#   'GTF3A',
#   'IGFBP3',
#   'PDX1',
#   'DUT',
#   'POMP',
#   'WRNIP1',
#   'SERF1B',
#   'HMGN1',
#   'PSIP1',
#   'TLR7',
#   'CNTLN',
#   'BNIP3L',
#   'NAP1L4',
#   'FAM175A',
#   'ZNF763',
#   'CHD3',
#   'AVP',
#   'IFNB1',
#   'IFNA2',
#   'NABP2',
#   'MTAP',
#   'BRCA2',
#   'ITPA',
#   'RBBP7',
#   'RFC3',
#   'FBXO18',
#   'GLRX',
#   'PHKA2',
#   'RREB1',
#   'DDX58',
#   'RIOK1',
#   'SMAD9',
#   'CYP1A1',
#   'KIN',
#   'FOXO1',
#   'ASPH',
#   'NEDD9',
#   'XDH',
#   'ISG15',
#   'LYRM7',
#   'E2F4',
#   'GATA3',
#   'DNAJC2',
#   'NUFIP1',
#   'LYRM9',
#   'POLA1',
#   'MAGEB10',
#   'MCM8',
#   'GALT',
#   'RAD50',
#   'FANCG',
#   'LGALS7',
#   'LIG3',
#   'ATP6AP2',
#   'LPAR6',
#   'APRT',
#   'TP73',
#   'DCLRE1C',
#   'TDP2',
#   'KDM6A',
#   'HIST1H4C',
#   'TRDMT1',
#   'POLR1E',
#   'HIST1H3D',
#   'HIST1H4B',
#   'HIST1H4H',
#   'MGME1',
#   'POLR3F',
#   'SF1',
#   'FTL',
#   'UIMC1',
#   'NMNAT1',
#   'XRN2',
#   'OR2J2',
#   'KLF9',
#   'UBD',
#   'GATA1',
#   'BMI1',
#   'MTHFR',
#   'TLE1',
#   'MDC1',
#   'UBQLN1',
#   'HNRNPK',
#   'FOXP3',
#   'ISCA1',
#   'ING1',
#   'CARD16',
#   'MSH5',
#   'HSPA1B',
#   'EHMT2',
#   'SDHB',
#   'CUL4A',
#   'NELFE',
#   'SKIV2L',
#   'STK19',
#   'FOXE1',
#   'CDA',
#   'PINK1',
#   'GALNT12',
#   'TGFBR1',
#   'APEX2',
#   'ABCA1',
#   'AOX1',
#   'AR',
#   'KLF4',
#   'DAXX',
#   'TXN',
#   'KIF4A',
#   'MAN1C1',
#   'C9orf84',
#   'FOXO4',
#   'CNKSR1',
#   'INIP',
#   'SLC31A1',
#   'POLE3',
#   'GPN2',
#   'NFS1',
#   'MED12',
#   'SPDEF',
#   'PHF20',
#   'AHDC1',
#   'TLR4',
#   'THEMIS2',
#   'UBE2D1',
#   'RPA2',
#   'MED18',
#   'RCC1',
#   'OGT',
#   'PEF1',
#   'RBL1',
#   'BAI2',
#   'TET1',
#   'SRC',
#   'HDAC8',
#   'SCAI',
#   'HDAC1',
#   'RBBP4',
#   'RNF8',
#   'UGT1A1',
#   'UGT1A7',
#   'GLO1',
#   'ATRX',
#   'PGK1',
#   'CDK9',
#   'ADPRHL2',
#   'RPA4',
#   'PGC',
#   'CCND3',
#   'CSTF2',
#   'NOX1',
#   'ADA',
#   'PPIE',
#   'WFDC5',
#   'PLAU',
#   'ZMPSTE24',
#   'EXO5',
#   'WFDC6',
#   'ENDOG',
#   'FOXJ3',
#   'CXorf57',
#   'YBX1',
#   'CDC20',
#   'TJAP1',
#   'POLR1C',
#   'ABL1',
#   'MMP9',
#   'PLK3',
#   'PTCH2',
#   'MUTYH',
#   'RAD54L',
#   'PTEN',
#   'SLC16A12',
#   'C9orf142',
#   'SLC25A5',
#   'UBE2A',
#   'NDOR1',
#   'TCTE1',
#   'CDC5L',
#   'PLCE1',
#   'LRRC42',
#   'CYP2C19',
#   'CYP2C8',
#   'SPO11',
#   'JUN',
#   'XIAP',
#   'DNTT',
#   'SMARCA1',
#   'GSTA4',
#   'PSMA7',
#   'ZZZ3',
#   'USP33',
#   'FUBP1',
#   'RBMX',
#   'GTF2B',
#   'SLC25A28',
#   'FMR1',
#   'ABCC2',
#   'CHUK',
#   'HMGB3',
#   'MB21D1',
#   'CSAG1',
#   'NSDHL',
#   'DPYD',
#   'BTRC',
#   'POLL',
#   'SLC30A7',
#   'NPM3',
#   'SUFU',
#   'CYP17A1',
#   'AS3MT',
#   'CYB561D1',
#   'EMD',
#   'TAF5',
#   'TTK',
#   'OVGP1',
#   'SFR1',
#   'GSTO1',
#   'ME1',
#   'DDX20',
#   'DCLRE1B',
#   'DKC1',
#   'BCAS2',
#   'SYCP1',
#   'RNGTT',
#   'BRCC3',
#   'PHGDH',
#   'CASP7',
#   'CHD1L',
#   'GJA8',
#   'HIST1H3H',
#   'ASCC3',
#   'HIST2H2AA',
#   'HIST2H2BE',
#   'BOLA1',
#   'PRDM1',
#   'ATG5',
#   'AIM1',
#   'MCL1',
#   'NSMCE4A',
#   'PSMD4',
#   'BUB3',
#   'S100A10',
#   'FLG',
#   'C1orf68',
#   'IVL',
#   'LOR',
#   'GLRX3',
#   'ZUFSP',
#   'ROS1',
#   'ADAR',
#   'LMNA',
#   'WDR42A',
#   'MED23',
#   'USF1',
#   'SDHC',
#   'DUSP12',
#   'ATF6',
#   'POU2F1',
#   'ADCY10',
#   'HBS1L',
#   'FASLG',
#   'RNASEL',
#   'DHX9',
#   'RNF2',
#   'SHPRH',
#   'TPR',
#   'PTGS2',
#   'CDC73',
#   'UBE2T',
#   'MDM4',
#   'SLC30A1',
#   'DTL',
#   'NSL1',
#   'SLC22A2',
#   'PARK2',
#   'H3F3A',
#   'PARP1',
#   'THBS2',
#   'IBA57',
#   'ABCB10',
#   'TSNAX',
#   'NTPCR',
#   'MTR',
#   'EXO1',
#   'TFB2M',
#   'APOBEC3C',
#   'E2F2',
#   'BECN1',
#   'DCLRE1A',
#   'COL6A1',
#   'NSMCE1',
#   'CTNNBL1',
#   'MT-ND2',
#   'SMC5',
#   'DMD',
#   'CDC14A',
#   'MT-CO2',
#   'NFE2L1',
#   'SMC3',
#   'TAF11',
#   'MTOR',
#   'MT-CYB',
#   'TOP1',
#   'ZNF830',
#   'COMT',
#   'MT-CO1',
#   'FAN1',
#   'ZEB1',
#   'STAT1',
#   'NMRK1',
#   'RFWD3',
#   'GYPA',
#   'CYP2D6',
#   'WDHD1',
#   'RRM2',
#   'CASS4',
#   'BAZ1A',
#   'MAGEA4',
#   'RTEL1',
#   'TFRC',
#   'DHDDS',
#   'TRRAP',
#   'SUPV3L1',
#   'ELF3',
#   'PCNT',
#   'ATP6V1H',
#   'DNMT1',
#   'BABAM1',
#   'OR51A7',
#   'XRCC2',
#   'XRCC6',
#   'HIST1H3J',
#   'NAE1',
#   'SMARCAD1',
#   'MAP3K5',
#   'TGFBR2',
#   'ELN',
#   'VCP',
#   'REV3L',
#   'BDP1',
#   'HELZ',
#   'WDR5',
#   'RAD52',
#   'CASP8',
#   'EPHA2',
#   'DNA2',
#   'CNOT3',
#   'DCAF4',
#   'XAB2',
#   'NF1',
#   'RAD23B',
#   'PHF8',
#   'COPS5',
#   'PRIM1',
#   'POT1',
#   'POTEF',
#   'ACTB',
#   'SMARCAL1',
#   'UBE2D3',
#   'XPNPEP3',
#   'DCTD',
#   'RASSF1',
#   'CHD4',
#   'SCRIB',
#   'NHEJ1',
#   'PPP4R2',
#   'TMEM259',
#   'GTF3C1',
#   'UVRAG',
#   'ZNF44',
#   'SPEF2',
#   'GTF2E2',
#   'C1D',
#   'SREBF1',
#   'UBE2I',
#   'MLH3',
#   'RET',
#   'ARID4A',
#   'ANO1',
#   'HTT',
#   'NEIL1',
#   'HIST1H4J',
#   'SERF1A',
#   'FN1',
#   'OCA2',
#   'THRAP3',
#   'OR5H1',
#   'ATG7',
#   'TAP1',
#   'PRKAA1',
#   'DDX21',
#   'RPS3A',
#   'RPL3',
#   'RPS21',
#   'DPY30',
#   'ATP7A',
#   'E2F1',
#   'PCDHB13',
#   'HMGB1',
#   'UBQLN2',
#   'GSTO2',
#   'FBXL5',
#   'DHRS2',
#   'NF2',
#   ...]}

# %% [markdown]
# ## 3. Get Top Genes Related to Disease through 1 Intermediate Node

# %%
# get results using intermediates 
node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %%
def predict_many(input_object_list, output_type_list, intermediate_node_list):
    df_list = []
    for input_object in input_object_list: 
        for output_type in output_type_list: 
            for inter in intermediate_node_list:
                try: 
                    print("Intermediate Node type running:")
                    print(inter)
                    fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
                    fc.connect(verbose=False)
                    df = fc.display_table_view()
                    rows = df.shape[0]
                    if(rows > 0):
                        df_list.append(df)
                except:
                    print("FAILED")
    if(len(df_list) > 0):
        return pd.concat(df_list)
    else:
        return None

# %%
disease_to_all_nodes_to_genes = predict_many([disease],['Gene'],node_type_list)
# Save an object to a file
# %store disease_to_all_nodes_to_genes
# Out:
# Intermediate Node type running:
# Gene
# API 3.3 semmed_gene failed
# API 3.2 semmed_gene failed
# API 3.6 semmed_gene failed
# API 3.5 semmed_gene failed
# API 4.1 cord_gene failed
# API 3.4 semmed_gene failed
# API 3.1 semmed_gene failed
# API 3.8 semmed_gene failed
# API 3.7 semmed_gene failed
# API 1.1 mygene failed
# API 3.9 semmed_gene failed
# API 3.10 semmed_gene failed
# Intermediate Node type running:
# SequenceVariant
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# Intermediate Node type running:
# ChemicalSubstance
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# Intermediate Node type running:
# Disease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# Intermediate Node type running:
# MolecularActivity
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# Intermediate Node type running:
# BiologicalProcess
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# Intermediate Node type running:
# CellularComponent
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# Intermediate Node type running:
# Pathway
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# Intermediate Node type running:
# AnatomicalEntity
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# Intermediate Node type running:
# PhenotypicFeature
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# Stored 'disease_to_all_nodes_to_genes' (DataFrame)

# %%
# %store -r disease_to_all_nodes_to_genes

# %%
def get_disease_to_nodes_to_gene_results(disease_all_nodes_genes,max_two_step_gene_count,symptom_list,symptoms_hpids):
    disease_to_node_to_gene_results = {}
    print("finding intermediate nodes that are symptoms")
    indices_with_symptom_as_intermediate = []
    go_dict = {}
    ## remove all rows with symptoms as intermediates -- first get indices, then remove
    for index, row in enumerate(disease_all_nodes_genes.iterrows()):
        row = disease_all_nodes_genes.iloc[index]
        if row["node1_type"] == 'Disease':
            if row["node1_name"].upper() in symptom_list:
                indices_with_symptom_as_intermediate.append(index)
        elif row["node1_type"] == 'BiologicalProcess':
            if row["node1_name"].upper() in symptom_list:
                indices_with_symptom_as_intermediate.append(index)
        elif row["node1_type"] == 'PhenotypicFeature':
            if((row["node1_name"].upper() in symptom_list) or (row["node1_name"] in symptoms_hpids)):
                indices_with_symptom_as_intermediate.append(index)

    # print("indices")
    # print(indices_with_symptom_as_intermediate)
    print("removing symptom intermediates")
    disease_all_nodes_genes = disease_all_nodes_genes.drop(disease_all_nodes_genes.index[indices_with_symptom_as_intermediate])

    print("getting gene counts from " + str(len(list(disease_all_nodes_genes["output_name"]))) + " gene entries" )
    i = list(disease_all_nodes_genes["output_name"])
    # d = {x:i.count(x) for x in i}
    d = {}
    for x in i: 
        if x in d: 
            d[x] = d[x] + 1
        else:
            d[x] = 1
    print("sorting counts dictionary")
    sorted_disease_to_all_nodes_to_genes = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}

    print("top genes occurrence counts: ")
    for x in list(reversed(list(sorted_disease_to_all_nodes_to_genes)))[0:max_two_step_gene_count]:
        print(str(x) + ": " + str(sorted_disease_to_all_nodes_to_genes[x]))
    
    top_related_genes_to_disease = list(reversed(list(sorted_disease_to_all_nodes_to_genes)))[0:max_two_step_gene_count]

    disease_to_node_to_gene_results["top_related_genes_to_disease"] = top_related_genes_to_disease
    disease_to_node_to_gene_results["sorted_disease_to_all_nodes_to_genes"] = sorted_disease_to_all_nodes_to_genes

    # keep track of pubication counts for genes in two-step disease -> intermediate node -> gene
    print("getting publicaiton counts")
    top_two_step_genes_pub_counts = {}
    for index, row in disease_all_nodes_genes.iterrows():
        if row["output_name"] in top_related_genes_to_disease:
            current_pubcount = 0
            if(row["pred1_pubmed"] != None):
                current_pubcount = current_pubcount + str(row["pred1_pubmed"]).count(",") + 1
            if(row["pred2_pubmed"] != None):
                current_pubcount = current_pubcount + str(row["pred2_pubmed"]).count(",") + 1
            if row["output_name"] in top_two_step_genes_pub_counts:
                top_two_step_genes_pub_counts[row["output_name"]] = top_two_step_genes_pub_counts[row["output_name"]] + current_pubcount
            else: 
                top_two_step_genes_pub_counts[row["output_name"]] = current_pubcount

    disease_to_node_to_gene_results["top_two_step_genes_pub_counts"] =  top_two_step_genes_pub_counts
    
    return(disease_to_node_to_gene_results)

# %%
disease_symptom_hpids = list(symptom_dict.keys())
disease_symptoms = []
for entry in list(symptom_dict.values()): disease_symptoms = disease_symptoms + entry['names']
# print(disease_symptoms)

# %%
max_2_step_genes = 200
disease_symptoms
disease_symptom_hpids
disease_to_all_nodes_to_genes_results = get_disease_to_nodes_to_gene_results(disease_to_all_nodes_to_genes, max_2_step_genes, disease_symptoms, disease_symptom_hpids)
# %store disease_to_all_nodes_to_genes_results
# Out:
# finding intermediate nodes that are symptoms
# removing symptom intermediates
# getting gene counts from 186109 gene entries
# sorting counts dictionary
# top genes occurrence counts:
# TP53: 471
# MYC: 414
# BRCA1: 397
# PLEKHA4: 360
# VIRMA: 339
# NTRK1: 338
# UBC: 338
# H4C1: 329
# EP300: 326
# TRIM25: 285
# PCNA: 275
# ESR2: 274
# RPA1: 273
# RECQL4: 268
# EGFR: 262
# RPA2: 259
# APP: 252
# TRIM28: 247
# POLR2A: 240
# CUL3: 234
# RPA3: 233
# RNF4: 231
# CDK2: 227
# RBX1: 226
# HSP90AA1: 218
# COPS5: 217
# FANCD2: 216
# CTNNB1: 210
# ESR1: 209
# UBB: 205
# ELAVL1: 203
# BIRC3: 202
# CUL1: 201
# RFC4: 198
# UBE2I: 198
# UBA52: 197
# NR2C2: 196
# EFTUD2: 195
# CUL4B: 195
# RPS27A: 195
# POLR2E: 195
# KRAS: 192
# ATM: 190
# XRCC6: 190
# POLD1: 190
# XPO1: 189
# CREBBP: 188
# CUL7: 183
# HSPA8: 183
# CDK9: 181
# SNW1: 181
# EGLN3: 181
# PHB: 181
# CHEK1: 180
# CUL4A: 180
# H2AX: 179
# DDB1: 179
# POLR2B: 178
# PRKDC: 178
# AKT1: 177
# HDAC1: 175
# NXF1: 175
# RFC3: 175
# POLR2C: 173
# TP53BP1: 173
# VCP: 173
# EZH2: 172
# RFC2: 172
# APEX1: 170
# RFC5: 169
# POLR2F: 165
# POLR2H: 164
# H3C1: 164
# OBSL1: 163
# WWP2: 163
# POLR2L: 163
# MDM2: 161
# CDC5L: 161
# MDC1: 161
# POLR2G: 160
# MCM2: 159
# CDK1: 159
# PARP1: 159
# PPP1CC: 156
# HDAC2: 156
# HEXIM1: 155
# RELA: 155
# RNF2: 155
# POLE: 155
# POLR2K: 155
# CHD4: 152
# ATG16L1: 149
# POLR2D: 146
# YAP1: 145
# USP7: 145
# PRKN: 144
# SUZ12: 144
# RFC1: 143
# POLR2J: 143
# HNRNPL: 142
# PLK1: 142
# H2BC3: 142
# CHD3: 141
# PCBP1: 141
# LARP7: 140
# CDK7: 140
# CSNK2A1: 138
# POLR2I: 138
# KAT5: 137
# POLE2: 137
# RAD18: 136
# CHEK2: 134
# ATR: 134
# CYLD: 133
# XRCC5: 132
# EED: 131
# EEF1A1: 131
# BLM: 131
# RAD50: 131
# FBXW7: 130
# COPS6: 129
# PPP2R1A: 129
# RB1: 128
# CUL2: 128
# CUL5: 128
# CCND1: 127
# GSK3B: 126
# PRPF8: 126
# PPIE: 126
# KAT2B: 125
# CDKN1A: 123
# HIF1A: 123
# CCNH: 123
# BARD1: 122
# GTF2H5: 122
# PTEN: 121
# KDM1A: 121
# MEPCE: 120
# PPARG: 119
# SP1: 118
# STAU1: 118
# POLD2: 118
# CDC73: 117
# RBBP4: 117
# SMURF1: 116
# AAR2: 116
# HSPA4: 116
# BTRC: 115
# TNIP2: 115
# CCNA2: 113
# UBE2M: 113
# EIF4A3: 113
# BRCA2: 113
# TUBB: 113
# EWSR1: 111
# PIH1D1: 111
# RC3H2: 111
# CFTR: 111
# PPP2CA: 111
# AR: 110
# POLK: 110
# ERCC4: 110
# PSMA3: 110
# CDK4: 109
# MOV10: 109
# POLE4: 109
# PML: 108
# ERCC1: 108
# EXO1: 108
# DDX5: 108
# RNF123: 107
# LMNA: 106
# H2BC1: 106
# HSPA5: 106
# PPP1CA: 106
# CAND1: 106
# POLD3: 106
# CCNB1: 105
# JUN: 105
# HNRNPU: 105
# MRE11: 105
# WRN: 105
# PRPF19: 105
# RAD23B: 105
# PKM: 105
# UBE2N: 104
# MAPK1: 104
# SUMO1: 104
# RAD52: 104
# CDKN2A: 103
# RBBP7: 103
# SIRT7: 103
# SNRNP70: 103
# RC3H1: 102
# PIK3R1: 102
# FEN1: 102
# HNRNPA1: 102
# PSMC5: 102
# LMBR1L: 101
# GTF2H1: 101
# getting publicaiton counts
# Stored 'disease_to_all_nodes_to_genes_results' (dict)

# %%
# %store -r disease_to_all_nodes_to_genes_results

# %% [markdown]
# ## 4. Get Disease Symptoms related to Genes
# Genes -> Symptoms, then filter based on disease symptoms

# %%
disease_top_genes_list = disease_to_gene_results["disease_to_genes_list"] + disease_to_all_nodes_to_genes_results["top_related_genes_to_disease"]
disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
disease_top_genes_list
# Out:
# ['ERCC3',
#  'ERCC2',
#  'XPA',
#  'POLH',
#  'ERCC5',
#  'ERCC4',
#  'XPC',
#  'DDB2',
#  'EDNRA',
#  'HFM1',
#  'GTF2H4',
#  'ERCC1',
#  'MYC',
#  'APAF1',
#  'DDX11',
#  'ENDOV',
#  'MMS19',
#  'BBC3',
#  'ZC3H12D',
#  'CDKN1A',
#  'BCL2',
#  'POLM',
#  'MAPK8',
#  'PCNA',
#  'FXN',
#  'HSPA1A',
#  'GADD45A',
#  'CETN2',
#  'NRAS',
#  'ERCC6',
#  'FAS',
#  'BLM',
#  'SFN',
#  'PTCH1',
#  'PMAIP1',
#  'DCTPP1',
#  'WDR48',
#  'FOS',
#  'HSPA9',
#  'BTG2',
#  'IFNA1',
#  'TNFRSF10B',
#  'EGFR',
#  'TP53',
#  'GTF2H1',
#  'ERCC8',
#  'POLQ',
#  'CCNH',
#  'TERF2',
#  'RPA1',
#  'NR1H2',
#  'RRM2B',
#  'AAGAB',
#  'WDR77',
#  'PSMC6',
#  'LRRC59',
#  'CSH1',
#  'CPD',
#  'ERVK-11',
#  'ERVK-19',
#  'ERVK-9',
#  'FASTK',
#  'REXO2',
#  'PERP',
#  'FASN',
#  'TRIAP1',
#  'SUSD6',
#  'AEN',
#  'BAX',
#  'hsa_circ_000559',
#  'MIR890',
#  'MIR744',
#  'MIR6771',
#  'MIR6732',
#  'MIR373',
#  'MIR346',
#  'MIR21',
#  'U2',
#  'U12',
#  'U11',
#  'TERC',
#  'TARID',
#  'SCAANT1',
#  'RNR3',
#  'RN5S1@',
#  'Pinc',
#  'MEG8',
#  'LINC01197',
#  'LINC00302',
#  'HCG14',
#  'FAM230A',
#  'FAM157B',
#  'MUC13',
#  'HIST1H3B',
#  'MUC1',
#  'HIST1H4E',
#  'HIST1H3C',
#  'HIST1H3G',
#  'LIG4',
#  'PRIM2',
#  'HIST1H3F',
#  'CD24',
#  'IKBKG',
#  'CHD1',
#  'RDM1',
#  'HAO2',
#  'NTMT1',
#  'HIST1H3I',
#  'HNRNPDL',
#  'ACD',
#  'CRABP2',
#  'C9orf72',
#  'ZNF501',
#  'MED22',
#  'RECQL4',
#  'HIST1H3E',
#  'CGA',
#  'PER3',
#  'PCGF2',
#  'IP6K1',
#  'MED6',
#  'C18orf25',
#  'HIST1H4I',
#  'SLC38A3',
#  'E2F8',
#  'TADA2A',
#  'SHFM1',
#  'MCM3',
#  'HIST1H4L',
#  'HIST1H3A',
#  'FGF1',
#  'GRIP2',
#  'WBSCR16',
#  'POLD2',
#  'POLR2A',
#  'EPHX1',
#  'ALOX5AP',
#  'CIB1',
#  'HIST1H4K',
#  'UHRF1',
#  'RHNO1',
#  'KIZ',
#  'PCID2',
#  'HIST1H4D',
#  'HNRNPCL1',
#  'HIST1H4A',
#  'LTN1',
#  'RAG2',
#  'LEPREL2',
#  'VEGFA',
#  'CYP1B1',
#  'ATXN3',
#  'POLR2E',
#  'IGHV4-38-2',
#  'ABCB1',
#  'CRY2',
#  'ANXA8',
#  'SRD5A2',
#  'NAP1L1',
#  'APBB1',
#  'FRRS1L',
#  'HIST2H3PS2',
#  'RPAP2',
#  'SIRT5',
#  'GTF2H5',
#  'POLDIP2',
#  'HIST2H2AA3',
#  'COMMD3-BMI1',
#  'BIVM-ERCC5',
#  'RUVBL2',
#  'RPS5',
#  'IRF3',
#  'SUPT5H',
#  'UPF1',
#  'TTN',
#  'MUM1',
#  'RAD23A',
#  'AC004223.3',
#  'LSM12',
#  'RAD51D',
#  'C19orf40',
#  'GALK1',
#  'POLRMT',
#  'PIAS2',
#  'TMC6',
#  'CD3EAP',
#  'MFSD11',
#  'RPL26',
#  'RBFOX3',
#  'KLF14',
#  'RBM8A',
#  'HIST2H4A',
#  'POLI',
#  'HIST2H4B',
#  'ZP2',
#  'CTRL',
#  'ACTG1',
#  'TGFBR3L',
#  'COX4I1',
#  'PECAM1',
#  'EME2',
#  'WWOX',
#  'DET1',
#  'MRC1',
#  'TAF1C',
#  'C16orf52',
#  'ASIP',
#  'RNF111',
#  'B2M',
#  'BCL2L2-PABPN1',
#  'ISCA2',
#  'XRCC3',
#  'AKT1',
#  'NDRG2',
#  'MC1R',
#  'AC092143.1',
#  'HNRNPC',
#  'H326',
#  'ZBTB1',
#  'SMEK1',
#  'TIMELESS',
#  'MRPL42',
#  'DDIT3',
#  'BRF1',
#  'VDR',
#  'SOD2',
#  'GTF2H3',
#  'CUL2',
#  'CYFIP2',
#  'SCO2',
#  'OTUB1',
#  'CITED2',
#  'POLR1B',
#  'NAT1',
#  'HIST4H4',
#  'TET2',
#  'GPN3',
#  'HTATSF1',
#  'TOP3A',
#  'CAND1',
#  'ITGAM',
#  'UBC',
#  'NNMT',
#  'CYP2E1',
#  'PHC1',
#  'PSMD9',
#  'ATXN7',
#  'DMXL1',
#  'RIMS4',
#  'NFE2',
#  'AL139300.1',
#  'CUL7',
#  'TIMM8B',
#  'KLRF2',
#  'MDH1',
#  'HIF1A',
#  'CD19',
#  'HMGA2',
#  'TNKS1BP1',
#  'DICER1',
#  'MUC5B',
#  'NXF1',
#  'EIF3M',
#  'POLN',
#  'FAU',
#  'FAM111A',
#  'PUF60',
#  'H2AFX',
#  'C11orf30',
#  'CASP1',
#  'HSPA8',
#  'HSF1',
#  'NTRK1',
#  'IKBKB',
#  'HDAC2',
#  'RNF130',
#  'LYRM2',
#  'ENY2',
#  'ERI1',
#  'SLC25A37',
#  'CCNC',
#  'TCEA1',
#  'CETN3',
#  'UBE2V2',
#  'RPL30',
#  'NACA2',
#  'CEBPA',
#  'PROM1',
#  'RNF4',
#  'RNASET2',
#  'ASTE1',
#  'RAD17',
#  'ADH1C',
#  'DROSHA',
#  'EIF4E',
#  'NEDD4',
#  'PLRG1',
#  'SMUG1',
#  'FBXL7',
#  'CSB-PGBD3',
#  'MRPL36',
#  'PAQR3',
#  'XRCC4',
#  'TIPARP',
#  'TFAM',
#  'BAG1',
#  'LAT2',
#  'PHC3',
#  'ADH7',
#  'NR6A1',
#  'POLE4',
#  'ZMYND8',
#  'LYRM4',
#  'POR',
#  'CDK5',
#  'SSBP1',
#  'NUDT5',
#  'RAD51B',
#  'BRCA1',
#  'CDKN2A',
#  'NDUFA6',
#  'FTO',
#  'UBN2',
#  'TAF1L',
#  'CIAO1',
#  'MCM10',
#  'RPL37A',
#  'FHIT',
#  'BAP1',
#  'DHX36',
#  'PHACTR2',
#  'RECQL',
#  'FDXR',
#  'SLC2A1',
#  'EIF4G1',
#  'TRANK1',
#  'SLC35A2',
#  'CTCFL',
#  'DCAF11',
#  'POLR2H',
#  'INTS12',
#  'KLC1',
#  'RPS24',
#  'BDNF',
#  'INTS2',
#  'CDKN1C',
#  'C7orf25',
#  'IL10',
#  'TOP2A',
#  'PTPRC',
#  'TLK1',
#  'STMN1',
#  'MAP2K4',
#  'POC5',
#  'SUMO3',
#  'OTUD4',
#  'CHTF8',
#  'RFC5',
#  'FBP1',
#  'HRAS',
#  'GPX1',
#  'TAF1',
#  'PMS1',
#  'TCEA3',
#  'SLC13A5',
#  'POLD1',
#  'KAT8',
#  'SUMO2',
#  'CDC45',
#  'CLMP',
#  'ESR1',
#  'SMC6',
#  'PPP1R13L',
#  'BRAP',
#  'LTA',
#  'PMEL',
#  'SENP6',
#  'SMG1',
#  'WEE1',
#  'RANGAP1',
#  'ERN1',
#  'APTX',
#  'PNPT1',
#  'RHOA',
#  'EWSR1',
#  'TAF6',
#  'HMGA1',
#  'CDK12',
#  'TNF',
#  'CD44',
#  'L3MBTL1',
#  'DIABLO',
#  'ALKBH2',
#  'E2F5',
#  'NFIC',
#  'TOP2B',
#  'DHFR',
#  'CLEC2A',
#  'SMARCA4',
#  'TCEB3',
#  'MECP2',
#  'BTBD19',
#  'SENP1',
#  'SESN1',
#  'FGFR1',
#  'VPRBP',
#  'CDC7',
#  'HTATIP2',
#  'DCT',
#  'CHFR',
#  'PPP6C',
#  'CHD7',
#  'IGF2',
#  'TKT',
#  'CYB561D2',
#  'SLC16A5',
#  'GLI2',
#  'IDH1',
#  'RNF212',
#  'CHEK1',
#  'PARN',
#  'CREB1',
#  'FAM96B',
#  'UBE4A',
#  'LRRC29',
#  'IMMT',
#  'NFU1',
#  'ALDH7A1',
#  'CXCR4',
#  'TET3',
#  'SETD2',
#  'CD8A',
#  'TONSL',
#  'MCC',
#  'DAPK1',
#  'FOXO3',
#  'RPAIN',
#  'MARK2',
#  'SMS',
#  'HERC3',
#  'IL6',
#  'HIPK2',
#  'PPARA',
#  'ELAVL1',
#  'ZNF792',
#  'APOBEC3G',
#  'C1S',
#  'FANCL',
#  'XPO1',
#  'SETD8',
#  'AKAP12',
#  'ARNTL',
#  'TFIP11',
#  'PARG',
#  'APOBEC3A',
#  'RELA',
#  'CUL4B',
#  'POMC',
#  'PAXIP1',
#  'NCOR2',
#  'SUN1',
#  'NHP2L1',
#  'C1orf86',
#  'NEDD4L',
#  'SFI1',
#  'CDC42',
#  'KDM1A',
#  'TUBA3C',
#  'DDX3X',
#  'RUNX3',
#  'RBBP8',
#  'PAICS',
#  'MAP3K1',
#  'NEURL4',
#  'ABCC1',
#  'PARP3',
#  'UBE2D2',
#  'DOT1L',
#  'GSTP1',
#  'TMPRSS2',
#  'FANCB',
#  'CABIN1',
#  'LONRF1',
#  'CRYBB2',
#  'CBSL',
#  'CBS',
#  'KHSRP',
#  'MAP2K7',
#  'RNASE1',
#  'MED13',
#  'PGBD4',
#  'TEN1',
#  'MYCL',
#  'INS',
#  'DEK',
#  'SMU1',
#  'CCNF',
#  'NFE2L2',
#  'NUDT1',
#  'SOX10',
#  'CSNK1E',
#  'DKK3',
#  'CYP19A1',
#  'DDX39B',
#  'EDA2R',
#  'ELP4',
#  'GLI3',
#  'RAE1',
#  'CXCL12',
#  'CXCL1',
#  'TYMP',
#  'SULT1A1',
#  'QPRT',
#  'CDK1',
#  'FZR1',
#  'SPP1',
#  'MATK',
#  'PBRM1',
#  'PRKCD',
#  'ACYP2',
#  'FKBP2',
#  'GTF2F1',
#  'CIAPIN1',
#  'RPL24',
#  'HELLS',
#  'PTTG1',
#  'SLC29A1',
#  'FDX1L',
#  'CDKN2D',
#  'G6PD',
#  'CBX1',
#  'PPP2R4',
#  'EME1',
#  'BCL2L11',
#  'NRF1',
#  'NME2',
#  'NME1-NME2',
#  'CUL5',
#  'DBH',
#  'TDG',
#  'ETS1',
#  'GRB2',
#  'TAOK3',
#  'SRSF2',
#  'RFC4',
#  'STRA13',
#  'SUMO1',
#  'MAP3K4',
#  'XRCC5',
#  'TBP',
#  'PAX3',
#  'AKT2',
#  'HNRNPUL1',
#  'CCNK',
#  'UVSSA',
#  'SQSTM1',
#  'TSN',
#  'RTF1',
#  'EP400',
#  'FANCA',
#  'RNF20',
#  'ALK',
#  'TYRP1',
#  'GPX3',
#  'SETMAR',
#  'NEK11',
#  'RNMT',
#  'STAG1',
#  'WHSC1',
#  'FECH',
#  'SIRT3',
#  'DEFA1',
#  'DEFA1B',
#  'RAD51',
#  'CHEK2',
#  'FBXL18',
#  'SACS',
#  'SOD3',
#  'TP53BP1',
#  'PARP4',
#  'SRXN1',
#  'TNK2',
#  'RFC1',
#  'GART',
#  'JAK2',
#  'CD274',
#  'CDK8',
#  'E2F6',
#  'MLANA',
#  'TGM3',
#  'SLC25A6',
#  'CCP110',
#  'MBD3L2',
#  'LYRM5',
#  'DDX1',
#  'POLR2B',
#  'GTF3A',
#  'IGFBP3',
#  'PDX1',
#  'DUT',
#  'POMP',
#  'WRNIP1',
#  'SERF1B',
#  'HMGN1',
#  'PSIP1',
#  'TLR7',
#  'CNTLN',
#  'BNIP3L',
#  'NAP1L4',
#  'FAM175A',
#  'ZNF763',
#  'CHD3',
#  'AVP',
#  'IFNB1',
#  'IFNA2',
#  'NABP2',
#  'MTAP',
#  'BRCA2',
#  'ITPA',
#  'RBBP7',
#  'RFC3',
#  'FBXO18',
#  'GLRX',
#  'PHKA2',
#  'RREB1',
#  'DDX58',
#  'RIOK1',
#  'SMAD9',
#  'CYP1A1',
#  'KIN',
#  'FOXO1',
#  'ASPH',
#  'NEDD9',
#  'XDH',
#  'ISG15',
#  'LYRM7',
#  'E2F4',
#  'GATA3',
#  'DNAJC2',
#  'NUFIP1',
#  'LYRM9',
#  'POLA1',
#  'MAGEB10',
#  'MCM8',
#  'GALT',
#  'RAD50',
#  'FANCG',
#  'LGALS7',
#  'LIG3',
#  'ATP6AP2',
#  'LPAR6',
#  'APRT',
#  'TP73',
#  'DCLRE1C',
#  'TDP2',
#  'KDM6A',
#  'HIST1H4C',
#  'TRDMT1',
#  'POLR1E',
#  'HIST1H3D',
#  'HIST1H4B',
#  'HIST1H4H',
#  'MGME1',
#  'POLR3F',
#  'SF1',
#  'FTL',
#  'UIMC1',
#  'NMNAT1',
#  'XRN2',
#  'OR2J2',
#  'KLF9',
#  'UBD',
#  'GATA1',
#  'BMI1',
#  'MTHFR',
#  'TLE1',
#  'MDC1',
#  'UBQLN1',
#  'HNRNPK',
#  'FOXP3',
#  'ISCA1',
#  'ING1',
#  'CARD16',
#  'MSH5',
#  'HSPA1B',
#  'EHMT2',
#  'SDHB',
#  'CUL4A',
#  'NELFE',
#  'SKIV2L',
#  'STK19',
#  'FOXE1',
#  'CDA',
#  'PINK1',
#  'GALNT12',
#  'TGFBR1',
#  'APEX2',
#  'ABCA1',
#  'AOX1',
#  'AR',
#  'KLF4',
#  'DAXX',
#  'TXN',
#  'KIF4A',
#  'MAN1C1',
#  'C9orf84',
#  'FOXO4',
#  'CNKSR1',
#  'INIP',
#  'SLC31A1',
#  'POLE3',
#  'GPN2',
#  'NFS1',
#  'MED12',
#  'SPDEF',
#  'PHF20',
#  'AHDC1',
#  'TLR4',
#  'THEMIS2',
#  'UBE2D1',
#  'RPA2',
#  'MED18',
#  'RCC1',
#  'OGT',
#  'PEF1',
#  'RBL1',
#  'BAI2',
#  'TET1',
#  'SRC',
#  'HDAC8',
#  'SCAI',
#  'HDAC1',
#  'RBBP4',
#  'RNF8',
#  'UGT1A1',
#  'UGT1A7',
#  'GLO1',
#  'ATRX',
#  'PGK1',
#  'CDK9',
#  'ADPRHL2',
#  'RPA4',
#  'PGC',
#  'CCND3',
#  'CSTF2',
#  'NOX1',
#  'ADA',
#  'PPIE',
#  'WFDC5',
#  'PLAU',
#  'ZMPSTE24',
#  'EXO5',
#  'WFDC6',
#  'ENDOG',
#  'FOXJ3',
#  'CXorf57',
#  'YBX1',
#  'CDC20',
#  'TJAP1',
#  'POLR1C',
#  'ABL1',
#  'MMP9',
#  'PLK3',
#  'PTCH2',
#  'MUTYH',
#  'RAD54L',
#  'PTEN',
#  'SLC16A12',
#  'C9orf142',
#  'SLC25A5',
#  'UBE2A',
#  'NDOR1',
#  'TCTE1',
#  'CDC5L',
#  'PLCE1',
#  'LRRC42',
#  'CYP2C19',
#  'CYP2C8',
#  'SPO11',
#  'JUN',
#  'XIAP',
#  'DNTT',
#  'SMARCA1',
#  'GSTA4',
#  'PSMA7',
#  'ZZZ3',
#  'USP33',
#  'FUBP1',
#  'RBMX',
#  'GTF2B',
#  'SLC25A28',
#  'FMR1',
#  'ABCC2',
#  'CHUK',
#  'HMGB3',
#  'MB21D1',
#  'CSAG1',
#  'NSDHL',
#  'DPYD',
#  'BTRC',
#  'POLL',
#  'SLC30A7',
#  'NPM3',
#  'SUFU',
#  'CYP17A1',
#  'AS3MT',
#  'CYB561D1',
#  'EMD',
#  'TAF5',
#  'TTK',
#  'OVGP1',
#  'SFR1',
#  'GSTO1',
#  'ME1',
#  'DDX20',
#  'DCLRE1B',
#  'DKC1',
#  'BCAS2',
#  'SYCP1',
#  'RNGTT',
#  'BRCC3',
#  'PHGDH',
#  'CASP7',
#  'CHD1L',
#  'GJA8',
#  'HIST1H3H',
#  'ASCC3',
#  'HIST2H2AA',
#  'HIST2H2BE',
#  'BOLA1',
#  'PRDM1',
#  'ATG5',
#  'AIM1',
#  'MCL1',
#  'NSMCE4A',
#  'PSMD4',
#  'BUB3',
#  'S100A10',
#  'FLG',
#  'C1orf68',
#  'IVL',
#  'LOR',
#  'GLRX3',
#  'ZUFSP',
#  'ROS1',
#  'ADAR',
#  'LMNA',
#  'WDR42A',
#  'MED23',
#  'USF1',
#  'SDHC',
#  'DUSP12',
#  'ATF6',
#  'POU2F1',
#  'ADCY10',
#  'HBS1L',
#  'FASLG',
#  'RNASEL',
#  'DHX9',
#  'RNF2',
#  'SHPRH',
#  'TPR',
#  'PTGS2',
#  'CDC73',
#  'UBE2T',
#  'MDM4',
#  'SLC30A1',
#  'DTL',
#  'NSL1',
#  'SLC22A2',
#  'PARK2',
#  'H3F3A',
#  'PARP1',
#  'THBS2',
#  'IBA57',
#  'ABCB10',
#  'TSNAX',
#  'NTPCR',
#  'MTR',
#  'EXO1',
#  'TFB2M',
#  'APOBEC3C',
#  'E2F2',
#  'BECN1',
#  'DCLRE1A',
#  'COL6A1',
#  'NSMCE1',
#  'CTNNBL1',
#  'MT-ND2',
#  'SMC5',
#  'DMD',
#  'CDC14A',
#  'MT-CO2',
#  'NFE2L1',
#  'SMC3',
#  'TAF11',
#  'MTOR',
#  'MT-CYB',
#  'TOP1',
#  'ZNF830',
#  'COMT',
#  'MT-CO1',
#  'FAN1',
#  'ZEB1',
#  'STAT1',
#  'NMRK1',
#  'RFWD3',
#  'GYPA',
#  'CYP2D6',
#  'WDHD1',
#  'RRM2',
#  'CASS4',
#  'BAZ1A',
#  'MAGEA4',
#  'RTEL1',
#  'TFRC',
#  'DHDDS',
#  'TRRAP',
#  'SUPV3L1',
#  'ELF3',
#  'PCNT',
#  'ATP6V1H',
#  'DNMT1',
#  'BABAM1',
#  'OR51A7',
#  'XRCC2',
#  'XRCC6',
#  'HIST1H3J',
#  'NAE1',
#  'SMARCAD1',
#  'MAP3K5',
#  'TGFBR2',
#  'ELN',
#  'VCP',
#  'REV3L',
#  'BDP1',
#  'HELZ',
#  'WDR5',
#  'RAD52',
#  'CASP8',
#  'EPHA2',
#  'DNA2',
#  'CNOT3',
#  'DCAF4',
#  'XAB2',
#  'NF1',
#  'RAD23B',
#  'PHF8',
#  'COPS5',
#  'PRIM1',
#  'POT1',
#  'POTEF',
#  'ACTB',
#  'SMARCAL1',
#  'UBE2D3',
#  'XPNPEP3',
#  'DCTD',
#  'RASSF1',
#  'CHD4',
#  'SCRIB',
#  'NHEJ1',
#  'PPP4R2',
#  'TMEM259',
#  'GTF3C1',
#  'UVRAG',
#  'ZNF44',
#  'SPEF2',
#  'GTF2E2',
#  'C1D',
#  'SREBF1',
#  'UBE2I',
#  'MLH3',
#  'RET',
#  'ARID4A',
#  'ANO1',
#  'HTT',
#  'NEIL1',
#  'HIST1H4J',
#  'SERF1A',
#  'FN1',
#  'OCA2',
#  'THRAP3',
#  'OR5H1',
#  'ATG7',
#  'TAP1',
#  'PRKAA1',
#  'DDX21',
#  'RPS3A',
#  'RPL3',
#  'RPS21',
#  'DPY30',
#  'ATP7A',
#  'E2F1',
#  'PCDHB13',
#  'HMGB1',
#  'UBQLN2',
#  'GSTO2',
#  'FBXL5',
#  'DHRS2',
#  'NF2',
#  ...]

# %%
def determined_genes_to_symptoms(gene_list, symptom_list, symptom_dict):

    # gene -> phenotypic feature nodes
    print("Genes -> PhenotypicFeatures")
    df_list = []
    for x in gene_list: 
        try: 
            gene = ht.query(x)["Gene"][0]
            fc = FindConnection(input_obj=gene, output_obj='PhenotypicFeature', intermediate_nodes=None)
            fc.connect(verbose=False)
            df = fc.display_table_view()
            rows = df.shape[0]
            if(rows > 0):
                df_list.append(df)
        except:
            print(str(x) + " FAILED")
    if(len(df_list) > 0):
        top_gene_to_phenotypicFeature = pd.concat(df_list)

    # top_gene_to_phenotypicFeature = top_gene_to_phenotypicFeature
    # top_gene_to_phenotypicFeature
    for index in range(top_gene_to_phenotypicFeature.shape[0]):
        if(top_gene_to_phenotypicFeature.iloc[index]["output_name"] in symptom_dict):
            top_gene_to_phenotypicFeature.iloc[index]["output_name"] = symptom_dict[top_gene_to_phenotypicFeature.iloc[index]["output_name"]]['names'][0]

    # gene -> bioprocess
    print("Genes -> Bioprocesses")
    df_list = []
    for x in gene_list: 
        try: 
            gene = ht.query(x)["Gene"][0]
            fc = FindConnection(input_obj=gene, output_obj='BiologicalProcess', intermediate_nodes=None)
            fc.connect(verbose=False)
            df = fc.display_table_view()
            rows = df.shape[0]
            if(rows > 0):
                df_list.append(df)
        except:
            print(str(x) + " FAILED")
    if(len(df_list) > 0):
        top_gene_to_bioprocesses = pd.concat(df_list)

    # bioprocess_top = top_gene_to_bioprocesses
    # Genes -> disease type "symptoms"
    print("Genes -> Diseases")
    df_list = []
    for x in gene_list: 
        try: 
            gene = ht.query(x)["Gene"][0]
            fc = FindConnection(input_obj=gene, output_obj='Disease', intermediate_nodes=None)
            fc.connect(verbose=False)
            df = fc.display_table_view()
            rows = df.shape[0]
            if(rows > 0):
                df_list.append(df)
        except:
            print(str(x) + " FAILED")
    if(len(df_list) > 0):
        top_gene_to_diseases = pd.concat(df_list)

    all_gene_connections = pd.concat([top_gene_to_bioprocesses,top_gene_to_phenotypicFeature,top_gene_to_diseases])
    all_gene_connections["output_name"] = all_gene_connections["output_name"].str.upper()
    return(all_gene_connections)

# %%
def filter_genes_to_symptoms(genes_to_symptoms_df, disease_symptoms):
    indices_to_keep = []
    for index, row in enumerate(genes_to_symptoms_df.iterrows()):
        row = genes_to_symptoms_df.iloc[index]
        if(row["output_name"].upper() in disease_symptoms):
            indices_to_keep.append(index)
    genes_to_symptoms_df = genes_to_symptoms_df.iloc[indices_to_keep]
    return(genes_to_symptoms_df)

# %%
genes_to_symptoms_df = determined_genes_to_symptoms(disease_top_genes_list, disease_symptoms, symptom_dict)
# Out:
# Genes -> PhenotypicFeatures
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# hsa_circ_000559 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# RN5S1@ FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# Pinc FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# HIST1H3B FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# HIST1H4E FAILED
# ...
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# HIST1H4L FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# HIST1H3A FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# WBSCR16 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# HIST1H4K FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# HIST1H4D FAILED
# Disease mydisease.info failed
# Disease mydisease.info failed
# HIST1H4A FAILED
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# LEPREL2 FAILED
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# Disease mydisease.info failed
# HIST2H3PS2 FAILED
# Disease mydisease.info failed
# HIST2H2AA3 FAILED
# MUM1 FAILED
# C19orf40 FAILED
# CD3EAP FAILED
# HIST2H4A FAILED
# HIST2H4B FAILED
# C16orf52 FAILED
# H326 FAILED
# SMEK1 FAILED
# HIST4H4 FAILED
# H2AFX FAILED
# C11orf30 FAILED
# CSB-PGBD3 FAILED
# TCEB3 FAILED
# VPRBP FAILED
# FAM96B FAILED
# SETD8 FAILED
# NHP2L1 FAILED
# C1orf86 FAILED
# FDX1L FAILED
# PPP2R4 FAILED
# STRA13 FAILED
# WHSC1 FAILED
# LYRM5 FAILED
# FAM175A FAILED
# FBXO18 FAILED
# HIST1H4C FAILED
# HIST1H3D FAILED
# HIST1H4B FAILED
# HIST1H4H FAILED
# C9orf84 FAILED
# BAI2 FAILED
# ADPRHL2 FAILED
# CXorf57 FAILED
# C9orf142 FAILED
# MB21D1 FAILED
# HIST1H3H FAILED
# HIST2H2AA FAILED
# HIST2H2BE FAILED
# AIM1 FAILED
# LOR FAILED
# ZUFSP FAILED
# WDR42A FAILED
# PARK2 FAILED
# H3F3A FAILED
# HIST1H3J FAILED
# HIST1H4J FAILED
# H1F0 FAILED
# BRE FAILED
# HIST1H1C FAILED
# C17orf70 FAILED
# HIST2H2AC FAILED
# NDNL2 FAILED
# MRE11A FAILED
# CCDC101 FAILED
# C10orf2 FAILED
# APITD1 FAILED
# H2AFV FAILED
# HIST1H1E FAILED
# ICT1 FAILED
# XRCC6BP1 FAILED
# KIAA0101 FAILED
# FAM96A FAILED
# WAPAL FAILED
# H2AFZ FAILED
# APP FAILED
# MUT FAILED
# ACPT FAILED
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# SGOL1 FAILED
# UFD1L FAILED
# TCEB2 FAILED
# CCBL2 FAILED
# MTL5 FAILED
# H3F3B FAILED
# NARFL FAILED
# HIST1H4F FAILED
# RARS FAILED
# PAPD7 FAILED
# SKIV2L2 FAILED
# OBFC1 FAILED
# KIAA2022 FAILED
# 45S_rRNA FAILED
# 28S_rRNA FAILED
# 18S_rRNA FAILED
# MGI:1195972 FAILED
# MGI:6258236 FAILED
# MGI:6258233 FAILED
# Genes -> Bioprocesses
# hsa_circ_000559 FAILED
# RN5S1@ FAILED
# Pinc FAILED
# HIST1H3B FAILED
# HIST1H4E FAILED
# HIST1H3C FAILED
# HIST1H3G FAILED
# HIST1H3F FAILED
# HIST1H3I FAILED
# HIST1H3E FAILED
# HIST1H4I FAILED
# HIST1H4L FAILED
# HIST1H3A FAILED
# WBSCR16 FAILED
# HIST1H4K FAILED
# HIST1H4D FAILED
# HIST1H4A FAILED
# LEPREL2 FAILED
# HIST2H3PS2 FAILED
# HIST2H2AA3 FAILED
# MUM1 FAILED
# C19orf40 FAILED
# CD3EAP FAILED
# HIST2H4A FAILED
# HIST2H4B FAILED
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# C16orf52 FAILED
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# H326 FAILED
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# SMEK1 FAILED
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# HIST4H4 FAILED
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# H2AFX FAILED
# C11orf30 FAILED
# CSB-PGBD3 FAILED
# TCEB3 FAILED
# VPRBP FAILED
# FAM96B FAILED
# SETD8 FAILED
# NHP2L1 FAILED
# C1orf86 FAILED
# FDX1L FAILED
# PPP2R4 FAILED
# STRA13 FAILED
# WHSC1 FAILED
# LYRM5 FAILED
# FAM175A FAILED
# FBXO18 FAILED
# HIST1H4C FAILED
# HIST1H3D FAILED
# HIST1H4B FAILED
# HIST1H4H FAILED
# C9orf84 FAILED
# BAI2 FAILED
# ADPRHL2 FAILED
# CXorf57 FAILED
# C9orf142 FAILED
# MB21D1 FAILED
# HIST1H3H FAILED
# HIST2H2AA FAILED
# HIST2H2BE FAILED
# AIM1 FAILED
# LOR FAILED
# ZUFSP FAILED
# WDR42A FAILED
# PARK2 FAILED
# H3F3A FAILED
# HIST1H3J FAILED
# HIST1H4J FAILED
# H1F0 FAILED
# BRE FAILED
# HIST1H1C FAILED
# C17orf70 FAILED
# HIST2H2AC FAILED
# NDNL2 FAILED
# Cannot connect to host mygene.info:443 ssl:default [nodename nor servname provided, or not known]
# SLX1B FAILED
# MRE11A FAILED
# CCDC101 FAILED
# C10orf2 FAILED
# APITD1 FAILED
# H2AFV FAILED
# HIST1H1E FAILED
# ICT1 FAILED
# XRCC6BP1 FAILED
# KIAA0101 FAILED
# FAM96A FAILED
# WAPAL FAILED
# H2AFZ FAILED
# APP FAILED
# MUT FAILED
# ACPT FAILED
# SGOL1 FAILED
# UFD1L FAILED
# TCEB2 FAILED
# CCBL2 FAILED
# MTL5 FAILED
# H3F3B FAILED
# NARFL FAILED
# HIST1H4F FAILED
# RARS FAILED
# PAPD7 FAILED
# SKIV2L2 FAILED
# OBFC1 FAILED
# KIAA2022 FAILED
# 45S_rRNA FAILED
# 28S_rRNA FAILED
# 18S_rRNA FAILED
# MGI:1195972 FAILED
# MGI:6258236 FAILED
# MGI:6258233 FAILED
# Genes -> Diseases
# hsa_circ_000559 FAILED
# RN5S1@ FAILED
# Pinc FAILED
# HIST1H3B FAILED
# HIST1H4E FAILED
# HIST1H3C FAILED
# HIST1H3G FAILED
# HIST1H3F FAILED
# HIST1H3I FAILED
# HIST1H3E FAILED
# HIST1H4I FAILED
# HIST1H4L FAILED
# HIST1H3A FAILED
# WBSCR16 FAILED
# HIST1H4K FAILED
# HIST1H4D FAILED
# HIST1H4A FAILED
# LEPREL2 FAILED
# HIST2H3PS2 FAILED
# HIST2H2AA3 FAILED
# MUM1 FAILED
# C19orf40 FAILED
# CD3EAP FAILED
# HIST2H4A FAILED
# HIST2H4B FAILED
# C16orf52 FAILED
# H326 FAILED
# SMEK1 FAILED
# HIST4H4 FAILED
# Response payload is not completed
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# HMGA2 FAILED
# H2AFX FAILED
# C11orf30 FAILED
# CSB-PGBD3 FAILED
# TCEB3 FAILED
# VPRBP FAILED
# FAM96B FAILED
# SETD8 FAILED
# NHP2L1 FAILED
# C1orf86 FAILED
# FDX1L FAILED
# PPP2R4 FAILED
# STRA13 FAILED
# WHSC1 FAILED
# LYRM5 FAILED
# FAM175A FAILED
# FBXO18 FAILED
# HIST1H4C FAILED
# HIST1H3D FAILED
# HIST1H4B FAILED
# HIST1H4H FAILED
# C9orf84 FAILED
# BAI2 FAILED
# ADPRHL2 FAILED
# CXorf57 FAILED
# C9orf142 FAILED
# MB21D1 FAILED
# HIST1H3H FAILED
# HIST2H2AA FAILED
# HIST2H2BE FAILED
# AIM1 FAILED
# LOR FAILED
# ZUFSP FAILED
# WDR42A FAILED
# PARK2 FAILED
# H3F3A FAILED
# HIST1H3J FAILED
# HIST1H4J FAILED
# H1F0 FAILED
# BRE FAILED
# HIST1H1C FAILED
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# C17orf70 FAILED
# HIST2H2AC FAILED
# NDNL2 FAILED
# MRE11A FAILED
# CCDC101 FAILED
# C10orf2 FAILED
# APITD1 FAILED
# H2AFV FAILED
# HIST1H1E FAILED
# ICT1 FAILED
# XRCC6BP1 FAILED
# KIAA0101 FAILED
# FAM96A FAILED
# WAPAL FAILED
# H2AFZ FAILED
# APP FAILED
# MUT FAILED
# ACPT FAILED
# SGOL1 FAILED
# UFD1L FAILED
# TCEB2 FAILED
# CCBL2 FAILED
# MTL5 FAILED
# H3F3B FAILED
# NARFL FAILED
# HIST1H4F FAILED
# RARS FAILED
# PAPD7 FAILED
# SKIV2L2 FAILED
# OBFC1 FAILED
# KIAA2022 FAILED
# 45S_rRNA FAILED
# 28S_rRNA FAILED
# 18S_rRNA FAILED
# MGI:1195972 FAILED
# MGI:6258236 FAILED
# MGI:6258233 FAILED

# %%
# %store genes_to_symptoms_df
# Out:
# Stored 'genes_to_symptoms_df' (DataFrame)

# %%
# %store -r genes_to_symptoms_df

# %%
relevant_genes_to_symptoms_df = filter_genes_to_symptoms(genes_to_symptoms_df,disease_symptoms)

# %%
def get_symptom_results(relevant_genes_to_symptoms_df):
    symptoms_results = {}
    relevant_top_genes_list = list(dict.fromkeys(list(relevant_genes_to_symptoms_df["input"])))
    for x in relevant_top_genes_list:
        symptoms_results[x] = {
            "related_symptoms" : [],
            "publication_count": 0
        }
    for index, row in relevant_genes_to_symptoms_df.iterrows():
        symptoms_results[row["input"]]["related_symptoms"].append(row["output_name"])
        if(row["pred1_pubmed"]):
            symptoms_results[row["input"]]["publication_count"] = symptoms_results[row["input"]]["publication_count"] + row["pred1_pubmed"].count(',') + 1
#     for x in list(symptoms_results.keys()):
#         if(len(symptoms_results[x]["related_symptoms"]) == 0):
#             print("MEHHH")
#             del symptoms_results[x]
    ### need to remove if related to symptoms length = 0 
    return(symptoms_results)

# %%
relevant_genes_to_symptoms_results = get_symptom_results(relevant_genes_to_symptoms_df )
relevant_top_genes_list = list(relevant_genes_to_symptoms_results.keys())
print(relevant_genes_to_symptoms_results)
# Out:
# {'ERCC3': {'related_symptoms': ['DECREASED ACTIVITY OF GONADS', 'DECREASED ACTIVITY OF GONADS', 'DECREASED ACTIVITY OF GONADS', 'ABNORMALLY SMALL CRANIUM', 'ABNORMALLY SMALL CRANIUM', 'ABNORMALLY SMALL CRANIUM', 'HEARING LOSS, SENSORINEURAL', 'HEARING LOSS, SENSORINEURAL', 'CATARACT', 'CATARACT', 'CATARACT', 'OPTIC ATROPHY', 'OPTIC ATROPHY', 'CUTANEOUS PHOTOSENSITIVITY', 'CUTANEOUS PHOTOSENSITIVITY', 'CUTANEOUS PHOTOSENSITIVITY', 'ATAXIA', 'ATAXIA', 'FRECKLING', 'FRECKLING', 'DECREASED BODY HEIGHT', 'DECREASED BODY HEIGHT', 'DECREASED BODY HEIGHT', 'ATROPHIC SKIN', 'ATROPHIC SKIN', 'ABNORMAL TISSUE MASS', 'DRY SKIN', 'INVOLUNTARY MUSCLE STIFFNESS, CONTRACTION, OR SPASM', 'NEUROPATHY', 'CANCER OF SKIN PIGMENT CELLS', 'DELAYED BONE AGE', 'CEREBRAL CORTEX ATROPHY', 'CROSS-EYED', 'ABNORMALITY OF COGNITION', 'CRYPTORCHIDISM', 'CONGENITAL DEAFNESS', 'POIKILODERMA', 'EXTREME SENSITIVITY OF THE EYES TO LIGHT', 'ECTROPION', 'FLAT, DISCOLORED AREA OF SKIN', 'CRANIOFACIAL HYPEROSTOSIS', 'ADHESION OF EYELIDS', 'ARTHRALGIA', 'PAPILLOMA', 'DEVELOPMENTAL REGRESSION', 'ABNORMAL EEG', 'FATIGUE', 'THIN SKIN', 'HYPERKERATOSIS', 'ABNORMALITY OF EXTRAPYRAMIDAL MOTOR FUNCTION', 'ERYTHEMA', 'CONJUNCTIVAL TELANGIECTASES', 'CORNEAL INFLAMMATION', 'BLEPHARITIS', 'DIFFUSELY THICKENED SKIN', 'DEPRESSED NASAL ALAE', 'ABNORMAL DENTITION', 'FEVER', 'ABNORMAL URINARY AMINO-ACID FINDINGS', 'DECREASED TESTICULAR SIZE', 'TELANGIECTASIA OF THE SKIN', 'ALOPECIA', 'FAILURE TO THRIVE', 'ABSENT OR DECREASED DEEP TENDON REFLEXES', 'INTELLECTUAL DISABILITY, PROGRESSIVE', 'EPILEPSY', 'EYE TUMOR', 'PTERYGIA', 'HYPOPIGMENTED SKIN PATCHES', 'HYPERMELANOTIC MACULE', 'CUTANEOUS TELANGIECTASIA', 'ENTROPION', 'BEAUTY MARK', 'CLOUDY CORNEA', 'PERIPHERAL NEUROPATHY', 'CATARACT', 'CATARACT', 'MALIGNANT MELANOMA', 'MALIGNANT MELANOMA', 'ATAXIA', 'TELANGIECTASIA', 'ECTROPION', 'ALOPECIA'], 'publication_count': 30}, 'ERCC2': {'related_symptoms': ['ABNORMALLY SMALL CRANIUM', 'ABNORMALLY SMALL CRANIUM', 'ABNORMALLY SMALL CRANIUM', 'ABNORMALLY SMALL CRANIUM', 'CONGENITAL DEAFNESS', 'CONGENITAL DEAFNESS', 'CATARACT', 'CATARACT', 'CATARACT', 'CUTANEOUS PHOTOSENSITIVITY', 'CUTANEOUS PHOTOSENSITIVITY', 'CUTANEOUS PHOTOSENSITIVITY', 'CUTANEOUS PHOTOSENSITIVITY', 'HEARING LOSS, SENSORINEURAL', 'HEARING LOSS, SENSORINEURAL', 'CORNEAL INFLAMMATION', 'CORNEAL INFLAMMATION', 'EXTREME SENSITIVITY OF THE EYES TO LIGHT', 'EXTREME SENSITIVITY OF THE EYES TO LIGHT', 'ENTROPION', 'ENTROPION', 'ECTROPION', 'ECTROPION', 'CUTANEOUS TELANGIECTASIA', 'CUTANEOUS TELANGIECTASIA', 'POIKILODERMA', 'POIKILODERMA', 'ATAXIA', 'ATAXIA', 'INVOLUNTARY MUSCLE STIFFNESS, CONTRACTION, OR SPASM', 'INVOLUNTARY MUSCLE STIFFNESS, CONTRACTION, OR SPASM', 'ATROPHIC SKIN', 'ATROPHIC SKIN', 'DECREASED ACTIVITY OF GONADS', 'DECREASED ACTIVITY OF GONADS', 'DECREASED BODY HEIGHT', 'DECREASED BODY HEIGHT', 'DRY SKIN', 'NEUROPATHY', 'CANCER OF SKIN PIGMENT CELLS', 'CEREBRAL CORTEX ATROPHY', 'CROSS-EYED', 'OPTIC ATROPHY', 'DELAYED BONE AGE', 'HYPERKERATOSIS', 'FRECKLING', 'CRYPTORCHIDISM', 'ABSENT OR DECREASED DEEP TENDON REFLEXES', 'EPILEPSY', 'FLAT, DISCOLORED AREA OF SKIN', 'CRANIOFACIAL HYPEROSTOSIS', 'ADHESION OF EYELIDS', 'ARTHRALGIA', 'ABNORMAL TISSUE MASS', 'PAPILLOMA', 'DEVELOPMENTAL REGRESSION', 'ABNORMAL EEG', 'FATIGUE', 'THIN SKIN', 'ABNORMALITY OF EXTRAPYRAMIDAL MOTOR FUNCTION', 'ERYTHEMA', 'CONJUNCTIVAL TELANGIECTASES', 'BLEPHARITIS', 'DIFFUSELY THICKENED SKIN', 'DEPRESSED NASAL ALAE', 'ABNORMAL DENTITION', 'ABNORMALITY OF COGNITION', 'FEVER', 'ABNORMAL URINARY AMINO-ACID FINDINGS', 'DECREASED TESTICULAR SIZE', 'TELANGIECTASIA OF THE SKIN', 'ALOPECIA', 'FAILURE TO THRIVE', 'INTELLECTUAL DISABILITY, PROGRESSIVE', 'EYE TUMOR', 'PTERYGIA', 'HYPOPIGMENTED SKIN PATCHES', 'HYPERMELANOTIC MACULE', 'BEAUTY MARK', 'CLOUDY CORNEA', 'MALIGNANT MELANOMA', 'MALIGNANT MELANOMA', 'MALIGNANT MELANOMA', 'MALIGNANT MELANOMA', 'MALIGNANT MELANOMA', 'MALIGNANT MELANOMA', 'CATARACT', 'CATARACT', 'CATARACT', 'ERYTHEMA', 'PAPILLOMA', 'ECTRO ...

# %% [markdown]
# ## 5. Get Genes Edges Out Count

# %%
## node type list is list of all nodes
def get_gene_edges_out_count(gene_list, node_type_list):
    # dictionary that keeps track of all connections from a gene to any node type 
    connection_dict = {}
    for gene_symbol in gene_list:
        gene_found = False
        gene_query = ht.query(gene_symbol)['Gene']
        for i in gene_query:
            if(i['SYMBOL'].lower() == gene_symbol.lower()):
                gene = i
                gene_found = True
        if(gene_found == True):
            count = 0
            input_object = gene
            for x in node_type_list:
                try: 
                    ## only look at direct connections
                    fc = FindConnection(input_obj=input_object, output_obj=x, intermediate_nodes=None)
                    fc.connect(verbose=False)
                    df = fc.display_table_view()
                    rows = df.shape[0]
                    count = count + rows
                except: 
                    print("gene " + str(gene_symbol) + " for node intermediate " + str(x) + " failed")
            connection_dict[gene_symbol]  = count
        else:
            print(gene_symbol + ' could not be found')
            connection_dict[gene_symbol] = 'Unknown'
    return(connection_dict)

# %%
## for example purposes, include ASLD5. - not a real gene as far as I know
gene_edges_out = get_gene_edges_out_count(relevant_top_genes_list, all_node_types)
gene_edges_out
# Out:
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene MTR for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene COL6A1 for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene DMD for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene CDC14A for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene SMC3 for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene MTOR for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene TOP1 for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene FAN1 for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene ZEB1 for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene STAT1 for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene RFWD3 for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250')
# Unable to fetch results from mydisease
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human')
# Unable to fetch results from mydisease.info
# ID resolution steps failed:
# gene CYP2D6 for node intermediate Disease failed
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=mondo.mondo,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.synonym.exact,mondo.synonym.related,disease_ontology.synonyms.exact,mondo.xrefs.mesh,disease_ontology.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# API 5.1 mydisease failed
# 1 mydisease.info failed
# 1 mydisease.info failed
# 1 mydisease.info failed
# 1 mydisease.info failed
# ID resolution steps failed:
# gene RTEL1 for node intermediate Disease failed
# Disease mydisease.info failed
# API 5.1 mydisease failed
# 1 mydisease.info failed
# 1 mydisease.info failed
# 1 mydisease.info failed
# 1 mydisease.info failed
# ID resolution steps failed:
# gene TFRC for node intermediate Disease failed
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# {'ERCC3': 1097,
#  'ERCC2': 1270,
#  'XPA': 748,
#  'POLH': 565,
#  'ERCC5': 697,
#  'ERCC4': 934,
#  'XPC': 570,
#  'DDB2': 628,
#  'EDNRA': 1430,
#  'ERCC1': 1117,
#  'DDX11': 459,
#  'PCNA': 2169,
#  'FXN': 1991,
#  'NRAS': 1533,
#  'ERCC6': 876,
#  'FAS': 5882,
#  'BLM': 1570,
#  'PTCH1': 1566,
#  'FOS': 7066,
#  'TP53': 14024,
#  'ERCC8': 2260,
#  'RRM2B': 755,
#  'PERP': 390,
#  'TERC': 252,
#  'MUC1': 1175,
#  'LIG4': 815,
#  'IKBKG': 1412,
#  'CHD1': 526,
#  'HNRNPDL': 642,
#  'ACD': 897,
#  'C9orf72': 709,
#  'RECQL4': 928,
#  'PCGF2': 556,
#  'EPHX1': 969,
#  'CIB1': 447,
#  'KIZ': 205,
#  'RAG2': 595,
#  'CYP1B1': 811,
#  'ATXN3': 1008,
#  'SRD5A2': 1161,
#  'FRRS1L': 295,
#  'GTF2H5': 652,
#  'BIVM-ERCC5': 273,
#  'TTN': 846,
#  'RAD51D': 539,
#  'GALK1': 403,
#  'TMC6': 438,
#  'RPL26': 627,
#  'RBM8A': 754,
#  'ACTG1': 770,
#  'WWOX': 1135,
#  'ISCA2': 247,
#  'AKT1': 16400,
#  'MC1R': 821,
#  'BRF1': 347,
#  'VDR': 1115,
#  'CYFIP2': 515,
#  'TET2': 669,
#  'TOP3A': 542,
#  'PHC1': 614,
#  'ATXN7': 565,
#  'CUL7': 688,
#  'CD19': 1732,
#  'FAM111A': 243,
#  'PUF60': 690,
#  'NTRK1': 2291,
#  'IKBKB': 1533,
#  'PROM1': 1497,
#  'RNASET2': 483,
#  'XRCC4': 630,
#  'POR': 1153,
#  'BRCA1': 3022,
#  'CDKN2A': 4888,
#  'NDUFA6': 588,
#  'FTO': 613,
#  'FDXR': 631,
#  'SLC2A1': 1955,
#  'SLC35A2': 1018,
#  'RPS24': 712,
#  'BDNF': 1572,
#  'CDKN1C': 1217,
#  'FBP1': 891,
#  'HRAS': 2276,
#  'TAF1': 1050,
#  'SLC13A5': 497,
#  'POLD1': 768,
#  'CDC45': 720,
#  'CLMP': 311,
#  'ESR1': 5414,
#  'APTX': 624,
#  'PNPT1': 616,
#  'RHOA': 3727,
#  'TAF6': 436,
#  'DIABLO': 506,
#  'DHFR': 781,
#  'SMARCA4': 1452,
#  'MECP2': 1004,
#  'FGFR1': 5023,
#  'CHD7': 837,
#  'IGF2': 1335,
#  'TKT': 923,
#  'GLI2': 1495,
#  'IDH1': 1210,
#  'PARN': 540,
#  'NFU1': 347,
#  'ALDH7A1': 1558,
#  'CXCR4': 3770,
#  'TET3': 464,
#  'SETD2': 1401,
#  'TONSL': 284,
#  'SMS': 2813,
#  'C1S': 753,
#  'FANCL': 578,
#  'CUL4B': 785,
#  'POMC': 5609,
#  'NEDD4L': 806,
#  'CDC42': 2638,
#  'KDM1A': 1437,
#  'DDX3X': 895,
#  'RBBP8': 763,
#  'MAP3K1': 982,
#  'FANCB': 747,
#  'CRYBB2': 359,
#  'CBS': 1175,
#  'INS': 9555,
#  'CCNF': 617,
#  'NFE2L2': 1313,
#  'SOX10': 1072,
#  'CYP19A1': 2241,
#  'EDA2R': 360,
#  'GLI3': 1690,
#  'TYMP': 1235,
#  'PRKCD': 1076,
#  'HELLS': 509,
#  'G6PD': 2370,
#  'DBH': 693,
#  'SRSF2': 623,
#  'TBP': 868,
#  'PAX3': 1000,
#  'AKT2': 1653,
#  'UVSSA': 267,
#  'SQSTM1': 2319,
#  'FANCA': 811,
#  'TYRP1': 1252,
#  'STAG1': 641,
#  'FECH': 591,
#  'RAD51': 973,
#  'CHEK2': 1820,
#  'SACS': 963,
#  'RFC1': 2139,
#  'JAK2': 2975,
#  'CDK8': 749,
#  'PDX1': 563,
#  'POMP': 367,
#  'BNIP3L': 399,
#  'CHD3': 600,
#  'AVP': 960,
#  'MTAP': 661,
#  'BRCA2': 1843,
#  'ITPA': 549,
#  'PHKA2': 420,
#  'RREB1': 628,
#  'DDX58': 728,
#  'ISG15': 693,
#  'LYRM7': 249,
#  'GATA3': 1384,
#  'POLA1': 746,
#  'GALT': 521,
#  'RAD50': 607,
#  'FANCG': 646,
#  'ATP6AP2': 821,
#  'LPAR6': 551,
#  'DCLRE1C': 481,
#  'TDP2': 485,
#  'KDM6A': 627,
#  'MGME1': 357,
#  'FTL': 625,
#  'NMNAT1': 505,
#  'GATA1': 1490,
#  'MTHFR': 1639,
#  'HNRNPK': 837,
#  'FOXP3': 1831,
#  'ISCA1': 332,
#  'SDHB': 1255,
#  'SKIV2L': 536,
#  'PINK1': 1143,
#  'TGFBR1': 1158,
#  'ABCA1': 1739,
#  'AR': 7003,
#  'MED12': 1289,
#  'AHDC1': 212,
#  'OGT': 884,
#  'HDAC8': 1445,
#  'UGT1A1': 1181,
#  'ATRX': 1387,
#  'PGK1': 690,
#  'ADA': 2226,
#  'ZMPSTE24': 930,
#  'POLR1C': 525,
#  'ABL1': 1850,
#  'MMP9': 8056,
#  'PTCH2': 453,
#  'PTEN': 5807,
#  'SLC16A12': 225,
#  'UBE2A': 629,
#  'XIAP': 2219,
#  'FMR1': 1269,
#  'ABCC2': 1414,
#  'CHUK': 759,
#  'HMGB3': 394,
#  'NSDHL': 543,
#  'DPYD': 1024,
#  'SUFU': 781,
#  'CYP17A1': 1822,
#  'EMD': 1024,
#  'DKC1': 668,
#  'PHGDH': 1569,
#  'GJA8': 603,
#  'BUB3': 671,
#  'ADAR': 961,
#  'LMNA': 1380,
#  'MED23': 632,
#  'SDHC': 659,
#  'ATF6': 660,
#  'FASLG': 906,
#  'RNASEL': 789,
#  'CDC73': 596,
#  'UBE2T': 581,
#  'IBA57': 352,
#  'MTR': 316,
#  'COL6A1': 269,
#  'DMD': 1279,
#  'CDC14A': 297,
#  'SMC3': 627,
#  'MTOR': 5874,
#  'TOP1': 699,
#  'FAN1': 185,
#  'ZEB1': 247,
#  'STAT1': 1260,
#  'RFWD3': 239,
#  'CYP2D6': 1895,
#  'RTEL1': 375,
#  'TFRC': 1467,
#  'DHDDS': 1866,
#  'TRRAP': 680,
#  'PCNT': 736,
#  'DNMT1': 837,
#  'XRCC2': 672,
#  'SMARCAD1': 404,
#  'TGFBR2': 1094,
#  'VCP': 1211,
#  'REV3L': 589,
#  'CASP8': 1275,
#  'NF1': 1554,
#  'PHF8': 539,
#  'ACTB': 1204,
#  'SMARCAL1': 502,
#  'XPNPEP3': 359,
#  'CHD4': 618,
#  'NHEJ1': 398,
#  'GTF2E2': 1369,
#  'MLH3': 469,
#  'RET': 2575,
#  'HTT': 1312,
#  'FN1': 1177,
#  'OCA2': 744,
#  'ATP7A': 979,
#  'UBQLN2': 617,
#  'NF2': 1709,
#  'CTNNB1': 1840,
#  'LIN28B': 446,
#  'ATR': 1874,
#  'USP7': 699,
#  'MCPH1': 445,
#  'EYA1': 599,
#  'SLC25A15': 459,
#  'HNRNPA1': 894,
#  'FAM111B': 181,
#  'SMAD4': 2145,
#  'SLC24A5': 366,
#  'MAPT': 5774,
#  'MAOA': 1216,
#  'HUWE1': 736,
#  'TAF1A': 334,
#  'LBR': 1635,
#  'FGFR3': 3198,
#  'RPS7': 1155,
#  'UBA1': 604,
#  'SNCA': 1765,
#  'LCK': 2150,
#  'RNASEH2B': 444,
#  'DACT1': 517,
#  'TDP1': 1392,
#  'UNC119': 495,
#  'RAD51C': 768,
#  'ARID2': 571,
#  'GATA4': 1416,
#  'HDAC6': 2802,
#  'HBB': 835,
#  'USP45': 252,
#  'SMAD3': 2636,
#  'NDN': 512,
#  'COL7A1': 612,
#  'RARB': 1215,
#  'ATP6V0A2': 2041,
#  'NOP10': 520,
#  'IDH2': 942,
#  'NPLOC4': 502,
#  'BOLA3': 264,
#  'WT1': 1838,
#  'FANCF': 545,
#  'TBK1': 1102,
#  'GLRX5': 472,
#  'DNMT3B': 1002,
#  'RNF135': 387,
#  'TRAIP': 524,
#  'NKX2-5': 745,
#  'LMNB2': 457,
#  'MAF': 1122,
#  'PSEN1': 1763,
#  'TMC8': 328,
#  'STK11': 1564,
#  'WRAP53': 472,
#  'SOX2': 2128,
#  'PNKP': 626,
#  'SMC1A': 823,
#  'ATRIP': 466,
#  'NDUFAF3': 590,
#  'MMP1': 2560,
#  'POLE': 806,
#  'TUFM': 636,
#  'TALDO1': 597,
#  'CNOT1': 550,
#  'RNF168': 580,
#  'CALR': 2018,
#  'ARID1A': 969,
#  'EZH2': 1963,
#  'MET': 2895,
#  'SNRNP200': 583,
#  'STAT2': 911,
#  'CTC1': 506,
#  'PRKDC': 910,
#  'RNASEH1': 462,
#  'HNF4A': 1607,
#  'LEP': 5866,
#  'UCP2': 982,
#  'FANCI': 709,
#  'BANF1': 634,
#  'TERT': 2498,
#  'GLE1': 489,
#  'LEMD3': 523,
#  'RNASEH2C': 535,
#  'EIF2AK3': 952,
#  'ESCO2': 630,
#  'PPM1D': 459,
#  'TUB': 469,
#  'MPLKIP': 441,
#  'IGF1': 2380,
#  'UBTF': 619,
#  'AGXT': 1087,
#  'BUB1': 805,
#  'MAP2K1': 2455,
#  'POLR1D': 586,
#  'FADD': 1102,
#  'KMT2D': 927,
#  'CDT1': 968,
#  'PPIB': 8640,
#  'RAG1': 861,
#  'LRRK2': 1990,
#  'HPRT1': 1276,
#  'WRN': 1091,
#  'RAD21': 713,
#  'SHH': 1627,
#  'NPM1': 1270,
#  'SLC45A2': 370,
#  'MASP1': 598,
#  'RHO': 4318,
#  'ALB': 4255,
#  'IHH': 628,
#  'MITF': 1632,
#  'SPRTN': 371,
#  'SLX4': 654,
#  'WNT1': 997,
#  'UBR1': 675,
#  'FANCC': 1194,
#  'ERCC6L2': 128,
#  'KIT': 4843,
#  'PPARG': 3570,
#  'FANCD2': 923,
#  'BUB1B': 996,
#  'NSMCE2': 389,
#  'GNAQ': 781,
#  'CASP10': 578,
#  'HNRNPU': 646,
#  'GJA1': 1172,
#  'NIPBL': 722,
#  'CRYGC': 1117,
#  'GRID2': 401,
#  'NUBPL': 441,
#  'MYCN': 1119,
#  'NGLY1': 458,
#  'HNMT': 422,
#  'CEP164': 557,
#  'MYRF': 468,
#  'ATM': 3707,
#  'NOTCH1': 2816,
#  'NDUFB9': 600,
#  'NONO': 629,
#  'NHP2': 628,
#  'SOD1': 2925,
#  'SMG9': 390,
#  'KRT10': 549,
#  'EIF4A3': 678,
#  'POLG': 863,
#  'IGF1R': 2089,
#  'FANCM': 597,
#  'TINF2': 678,
#  'RB1': 2378,
#  'SMARCC2': 599,
#  'DHH': 485,
#  'PMS2': 799,
#  'SMARCA2': 816,
#  'CDK6': 1572,
#  'NBN': 1185,
#  'AFF4': 483,
#  'EGF': 3682,
#  'CENPE': 687,
#  'MSH3': 670,
#  'SDHA': 1195,
#  'PPARGC1A': 923,
#  'KLF1': 391,
#  'TP63': 3136,
#  'DNMT3A': 1247,
#  'MTRR': 570,
#  'STAT3': 6659,
#  'WNT5A': 1771,
#  'TUBB4A': 836,
#  'CTCF': 1087,
#  'PIK3CA': 7686,
#  'POLR1A': 580,
#  'AKT3': 1049,
#  'BRD4': 1164,
#  'TYR': 1341,
#  'EP300': 1479,
#  'SMARCB1': 1102,
#  'SAMHD1': 713,
#  'SRCAP': 521,
#  'CREBBP': 3958,
#  'AXIN1': 962,
#  'YY1': 1288,
#  'MCM4': 691,
#  'CDH1': 1693,
#  'PALB2': 795,
#  'LIAS': 492,
#  'LMNB1': 700,
#  'CCND2': 1278,
#  'BARD1': 714,
#  'KIF11': 1316,
#  'LRPPRC': 810,
#  'ADAM10': 793,
#  'BRIP1': 897,
#  'IREB2': 473,
#  'MDM2': 4363,
#  'RINT1': 383,
#  'APC': 2693,
#  'PDGFRA': 1349,
#  'SLCO1B1': 847,
#  'KRAS': 1811,
#  'IGHMBP2': 427,
#  'FUS': 1254,
#  'RARA': 1600,
#  'ABCB7': 523,
#  'TRIM28': 789,
#  'APOE': 1930,
#  'KRT6B': 792,
#  'KRT5': 647,
#  'MED17': 402,
#  'RAF1': 2501,
#  'MYOD1': 643,
#  'HSPB1': 1918,
#  'GFER': 1065,
#  'THOC2': 513,
#  'ATP7B': 678,
#  'AHR': 2467,
#  'TTR': 3146,
#  'MAD2L2': 630,
#  'MSH6': 1010,
#  'MSH2': 1206,
#  'UMPS': 530,
#  'NPRL2': 376,
#  'UBE3A': 1523,
#  'MLH1': 1387,
#  'NR3C1': 2284,
#  'GMNN': 956,
#  'FANCE': 651,
#  'GCLC': 1893,
#  'TPI1': 618,
#  'NUP107': 712,
#  'CDKN1B': 2138,
#  'GLI1': 1645,
#  'CYP27B1': 513,
#  'KITLG': 2915,
#  'CCND1': 5151,
#  'NFKB1': 1557,
#  'PHOX2B': 561,
#  'COL1A1': 1241,
#  'SETX': 471,
#  'CRX': 801,
#  'TGFB1': 9079,
#  'RNASEH2A': 569,
#  'GSR': 1846,
#  'TGM5': 356,
#  'STUB1': 729,
#  'TSC2': 1506,
#  'USB1': 365,
#  'MMP2': 7392,
#  'FERMT1': 411,
#  'CSNK2A1': 921,
#  'EEF1A2': 1017,
#  'CYP24A1': 469,
#  'MTHFD1': 584,
#  'ACO2': 683,
#  'VCL': 998,
#  'CDC6': 1009,
#  'OSGEP': 506,
#  'KRT14': 682,
#  'TRIP13': 622,
#  'TNFRSF1A': 1785,
#  'GNA11': 636,
#  'CFTR': 1918,
#  'EFTUD2': 616,
#  'OBSL1': 525,
#  'YAP1': 779,
#  'PRKN': 921,
#  'SUZ12': 715,
#  'LARP7': 432,
#  'CYLD': 1052,
#  'EED': 770,
#  'PPP2R1A': 788,
#  'PRPF8': 608,
#  'TUBB': 828,
#  'PPP2CA': 910,
#  'MRE11': 521,
#  'PIK3R1': 1989,
#  'HFM1': 1192,
#  'GTF2H4': 509,
#  'MYC': 3503,
#  'APAF1': 557,
#  'ENDOV': 257,
#  'MMS19': 482,
#  'BBC3': 515,
#  'CDKN1A': 7400,
#  'BCL2': 4482,
#  'POLM': 322,
#  'MAPK8': 7641,
#  'HSPA1A': 1216,
#  'GADD45A': 1144,
#  'CETN2': 541,
#  'SFN': 826,
#  'PMAIP1': 782,
#  'WDR48': 704,
#  'HSPA9': 2027,
#  'BTG2': 857,
#  'IFNA1': 7673,
#  'TNFRSF10B': 2356,
#  'EGFR': 9004,
#  'GTF2H1': 713,
#  'POLQ': 460,
#  'CCNH': 1161,
#  'TERF2': 613,
#  'RPA1': 656,
#  'NR1H2': 642,
#  'AAGAB': 515,
#  'WDR77': 932,
#  'PSMC6': 1524,
#  'LRRC59': 598,
#  'CSH1': 2605,
#  'CPD': 447,
#  'ERVK-11': 3129,
#  'ERVK-19': 3327,
#  'ERVK-9': 3079,
#  'FASTK': 1878,
#  'REXO2': 381,
#  'FASN': 3770,
#  'TRIAP1': 393,
#  'AEN': 267,
#  'BAX': 5178,
#  'MIR744': 377,
#  'MIR373': 321,
#  'MIR346': 290,
#  'MIR21': 1519,
#  'U2': 124,
#  'TARID': 119,
#  'SCAANT1': 111,
#  'RNR3': 82,
#  'MEG8': 248,
#  'MUC13': 411,
#  'PRIM2': 463,
#  'CD24': 1058,
#  'NTMT1': 166,
#  'CRABP2': 365,
#  'ZNF501': 339,
#  'CGA': 2596,
#  'PER3': 392,
#  'SLC38A3': 387,
#  'E2F8': 415,
#  'MCM3': 621,
#  'FGF1': 1052,
#  'POLD2': 427,
#  'POLR2A': 670,
#  'ALOX5AP': 2602,
#  'UHRF1': 509,
#  'RHNO1': 199,
#  'HNRNPCL1': 150,
#  'LTN1': 360,
#  'VEGFA': 11194,
#  'POLR2E': 513,
#  'IGHV4-38-2': 270,
#  'ABCB1': 3810,
#  'CRY2': 651,
#  'ANXA8': 312,
#  'NAP1L1': 584,
#  'APBB1': 567,
#  'SIRT5': 489,
#  'POLDIP2': 3150,
#  'COMMD3-BMI1': 393,
#  'RUVBL2': 685,
#  'RPS5': 1534,
#  'IRF3': 1479,
#  'SUPT5H': 598,
#  'UPF1': 743,
#  'RAD23A': 507,
#  'AC004223.3': 243,
#  'LSM12': 133,
#  'POLRMT': 405,
#  'PIAS2': 519,
#  'RBFOX3': 550,
#  'KLF14': 324,
#  'POLI': 1852,
#  'ZP2': 364,
#  'CTRL': 811,
#  'COX4I1': 532,
#  'PECAM1': 1442,
#  'EME2': 214,
#  'DET1': 440,
#  'MRC1': 654,
#  'ASIP': 1840,
#  'RNF111': 532,
#  'B2M': 1229,
#  'BCL2L2-PABPN1': 295,
#  'XRCC3': 714,
#  'NDRG2': 319,
#  'AC092143.1': 257,
#  'HNRNPC': 1003,
#  'TIMELESS': 932,
#  'DDIT3': 1048,
#  'SOD2': 2109,
#  'GTF2H3': 482,
#  'CUL2': 561,
#  'SCO2': 538,
#  'OTUB1': 570,
#  'CITED2': 663,
#  'POLR1B': 416,
#  'NAT1': 375,
#  'CAND1': 553,
#  'ITGAM': 2788,
#  'UBC': 1039,
#  'NNMT': 425,
#  'CYP2E1': 2141,
#  'PSMD9': 3596,
#  'NFE2': 383,
#  'AL139300.1': 247,
#  'MDH1': 522,
#  'HIF1A': 2581,
#  'DICER1': 865,
#  'MUC5B': 808,
#  'NXF1': 825,
#  'EIF3M': 398,
#  'POLN': 252,
#  'FAU': 608,
#  'CASP1': 1239,
#  'HSPA8': 1188,
#  'HSF1': 744,
#  'HDAC2': 2111,
#  'RNF130': 997,
#  'LYRM2': 111,
#  'ENY2': 333,
#  'ERI1': 378,
#  'SLC25A37': 385,
#  'CCNC': 523,
#  'TCEA1': 677,
#  'CETN3': 360,
#  'UBE2V2': 894,
#  'RPL30': 592,
#  'NACA2': 194,
#  'CEBPA': 858,
#  'RNF4': 624,
#  'RAD17': 560,
#  'DROSHA': 697,
#  'EIF4E': 901,
#  'NEDD4': 964,
#  'PLRG1': 366,
#  'SMUG1': 880,
#  'PAQR3': 282,
#  'TIPARP': 632,
#  'TFAM': 610,
#  'BAG1': 515,
#  'PHC3': 484,
#  'ADH7': 398,
#  'NR6A1': 400,
#  'POLE4': 463,
#  'ZMYND8': 286,
#  'LYRM4': 284,
#  'CDK5': 813,
#  'SSBP1': 513,
#  'RAD51B': 497,
#  'TAF1L': 376,
#  'CIAO1': 331,
#  'MCM10': 560,
#  'FHIT': 882,
#  'BAP1': 679,
#  'DHX36': 529,
#  'RECQL': 418,
#  'EIF4G1': 961,
#  'DCAF11': 210,
#  'POLR2H': 472,
#  'KLC1': 499,
#  'C7orf25': 90,
#  'IL10': 3510,
#  'TOP2A': 997,
#  'PTPRC': 1900,
#  'STMN1': 506,
#  'MAP2K4': 534,
#  'SUMO3': 375,
#  'OTUD4': 357,
#  'RFC5': 538,
#  'GPX1': 815,
#  'PMS1': 431,
#  'TCEA3': 331,
#  'KAT8': 788,
#  'SUMO2': 621,
#  'SMC6': 314,
#  'PPP1R13L': 472,
#  'BRAP': 787,
#  'LTA': 1303,
#  'PMEL': 1991,
#  'SENP6': 358,
#  'SMG1': 808,
#  'WEE1': 1034,
#  'RANGAP1': 525,
#  'ERN1': 633,
#  'EWSR1': 887,
#  'HMGA1': 940,
#  'CDK12': 525,
#  'TNF': 19386,
#  'CD44': 3734,
#  'L3MBTL1': 432,
#  'ALKBH2': 263,
#  'E2F5': 452,
#  'NFIC': 617,
#  'TOP2B': 519,
#  'SENP1': 526,
#  'SESN1': 359,
#  'CDC7': 794,
#  'HTATIP2': 608,
#  'DCT': 385,
#  'CHFR': 392,
#  'PPP6C': 503,
#  'CYB561D2': 168,
#  'SLC16A5': 191,
#  'CHEK1': 2297,
#  'CREB1': 3386,
#  'UBE4A': 922,
#  'IMMT': 683,
#  'CD8A': 1380,
#  'MCC': 613,
#  'DAPK1': 724,
#  'FOXO3': 2165,
#  'MARK2': 810,
#  'IL6': 5944,
#  'HIPK2': 653,
#  'PPARA': 3462,
#  'ELAVL1': 716,
#  'APOBEC3G': 670,
#  'XPO1': 776,
#  'AKAP12': 422,
#  'ARNTL': 567,
#  'PARG': 478,
#  'APOBEC3A': 515,
#  'RELA': 4386,
#  'PAXIP1': 536,
#  'NCOR2': 863,
#  'SUN1': 433,
#  'TUBA3C': 500,
#  'RUNX3': 615,
#  'PAICS': 517,
#  'NEURL4': 227,
#  'ABCC1': 870,
#  'PARP3': 448,
#  'UBE2D2': 604,
#  'DOT1L': 539,
#  'GSTP1': 1388,
#  'TMPRSS2': 482,
#  'CABIN1': 343,
#  'LONRF1': 274,
#  'CBSL': 325,
#  'KHSRP': 625,
#  'MAP2K7': 855,
#  'RNASE1': 597,
#  'MED13': 447,
#  'TEN1': 207,
#  'MYCL': 381,
#  'DEK': 600,
#  'NUDT1': 333,
#  'CSNK1E': 595,
#  'DKK3': 395,
#  'DDX39B': 526,
#  'ELP4': 291,
#  'RAE1': 565,
#  'CXCL12': 1201,
#  'CXCL1': 830,
#  'QPRT': 392,
#  'CDK1': 3336,
#  'FZR1': 655,
#  'SPP1': 1032,
#  'PBRM1': 564,
#  'ACYP2': 211,
#  'FKBP2': 475,
#  'CIAPIN1': 417,
#  'RPL24': 480,
#  'PTTG1': 819,
#  'SLC29A1': 593,
#  'CDKN2D': 1105,
#  'CBX1': 458,
#  'EME1': 400,
#  'BCL2L11': 889,
#  'NRF1': 673,
#  'NME2': 653,
#  'NME1-NME2': 389,
#  'CUL5': 605,
#  'TDG': 461,
#  'ETS1': 1787,
#  'GRB2': 1874,
#  'TAOK3': 294,
#  'RFC4': 2065,
#  'SUMO1': 630,
#  'MAP3K4': 416,
#  'XRCC5': 916,
#  'TSN': 448,
#  'EP400': 433,
#  'RNF20': 515,
#  'ALK': 1751,
#  'GPX3': 520,
#  'SETMAR': 297,
#  'NEK11': 270,
#  'RNMT': 1438,
#  'SIRT3': 585,
#  'DEFA1': 1027,
#  'DEFA1B': 532,
#  'SOD3': 419,
#  'TP53BP1': 581,
#  'PARP4': 296,
#  'SRXN1': 367,
#  'TNK2': 622,
#  'GART': 703,
#  'CD274': 1220,
#  'E2F6': 438,
#  'MLANA': 432,
#  'TGM3': 401,
#  'SLC25A6': 573,
#  'CCP110': 522,
#  'DDX1': 562,
#  'POLR2B': 597,
#  'GTF3A': 996,
#  'IGFBP3': 931,
#  'DUT': 636,
#  'SERF1B': 217,
#  'HMGN1': 454,
#  'PSIP1': 1786,
#  'TLR7': 1429,
#  'CNTLN': 313,
#  'NAP1L4': 314,
#  'ZNF763': 335,
#  'IFNB1': 930,
#  'IFNA2': 772,
#  'NABP2': 310,
#  'RBBP7': 567,
#  'RFC3': 497,
#  'GLRX': 639,
#  'RIOK1': 431,
#  'SMAD9': 535,
#  'CYP1A1': 2510,
#  'KIN': 379,
#  'FOXO1': 1100,
#  'ASPH': 645,
#  'NEDD9': 405,
#  'XDH': 1155,
#  'E2F4': 472,
#  'DNAJC2': 312,
#  'LYRM9': 73,
#  'MAGEB10': 66,
#  'MCM8': 651,
#  'LGALS7': 386,
#  'LIG3': 491,
#  'APRT': 1302,
#  'TP73': 809,
#  'TRDMT1': 320,
#  'SF1': 672,
#  'UIMC1': 484,
#  'XRN2': 504,
#  'KLF9': 424,
#  'UBD': 567,
#  'BMI1': 642,
#  'TLE1': 592,
#  'MDC1': 518,
#  'UBQLN1': 675,
#  'ING1': 509,
#  'CARD16': 590,
#  'MSH5': 511,
#  'HSPA1B': 620,
#  'EHMT2': 983,
#  'CUL4A': 646,
#  'NELFE': 994,
#  'STK19': 391,
#  'FOXE1': 570,
#  'CDA': 1054,
#  'GALNT12': 294,
#  'APEX2': 250,
#  'AOX1': 884,
#  'KLF4': 1288,
#  'DAXX': 968,
#  'TXN': 912,
#  'KIF4A': 523,
#  'MAN1C1': 209,
#  'FOXO4': 610,
#  'CNKSR1': 450,
#  'INIP': 141,
#  'SLC31A1': 357,
#  'NFS1': 723,
#  'SPDEF': 435,
#  'PHF20': 341,
#  'TLR4': 4541,
#  'UBE2D1': 652,
#  'RPA2': 627,
#  'RCC1': 488,
#  'PEF1': 398,
#  'RBL1': 480,
#  'TET1': 668,
#  'SRC': 2637,
#  'SCAI': 380,
#  'HDAC1': 4440,
#  'RBBP4': 557,
#  'RNF8': 600,
#  'GLO1': 602,
#  'CDK9': 827,
#  'CCND3': 681,
#  'CSTF2': 483,
#  'NOX1': 914,
#  'PLAU': 1536,
#  'ENDOG': 480,
#  'YBX1': 570,
#  'CDC20': 835,
#  'PLK3': 457,
#  'MUTYH': 494,
#  'RAD54L': 433,
#  'SLC25A5': 2308,
#  'NDOR1': 631,
#  'TCTE1': 133,
#  'CDC5L': 604,
#  'PLCE1': 452,
#  'CYP2C19': 2077,
#  'CYP2C8': 868,
#  'SPO11': 437,
#  'JUN': 1816,
#  'DNTT': 508,
#  'SMARCA1': 602,
#  'GSTA4': 403,
#  'PSMA7': 1624,
#  'USP33': 359,
#  'FUBP1': 462,
#  'RBMX': 566,
#  'GTF2B': 663,
#  'SLC25A28': 272,
#  'CSAG1': 110,
#  'BTRC': 610,
#  'POLL': 403,
#  'SLC30A7': 301,
#  'AS3MT': 342,
#  'TTK': 840,
#  'OVGP1': 342,
#  'GSTO1': 840,
#  'ME1': 573,
#  'DDX20': 478,
#  'DCLRE1B': 348,
#  'SYCP1': 358,
#  'BRCC3': 455,
#  'CASP7': 869,
#  'CHD1L': 510,
#  'ASCC3': 278,
#  'BOLA1': 140,
#  ...}

# %%
len(relevant_top_genes_list)
# Out:
# 1630

# %%
# %store gene_edges_out
# Out:
# Stored 'gene_edges_out' (dict)

# %%
# %store -r gene_edges_out

# %% [markdown]
# ## 6. Assemble Genes related to both Disease and Disease Symptoms

# %%
# disease_to_gene_results 
# disease_to_all_nodes_to_genes_results


# relevant_genes_to_symptoms_df 




final_dict = {}

relevant_top_genes_list[1]

for x in relevant_top_genes_list
    final_dict[x] = {
        "disease_to_gene_occurrences" = disease_to_gene_results['sorted_disease_to_genes'][x] if x in disease_to_gene_results['sorted_disease_to_genes'] else 0,
        "disease_to_gene_pub_counts" = disease_to_gene_results['one_step_genes_pub_counts'][x] if x in disease_to_gene_results['one_step_genes_pub_counts'] else 0,
        "disease_to_int_to_gen_occurrences" = disease_to_all_nodes_to_genes_results['sorted_disease_to_all_nodes_to_genes'][x] if x in disease_to_all_nodes_to_genes_results['sorted_disease_to_all_nodes_to_genes'] else 0,
        "disease_to_int_to_gene_pubs" = disease_to_all_nodes_to_genes_results['top_two_step_genes_pub_counts'][x] if x in disease_to_all_nodes_to_genes_results['top_two_step_genes_pub_counts'] else 0,
        "disease_symtpoms_gene_related_to" = 
    }
# Out:
# 'ERCC2'

# %%
disease_to_all_nodes_to_genes_results.keys()
# Out:
# dict_keys(['top_related_genes_to_disease', 'sorted_disease_to_all_nodes_to_genes', 'top_two_step_genes_pub_counts'])

# %%
disease_symptoms
# Out:
# ['FLAT, DISCOLORED AREA OF SKIN',
#  'MACULE',
#  'CRANIOFACIAL HYPEROSTOSIS',
#  'ENLARGEMENT OF CRANIOFACIAL BONES',
#  'EXCESSIVE BONE GROWTH OF THE SKULL AND FACE',
#  'EXCESSIVE GROWTH OF CRANIOFACIAL BONES',
#  'HYPEROSTOSIS OF CRANIOFACIAL BONES',
#  'HYPERTROPHY OF CRANIOFACIAL BONES',
#  'INCREASED OSSIFICATION OF CRANIOFACIAL BONES',
#  'OVERGROWTH OF CRANIOFACIAL BONES',
#  'THICK CRANIOFACIAL BONES',
#  'ATROPHIC SKIN',
#  'DERMAL ATROPHY',
#  'SKIN ATROPHY',
#  'SKIN DEGENERATION',
#  'DECREASED BODY HEIGHT',
#  'HEIGHT LESS THAN 3RD PERCENTILE',
#  'SHORT STATURE',
#  'SMALL STATURE',
#  'STATURE BELOW 3RD PERCENTILE',
#  'NEUROPATHY',
#  'PERIPHERAL NERVE DAMAGE',
#  'PERIPHERAL NEURITIS',
#  'PERIPHERAL NEUROPATHY',
#  'ADHESION OF EYELIDS',
#  'ANKYLOBLEPHARON',
#  'ANKYLOBLEPHARON FILIFORME ADNATUM',
#  'EYELID SYNECHIAE',
#  'EYELIDS STUCK TOGETHER',
#  'CANCER OF SKIN PIGMENT CELLS',
#  'MALIGNANT MELANOMA',
#  'MELANOMA',
#  'SKIN CANCER (MELANOMA)',
#  'ARTHRALGIA',
#  'ARTHRALGIAS',
#  'ARTHRITIC PAIN',
#  'JOINT PAIN',
#  'JOINT PAINS',
#  'DELAYED BONE AGE',
#  'DELAYED BONE AGE BEFORE PUBERTY',
#  'DELAYED BONE MATURATION',
#  'DELAYED SKELETAL DEVELOPMENT',
#  'DELAYED SKELETAL MATURATION',
#  'RETARDED BONE AGE',
#  'RETARDED OSSIFICATION',
#  'SKELETAL MATURATION RETARDATION',
#  'ABNORMAL TISSUE MASS',
#  'CANCER',
#  'NEOPLASIA',
#  'NEOPLASM',
#  'ONCOLOGICAL ABNORMALITY',
#  'ONCOLOGY',
#  'TUMOR',
#  'TUMOUR',
#  'PAPILLOMA',
#  'DEVELOPMENTAL REGRESSION',
#  'LOSS OF DEVELOPMENTAL MILESTONES',
#  'MENTAL DETERIORATION IN CHILDHOOD',
#  'NEURODEVELOPMENTAL REGRESSION',
#  'PSYCHOMOTOR REGRESSION',
#  'PSYCHOMOTOR REGRESSION BEGINNING IN INFANCY',
#  'PSYCHOMOTOR REGRESSION IN INFANTS',
#  'PSYCHOMOTOR REGRESSION, PROGRESSIVE',
#  'ABNORMAL EEG',
#  'ABNORMAL ELECTROENCEPHALOGRAM',
#  'EEG ABNORMALITIES',
#  'EEG ABNORMALITY',
#  'ELECTROENCEPHALOGRAM ABNORMAL',
#  'ELECTROENCEPHALOGRAM ABNORMALITIES',
#  'CEREBRAL CORTEX ATROPHY',
#  'CEREBRAL CORTICAL ATROPHY',
#  'CORTICAL ATROPHY',
#  'DECREASE IN SIZE OF THE OUTER LAYER OF THE BRAIN DUE TO LOSS OF BRAIN CELLS',
#  'CUTANEOUS PHOTOSENSITIVITY',
#  'PHOTOSENSITIVE SKIN',
#  'PHOTOSENSITIVE SKIN RASHES',
#  'PHOTOSENSITIVITY',
#  'SENSITIVITY TO SUNLIGHT',
#  'SKIN PHOTOSENSITIVITY',
#  'SUN SENSITIVITY',
#  'FATIGUE',
#  'MALAISE',
#  'TIRED',
#  'TIREDNESS',
#  'THIN SKIN',
#  'HYPERKERATOSIS',
#  'DRY SKIN',
#  'XEROSIS',
#  'ABNORMALITY OF EXTRAPYRAMIDAL MOTOR FUNCTION',
#  'EXTRAPYRAMIDAL DYSFUNCTION',
#  'EXTRAPYRAMIDAL SIGNS',
#  'EXTRAPYRAMIDAL SYMPTOMS',
#  'EXTRAPYRAMIDAL SYNDROME',
#  'EXTRAPYRAMIDAL TRACT SIGNS',
#  'ERYTHEMA',
#  'REDNESS OF SKIN OR MUCOUS MEMBRANE',
#  'CONJUNCTIVAL TELANGIECTASES',
#  'CONJUNCTIVAL TELANGIECTASIA',
#  'SMALL DILATED BLOOD VESSELS NEAR MEMBRANE COVERING FRONT OF EYE AND EYELIDS',
#  'TELANGIECTASIA, CONJUNCTIVAL',
#  'CORNEAL INFLAMMATION',
#  'KERATITIS',
#  'CROSS-EYED',
#  'SQUINT',
#  'SQUINT EYES',
#  'STRABISMUS',
#  'HEARING LOSS, SENSORINEURAL',
#  'SENSORINEURAL DEAFNESS',
#  'SENSORINEURAL HEARING IMPAIRMENT',
#  'SENSORINEURAL HEARING LOSS',
#  'BLEPHARITIS',
#  'CELLULITIS OF EYELIDS',
#  'INFLAMMATION OF EYELIDS',
#  'DIFFUSELY THICKENED SKIN',
#  'PACHYDERMIA',
#  'THICK SKIN',
#  'THICKENED SKIN',
#  'DEPRESSED NASAL ALAE',
#  'FLAT NASAL ALAE',
#  'ABNORMALLY SMALL CRANIUM',
#  'ABNORMALLY SMALL HEAD',
#  'ABNORMALLY SMALL SKULL',
#  'DECREASED CIRCUMFERENCE OF CRANIUM',
#  'DECREASED SIZE OF CRANIUM',
#  'DECREASED SIZE OF HEAD',
#  'DECREASED SIZE OF SKULL',
#  'MICROCEPHALY',
#  'REDUCED HEAD CIRCUMFERENCE',
#  'SMALL CALVARIUM',
#  'SMALL CRANIUM',
#  'SMALL HEAD',
#  'SMALL HEAD CIRCUMFERENCE',
#  'SMALL SKULL',
#  'ABNORMAL DENTITION',
#  'ABNORMAL TEETH',
#  'ABNORMALITY OF THE DENTITION',
#  'ABNORMALITY OF THE TEETH',
#  'DENTAL ABNORMALITIES',
#  'DENTAL ABNORMALITY',
#  'DENTAL ANOMALIES',
#  'DENTAL PROBLEM',
#  'DENTAL PROBLEMS',
#  'TOOTH ABNORMALITIES',
#  'DECREASED ACTIVITY OF GONADS',
#  'HYPOGONADISM',
#  'ABNORMALITY OF COGNITION',
#  'COGNITIVE ABNORMALITY',
#  'COGNITIVE DEFECTS',
#  'COGNITIVE DEFICITS',
#  'COGNITIVE IMPAIRMENT',
#  'INTELLECTUAL IMPAIRMENT',
#  'MENTAL IMPAIRMENT',
#  'FEVER',
#  'HYPERTHERMIA',
#  'PYREXIA',
#  'ABNORMAL URINARY AMINO-ACID FINDINGS',
#  'AMINOACIDURIA',
#  'HIGH URINE AMINO ACID LEVELS',
#  'HYPERAMINOACIDURIA',
#  'INCREASED LEVELS OF ANIMO ACIDS IN URINE',
#  'DECREASED TESTICULAR SIZE',
#  'HYPOPLASTIC TESTES',
#  'SMALL TESTES',
#  'SMALL TESTIS',
#  'TESTICULAR HYPOPLASIA',
#  'OPTIC ATROPHY',
#  'OPTIC NERVE ATROPHY',
#  'OPTIC-NERVE DEGENERATION',
#  'TELANGIECTASIA OF THE SKIN',
#  'TELEANGIECTASIA OF THE SKIN',
#  'ALOPECIA',
#  'HAIR LOSS',
#  'FAILURE TO THRIVE',
#  'FALTERING WEIGHT',
#  'POOR WEIGHT GAIN',
#  'POSTNATAL FAILURE TO THRIVE',
#  'UNDERGROWTH',
#  'WEIGHT FALTERING',
#  'FRECKLING',
#  'CRYPTORCHIDISM',
#  'CRYPTORCHISM',
#  'UNDESCENDED TESTES',
#  'UNDESCENDED TESTIS',
#  'ABSENT OR DECREASED DEEP TENDON REFLEXES',
#  'DECREASED DEEP TENDON REFLEXES',
#  'DECREASED TENDON REFLEXES',
#  'DECREASED TO ABSENT DEEP TENDON REFLEXES',
#  'DECREASED/ABSENT DEEP TENDON REFLEXES',
#  'DEPRESSED TENDON REFLEXES',
#  'DIMINISHED DEEP TENDON REFLEXES',
#  'DIMINISHED OR ABSENT DEEP TENDON REFLEXES',
#  'DIMINISHED OR ABSENT TENDON REFLEXES',
#  'HYPOACTIVE TO ABSENT DEEP TENDON REFLEXES',
#  'IMPAIRED TENDON REFLEXES',
#  'REDUCED TENDON REFLEXES',
#  'REDUCED/ABSENT DEEP TENDON REFLEXES',
#  'WEAK OR ABSENT DEEP TENDON REFLEXES',
#  'INTELLECTUAL DISABILITY, PROGRESSIVE',
#  'MENTAL RETARDATION, PROGRESSIVE',
#  'PROGRESSIVE MENTAL RETARDATION',
#  'INVOLUNTARY MUSCLE STIFFNESS, CONTRACTION, OR SPASM',
#  'MUSCLE SPASTICITY',
#  'MUSCULAR SPASTICITY',
#  'SPASTICITY',
#  'ATAXIA',
#  'CEREBELLAR ATAXIA',
#  'EPILEPSY',
#  'EPILEPTIC SEIZURE',
#  'SEIZURE',
#  'SEIZURES',
#  'CONGENITAL DEAFNESS',
#  'CONGENITAL HEARING LOSS',
#  'DEAFNESS',
#  'HEARING DEFECT',
#  'HEARING IMPAIRMENT',
#  'HEARING LOSS',
#  'HYPOACUSIS',
#  'EYE TUMOR',
#  'NEOPLASIA OF THE EYE',
#  'NEOPLASM OF THE EYE',
#  'PTERYGIA',
#  'PTERYGIUM',
#  'HYPOPIGMENTED SKIN PATCHES',
#  'PATCHY LOSS OF SKIN COLOR',
#  'HYPERMELANOTIC MACULE',
#  'HYPERPIGMENTED MACULES',
#  'HYPERPIGMENTED SKIN PATCHES',
#  'HYPERPIGMENTED SPOTS',
#  'POIKILODERMA',
#  'CUTANEOUS TELANGIECTASIA',
#  'SPIDER VEINS',
#  'TELANGIECTASES',
#  'TELANGIECTASIA',
#  'CATARACT',
#  'CATARACTS',
#  'CLOUDING OF THE LENS OF THE EYE',
#  'CLOUDY LENS',
#  'LENS OPACITIES',
#  'LENS OPACITY',
#  'EXTREME SENSITIVITY OF THE EYES TO LIGHT',
#  'LIGHT HYPERSENSITIVITY',
#  'PHOTODYSPHORIA',
#  'PHOTOPHOBIA',
#  'ENTROPION',
#  'EYELID FOLDED IN',
#  'EYELID TURNED IN',
#  'INVERTED EYELID',
#  'ECTROPION',
#  'EVERTED EYELID',
#  'EYELID FOLDED OUT',
#  'EYELID TURNED OUT',
#  'BEAUTY MARK',
#  'MELANOCYTIC NAEVUS',
#  'MELANOCYTIC NEVI',
#  'MELANOCYTIC NEVUS',
#  'NEVOCELLULAR NEVI',
#  'NONCANCEROUS MOLE',
#  'PIGMENTED NAEVI',
#  'PIGMENTED NEVI',
#  'CLOUDY CORNEA',
#  'CLOUDY CORNEAS',
#  'CORNEAL STROMAL OPACITY',
#  'OPACIFICATION OF THE CORNEAL STROMA']

# %%
genes_to_symptoms_df.iloc[[1,3,4]]
# Out:
#    input input_type    pred1 pred1_source        pred1_api  \
# 1  ERCC3       Gene  affects       SEMMED  SEMMED Gene API
# 3  ERCC3       Gene  affects       SEMMED  SEMMED Gene API
# 4  ERCC3       Gene  affects       SEMMED  SEMMED Gene API
#
#                                         pred1_pubmed        output_type  \
# 1                                           10467415  BiologicalProcess
# 3                                            9637787  BiologicalProcess
# 4  10214907,11335038,11412842,12221129,16427011,2...  BiologicalProcess
#
#   output_name      output_id
# 1    C0007587  UMLS:C0007587
# 3    C0011065  UMLS:C0011065
# 4    C0012899  UMLS:C0012899

# %%
relevant_genes_to_symptoms_df

# %%
relevant_top_genes_list
# Out:
# ['ERCC3',
#  'ERCC2',
#  'XPA',
#  'POLH',
#  'ERCC5',
#  'ERCC4',
#  'XPC',
#  'DDB2',
#  'EDNRA',
#  'ERCC1',
#  'DDX11',
#  'PCNA',
#  'FXN',
#  'NRAS',
#  'ERCC6',
#  'FAS',
#  'BLM',
#  'PTCH1',
#  'FOS',
#  'TP53',
#  'ERCC8',
#  'RRM2B',
#  'PERP',
#  'TERC',
#  'MUC1',
#  'LIG4',
#  'IKBKG',
#  'CHD1',
#  'HNRNPDL',
#  'ACD',
#  'C9orf72',
#  'RECQL4',
#  'PCGF2',
#  'EPHX1',
#  'CIB1',
#  'KIZ',
#  'RAG2',
#  'CYP1B1',
#  'ATXN3',
#  'SRD5A2',
#  'FRRS1L',
#  'GTF2H5',
#  'BIVM-ERCC5',
#  'TTN',
#  'RAD51D',
#  'GALK1',
#  'TMC6',
#  'RPL26',
#  'RBM8A',
#  'ACTG1',
#  'WWOX',
#  'ISCA2',
#  'AKT1',
#  'MC1R',
#  'BRF1',
#  'VDR',
#  'CYFIP2',
#  'TET2',
#  'TOP3A',
#  'PHC1',
#  'ATXN7',
#  'CUL7',
#  'CD19',
#  'FAM111A',
#  'PUF60',
#  'NTRK1',
#  'IKBKB',
#  'PROM1',
#  'RNASET2',
#  'XRCC4',
#  'POR',
#  'BRCA1',
#  'CDKN2A',
#  'NDUFA6',
#  'FTO',
#  'FDXR',
#  'SLC2A1',
#  'SLC35A2',
#  'RPS24',
#  'BDNF',
#  'CDKN1C',
#  'FBP1',
#  'HRAS',
#  'TAF1',
#  'SLC13A5',
#  'POLD1',
#  'CDC45',
#  'CLMP',
#  'ESR1',
#  'APTX',
#  'PNPT1',
#  'RHOA',
#  'TAF6',
#  'DIABLO',
#  'DHFR',
#  'SMARCA4',
#  'MECP2',
#  'FGFR1',
#  'CHD7',
#  'IGF2',
#  'TKT',
#  'GLI2',
#  'IDH1',
#  'PARN',
#  'NFU1',
#  'ALDH7A1',
#  'CXCR4',
#  'TET3',
#  'SETD2',
#  'TONSL',
#  'SMS',
#  'C1S',
#  'FANCL',
#  'CUL4B',
#  'POMC',
#  'NEDD4L',
#  'CDC42',
#  'KDM1A',
#  'DDX3X',
#  'RBBP8',
#  'MAP3K1',
#  'FANCB',
#  'CRYBB2',
#  'CBS',
#  'INS',
#  'CCNF',
#  'NFE2L2',
#  'SOX10',
#  'CYP19A1',
#  'EDA2R',
#  'GLI3',
#  'TYMP',
#  'PRKCD',
#  'HELLS',
#  'G6PD',
#  'DBH',
#  'SRSF2',
#  'TBP',
#  'PAX3',
#  'AKT2',
#  'UVSSA',
#  'SQSTM1',
#  'FANCA',
#  'TYRP1',
#  'STAG1',
#  'FECH',
#  'RAD51',
#  'CHEK2',
#  'SACS',
#  'RFC1',
#  'JAK2',
#  'CDK8',
#  'PDX1',
#  'POMP',
#  'BNIP3L',
#  'CHD3',
#  'AVP',
#  'MTAP',
#  'BRCA2',
#  'ITPA',
#  'PHKA2',
#  'RREB1',
#  'DDX58',
#  'ISG15',
#  'LYRM7',
#  'GATA3',
#  'POLA1',
#  'GALT',
#  'RAD50',
#  'FANCG',
#  'ATP6AP2',
#  'LPAR6',
#  'DCLRE1C',
#  'TDP2',
#  'KDM6A',
#  'MGME1',
#  'FTL',
#  'NMNAT1',
#  'GATA1',
#  'MTHFR',
#  'HNRNPK',
#  'FOXP3',
#  'ISCA1',
#  'SDHB',
#  'SKIV2L',
#  'PINK1',
#  'TGFBR1',
#  'ABCA1',
#  'AR',
#  'MED12',
#  'AHDC1',
#  'OGT',
#  'HDAC8',
#  'UGT1A1',
#  'ATRX',
#  'PGK1',
#  'ADA',
#  'ZMPSTE24',
#  'POLR1C',
#  'ABL1',
#  'MMP9',
#  'PTCH2',
#  'PTEN',
#  'SLC16A12',
#  'UBE2A',
#  'XIAP',
#  'FMR1',
#  'ABCC2',
#  'CHUK',
#  'HMGB3',
#  'NSDHL',
#  'DPYD',
#  'SUFU',
#  'CYP17A1',
#  'EMD',
#  'DKC1',
#  'PHGDH',
#  'GJA8',
#  'BUB3',
#  'ADAR',
#  'LMNA',
#  'MED23',
#  'SDHC',
#  'ATF6',
#  'FASLG',
#  'RNASEL',
#  'CDC73',
#  'UBE2T',
#  'IBA57',
#  'MTR',
#  'COL6A1',
#  'DMD',
#  'CDC14A',
#  'SMC3',
#  'MTOR',
#  'TOP1',
#  'FAN1',
#  'ZEB1',
#  'STAT1',
#  'RFWD3',
#  'CYP2D6',
#  'RTEL1',
#  'TFRC',
#  'DHDDS',
#  'TRRAP',
#  'PCNT',
#  'DNMT1',
#  'XRCC2',
#  'SMARCAD1',
#  'TGFBR2',
#  'VCP',
#  'REV3L',
#  'CASP8',
#  'NF1',
#  'PHF8',
#  'ACTB',
#  'SMARCAL1',
#  'XPNPEP3',
#  'CHD4',
#  'NHEJ1',
#  'GTF2E2',
#  'MLH3',
#  'RET',
#  'HTT',
#  'FN1',
#  'OCA2',
#  'ATP7A',
#  'UBQLN2',
#  'NF2',
#  'CTNNB1',
#  'LIN28B',
#  'ATR',
#  'USP7',
#  'MCPH1',
#  'EYA1',
#  'SLC25A15',
#  'HNRNPA1',
#  'FAM111B',
#  'SMAD4',
#  'SLC24A5',
#  'MAPT',
#  'MAOA',
#  'HUWE1',
#  'TAF1A',
#  'LBR',
#  'FGFR3',
#  'RPS7',
#  'UBA1',
#  'SNCA',
#  'LCK',
#  'RNASEH2B',
#  'DACT1',
#  'TDP1',
#  'UNC119',
#  'RAD51C',
#  'ARID2',
#  'GATA4',
#  'HDAC6',
#  'HBB',
#  'USP45',
#  'SMAD3',
#  'NDN',
#  'COL7A1',
#  'RARB',
#  'ATP6V0A2',
#  'NOP10',
#  'IDH2',
#  'NPLOC4',
#  'BOLA3',
#  'WT1',
#  'FANCF',
#  'TBK1',
#  'GLRX5',
#  'DNMT3B',
#  'RNF135',
#  'TRAIP',
#  'NKX2-5',
#  'LMNB2',
#  'MAF',
#  'PSEN1',
#  'TMC8',
#  'STK11',
#  'WRAP53',
#  'SOX2',
#  'PNKP',
#  'SMC1A',
#  'ATRIP',
#  'NDUFAF3',
#  'MMP1',
#  'POLE',
#  'TUFM',
#  'TALDO1',
#  'CNOT1',
#  'RNF168',
#  'CALR',
#  'ARID1A',
#  'EZH2',
#  'MET',
#  'SNRNP200',
#  'STAT2',
#  'CTC1',
#  'PRKDC',
#  'RNASEH1',
#  'HNF4A',
#  'LEP',
#  'UCP2',
#  'FANCI',
#  'BANF1',
#  'TERT',
#  'GLE1',
#  'LEMD3',
#  'RNASEH2C',
#  'EIF2AK3',
#  'ESCO2',
#  'PPM1D',
#  'TUB',
#  'MPLKIP',
#  'IGF1',
#  'UBTF',
#  'AGXT',
#  'BUB1',
#  'MAP2K1',
#  'POLR1D',
#  'FADD',
#  'KMT2D',
#  'CDT1',
#  'PPIB',
#  'RAG1',
#  'LRRK2',
#  'HPRT1',
#  'WRN',
#  'RAD21',
#  'SHH',
#  'NPM1',
#  'SLC45A2',
#  'MASP1',
#  'RHO',
#  'ALB',
#  'IHH',
#  'MITF',
#  'SPRTN',
#  'SLX4',
#  'WNT1',
#  'UBR1',
#  'FANCC',
#  'ERCC6L2',
#  'KIT',
#  'PPARG',
#  'FANCD2',
#  'BUB1B',
#  'NSMCE2',
#  'GNAQ',
#  'CASP10',
#  'HNRNPU',
#  'GJA1',
#  'NIPBL',
#  'CRYGC',
#  'GRID2',
#  'NUBPL',
#  'MYCN',
#  'NGLY1',
#  'HNMT',
#  'CEP164',
#  'MYRF',
#  'ATM',
#  'NOTCH1',
#  'NDUFB9',
#  'NONO',
#  'NHP2',
#  'SOD1',
#  'SMG9',
#  'KRT10',
#  'EIF4A3',
#  'POLG',
#  'IGF1R',
#  'FANCM',
#  'TINF2',
#  'RB1',
#  'SMARCC2',
#  'DHH',
#  'PMS2',
#  'SMARCA2',
#  'CDK6',
#  'NBN',
#  'AFF4',
#  'EGF',
#  'CENPE',
#  'MSH3',
#  'SDHA',
#  'PPARGC1A',
#  'KLF1',
#  'TP63',
#  'DNMT3A',
#  'MTRR',
#  'STAT3',
#  'WNT5A',
#  'TUBB4A',
#  'CTCF',
#  'PIK3CA',
#  'POLR1A',
#  'AKT3',
#  'BRD4',
#  'TYR',
#  'EP300',
#  'SMARCB1',
#  'SAMHD1',
#  'SRCAP',
#  'CREBBP',
#  'AXIN1',
#  'YY1',
#  'MCM4',
#  'CDH1',
#  'PALB2',
#  'LIAS',
#  'LMNB1',
#  'CCND2',
#  'BARD1',
#  'KIF11',
#  'LRPPRC',
#  'ADAM10',
#  'BRIP1',
#  'IREB2',
#  'MDM2',
#  'RINT1',
#  'APC',
#  'PDGFRA',
#  'SLCO1B1',
#  'KRAS',
#  'IGHMBP2',
#  'FUS',
#  'RARA',
#  'ABCB7',
#  'TRIM28',
#  'APOE',
#  'KRT6B',
#  'KRT5',
#  'MED17',
#  'RAF1',
#  'MYOD1',
#  'HSPB1',
#  'GFER',
#  'THOC2',
#  'ATP7B',
#  'AHR',
#  'TTR',
#  'MAD2L2',
#  'MSH6',
#  'MSH2',
#  'UMPS',
#  'NPRL2',
#  'UBE3A',
#  'MLH1',
#  'NR3C1',
#  'GMNN',
#  'FANCE',
#  'GCLC',
#  'TPI1',
#  'NUP107',
#  'CDKN1B',
#  'GLI1',
#  'CYP27B1',
#  'KITLG',
#  'CCND1',
#  'NFKB1',
#  'PHOX2B',
#  'COL1A1',
#  'SETX',
#  'CRX',
#  'TGFB1',
#  'RNASEH2A',
#  'GSR',
#  'TGM5',
#  'STUB1',
#  'TSC2',
#  'USB1',
#  'MMP2',
#  'FERMT1',
#  'CSNK2A1',
#  'EEF1A2',
#  'CYP24A1',
#  'MTHFD1',
#  'ACO2',
#  'VCL',
#  'CDC6',
#  'OSGEP',
#  'KRT14',
#  'TRIP13',
#  'TNFRSF1A',
#  'GNA11',
#  'CFTR',
#  'EFTUD2',
#  'OBSL1',
#  'YAP1',
#  'PRKN',
#  'SUZ12',
#  'LARP7',
#  'CYLD',
#  'EED',
#  'PPP2R1A',
#  'PRPF8',
#  'TUBB',
#  'PPP2CA',
#  'MRE11',
#  'PIK3R1',
#  'HFM1',
#  'GTF2H4',
#  'MYC',
#  'APAF1',
#  'ENDOV',
#  'MMS19',
#  'BBC3',
#  'CDKN1A',
#  'BCL2',
#  'POLM',
#  'MAPK8',
#  'HSPA1A',
#  'GADD45A',
#  'CETN2',
#  'SFN',
#  'PMAIP1',
#  'WDR48',
#  'HSPA9',
#  'BTG2',
#  'IFNA1',
#  'TNFRSF10B',
#  'EGFR',
#  'GTF2H1',
#  'POLQ',
#  'CCNH',
#  'TERF2',
#  'RPA1',
#  'NR1H2',
#  'AAGAB',
#  'WDR77',
#  'PSMC6',
#  'LRRC59',
#  'CSH1',
#  'CPD',
#  'ERVK-11',
#  'ERVK-19',
#  'ERVK-9',
#  'FASTK',
#  'REXO2',
#  'FASN',
#  'TRIAP1',
#  'AEN',
#  'BAX',
#  'MIR744',
#  'MIR373',
#  'MIR346',
#  'MIR21',
#  'U2',
#  'TARID',
#  'SCAANT1',
#  'RNR3',
#  'MEG8',
#  'MUC13',
#  'PRIM2',
#  'CD24',
#  'NTMT1',
#  'CRABP2',
#  'ZNF501',
#  'CGA',
#  'PER3',
#  'SLC38A3',
#  'E2F8',
#  'MCM3',
#  'FGF1',
#  'POLD2',
#  'POLR2A',
#  'ALOX5AP',
#  'UHRF1',
#  'RHNO1',
#  'HNRNPCL1',
#  'LTN1',
#  'VEGFA',
#  'POLR2E',
#  'IGHV4-38-2',
#  'ABCB1',
#  'CRY2',
#  'ANXA8',
#  'NAP1L1',
#  'APBB1',
#  'SIRT5',
#  'POLDIP2',
#  'COMMD3-BMI1',
#  'RUVBL2',
#  'RPS5',
#  'IRF3',
#  'SUPT5H',
#  'UPF1',
#  'RAD23A',
#  'AC004223.3',
#  'LSM12',
#  'POLRMT',
#  'PIAS2',
#  'RBFOX3',
#  'KLF14',
#  'POLI',
#  'ZP2',
#  'CTRL',
#  'COX4I1',
#  'PECAM1',
#  'EME2',
#  'DET1',
#  'MRC1',
#  'ASIP',
#  'RNF111',
#  'B2M',
#  'BCL2L2-PABPN1',
#  'XRCC3',
#  'NDRG2',
#  'AC092143.1',
#  'HNRNPC',
#  'TIMELESS',
#  'DDIT3',
#  'SOD2',
#  'GTF2H3',
#  'CUL2',
#  'SCO2',
#  'OTUB1',
#  'CITED2',
#  'POLR1B',
#  'NAT1',
#  'CAND1',
#  'ITGAM',
#  'UBC',
#  'NNMT',
#  'CYP2E1',
#  'PSMD9',
#  'NFE2',
#  'AL139300.1',
#  'MDH1',
#  'HIF1A',
#  'DICER1',
#  'MUC5B',
#  'NXF1',
#  'EIF3M',
#  'POLN',
#  'FAU',
#  'CASP1',
#  'HSPA8',
#  'HSF1',
#  'HDAC2',
#  'RNF130',
#  'LYRM2',
#  'ENY2',
#  'ERI1',
#  'SLC25A37',
#  'CCNC',
#  'TCEA1',
#  'CETN3',
#  'UBE2V2',
#  'RPL30',
#  'NACA2',
#  'CEBPA',
#  'RNF4',
#  'RAD17',
#  'DROSHA',
#  'EIF4E',
#  'NEDD4',
#  'PLRG1',
#  'SMUG1',
#  'PAQR3',
#  'TIPARP',
#  'TFAM',
#  'BAG1',
#  'PHC3',
#  'ADH7',
#  'NR6A1',
#  'POLE4',
#  'ZMYND8',
#  'LYRM4',
#  'CDK5',
#  'SSBP1',
#  'RAD51B',
#  'TAF1L',
#  'CIAO1',
#  'MCM10',
#  'FHIT',
#  'BAP1',
#  'DHX36',
#  'RECQL',
#  'EIF4G1',
#  'DCAF11',
#  'POLR2H',
#  'KLC1',
#  'C7orf25',
#  'IL10',
#  'TOP2A',
#  'PTPRC',
#  'STMN1',
#  'MAP2K4',
#  'SUMO3',
#  'OTUD4',
#  'RFC5',
#  'GPX1',
#  'PMS1',
#  'TCEA3',
#  'KAT8',
#  'SUMO2',
#  'SMC6',
#  'PPP1R13L',
#  'BRAP',
#  'LTA',
#  'PMEL',
#  'SENP6',
#  'SMG1',
#  'WEE1',
#  'RANGAP1',
#  'ERN1',
#  'EWSR1',
#  'HMGA1',
#  'CDK12',
#  'TNF',
#  'CD44',
#  'L3MBTL1',
#  'ALKBH2',
#  'E2F5',
#  'NFIC',
#  'TOP2B',
#  'SENP1',
#  'SESN1',
#  'CDC7',
#  'HTATIP2',
#  'DCT',
#  'CHFR',
#  'PPP6C',
#  'CYB561D2',
#  'SLC16A5',
#  'CHEK1',
#  'CREB1',
#  'UBE4A',
#  'IMMT',
#  'CD8A',
#  'MCC',
#  'DAPK1',
#  'FOXO3',
#  'MARK2',
#  'IL6',
#  'HIPK2',
#  'PPARA',
#  'ELAVL1',
#  'APOBEC3G',
#  'XPO1',
#  'AKAP12',
#  'ARNTL',
#  'PARG',
#  'APOBEC3A',
#  'RELA',
#  'PAXIP1',
#  'NCOR2',
#  'SUN1',
#  'TUBA3C',
#  'RUNX3',
#  'PAICS',
#  'NEURL4',
#  'ABCC1',
#  'PARP3',
#  'UBE2D2',
#  'DOT1L',
#  'GSTP1',
#  'TMPRSS2',
#  'CABIN1',
#  'LONRF1',
#  'CBSL',
#  'KHSRP',
#  'MAP2K7',
#  'RNASE1',
#  'MED13',
#  'TEN1',
#  'MYCL',
#  'DEK',
#  'NUDT1',
#  'CSNK1E',
#  'DKK3',
#  'DDX39B',
#  'ELP4',
#  'RAE1',
#  'CXCL12',
#  'CXCL1',
#  'QPRT',
#  'CDK1',
#  'FZR1',
#  'SPP1',
#  'PBRM1',
#  'ACYP2',
#  'FKBP2',
#  'CIAPIN1',
#  'RPL24',
#  'PTTG1',
#  'SLC29A1',
#  'CDKN2D',
#  'CBX1',
#  'EME1',
#  'BCL2L11',
#  'NRF1',
#  'NME2',
#  'NME1-NME2',
#  'CUL5',
#  'TDG',
#  'ETS1',
#  'GRB2',
#  'TAOK3',
#  'RFC4',
#  'SUMO1',
#  'MAP3K4',
#  'XRCC5',
#  'TSN',
#  'EP400',
#  'RNF20',
#  'ALK',
#  'GPX3',
#  'SETMAR',
#  'NEK11',
#  'RNMT',
#  'SIRT3',
#  'DEFA1',
#  'DEFA1B',
#  'SOD3',
#  'TP53BP1',
#  'PARP4',
#  'SRXN1',
#  'TNK2',
#  'GART',
#  'CD274',
#  'E2F6',
#  'MLANA',
#  'TGM3',
#  'SLC25A6',
#  'CCP110',
#  'DDX1',
#  'POLR2B',
#  'GTF3A',
#  'IGFBP3',
#  'DUT',
#  'SERF1B',
#  'HMGN1',
#  'PSIP1',
#  'TLR7',
#  'CNTLN',
#  'NAP1L4',
#  'ZNF763',
#  'IFNB1',
#  'IFNA2',
#  'NABP2',
#  'RBBP7',
#  'RFC3',
#  'GLRX',
#  'RIOK1',
#  'SMAD9',
#  'CYP1A1',
#  'KIN',
#  'FOXO1',
#  'ASPH',
#  'NEDD9',
#  'XDH',
#  'E2F4',
#  'DNAJC2',
#  'LYRM9',
#  'MAGEB10',
#  'MCM8',
#  'LGALS7',
#  'LIG3',
#  'APRT',
#  'TP73',
#  'TRDMT1',
#  'SF1',
#  'UIMC1',
#  'XRN2',
#  'KLF9',
#  'UBD',
#  'BMI1',
#  'TLE1',
#  'MDC1',
#  'UBQLN1',
#  'ING1',
#  'CARD16',
#  'MSH5',
#  'HSPA1B',
#  'EHMT2',
#  'CUL4A',
#  'NELFE',
#  'STK19',
#  'FOXE1',
#  'CDA',
#  'GALNT12',
#  'APEX2',
#  'AOX1',
#  'KLF4',
#  'DAXX',
#  'TXN',
#  'KIF4A',
#  'MAN1C1',
#  'FOXO4',
#  'CNKSR1',
#  'INIP',
#  'SLC31A1',
#  'NFS1',
#  'SPDEF',
#  'PHF20',
#  'TLR4',
#  'UBE2D1',
#  'RPA2',
#  'RCC1',
#  'PEF1',
#  'RBL1',
#  'TET1',
#  'SRC',
#  'SCAI',
#  'HDAC1',
#  'RBBP4',
#  'RNF8',
#  'GLO1',
#  'CDK9',
#  'CCND3',
#  'CSTF2',
#  'NOX1',
#  'PLAU',
#  'ENDOG',
#  'YBX1',
#  'CDC20',
#  'PLK3',
#  'MUTYH',
#  'RAD54L',
#  'SLC25A5',
#  'NDOR1',
#  'TCTE1',
#  'CDC5L',
#  'PLCE1',
#  'CYP2C19',
#  'CYP2C8',
#  'SPO11',
#  'JUN',
#  'DNTT',
#  'SMARCA1',
#  'GSTA4',
#  'PSMA7',
#  'USP33',
#  'FUBP1',
#  'RBMX',
#  'GTF2B',
#  'SLC25A28',
#  'CSAG1',
#  'BTRC',
#  'POLL',
#  'SLC30A7',
#  'AS3MT',
#  'TTK',
#  'OVGP1',
#  'GSTO1',
#  'ME1',
#  'DDX20',
#  'DCLRE1B',
#  'SYCP1',
#  'BRCC3',
#  'CASP7',
#  'CHD1L',
#  'ASCC3',
#  'BOLA1',
#  ...]

# %%
symptoms_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-4a3884fea288> in <module>
# ----> 1 symptoms_dict
#
# NameError: name 'symptoms_dict' is not defined

# %%
len(relevant_top_genes_list)

# for x in relevant_genes_to_symptoms_results.keys():
#     if
# Out:
# 1630

# %%
list(relevant_genes_to_symptoms_results.keys())
# Out:
# ['ERCC3',
#  'ERCC2',
#  'XPA',
#  'POLH',
#  'ERCC5',
#  'ERCC4',
#  'XPC',
#  'DDB2',
#  'EDNRA',
#  'ERCC1',
#  'DDX11',
#  'PCNA',
#  'FXN',
#  'NRAS',
#  'ERCC6',
#  'FAS',
#  'BLM',
#  'PTCH1',
#  'FOS',
#  'TP53',
#  'ERCC8',
#  'RRM2B',
#  'PERP',
#  'TERC',
#  'MUC1',
#  'LIG4',
#  'IKBKG',
#  'CHD1',
#  'HNRNPDL',
#  'ACD',
#  'C9orf72',
#  'RECQL4',
#  'PCGF2',
#  'EPHX1',
#  'CIB1',
#  'KIZ',
#  'RAG2',
#  'CYP1B1',
#  'ATXN3',
#  'SRD5A2',
#  'FRRS1L',
#  'GTF2H5',
#  'BIVM-ERCC5',
#  'TTN',
#  'RAD51D',
#  'GALK1',
#  'TMC6',
#  'RPL26',
#  'RBM8A',
#  'ACTG1',
#  'WWOX',
#  'ISCA2',
#  'AKT1',
#  'MC1R',
#  'BRF1',
#  'VDR',
#  'CYFIP2',
#  'TET2',
#  'TOP3A',
#  'PHC1',
#  'ATXN7',
#  'CUL7',
#  'CD19',
#  'FAM111A',
#  'PUF60',
#  'NTRK1',
#  'IKBKB',
#  'PROM1',
#  'RNASET2',
#  'XRCC4',
#  'POR',
#  'BRCA1',
#  'CDKN2A',
#  'NDUFA6',
#  'FTO',
#  'FDXR',
#  'SLC2A1',
#  'SLC35A2',
#  'RPS24',
#  'BDNF',
#  'CDKN1C',
#  'FBP1',
#  'HRAS',
#  'TAF1',
#  'SLC13A5',
#  'POLD1',
#  'CDC45',
#  'CLMP',
#  'ESR1',
#  'APTX',
#  'PNPT1',
#  'RHOA',
#  'TAF6',
#  'DIABLO',
#  'DHFR',
#  'SMARCA4',
#  'MECP2',
#  'FGFR1',
#  'CHD7',
#  'IGF2',
#  'TKT',
#  'GLI2',
#  'IDH1',
#  'PARN',
#  'NFU1',
#  'ALDH7A1',
#  'CXCR4',
#  'TET3',
#  'SETD2',
#  'TONSL',
#  'SMS',
#  'C1S',
#  'FANCL',
#  'CUL4B',
#  'POMC',
#  'NEDD4L',
#  'CDC42',
#  'KDM1A',
#  'DDX3X',
#  'RBBP8',
#  'MAP3K1',
#  'FANCB',
#  'CRYBB2',
#  'CBS',
#  'INS',
#  'CCNF',
#  'NFE2L2',
#  'SOX10',
#  'CYP19A1',
#  'EDA2R',
#  'GLI3',
#  'TYMP',
#  'PRKCD',
#  'HELLS',
#  'G6PD',
#  'DBH',
#  'SRSF2',
#  'TBP',
#  'PAX3',
#  'AKT2',
#  'UVSSA',
#  'SQSTM1',
#  'FANCA',
#  'TYRP1',
#  'STAG1',
#  'FECH',
#  'RAD51',
#  'CHEK2',
#  'SACS',
#  'RFC1',
#  'JAK2',
#  'CDK8',
#  'PDX1',
#  'POMP',
#  'BNIP3L',
#  'CHD3',
#  'AVP',
#  'MTAP',
#  'BRCA2',
#  'ITPA',
#  'PHKA2',
#  'RREB1',
#  'DDX58',
#  'ISG15',
#  'LYRM7',
#  'GATA3',
#  'POLA1',
#  'GALT',
#  'RAD50',
#  'FANCG',
#  'ATP6AP2',
#  'LPAR6',
#  'DCLRE1C',
#  'TDP2',
#  'KDM6A',
#  'MGME1',
#  'FTL',
#  'NMNAT1',
#  'GATA1',
#  'MTHFR',
#  'HNRNPK',
#  'FOXP3',
#  'ISCA1',
#  'SDHB',
#  'SKIV2L',
#  'PINK1',
#  'TGFBR1',
#  'ABCA1',
#  'AR',
#  'MED12',
#  'AHDC1',
#  'OGT',
#  'HDAC8',
#  'UGT1A1',
#  'ATRX',
#  'PGK1',
#  'ADA',
#  'ZMPSTE24',
#  'POLR1C',
#  'ABL1',
#  'MMP9',
#  'PTCH2',
#  'PTEN',
#  'SLC16A12',
#  'UBE2A',
#  'XIAP',
#  'FMR1',
#  'ABCC2',
#  'CHUK',
#  'HMGB3',
#  'NSDHL',
#  'DPYD',
#  'SUFU',
#  'CYP17A1',
#  'EMD',
#  'DKC1',
#  'PHGDH',
#  'GJA8',
#  'BUB3',
#  'ADAR',
#  'LMNA',
#  'MED23',
#  'SDHC',
#  'ATF6',
#  'FASLG',
#  'RNASEL',
#  'CDC73',
#  'UBE2T',
#  'IBA57',
#  'MTR',
#  'COL6A1',
#  'DMD',
#  'CDC14A',
#  'SMC3',
#  'MTOR',
#  'TOP1',
#  'FAN1',
#  'ZEB1',
#  'STAT1',
#  'RFWD3',
#  'CYP2D6',
#  'RTEL1',
#  'TFRC',
#  'DHDDS',
#  'TRRAP',
#  'PCNT',
#  'DNMT1',
#  'XRCC2',
#  'SMARCAD1',
#  'TGFBR2',
#  'VCP',
#  'REV3L',
#  'CASP8',
#  'NF1',
#  'PHF8',
#  'ACTB',
#  'SMARCAL1',
#  'XPNPEP3',
#  'CHD4',
#  'NHEJ1',
#  'GTF2E2',
#  'MLH3',
#  'RET',
#  'HTT',
#  'FN1',
#  'OCA2',
#  'ATP7A',
#  'UBQLN2',
#  'NF2',
#  'CTNNB1',
#  'LIN28B',
#  'ATR',
#  'USP7',
#  'MCPH1',
#  'EYA1',
#  'SLC25A15',
#  'HNRNPA1',
#  'FAM111B',
#  'SMAD4',
#  'SLC24A5',
#  'MAPT',
#  'MAOA',
#  'HUWE1',
#  'TAF1A',
#  'LBR',
#  'FGFR3',
#  'RPS7',
#  'UBA1',
#  'SNCA',
#  'LCK',
#  'RNASEH2B',
#  'DACT1',
#  'TDP1',
#  'UNC119',
#  'RAD51C',
#  'ARID2',
#  'GATA4',
#  'HDAC6',
#  'HBB',
#  'USP45',
#  'SMAD3',
#  'NDN',
#  'COL7A1',
#  'RARB',
#  'ATP6V0A2',
#  'NOP10',
#  'IDH2',
#  'NPLOC4',
#  'BOLA3',
#  'WT1',
#  'FANCF',
#  'TBK1',
#  'GLRX5',
#  'DNMT3B',
#  'RNF135',
#  'TRAIP',
#  'NKX2-5',
#  'LMNB2',
#  'MAF',
#  'PSEN1',
#  'TMC8',
#  'STK11',
#  'WRAP53',
#  'SOX2',
#  'PNKP',
#  'SMC1A',
#  'ATRIP',
#  'NDUFAF3',
#  'MMP1',
#  'POLE',
#  'TUFM',
#  'TALDO1',
#  'CNOT1',
#  'RNF168',
#  'CALR',
#  'ARID1A',
#  'EZH2',
#  'MET',
#  'SNRNP200',
#  'STAT2',
#  'CTC1',
#  'PRKDC',
#  'RNASEH1',
#  'HNF4A',
#  'LEP',
#  'UCP2',
#  'FANCI',
#  'BANF1',
#  'TERT',
#  'GLE1',
#  'LEMD3',
#  'RNASEH2C',
#  'EIF2AK3',
#  'ESCO2',
#  'PPM1D',
#  'TUB',
#  'MPLKIP',
#  'IGF1',
#  'UBTF',
#  'AGXT',
#  'BUB1',
#  'MAP2K1',
#  'POLR1D',
#  'FADD',
#  'KMT2D',
#  'CDT1',
#  'PPIB',
#  'RAG1',
#  'LRRK2',
#  'HPRT1',
#  'WRN',
#  'RAD21',
#  'SHH',
#  'NPM1',
#  'SLC45A2',
#  'MASP1',
#  'RHO',
#  'ALB',
#  'IHH',
#  'MITF',
#  'SPRTN',
#  'SLX4',
#  'WNT1',
#  'UBR1',
#  'FANCC',
#  'ERCC6L2',
#  'KIT',
#  'PPARG',
#  'FANCD2',
#  'BUB1B',
#  'NSMCE2',
#  'GNAQ',
#  'CASP10',
#  'HNRNPU',
#  'GJA1',
#  'NIPBL',
#  'CRYGC',
#  'GRID2',
#  'NUBPL',
#  'MYCN',
#  'NGLY1',
#  'HNMT',
#  'CEP164',
#  'MYRF',
#  'ATM',
#  'NOTCH1',
#  'NDUFB9',
#  'NONO',
#  'NHP2',
#  'SOD1',
#  'SMG9',
#  'KRT10',
#  'EIF4A3',
#  'POLG',
#  'IGF1R',
#  'FANCM',
#  'TINF2',
#  'RB1',
#  'SMARCC2',
#  'DHH',
#  'PMS2',
#  'SMARCA2',
#  'CDK6',
#  'NBN',
#  'AFF4',
#  'EGF',
#  'CENPE',
#  'MSH3',
#  'SDHA',
#  'PPARGC1A',
#  'KLF1',
#  'TP63',
#  'DNMT3A',
#  'MTRR',
#  'STAT3',
#  'WNT5A',
#  'TUBB4A',
#  'CTCF',
#  'PIK3CA',
#  'POLR1A',
#  'AKT3',
#  'BRD4',
#  'TYR',
#  'EP300',
#  'SMARCB1',
#  'SAMHD1',
#  'SRCAP',
#  'CREBBP',
#  'AXIN1',
#  'YY1',
#  'MCM4',
#  'CDH1',
#  'PALB2',
#  'LIAS',
#  'LMNB1',
#  'CCND2',
#  'BARD1',
#  'KIF11',
#  'LRPPRC',
#  'ADAM10',
#  'BRIP1',
#  'IREB2',
#  'MDM2',
#  'RINT1',
#  'APC',
#  'PDGFRA',
#  'SLCO1B1',
#  'KRAS',
#  'IGHMBP2',
#  'FUS',
#  'RARA',
#  'ABCB7',
#  'TRIM28',
#  'APOE',
#  'KRT6B',
#  'KRT5',
#  'MED17',
#  'RAF1',
#  'MYOD1',
#  'HSPB1',
#  'GFER',
#  'THOC2',
#  'ATP7B',
#  'AHR',
#  'TTR',
#  'MAD2L2',
#  'MSH6',
#  'MSH2',
#  'UMPS',
#  'NPRL2',
#  'UBE3A',
#  'MLH1',
#  'NR3C1',
#  'GMNN',
#  'FANCE',
#  'GCLC',
#  'TPI1',
#  'NUP107',
#  'CDKN1B',
#  'GLI1',
#  'CYP27B1',
#  'KITLG',
#  'CCND1',
#  'NFKB1',
#  'PHOX2B',
#  'COL1A1',
#  'SETX',
#  'CRX',
#  'TGFB1',
#  'RNASEH2A',
#  'GSR',
#  'TGM5',
#  'STUB1',
#  'TSC2',
#  'USB1',
#  'MMP2',
#  'FERMT1',
#  'CSNK2A1',
#  'EEF1A2',
#  'CYP24A1',
#  'MTHFD1',
#  'ACO2',
#  'VCL',
#  'CDC6',
#  'OSGEP',
#  'KRT14',
#  'TRIP13',
#  'TNFRSF1A',
#  'GNA11',
#  'CFTR',
#  'EFTUD2',
#  'OBSL1',
#  'YAP1',
#  'PRKN',
#  'SUZ12',
#  'LARP7',
#  'CYLD',
#  'EED',
#  'PPP2R1A',
#  'PRPF8',
#  'TUBB',
#  'PPP2CA',
#  'MRE11',
#  'PIK3R1',
#  'HFM1',
#  'GTF2H4',
#  'MYC',
#  'APAF1',
#  'ENDOV',
#  'MMS19',
#  'BBC3',
#  'CDKN1A',
#  'BCL2',
#  'POLM',
#  'MAPK8',
#  'HSPA1A',
#  'GADD45A',
#  'CETN2',
#  'SFN',
#  'PMAIP1',
#  'WDR48',
#  'HSPA9',
#  'BTG2',
#  'IFNA1',
#  'TNFRSF10B',
#  'EGFR',
#  'GTF2H1',
#  'POLQ',
#  'CCNH',
#  'TERF2',
#  'RPA1',
#  'NR1H2',
#  'AAGAB',
#  'WDR77',
#  'PSMC6',
#  'LRRC59',
#  'CSH1',
#  'CPD',
#  'ERVK-11',
#  'ERVK-19',
#  'ERVK-9',
#  'FASTK',
#  'REXO2',
#  'FASN',
#  'TRIAP1',
#  'AEN',
#  'BAX',
#  'MIR744',
#  'MIR373',
#  'MIR346',
#  'MIR21',
#  'U2',
#  'TARID',
#  'SCAANT1',
#  'RNR3',
#  'MEG8',
#  'MUC13',
#  'PRIM2',
#  'CD24',
#  'NTMT1',
#  'CRABP2',
#  'ZNF501',
#  'CGA',
#  'PER3',
#  'SLC38A3',
#  'E2F8',
#  'MCM3',
#  'FGF1',
#  'POLD2',
#  'POLR2A',
#  'ALOX5AP',
#  'UHRF1',
#  'RHNO1',
#  'HNRNPCL1',
#  'LTN1',
#  'VEGFA',
#  'POLR2E',
#  'IGHV4-38-2',
#  'ABCB1',
#  'CRY2',
#  'ANXA8',
#  'NAP1L1',
#  'APBB1',
#  'SIRT5',
#  'POLDIP2',
#  'COMMD3-BMI1',
#  'RUVBL2',
#  'RPS5',
#  'IRF3',
#  'SUPT5H',
#  'UPF1',
#  'RAD23A',
#  'AC004223.3',
#  'LSM12',
#  'POLRMT',
#  'PIAS2',
#  'RBFOX3',
#  'KLF14',
#  'POLI',
#  'ZP2',
#  'CTRL',
#  'COX4I1',
#  'PECAM1',
#  'EME2',
#  'DET1',
#  'MRC1',
#  'ASIP',
#  'RNF111',
#  'B2M',
#  'BCL2L2-PABPN1',
#  'XRCC3',
#  'NDRG2',
#  'AC092143.1',
#  'HNRNPC',
#  'TIMELESS',
#  'DDIT3',
#  'SOD2',
#  'GTF2H3',
#  'CUL2',
#  'SCO2',
#  'OTUB1',
#  'CITED2',
#  'POLR1B',
#  'NAT1',
#  'CAND1',
#  'ITGAM',
#  'UBC',
#  'NNMT',
#  'CYP2E1',
#  'PSMD9',
#  'NFE2',
#  'AL139300.1',
#  'MDH1',
#  'HIF1A',
#  'DICER1',
#  'MUC5B',
#  'NXF1',
#  'EIF3M',
#  'POLN',
#  'FAU',
#  'CASP1',
#  'HSPA8',
#  'HSF1',
#  'HDAC2',
#  'RNF130',
#  'LYRM2',
#  'ENY2',
#  'ERI1',
#  'SLC25A37',
#  'CCNC',
#  'TCEA1',
#  'CETN3',
#  'UBE2V2',
#  'RPL30',
#  'NACA2',
#  'CEBPA',
#  'RNF4',
#  'RAD17',
#  'DROSHA',
#  'EIF4E',
#  'NEDD4',
#  'PLRG1',
#  'SMUG1',
#  'PAQR3',
#  'TIPARP',
#  'TFAM',
#  'BAG1',
#  'PHC3',
#  'ADH7',
#  'NR6A1',
#  'POLE4',
#  'ZMYND8',
#  'LYRM4',
#  'CDK5',
#  'SSBP1',
#  'RAD51B',
#  'TAF1L',
#  'CIAO1',
#  'MCM10',
#  'FHIT',
#  'BAP1',
#  'DHX36',
#  'RECQL',
#  'EIF4G1',
#  'DCAF11',
#  'POLR2H',
#  'KLC1',
#  'C7orf25',
#  'IL10',
#  'TOP2A',
#  'PTPRC',
#  'STMN1',
#  'MAP2K4',
#  'SUMO3',
#  'OTUD4',
#  'RFC5',
#  'GPX1',
#  'PMS1',
#  'TCEA3',
#  'KAT8',
#  'SUMO2',
#  'SMC6',
#  'PPP1R13L',
#  'BRAP',
#  'LTA',
#  'PMEL',
#  'SENP6',
#  'SMG1',
#  'WEE1',
#  'RANGAP1',
#  'ERN1',
#  'EWSR1',
#  'HMGA1',
#  'CDK12',
#  'TNF',
#  'CD44',
#  'L3MBTL1',
#  'ALKBH2',
#  'E2F5',
#  'NFIC',
#  'TOP2B',
#  'SENP1',
#  'SESN1',
#  'CDC7',
#  'HTATIP2',
#  'DCT',
#  'CHFR',
#  'PPP6C',
#  'CYB561D2',
#  'SLC16A5',
#  'CHEK1',
#  'CREB1',
#  'UBE4A',
#  'IMMT',
#  'CD8A',
#  'MCC',
#  'DAPK1',
#  'FOXO3',
#  'MARK2',
#  'IL6',
#  'HIPK2',
#  'PPARA',
#  'ELAVL1',
#  'APOBEC3G',
#  'XPO1',
#  'AKAP12',
#  'ARNTL',
#  'PARG',
#  'APOBEC3A',
#  'RELA',
#  'PAXIP1',
#  'NCOR2',
#  'SUN1',
#  'TUBA3C',
#  'RUNX3',
#  'PAICS',
#  'NEURL4',
#  'ABCC1',
#  'PARP3',
#  'UBE2D2',
#  'DOT1L',
#  'GSTP1',
#  'TMPRSS2',
#  'CABIN1',
#  'LONRF1',
#  'CBSL',
#  'KHSRP',
#  'MAP2K7',
#  'RNASE1',
#  'MED13',
#  'TEN1',
#  'MYCL',
#  'DEK',
#  'NUDT1',
#  'CSNK1E',
#  'DKK3',
#  'DDX39B',
#  'ELP4',
#  'RAE1',
#  'CXCL12',
#  'CXCL1',
#  'QPRT',
#  'CDK1',
#  'FZR1',
#  'SPP1',
#  'PBRM1',
#  'ACYP2',
#  'FKBP2',
#  'CIAPIN1',
#  'RPL24',
#  'PTTG1',
#  'SLC29A1',
#  'CDKN2D',
#  'CBX1',
#  'EME1',
#  'BCL2L11',
#  'NRF1',
#  'NME2',
#  'NME1-NME2',
#  'CUL5',
#  'TDG',
#  'ETS1',
#  'GRB2',
#  'TAOK3',
#  'RFC4',
#  'SUMO1',
#  'MAP3K4',
#  'XRCC5',
#  'TSN',
#  'EP400',
#  'RNF20',
#  'ALK',
#  'GPX3',
#  'SETMAR',
#  'NEK11',
#  'RNMT',
#  'SIRT3',
#  'DEFA1',
#  'DEFA1B',
#  'SOD3',
#  'TP53BP1',
#  'PARP4',
#  'SRXN1',
#  'TNK2',
#  'GART',
#  'CD274',
#  'E2F6',
#  'MLANA',
#  'TGM3',
#  'SLC25A6',
#  'CCP110',
#  'DDX1',
#  'POLR2B',
#  'GTF3A',
#  'IGFBP3',
#  'DUT',
#  'SERF1B',
#  'HMGN1',
#  'PSIP1',
#  'TLR7',
#  'CNTLN',
#  'NAP1L4',
#  'ZNF763',
#  'IFNB1',
#  'IFNA2',
#  'NABP2',
#  'RBBP7',
#  'RFC3',
#  'GLRX',
#  'RIOK1',
#  'SMAD9',
#  'CYP1A1',
#  'KIN',
#  'FOXO1',
#  'ASPH',
#  'NEDD9',
#  'XDH',
#  'E2F4',
#  'DNAJC2',
#  'LYRM9',
#  'MAGEB10',
#  'MCM8',
#  'LGALS7',
#  'LIG3',
#  'APRT',
#  'TP73',
#  'TRDMT1',
#  'SF1',
#  'UIMC1',
#  'XRN2',
#  'KLF9',
#  'UBD',
#  'BMI1',
#  'TLE1',
#  'MDC1',
#  'UBQLN1',
#  'ING1',
#  'CARD16',
#  'MSH5',
#  'HSPA1B',
#  'EHMT2',
#  'CUL4A',
#  'NELFE',
#  'STK19',
#  'FOXE1',
#  'CDA',
#  'GALNT12',
#  'APEX2',
#  'AOX1',
#  'KLF4',
#  'DAXX',
#  'TXN',
#  'KIF4A',
#  'MAN1C1',
#  'FOXO4',
#  'CNKSR1',
#  'INIP',
#  'SLC31A1',
#  'NFS1',
#  'SPDEF',
#  'PHF20',
#  'TLR4',
#  'UBE2D1',
#  'RPA2',
#  'RCC1',
#  'PEF1',
#  'RBL1',
#  'TET1',
#  'SRC',
#  'SCAI',
#  'HDAC1',
#  'RBBP4',
#  'RNF8',
#  'GLO1',
#  'CDK9',
#  'CCND3',
#  'CSTF2',
#  'NOX1',
#  'PLAU',
#  'ENDOG',
#  'YBX1',
#  'CDC20',
#  'PLK3',
#  'MUTYH',
#  'RAD54L',
#  'SLC25A5',
#  'NDOR1',
#  'TCTE1',
#  'CDC5L',
#  'PLCE1',
#  'CYP2C19',
#  'CYP2C8',
#  'SPO11',
#  'JUN',
#  'DNTT',
#  'SMARCA1',
#  'GSTA4',
#  'PSMA7',
#  'USP33',
#  'FUBP1',
#  'RBMX',
#  'GTF2B',
#  'SLC25A28',
#  'CSAG1',
#  'BTRC',
#  'POLL',
#  'SLC30A7',
#  'AS3MT',
#  'TTK',
#  'OVGP1',
#  'GSTO1',
#  'ME1',
#  'DDX20',
#  'DCLRE1B',
#  'SYCP1',
#  'BRCC3',
#  'CASP7',
#  'CHD1L',
#  'ASCC3',
#  'BOLA1',
#  ...]
