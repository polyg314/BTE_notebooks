# %% [markdown]
# # BTE -- Question #2 -- Use Case Workflow

# %% [markdown]
# ## 0. Uploads, Functions, and Parameters

# %%
# Import pandas and biothings explorers modules
import pandas as pd
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %%
# set list constant that represents every node type available in BTE
ALL_NODE_TYPES = ['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature']

# %%
# predict_many funciton will be used to run many BTE queries and return results as a single table
def predict_many(input_object_list, output_type_list, intermediate_node_list = ''):
    df_list = []
    for input_object in input_object_list: 
        for output_type in output_type_list: 
            if(len(intermediate_node_list) > 0):
                for inter in intermediate_node_list:
                    try: 
                        print("Running: " + input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type )
                        fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        rows = df.shape[0]
                        if(rows > 0):
                            df_list.append(df)
                    except:
                        print(input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type + ' FAILED')
            else:
                try:
                    print("Running: " + input_object['name'] + ' --> output type ' + output_type )
                    fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=None)
                    fc.connect(verbose=False)
                    df = fc.display_table_view()
                    rows = df.shape[0]
                    if(rows > 0):
                        df_list.append(df)
                except:
                    print(input_object['name'] + ' --> output type ' + output_type + ' FAILED')

    if(len(df_list) > 0):
        return pd.concat(df_list)
    else:
        return None

# %%
# max_one_step_genes represents the number of genes returned from direct disease -> gene query 
# that will be included in results. Genes with most occurrences will be included over those with less
max_one_step_genes = 50

# max_two_step_genes represents the number of genes returned from disease -> intermediate node -> gene query 
max_two_step_genes = 200

# set disease name
disease_name = 'severe acute respiratory syndrome'

# set disease output files
disease_csv_file = 'COVID-19_BTE_custom_symptoms_2020_09_10.csv'
disease_symptoms_csv = 'COVID-19_custom_symptoms_Symptoms_2020_09_10.csv'
disease_csv_weighted_file = 'COVID-19_BTE_custom_symptoms_weighted_2020_09_10.csv'

# %% [markdown]
# ## 1. Get Disease Symptoms and Symptom Information

# %% [markdown]
# ### 1.1 Get Disease

# %%
# run hint query to get disease input
disease = ht.query('severe acute respiratory syndrome')['Disease'][0]
print(disease)
# Out:
# {'MONDO': 'MONDO:0005091', 'DOID': 'DOID:2945', 'UMLS': 'C1175175', 'name': 'severe acute respiratory syndrome', 'MESH': 'D045169', 'ORPHANET': '140896', 'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'MONDO:0005091'}, 'display': 'MONDO(MONDO:0005091) DOID(DOID:2945) ORPHANET(140896) UMLS(C1175175) MESH(D045169) name(severe acute respiratory syndrome)', 'type': 'Disease'}

# %% [markdown]
# ### 1.2 Get 'PhenotypicFeatures' Related to Disease

# %%
## custom symptom dictionary 
import requests 

symptoms = ([ 'fever','cough', 'hemoptysis', 
'shortness of breath', 'myalgia', 'fatigue', 'sore throat', 
'nausea', 'vomiting', 'diarrhea', 'conjunctivitis', 'anorexia',
'headache', 'leukopenia', 'eosinopenia', 'neutrophilia', 'elevated liver enzymes', 'C-reactive protein', 'ferritin',
'hyaline membrane', 'alveolar lesions', 'prominent hyaline membranes', 'alveolar damage',
 'acute myocardial injury', ' myocarditis', 'arrhythmias','cardiac dysfunction', 'encephalopathy'])


symptom_dict = {}

for symptom in symptoms: 
    try: 
        symptom = ht.query(symptom)['PhenotypicFeature'][0]
        print(symptom['name'])
        symptom_dict[symptom['HP']] = {
            'names': [symptom['name'].upper()],
            'frequency': 'Unknown'
        }
        r = requests.get('https://biothings.ncats.io/hpo/phenotype/' + str(symptom['HP']))
        res = r.json()
#         print(res)
        if('synonym' in res):
            if('exact' in res['synonym']):
                for name in res['synonym']['exact']:
                    if name.upper() not in symptom_dict[res['_id']]['names']: 
#                         print(name.upper())
                        symptom_dict[res['_id']]['names'].append(name.upper())
    except:
        print(symptom + " failed")
        

symptom_dict
# Out:
# Low-grade fever
# Cough
# Hemoptysis
# Respiratory distress
# Myalgia
# Fatigue
# Throat pain
# Nausea
# Feculent vomiting
# Diarrhea
# Conjunctival cicatrization
# Anorexia
# Headache
# Leukopenia
# eosinopenia failed
# Neutrophilia
# Elevated hepatic transaminase
# Abnormal C-reactive protein level
# Abnormal serum ferritin
# hyaline membrane failed
# alveolar lesions failed
# prominent hyaline membranes failed
# Diffuse alveolar damage
# acute myocardial injury failed
# Myocarditis
# Supraventricular arrhythmia
# cardiac dysfunction failed
# Encephalopathy
# {'HP:0011134': {'names': ['LOW-GRADE FEVER', 'MILD FEVER'],
#   'frequency': 'Unknown'},
#  'HP:0012735': {'names': ['COUGH', 'COUGHING'], 'frequency': 'Unknown'},
#  'HP:0002105': {'names': ['HEMOPTYSIS', 'COUGHING UP BLOOD', 'HAEMOPTYSIS'],
#   'frequency': 'Unknown'},
#  'HP:0002098': {'names': ['RESPIRATORY DISTRESS',
#    'BREATHING DIFFICULTIES',
#    'DIFFICULTY BREATHING',
#    'RESPIRATORY DIFFICULTIES'],
#   'frequency': 'Unknown'},
#  'HP:0003326': {'names': ['MYALGIA', 'MUSCLE ACHE', 'MUSCLE PAIN'],
#   'frequency': 'Unknown'},
#  'HP:0012378': {'names': ['FATIGUE', 'TIRED', 'TIREDNESS'],
#   'frequency': 'Unknown'},
#  'HP:0033050': {'names': ['THROAT PAIN', 'SORE THROAT'],
#   'frequency': 'Unknown'},
#  'HP:0002018': {'names': ['NAUSEA'], 'frequency': 'Unknown'},
#  'HP:0025089': {'names': ['FECULENT VOMITING',
#    'FECAL VOMITING',
#    'STERCORACEOUS VOMITING'],
#   'frequency': 'Unknown'},
#  'HP:0002014': {'names': ['DIARRHEA', 'DIARRHOEA', 'WATERY STOOL'],
#   'frequency': 'Unknown'},
#  'HP:0500039': {'names': ['CONJUNCTIVAL CICATRIZATION',
#    'CICATRICIAL CONJUNCTIVITIS',
#    'CICATRIZATING CONJUNCTIVITIS',
#    'CONJUNCTIVAL CICATRICIAL CONJUNCTIVITIS'],
#   'frequency': 'Unknown'},
#  'HP:0002039': {'names': ['ANOREXIA'], 'frequency': 'Unknown'},
#  'HP:0002315': {'names': ['HEADACHE', 'HEADACHES'], 'frequency': 'Unknown'},
#  'HP:0001882': {'names': ['LEUKOPENIA',
#    'DECREASED BLOOD LEUKOCYTE NUMBER',
#    'LOW WHITE BLOOD CELL COUNT'],
#   'frequency': 'Unknown'},
#  'HP:0011897': {'names': ['NEUTROPHILIA', 'INCREASED BLOOD NEUTROPHIL COUNTS'],
#   'frequency': 'Unknown'},
#  'HP:0002910': {'names': ['ELEVATED HEPATIC TRANSAMINASE',
#    'ABNORMAL LIVER ENZYMES',
#    'ABNORMAL LIVER FUNCTION',
#    'ABNORMAL LIVER FUNCTION TESTS',
#    'ELEVATED LIVER ENZYMES',
#    'ELEVATED SERUM TRANSAMINASES',
#    'ELEVATED TRANSAMINASES',
#    'HIGH LIVER ENZYMES',
#    'INCREASED LIVER ENZYMES',
#    'INCREASED LIVER FUNCTION TESTS',
#    'INCREASED TRANSAMINASES',
#    'SUBCLINICAL ABNORMAL LIVER FUNCTION TESTS'],
#   'frequency': 'Unknown'},
#  'HP:0032436': {'names': ['ABNORMAL C-REACTIVE PROTEIN LEVEL'],
#   'frequency': 'Unknown'},
#  'HP:0040133': {'names': ['ABNORMAL SERUM FERRITIN',
#    'ABNORMAL PLASMA FERRITIN'],
#   'frequency': 'Unknown'},
#  'HP:0033006': {'names': ['DIFFUSE ALVEOLAR DAMAGE'], 'frequency': 'Unknown'},
#  'HP:0012819': {'names': ['MYOCARDITIS', 'INFLAMMATION OF HEART MUSCLE'],
#   'frequency': 'Unknown'},
#  'HP:0005115': {'names': ['SUPRAVENTRICULAR ARRHYTHMIA',
#    'ARRHYTHMIAS, SUPRAVENTRICULAR'],
#   'frequency': 'Unknown'},
#  'HP:0001298': {'names': ['ENCEPHALOPATHY'], 'frequency': 'Unknown'}}

# %%
# # get phenotypes (signs and symptoms) related to diesase

# fc = FindConnection(input_obj=disease, output_obj='PhenotypicFeature', intermediate_nodes=None)
# fc.connect(verbose=False)
# disease_to_phenotypicFeature = fc.display_table_view()
# disease_to_phenotypicFeature

# %%
# Print equivalent names for the disease input
# print('Note: all equivalent names for the disease input are as follows:')
# for name in fc.fc.display_node_info(disease_name)['equivalent_ids']['name']: print(name)

# %%
# create dictionary of symptom HPIDs, nad symptom names (with synonyms)
# symptom_dict = {}
# for index, row in disease_to_phenotypicFeature.iterrows():
#     output_name = disease_to_phenotypicFeature['output_name'][index]
#     items = fc.fc.G[disease_name][output_name].values()
#     for item in items: 
# #         print(item)
#         if('frequency' in item['info']):
#             freq = [_item['info']['frequency'] for _item in fc.fc.G[disease_name][output_name].values() if "frequency" in _item["info"]][0][0]
#             freq_value = ht.query(freq)['PhenotypicFeature'][0]['name']
#         else: 
#             freq_value = 'Unknown'
                    
#         symptom_dict[fc.fc.display_node_info(output_name)['equivalent_ids']['HP'][0]] = {
#             "names": fc.fc.display_node_info(output_name)['equivalent_ids']['name'],
#             "frequency": freq_value,
#         }
# # print(symptom_dict)
# symptom_dict

# %%
# create list of HPIDs and Symptoms for later use
disease_symptom_hpids = list(symptom_dict.keys())
disease_symptoms = []
for entry in list(symptom_dict.values()): disease_symptoms = disease_symptoms + entry['names']


# create dict of HPIDs : symptoms for use in assembling final results
symptom_to_hpid_dict = {}
for key,value in symptom_dict.items(): 
    for name in value['names']:
        symptom_to_hpid_dict[name] = key

# %%
# add "edges out" counts from each phenotype to any node type, to get a rough estimate of how prevalent a phenotype is
phenotype_inputs = []
for hpid in disease_symptom_hpids: 
    try: 
        phenotype_input = ht.query(hpid)['PhenotypicFeature'][0]
        all_edges_out_df = predict_many([phenotype_input], ALL_NODE_TYPES)
        symptom_dict[hpid]['edges_out_count'] = all_edges_out_df.shape[0]
    except: 
        print(hpid + ' Failed')

print(symptom_dict)
# Out:
# Running: Low-grade fever --> output type Gene
# Running: Low-grade fever --> output type SequenceVariant
# Running: Low-grade fever --> output type ChemicalSubstance
# Running: Low-grade fever --> output type Disease
# Running: Low-grade fever --> output type MolecularActivity
# Running: Low-grade fever --> output type BiologicalProcess
# Running: Low-grade fever --> output type CellularComponent
# Running: Low-grade fever --> output type Pathway
# Running: Low-grade fever --> output type AnatomicalEntity
# Running: Low-grade fever --> output type PhenotypicFeature
# Running: Cough --> output type Gene
# Running: Cough --> output type SequenceVariant
# Running: Cough --> output type ChemicalSubstance
# Running: Cough --> output type Disease
# Running: Cough --> output type MolecularActivity
# Running: Cough --> output type BiologicalProcess
# Running: Cough --> output type CellularComponent
# Running: Cough --> output type Pathway
# Running: Cough --> output type AnatomicalEntity
# Running: Cough --> output type PhenotypicFeature
# Running: Hemoptysis --> output type Gene
# Running: Hemoptysis --> output type SequenceVariant
# Running: Hemoptysis --> output type ChemicalSubstance
# Running: Hemoptysis --> output type Disease
# Running: Hemoptysis --> output type MolecularActivity
# Running: Hemoptysis --> output type BiologicalProcess
# Running: Hemoptysis --> output type CellularComponent
# Running: Hemoptysis --> output type Pathway
# Running: Hemoptysis --> output type AnatomicalEntity
# Running: Hemoptysis --> output type PhenotypicFeature
# Running: Respiratory distress --> output type Gene
# Running: Respiratory distress --> output type SequenceVariant
# Running: Respiratory distress --> output type ChemicalSubstance
# Running: Respiratory distress --> output type Disease
# Running: Respiratory distress --> output type MolecularActivity
# Running: Respiratory distress --> output type BiologicalProcess
# Running: Respiratory distress --> output type CellularComponent
# Running: Respiratory distress --> output type Pathway
# Running: Respiratory distress --> output type AnatomicalEntity
# Running: Respiratory distress --> output type PhenotypicFeature
# Running: Myalgia --> output type Gene
# Running: Myalgia --> output type SequenceVariant
# Running: Myalgia --> output type ChemicalSubstance
# Running: Myalgia --> output type Disease
# Running: Myalgia --> output type MolecularActivity
# Running: Myalgia --> output type BiologicalProcess
# Running: Myalgia --> output type CellularComponent
# Running: Myalgia --> output type Pathway
# Running: Myalgia --> output type AnatomicalEntity
# Running: Myalgia --> output type PhenotypicFeature
# Running: Fatigue --> output type Gene
# Running: Fatigue --> output type SequenceVariant
# Running: Fatigue --> output type ChemicalSubstance
# Running: Fatigue --> output type Disease
# Running: Fatigue --> output type MolecularActivity
# Running: Fatigue --> output type BiologicalProcess
# Running: Fatigue --> output type CellularComponent
# Running: Fatigue --> output type Pathway
# Running: Fatigue --> output type AnatomicalEntity
# Running: Fatigue --> output type PhenotypicFeature
# Running: Throat pain --> output type Gene
# Running: Throat pain --> output type SequenceVariant
# Running: Throat pain --> output type ChemicalSubstance
# Running: Throat pain --> output type Disease
# Running: Throat pain --> output type MolecularActivity
# Running: Throat pain --> output type BiologicalProcess
# Running: Throat pain --> output type CellularComponent
# Running: Throat pain --> output type Pathway
# Running: Throat pain --> output type AnatomicalEntity
# Running: Throat pain --> output type PhenotypicFeature
# HP:0033050 Failed
# Running: Nausea --> output type Gene
# Running: Nausea --> output type SequenceVariant
# Running: Nausea --> output type ChemicalSubstance
# Running: Nausea --> output type Disease
# Running: Nausea --> output type MolecularActivity
# Running: Nausea --> output type BiologicalProcess
# Running: Nausea --> output type CellularComponent
# Running: Nausea --> output type Pathway
# Running: Nausea --> output type AnatomicalEntity
# Running: Nausea --> output type PhenotypicFeature
# Running: Feculent vomiting --> output type Gene
# Running: Feculent vomiting --> output type SequenceVariant
# Running: Feculent vomiting --> output type ChemicalSubstance
# Running: Feculent vomiting --> output type Disease
# Running: Feculent vomiting --> output type MolecularActivity
# Running: Feculent vomiting --> output type BiologicalProcess
# Running: Feculent vomiting --> output type CellularComponent
# Running: Feculent vomiting --> output type Pathway
# Running: Feculent vomiting --> output type AnatomicalEntity
# Running: Feculent vomiting --> output type PhenotypicFeature
# HP:0025089 Failed
# Running: Diarrhea --> output type Gene
# Running: Diarrhea --> output type SequenceVariant
# Running: Diarrhea --> output type ChemicalSubstance
# Running: Diarrhea --> output type Disease
# Running: Diarrhea --> output type MolecularActivity
# Running: Diarrhea --> output type BiologicalProcess
# Running: Diarrhea --> output type CellularComponent
# Running: Diarrhea --> output type Pathway
# Running: Diarrhea --> output type AnatomicalEntity
# Running: Diarrhea --> output type PhenotypicFeature
# Running: Conjunctival cicatrization --> output type Gene
# Running: Conjunctival cicatrization --> output type SequenceVariant
# Running: Conjunctival cicatrization --> output type ChemicalSubstance
# Running: Conjunctival cicatrization --> output type Disease
# Running: Conjunctival cicatrization --> output type MolecularActivity
# Running: Conjunctival cicatrization --> output type BiologicalProcess
# Running: Conjunctival cicatrization --> output type CellularComponent
# Running: Conjunctival cicatrization --> output type Pathway
# Running: Conjunctival cicatrization --> output type AnatomicalEntity
# Running: Conjunctival cicatrization --> output type PhenotypicFeature
# HP:0500039 Failed
# Running: Anorexia --> output type Gene
# Running: Anorexia --> output type SequenceVariant
# Running: Anorexia --> output type ChemicalSubstance
# Running: Anorexia --> output type Disease
# Running: Anorexia --> output type MolecularActivity
# Running: Anorexia --> output type BiologicalProcess
# Running: Anorexia --> output type CellularComponent
# Running: Anorexia --> output type Pathway
# Running: Anorexia --> output type AnatomicalEntity
# Running: Anorexia --> output type PhenotypicFeature
# Running: Headache --> output type Gene
# Running: Headache --> output type SequenceVariant
# Running: Headache --> output type ChemicalSubstance
# Running: Headache --> output type Disease
# Running: Headache --> output type MolecularActivity
# Running: Headache --> output type BiologicalProcess
# Running: Headache --> output type CellularComponent
# Running: Headache --> output type Pathway
# Running: Headache --> output type AnatomicalEntity
# Running: Headache --> output type PhenotypicFeature
# Running: Leukopenia --> output type Gene
# Running: Leukopenia --> output type SequenceVariant
# Running: Leukopenia --> output type ChemicalSubstance
# Running: Leukopenia --> output type Disease
# Running: Leukopenia --> output type MolecularActivity
# Running: Leukopenia --> output type BiologicalProcess
# Running: Leukopenia --> output type CellularComponent
# Running: Leukopenia --> output type Pathway
# Running: Leukopenia --> output type AnatomicalEntity
# Running: Leukopenia --> output type PhenotypicFeature
# Running: Neutrophilia --> output type Gene
# Running: Neutrophilia --> output type SequenceVariant
# Running: Neutrophilia --> output type ChemicalSubstance
# Running: Neutrophilia --> output type Disease
# Running: Neutrophilia --> output type MolecularActivity
# Running: Neutrophilia --> output type BiologicalProcess
# Running: Neutrophilia --> output type CellularComponent
# Running: Neutrophilia --> output type Pathway
# Running: Neutrophilia --> output type AnatomicalEntity
# Running: Neutrophilia --> output type PhenotypicFeature
# Running: Elevated hepatic transaminase --> output type Gene
# Running: Elevated hepatic transaminase --> output type SequenceVariant
# Running: Elevated hepatic transaminase --> output type ChemicalSubstance
# Running: Elevated hepatic transaminase --> output type Disease
# Running: Elevated hepatic transaminase --> output type MolecularActivity
# Running: Elevated hepatic transaminase --> output type BiologicalProcess
# Running: Elevated hepatic transaminase --> output type CellularComponent
# Running: Elevated hepatic transaminase --> output type Pathway
# Running: Elevated hepatic transaminase --> output type AnatomicalEntity
# Running: Elevated hepatic transaminase --> output type PhenotypicFeature
# Running: Abnormal C-reactive protein level --> output type Gene
# Running: Abnormal C-reactive protein level --> output type SequenceVariant
# Running: Abnormal C-reactive protein level --> output type ChemicalSubstance
# Running: Abnormal C-reactive protein level --> output type Disease
# Running: Abnormal C-reactive protein level --> output type MolecularActivity
# Running: Abnormal C-reactive protein level --> output type BiologicalProcess
# Running: Abnormal C-reactive protein level --> output type CellularComponent
# Running: Abnormal C-reactive protein level --> output type Pathway
# Running: Abnormal C-reactive protein level --> output type AnatomicalEntity
# Running: Abnormal C-reactive protein level --> output type PhenotypicFeature
# HP:0032436 Failed
# Running: Abnormal serum ferritin --> output type Gene
# Running: Abnormal serum ferritin --> output type SequenceVariant
# Running: Abnormal serum ferritin --> output type ChemicalSubstance
# Running: Abnormal serum ferritin --> output type Disease
# Running: Abnormal serum ferritin --> output type MolecularActivity
# Running: Abnormal serum ferritin --> output type BiologicalProcess
# Running: Abnormal serum ferritin --> output type CellularComponent
# Running: Abnormal serum ferritin --> output type Pathway
# Running: Abnormal serum ferritin --> output type AnatomicalEntity
# Running: Abnormal serum ferritin --> output type PhenotypicFeature
# Running: Diffuse alveolar damage --> output type Gene
# Running: Diffuse alveolar damage --> output type SequenceVariant
# Running: Diffuse alveolar damage --> output type ChemicalSubstance
# Running: Diffuse alveolar damage --> output type Disease
# Running: Diffuse alveolar damage --> output type MolecularActivity
# Running: Diffuse alveolar damage --> output type BiologicalProcess
# Running: Diffuse alveolar damage --> output type CellularComponent
# Running: Diffuse alveolar damage --> output type Pathway
# Running: Diffuse alveolar damage --> output type AnatomicalEntity
# Running: Diffuse alveolar damage --> output type PhenotypicFeature
# HP:0033006 Failed
# Running: Myocarditis --> output type Gene
# Running: Myocarditis --> output type SequenceVariant
# Running: Myocarditis --> output type ChemicalSubstance
# Running: Myocarditis --> output type Disease
# Running: Myocarditis --> output type MolecularActivity
# Running: Myocarditis --> output type BiologicalProcess
# Running: Myocarditis --> output type CellularComponent
# Running: Myocarditis --> output type Pathway
# Running: Myocarditis --> output type AnatomicalEntity
# Running: Myocarditis --> output type PhenotypicFeature
# Running: Supraventricular arrhythmia --> output type Gene
# Running: Supraventricular arrhythmia --> output type SequenceVariant
# Running: Supraventricular arrhythmia --> output type ChemicalSubstance
# Running: Supraventricular arrhythmia --> output type Disease
# Running: Supraventricular arrhythmia --> output type MolecularActivity
# Running: Supraventricular arrhythmia --> output type BiologicalProcess
# Running: Supraventricular arrhythmia --> output type CellularComponent
# Running: Supraventricular arrhythmia --> output type Pathway
# Running: Supraventricular arrhythmia --> output type AnatomicalEntity
# Running: Supraventricular arrhythmia --> output type PhenotypicFeature
# Running: Encephalopathy --> output type Gene
# Running: Encephalopathy --> output type SequenceVariant
# Running: Encephalopathy --> output type ChemicalSubstance
# Running: Encephalopathy --> output type Disease
# Running: Encephalopathy --> output type MolecularActivity
# Running: Encephalopathy --> output type BiologicalProcess
# Running: Encephalopathy --> output type CellularComponent
# Running: Encephalopathy --> output type Pathway
# Running: Encephalopathy --> output type AnatomicalEntity
# Running: Encephalopathy --> output type PhenotypicFeature
# {'HP:0011134': {'names': ['LOW-GRADE FEVER', 'MILD FEVER'], 'frequency': 'Unknown', 'edges_out_count': 11}, 'HP:0012735': {'names': ['COUGH', 'COUGHING'], 'frequency': 'Unknown', 'edges_out_count': 254}, 'HP:0002105': {'names': ['HEMOPTYSIS', 'COUGHING UP BLOOD', 'HAEMOPTYSIS'], 'frequency': 'Unknown', 'edges_out_count': 77}, 'HP:0002098': {'names': ['RESPIRATORY DISTRESS', 'BREATHING DIFFICULTIES', 'DIFFICULTY BREATHING', 'RESPIRATORY DIFFICULTIES'], 'frequency': 'Unknown', 'edges_out_count': 970}, 'HP:0003326': {'names': ['MYALGIA', 'MUSCLE ACHE', 'MUSCLE PAIN'], 'frequency': 'Unknown', 'edges_out_count': 346}, 'HP:0012378': {'names': ['FATIGUE', 'TIRED', 'TIREDNESS'], 'frequency': 'Unknown', 'edges_out_count': 458}, 'HP:0033050': {'names': ['THROAT PAIN', 'SORE THROAT'], 'frequency': 'Unknown'}, 'HP:0002018': {'names': ['NAUSEA'], 'frequency': 'Unknown', 'edges_out_count': 152}, 'HP:0025089': {'names': ['FECULENT VOMITING', 'FECAL VOMITING', 'STERCORACEOUS VOMITING'], 'frequency': 'Unknown'}, 'HP:0002014': {'names': ['DIARRHEA', 'DIARRHOEA', 'WATERY STOOL'], 'frequency': 'Unknown', 'edges_out_count': 702}, 'HP:0500039': {'names': ['CONJUNCTIVAL CICATRIZATION', 'CICATRICIAL CONJUNCTIVITIS', 'CICATRIZATING CONJUNCTIVITIS', 'CONJUNCTIVAL CICATRICIAL CONJUNCTIVITIS'], 'frequency': 'Unknown'}, 'HP:0002039': {'names': ['ANOREXIA'], 'frequency': 'Unknown', 'edges_out_count': 172}, 'HP:0002315': {'names': ['HEADACHE', 'HEADACHES'], 'frequency': 'Unknown', 'edges_out_count': 411}, 'HP:0001882': {'names': ['LEUKOPENIA', 'DECREASED BLOOD LEUKOCYTE NUMBER', 'LOW WHITE BLOOD CELL COUNT'], 'frequency': 'Unknown', 'edges_out_count': 369}, 'HP:0011897': {'names': ['NEUTROPHILIA', 'INCREASED BLOOD NEUTROPHIL COUNTS'], 'frequency': 'Unknown', 'edges_out_count': 22}, 'HP:0002910': {'names': ['ELEVATED HEPATIC TRANSAMINASE', 'ABNORMAL LIVER ENZYMES', 'ABNORMAL LIVER FUNCTION', 'ABNORMAL LIVER FUNCTION TESTS', 'ELEVATED LIVER ENZYMES', 'ELEVATED SERUM TRANSAMINASES', 'ELEVATED TRANSAMINASES', 'HIGH LIVER ENZYMES', 'INCREASED LIVER ENZYMES', 'INCREASED LIVER FUNCTION TESTS', 'INCREASED TRANSAMINASES', 'SUBCLINICAL ABNORMAL LIVER FUNCTION TESTS'], 'frequency': 'Unknown', 'edges_out_count': 897}, 'HP:0032436': {'names': ['ABNORMAL C-REACTIVE PROTEIN LEVEL'], 'frequency': 'Unknown'}, 'HP:0040133': {'names': ['ABNORMAL SERUM FERRITIN', 'ABNORMAL PLASMA FERRITIN'], 'frequency': 'Unknown', 'edges_out_count': 1}, 'HP:0033006': {'names': ['DIFFUSE ALVEOLAR DAMAGE'], 'frequency': 'Unknown'}, 'HP:0012819': {'names': ['MYOCARDITIS', 'INFLAMMATION OF HEART MUSCLE'], 'frequency': 'Unknown', 'edges_out_count': 99}, 'HP:0005115': {'names': ['SUPRAVENTRICULAR ARRHYTHMIA', 'ARRHYTHMIAS, SUPRAVENTRICULAR'], 'frequency': 'Unknown', 'edges_out_count': 31}, 'HP:0001298': {'names': ['ENCEPHALOPATHY'], 'frequency': 'Unknown', 'edges_out_count': 362}}

# %%
# convert symptom dictionary to dataframe and sort by edges out and frequency 
disease_symptom_df = pd.DataFrame.from_dict(symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptom_df = pd.concat([disease_symptom_df[disease_symptom_df["frequency"] == "Very frequent"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Frequent"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Occasional"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Rare"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Unknown"]
              ])
disease_symptom_df
# Out:
#                                                         names frequency  \
# HP:0040133  [ABNORMAL SERUM FERRITIN, ABNORMAL PLASMA FERR...   Unknown
# HP:0011134                      [LOW-GRADE FEVER, MILD FEVER]   Unknown
# HP:0011897  [NEUTROPHILIA, INCREASED BLOOD NEUTROPHIL COUNTS]   Unknown
# HP:0005115  [SUPRAVENTRICULAR ARRHYTHMIA, ARRHYTHMIAS, SUP...   Unknown
# HP:0002105       [HEMOPTYSIS, COUGHING UP BLOOD, HAEMOPTYSIS]   Unknown
# HP:0012819        [MYOCARDITIS, INFLAMMATION OF HEART MUSCLE]   Unknown
# HP:0002018                                           [NAUSEA]   Unknown
# HP:0002039                                         [ANOREXIA]   Unknown
# HP:0012735                                  [COUGH, COUGHING]   Unknown
# HP:0003326                [MYALGIA, MUSCLE ACHE, MUSCLE PAIN]   Unknown
# HP:0001298                                   [ENCEPHALOPATHY]   Unknown
# HP:0001882  [LEUKOPENIA, DECREASED BLOOD LEUKOCYTE NUMBER,...   Unknown
# HP:0002315                              [HEADACHE, HEADACHES]   Unknown
# HP:0012378                        [FATIGUE, TIRED, TIREDNESS]   Unknown
# HP:0002014                [DIARRHEA, DIARRHOEA, WATERY STOOL]   Unknown
# HP:0002910  [ELEVATED HEPATIC TRANSAMINASE, ABNORMAL LIVER...   Unknown
# HP:0002098  [RESPIRATORY DISTRESS, BREATHING DIFFICULTIES,...   Unknown
# HP:0033050                         [THROAT PAIN, SORE THROAT]   Unknown
# HP:0025089  [FECULENT VOMITING, FECAL VOMITING, STERCORACE...   Unknown
# HP:0500039  [CONJUNCTIVAL CICATRIZATION, CICATRICIAL CONJU...   Unknown
# HP:0032436                [ABNORMAL C-REACTIVE PROTEIN LEVEL]   Unknown
# HP:0033006                          [DIFFUSE ALVEOLAR DAMAGE]   Unknown
#
#             edges_out_count
# HP:0040133              1.0
# HP:0011134             11.0
# HP:0011897             22.0
# HP:0005115             31.0
# HP:0002105             77.0
# HP:0012819             99.0
# HP:0002018            152.0
# HP:0002039            172.0
# HP:0012735            254.0
# HP:0003326            346.0
# HP:0001298            362.0
# HP:0001882            369.0
# HP:0002315            411.0
# HP:0012378            458.0
# HP:0002014            702.0
# HP:0002910            897.0
# HP:0002098            970.0
# HP:0033050              NaN
# HP:0025089              NaN
# HP:0500039              NaN
# HP:0032436              NaN
# HP:0033006              NaN

# %%
disease_symptom_df.to_csv(disease_symptoms_csv, index = True)

# %% [markdown]
# ## 2. Get Genes Directly Related to Disease

# %%
# find genes directly related to disease
disease = ht.query("COVID-19")['Disease'][0]
disease
fc = FindConnection(input_obj=disease, output_obj='Gene', intermediate_nodes=None)
fc.connect(verbose=False)
disease_to_genes = fc.display_table_view()
disease_to_genes = disease_to_genes[~disease_to_genes['output_id'].str.contains('UMLS')]
disease_to_genes
# Out:
#                       input input_type       pred1 pred1_source  \
# 0    2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 1    2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 2    2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 3    2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 4    2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# ..                      ...        ...         ...          ...
# 387  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 388  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 389  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 390  2019 NOVEL CORONAVIRUS    Disease  related_to     scigraph
# 391  2019 NOVEL CORONAVIRUS    Disease  related_to         None
#
#                        pred1_api pred1_pubmed output_type output_name  \
# 0                   DISEASES API         None        Gene        CFTR
# 1                   DISEASES API         None        Gene     CEACAM7
# 2                   DISEASES API         None        Gene         CD4
# 3                   DISEASES API         None        Gene        CPB2
# 4                   DISEASES API         None        Gene       SIRT4
# ..                           ...          ...         ...         ...
# 387  Automat CORD19 Scigraph API         None        Gene          TH
# 388  Automat CORD19 Scigraph API         None        Gene         SON
# 389  Automat CORD19 Scigraph API         None        Gene       MARS1
# 390  Automat CORD19 Scigraph API         None        Gene         POR
# 391                  BioLink API         None        Gene         ABO
#
#           output_id
# 0     NCBIGene:1080
# 1     NCBIGene:1087
# 2      NCBIGene:920
# 3     NCBIGene:1361
# 4    NCBIGene:23409
# ..              ...
# 387   NCBIGene:7054
# 388   NCBIGene:6651
# 389   NCBIGene:4141
# 390   NCBIGene:5447
# 391     NCBIGene:28
#
# [391 rows x 9 columns]

# %%
# create dictionary of gene reults whereby each Gene has values for the number of occurrences of the gene in results
# and the number of publications connecting the disease -> gene directly
disease_to_gene_results = {}
disease_to_gene_genes = list(disease_to_genes["output_name"]) # create list of genes
disease_to_gene_genes = list(dict.fromkeys(disease_to_gene_genes))  # remove duplicates

for gene in disease_to_gene_genes: 
    disease_to_gene_results[gene] = {
        'gene_count' : 0,
        'publications': []
    }

for index, row in disease_to_genes.iterrows():
    disease_to_gene_results[row['output_name']]['gene_count'] = disease_to_gene_results[row['output_name']]['gene_count'] + 1
    if(row['pred1_pubmed'] != None): 
        disease_to_gene_results[row['output_name']]['publications'] = disease_to_gene_results[row['output_name']]['publications'] + row['pred1_pubmed'].split(",")

disease_to_gene_results = dict(sorted(disease_to_gene_results.items(), key = lambda x: x[1]['gene_count'], reverse = True))

for key,value in disease_to_gene_results.items(): 
    disease_to_gene_results[key]['publications'] = list(dict.fromkeys(disease_to_gene_results[key]['publications']))
    
    
disease_to_gene_results
# Out:
# {'CRP': {'gene_count': 2, 'publications': []},
#  'LZTFL1': {'gene_count': 2, 'publications': []},
#  'TMPRSS2': {'gene_count': 2, 'publications': []},
#  'ACE2': {'gene_count': 2, 'publications': []},
#  'CFTR': {'gene_count': 1, 'publications': []},
#  'CEACAM7': {'gene_count': 1, 'publications': []},
#  'CD4': {'gene_count': 1, 'publications': []},
#  'CPB2': {'gene_count': 1, 'publications': []},
#  'SIRT4': {'gene_count': 1, 'publications': []},
#  'APOH': {'gene_count': 1, 'publications': []},
#  'TMEM14A': {'gene_count': 1, 'publications': []},
#  'SIRT1': {'gene_count': 1, 'publications': []},
#  'GADD45B': {'gene_count': 1, 'publications': []},
#  'MAPK1': {'gene_count': 1, 'publications': []},
#  'GZMB': {'gene_count': 1, 'publications': []},
#  'BDKRB1': {'gene_count': 1, 'publications': []},
#  'OXT': {'gene_count': 1, 'publications': []},
#  'TBL1X': {'gene_count': 1, 'publications': []},
#  'ATP12A': {'gene_count': 1, 'publications': []},
#  'DHODH': {'gene_count': 1, 'publications': []},
#  'MEFV': {'gene_count': 1, 'publications': []},
#  'MGA': {'gene_count': 1, 'publications': []},
#  'PLAT': {'gene_count': 1, 'publications': []},
#  'EIF3E': {'gene_count': 1, 'publications': []},
#  'FCGRT': {'gene_count': 1, 'publications': []},
#  'SGTA': {'gene_count': 1, 'publications': []},
#  'SERPINE1': {'gene_count': 1, 'publications': []},
#  'CHMP5': {'gene_count': 1, 'publications': []},
#  'C5': {'gene_count': 1, 'publications': []},
#  'MPO': {'gene_count': 1, 'publications': []},
#  'CSF3': {'gene_count': 1, 'publications': []},
#  'CCL2': {'gene_count': 1, 'publications': []},
#  'IL2': {'gene_count': 1, 'publications': []},
#  'CTSC': {'gene_count': 1, 'publications': []},
#  'IFNG': {'gene_count': 1, 'publications': []},
#  'MAPK14': {'gene_count': 1, 'publications': []},
#  'IL4': {'gene_count': 1, 'publications': []},
#  'MAPRE3': {'gene_count': 1, 'publications': []},
#  'TNNT2': {'gene_count': 1, 'publications': []},
#  'TTR': {'gene_count': 1, 'publications': []},
#  'LGALSL': {'gene_count': 1, 'publications': []},
#  'TAS2R10': {'gene_count': 1, 'publications': []},
#  'ZC3HAV1': {'gene_count': 1, 'publications': []},
#  'NT5C': {'gene_count': 1, 'publications': []},
#  'C3': {'gene_count': 1, 'publications': []},
#  'SH2D3A': {'gene_count': 1, 'publications': []},
#  'F2RL3': {'gene_count': 1, 'publications': []},
#  'FGL2': {'gene_count': 1, 'publications': []},
#  'SGSM3': {'gene_count': 1, 'publications': []},
#  'SIRT2': {'gene_count': 1, 'publications': []},
#  'CD68': {'gene_count': 1, 'publications': []},
#  'APOE': {'gene_count': 1, 'publications': []},
#  'MAS1': {'gene_count': 1, 'publications': []},
#  'HRC': {'gene_count': 1, 'publications': []},
#  'TAF4': {'gene_count': 1, 'publications': []},
#  'NT5E': {'gene_count': 1, 'publications': []},
#  'EIF4E2': {'gene_count': 1, 'publications': []},
#  'BAAT': {'gene_count': 1, 'publications': []},
#  'TLR2': {'gene_count': 1, 'publications': []},
#  'PPIG': {'gene_count': 1, 'publications': []},
#  'VWF': {'gene_count': 1, 'publications': []},
#  'SPECC1': {'gene_count': 1, 'publications': []},
#  'COX10': {'gene_count': 1, 'publications': []},
#  'MPP5': {'gene_count': 1, 'publications': []},
#  'HCN4': {'gene_count': 1, 'publications': []},
#  'MTUS1': {'gene_count': 1, 'publications': []},
#  'MYOM2': {'gene_count': 1, 'publications': []},
#  'ITGA2B': {'gene_count': 1, 'publications': []},
#  'ATP4A': {'gene_count': 1, 'publications': []},
#  'IL37': {'gene_count': 1, 'publications': []},
#  'IL1B': {'gene_count': 1, 'publications': []},
#  'IFIH1': {'gene_count': 1, 'publications': []},
#  'SELP': {'gene_count': 1, 'publications': []},
#  'OSBP': {'gene_count': 1, 'publications': []},
#  'IL7': {'gene_count': 1, 'publications': []},
#  'GNLY': {'gene_count': 1, 'publications': []},
#  'CHIC2': {'gene_count': 1, 'publications': []},
#  'USP13': {'gene_count': 1, 'publications': []},
#  'NOA1': {'gene_count': 1, 'publications': []},
#  'TXNDC9': {'gene_count': 1, 'publications': []},
#  'PIKFYVE': {'gene_count': 1, 'publications': []},
#  'CDH10': {'gene_count': 1, 'publications': []},
#  'STAT3': {'gene_count': 1, 'publications': []},
#  'KLKB1': {'gene_count': 1, 'publications': []},
#  'ICAM1': {'gene_count': 1, 'publications': []},
#  'KNG1': {'gene_count': 1, 'publications': []},
#  'ENPEP': {'gene_count': 1, 'publications': []},
#  'SLC5A4': {'gene_count': 1, 'publications': []},
#  'MED9': {'gene_count': 1, 'publications': []},
#  'PCTP': {'gene_count': 1, 'publications': []},
#  'NPC1': {'gene_count': 1, 'publications': []},
#  'NTN5': {'gene_count': 1, 'publications': []},
#  'PRCC': {'gene_count': 1, 'publications': []},
#  'REN': {'gene_count': 1, 'publications': []},
#  'CTDSP1': {'gene_count': 1, 'publications': []},
#  'IL9': {'gene_count': 1, 'publications': []},
#  'PM20D2': {'gene_count': 1, 'publications': []},
#  'TAAR6': {'gene_count': 1, 'publications': []},
#  'TAAR8': {'gene_count': 1, 'publications': []},
#  'IFNA1': {'gene_count': 1, 'publications': []},
#  'NINL': {'gene_count': 1, 'publications': []},
#  'IL18': {'gene_count': 1, 'publications': []},
#  'CRYGC': {'gene_count': 1, 'publications': []},
#  'TMPRSS11D': {'gene_count': 1, 'publications': []},
#  'TOMM70A': {'gene_count': 1, 'publications': []},
#  'ASZ1': {'gene_count': 1, 'publications': []},
#  'PPARG': {'gene_count': 1, 'publications': []},
#  'PDPR': {'gene_count': 1, 'publications': []},
#  'ACE': {'gene_count': 1, 'publications': []},
#  'CCR5': {'gene_count': 1, 'publications': []},
#  'EIF4A1': {'gene_count': 1, 'publications': []},
#  'SLX4': {'gene_count': 1, 'publications': []},
#  'TPCN2': {'gene_count': 1, 'publications': []},
#  'NUP35': {'gene_count': 1, 'publications': []},
#  'ALB': {'gene_count': 1, 'publications': []},
#  'CXCL3': {'gene_count': 1, 'publications': []},
#  'PF4': {'gene_count': 1, 'publications': []},
#  'FYCO1': {'gene_count': 1, 'publications': []},
#  'CCR1': {'gene_count': 1, 'publications': []},
#  'TLR3': {'gene_count': 1, 'publications': []},
#  'CSF2': {'gene_count': 1, 'publications': []},
#  'BMPER': {'gene_count': 1, 'publications': []},
#  'DEFA4': {'gene_count': 1, 'publications': []},
#  'PPIB': {'gene_count': 1, 'publications': []},
#  'ANPEP': {'gene_count': 1, 'publications': []},
#  'AXL': {'gene_count': 1, 'publications': []},
#  'CCL11': {'gene_count': 1, 'publications': []},
#  'IL16': {'gene_count': 1, 'publications': []},
#  'MAGI3': {'gene_count': 1, 'publications': []},
#  'IL13': {'gene_count': 1, 'publications': []},
#  'SRP9': {'gene_count': 1, 'publications': []},
#  'SLC6A19': {'gene_count': 1, 'publications': []},
#  'TUB': {'gene_count': 1, 'publications': []},
#  'CXCL10': {'gene_count': 1, 'publications': []},
#  'CXCL8': {'gene_count': 1, 'publications': []},
#  'ZNF608': {'gene_count': 1, 'publications': []},
#  'F2': {'gene_count': 1, 'publications': []},
#  'GPR151': {'gene_count': 1, 'publications': []},
#  'PLG': {'gene_count': 1, 'publications': []},
#  'FAM134C': {'gene_count': 1, 'publications': []},
#  'CA5A': {'gene_count': 1, 'publications': []},
#  'ADAM17': {'gene_count': 1, 'publications': []},
#  'MRGPRD': {'gene_count': 1, 'publications': []},
#  'DNAH7': {'gene_count': 1, 'publications': []},
#  'HAVCR2': {'gene_count': 1, 'publications': []},
#  'TLR8': {'gene_count': 1, 'publications': []},
#  'GAK': {'gene_count': 1, 'publications': []},
#  'CD209': {'gene_count': 1, 'publications': []},
#  'CLEC4M': {'gene_count': 1, 'publications': []},
#  'APOL1': {'gene_count': 1, 'publications': []},
#  'SH2D3C': {'gene_count': 1, 'publications': []},
#  'RHOT2': {'gene_count': 1, 'publications': []},
#  'FOXJ1': {'gene_count': 1, 'publications': []},
#  'HSPA5': {'gene_count': 1, 'publications': []},
#  'PARP10': {'gene_count': 1, 'publications': []},
#  'PPP1CA': {'gene_count': 1, 'publications': []},
#  'KLK4': {'gene_count': 1, 'publications': []},
#  'EIF4A2': {'gene_count': 1, 'publications': []},
#  'CSF1': {'gene_count': 1, 'publications': []},
#  'SLC5A2': {'gene_count': 1, 'publications': []},
#  'SIRT7': {'gene_count': 1, 'publications': []},
#  'ADAP2': {'gene_count': 1, 'publications': []},
#  'DEFA5': {'gene_count': 1, 'publications': []},
#  'PHF12': {'gene_count': 1, 'publications': []},
#  'SELE': {'gene_count': 1, 'publications': []},
#  'RNLS': {'gene_count': 1, 'publications': []},
#  'BACE2': {'gene_count': 1, 'publications': []},
#  'BSG': {'gene_count': 1, 'publications': []},
#  'HBB': {'gene_count': 1, 'publications': []},
#  'F3': {'gene_count': 1, 'publications': []},
#  'TMPRSS11A': {'gene_count': 1, 'publications': []},
#  'ATF4': {'gene_count': 1, 'publications': []},
#  'PNRC1': {'gene_count': 1, 'publications': []},
#  'ENOX2': {'gene_count': 1, 'publications': []},
#  'SIRT6': {'gene_count': 1, 'publications': []},
#  'MED19': {'gene_count': 1, 'publications': []},
#  'NLRP3': {'gene_count': 1, 'publications': []},
#  'CYP3A4': {'gene_count': 1, 'publications': []},
#  'OSTF1': {'gene_count': 1, 'publications': []},
#  'C1QTNF1': {'gene_count': 1, 'publications': []},
#  'TNNI3': {'gene_count': 1, 'publications': []},
#  'OAS2': {'gene_count': 1, 'publications': []},
#  'PTGES': {'gene_count': 1, 'publications': []},
#  'JAK1': {'gene_count': 1, 'publications': []},
#  'TNFSF13': {'gene_count': 1, 'publications': []},
#  'GPR29': {'gene_count': 1, 'publications': []},
#  'IL17A': {'gene_count': 1, 'publications': []},
#  'GPT2': {'gene_count': 1, 'publications': []},
#  'CTSL': {'gene_count': 1, 'publications': []},
#  'HMGB1': {'gene_count': 1, 'publications': []},
#  'CTSB': {'gene_count': 1, 'publications': []},
#  'SLC6A20': {'gene_count': 1, 'publications': []},
#  'PDE5A': {'gene_count': 1, 'publications': []},
#  'STOML2': {'gene_count': 1, 'publications': []},
#  'CCRL2': {'gene_count': 1, 'publications': []},
#  'SYCP2': {'gene_count': 1, 'publications': []},
#  'FAM3B': {'gene_count': 1, 'publications': []},
#  'CCL20': {'gene_count': 1, 'publications': []},
#  'CNDP1': {'gene_count': 1, 'publications': []},
#  'CALCR': {'gene_count': 1, 'publications': []},
#  'SCNN1A': {'gene_count': 1, 'publications': []},
#  'F8': {'gene_count': 1, 'publications': []},
#  'DPP4': {'gene_count': 1, 'publications': []},
#  'TLR9': {'gene_count': 1, 'publications': []},
#  'STAT1': {'gene_count': 1, 'publications': []},
#  'MTOR': {'gene_count': 1, 'publications': []},
#  'TBKBP1': {'gene_count': 1, 'publications': []},
#  'XAF1': {'gene_count': 1, 'publications': []},
#  'CXCL9': {'gene_count': 1, 'publications': []},
#  'AGT': {'gene_count': 1, 'publications': []},
#  'EPRS': {'gene_count': 1, 'publications': []},
#  'KDM5B': {'gene_count': 1, 'publications': []},
#  'NEK7': {'gene_count': 1, 'publications': []},
#  'SERPINC1': {'gene_count': 1, 'publications': []},
#  'FCGR3A': {'gene_count': 1, 'publications': []},
#  'ADAR': {'gene_count': 1, 'publications': []},
#  'IL6R': {'gene_count': 1, 'publications': []},
#  'PI4KB': {'gene_count': 1, 'publications': []},
#  'CTSS': {'gene_count': 1, 'publications': []},
#  'DUSP5': {'gene_count': 1, 'publications': []},
#  'TAF5': {'gene_count': 1, 'publications': []},
#  'NTNG1': {'gene_count': 1, 'publications': []},
#  'GBP1': {'gene_count': 1, 'publications': []},
#  'NTSR1': {'gene_count': 1, 'publications': []},
#  'IFI44': {'gene_count': 1, 'publications': []},
#  'JUN': {'gene_count': 1, 'publications': []},
#  'TNKS2': {'gene_count': 1, 'publications': []},
#  'IFIT1': {'gene_count': 1, 'publications': []},
#  'FCN1': {'gene_count': 1, 'publications': []},
#  'IFIT2': {'gene_count': 1, 'publications': []},
#  'AGTR2': {'gene_count': 1, 'publications': []},
#  'ADAMTS13': {'gene_count': 1, 'publications': []},
#  'SFTPA2': {'gene_count': 1, 'publications': []},
#  'CXorf57': {'gene_count': 1, 'publications': []},
#  'ZMPSTE24': {'gene_count': 1, 'publications': []},
#  'TAF7L': {'gene_count': 1, 'publications': []},
#  'YARS': {'gene_count': 1, 'publications': []},
#  'EIF3I': {'gene_count': 1, 'publications': []},
#  'CXCR3': {'gene_count': 1, 'publications': []},
#  'TLR4': {'gene_count': 1, 'publications': []},
#  'UQCC1': {'gene_count': 1, 'publications': []},
#  'PADI1': {'gene_count': 1, 'publications': []},
#  'F10': {'gene_count': 1, 'publications': []},
#  'F7': {'gene_count': 1, 'publications': []},
#  'NPPB': {'gene_count': 1, 'publications': []},
#  'PPP1R10': {'gene_count': 1, 'publications': []},
#  'THBD': {'gene_count': 1, 'publications': []},
#  'HMGN4': {'gene_count': 1, 'publications': []},
#  'ESPN': {'gene_count': 1, 'publications': []},
#  'CCL7': {'gene_count': 1, 'publications': []},
#  'LGR4': {'gene_count': 1, 'publications': []},
#  'ISG15': {'gene_count': 1, 'publications': []},
#  'DDX58': {'gene_count': 1, 'publications': []},
#  'IL2RA': {'gene_count': 1, 'publications': []},
#  'IFNA2': {'gene_count': 1, 'publications': []},
#  'IFNB1': {'gene_count': 1, 'publications': []},
#  'AVP': {'gene_count': 1, 'publications': []},
#  'TMEM27': {'gene_count': 1, 'publications': []},
#  'NQO2': {'gene_count': 1, 'publications': []},
#  'TLR7': {'gene_count': 1, 'publications': []},
#  'PDE4A': {'gene_count': 1, 'publications': []},
#  'CD274': {'gene_count': 1, 'publications': []},
#  'JAK2': {'gene_count': 1, 'publications': []},
#  'ANGPT4': {'gene_count': 1, 'publications': []},
#  'SOD3': {'gene_count': 1, 'publications': []},
#  'AQP4': {'gene_count': 1, 'publications': []},
#  'KRT18': {'gene_count': 1, 'publications': []},
#  'TYRP1': {'gene_count': 1, 'publications': []},
#  'EID2': {'gene_count': 1, 'publications': []},
#  'IL1F10': {'gene_count': 1, 'publications': []},
#  'NTNG2': {'gene_count': 1, 'publications': []},
#  'PICALM': {'gene_count': 1, 'publications': []},
#  'SRPK2': {'gene_count': 1, 'publications': []},
#  'GPT': {'gene_count': 1, 'publications': []},
#  'DAAM1': {'gene_count': 1, 'publications': []},
#  'PPP1CB': {'gene_count': 1, 'publications': []},
#  'HLA-A': {'gene_count': 1, 'publications': []},
#  'OR51E2': {'gene_count': 1, 'publications': []},
#  'INS': {'gene_count': 1, 'publications': []},
#  'MB': {'gene_count': 1, 'publications': []},
#  'CEP250': {'gene_count': 1, 'publications': []},
#  'IRF7': {'gene_count': 1, 'publications': []},
#  'MX1': {'gene_count': 1, 'publications': []},
#  'TOP3B': {'gene_count': 1, 'publications': []},
#  'IFITM3': {'gene_count': 1, 'publications': []},
#  'CMKBR6': {'gene_count': 1, 'publications': []},
#  'XPO1': {'gene_count': 1, 'publications': []},
#  'SAA1': {'gene_count': 1, 'publications': []},
#  'IL6': {'gene_count': 1, 'publications': []},
#  'DNASE1': {'gene_count': 1, 'publications': []},
#  'IFITM1': {'gene_count': 1, 'publications': []},
#  'SAG': {'gene_count': 1, 'publications': []},
#  'AAK1': {'gene_count': 1, 'publications': []},
#  'CD8A': {'gene_count': 1, 'publications': []},
#  'GIGYF2': {'gene_count': 1, 'publications': []},
#  'RAB1A': {'gene_count': 1, 'publications': []},
#  'OAS1': {'gene_count': 1, 'publications': []},
#  'NSG1': {'gene_count': 1, 'publications': []},
#  'RPP30': {'gene_count': 1, 'publications': []},
#  'ARPC1B': {'gene_count': 1, 'publications': []},
#  'INO80C': {'gene_count': 1, 'publications': []},
#  'MFRP': {'gene_count': 1, 'publications': []},
#  'VPRBP': {'gene_count': 1, 'publications': []},
#  'ORM2': {'gene_count': 1, 'publications': []},
#  'ENDOU': {'gene_count': 1, 'publications': []},
#  'PRF1': {'gene_count': 1, 'publications': []},
#  'TNF': {'gene_count': 1, 'publications': []},
#  'MAVS': {'gene_count': 1, 'publications': []},
#  'C11orf74': {'gene_count': 1, 'publications': []},
#  'TAPBP': {'gene_count': 1, 'publications': []},
#  'MARK3': {'gene_count': 1, 'publications': []},
#  'IL10': {'gene_count': 1, 'publications': []},
#  'MED12L': {'gene_count': 1, 'publications': []},
#  'HFE': {'gene_count': 1, 'publications': []},
#  'AC097637.1': {'gene_count': 1, 'publications': []},
#  'PARP14': {'gene_count': 1, 'publications': []},
#  'MME': {'gene_count': 1, 'publications': []},
#  'AGTR1': {'gene_count': 1, 'publications': []},
#  'ERVW-1': {'gene_count': 1, 'publications': []},
#  'CD200': {'gene_count': 1, 'publications': []},
#  'ABHD6': {'gene_count': 1, 'publications': []},
#  'TAAR9': {'gene_count': 1, 'publications': []},
#  'COX18': {'gene_count': 1, 'publications': []},
#  'CRIP2': {'gene_count': 1, 'publications': []},
#  'RAD17': {'gene_count': 1, 'publications': []},
#  'ABL2': {'gene_count': 1, 'publications': []},
#  'LY6E': {'gene_count': 1, 'publications': []},
#  'EIF3F': {'gene_count': 1, 'publications': []},
#  'CASP1': {'gene_count': 1, 'publications': []},
#  'FCGR3B': {'gene_count': 1, 'publications': []},
#  'KIRREL3': {'gene_count': 1, 'publications': []},
#  'CNTN5': {'gene_count': 1, 'publications': []},
#  'OMP': {'gene_count': 1, 'publications': []},
#  'CD19': {'gene_count': 1, 'publications': []},
#  'KLRC1': {'gene_count': 1, 'publications': []},
#  'TLR5': {'gene_count': 1, 'publications': []},
#  'NKRF': {'gene_count': 1, 'publications': []},
#  'MIXL1': {'gene_count': 1, 'publications': []},
#  'CMIP': {'gene_count': 1, 'publications': []},
#  'TAS2R38': {'gene_count': 1, 'publications': []},
#  'GPR84': {'gene_count': 1, 'publications': []},
#  'ITGB3': {'gene_count': 1, 'publications': []},
#  'ITGAX': {'gene_count': 1, 'publications': []},
#  'OBBP2': {'gene_count': 1, 'publications': []},
#  'CTRL': {'gene_count': 1, 'publications': []},
#  'ELANE': {'gene_count': 1, 'publications': []},
#  'AC007998.2': {'gene_count': 1, 'publications': []},
#  'TNNT1': {'gene_count': 1, 'publications': []},
#  'TNFSF14': {'gene_count': 1, 'publications': []},
#  'KLK15': {'gene_count': 1, 'publications': []},
#  'CD33L2': {'gene_count': 1, 'publications': []},
#  'IRF3': {'gene_count': 1, 'publications': []},
#  'SARS2': {'gene_count': 1, 'publications': []},
#  'NELFCD': {'gene_count': 1, 'publications': []},
#  'CCL5': {'gene_count': 1, 'publications': []},
#  'CWC15': {'gene_count': 1, 'publications': []},
#  'SIRT5': {'gene_count': 1, 'publications': []},
#  'CCL3': {'gene_count': 1, 'publications': []},
#  'TMPRSS4': {'gene_count': 1, 'publications': []},
#  'ABCB1': {'gene_count': 1, 'publications': []},
#  'IGHV4-38-2': {'gene_count': 1, 'publications': []},
#  'VEGFA': {'gene_count': 1, 'publications': []},
#  'SLC1A7': {'gene_count': 1, 'publications': []},
#  'SEC14L2': {'gene_count': 1, 'publications': []},
#  'ECSCR': {'gene_count': 1, 'publications': []},
#  'IGHV3-15': {'gene_count': 1, 'publications': []},
#  'SEPT2': {'gene_count': 1, 'publications': []},
#  'ADORA2A': {'gene_count': 1, 'publications': []},
#  'NCAM1': {'gene_count': 1, 'publications': []},
#  'SLC9A7': {'gene_count': 1, 'publications': []},
#  'NEFL': {'gene_count': 1, 'publications': []},
#  'CCL4': {'gene_count': 1, 'publications': []},
#  'FURIN': {'gene_count': 1, 'publications': []},
#  'BTK': {'gene_count': 1, 'publications': []},
#  'APELA': {'gene_count': 1, 'publications': []},
#  'IFITM2': {'gene_count': 1, 'publications': []},
#  'MUC1': {'gene_count': 1, 'publications': []},
#  'PRSS3P2': {'gene_count': 1, 'publications': []},
#  'WASH1': {'gene_count': 1, 'publications': []},
#  'SNORA81': {'gene_count': 1, 'publications': []},
#  'MIR1267': {'gene_count': 1, 'publications': []},
#  'MIR1307': {'gene_count': 1, 'publications': []},
#  'TH': {'gene_count': 1, 'publications': []},
#  'SON': {'gene_count': 1, 'publications': []},
#  'MARS1': {'gene_count': 1, 'publications': []},
#  'POR': {'gene_count': 1, 'publications': []},
#  'ABO': {'gene_count': 1, 'publications': []}}

# %% [markdown]
# ## 3. Get Top Genes Related to Disease through 1 Intermediate Node

# %%
# get results for disease -> any node type -> gene
disease2 = ht.query("severe acute respiratory syndrome")['Disease'][0]
disease_to_all_nodes_to_genes = predict_many([disease, disease2],['Gene'], ALL_NODE_TYPES)
disease_to_all_nodes_to_genes.head()
# Out:
# Running: COVID-19 --> intermediate type Gene --> output type Gene
# Running: COVID-19 --> intermediate type SequenceVariant --> output type Gene
# Running: COVID-19 --> intermediate type ChemicalSubstance --> output type Gene
# API 5.1 pharos failed
# Running: COVID-19 --> intermediate type Disease --> output type Gene
# Running: COVID-19 --> intermediate type MolecularActivity --> output type Gene
# Running: COVID-19 --> intermediate type BiologicalProcess --> output type Gene
# Running: COVID-19 --> intermediate type CellularComponent --> output type Gene
# Running: COVID-19 --> intermediate type Pathway --> output type Gene
# Running: COVID-19 --> intermediate type AnatomicalEntity --> output type Gene
# Running: COVID-19 --> intermediate type PhenotypicFeature --> output type Gene
# Running: severe acute respiratory syndrome --> intermediate type Gene --> output type Gene
# API 3.1 cord_gene failed
# API 1.2 semmed_gene failed
# API 1.4 semmed_gene failed
# API 1.3 semmed_gene failed
# API 1.7 semmed_gene failed
# API 1.5 semmed_gene failed
# API 1.6 semmed_gene failed
# API 1.8 semmed_gene failed
# API 2.1 mygene failed
# API 1.9 semmed_gene failed
# API 1.10 semmed_gene failed
# API 1.1 semmed_gene failed
# Running: severe acute respiratory syndrome --> intermediate type SequenceVariant --> output type Gene
# Running: severe acute respiratory syndrome --> intermediate type ChemicalSubstance --> output type Gene
# API 6.1 pharos failed
# severe acute respiratory syndrome --> intermediate type ChemicalSubstance --> output type Gene FAILED
# Running: severe acute respiratory syndrome --> intermediate type Disease --> output type Gene
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16342' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:829> wait_for=<Future finished result=[(<AddressFamily.AF_INET: 2>, <SocketKind.SOCK_STREAM: 1>, 6, '', ('54.213.4.93', 443)), (<AddressFamily.AF_INET: 2>, <SocketKind.SOCK_STREAM: 1>, 6, '', ('52.32.231.93', 443)), (<AddressFamily.AF_INET: 2>, <SocketKind.SOCK_STREAM: 1>, 6, '', ('54.191.240.224', 443))]> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16343' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16377' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16344' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16378' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16345' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16379' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16346' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16380' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16347' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16381' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16348' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16382' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16349' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16383' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16350' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16384' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16351' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16385' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16352' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16386' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16353' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16387' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16354' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16388' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16355' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16389' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16356' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16390' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16357' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16391' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16358' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16392' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16359' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16393' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16360' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16394' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16361' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16395' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16362' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16396' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16363' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16397' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16364' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16398' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16365' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16399' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16366' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16400' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16367' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16401' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16368' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16402' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16369' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16403' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16370' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16404' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16371' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16405' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16372' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16406' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16373' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16407' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16374' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16408' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16375' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16409' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-16376' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:815> wait_for=<Task cancelled name='Task-16410' coro=<Event.wait() done, defined at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/locks.py:296>> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Running: severe acute respiratory syndrome --> intermediate type MolecularActivity --> output type Gene
# Running: severe acute respiratory syndrome --> intermediate type BiologicalProcess --> output type Gene
# Running: severe acute respiratory syndrome --> intermediate type CellularComponent --> output type Gene
# Running: severe acute respiratory syndrome --> intermediate type Pathway --> output type Gene
# Running: severe acute respiratory syndrome --> intermediate type AnatomicalEntity --> output type Gene
# Running: severe acute respiratory syndrome --> intermediate type PhenotypicFeature --> output type Gene
#                     input input_type       pred1 pred1_source     pred1_api  \
# 0  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 1  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 2  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 3  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
# 4  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE  DISEASES API
#
#   pred1_pubmed node1_type node1_name       node1_id  \
# 0         None       Gene       CFTR  NCBIGene:1080
# 1         None       Gene       CFTR  NCBIGene:1080
# 2         None       Gene        CD4   NCBIGene:920
# 3         None       Gene      MAPK1  NCBIGene:5594
# 4         None       Gene      MAPK1  NCBIGene:5594
#
#                        pred2 pred2_source        pred2_api      pred2_pubmed  \
# 0       negatively_regulates       SEMMED  SEMMED Gene API           1718277
# 1  physically_interacts_with       SEMMED  SEMMED Gene API  1718277,26542396
# 2  physically_interacts_with       SEMMED  SEMMED Gene API           3110358
# 3    negatively_regulated_by       SEMMED  SEMMED Gene API          17303142
# 4       positively_regulates       SEMMED  SEMMED Gene API           8816389
#
#   output_type output_name      output_id
# 0        Gene    C1704947  UMLS:C1704947
# 1        Gene    C1704947  UMLS:C1704947
# 2        Gene    C1704947  UMLS:C1704947
# 3        Gene    C1704947  UMLS:C1704947
# 4        Gene    C1704947  UMLS:C1704947

# %%
# Save
# %store disease_to_all_nodes_to_genes
# %store -r disease_to_all_nodes_to_genes
# Out:
# Stored 'disease_to_all_nodes_to_genes' (DataFrame)

# %%
list(dict.fromkeys(list(disease_to_all_nodes_to_genes["node1_type"])))
# Out:
# ['Gene',
#  'ChemicalSubstance',
#  'SequenceVariant',
#  'Disease',
#  'MolecularActivity',
#  'BiologicalProcess',
#  'CellularComponent',
#  'AnatomicalEntity',
#  'PhenotypicFeature']

# %%
# remove entries with symptoms as intermediates
indices_with_symptom_intermediates = [i for i, val in enumerate(list(disease_to_all_nodes_to_genes['node1_name'])) if val in disease_symptoms]
disease_to_all_nodes_to_genes = disease_to_all_nodes_to_genes.drop( disease_to_all_nodes_to_genes.index[indices_with_symptom_intermediates])
# remove UMLS entries - not totally gene specific
disease_to_all_nodes_to_genes = disease_to_all_nodes_to_genes[~disease_to_all_nodes_to_genes['output_id'].str.contains('UMLS')]
disease_to_all_nodes_to_genes.head()
# Out:
#                        input input_type       pred1 pred1_source  \
# 4026  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 4027  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 4028  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 4029  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
# 4030  2019 NOVEL CORONAVIRUS    Disease  related_to      DISEASE
#
#          pred1_api pred1_pubmed node1_type node1_name       node1_id  \
# 4026  DISEASES API         None       Gene       CFTR  NCBIGene:1080
# 4027  DISEASES API         None       Gene       CFTR  NCBIGene:1080
# 4028  DISEASES API         None       Gene       CFTR  NCBIGene:1080
# 4029  DISEASES API         None       Gene       CFTR  NCBIGene:1080
# 4030  DISEASES API         None       Gene       CFTR  NCBIGene:1080
#
#                           pred2 pred2_source        pred2_api  \
# 4026              homologous_to         None  MyGene.info API
# 4027       negatively_regulates       SEMMED  SEMMED Gene API
# 4028    positively_regulated_by       SEMMED  SEMMED Gene API
# 4029  physically_interacts_with       SEMMED  SEMMED Gene API
# 4030    negatively_regulated_by       SEMMED  SEMMED Gene API
#
#                                            pred2_pubmed output_type  \
# 4026                                               None        Gene
# 4027  1378393,16162662,16920886,17040873,17053783,17...        Gene
# 4028  10516175,11356184,12842823,15238504,15767295,1...        Gene
# 4029  12208510,15447951,15880796,16093420,16798551,1...        Gene
# 4030  1378393,16162662,16920886,17040873,17053783,17...        Gene
#
#      output_name      output_id
# 4026       88388      MGI:88388
# 4027        CFTR  NCBIGene:1080
# 4028        CFTR  NCBIGene:1080
# 4029        CFTR  NCBIGene:1080
# 4030        CFTR  NCBIGene:1080

# %%
# create dictionary of gene reults whereby each Gene has values for the number of occurrences of the gene in results
# and the number of publications connecting the disease -> intermediates -> gene
disease_to_all_nodes_to_genes_results = {}
disease_to_all_nodes_to_genes_genes = list(disease_to_all_nodes_to_genes["output_name"]) # create list of genes
disease_to_all_nodes_to_genes_genes = list(dict.fromkeys(disease_to_all_nodes_to_genes_genes))  # remove duplicates

for gene in disease_to_all_nodes_to_genes_genes: 
    disease_to_all_nodes_to_genes_results[gene] = {
        'gene_count' : 0,
        'publications': []
    }

for index, row in disease_to_all_nodes_to_genes.iterrows():
    disease_to_all_nodes_to_genes_results[row['output_name']]['gene_count'] = disease_to_all_nodes_to_genes_results[row['output_name']]['gene_count'] + 1
    if(row['pred1_pubmed'] != None): 
        disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] = disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] + row['pred1_pubmed'].split(",")
    if(row['pred2_pubmed'] != None): 
        disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] = disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] + row['pred2_pubmed'].split(",")

disease_to_all_nodes_to_genes_results = dict(sorted(disease_to_all_nodes_to_genes_results.items(), key = lambda x: x[1]['gene_count'], reverse = True))
# disease_to_all_nodes_to_genes_results

for key,value in disease_to_all_nodes_to_genes_results.items(): 
    disease_to_all_nodes_to_genes_results[key]['publications'] = list(dict.fromkeys(disease_to_all_nodes_to_genes_results[key]['publications']))
    
        
# printing top 10   
print("Top 10 Gene Occurrences : ")
{A:N['gene_count'] for (A,N) in [x for x in disease_to_all_nodes_to_genes_results.items()][:10]}
# Out:
# Top 10 Gene Occurrences :
# {'TNF': 1683,
#  'IFNA1': 1043,
#  'CD4': 970,
#  'TP53': 956,
#  'VEGFA': 949,
#  'AKT1': 918,
#  'EGFR': 913,
#  'IL6': 880,
#  'TGFB1': 848,
#  'INS': 810}

# %% [markdown]
# ## 4. Determine Genes to Further Analyze

# %%
# get list of genes based off of "max" gene parameters
disease_top_genes_list = ([A for (A,N) in [x for x in disease_to_gene_results.items()][:max_one_step_genes]]
    + [A for (A,N) in [x for x in disease_to_all_nodes_to_genes_results.items()][:max_two_step_genes]])

disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
disease_top_genes_list
# Out:
# ['CRP',
#  'LZTFL1',
#  'TMPRSS2',
#  'ACE2',
#  'CFTR',
#  'CEACAM7',
#  'CD4',
#  'CPB2',
#  'SIRT4',
#  'APOH',
#  'TMEM14A',
#  'SIRT1',
#  'GADD45B',
#  'MAPK1',
#  'GZMB',
#  'BDKRB1',
#  'OXT',
#  'TBL1X',
#  'ATP12A',
#  'DHODH',
#  'MEFV',
#  'MGA',
#  'PLAT',
#  'EIF3E',
#  'FCGRT',
#  'SGTA',
#  'SERPINE1',
#  'CHMP5',
#  'C5',
#  'MPO',
#  'CSF3',
#  'CCL2',
#  'IL2',
#  'CTSC',
#  'IFNG',
#  'MAPK14',
#  'IL4',
#  'MAPRE3',
#  'TNNT2',
#  'TTR',
#  'LGALSL',
#  'TAS2R10',
#  'ZC3HAV1',
#  'NT5C',
#  'C3',
#  'SH2D3A',
#  'F2RL3',
#  'FGL2',
#  'SGSM3',
#  'SIRT2',
#  'TNF',
#  'IFNA1',
#  'TP53',
#  'VEGFA',
#  'AKT1',
#  'EGFR',
#  'IL6',
#  'TGFB1',
#  'INS',
#  'CAT',
#  'TLR4',
#  'MMP9',
#  'STAT3',
#  'IL10',
#  'APP',
#  'CAMP',
#  'MAPK8',
#  'LEP',
#  'POMC',
#  'FAS',
#  'PIK3CA',
#  'CD40',
#  'CA2',
#  'ALB',
#  'RELA',
#  'CXCR4',
#  'PTEN',
#  'ESR1',
#  'CRK',
#  'CISH',
#  'FOS',
#  'NTRK1',
#  'CCL5',
#  'CCR5',
#  'ITGAM',
#  'MMP2',
#  'AR',
#  'CD44',
#  'MTOR',
#  'CDKN1A',
#  'SOD1',
#  'MYD88',
#  'MYC',
#  'PTPN11',
#  'KIT',
#  'C5AR1',
#  'STAT5A',
#  'TH',
#  'CXCL8',
#  'HSPA4',
#  'ACE',
#  'IL2RA',
#  'TIMP1',
#  'CD14',
#  'TLR3',
#  'SST',
#  'ESR2',
#  'ATM',
#  'PTH',
#  'ICAM1',
#  'ANG',
#  'GRK2',
#  'CD79A',
#  'CDKN2A',
#  'REN',
#  'EGF',
#  'CREBBP',
#  'GABPA',
#  'IL13',
#  'CCR2',
#  'BRCA1',
#  'HMGB1',
#  'TNFRSF1A',
#  'CTLA4',
#  'CD28',
#  'TLR7',
#  'BAX',
#  'RHO',
#  'HGS',
#  'LOX',
#  'IGHE',
#  'MAPT',
#  'PTPRC',
#  'PPARA',
#  'PIK3CB',
#  'PTGS2',
#  'CCND1',
#  'SYK',
#  'HSPA9',
#  'PPIB',
#  'MAPK3',
#  'CXCL10',
#  'PPARG',
#  'AHSA1',
#  'GPI',
#  'RHOA',
#  'BCR',
#  'HIF1A',
#  'STAT1',
#  'HSPA5',
#  'ISG20',
#  'STAT6',
#  'IRF3',
#  'SQSTM1',
#  'CP',
#  'CREB1',
#  'APEX1',
#  'SOCS3',
#  'IL1B',
#  'EPO',
#  'PSMB6',
#  'ERVK-10',
#  'HSPB1',
#  'ADA',
#  'TCEAL1',
#  'HLA-E',
#  'TNFRSF10B',
#  'VCAM1',
#  'EGR1',
#  'CSF2',
#  'CD34',
#  'CTNNB1',
#  'TLR2',
#  'ITGB2',
#  'AHR',
#  'SMAD3',
#  'CCL3',
#  'CD80',
#  'PIK3R1',
#  'CX3CL1',
#  'MSC',
#  'APCS',
#  'TUBB4B',
#  'CD19',
#  'CSH1',
#  'TRIM25',
#  'KITLG',
#  'CD36',
#  'RHOD',
#  'TAT',
#  'IL9',
#  'ELANE',
#  'BIRC3',
#  'UBC',
#  'FOXP3',
#  'H3P16',
#  'ITGAX',
#  'MDM2',
#  'GRAP2',
#  'MICE',
#  'RPSA',
#  'PTPN6',
#  'CCL20',
#  'IGF1',
#  'TF',
#  'S100A9',
#  'HDAC1',
#  'NOD2',
#  'XK',
#  'SP1',
#  'IFI27',
#  'HLA-DRB1',
#  'FYN',
#  'CNR1',
#  'CCK',
#  'VWF',
#  'HSPA8',
#  'CD69',
#  'IL3',
#  'PPBP',
#  'PHB',
#  'KLK3',
#  'NOTCH1',
#  'AGER',
#  'FGFR1',
#  'EIF2AK2',
#  'IKBKG',
#  'CBL',
#  'TFRC',
#  'CD8A',
#  'NCAM1',
#  'SYT1',
#  'NR3C1',
#  'IRF1',
#  'CDK2',
#  'BCL2']

# %% [markdown]
# ## 5. Get Disease Symptoms related to Genes
# Genes -> Symptoms, then filter based on disease symptoms

# %%
# get gene inputs through hint module
gene_inputs = []
for gene in disease_top_genes_list: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        gene_inputs.append(gene_input)
    except: 
        print(gene + ' Failed')

print(gene_inputs)
# Out:
# APP Failed
# [{'NCBIGene': '1401', 'name': 'C-reactive protein', 'SYMBOL': 'CRP', 'UMLS': 'C1413716', 'HGNC': '2367', 'UNIPROTKB': 'P02741', 'ENSEMBL': 'ENSG00000132693', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1401'}, 'display': 'NCBIGene(1401) ENSEMBL(ENSG00000132693) HGNC(2367) UMLS(C1413716) UNIPROTKB(P02741) SYMBOL(CRP)', 'type': 'Gene'}, {'NCBIGene': '54585', 'name': 'leucine zipper transcription factor like 1', 'SYMBOL': 'LZTFL1', 'UMLS': 'C1416946', 'HGNC': '6741', 'UNIPROTKB': 'Q9NQ48', 'ENSEMBL': 'ENSG00000163818', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '54585'}, 'display': 'NCBIGene(54585) ENSEMBL(ENSG00000163818) HGNC(6741) UMLS(C1416946) UNIPROTKB(Q9NQ48) SYMBOL(LZTFL1)', 'type': 'Gene'}, {'NCBIGene': '7113', 'name': 'transmembrane serine protease 2', 'SYMBOL': 'TMPRSS2', 'UMLS': 'C1336641', 'HGNC': '11876', 'UNIPROTKB': 'O15393', 'ENSEMBL': 'ENSG00000184012', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7113'}, 'display': 'NCBIGene(7113) ENSEMBL(ENSG00000184012) HGNC(11876) UMLS(C1336641) UNIPROTKB(O15393) SYMBOL(TMPRSS2)', 'type': 'Gene'}, {'NCBIGene': '59272', 'name': 'angiotensin I converting enzyme 2', 'SYMBOL': 'ACE2', 'UMLS': 'C1422064', 'HGNC': '13557', 'UNIPROTKB': 'Q9BYF1', 'ENSEMBL': 'ENSG00000130234', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'}, 'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)', 'type': 'Gene'}, {'NCBIGene': '1080', 'name': 'CF transmembrane conductance regulator', 'SYMBOL': 'CFTR', 'UMLS': 'C1413365', 'HGNC': '1884', 'UNIPROTKB': 'P13569', 'ENSEMBL': 'ENSG00000001626', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1080'}, 'display': 'NCBIGene(1080) ENSEMBL(ENSG00000001626) HGNC(1884) UMLS(C1413365) UNIPROTKB(P13569) SYMBOL(CFTR)', 'type': 'Gene'}, {'NCBIGene': '1087', 'name': 'CEA cell adhesion molecule 7', 'SYMBOL': 'CEACAM7', 'UMLS': 'C1332745', 'HGNC': '1819', 'UNIPROTKB': 'Q14002', 'ENSEMBL': 'ENSG00000007306', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1087'}, 'display': 'NCBIGene(1087) ENSEMBL(ENSG00000007306) HGNC(1819) UMLS(C1332745) UNIPROTKB(Q14002) SYMBOL(CEACAM7)', 'type': 'Gene'}, {'NCBIGene': '920', 'name': 'CD4 molecule', 'SYMBOL': 'CD4', 'UMLS': 'C1332714', 'HGNC': '1678', 'UNIPROTKB': 'P01730', 'ENSEMBL': 'ENSG00000010610', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '920'}, 'display': 'NCBIGene(920) ENSEMBL(ENSG00000010610) HGNC(1678) UMLS(C1332714) UNIPROTKB(P01730) SYMBOL(CD4)', 'type': 'Gene'}, {'NCBIGene': '1361', 'name': 'carboxypeptidase B2', 'SYMBOL': 'CPB2', 'UMLS': 'C1413666', 'HGNC': '2300', 'UNIPROTKB': 'Q96IY4', 'ENSEMBL': 'ENSG00000080618', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1361'}, 'display': 'NCBIGene(1361) ENSEMBL(ENSG00000080618) HGNC(2300) UMLS(C1413666) UNIPROTKB(Q96IY4) SYMBOL(CPB2)', 'type': 'Gene'}, {'NCBIGene': '23409', 'name': 'sirtuin 4', 'SYMBOL': 'SIRT4', 'UMLS': 'C1423064', 'HGNC': '14932', 'UNIPROTKB': 'Q9Y6E7', 'ENSEMBL': 'ENSG00000089163', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '23409'}, 'display': 'NCBIGene(23409) ENSEMBL(ENSG00000089163) HGNC(14932) UMLS(C1423064) UNIPROTKB(Q9Y6E7) SYMBOL(SIRT4)', 'type': 'Gene'}, {'NCBIGene': '350', 'name': 'apolipoprotein H', 'SYMBOL': 'APOH', 'UMLS': 'C1412484', 'HGNC': '616', 'UNIPROTKB': 'P02749', 'ENSEMBL': 'ENSG00000091583', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '350'}, 'display': 'NCBIGene(350) ENSEMBL(ENSG00000091583) HGNC(616) UMLS(C1412484) UNIPROTKB(P02749) SYMBOL(APOH)', 'type': 'Gene'}, {'NCBIGene': '28978', 'name': 'transmembrane protein 14A', 'SYMBOL': 'TMEM14A', 'UMLS': 'C1427297', 'HGNC': '21076', 'UNIPROTKB': 'Q9Y6G1', 'ENSEMBL': 'ENSG00000096092', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '28978'}, 'display': 'NCBIGene(28978) ENSEMBL(ENSG00000096092) HGNC(21076) UMLS(C1427297) UNIPROTKB(Q9Y6G1) SY ...

# %%
# get genes to symptoms, which could be represented as a phenotypic feature, biological process, or diesase
genes_to_symptoms = predict_many(gene_inputs, ['PhenotypicFeature','BiologicalProcess','Disease'])
print(genes_to_symptoms.shape)
genes_to_symptoms.head()
# Out:
# Running: C-reactive protein --> output type PhenotypicFeature
# Running: C-reactive protein --> output type BiologicalProcess
# Running: C-reactive protein --> output type Disease
# Running: leucine zipper transcription factor like 1 --> output type PhenotypicFeature
# Running: leucine zipper transcription factor like 1 --> output type BiologicalProcess
# Running: leucine zipper transcription factor like 1 --> output type Disease
# Running: transmembrane serine protease 2 --> output type PhenotypicFeature
# Running: transmembrane serine protease 2 --> output type BiologicalProcess
# Running: transmembrane serine protease 2 --> output type Disease
# Running: angiotensin I converting enzyme 2 --> output type PhenotypicFeature
# Running: angiotensin I converting enzyme 2 --> output type BiologicalProcess
# Running: angiotensin I converting enzyme 2 --> output type Disease
# Running: CF transmembrane conductance regulator --> output type PhenotypicFeature
# Running: CF transmembrane conductance regulator --> output type BiologicalProcess
# Running: CF transmembrane conductance regulator --> output type Disease
# Running: CEA cell adhesion molecule 7 --> output type PhenotypicFeature
# Running: CEA cell adhesion molecule 7 --> output type BiologicalProcess
# Running: CEA cell adhesion molecule 7 --> output type Disease
# Running: CD4 molecule --> output type PhenotypicFeature
# Running: CD4 molecule --> output type BiologicalProcess
# Running: CD4 molecule --> output type Disease
# Running: carboxypeptidase B2 --> output type PhenotypicFeature
# Running: carboxypeptidase B2 --> output type BiologicalProcess
# Running: carboxypeptidase B2 --> output type Disease
# Running: sirtuin 4 --> output type PhenotypicFeature
# Running: sirtuin 4 --> output type BiologicalProcess
# Running: sirtuin 4 --> output type Disease
# Running: apolipoprotein H --> output type PhenotypicFeature
# Running: apolipoprotein H --> output type BiologicalProcess
# Running: apolipoprotein H --> output type Disease
# Running: transmembrane protein 14A --> output type PhenotypicFeature
# Running: transmembrane protein 14A --> output type BiologicalProcess
# Running: transmembrane protein 14A --> output type Disease
# Running: sirtuin 1 --> output type PhenotypicFeature
# Running: sirtuin 1 --> output type BiologicalProcess
# Running: sirtuin 1 --> output type Disease
# Running: growth arrest and DNA damage inducible beta --> output type PhenotypicFeature
# Running: growth arrest and DNA damage inducible beta --> output type BiologicalProcess
# Running: growth arrest and DNA damage inducible beta --> output type Disease
# Running: mitogen-activated protein kinase 1 --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 1 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 1 --> output type Disease
# Running: granzyme B --> output type PhenotypicFeature
# Running: granzyme B --> output type BiologicalProcess
# Running: granzyme B --> output type Disease
# Running: bradykinin receptor B1 --> output type PhenotypicFeature
# Running: bradykinin receptor B1 --> output type BiologicalProcess
# Running: bradykinin receptor B1 --> output type Disease
# Running: oxytocin/neurophysin I prepropeptide --> output type PhenotypicFeature
# Running: oxytocin/neurophysin I prepropeptide --> output type BiologicalProcess
# Running: oxytocin/neurophysin I prepropeptide --> output type Disease
# Running: transducin beta like 1 X-linked --> output type PhenotypicFeature
# Running: transducin beta like 1 X-linked --> output type BiologicalProcess
# Running: transducin beta like 1 X-linked --> output type Disease
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type PhenotypicFeature
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type BiologicalProcess
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type Disease
# Running: dihydroorotate dehydrogenase (quinone) --> output type PhenotypicFeature
# Running: dihydroorotate dehydrogenase (quinone) --> output type BiologicalProcess
# Running: dihydroorotate dehydrogenase (quinone) --> output type Disease
# Running: MEFV innate immuity regulator, pyrin --> output type PhenotypicFeature
# Running: MEFV innate immuity regulator, pyrin --> output type BiologicalProcess
# Running: MEFV innate immuity regulator, pyrin --> output type Disease
# Running: MAX dimerization protein MGA --> output type PhenotypicFeature
# Running: MAX dimerization protein MGA --> output type BiologicalProcess
# Running: MAX dimerization protein MGA --> output type Disease
# Running: plasminogen activator, tissue type --> output type PhenotypicFeature
# Running: plasminogen activator, tissue type --> output type BiologicalProcess
# Running: plasminogen activator, tissue type --> output type Disease
# Running: eukaryotic translation initiation factor 3 subunit E --> output type PhenotypicFeature
# Running: eukaryotic translation initiation factor 3 subunit E --> output type BiologicalProcess
# Running: eukaryotic translation initiation factor 3 subunit E --> output type Disease
# Running: Fc fragment of IgG receptor and transporter --> output type PhenotypicFeature
# Running: Fc fragment of IgG receptor and transporter --> output type BiologicalProcess
# Running: Fc fragment of IgG receptor and transporter --> output type Disease
# Running: small glutamine rich tetratricopeptide repeat containing alpha --> output type PhenotypicFeature
# Running: small glutamine rich tetratricopeptide repeat containing alpha --> output type BiologicalProcess
# Running: small glutamine rich tetratricopeptide repeat containing alpha --> output type Disease
# Running: serpin family E member 1 --> output type PhenotypicFeature
# Running: serpin family E member 1 --> output type BiologicalProcess
# Running: serpin family E member 1 --> output type Disease
# Running: charged multivesicular body protein 5 --> output type PhenotypicFeature
# Running: charged multivesicular body protein 5 --> output type BiologicalProcess
# Running: charged multivesicular body protein 5 --> output type Disease
# Running: complement C5 --> output type PhenotypicFeature
# Running: complement C5 --> output type BiologicalProcess
# Running: complement C5 --> output type Disease
# Running: myeloperoxidase --> output type PhenotypicFeature
# Running: myeloperoxidase --> output type BiologicalProcess
# Running: myeloperoxidase --> output type Disease
# Running: colony stimulating factor 3 --> output type PhenotypicFeature
# Running: colony stimulating factor 3 --> output type BiologicalProcess
# Running: colony stimulating factor 3 --> output type Disease
# Running: C-C motif chemokine ligand 2 --> output type PhenotypicFeature
# Running: C-C motif chemokine ligand 2 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 2 --> output type Disease
# Running: interleukin 2 --> output type PhenotypicFeature
# Running: interleukin 2 --> output type BiologicalProcess
# Running: interleukin 2 --> output type Disease
# Running: cathepsin C --> output type PhenotypicFeature
# Running: cathepsin C --> output type BiologicalProcess
# Running: cathepsin C --> output type Disease
# Running: interferon gamma --> output type PhenotypicFeature
# Running: interferon gamma --> output type BiologicalProcess
# Running: interferon gamma --> output type Disease
# Running: mitogen-activated protein kinase 14 --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 14 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 14 --> output type Disease
# Running: interleukin 4 --> output type PhenotypicFeature
# Running: interleukin 4 --> output type BiologicalProcess
# Running: interleukin 4 --> output type Disease
# Running: microtubule associated protein RP/EB family member 3 --> output type PhenotypicFeature
# Running: microtubule associated protein RP/EB family member 3 --> output type BiologicalProcess
# Running: microtubule associated protein RP/EB family member 3 --> output type Disease
# Running: troponin T2, cardiac type --> output type PhenotypicFeature
# Running: troponin T2, cardiac type --> output type BiologicalProcess
# Running: troponin T2, cardiac type --> output type Disease
# Running: transthyretin --> output type PhenotypicFeature
# Running: transthyretin --> output type BiologicalProcess
# Running: transthyretin --> output type Disease
# Running: galectin like --> output type PhenotypicFeature
# Running: galectin like --> output type BiologicalProcess
# Running: galectin like --> output type Disease
# Running: taste 2 receptor member 10 --> output type PhenotypicFeature
# Running: taste 2 receptor member 10 --> output type BiologicalProcess
# Running: taste 2 receptor member 10 --> output type Disease
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type PhenotypicFeature
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type BiologicalProcess
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type Disease
# Running: 5', 3'-nucleotidase, cytosolic --> output type PhenotypicFeature
# Running: 5', 3'-nucleotidase, cytosolic --> output type BiologicalProcess
# Running: 5', 3'-nucleotidase, cytosolic --> output type Disease
# Running: complement C3 --> output type PhenotypicFeature
# Running: complement C3 --> output type BiologicalProcess
# Running: complement C3 --> output type Disease
# Running: SH2 domain containing 3A --> output type PhenotypicFeature
# Running: SH2 domain containing 3A --> output type BiologicalProcess
# Running: SH2 domain containing 3A --> output type Disease
# Running: F2R like thrombin or trypsin receptor 3 --> output type PhenotypicFeature
# Running: F2R like thrombin or trypsin receptor 3 --> output type BiologicalProcess
# Running: F2R like thrombin or trypsin receptor 3 --> output type Disease
# Running: fibrinogen like 2 --> output type PhenotypicFeature
# Running: fibrinogen like 2 --> output type BiologicalProcess
# Running: fibrinogen like 2 --> output type Disease
# Running: small G protein signaling modulator 3 --> output type PhenotypicFeature
# Running: small G protein signaling modulator 3 --> output type BiologicalProcess
# Running: small G protein signaling modulator 3 --> output type Disease
# Running: sirtuin 2 --> output type PhenotypicFeature
# Running: sirtuin 2 --> output type BiologicalProcess
# Running: sirtuin 2 --> output type Disease
# Running: tumor necrosis factor --> output type PhenotypicFeature
# Running: tumor necrosis factor --> output type BiologicalProcess
# Running: tumor necrosis factor --> output type Disease
# Running: interferon alpha 1 --> output type PhenotypicFeature
# Running: interferon alpha 1 --> output type BiologicalProcess
# Running: interferon alpha 1 --> output type Disease
# Running: tumor protein p53 --> output type PhenotypicFeature
# Running: tumor protein p53 --> output type BiologicalProcess
# Running: tumor protein p53 --> output type Disease
# Running: vascular endothelial growth factor A --> output type PhenotypicFeature
# Running: vascular endothelial growth factor A --> output type BiologicalProcess
# Running: vascular endothelial growth factor A --> output type Disease
# Running: AKT serine/threonine kinase 1 --> output type PhenotypicFeature
# Running: AKT serine/threonine kinase 1 --> output type BiologicalProcess
# Running: AKT serine/threonine kinase 1 --> output type Disease
# Running: epidermal growth factor receptor --> output type PhenotypicFeature
# Running: epidermal growth factor receptor --> output type BiologicalProcess
# Running: epidermal growth factor receptor --> output type Disease
# Running: interleukin 6 --> output type PhenotypicFeature
# Running: interleukin 6 --> output type BiologicalProcess
# Running: interleukin 6 --> output type Disease
# Running: transforming growth factor beta 1 --> output type PhenotypicFeature
# Running: transforming growth factor beta 1 --> output type BiologicalProcess
# Running: transforming growth factor beta 1 --> output type Disease
# Running: insulin --> output type PhenotypicFeature
# Running: insulin --> output type BiologicalProcess
# Running: insulin --> output type Disease
# Running: catalase --> output type PhenotypicFeature
# Running: catalase --> output type BiologicalProcess
# Running: catalase --> output type Disease
# Running: toll like receptor 4 --> output type PhenotypicFeature
# Running: toll like receptor 4 --> output type BiologicalProcess
# Running: toll like receptor 4 --> output type Disease
# Running: matrix metallopeptidase 9 --> output type PhenotypicFeature
# Running: matrix metallopeptidase 9 --> output type BiologicalProcess
# Running: matrix metallopeptidase 9 --> output type Disease
# Running: signal transducer and activator of transcription 3 --> output type PhenotypicFeature
# Running: signal transducer and activator of transcription 3 --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 3 --> output type Disease
# Running: interleukin 10 --> output type PhenotypicFeature
# Running: interleukin 10 --> output type BiologicalProcess
# Running: interleukin 10 --> output type Disease
# Running: cathelicidin antimicrobial peptide --> output type PhenotypicFeature
# Running: cathelicidin antimicrobial peptide --> output type BiologicalProcess
# Running: cathelicidin antimicrobial peptide --> output type Disease
# Running: mitogen-activated protein kinase 8 --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 8 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 8 --> output type Disease
# Running: leptin --> output type PhenotypicFeature
# Running: leptin --> output type BiologicalProcess
# Running: leptin --> output type Disease
# Running: proopiomelanocortin --> output type PhenotypicFeature
# Running: proopiomelanocortin --> output type BiologicalProcess
# Running: proopiomelanocortin --> output type Disease
# Running: Fas cell surface death receptor --> output type PhenotypicFeature
# Running: Fas cell surface death receptor --> output type BiologicalProcess
# Running: Fas cell surface death receptor --> output type Disease
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type PhenotypicFeature
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type BiologicalProcess
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type Disease
# Running: CD40 molecule --> output type PhenotypicFeature
# Running: CD40 molecule --> output type BiologicalProcess
# Running: CD40 molecule --> output type Disease
# Running: carbonic anhydrase 2 --> output type PhenotypicFeature
# Running: carbonic anhydrase 2 --> output type BiologicalProcess
# Running: carbonic anhydrase 2 --> output type Disease
# Running: albumin --> output type PhenotypicFeature
# Running: albumin --> output type BiologicalProcess
# Running: albumin --> output type Disease
# Running: RELA proto-oncogene, NF-kB subunit --> output type PhenotypicFeature
# Running: RELA proto-oncogene, NF-kB subunit --> output type BiologicalProcess
# Running: RELA proto-oncogene, NF-kB subunit --> output type Disease
# Running: C-X-C motif chemokine receptor 4 --> output type PhenotypicFeature
# Running: C-X-C motif chemokine receptor 4 --> output type BiologicalProcess
# Running: C-X-C motif chemokine receptor 4 --> output type Disease
# Running: phosphatase and tensin homolog --> output type PhenotypicFeature
# Running: phosphatase and tensin homolog --> output type BiologicalProcess
# Running: phosphatase and tensin homolog --> output type Disease
# Running: estrogen receptor 1 --> output type PhenotypicFeature
# Running: estrogen receptor 1 --> output type BiologicalProcess
# Running: estrogen receptor 1 --> output type Disease
# Running: CRK proto-oncogene, adaptor protein --> output type PhenotypicFeature
# Running: CRK proto-oncogene, adaptor protein --> output type BiologicalProcess
# Running: CRK proto-oncogene, adaptor protein --> output type Disease
# Running: cytokine inducible SH2 containing protein --> output type PhenotypicFeature
# Running: cytokine inducible SH2 containing protein --> output type BiologicalProcess
# Running: cytokine inducible SH2 containing protein --> output type Disease
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type PhenotypicFeature
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type BiologicalProcess
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type Disease
# Running: neurotrophic receptor tyrosine kinase 1 --> output type PhenotypicFeature
# Running: neurotrophic receptor tyrosine kinase 1 --> output type BiologicalProcess
# Running: neurotrophic receptor tyrosine kinase 1 --> output type Disease
# Running: C-C motif chemokine ligand 5 --> output type PhenotypicFeature
# Running: C-C motif chemokine ligand 5 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 5 --> output type Disease
# Running: C-C motif chemokine receptor 5 --> output type PhenotypicFeature
# Running: C-C motif chemokine receptor 5 --> output type BiologicalProcess
# Running: C-C motif chemokine receptor 5 --> output type Disease
# Running: integrin subunit alpha M --> output type PhenotypicFeature
# Running: integrin subunit alpha M --> output type BiologicalProcess
# Running: integrin subunit alpha M --> output type Disease
# Running: matrix metallopeptidase 2 --> output type PhenotypicFeature
# Running: matrix metallopeptidase 2 --> output type BiologicalProcess
# Running: matrix metallopeptidase 2 --> output type Disease
# Running: androgen receptor --> output type PhenotypicFeature
# Running: androgen receptor --> output type BiologicalProcess
# Running: androgen receptor --> output type Disease
# Running: CD44 molecule (Indian blood group) --> output type PhenotypicFeature
# Running: CD44 molecule (Indian blood group) --> output type BiologicalProcess
# Running: CD44 molecule (Indian blood group) --> output type Disease
# Running: mechanistic target of rapamycin kinase --> output type PhenotypicFeature
# Running: mechanistic target of rapamycin kinase --> output type BiologicalProcess
# Running: mechanistic target of rapamycin kinase --> output type Disease
# Running: cyclin dependent kinase inhibitor 1A --> output type PhenotypicFeature
# Running: cyclin dependent kinase inhibitor 1A --> output type BiologicalProcess
# Running: cyclin dependent kinase inhibitor 1A --> output type Disease
# Running: superoxide dismutase 1 --> output type PhenotypicFeature
# Running: superoxide dismutase 1 --> output type BiologicalProcess
# Running: superoxide dismutase 1 --> output type Disease
# Running: MYD88 innate immune signal transduction adaptor --> output type PhenotypicFeature
# Running: MYD88 innate immune signal transduction adaptor --> output type BiologicalProcess
# Running: MYD88 innate immune signal transduction adaptor --> output type Disease
# Running: MYC proto-oncogene, bHLH transcription factor --> output type PhenotypicFeature
# Running: MYC proto-oncogene, bHLH transcription factor --> output type BiologicalProcess
# Running: MYC proto-oncogene, bHLH transcription factor --> output type Disease
# Running: protein tyrosine phosphatase non-receptor type 11 --> output type PhenotypicFeature
# Running: protein tyrosine phosphatase non-receptor type 11 --> output type BiologicalProcess
# Running: protein tyrosine phosphatase non-receptor type 11 --> output type Disease
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type PhenotypicFeature
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type BiologicalProcess
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type Disease
# Running: complement C5a receptor 1 --> output type PhenotypicFeature
# Running: complement C5a receptor 1 --> output type BiologicalProcess
# Running: complement C5a receptor 1 --> output type Disease
# Running: signal transducer and activator of transcription 5A --> output type PhenotypicFeature
# Running: signal transducer and activator of transcription 5A --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 5A --> output type Disease
# Running: tyrosine hydroxylase --> output type PhenotypicFeature
# Running: tyrosine hydroxylase --> output type BiologicalProcess
# Running: tyrosine hydroxylase --> output type Disease
# Running: C-X-C motif chemokine ligand 8 --> output type PhenotypicFeature
# Running: C-X-C motif chemokine ligand 8 --> output type BiologicalProcess
# Running: C-X-C motif chemokine ligand 8 --> output type Disease
# Running: heat shock protein family A (Hsp70) member 4 --> output type PhenotypicFeature
# Running: heat shock protein family A (Hsp70) member 4 --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 4 --> output type Disease
# Running: angiotensin I converting enzyme --> output type PhenotypicFeature
# Running: angiotensin I converting enzyme --> output type BiologicalProcess
# Running: angiotensin I converting enzyme --> output type Disease
# Running: interleukin 2 receptor subunit alpha --> output type PhenotypicFeature
# Running: interleukin 2 receptor subunit alpha --> output type BiologicalProcess
# Running: interleukin 2 receptor subunit alpha --> output type Disease
# Running: TIMP metallopeptidase inhibitor 1 --> output type PhenotypicFeature
# Running: TIMP metallopeptidase inhibitor 1 --> output type BiologicalProcess
# Running: TIMP metallopeptidase inhibitor 1 --> output type Disease
# Running: CD14 molecule --> output type PhenotypicFeature
# Running: CD14 molecule --> output type BiologicalProcess
# Running: CD14 molecule --> output type Disease
# Running: toll like receptor 3 --> output type PhenotypicFeature
# Running: toll like receptor 3 --> output type BiologicalProcess
# Running: toll like receptor 3 --> output type Disease
# Running: somatostatin --> output type PhenotypicFeature
# Running: somatostatin --> output type BiologicalProcess
# Running: somatostatin --> output type Disease
# Running: estrogen receptor 2 --> output type PhenotypicFeature
# Running: estrogen receptor 2 --> output type BiologicalProcess
# Running: estrogen receptor 2 --> output type Disease
# Running: ATM serine/threonine kinase --> output type PhenotypicFeature
# Running: ATM serine/threonine kinase --> output type BiologicalProcess
# Running: ATM serine/threonine kinase --> output type Disease
# Running: parathyroid hormone --> output type PhenotypicFeature
# Running: parathyroid hormone --> output type BiologicalProcess
# Running: parathyroid hormone --> output type Disease
# Running: intercellular adhesion molecule 1 --> output type PhenotypicFeature
# Running: intercellular adhesion molecule 1 --> output type BiologicalProcess
# Running: intercellular adhesion molecule 1 --> output type Disease
# Running: angiogenin --> output type PhenotypicFeature
# Running: angiogenin --> output type BiologicalProcess
# Running: angiogenin --> output type Disease
# Running: G protein-coupled receptor kinase 2 --> output type PhenotypicFeature
# Running: G protein-coupled receptor kinase 2 --> output type BiologicalProcess
# Running: G protein-coupled receptor kinase 2 --> output type Disease
# Running: CD79a molecule --> output type PhenotypicFeature
# Running: CD79a molecule --> output type BiologicalProcess
# Running: CD79a molecule --> output type Disease
# Running: cyclin dependent kinase inhibitor 2A --> output type PhenotypicFeature
# Running: cyclin dependent kinase inhibitor 2A --> output type BiologicalProcess
# Running: cyclin dependent kinase inhibitor 2A --> output type Disease
# Running: renin --> output type PhenotypicFeature
# Running: renin --> output type BiologicalProcess
# Running: renin --> output type Disease
# Running: epidermal growth factor --> output type PhenotypicFeature
# Running: epidermal growth factor --> output type BiologicalProcess
# Running: epidermal growth factor --> output type Disease
# Running: CREB binding protein --> output type PhenotypicFeature
# Running: CREB binding protein --> output type BiologicalProcess
# Running: CREB binding protein --> output type Disease
# Running: GA binding protein transcription factor subunit alpha --> output type PhenotypicFeature
# Running: GA binding protein transcription factor subunit alpha --> output type BiologicalProcess
# Running: GA binding protein transcription factor subunit alpha --> output type Disease
# Running: interleukin 13 --> output type PhenotypicFeature
# Running: interleukin 13 --> output type BiologicalProcess
# Running: interleukin 13 --> output type Disease
# Running: C-C motif chemokine receptor 2 --> output type PhenotypicFeature
# Running: C-C motif chemokine receptor 2 --> output type BiologicalProcess
# Running: C-C motif chemokine receptor 2 --> output type Disease
# Running: BRCA1 DNA repair associated --> output type PhenotypicFeature
# Running: BRCA1 DNA repair associated --> output type BiologicalProcess
# Running: BRCA1 DNA repair associated --> output type Disease
# Running: high mobility group box 1 --> output type PhenotypicFeature
# Running: high mobility group box 1 --> output type BiologicalProcess
# Running: high mobility group box 1 --> output type Disease
# Running: TNF receptor superfamily member 1A --> output type PhenotypicFeature
# Running: TNF receptor superfamily member 1A --> output type BiologicalProcess
# Running: TNF receptor superfamily member 1A --> output type Disease
# Running: cytotoxic T-lymphocyte associated protein 4 --> output type PhenotypicFeature
# Running: cytotoxic T-lymphocyte associated protein 4 --> output type BiologicalProcess
# Running: cytotoxic T-lymphocyte associated protein 4 --> output type Disease
# Running: CD28 molecule --> output type PhenotypicFeature
# Running: CD28 molecule --> output type BiologicalProcess
# Running: CD28 molecule --> output type Disease
# Running: toll like receptor 7 --> output type PhenotypicFeature
# Running: toll like receptor 7 --> output type BiologicalProcess
# Running: toll like receptor 7 --> output type Disease
# Running: BCL2 associated X, apoptosis regulator --> output type PhenotypicFeature
# Running: BCL2 associated X, apoptosis regulator --> output type BiologicalProcess
# Running: BCL2 associated X, apoptosis regulator --> output type Disease
# Running: rhodopsin --> output type PhenotypicFeature
# Running: rhodopsin --> output type BiologicalProcess
# Running: rhodopsin --> output type Disease
# Running: hepatocyte growth factor-regulated tyrosine kinase substrate --> output type PhenotypicFeature
# Running: hepatocyte growth factor-regulated tyrosine kinase substrate --> output type BiologicalProcess
# Running: hepatocyte growth factor-regulated tyrosine kinase substrate --> output type Disease
# Running: lysyl oxidase --> output type PhenotypicFeature
# Running: lysyl oxidase --> output type BiologicalProcess
# Running: lysyl oxidase --> output type Disease
# Running: immunoglobulin heavy constant epsilon --> output type PhenotypicFeature
# Running: immunoglobulin heavy constant epsilon --> output type BiologicalProcess
# Running: immunoglobulin heavy constant epsilon --> output type Disease
# Running: microtubule associated protein tau --> output type PhenotypicFeature
# Running: microtubule associated protein tau --> output type BiologicalProcess
# Running: microtubule associated protein tau --> output type Disease
# Running: protein tyrosine phosphatase receptor type C --> output type PhenotypicFeature
# Running: protein tyrosine phosphatase receptor type C --> output type BiologicalProcess
# Running: protein tyrosine phosphatase receptor type C --> output type Disease
# Running: peroxisome proliferator activated receptor alpha --> output type PhenotypicFeature
# Running: peroxisome proliferator activated receptor alpha --> output type BiologicalProcess
# Running: peroxisome proliferator activated receptor alpha --> output type Disease
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit beta --> output type PhenotypicFeature
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit beta --> output type BiologicalProcess
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit beta --> output type Disease
# Running: prostaglandin-endoperoxide synthase 2 --> output type PhenotypicFeature
# Running: prostaglandin-endoperoxide synthase 2 --> output type BiologicalProcess
# Running: prostaglandin-endoperoxide synthase 2 --> output type Disease
# Running: cyclin D1 --> output type PhenotypicFeature
# Running: cyclin D1 --> output type BiologicalProcess
# Running: cyclin D1 --> output type Disease
# Running: spleen associated tyrosine kinase --> output type PhenotypicFeature
# Running: spleen associated tyrosine kinase --> output type BiologicalProcess
# Running: spleen associated tyrosine kinase --> output type Disease
# Running: heat shock protein family A (Hsp70) member 9 --> output type PhenotypicFeature
# Running: heat shock protein family A (Hsp70) member 9 --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 9 --> output type Disease
# Running: peptidylprolyl isomerase B --> output type PhenotypicFeature
# Running: peptidylprolyl isomerase B --> output type BiologicalProcess
# Running: peptidylprolyl isomerase B --> output type Disease
# Running: mitogen-activated protein kinase 3 --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 3 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 3 --> output type Disease
# Running: C-X-C motif chemokine ligand 10 --> output type PhenotypicFeature
# Running: C-X-C motif chemokine ligand 10 --> output type BiologicalProcess
# Running: C-X-C motif chemokine ligand 10 --> output type Disease
# Running: peroxisome proliferator activated receptor gamma --> output type PhenotypicFeature
# Running: peroxisome proliferator activated receptor gamma --> output type BiologicalProcess
# Running: peroxisome proliferator activated receptor gamma --> output type Disease
# Running: activator of HSP90 ATPase activity 1 --> output type PhenotypicFeature
# Running: activator of HSP90 ATPase activity 1 --> output type BiologicalProcess
# Running: activator of HSP90 ATPase activity 1 --> output type Disease
# Running: glucose-6-phosphate isomerase --> output type PhenotypicFeature
# Running: glucose-6-phosphate isomerase --> output type BiologicalProcess
# Running: glucose-6-phosphate isomerase --> output type Disease
# Running: ras homolog family member A --> output type PhenotypicFeature
# Running: ras homolog family member A --> output type BiologicalProcess
# Running: ras homolog family member A --> output type Disease
# Running: BCR activator of RhoGEF and GTPase --> output type PhenotypicFeature
# Running: BCR activator of RhoGEF and GTPase --> output type BiologicalProcess
# Running: BCR activator of RhoGEF and GTPase --> output type Disease
# Running: hypoxia inducible factor 1 subunit alpha --> output type PhenotypicFeature
# Running: hypoxia inducible factor 1 subunit alpha --> output type BiologicalProcess
# Running: hypoxia inducible factor 1 subunit alpha --> output type Disease
# Running: signal transducer and activator of transcription 1 --> output type PhenotypicFeature
# Running: signal transducer and activator of transcription 1 --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 1 --> output type Disease
# Running: heat shock protein family A (Hsp70) member 5 --> output type PhenotypicFeature
# Running: heat shock protein family A (Hsp70) member 5 --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 5 --> output type Disease
# Running: interferon stimulated exonuclease gene 20 --> output type PhenotypicFeature
# Running: interferon stimulated exonuclease gene 20 --> output type BiologicalProcess
# Running: interferon stimulated exonuclease gene 20 --> output type Disease
# Running: signal transducer and activator of transcription 6 --> output type PhenotypicFeature
# Running: signal transducer and activator of transcription 6 --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 6 --> output type Disease
# Running: interferon regulatory factor 3 --> output type PhenotypicFeature
# Running: interferon regulatory factor 3 --> output type BiologicalProcess
# Running: interferon regulatory factor 3 --> output type Disease
# Running: sequestosome 1 --> output type PhenotypicFeature
# Running: sequestosome 1 --> output type BiologicalProcess
# Running: sequestosome 1 --> output type Disease
# Running: ceruloplasmin --> output type PhenotypicFeature
# Running: ceruloplasmin --> output type BiologicalProcess
# Running: ceruloplasmin --> output type Disease
# Running: cAMP responsive element binding protein 1 --> output type PhenotypicFeature
# Running: cAMP responsive element binding protein 1 --> output type BiologicalProcess
# Running: cAMP responsive element binding protein 1 --> output type Disease
# Running: apurinic/apyrimidinic endodeoxyribonuclease 1 --> output type PhenotypicFeature
# Running: apurinic/apyrimidinic endodeoxyribonuclease 1 --> output type BiologicalProcess
# Running: apurinic/apyrimidinic endodeoxyribonuclease 1 --> output type Disease
# Running: suppressor of cytokine signaling 3 --> output type PhenotypicFeature
# Running: suppressor of cytokine signaling 3 --> output type BiologicalProcess
# Running: suppressor of cytokine signaling 3 --> output type Disease
# Running: interleukin 1 beta --> output type PhenotypicFeature
# Running: interleukin 1 beta --> output type BiologicalProcess
# Running: interleukin 1 beta --> output type Disease
# Running: erythropoietin --> output type PhenotypicFeature
# Running: erythropoietin --> output type BiologicalProcess
# Running: erythropoietin --> output type Disease
# Running: proteasome 20S subunit beta 6 --> output type PhenotypicFeature
# Running: proteasome 20S subunit beta 6 --> output type BiologicalProcess
# Running: proteasome 20S subunit beta 6 --> output type Disease
# Running: endogenous retrovirus group K member 10 --> output type PhenotypicFeature
# Running: endogenous retrovirus group K member 10 --> output type BiologicalProcess
# Running: endogenous retrovirus group K member 10 --> output type Disease
# Running: heat shock protein family B (small) member 1 --> output type PhenotypicFeature
# Running: heat shock protein family B (small) member 1 --> output type BiologicalProcess
# Running: heat shock protein family B (small) member 1 --> output type Disease
# Running: adenosine deaminase --> output type PhenotypicFeature
# Running: adenosine deaminase --> output type BiologicalProcess
# Running: adenosine deaminase --> output type Disease
# Running: transcription elongation factor A like 1 --> output type PhenotypicFeature
# Running: transcription elongation factor A like 1 --> output type BiologicalProcess
# Running: transcription elongation factor A like 1 --> output type Disease
# Running: major histocompatibility complex, class I, E --> output type PhenotypicFeature
# Running: major histocompatibility complex, class I, E --> output type BiologicalProcess
# Running: major histocompatibility complex, class I, E --> output type Disease
# Running: TNF receptor superfamily member 10b --> output type PhenotypicFeature
# Running: TNF receptor superfamily member 10b --> output type BiologicalProcess
# Running: TNF receptor superfamily member 10b --> output type Disease
# Running: vascular cell adhesion molecule 1 --> output type PhenotypicFeature
# Running: vascular cell adhesion molecule 1 --> output type BiologicalProcess
# Running: vascular cell adhesion molecule 1 --> output type Disease
# Running: early growth response 1 --> output type PhenotypicFeature
# Running: early growth response 1 --> output type BiologicalProcess
# Running: early growth response 1 --> output type Disease
# Running: colony stimulating factor 2 --> output type PhenotypicFeature
# Running: colony stimulating factor 2 --> output type BiologicalProcess
# Running: colony stimulating factor 2 --> output type Disease
# Running: CD34 molecule --> output type PhenotypicFeature
# Running: CD34 molecule --> output type BiologicalProcess
# Running: CD34 molecule --> output type Disease
# Running: catenin beta 1 --> output type PhenotypicFeature
# Running: catenin beta 1 --> output type BiologicalProcess
# Running: catenin beta 1 --> output type Disease
# Running: toll like receptor 2 --> output type PhenotypicFeature
# Running: toll like receptor 2 --> output type BiologicalProcess
# Running: toll like receptor 2 --> output type Disease
# Running: integrin subunit beta 2 --> output type PhenotypicFeature
# Running: integrin subunit beta 2 --> output type BiologicalProcess
# Running: integrin subunit beta 2 --> output type Disease
# Running: aryl hydrocarbon receptor --> output type PhenotypicFeature
# Running: aryl hydrocarbon receptor --> output type BiologicalProcess
# Running: aryl hydrocarbon receptor --> output type Disease
# Running: SMAD family member 3 --> output type PhenotypicFeature
# Running: SMAD family member 3 --> output type BiologicalProcess
# Running: SMAD family member 3 --> output type Disease
# Running: C-C motif chemokine ligand 3 --> output type PhenotypicFeature
# Running: C-C motif chemokine ligand 3 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 3 --> output type Disease
# Running: CD80 molecule --> output type PhenotypicFeature
# Running: CD80 molecule --> output type BiologicalProcess
# Running: CD80 molecule --> output type Disease
# Running: phosphoinositide-3-kinase regulatory subunit 1 --> output type PhenotypicFeature
# Running: phosphoinositide-3-kinase regulatory subunit 1 --> output type BiologicalProcess
# Running: phosphoinositide-3-kinase regulatory subunit 1 --> output type Disease
# Running: C-X3-C motif chemokine ligand 1 --> output type PhenotypicFeature
# Running: C-X3-C motif chemokine ligand 1 --> output type BiologicalProcess
# Running: C-X3-C motif chemokine ligand 1 --> output type Disease
# Running: musculin --> output type PhenotypicFeature
# Running: musculin --> output type BiologicalProcess
# Running: musculin --> output type Disease
# Running: amyloid P component, serum --> output type PhenotypicFeature
# Running: amyloid P component, serum --> output type BiologicalProcess
# Running: amyloid P component, serum --> output type Disease
# Running: tubulin beta 4B class IVb --> output type PhenotypicFeature
# Running: tubulin beta 4B class IVb --> output type BiologicalProcess
# Running: tubulin beta 4B class IVb --> output type Disease
# Running: CD19 molecule --> output type PhenotypicFeature
# Running: CD19 molecule --> output type BiologicalProcess
# Running: CD19 molecule --> output type Disease
# Running: chorionic somatomammotropin hormone 1 --> output type PhenotypicFeature
# Running: chorionic somatomammotropin hormone 1 --> output type BiologicalProcess
# Running: chorionic somatomammotropin hormone 1 --> output type Disease
# Running: tripartite motif containing 25 --> output type PhenotypicFeature
# Running: tripartite motif containing 25 --> output type BiologicalProcess
# Running: tripartite motif containing 25 --> output type Disease
# Running: KIT ligand --> output type PhenotypicFeature
# Running: KIT ligand --> output type BiologicalProcess
# Running: KIT ligand --> output type Disease
# Running: CD36 molecule --> output type PhenotypicFeature
# Running: CD36 molecule --> output type BiologicalProcess
# Running: CD36 molecule --> output type Disease
# Running: ras homolog family member D --> output type PhenotypicFeature
# Running: ras homolog family member D --> output type BiologicalProcess
# Running: ras homolog family member D --> output type Disease
# Running: tyrosine aminotransferase --> output type PhenotypicFeature
# Running: tyrosine aminotransferase --> output type BiologicalProcess
# Running: tyrosine aminotransferase --> output type Disease
# Running: interleukin 9 --> output type PhenotypicFeature
# Running: interleukin 9 --> output type BiologicalProcess
# Running: interleukin 9 --> output type Disease
# Running: elastase, neutrophil expressed --> output type PhenotypicFeature
# Running: elastase, neutrophil expressed --> output type BiologicalProcess
# Running: elastase, neutrophil expressed --> output type Disease
# Running: baculoviral IAP repeat containing 3 --> output type PhenotypicFeature
# Running: baculoviral IAP repeat containing 3 --> output type BiologicalProcess
# Running: baculoviral IAP repeat containing 3 --> output type Disease
# Running: ubiquitin C --> output type PhenotypicFeature
# Running: ubiquitin C --> output type BiologicalProcess
# Running: ubiquitin C --> output type Disease
# Running: forkhead box P3 --> output type PhenotypicFeature
# Running: forkhead box P3 --> output type BiologicalProcess
# Running: forkhead box P3 --> output type Disease
# Running: H3 histone pseudogene 16 --> output type PhenotypicFeature
# Running: H3 histone pseudogene 16 --> output type BiologicalProcess
# Running: H3 histone pseudogene 16 --> output type Disease
# Running: integrin subunit alpha X --> output type PhenotypicFeature
# Running: integrin subunit alpha X --> output type BiologicalProcess
# Running: integrin subunit alpha X --> output type Disease
# Running: MDM2 proto-oncogene --> output type PhenotypicFeature
# Running: MDM2 proto-oncogene --> output type BiologicalProcess
# Running: MDM2 proto-oncogene --> output type Disease
# Running: GRB2 related adaptor protein 2 --> output type PhenotypicFeature
# Running: GRB2 related adaptor protein 2 --> output type BiologicalProcess
# Running: GRB2 related adaptor protein 2 --> output type Disease
# Running: MHC class I polypeptide-related sequence E (pseudogene) --> output type PhenotypicFeature
# Running: MHC class I polypeptide-related sequence E (pseudogene) --> output type BiologicalProcess
# Running: MHC class I polypeptide-related sequence E (pseudogene) --> output type Disease
# Running: ribosomal protein SA --> output type PhenotypicFeature
# Running: ribosomal protein SA --> output type BiologicalProcess
# Running: ribosomal protein SA --> output type Disease
# Running: protein tyrosine phosphatase non-receptor type 6 --> output type PhenotypicFeature
# Running: protein tyrosine phosphatase non-receptor type 6 --> output type BiologicalProcess
# Running: protein tyrosine phosphatase non-receptor type 6 --> output type Disease
# Running: C-C motif chemokine ligand 20 --> output type PhenotypicFeature
# Running: C-C motif chemokine ligand 20 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 20 --> output type Disease
# Running: insulin like growth factor 1 --> output type PhenotypicFeature
# Running: insulin like growth factor 1 --> output type BiologicalProcess
# Running: insulin like growth factor 1 --> output type Disease
# Running: transferrin --> output type PhenotypicFeature
# Running: transferrin --> output type BiologicalProcess
# Running: transferrin --> output type Disease
# Running: S100 calcium binding protein A9 --> output type PhenotypicFeature
# Running: S100 calcium binding protein A9 --> output type BiologicalProcess
# Running: S100 calcium binding protein A9 --> output type Disease
# Running: histone deacetylase 1 --> output type PhenotypicFeature
# Running: histone deacetylase 1 --> output type BiologicalProcess
# Running: histone deacetylase 1 --> output type Disease
# Running: nucleotide binding oligomerization domain containing 2 --> output type PhenotypicFeature
# Running: nucleotide binding oligomerization domain containing 2 --> output type BiologicalProcess
# Running: nucleotide binding oligomerization domain containing 2 --> output type Disease
# Running: X-linked Kx blood group --> output type PhenotypicFeature
# Running: X-linked Kx blood group --> output type BiologicalProcess
# Running: X-linked Kx blood group --> output type Disease
# Running: Sp1 transcription factor --> output type PhenotypicFeature
# Running: Sp1 transcription factor --> output type BiologicalProcess
# Running: Sp1 transcription factor --> output type Disease
# Cannot connect to host mydisease.info:80 ssl:default [Connect call failed ('54.191.217.118', 80)]
# Cannot connect to host mydisease.info:80 ssl:default [Connect call failed ('54.191.217.118', 80)]
# Cannot connect to host mydisease.info:80 ssl:default [Connect call failed ('54.70.133.249', 80)]
# Cannot connect to host mydisease.info:80 ssl:default [Connect call failed ('54.70.133.249', 80)]
# ID resolution steps failed:
# Sp1 transcription factor --> output type Disease FAILED
# Running: interferon alpha inducible protein 27 --> output type PhenotypicFeature
# Running: interferon alpha inducible protein 27 --> output type BiologicalProcess
# Running: interferon alpha inducible protein 27 --> output type Disease
# Running: major histocompatibility complex, class II, DR beta 1 --> output type PhenotypicFeature
# Running: major histocompatibility complex, class II, DR beta 1 --> output type BiologicalProcess
# Running: major histocompatibility complex, class II, DR beta 1 --> output type Disease
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type PhenotypicFeature
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type BiologicalProcess
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type Disease
# Running: cannabinoid receptor 1 --> output type PhenotypicFeature
# Running: cannabinoid receptor 1 --> output type BiologicalProcess
# Running: cannabinoid receptor 1 --> output type Disease
# Running: cholecystokinin --> output type PhenotypicFeature
# Running: cholecystokinin --> output type BiologicalProcess
# Running: cholecystokinin --> output type Disease
# Running: von Willebrand factor --> output type PhenotypicFeature
# Running: von Willebrand factor --> output type BiologicalProcess
# Running: von Willebrand factor --> output type Disease
# Running: heat shock protein family A (Hsp70) member 8 --> output type PhenotypicFeature
# Running: heat shock protein family A (Hsp70) member 8 --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 8 --> output type Disease
# Running: CD69 molecule --> output type PhenotypicFeature
# Running: CD69 molecule --> output type BiologicalProcess
# Running: CD69 molecule --> output type Disease
# Running: interleukin 3 --> output type PhenotypicFeature
# Running: interleukin 3 --> output type BiologicalProcess
# Running: interleukin 3 --> output type Disease
# Running: pro-platelet basic protein --> output type PhenotypicFeature
# Running: pro-platelet basic protein --> output type BiologicalProcess
# Running: pro-platelet basic protein --> output type Disease
# Running: prohibitin --> output type PhenotypicFeature
# Running: prohibitin --> output type BiologicalProcess
# Running: prohibitin --> output type Disease
# Running: kallikrein related peptidase 3 --> output type PhenotypicFeature
# Running: kallikrein related peptidase 3 --> output type BiologicalProcess
# Running: kallikrein related peptidase 3 --> output type Disease
# Running: notch receptor 1 --> output type PhenotypicFeature
# Running: notch receptor 1 --> output type BiologicalProcess
# Running: notch receptor 1 --> output type Disease
# Running: advanced glycosylation end-product specific receptor --> output type PhenotypicFeature
# Running: advanced glycosylation end-product specific receptor --> output type BiologicalProcess
# Running: advanced glycosylation end-product specific receptor --> output type Disease
# Running: fibroblast growth factor receptor 1 --> output type PhenotypicFeature
# Running: fibroblast growth factor receptor 1 --> output type BiologicalProcess
# Running: fibroblast growth factor receptor 1 --> output type Disease
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type PhenotypicFeature
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type BiologicalProcess
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type Disease
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type PhenotypicFeature
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type BiologicalProcess
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type Disease
# Running: Cbl proto-oncogene --> output type PhenotypicFeature
# Running: Cbl proto-oncogene --> output type BiologicalProcess
# Running: Cbl proto-oncogene --> output type Disease
# Running: transferrin receptor --> output type PhenotypicFeature
# Running: transferrin receptor --> output type BiologicalProcess
# Running: transferrin receptor --> output type Disease
# Running: CD8a molecule --> output type PhenotypicFeature
# Running: CD8a molecule --> output type BiologicalProcess
# Running: CD8a molecule --> output type Disease
# Running: neural cell adhesion molecule 1 --> output type PhenotypicFeature
# Running: neural cell adhesion molecule 1 --> output type BiologicalProcess
# Running: neural cell adhesion molecule 1 --> output type Disease
# Running: synaptotagmin 1 --> output type PhenotypicFeature
# Running: synaptotagmin 1 --> output type BiologicalProcess
# Running: synaptotagmin 1 --> output type Disease
# Running: nuclear receptor subfamily 3 group C member 1 --> output type PhenotypicFeature
# Running: nuclear receptor subfamily 3 group C member 1 --> output type BiologicalProcess
# Running: nuclear receptor subfamily 3 group C member 1 --> output type Disease
# Running: interferon regulatory factor 1 --> output type PhenotypicFeature
# Running: interferon regulatory factor 1 --> output type BiologicalProcess
# Running: interferon regulatory factor 1 --> output type Disease
# Running: cyclin dependent kinase 2 --> output type PhenotypicFeature
# Running: cyclin dependent kinase 2 --> output type BiologicalProcess
# Running: cyclin dependent kinase 2 --> output type Disease
# Running: BCL2 apoptosis regulator --> output type PhenotypicFeature
# Running: BCL2 apoptosis regulator --> output type BiologicalProcess
# Running: BCL2 apoptosis regulator --> output type Disease
# (243332, 9)
#   input input_type     pred1 pred1_source        pred1_api       pred1_pubmed  \
# 0   CRP       Gene   affects       SEMMED  SEMMED Gene API            7494474
# 1   CRP       Gene    causes       SEMMED  SEMMED Gene API  23373721,23586631
# 2   CRP       Gene   affects       SEMMED  SEMMED Gene API            9150882
# 3   CRP       Gene  disrupts       SEMMED  SEMMED Gene API           27343075
# 4   CRP       Gene    causes       SEMMED  SEMMED Gene API           23251905
#
#          output_type output_name      output_id
# 0  BiologicalProcess    C0013081  UMLS:C0013081
# 1  BiologicalProcess    C0013081  UMLS:C0013081
# 2  BiologicalProcess    C1327287  UMLS:C1327287
# 3  BiologicalProcess    C0018270  UMLS:C0018270
# 4  BiologicalProcess    C0041904  UMLS:C0041904

# %%
# filter gene -> symptoms table to only include rows where symptoms match disease symptoms
indices_with_symptom_outputs = [i for i, val in enumerate([x.upper() for x in list(genes_to_symptoms['output_name'])]) if val in disease_symptoms]
relevant_genes_to_symptoms_df = genes_to_symptoms.iloc[indices_with_symptom_outputs]
relevant_genes_to_symptoms_df.head()
# Out:
#        input input_type       pred1 pred1_source                    pred1_api  \
# 253      CRP       Gene  related_to     scigraph  Automat CORD19 Scigraph API
# 82   TMPRSS2       Gene  related_to      DISEASE                 DISEASES API
# 287     ACE2       Gene  related_to      DISEASE                 DISEASES API
# 27      CFTR       Gene  related_to         None                  BioLink API
# 34      CFTR       Gene  related_to         None                  BioLink API
#
#     pred1_pubmed        output_type             output_name  \
# 253         None            Disease                DIARRHEA
# 82          None            Disease                DIARRHEA
# 287         None            Disease                DIARRHEA
# 27          None  PhenotypicFeature  ABNORMAL LIVER ENZYMES
# 34          None  PhenotypicFeature                 FATIGUE
#
#                output_id
# 253  MONDO:MONDO:0001673
# 82   MONDO:MONDO:0001673
# 287  MONDO:MONDO:0001673
# 27         UMLS:C0438237
# 34         UMLS:C0015672

# %%
# %store relevant_genes_to_symptoms_df
# %store -r relevant_genes_to_symptoms_df
# Out:
# Stored 'relevant_genes_to_symptoms_df' (DataFrame)

# %%
# create dictionary to keep track of symptoms a gene is related to, and the number of publications relating the 
# gene to any of the disease symptoms
symptoms_results = {}
relevant_top_genes_list = list(dict.fromkeys(list(relevant_genes_to_symptoms_df["input"])))
for x in relevant_top_genes_list:
    symptoms_results[x] = {
        "related_symptoms" : [],
        "publications": []
    }
for index, row in relevant_genes_to_symptoms_df.iterrows():
    symptoms_results[row["input"]]["related_symptoms"].append(row["output_name"])
    if(row["pred1_pubmed"]):
        symptoms_results[row["input"]]["publications"] = symptoms_results[row["input"]]["publications"] + row["pred1_pubmed"].split(',')

for key,value in symptoms_results.items(): 
    symptoms_results[key]['publications'] = list(dict.fromkeys(symptoms_results[key]['publications']))
            
        
# print(symptoms_results)

# %% [markdown]
# ## 6. Get Genes Edges Out Count

# %%
# get edges out count from genes to any node type to get rough estimate of how well researched a gene is
relevant_gene_inputs = []
gene_edges_out = {}
for gene_input in gene_inputs: 
    if(gene_input['SYMBOL'] in relevant_top_genes_list):
        relevant_gene_inputs.append(gene_input)

for gene_input in relevant_gene_inputs: 
    current_gene = predict_many([gene_input], ALL_NODE_TYPES)
    rows = current_gene.shape[0]
    gene_edges_out[gene_input["SYMBOL"]] = rows
# Out:
# Running: C-reactive protein --> output type Gene
# Running: C-reactive protein --> output type SequenceVariant
# Running: C-reactive protein --> output type ChemicalSubstance
# Running: C-reactive protein --> output type Disease
# Running: C-reactive protein --> output type MolecularActivity
# Running: C-reactive protein --> output type BiologicalProcess
# Running: C-reactive protein --> output type CellularComponent
# Running: C-reactive protein --> output type Pathway
# Running: C-reactive protein --> output type AnatomicalEntity
# Running: C-reactive protein --> output type PhenotypicFeature
# Running: transmembrane serine protease 2 --> output type Gene
# Running: transmembrane serine protease 2 --> output type SequenceVariant
# Running: transmembrane serine protease 2 --> output type ChemicalSubstance
# Running: transmembrane serine protease 2 --> output type Disease
# Running: transmembrane serine protease 2 --> output type MolecularActivity
# Running: transmembrane serine protease 2 --> output type BiologicalProcess
# Running: transmembrane serine protease 2 --> output type CellularComponent
# Running: transmembrane serine protease 2 --> output type Pathway
# Running: transmembrane serine protease 2 --> output type AnatomicalEntity
# Running: transmembrane serine protease 2 --> output type PhenotypicFeature
# Running: angiotensin I converting enzyme 2 --> output type Gene
# Running: angiotensin I converting enzyme 2 --> output type SequenceVariant
# Running: angiotensin I converting enzyme 2 --> output type ChemicalSubstance
# Running: angiotensin I converting enzyme 2 --> output type Disease
# Running: angiotensin I converting enzyme 2 --> output type MolecularActivity
# Running: angiotensin I converting enzyme 2 --> output type BiologicalProcess
# Running: angiotensin I converting enzyme 2 --> output type CellularComponent
# Running: angiotensin I converting enzyme 2 --> output type Pathway
# Running: angiotensin I converting enzyme 2 --> output type AnatomicalEntity
# Running: angiotensin I converting enzyme 2 --> output type PhenotypicFeature
# Running: CF transmembrane conductance regulator --> output type Gene
# Running: CF transmembrane conductance regulator --> output type SequenceVariant
# Running: CF transmembrane conductance regulator --> output type ChemicalSubstance
# Running: CF transmembrane conductance regulator --> output type Disease
# Running: CF transmembrane conductance regulator --> output type MolecularActivity
# Running: CF transmembrane conductance regulator --> output type BiologicalProcess
# Running: CF transmembrane conductance regulator --> output type CellularComponent
# Running: CF transmembrane conductance regulator --> output type Pathway
# Running: CF transmembrane conductance regulator --> output type AnatomicalEntity
# Running: CF transmembrane conductance regulator --> output type PhenotypicFeature
# Running: CD4 molecule --> output type Gene
# Running: CD4 molecule --> output type SequenceVariant
# Running: CD4 molecule --> output type ChemicalSubstance
# Running: CD4 molecule --> output type Disease
# Running: CD4 molecule --> output type MolecularActivity
# Running: CD4 molecule --> output type BiologicalProcess
# Running: CD4 molecule --> output type CellularComponent
# Running: CD4 molecule --> output type Pathway
# Running: CD4 molecule --> output type AnatomicalEntity
# Running: CD4 molecule --> output type PhenotypicFeature
# Running: carboxypeptidase B2 --> output type Gene
# Running: carboxypeptidase B2 --> output type SequenceVariant
# Running: carboxypeptidase B2 --> output type ChemicalSubstance
# Running: carboxypeptidase B2 --> output type Disease
# Running: carboxypeptidase B2 --> output type MolecularActivity
# Running: carboxypeptidase B2 --> output type BiologicalProcess
# Running: carboxypeptidase B2 --> output type CellularComponent
# Running: carboxypeptidase B2 --> output type Pathway
# Running: carboxypeptidase B2 --> output type AnatomicalEntity
# Running: carboxypeptidase B2 --> output type PhenotypicFeature
# Running: sirtuin 4 --> output type Gene
# Running: sirtuin 4 --> output type SequenceVariant
# Running: sirtuin 4 --> output type ChemicalSubstance
# Running: sirtuin 4 --> output type Disease
# Running: sirtuin 4 --> output type MolecularActivity
# Running: sirtuin 4 --> output type BiologicalProcess
# Running: sirtuin 4 --> output type CellularComponent
# Running: sirtuin 4 --> output type Pathway
# Running: sirtuin 4 --> output type AnatomicalEntity
# Running: sirtuin 4 --> output type PhenotypicFeature
# Running: apolipoprotein H --> output type Gene
# Running: apolipoprotein H --> output type SequenceVariant
# Running: apolipoprotein H --> output type ChemicalSubstance
# Running: apolipoprotein H --> output type Disease
# Running: apolipoprotein H --> output type MolecularActivity
# Running: apolipoprotein H --> output type BiologicalProcess
# Running: apolipoprotein H --> output type CellularComponent
# Running: apolipoprotein H --> output type Pathway
# Running: apolipoprotein H --> output type AnatomicalEntity
# Running: apolipoprotein H --> output type PhenotypicFeature
# Running: sirtuin 1 --> output type Gene
# Running: sirtuin 1 --> output type SequenceVariant
# Running: sirtuin 1 --> output type ChemicalSubstance
# Running: sirtuin 1 --> output type Disease
# Running: sirtuin 1 --> output type MolecularActivity
# Running: sirtuin 1 --> output type BiologicalProcess
# Running: sirtuin 1 --> output type CellularComponent
# Running: sirtuin 1 --> output type Pathway
# Running: sirtuin 1 --> output type AnatomicalEntity
# Running: sirtuin 1 --> output type PhenotypicFeature
# Running: growth arrest and DNA damage inducible beta --> output type Gene
# Running: growth arrest and DNA damage inducible beta --> output type SequenceVariant
# Running: growth arrest and DNA damage inducible beta --> output type ChemicalSubstance
# Running: growth arrest and DNA damage inducible beta --> output type Disease
# Running: growth arrest and DNA damage inducible beta --> output type MolecularActivity
# Running: growth arrest and DNA damage inducible beta --> output type BiologicalProcess
# Running: growth arrest and DNA damage inducible beta --> output type CellularComponent
# Running: growth arrest and DNA damage inducible beta --> output type Pathway
# Running: growth arrest and DNA damage inducible beta --> output type AnatomicalEntity
# Running: growth arrest and DNA damage inducible beta --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 1 --> output type Gene
# Running: mitogen-activated protein kinase 1 --> output type SequenceVariant
# Running: mitogen-activated protein kinase 1 --> output type ChemicalSubstance
# Running: mitogen-activated protein kinase 1 --> output type Disease
# Running: mitogen-activated protein kinase 1 --> output type MolecularActivity
# Running: mitogen-activated protein kinase 1 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 1 --> output type CellularComponent
# Running: mitogen-activated protein kinase 1 --> output type Pathway
# Running: mitogen-activated protein kinase 1 --> output type AnatomicalEntity
# Running: mitogen-activated protein kinase 1 --> output type PhenotypicFeature
# Running: oxytocin/neurophysin I prepropeptide --> output type Gene
# Running: oxytocin/neurophysin I prepropeptide --> output type SequenceVariant
# Running: oxytocin/neurophysin I prepropeptide --> output type ChemicalSubstance
# Running: oxytocin/neurophysin I prepropeptide --> output type Disease
# Running: oxytocin/neurophysin I prepropeptide --> output type MolecularActivity
# Running: oxytocin/neurophysin I prepropeptide --> output type BiologicalProcess
# Running: oxytocin/neurophysin I prepropeptide --> output type CellularComponent
# Running: oxytocin/neurophysin I prepropeptide --> output type Pathway
# Running: oxytocin/neurophysin I prepropeptide --> output type AnatomicalEntity
# Running: oxytocin/neurophysin I prepropeptide --> output type PhenotypicFeature
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type Gene
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type SequenceVariant
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type ChemicalSubstance
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type Disease
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type MolecularActivity
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type BiologicalProcess
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type CellularComponent
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type Pathway
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type AnatomicalEntity
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type PhenotypicFeature
# Running: MEFV innate immuity regulator, pyrin --> output type Gene
# Running: MEFV innate immuity regulator, pyrin --> output type SequenceVariant
# Running: MEFV innate immuity regulator, pyrin --> output type ChemicalSubstance
# Running: MEFV innate immuity regulator, pyrin --> output type Disease
# Running: MEFV innate immuity regulator, pyrin --> output type MolecularActivity
# Running: MEFV innate immuity regulator, pyrin --> output type BiologicalProcess
# Running: MEFV innate immuity regulator, pyrin --> output type CellularComponent
# Running: MEFV innate immuity regulator, pyrin --> output type Pathway
# Running: MEFV innate immuity regulator, pyrin --> output type AnatomicalEntity
# Running: MEFV innate immuity regulator, pyrin --> output type PhenotypicFeature
# Running: plasminogen activator, tissue type --> output type Gene
# Running: plasminogen activator, tissue type --> output type SequenceVariant
# Running: plasminogen activator, tissue type --> output type ChemicalSubstance
# Running: plasminogen activator, tissue type --> output type Disease
# Running: plasminogen activator, tissue type --> output type MolecularActivity
# Running: plasminogen activator, tissue type --> output type BiologicalProcess
# Running: plasminogen activator, tissue type --> output type CellularComponent
# Running: plasminogen activator, tissue type --> output type Pathway
# Running: plasminogen activator, tissue type --> output type AnatomicalEntity
# Running: plasminogen activator, tissue type --> output type PhenotypicFeature
# Running: Fc fragment of IgG receptor and transporter --> output type Gene
# Running: Fc fragment of IgG receptor and transporter --> output type SequenceVariant
# Running: Fc fragment of IgG receptor and transporter --> output type ChemicalSubstance
# Running: Fc fragment of IgG receptor and transporter --> output type Disease
# Running: Fc fragment of IgG receptor and transporter --> output type MolecularActivity
# Running: Fc fragment of IgG receptor and transporter --> output type BiologicalProcess
# Running: Fc fragment of IgG receptor and transporter --> output type CellularComponent
# Running: Fc fragment of IgG receptor and transporter --> output type Pathway
# Running: Fc fragment of IgG receptor and transporter --> output type AnatomicalEntity
# Running: Fc fragment of IgG receptor and transporter --> output type PhenotypicFeature
# Running: serpin family E member 1 --> output type Gene
# Running: serpin family E member 1 --> output type SequenceVariant
# Running: serpin family E member 1 --> output type ChemicalSubstance
# Running: serpin family E member 1 --> output type Disease
# Running: serpin family E member 1 --> output type MolecularActivity
# Running: serpin family E member 1 --> output type BiologicalProcess
# Running: serpin family E member 1 --> output type CellularComponent
# Running: serpin family E member 1 --> output type Pathway
# Running: serpin family E member 1 --> output type AnatomicalEntity
# Running: serpin family E member 1 --> output type PhenotypicFeature
# Running: complement C5 --> output type Gene
# Running: complement C5 --> output type SequenceVariant
# Running: complement C5 --> output type ChemicalSubstance
# Running: complement C5 --> output type Disease
# Running: complement C5 --> output type MolecularActivity
# Running: complement C5 --> output type BiologicalProcess
# Running: complement C5 --> output type CellularComponent
# Running: complement C5 --> output type Pathway
# Running: complement C5 --> output type AnatomicalEntity
# Running: complement C5 --> output type PhenotypicFeature
# Running: myeloperoxidase --> output type Gene
# Running: myeloperoxidase --> output type SequenceVariant
# Running: myeloperoxidase --> output type ChemicalSubstance
# Running: myeloperoxidase --> output type Disease
# Running: myeloperoxidase --> output type MolecularActivity
# Running: myeloperoxidase --> output type BiologicalProcess
# Running: myeloperoxidase --> output type CellularComponent
# Running: myeloperoxidase --> output type Pathway
# Running: myeloperoxidase --> output type AnatomicalEntity
# Running: myeloperoxidase --> output type PhenotypicFeature
# Running: colony stimulating factor 3 --> output type Gene
# Running: colony stimulating factor 3 --> output type SequenceVariant
# Running: colony stimulating factor 3 --> output type ChemicalSubstance
# Running: colony stimulating factor 3 --> output type Disease
# Running: colony stimulating factor 3 --> output type MolecularActivity
# Running: colony stimulating factor 3 --> output type BiologicalProcess
# Running: colony stimulating factor 3 --> output type CellularComponent
# Running: colony stimulating factor 3 --> output type Pathway
# Running: colony stimulating factor 3 --> output type AnatomicalEntity
# Running: colony stimulating factor 3 --> output type PhenotypicFeature
# Running: C-C motif chemokine ligand 2 --> output type Gene
# Running: C-C motif chemokine ligand 2 --> output type SequenceVariant
# Running: C-C motif chemokine ligand 2 --> output type ChemicalSubstance
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Running: C-C motif chemokine ligand 2 --> output type Disease
# Running: C-C motif chemokine ligand 2 --> output type MolecularActivity
# Running: C-C motif chemokine ligand 2 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 2 --> output type CellularComponent
# Running: C-C motif chemokine ligand 2 --> output type Pathway
# Running: C-C motif chemokine ligand 2 --> output type AnatomicalEntity
# Running: C-C motif chemokine ligand 2 --> output type PhenotypicFeature
# Running: interleukin 2 --> output type Gene
# Running: interleukin 2 --> output type SequenceVariant
# Running: interleukin 2 --> output type ChemicalSubstance
# Running: interleukin 2 --> output type Disease
# Running: interleukin 2 --> output type MolecularActivity
# Running: interleukin 2 --> output type BiologicalProcess
# Running: interleukin 2 --> output type CellularComponent
# Running: interleukin 2 --> output type Pathway
# Running: interleukin 2 --> output type AnatomicalEntity
# Running: interleukin 2 --> output type PhenotypicFeature
# Running: cathepsin C --> output type Gene
# Running: cathepsin C --> output type SequenceVariant
# Running: cathepsin C --> output type ChemicalSubstance
# Running: cathepsin C --> output type Disease
# Running: cathepsin C --> output type MolecularActivity
# Running: cathepsin C --> output type BiologicalProcess
# Running: cathepsin C --> output type CellularComponent
# Running: cathepsin C --> output type Pathway
# Running: cathepsin C --> output type AnatomicalEntity
# Running: cathepsin C --> output type PhenotypicFeature
# Running: interferon gamma --> output type Gene
# Running: interferon gamma --> output type SequenceVariant
# Running: interferon gamma --> output type ChemicalSubstance
# Running: interferon gamma --> output type Disease
# Running: interferon gamma --> output type MolecularActivity
# Running: interferon gamma --> output type BiologicalProcess
# Running: interferon gamma --> output type CellularComponent
# Running: interferon gamma --> output type Pathway
# Running: interferon gamma --> output type AnatomicalEntity
# Running: interferon gamma --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 14 --> output type Gene
# Running: mitogen-activated protein kinase 14 --> output type SequenceVariant
# Running: mitogen-activated protein kinase 14 --> output type ChemicalSubstance
# Running: mitogen-activated protein kinase 14 --> output type Disease
# Running: mitogen-activated protein kinase 14 --> output type MolecularActivity
# Running: mitogen-activated protein kinase 14 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 14 --> output type CellularComponent
# Running: mitogen-activated protein kinase 14 --> output type Pathway
# Running: mitogen-activated protein kinase 14 --> output type AnatomicalEntity
# Running: mitogen-activated protein kinase 14 --> output type PhenotypicFeature
# Running: interleukin 4 --> output type Gene
# Running: interleukin 4 --> output type SequenceVariant
# Running: interleukin 4 --> output type ChemicalSubstance
# Running: interleukin 4 --> output type Disease
# Running: interleukin 4 --> output type MolecularActivity
# Running: interleukin 4 --> output type BiologicalProcess
# Running: interleukin 4 --> output type CellularComponent
# Running: interleukin 4 --> output type Pathway
# Running: interleukin 4 --> output type AnatomicalEntity
# Running: interleukin 4 --> output type PhenotypicFeature
# Running: microtubule associated protein RP/EB family member 3 --> output type Gene
# Running: microtubule associated protein RP/EB family member 3 --> output type SequenceVariant
# Running: microtubule associated protein RP/EB family member 3 --> output type ChemicalSubstance
# Running: microtubule associated protein RP/EB family member 3 --> output type Disease
# Running: microtubule associated protein RP/EB family member 3 --> output type MolecularActivity
# Running: microtubule associated protein RP/EB family member 3 --> output type BiologicalProcess
# Running: microtubule associated protein RP/EB family member 3 --> output type CellularComponent
# Running: microtubule associated protein RP/EB family member 3 --> output type Pathway
# Running: microtubule associated protein RP/EB family member 3 --> output type AnatomicalEntity
# Running: microtubule associated protein RP/EB family member 3 --> output type PhenotypicFeature
# Running: troponin T2, cardiac type --> output type Gene
# Running: troponin T2, cardiac type --> output type SequenceVariant
# Running: troponin T2, cardiac type --> output type ChemicalSubstance
# Running: troponin T2, cardiac type --> output type Disease
# Running: troponin T2, cardiac type --> output type MolecularActivity
# Running: troponin T2, cardiac type --> output type BiologicalProcess
# Running: troponin T2, cardiac type --> output type CellularComponent
# Running: troponin T2, cardiac type --> output type Pathway
# Running: troponin T2, cardiac type --> output type AnatomicalEntity
# Running: troponin T2, cardiac type --> output type PhenotypicFeature
# Running: transthyretin --> output type Gene
# Running: transthyretin --> output type SequenceVariant
# Running: transthyretin --> output type ChemicalSubstance
# Running: transthyretin --> output type Disease
# Running: transthyretin --> output type MolecularActivity
# Running: transthyretin --> output type BiologicalProcess
# Running: transthyretin --> output type CellularComponent
# Running: transthyretin --> output type Pathway
# Running: transthyretin --> output type AnatomicalEntity
# Running: transthyretin --> output type PhenotypicFeature
# Running: galectin like --> output type Gene
# Running: galectin like --> output type SequenceVariant
# Running: galectin like --> output type ChemicalSubstance
# Running: galectin like --> output type Disease
# Running: galectin like --> output type MolecularActivity
# Running: galectin like --> output type BiologicalProcess
# Running: galectin like --> output type CellularComponent
# Running: galectin like --> output type Pathway
# Running: galectin like --> output type AnatomicalEntity
# Running: galectin like --> output type PhenotypicFeature
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type Gene
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type SequenceVariant
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type ChemicalSubstance
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type Disease
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type MolecularActivity
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type BiologicalProcess
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type CellularComponent
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type Pathway
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type AnatomicalEntity
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type PhenotypicFeature
# Running: 5', 3'-nucleotidase, cytosolic --> output type Gene
# Running: 5', 3'-nucleotidase, cytosolic --> output type SequenceVariant
# Running: 5', 3'-nucleotidase, cytosolic --> output type ChemicalSubstance
# Running: 5', 3'-nucleotidase, cytosolic --> output type Disease
# Running: 5', 3'-nucleotidase, cytosolic --> output type MolecularActivity
# Running: 5', 3'-nucleotidase, cytosolic --> output type BiologicalProcess
# Running: 5', 3'-nucleotidase, cytosolic --> output type CellularComponent
# Running: 5', 3'-nucleotidase, cytosolic --> output type Pathway
# Running: 5', 3'-nucleotidase, cytosolic --> output type AnatomicalEntity
# Running: 5', 3'-nucleotidase, cytosolic --> output type PhenotypicFeature
# Running: complement C3 --> output type Gene
# Running: complement C3 --> output type SequenceVariant
# Running: complement C3 --> output type ChemicalSubstance
# Running: complement C3 --> output type Disease
# Running: complement C3 --> output type MolecularActivity
# Running: complement C3 --> output type BiologicalProcess
# Running: complement C3 --> output type CellularComponent
# Running: complement C3 --> output type Pathway
# Running: complement C3 --> output type AnatomicalEntity
# Running: complement C3 --> output type PhenotypicFeature
# Running: SH2 domain containing 3A --> output type Gene
# Running: SH2 domain containing 3A --> output type SequenceVariant
# Running: SH2 domain containing 3A --> output type ChemicalSubstance
# Running: SH2 domain containing 3A --> output type Disease
# Running: SH2 domain containing 3A --> output type MolecularActivity
# Running: SH2 domain containing 3A --> output type BiologicalProcess
# Running: SH2 domain containing 3A --> output type CellularComponent
# Running: SH2 domain containing 3A --> output type Pathway
# Running: SH2 domain containing 3A --> output type AnatomicalEntity
# Running: SH2 domain containing 3A --> output type PhenotypicFeature
# Running: fibrinogen like 2 --> output type Gene
# Running: fibrinogen like 2 --> output type SequenceVariant
# Running: fibrinogen like 2 --> output type ChemicalSubstance
# Running: fibrinogen like 2 --> output type Disease
# Running: fibrinogen like 2 --> output type MolecularActivity
# Running: fibrinogen like 2 --> output type BiologicalProcess
# Running: fibrinogen like 2 --> output type CellularComponent
# Running: fibrinogen like 2 --> output type Pathway
# Running: fibrinogen like 2 --> output type AnatomicalEntity
# Running: fibrinogen like 2 --> output type PhenotypicFeature
# Running: sirtuin 2 --> output type Gene
# Running: sirtuin 2 --> output type SequenceVariant
# Running: sirtuin 2 --> output type ChemicalSubstance
# Running: sirtuin 2 --> output type Disease
# Running: sirtuin 2 --> output type MolecularActivity
# Running: sirtuin 2 --> output type BiologicalProcess
# Running: sirtuin 2 --> output type CellularComponent
# Running: sirtuin 2 --> output type Pathway
# Running: sirtuin 2 --> output type AnatomicalEntity
# Running: sirtuin 2 --> output type PhenotypicFeature
# Running: tumor necrosis factor --> output type Gene
# Running: tumor necrosis factor --> output type SequenceVariant
# Running: tumor necrosis factor --> output type ChemicalSubstance
# Running: tumor necrosis factor --> output type Disease
# Running: tumor necrosis factor --> output type MolecularActivity
# Running: tumor necrosis factor --> output type BiologicalProcess
# Running: tumor necrosis factor --> output type CellularComponent
# Running: tumor necrosis factor --> output type Pathway
# Running: tumor necrosis factor --> output type AnatomicalEntity
# Running: tumor necrosis factor --> output type PhenotypicFeature
# Running: interferon alpha 1 --> output type Gene
# Running: interferon alpha 1 --> output type SequenceVariant
# Running: interferon alpha 1 --> output type ChemicalSubstance
# Running: interferon alpha 1 --> output type Disease
# Running: interferon alpha 1 --> output type MolecularActivity
# Running: interferon alpha 1 --> output type BiologicalProcess
# Running: interferon alpha 1 --> output type CellularComponent
# Running: interferon alpha 1 --> output type Pathway
# Running: interferon alpha 1 --> output type AnatomicalEntity
# Running: interferon alpha 1 --> output type PhenotypicFeature
# Running: tumor protein p53 --> output type Gene
# Running: tumor protein p53 --> output type SequenceVariant
# Running: tumor protein p53 --> output type ChemicalSubstance
# Running: tumor protein p53 --> output type Disease
# Running: tumor protein p53 --> output type MolecularActivity
# Running: tumor protein p53 --> output type BiologicalProcess
# Running: tumor protein p53 --> output type CellularComponent
# Running: tumor protein p53 --> output type Pathway
# Running: tumor protein p53 --> output type AnatomicalEntity
# Running: tumor protein p53 --> output type PhenotypicFeature
# Running: vascular endothelial growth factor A --> output type Gene
# Running: vascular endothelial growth factor A --> output type SequenceVariant
# Running: vascular endothelial growth factor A --> output type ChemicalSubstance
# Running: vascular endothelial growth factor A --> output type Disease
# Running: vascular endothelial growth factor A --> output type MolecularActivity
# Running: vascular endothelial growth factor A --> output type BiologicalProcess
# Running: vascular endothelial growth factor A --> output type CellularComponent
# Running: vascular endothelial growth factor A --> output type Pathway
# Running: vascular endothelial growth factor A --> output type AnatomicalEntity
# Running: vascular endothelial growth factor A --> output type PhenotypicFeature
# Running: AKT serine/threonine kinase 1 --> output type Gene
# Running: AKT serine/threonine kinase 1 --> output type SequenceVariant
# Running: AKT serine/threonine kinase 1 --> output type ChemicalSubstance
# Running: AKT serine/threonine kinase 1 --> output type Disease
# Running: AKT serine/threonine kinase 1 --> output type MolecularActivity
# Running: AKT serine/threonine kinase 1 --> output type BiologicalProcess
# Running: AKT serine/threonine kinase 1 --> output type CellularComponent
# Running: AKT serine/threonine kinase 1 --> output type Pathway
# Running: AKT serine/threonine kinase 1 --> output type AnatomicalEntity
# Running: AKT serine/threonine kinase 1 --> output type PhenotypicFeature
# Running: epidermal growth factor receptor --> output type Gene
# Running: epidermal growth factor receptor --> output type SequenceVariant
# Running: epidermal growth factor receptor --> output type ChemicalSubstance
# Running: epidermal growth factor receptor --> output type Disease
# Running: epidermal growth factor receptor --> output type MolecularActivity
# Running: epidermal growth factor receptor --> output type BiologicalProcess
# Running: epidermal growth factor receptor --> output type CellularComponent
# Running: epidermal growth factor receptor --> output type Pathway
# Running: epidermal growth factor receptor --> output type AnatomicalEntity
# Running: epidermal growth factor receptor --> output type PhenotypicFeature
# Running: interleukin 6 --> output type Gene
# Running: interleukin 6 --> output type SequenceVariant
# Running: interleukin 6 --> output type ChemicalSubstance
# Running: interleukin 6 --> output type Disease
# Running: interleukin 6 --> output type MolecularActivity
# Running: interleukin 6 --> output type BiologicalProcess
# Running: interleukin 6 --> output type CellularComponent
# Running: interleukin 6 --> output type Pathway
# Running: interleukin 6 --> output type AnatomicalEntity
# Running: interleukin 6 --> output type PhenotypicFeature
# Running: transforming growth factor beta 1 --> output type Gene
# Running: transforming growth factor beta 1 --> output type SequenceVariant
# Running: transforming growth factor beta 1 --> output type ChemicalSubstance
# Running: transforming growth factor beta 1 --> output type Disease
# Running: transforming growth factor beta 1 --> output type MolecularActivity
# Running: transforming growth factor beta 1 --> output type BiologicalProcess
# Running: transforming growth factor beta 1 --> output type CellularComponent
# Running: transforming growth factor beta 1 --> output type Pathway
# Running: transforming growth factor beta 1 --> output type AnatomicalEntity
# Running: transforming growth factor beta 1 --> output type PhenotypicFeature
# Running: insulin --> output type Gene
# Running: insulin --> output type SequenceVariant
# Running: insulin --> output type ChemicalSubstance
# Running: insulin --> output type Disease
# Running: insulin --> output type MolecularActivity
# Running: insulin --> output type BiologicalProcess
# Running: insulin --> output type CellularComponent
# Running: insulin --> output type Pathway
# Running: insulin --> output type AnatomicalEntity
# Running: insulin --> output type PhenotypicFeature
# Running: catalase --> output type Gene
# Running: catalase --> output type SequenceVariant
# Running: catalase --> output type ChemicalSubstance
# Running: catalase --> output type Disease
# Running: catalase --> output type MolecularActivity
# Running: catalase --> output type BiologicalProcess
# Running: catalase --> output type CellularComponent
# Running: catalase --> output type Pathway
# Running: catalase --> output type AnatomicalEntity
# Running: catalase --> output type PhenotypicFeature
# Running: toll like receptor 4 --> output type Gene
# Running: toll like receptor 4 --> output type SequenceVariant
# Running: toll like receptor 4 --> output type ChemicalSubstance
# Running: toll like receptor 4 --> output type Disease
# Running: toll like receptor 4 --> output type MolecularActivity
# Running: toll like receptor 4 --> output type BiologicalProcess
# Running: toll like receptor 4 --> output type CellularComponent
# Running: toll like receptor 4 --> output type Pathway
# Running: toll like receptor 4 --> output type AnatomicalEntity
# Running: toll like receptor 4 --> output type PhenotypicFeature
# Running: matrix metallopeptidase 9 --> output type Gene
# Running: matrix metallopeptidase 9 --> output type SequenceVariant
# Running: matrix metallopeptidase 9 --> output type ChemicalSubstance
# Running: matrix metallopeptidase 9 --> output type Disease
# Running: matrix metallopeptidase 9 --> output type MolecularActivity
# Running: matrix metallopeptidase 9 --> output type BiologicalProcess
# Running: matrix metallopeptidase 9 --> output type CellularComponent
# Running: matrix metallopeptidase 9 --> output type Pathway
# Running: matrix metallopeptidase 9 --> output type AnatomicalEntity
# Running: matrix metallopeptidase 9 --> output type PhenotypicFeature
# Running: signal transducer and activator of transcription 3 --> output type Gene
# Running: signal transducer and activator of transcription 3 --> output type SequenceVariant
# Running: signal transducer and activator of transcription 3 --> output type ChemicalSubstance
# Running: signal transducer and activator of transcription 3 --> output type Disease
# Running: signal transducer and activator of transcription 3 --> output type MolecularActivity
# Running: signal transducer and activator of transcription 3 --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 3 --> output type CellularComponent
# Running: signal transducer and activator of transcription 3 --> output type Pathway
# Running: signal transducer and activator of transcription 3 --> output type AnatomicalEntity
# Running: signal transducer and activator of transcription 3 --> output type PhenotypicFeature
# Running: interleukin 10 --> output type Gene
# Running: interleukin 10 --> output type SequenceVariant
# Running: interleukin 10 --> output type ChemicalSubstance
# Running: interleukin 10 --> output type Disease
# Running: interleukin 10 --> output type MolecularActivity
# Running: interleukin 10 --> output type BiologicalProcess
# Running: interleukin 10 --> output type CellularComponent
# Running: interleukin 10 --> output type Pathway
# Running: interleukin 10 --> output type AnatomicalEntity
# Running: interleukin 10 --> output type PhenotypicFeature
# Running: cathelicidin antimicrobial peptide --> output type Gene
# Running: cathelicidin antimicrobial peptide --> output type SequenceVariant
# Running: cathelicidin antimicrobial peptide --> output type ChemicalSubstance
# Running: cathelicidin antimicrobial peptide --> output type Disease
# Running: cathelicidin antimicrobial peptide --> output type MolecularActivity
# Running: cathelicidin antimicrobial peptide --> output type BiologicalProcess
# Running: cathelicidin antimicrobial peptide --> output type CellularComponent
# Running: cathelicidin antimicrobial peptide --> output type Pathway
# Running: cathelicidin antimicrobial peptide --> output type AnatomicalEntity
# Running: cathelicidin antimicrobial peptide --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 8 --> output type Gene
# Running: mitogen-activated protein kinase 8 --> output type SequenceVariant
# Running: mitogen-activated protein kinase 8 --> output type ChemicalSubstance
# Running: mitogen-activated protein kinase 8 --> output type Disease
# Running: mitogen-activated protein kinase 8 --> output type MolecularActivity
# Running: mitogen-activated protein kinase 8 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 8 --> output type CellularComponent
# Running: mitogen-activated protein kinase 8 --> output type Pathway
# Running: mitogen-activated protein kinase 8 --> output type AnatomicalEntity
# Running: mitogen-activated protein kinase 8 --> output type PhenotypicFeature
# Running: leptin --> output type Gene
# Running: leptin --> output type SequenceVariant
# Running: leptin --> output type ChemicalSubstance
# Running: leptin --> output type Disease
# Running: leptin --> output type MolecularActivity
# Running: leptin --> output type BiologicalProcess
# Running: leptin --> output type CellularComponent
# Running: leptin --> output type Pathway
# Running: leptin --> output type AnatomicalEntity
# Running: leptin --> output type PhenotypicFeature
# Running: proopiomelanocortin --> output type Gene
# Running: proopiomelanocortin --> output type SequenceVariant
# Running: proopiomelanocortin --> output type ChemicalSubstance
# Running: proopiomelanocortin --> output type Disease
# Running: proopiomelanocortin --> output type MolecularActivity
# Running: proopiomelanocortin --> output type BiologicalProcess
# Running: proopiomelanocortin --> output type CellularComponent
# Running: proopiomelanocortin --> output type Pathway
# Running: proopiomelanocortin --> output type AnatomicalEntity
# Running: proopiomelanocortin --> output type PhenotypicFeature
# Running: Fas cell surface death receptor --> output type Gene
# Running: Fas cell surface death receptor --> output type SequenceVariant
# Running: Fas cell surface death receptor --> output type ChemicalSubstance
# Running: Fas cell surface death receptor --> output type Disease
# Running: Fas cell surface death receptor --> output type MolecularActivity
# Running: Fas cell surface death receptor --> output type BiologicalProcess
# Running: Fas cell surface death receptor --> output type CellularComponent
# Running: Fas cell surface death receptor --> output type Pathway
# Running: Fas cell surface death receptor --> output type AnatomicalEntity
# Running: Fas cell surface death receptor --> output type PhenotypicFeature
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type Gene
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type SequenceVariant
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type ChemicalSubstance
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type Disease
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type MolecularActivity
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type BiologicalProcess
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type CellularComponent
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type Pathway
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type AnatomicalEntity
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type PhenotypicFeature
# Running: CD40 molecule --> output type Gene
# Running: CD40 molecule --> output type SequenceVariant
# Running: CD40 molecule --> output type ChemicalSubstance
# Running: CD40 molecule --> output type Disease
# Running: CD40 molecule --> output type MolecularActivity
# Running: CD40 molecule --> output type BiologicalProcess
# Running: CD40 molecule --> output type CellularComponent
# Running: CD40 molecule --> output type Pathway
# Running: CD40 molecule --> output type AnatomicalEntity
# Running: CD40 molecule --> output type PhenotypicFeature
# Running: carbonic anhydrase 2 --> output type Gene
# Running: carbonic anhydrase 2 --> output type SequenceVariant
# Running: carbonic anhydrase 2 --> output type ChemicalSubstance
# Running: carbonic anhydrase 2 --> output type Disease
# Running: carbonic anhydrase 2 --> output type MolecularActivity
# Running: carbonic anhydrase 2 --> output type BiologicalProcess
# Running: carbonic anhydrase 2 --> output type CellularComponent
# Running: carbonic anhydrase 2 --> output type Pathway
# Running: carbonic anhydrase 2 --> output type AnatomicalEntity
# Running: carbonic anhydrase 2 --> output type PhenotypicFeature
# Running: albumin --> output type Gene
# Running: albumin --> output type SequenceVariant
# Running: albumin --> output type ChemicalSubstance
# Running: albumin --> output type Disease
# Running: albumin --> output type MolecularActivity
# Running: albumin --> output type BiologicalProcess
# Running: albumin --> output type CellularComponent
# Running: albumin --> output type Pathway
# Running: albumin --> output type AnatomicalEntity
# Running: albumin --> output type PhenotypicFeature
# Running: RELA proto-oncogene, NF-kB subunit --> output type Gene
# Running: RELA proto-oncogene, NF-kB subunit --> output type SequenceVariant
# Running: RELA proto-oncogene, NF-kB subunit --> output type ChemicalSubstance
# Running: RELA proto-oncogene, NF-kB subunit --> output type Disease
# Running: RELA proto-oncogene, NF-kB subunit --> output type MolecularActivity
# Running: RELA proto-oncogene, NF-kB subunit --> output type BiologicalProcess
# Running: RELA proto-oncogene, NF-kB subunit --> output type CellularComponent
# Running: RELA proto-oncogene, NF-kB subunit --> output type Pathway
# Running: RELA proto-oncogene, NF-kB subunit --> output type AnatomicalEntity
# Running: RELA proto-oncogene, NF-kB subunit --> output type PhenotypicFeature
# Running: C-X-C motif chemokine receptor 4 --> output type Gene
# Running: C-X-C motif chemokine receptor 4 --> output type SequenceVariant
# Running: C-X-C motif chemokine receptor 4 --> output type ChemicalSubstance
# Running: C-X-C motif chemokine receptor 4 --> output type Disease
# Running: C-X-C motif chemokine receptor 4 --> output type MolecularActivity
# Running: C-X-C motif chemokine receptor 4 --> output type BiologicalProcess
# Running: C-X-C motif chemokine receptor 4 --> output type CellularComponent
# Running: C-X-C motif chemokine receptor 4 --> output type Pathway
# Running: C-X-C motif chemokine receptor 4 --> output type AnatomicalEntity
# Running: C-X-C motif chemokine receptor 4 --> output type PhenotypicFeature
# Running: phosphatase and tensin homolog --> output type Gene
# Running: phosphatase and tensin homolog --> output type SequenceVariant
# Running: phosphatase and tensin homolog --> output type ChemicalSubstance
# Running: phosphatase and tensin homolog --> output type Disease
# Running: phosphatase and tensin homolog --> output type MolecularActivity
# Running: phosphatase and tensin homolog --> output type BiologicalProcess
# Running: phosphatase and tensin homolog --> output type CellularComponent
# Running: phosphatase and tensin homolog --> output type Pathway
# Running: phosphatase and tensin homolog --> output type AnatomicalEntity
# Running: phosphatase and tensin homolog --> output type PhenotypicFeature
# Running: estrogen receptor 1 --> output type Gene
# Running: estrogen receptor 1 --> output type SequenceVariant
# Running: estrogen receptor 1 --> output type ChemicalSubstance
# Running: estrogen receptor 1 --> output type Disease
# Running: estrogen receptor 1 --> output type MolecularActivity
# Running: estrogen receptor 1 --> output type BiologicalProcess
# Running: estrogen receptor 1 --> output type CellularComponent
# Running: estrogen receptor 1 --> output type Pathway
# Running: estrogen receptor 1 --> output type AnatomicalEntity
# Running: estrogen receptor 1 --> output type PhenotypicFeature
# Running: CRK proto-oncogene, adaptor protein --> output type Gene
# Running: CRK proto-oncogene, adaptor protein --> output type SequenceVariant
# Running: CRK proto-oncogene, adaptor protein --> output type ChemicalSubstance
# Running: CRK proto-oncogene, adaptor protein --> output type Disease
# Running: CRK proto-oncogene, adaptor protein --> output type MolecularActivity
# Running: CRK proto-oncogene, adaptor protein --> output type BiologicalProcess
# Running: CRK proto-oncogene, adaptor protein --> output type CellularComponent
# Running: CRK proto-oncogene, adaptor protein --> output type Pathway
# Running: CRK proto-oncogene, adaptor protein --> output type AnatomicalEntity
# Running: CRK proto-oncogene, adaptor protein --> output type PhenotypicFeature
# Running: cytokine inducible SH2 containing protein --> output type Gene
# Running: cytokine inducible SH2 containing protein --> output type SequenceVariant
# Running: cytokine inducible SH2 containing protein --> output type ChemicalSubstance
# Running: cytokine inducible SH2 containing protein --> output type Disease
# Running: cytokine inducible SH2 containing protein --> output type MolecularActivity
# Running: cytokine inducible SH2 containing protein --> output type BiologicalProcess
# Running: cytokine inducible SH2 containing protein --> output type CellularComponent
# Running: cytokine inducible SH2 containing protein --> output type Pathway
# Running: cytokine inducible SH2 containing protein --> output type AnatomicalEntity
# Running: cytokine inducible SH2 containing protein --> output type PhenotypicFeature
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type Gene
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type SequenceVariant
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type ChemicalSubstance
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type Disease
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type MolecularActivity
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type BiologicalProcess
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type CellularComponent
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type Pathway
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type AnatomicalEntity
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type PhenotypicFeature
# Running: neurotrophic receptor tyrosine kinase 1 --> output type Gene
# Running: neurotrophic receptor tyrosine kinase 1 --> output type SequenceVariant
# Running: neurotrophic receptor tyrosine kinase 1 --> output type ChemicalSubstance
# Running: neurotrophic receptor tyrosine kinase 1 --> output type Disease
# Running: neurotrophic receptor tyrosine kinase 1 --> output type MolecularActivity
# Running: neurotrophic receptor tyrosine kinase 1 --> output type BiologicalProcess
# Running: neurotrophic receptor tyrosine kinase 1 --> output type CellularComponent
# Running: neurotrophic receptor tyrosine kinase 1 --> output type Pathway
# Running: neurotrophic receptor tyrosine kinase 1 --> output type AnatomicalEntity
# Running: neurotrophic receptor tyrosine kinase 1 --> output type PhenotypicFeature
# Running: C-C motif chemokine ligand 5 --> output type Gene
# Running: C-C motif chemokine ligand 5 --> output type SequenceVariant
# Running: C-C motif chemokine ligand 5 --> output type ChemicalSubstance
# Running: C-C motif chemokine ligand 5 --> output type Disease
# Running: C-C motif chemokine ligand 5 --> output type MolecularActivity
# Running: C-C motif chemokine ligand 5 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 5 --> output type CellularComponent
# Running: C-C motif chemokine ligand 5 --> output type Pathway
# Running: C-C motif chemokine ligand 5 --> output type AnatomicalEntity
# Running: C-C motif chemokine ligand 5 --> output type PhenotypicFeature
# Running: C-C motif chemokine receptor 5 --> output type Gene
# Running: C-C motif chemokine receptor 5 --> output type SequenceVariant
# Running: C-C motif chemokine receptor 5 --> output type ChemicalSubstance
# Running: C-C motif chemokine receptor 5 --> output type Disease
# Running: C-C motif chemokine receptor 5 --> output type MolecularActivity
# Running: C-C motif chemokine receptor 5 --> output type BiologicalProcess
# Running: C-C motif chemokine receptor 5 --> output type CellularComponent
# Running: C-C motif chemokine receptor 5 --> output type Pathway
# Running: C-C motif chemokine receptor 5 --> output type AnatomicalEntity
# Running: C-C motif chemokine receptor 5 --> output type PhenotypicFeature
# Running: integrin subunit alpha M --> output type Gene
# Running: integrin subunit alpha M --> output type SequenceVariant
# Running: integrin subunit alpha M --> output type ChemicalSubstance
# Running: integrin subunit alpha M --> output type Disease
# Running: integrin subunit alpha M --> output type MolecularActivity
# Running: integrin subunit alpha M --> output type BiologicalProcess
# Running: integrin subunit alpha M --> output type CellularComponent
# Running: integrin subunit alpha M --> output type Pathway
# Running: integrin subunit alpha M --> output type AnatomicalEntity
# Running: integrin subunit alpha M --> output type PhenotypicFeature
# Running: matrix metallopeptidase 2 --> output type Gene
# Running: matrix metallopeptidase 2 --> output type SequenceVariant
# Running: matrix metallopeptidase 2 --> output type ChemicalSubstance
# Running: matrix metallopeptidase 2 --> output type Disease
# Running: matrix metallopeptidase 2 --> output type MolecularActivity
# Running: matrix metallopeptidase 2 --> output type BiologicalProcess
# Running: matrix metallopeptidase 2 --> output type CellularComponent
# Running: matrix metallopeptidase 2 --> output type Pathway
# Running: matrix metallopeptidase 2 --> output type AnatomicalEntity
# Running: matrix metallopeptidase 2 --> output type PhenotypicFeature
# Running: androgen receptor --> output type Gene
# Running: androgen receptor --> output type SequenceVariant
# Running: androgen receptor --> output type ChemicalSubstance
# Running: androgen receptor --> output type Disease
# Running: androgen receptor --> output type MolecularActivity
# Running: androgen receptor --> output type BiologicalProcess
# Running: androgen receptor --> output type CellularComponent
# Running: androgen receptor --> output type Pathway
# Running: androgen receptor --> output type AnatomicalEntity
# Running: androgen receptor --> output type PhenotypicFeature
# Running: CD44 molecule (Indian blood group) --> output type Gene
# ...
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type SequenceVariant
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type ChemicalSubstance
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type Disease
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type MolecularActivity
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type BiologicalProcess
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type CellularComponent
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type Pathway
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type AnatomicalEntity
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type PhenotypicFeature
# Running: cannabinoid receptor 1 --> output type Gene
# Running: cannabinoid receptor 1 --> output type SequenceVariant
# Running: cannabinoid receptor 1 --> output type ChemicalSubstance
# Running: cannabinoid receptor 1 --> output type Disease
# Running: cannabinoid receptor 1 --> output type MolecularActivity
# Running: cannabinoid receptor 1 --> output type BiologicalProcess
# Running: cannabinoid receptor 1 --> output type CellularComponent
# Running: cannabinoid receptor 1 --> output type Pathway
# Running: cannabinoid receptor 1 --> output type AnatomicalEntity
# Running: cannabinoid receptor 1 --> output type PhenotypicFeature
# Running: cholecystokinin --> output type Gene
# Running: cholecystokinin --> output type SequenceVariant
# Running: cholecystokinin --> output type ChemicalSubstance
# Running: cholecystokinin --> output type Disease
# Running: cholecystokinin --> output type MolecularActivity
# Running: cholecystokinin --> output type BiologicalProcess
# Running: cholecystokinin --> output type CellularComponent
# Running: cholecystokinin --> output type Pathway
# Running: cholecystokinin --> output type AnatomicalEntity
# Running: cholecystokinin --> output type PhenotypicFeature
# Running: von Willebrand factor --> output type Gene
# Running: von Willebrand factor --> output type SequenceVariant
# Running: von Willebrand factor --> output type ChemicalSubstance
# Running: von Willebrand factor --> output type Disease
# Running: von Willebrand factor --> output type MolecularActivity
# Running: von Willebrand factor --> output type BiologicalProcess
# Running: von Willebrand factor --> output type CellularComponent
# Running: von Willebrand factor --> output type Pathway
# Running: von Willebrand factor --> output type AnatomicalEntity
# Running: von Willebrand factor --> output type PhenotypicFeature
# Running: heat shock protein family A (Hsp70) member 8 --> output type Gene
# Running: heat shock protein family A (Hsp70) member 8 --> output type SequenceVariant
# Running: heat shock protein family A (Hsp70) member 8 --> output type ChemicalSubstance
# Running: heat shock protein family A (Hsp70) member 8 --> output type Disease
# Running: heat shock protein family A (Hsp70) member 8 --> output type MolecularActivity
# Running: heat shock protein family A (Hsp70) member 8 --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 8 --> output type CellularComponent
# Running: heat shock protein family A (Hsp70) member 8 --> output type Pathway
# Running: heat shock protein family A (Hsp70) member 8 --> output type AnatomicalEntity
# Running: heat shock protein family A (Hsp70) member 8 --> output type PhenotypicFeature
# Running: CD69 molecule --> output type Gene
# Running: CD69 molecule --> output type SequenceVariant
# Running: CD69 molecule --> output type ChemicalSubstance
# Running: CD69 molecule --> output type Disease
# Running: CD69 molecule --> output type MolecularActivity
# Running: CD69 molecule --> output type BiologicalProcess
# Running: CD69 molecule --> output type CellularComponent
# Running: CD69 molecule --> output type Pathway
# Running: CD69 molecule --> output type AnatomicalEntity
# Running: CD69 molecule --> output type PhenotypicFeature
# Running: interleukin 3 --> output type Gene
# Running: interleukin 3 --> output type SequenceVariant
# Running: interleukin 3 --> output type ChemicalSubstance
# Running: interleukin 3 --> output type Disease
# Running: interleukin 3 --> output type MolecularActivity
# Running: interleukin 3 --> output type BiologicalProcess
# Running: interleukin 3 --> output type CellularComponent
# Running: interleukin 3 --> output type Pathway
# Running: interleukin 3 --> output type AnatomicalEntity
# Running: interleukin 3 --> output type PhenotypicFeature
# Running: pro-platelet basic protein --> output type Gene
# Running: pro-platelet basic protein --> output type SequenceVariant
# Running: pro-platelet basic protein --> output type ChemicalSubstance
# Running: pro-platelet basic protein --> output type Disease
# Running: pro-platelet basic protein --> output type MolecularActivity
# Running: pro-platelet basic protein --> output type BiologicalProcess
# Running: pro-platelet basic protein --> output type CellularComponent
# Running: pro-platelet basic protein --> output type Pathway
# Running: pro-platelet basic protein --> output type AnatomicalEntity
# Running: pro-platelet basic protein --> output type PhenotypicFeature
# Running: prohibitin --> output type Gene
# Running: prohibitin --> output type SequenceVariant
# Running: prohibitin --> output type ChemicalSubstance
# Running: prohibitin --> output type Disease
# Running: prohibitin --> output type MolecularActivity
# Running: prohibitin --> output type BiologicalProcess
# Running: prohibitin --> output type CellularComponent
# Running: prohibitin --> output type Pathway
# Running: prohibitin --> output type AnatomicalEntity
# Running: prohibitin --> output type PhenotypicFeature
# Running: kallikrein related peptidase 3 --> output type Gene
# Running: kallikrein related peptidase 3 --> output type SequenceVariant
# Running: kallikrein related peptidase 3 --> output type ChemicalSubstance
# Running: kallikrein related peptidase 3 --> output type Disease
# Running: kallikrein related peptidase 3 --> output type MolecularActivity
# Running: kallikrein related peptidase 3 --> output type BiologicalProcess
# Running: kallikrein related peptidase 3 --> output type CellularComponent
# Running: kallikrein related peptidase 3 --> output type Pathway
# Running: kallikrein related peptidase 3 --> output type AnatomicalEntity
# Running: kallikrein related peptidase 3 --> output type PhenotypicFeature
# Running: notch receptor 1 --> output type Gene
# Running: notch receptor 1 --> output type SequenceVariant
# Running: notch receptor 1 --> output type ChemicalSubstance
# Running: notch receptor 1 --> output type Disease
# Running: notch receptor 1 --> output type MolecularActivity
# Running: notch receptor 1 --> output type BiologicalProcess
# Running: notch receptor 1 --> output type CellularComponent
# Running: notch receptor 1 --> output type Pathway
# Running: notch receptor 1 --> output type AnatomicalEntity
# Running: notch receptor 1 --> output type PhenotypicFeature
# Running: advanced glycosylation end-product specific receptor --> output type Gene
# Running: advanced glycosylation end-product specific receptor --> output type SequenceVariant
# Running: advanced glycosylation end-product specific receptor --> output type ChemicalSubstance
# Running: advanced glycosylation end-product specific receptor --> output type Disease
# Running: advanced glycosylation end-product specific receptor --> output type MolecularActivity
# Running: advanced glycosylation end-product specific receptor --> output type BiologicalProcess
# Running: advanced glycosylation end-product specific receptor --> output type CellularComponent
# Running: advanced glycosylation end-product specific receptor --> output type Pathway
# Running: advanced glycosylation end-product specific receptor --> output type AnatomicalEntity
# Running: advanced glycosylation end-product specific receptor --> output type PhenotypicFeature
# Running: fibroblast growth factor receptor 1 --> output type Gene
# Running: fibroblast growth factor receptor 1 --> output type SequenceVariant
# Running: fibroblast growth factor receptor 1 --> output type ChemicalSubstance
# Running: fibroblast growth factor receptor 1 --> output type Disease
# Running: fibroblast growth factor receptor 1 --> output type MolecularActivity
# Running: fibroblast growth factor receptor 1 --> output type BiologicalProcess
# Running: fibroblast growth factor receptor 1 --> output type CellularComponent
# Running: fibroblast growth factor receptor 1 --> output type Pathway
# Running: fibroblast growth factor receptor 1 --> output type AnatomicalEntity
# Running: fibroblast growth factor receptor 1 --> output type PhenotypicFeature
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type Gene
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type SequenceVariant
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type ChemicalSubstance
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type Disease
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type MolecularActivity
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type BiologicalProcess
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type CellularComponent
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type Pathway
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type AnatomicalEntity
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type PhenotypicFeature
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type Gene
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type SequenceVariant
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type ChemicalSubstance
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type Disease
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type MolecularActivity
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type BiologicalProcess
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type CellularComponent
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type Pathway
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type AnatomicalEntity
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type PhenotypicFeature
# Running: Cbl proto-oncogene --> output type Gene
# Running: Cbl proto-oncogene --> output type SequenceVariant
# Running: Cbl proto-oncogene --> output type ChemicalSubstance
# Running: Cbl proto-oncogene --> output type Disease
# Running: Cbl proto-oncogene --> output type MolecularActivity
# Running: Cbl proto-oncogene --> output type BiologicalProcess
# Running: Cbl proto-oncogene --> output type CellularComponent
# Running: Cbl proto-oncogene --> output type Pathway
# Running: Cbl proto-oncogene --> output type AnatomicalEntity
# Running: Cbl proto-oncogene --> output type PhenotypicFeature
# Running: transferrin receptor --> output type Gene
# Running: transferrin receptor --> output type SequenceVariant
# Running: transferrin receptor --> output type ChemicalSubstance
# Running: transferrin receptor --> output type Disease
# Running: transferrin receptor --> output type MolecularActivity
# Running: transferrin receptor --> output type BiologicalProcess
# Running: transferrin receptor --> output type CellularComponent
# Running: transferrin receptor --> output type Pathway
# Running: transferrin receptor --> output type AnatomicalEntity
# Running: transferrin receptor --> output type PhenotypicFeature
# Running: CD8a molecule --> output type Gene
# Running: CD8a molecule --> output type SequenceVariant
# Running: CD8a molecule --> output type ChemicalSubstance
# Running: CD8a molecule --> output type Disease
# Running: CD8a molecule --> output type MolecularActivity
# Running: CD8a molecule --> output type BiologicalProcess
# Running: CD8a molecule --> output type CellularComponent
# Running: CD8a molecule --> output type Pathway
# Running: CD8a molecule --> output type AnatomicalEntity
# Running: CD8a molecule --> output type PhenotypicFeature
# Running: neural cell adhesion molecule 1 --> output type Gene
# Running: neural cell adhesion molecule 1 --> output type SequenceVariant
# Running: neural cell adhesion molecule 1 --> output type ChemicalSubstance
# Running: neural cell adhesion molecule 1 --> output type Disease
# Running: neural cell adhesion molecule 1 --> output type MolecularActivity
# Running: neural cell adhesion molecule 1 --> output type BiologicalProcess
# Running: neural cell adhesion molecule 1 --> output type CellularComponent
# Running: neural cell adhesion molecule 1 --> output type Pathway
# Running: neural cell adhesion molecule 1 --> output type AnatomicalEntity
# Running: neural cell adhesion molecule 1 --> output type PhenotypicFeature
# Running: nuclear receptor subfamily 3 group C member 1 --> output type Gene
# Running: nuclear receptor subfamily 3 group C member 1 --> output type SequenceVariant
# Running: nuclear receptor subfamily 3 group C member 1 --> output type ChemicalSubstance
# Running: nuclear receptor subfamily 3 group C member 1 --> output type Disease
# Running: nuclear receptor subfamily 3 group C member 1 --> output type MolecularActivity
# Running: nuclear receptor subfamily 3 group C member 1 --> output type BiologicalProcess
# Running: nuclear receptor subfamily 3 group C member 1 --> output type CellularComponent
# Running: nuclear receptor subfamily 3 group C member 1 --> output type Pathway
# Running: nuclear receptor subfamily 3 group C member 1 --> output type AnatomicalEntity
# Running: nuclear receptor subfamily 3 group C member 1 --> output type PhenotypicFeature
# Running: interferon regulatory factor 1 --> output type Gene
# Running: interferon regulatory factor 1 --> output type SequenceVariant
# Running: interferon regulatory factor 1 --> output type ChemicalSubstance
# Running: interferon regulatory factor 1 --> output type Disease
# Running: interferon regulatory factor 1 --> output type MolecularActivity
# Running: interferon regulatory factor 1 --> output type BiologicalProcess
# Running: interferon regulatory factor 1 --> output type CellularComponent
# Running: interferon regulatory factor 1 --> output type Pathway
# Running: interferon regulatory factor 1 --> output type AnatomicalEntity
# Running: interferon regulatory factor 1 --> output type PhenotypicFeature
# Running: cyclin dependent kinase 2 --> output type Gene
# Running: cyclin dependent kinase 2 --> output type SequenceVariant
# Running: cyclin dependent kinase 2 --> output type ChemicalSubstance
# Running: cyclin dependent kinase 2 --> output type Disease
# Running: cyclin dependent kinase 2 --> output type MolecularActivity
# Running: cyclin dependent kinase 2 --> output type BiologicalProcess
# Running: cyclin dependent kinase 2 --> output type CellularComponent
# Running: cyclin dependent kinase 2 --> output type Pathway
# Running: cyclin dependent kinase 2 --> output type AnatomicalEntity
# Running: cyclin dependent kinase 2 --> output type PhenotypicFeature
# Running: BCL2 apoptosis regulator --> output type Gene
# Running: BCL2 apoptosis regulator --> output type SequenceVariant
# Running: BCL2 apoptosis regulator --> output type ChemicalSubstance
# Running: BCL2 apoptosis regulator --> output type Disease
# Running: BCL2 apoptosis regulator --> output type MolecularActivity
# Running: BCL2 apoptosis regulator --> output type BiologicalProcess
# Running: BCL2 apoptosis regulator --> output type CellularComponent
# Running: BCL2 apoptosis regulator --> output type Pathway
# Running: BCL2 apoptosis regulator --> output type AnatomicalEntity
# Running: BCL2 apoptosis regulator --> output type PhenotypicFeature

# %%
# %store gene_edges_out
# %store -r gene_edges_out
# Out:
# Stored 'gene_edges_out' (dict)

# %% [markdown]
# ## 7. Assemble Genes related to both Disease and Disease Symptoms

# %%
# assemble final dictionary that includes all metrics for gene's connections to disease (direct and through one node)
# as well as to disease symptoms
final_dict = {}

for x in relevant_top_genes_list:
    symptoms_to_hpids = [];
    for symptom in symptoms_results[x]['related_symptoms']: 
        symptoms_to_hpids.append(symptom_to_hpid_dict[symptom])
    unique_symptoms = list(dict.fromkeys(symptoms_to_hpids))
    final_dict[x] = {
        "disease_to_gene_occurrences" : disease_to_gene_results[x]['gene_count'] if x in disease_to_gene_results else 0,
        "disease_to_gene_pub_counts" : len(disease_to_gene_results[x]['publications']) if x in disease_to_gene_results else 0,
        "disease_to_int_to_gen_occurrences" : disease_to_all_nodes_to_genes_results[x]['gene_count'] if x in disease_to_all_nodes_to_genes_results else 0,
        "disease_to_int_to_gene_pubs" : len(disease_to_all_nodes_to_genes_results[x]['publications']) if x in disease_to_all_nodes_to_genes_results else 0,
        "disease_symtpoms_gene_related_to" : symptoms_results[x]['related_symptoms'],
        "disease_symtpoms_gene_related_to_count" : len(symptoms_results[x]['related_symptoms']),
        "unique_symptoms_count": len(unique_symptoms),
        "gene_to_symptoms_pub_counts" : len(symptoms_results[x]['publications']),
        "gene_edges_out": gene_edges_out[x]
    }

# %%
final_df = pd.DataFrame(final_dict).transpose()
final_df
# Out:
#         disease_to_gene_occurrences disease_to_gene_pub_counts  \
# CRP                               2                          0
# TMPRSS2                           2                          0
# ACE2                              2                          0
# CFTR                              1                          0
# CD4                               1                          0
# ...                             ...                        ...
# NCAM1                             1                          0
# NR3C1                             0                          0
# IRF1                              0                          0
# CDK2                              0                          0
# BCL2                              0                          0
#
#         disease_to_int_to_gen_occurrences disease_to_int_to_gene_pubs  \
# CRP                                   362                         156
# TMPRSS2                                97                         202
# ACE2                                  268                         272
# CFTR                                  462                        1111
# CD4                                   970                        3542
# ...                                   ...                         ...
# NCAM1                                 305                         395
# NR3C1                                 304                         302
# IRF1                                  304                         292
# CDK2                                  304                         336
# BCL2                                  303                         787
#
#                     disease_symtpoms_gene_related_to  \
# CRP                                       [DIARRHEA]
# TMPRSS2                                   [DIARRHEA]
# ACE2                                      [DIARRHEA]
# CFTR     [ABNORMAL LIVER ENZYMES, FATIGUE, DIARRHEA]
# CD4          [DIARRHEA, DIARRHEA, DIARRHEA, FATIGUE]
# ...                                              ...
# NCAM1                                     [DIARRHEA]
# NR3C1                  [FATIGUE, DIARRHEA, DIARRHEA]
# IRF1                                      [DIARRHEA]
# CDK2                                      [DIARRHEA]
# BCL2                                      [DIARRHEA]
#
#         disease_symtpoms_gene_related_to_count unique_symptoms_count  \
# CRP                                          1                     1
# TMPRSS2                                      1                     1
# ACE2                                         1                     1
# CFTR                                         3                     3
# CD4                                          4                     2
# ...                                        ...                   ...
# NCAM1                                        1                     1
# NR3C1                                        3                     2
# IRF1                                         1                     1
# CDK2                                         1                     1
# BCL2                                         1                     1
#
#         gene_to_symptoms_pub_counts gene_edges_out
# CRP                               0           2127
# TMPRSS2                           0            502
# ACE2                              0           1050
# CFTR                              0           1918
# CD4                               3           7913
# ...                             ...            ...
# NCAM1                             0           1684
# NR3C1                             1           2284
# IRF1                              0           1394
# CDK2                              0           3378
# BCL2                              0           4482
#
# [211 rows x 9 columns]

# %%
final_df.to_csv(disease_csv_file, index = True)

# %% [markdown]
# ## 8. EXTRA --- WEIGHTING RESULTS

# %%
# Symptom Table Weighting
import math

# disease_symptom_df = disease_symptom_df.head(-1)
# disease_symptom_df

# in this case, don't weight edges out
disease_symptom_df.loc[:, 'edges_out_count'] = 10

individual_symptom_scores = [];
for index,x in disease_symptom_df.iterrows():
    if(x["frequency"] == "Very frequent"):
        score = 20 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Frequent"):
        score = 15 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Occasional"):
        score = 10 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Rare"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Unknown"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    individual_symptom_scores.append(score)

# print(len(individual_symptom_scores))
disease_symptom_df["ISS"] = individual_symptom_scores
disease_symptom_df
# Out:
#                                                         names frequency  \
# HP:0040133  [ABNORMAL SERUM FERRITIN, ABNORMAL PLASMA FERR...   Unknown
# HP:0011134                      [LOW-GRADE FEVER, MILD FEVER]   Unknown
# HP:0011897  [NEUTROPHILIA, INCREASED BLOOD NEUTROPHIL COUNTS]   Unknown
# HP:0005115  [SUPRAVENTRICULAR ARRHYTHMIA, ARRHYTHMIAS, SUP...   Unknown
# HP:0002105       [HEMOPTYSIS, COUGHING UP BLOOD, HAEMOPTYSIS]   Unknown
# HP:0012819        [MYOCARDITIS, INFLAMMATION OF HEART MUSCLE]   Unknown
# HP:0002018                                           [NAUSEA]   Unknown
# HP:0002039                                         [ANOREXIA]   Unknown
# HP:0012735                                  [COUGH, COUGHING]   Unknown
# HP:0003326                [MYALGIA, MUSCLE ACHE, MUSCLE PAIN]   Unknown
# HP:0001298                                   [ENCEPHALOPATHY]   Unknown
# HP:0001882  [LEUKOPENIA, DECREASED BLOOD LEUKOCYTE NUMBER,...   Unknown
# HP:0002315                              [HEADACHE, HEADACHES]   Unknown
# HP:0012378                        [FATIGUE, TIRED, TIREDNESS]   Unknown
# HP:0002014                [DIARRHEA, DIARRHOEA, WATERY STOOL]   Unknown
# HP:0002910  [ELEVATED HEPATIC TRANSAMINASE, ABNORMAL LIVER...   Unknown
# HP:0002098  [RESPIRATORY DISTRESS, BREATHING DIFFICULTIES,...   Unknown
# HP:0033050                         [THROAT PAIN, SORE THROAT]   Unknown
# HP:0025089  [FECULENT VOMITING, FECAL VOMITING, STERCORACE...   Unknown
# HP:0500039  [CONJUNCTIVAL CICATRIZATION, CICATRICIAL CONJU...   Unknown
# HP:0032436                [ABNORMAL C-REACTIVE PROTEIN LEVEL]   Unknown
# HP:0033006                          [DIFFUSE ALVEOLAR DAMAGE]   Unknown
#
#             edges_out_count       ISS
# HP:0040133               10  1.581139
# HP:0011134               10  1.581139
# HP:0011897               10  1.581139
# HP:0005115               10  1.581139
# HP:0002105               10  1.581139
# HP:0012819               10  1.581139
# HP:0002018               10  1.581139
# HP:0002039               10  1.581139
# HP:0012735               10  1.581139
# HP:0003326               10  1.581139
# HP:0001298               10  1.581139
# HP:0001882               10  1.581139
# HP:0002315               10  1.581139
# HP:0012378               10  1.581139
# HP:0002014               10  1.581139
# HP:0002910               10  1.581139
# HP:0002098               10  1.581139
# HP:0033050               10  1.581139
# HP:0025089               10  1.581139
# HP:0500039               10  1.581139
# HP:0032436               10  1.581139
# HP:0033006               10  1.581139

# %%
symptom_score_dict = {}
for index, row in disease_symptom_df.iterrows():
    # print(row)
    for x in row["names"]:
        symptom_score_dict[x.lower()] = row["ISS"]

final_symptom_scores = []
for index, row in final_df.iterrows():
    current_score = 0
    current_symptoms = row["disease_symtpoms_gene_related_to"]
    for x in current_symptoms:
        singular = x.lower()[0:-1]
        plural = x.lower() + 's'
        if(x.lower() in symptom_score_dict):
            current_score = current_score + symptom_score_dict[x.lower()]
        elif(plural in symptom_score_dict):
            current_score = current_score + symptom_score_dict[plural]
        elif(singular in symptom_score_dict):
            current_score = current_score + symptom_score_dict[singular]
    final_symptom_scores.append(current_score)

final_df["final_symptom_score"] = final_symptom_scores

range_direct = max(list(final_df["disease_to_gene_occurrences"])) - min(list(final_df["disease_to_gene_occurrences"]))
min_direct = min(list(final_df["disease_to_gene_occurrences"]))

range_two_step = max(list(final_df["disease_to_int_to_gen_occurrences"])) - min(list(final_df["disease_to_int_to_gen_occurrences"]))
min_two_step = min(list(final_df["disease_to_int_to_gen_occurrences"]))

range_symptoms = max(list(final_df["final_symptom_score"])) - min(list(final_df["final_symptom_score"]))
min_symptoms = min(list(final_df["final_symptom_score"]))
relevance_score = []
for index, row in final_df.iterrows():
    current_direct = final_df["disease_to_gene_occurrences"][index]
    current_two_step = final_df["disease_to_int_to_gen_occurrences"][index]
    current_symptom = final_df["final_symptom_score"][index]
    direct_weighted = (current_direct - min_direct)/range_direct
    two_step_weighted = (current_two_step - min_two_step)/range_two_step
    symptom_weighted = (current_symptom - min_symptoms)/range_symptoms

    current_rs = ((direct_weighted + two_step_weighted)*symptom_weighted)/math.sqrt(final_df["gene_edges_out"][index])
    relevance_score.append(current_rs)

relevance_score_norm = [(float(i) - min(relevance_score))/(max(relevance_score)-min(relevance_score)) for i in relevance_score]
final_df["relevance_score"] = relevance_score_norm
# sort by relevance score
final_df = final_df.sort_values(by=['relevance_score'], ascending=False)

# %%
final_df
# Out:
#        disease_to_gene_occurrences disease_to_gene_pub_counts  \
# TNF                              1                          0
# IFNA1                            1                          0
# CSF3                             1                          0
# VEGFA                            1                          0
# IL2                              1                          0
# ...                            ...                        ...
# STAT5A                           0                          0
# C5AR1                            0                          0
# PTPN11                           0                          0
# MYC                              0                          0
# BCL2                             0                          0
#
#        disease_to_int_to_gen_occurrences disease_to_int_to_gene_pubs  \
# TNF                                 1683                        8797
# IFNA1                               1043                        3605
# CSF3                                 228                         150
# VEGFA                                949                        4342
# IL2                                  759                        2205
# ...                                  ...                         ...
# STAT5A                               466                        1088
# C5AR1                                469                         554
# PTPN11                               470                         740
# MYC                                  479                         614
# BCL2                                 303                         787
#
#                          disease_symtpoms_gene_related_to  \
# TNF     [ANOREXIA, ANOREXIA, ANOREXIA, ANOREXIA, COUGH...
# IFNA1   [ANOREXIA, FATIGUE, FATIGUE, FATIGUE, NAUSEA, ...
# CSF3             [HEADACHE, DIARRHEA, DIARRHEA, DIARRHEA]
# VEGFA   [FATIGUE, FATIGUE, COUGHING, COUGHING, ANOREXI...
# IL2     [DIARRHEA, DIARRHEA, DIARRHEA, FATIGUE, ANOREXIA]
# ...                                                   ...
# STAT5A                                         [DIARRHEA]
# C5AR1                              [RESPIRATORY DISTRESS]
# PTPN11                                         [DIARRHEA]
# MYC                                            [DIARRHEA]
# BCL2                                           [DIARRHEA]
#
#        disease_symtpoms_gene_related_to_count unique_symptoms_count  \
# TNF                                        14                     5
# IFNA1                                       6                     4
# CSF3                                        4                     2
# VEGFA                                       6                     4
# IL2                                         5                     3
# ...                                       ...                   ...
# STAT5A                                      1                     1
# C5AR1                                       1                     1
# PTPN11                                      1                     1
# MYC                                         1                     1
# BCL2                                        1                     1
#
#        gene_to_symptoms_pub_counts gene_edges_out  final_symptom_score  \
# TNF                             23          19386            22.135944
# IFNA1                            7           7673             9.486833
# CSF3                             1            923             6.324555
# VEGFA                            4          11194             9.486833
# IL2                              2           5767             7.905694
# ...                            ...            ...                  ...
# STAT5A                           0           3516             1.581139
# C5AR1                            1           2336             1.581139
# PTPN11                           0           2897             1.581139
# MYC                              0           3503             1.581139
# BCL2                             0           4482             1.581139
#
#         relevance_score
# TNF            1.000000
# IFNA1          0.452588
# CSF3           0.433210
# VEGFA          0.355403
# IL2            0.352630
# ...                 ...
# STAT5A         0.000000
# C5AR1          0.000000
# PTPN11         0.000000
# MYC            0.000000
# BCL2           0.000000
#
# [211 rows x 11 columns]

# %%
final_df.to_csv(disease_csv_weighted_file, index = True)

# %% [markdown]
# ## 9. Look at pathways and biological processes

# %%
gene_to_pathways = predict_many(relevant_gene_inputs, ['Pathway'])
# Out:
# Running: C-reactive protein --> output type Pathway
# Running: transmembrane serine protease 2 --> output type Pathway
# Running: angiotensin I converting enzyme 2 --> output type Pathway
# Running: CF transmembrane conductance regulator --> output type Pathway
# Running: CD4 molecule --> output type Pathway
# Running: carboxypeptidase B2 --> output type Pathway
# Running: sirtuin 4 --> output type Pathway
# Running: apolipoprotein H --> output type Pathway
# Running: sirtuin 1 --> output type Pathway
# Running: growth arrest and DNA damage inducible beta --> output type Pathway
# Running: mitogen-activated protein kinase 1 --> output type Pathway
# Running: oxytocin/neurophysin I prepropeptide --> output type Pathway
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type Pathway
# Running: MEFV innate immuity regulator, pyrin --> output type Pathway
# Running: plasminogen activator, tissue type --> output type Pathway
# Running: Fc fragment of IgG receptor and transporter --> output type Pathway
# Running: serpin family E member 1 --> output type Pathway
# Running: complement C5 --> output type Pathway
# Running: myeloperoxidase --> output type Pathway
# Running: colony stimulating factor 3 --> output type Pathway
# Running: C-C motif chemokine ligand 2 --> output type Pathway
# Running: interleukin 2 --> output type Pathway
# Running: cathepsin C --> output type Pathway
# Running: interferon gamma --> output type Pathway
# Running: mitogen-activated protein kinase 14 --> output type Pathway
# Running: interleukin 4 --> output type Pathway
# Running: microtubule associated protein RP/EB family member 3 --> output type Pathway
# Running: troponin T2, cardiac type --> output type Pathway
# Running: transthyretin --> output type Pathway
# Running: galectin like --> output type Pathway
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type Pathway
# Running: 5', 3'-nucleotidase, cytosolic --> output type Pathway
# Running: complement C3 --> output type Pathway
# Running: SH2 domain containing 3A --> output type Pathway
# Running: fibrinogen like 2 --> output type Pathway
# Running: sirtuin 2 --> output type Pathway
# Running: tumor necrosis factor --> output type Pathway
# Running: interferon alpha 1 --> output type Pathway
# Running: tumor protein p53 --> output type Pathway
# Running: vascular endothelial growth factor A --> output type Pathway
# Running: AKT serine/threonine kinase 1 --> output type Pathway
# Running: epidermal growth factor receptor --> output type Pathway
# Running: interleukin 6 --> output type Pathway
# Running: transforming growth factor beta 1 --> output type Pathway
# Running: insulin --> output type Pathway
# Running: catalase --> output type Pathway
# Running: toll like receptor 4 --> output type Pathway
# Running: matrix metallopeptidase 9 --> output type Pathway
# Running: signal transducer and activator of transcription 3 --> output type Pathway
# Running: interleukin 10 --> output type Pathway
# Running: cathelicidin antimicrobial peptide --> output type Pathway
# Running: mitogen-activated protein kinase 8 --> output type Pathway
# Running: leptin --> output type Pathway
# Running: proopiomelanocortin --> output type Pathway
# Running: Fas cell surface death receptor --> output type Pathway
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type Pathway
# Running: CD40 molecule --> output type Pathway
# Running: carbonic anhydrase 2 --> output type Pathway
# Running: albumin --> output type Pathway
# Running: RELA proto-oncogene, NF-kB subunit --> output type Pathway
# Running: C-X-C motif chemokine receptor 4 --> output type Pathway
# Running: phosphatase and tensin homolog --> output type Pathway
# Running: estrogen receptor 1 --> output type Pathway
# Running: CRK proto-oncogene, adaptor protein --> output type Pathway
# Running: cytokine inducible SH2 containing protein --> output type Pathway
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type Pathway
# Running: neurotrophic receptor tyrosine kinase 1 --> output type Pathway
# Running: C-C motif chemokine ligand 5 --> output type Pathway
# Running: C-C motif chemokine receptor 5 --> output type Pathway
# Running: integrin subunit alpha M --> output type Pathway
# Running: matrix metallopeptidase 2 --> output type Pathway
# Running: androgen receptor --> output type Pathway
# Running: CD44 molecule (Indian blood group) --> output type Pathway
# Running: mechanistic target of rapamycin kinase --> output type Pathway
# Running: cyclin dependent kinase inhibitor 1A --> output type Pathway
# Running: superoxide dismutase 1 --> output type Pathway
# Running: MYD88 innate immune signal transduction adaptor --> output type Pathway
# Running: MYC proto-oncogene, bHLH transcription factor --> output type Pathway
# Running: protein tyrosine phosphatase non-receptor type 11 --> output type Pathway
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type Pathway
# Running: complement C5a receptor 1 --> output type Pathway
# Running: signal transducer and activator of transcription 5A --> output type Pathway
# Running: tyrosine hydroxylase --> output type Pathway
# Running: C-X-C motif chemokine ligand 8 --> output type Pathway
# Running: heat shock protein family A (Hsp70) member 4 --> output type Pathway
# Running: angiotensin I converting enzyme --> output type Pathway
# Running: interleukin 2 receptor subunit alpha --> output type Pathway
# Running: TIMP metallopeptidase inhibitor 1 --> output type Pathway
# Running: CD14 molecule --> output type Pathway
# Running: toll like receptor 3 --> output type Pathway
# Running: somatostatin --> output type Pathway
# Running: estrogen receptor 2 --> output type Pathway
# Running: ATM serine/threonine kinase --> output type Pathway
# Running: parathyroid hormone --> output type Pathway
# Running: intercellular adhesion molecule 1 --> output type Pathway
# Running: angiogenin --> output type Pathway
# Running: G protein-coupled receptor kinase 2 --> output type Pathway
# Running: CD79a molecule --> output type Pathway
# Running: cyclin dependent kinase inhibitor 2A --> output type Pathway
# Running: renin --> output type Pathway
# Running: epidermal growth factor --> output type Pathway
# Running: CREB binding protein --> output type Pathway
# Running: interleukin 13 --> output type Pathway
# Running: C-C motif chemokine receptor 2 --> output type Pathway
# Running: BRCA1 DNA repair associated --> output type Pathway
# Running: high mobility group box 1 --> output type Pathway
# Running: TNF receptor superfamily member 1A --> output type Pathway
# Running: cytotoxic T-lymphocyte associated protein 4 --> output type Pathway
# Running: CD28 molecule --> output type Pathway
# Running: toll like receptor 7 --> output type Pathway
# Running: BCL2 associated X, apoptosis regulator --> output type Pathway
# Running: rhodopsin --> output type Pathway
# Running: hepatocyte growth factor-regulated tyrosine kinase substrate --> output type Pathway
# Running: lysyl oxidase --> output type Pathway
# Running: immunoglobulin heavy constant epsilon --> output type Pathway
# Running: microtubule associated protein tau --> output type Pathway
# Running: protein tyrosine phosphatase receptor type C --> output type Pathway
# Running: peroxisome proliferator activated receptor alpha --> output type Pathway
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit beta --> output type Pathway
# Running: prostaglandin-endoperoxide synthase 2 --> output type Pathway
# Running: cyclin D1 --> output type Pathway
# Running: spleen associated tyrosine kinase --> output type Pathway
# Running: heat shock protein family A (Hsp70) member 9 --> output type Pathway
# Running: peptidylprolyl isomerase B --> output type Pathway
# Running: C-X-C motif chemokine ligand 10 --> output type Pathway
# Running: peroxisome proliferator activated receptor gamma --> output type Pathway
# Running: activator of HSP90 ATPase activity 1 --> output type Pathway
# Running: glucose-6-phosphate isomerase --> output type Pathway
# Running: ras homolog family member A --> output type Pathway
# Running: BCR activator of RhoGEF and GTPase --> output type Pathway
# Running: hypoxia inducible factor 1 subunit alpha --> output type Pathway
# Running: signal transducer and activator of transcription 1 --> output type Pathway
# Running: heat shock protein family A (Hsp70) member 5 --> output type Pathway
# Running: interferon stimulated exonuclease gene 20 --> output type Pathway
# Running: signal transducer and activator of transcription 6 --> output type Pathway
# Running: interferon regulatory factor 3 --> output type Pathway
# Running: sequestosome 1 --> output type Pathway
# Running: ceruloplasmin --> output type Pathway
# Running: cAMP responsive element binding protein 1 --> output type Pathway
# Running: apurinic/apyrimidinic endodeoxyribonuclease 1 --> output type Pathway
# Running: suppressor of cytokine signaling 3 --> output type Pathway
# Running: interleukin 1 beta --> output type Pathway
# Running: erythropoietin --> output type Pathway
# Running: heat shock protein family B (small) member 1 --> output type Pathway
# Running: adenosine deaminase --> output type Pathway
# Running: transcription elongation factor A like 1 --> output type Pathway
# Running: major histocompatibility complex, class I, E --> output type Pathway
# Running: TNF receptor superfamily member 10b --> output type Pathway
# Running: vascular cell adhesion molecule 1 --> output type Pathway
# Running: early growth response 1 --> output type Pathway
# Running: colony stimulating factor 2 --> output type Pathway
# Running: CD34 molecule --> output type Pathway
# Running: catenin beta 1 --> output type Pathway
# Running: toll like receptor 2 --> output type Pathway
# Running: integrin subunit beta 2 --> output type Pathway
# Running: aryl hydrocarbon receptor --> output type Pathway
# Running: SMAD family member 3 --> output type Pathway
# Running: C-C motif chemokine ligand 3 --> output type Pathway
# Running: CD80 molecule --> output type Pathway
# Running: phosphoinositide-3-kinase regulatory subunit 1 --> output type Pathway
# Running: C-X3-C motif chemokine ligand 1 --> output type Pathway
# Running: musculin --> output type Pathway
# Running: amyloid P component, serum --> output type Pathway
# Running: CD19 molecule --> output type Pathway
# Running: chorionic somatomammotropin hormone 1 --> output type Pathway
# Running: tripartite motif containing 25 --> output type Pathway
# Running: KIT ligand --> output type Pathway
# Running: CD36 molecule --> output type Pathway
# Running: ras homolog family member D --> output type Pathway
# Running: tyrosine aminotransferase --> output type Pathway
# Running: interleukin 9 --> output type Pathway
# Running: elastase, neutrophil expressed --> output type Pathway
# Running: baculoviral IAP repeat containing 3 --> output type Pathway
# Running: ubiquitin C --> output type Pathway
# Running: forkhead box P3 --> output type Pathway
# Running: integrin subunit alpha X --> output type Pathway
# Running: MDM2 proto-oncogene --> output type Pathway
# Running: ribosomal protein SA --> output type Pathway
# Running: protein tyrosine phosphatase non-receptor type 6 --> output type Pathway
# Running: C-C motif chemokine ligand 20 --> output type Pathway
# Running: insulin like growth factor 1 --> output type Pathway
# Running: transferrin --> output type Pathway
# Running: S100 calcium binding protein A9 --> output type Pathway
# Running: histone deacetylase 1 --> output type Pathway
# Running: nucleotide binding oligomerization domain containing 2 --> output type Pathway
# Running: X-linked Kx blood group --> output type Pathway
# Running: interferon alpha inducible protein 27 --> output type Pathway
# Running: major histocompatibility complex, class II, DR beta 1 --> output type Pathway
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type Pathway
# Running: cannabinoid receptor 1 --> output type Pathway
# Running: cholecystokinin --> output type Pathway
# Running: von Willebrand factor --> output type Pathway
# Running: heat shock protein family A (Hsp70) member 8 --> output type Pathway
# Running: CD69 molecule --> output type Pathway
# Running: interleukin 3 --> output type Pathway
# Running: pro-platelet basic protein --> output type Pathway
# Running: prohibitin --> output type Pathway
# Running: kallikrein related peptidase 3 --> output type Pathway
# Running: notch receptor 1 --> output type Pathway
# Running: advanced glycosylation end-product specific receptor --> output type Pathway
# Running: fibroblast growth factor receptor 1 --> output type Pathway
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type Pathway
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type Pathway
# Running: Cbl proto-oncogene --> output type Pathway
# Running: transferrin receptor --> output type Pathway
# Running: CD8a molecule --> output type Pathway
# Running: neural cell adhesion molecule 1 --> output type Pathway
# Running: nuclear receptor subfamily 3 group C member 1 --> output type Pathway
# Running: interferon regulatory factor 1 --> output type Pathway
# Running: cyclin dependent kinase 2 --> output type Pathway
# Running: BCL2 apoptosis regulator --> output type Pathway

# %%
list(dict.fromkeys(list(gene_to_pathways["output_name"])))
# Out:
# ['COMPLEMENT CASCADE',
#  'INITIAL TRIGGERING OF COMPLEMENT',
#  'CREATION OF C4 AND C2 ACTIVATORS',
#  'INNATE IMMUNE SYSTEM',
#  'IMMUNE SYSTEM',
#  'CLASSICAL ANTIBODY-MEDIATED COMPLEMENT ACTIVATION',
#  'SELENIUM MICRONUTRIENT NETWORK',
#  'VITAMIN B12 METABOLISM',
#  'FOLATE METABOLISM',
#  'HUMAN COMPLEMENT SYSTEM',
#  'OVERVIEW OF NANOPARTICLE EFFECTS',
#  'IL-6 SIGNALING PATHWAY',
#  'R-HSA-9678108',
#  'R-HSA-9678110',
#  'R-HSA-9679506',
#  'DISEASE',
#  'INFECTIOUS DISEASE',
#  'R-HSA-9679191',
#  'METABOLISM OF ANGIOTENSINOGEN TO ANGIOTENSINS',
#  'PEPTIDE HORMONE METABOLISM',
#  'METABOLISM OF PROTEINS',
#  'ACE INHIBITOR PATHWAY',
#  'R-HSA-9646399',
#  'R-HSA-9663891',
#  'SIGNAL TRANSDUCTION',
#  'MACROAUTOPHAGY',
#  'SIGNALING BY RHO GTPASES',
#  'RHO GTPASE EFFECTORS',
#  'MEMBRANE TRAFFICKING',
#  'TRANSPORT OF SMALL MOLECULES',
#  'ABC-FAMILY PROTEINS MEDIATED TRANSPORT',
#  'ABC TRANSPORTER DISORDERS',
#  'DISORDERS OF TRANSMEMBRANE TRANSPORTERS',
#  'RHO GTPASES REGULATE CFTR TRAFFICKING',
#  'VESICLE-MEDIATED TRANSPORT',
#  'DEFECTIVE CFTR CAUSES CYSTIC FIBROSIS',
#  'DEUBIQUITINATION',
#  'UB-SPECIFIC PROCESSING PROTEASES',
#  'POST-TRANSLATIONAL PROTEIN MODIFICATION',
#  'CARGO RECOGNITION FOR CLATHRIN-MEDIATED ENDOCYTOSIS',
#  'CLATHRIN-MEDIATED ENDOCYTOSIS',
#  'AUTOPHAGY',
#  'CHAPERONE MEDIATED AUTOPHAGY',
#  'MICROAUTOPHAGY',
#  'CYTOKINE SIGNALING IN IMMUNE SYSTEM',
#  'ADAPTIVE IMMUNE SYSTEM',
#  'DEFENSINS',
#  'ALPHA-DEFENSINS',
#  'HIV LIFE CYCLE',
#  'EARLY PHASE OF HIV LIFE CYCLE',
#  'HIV INFECTION',
#  'HOST INTERACTIONS OF HIV FACTORS',
#  'NEF-MEDIATES DOWN MODULATION OF CELL SURFACE RECEPTORS BY RECRUITING THEM TO CLATHRIN ADAPTERS',
#  'THE ROLE OF NEF IN HIV-1 REPLICATION AND DISEASE PATHOGENESIS',
#  'NEF MEDIATED CD4 DOWN-REGULATION',
#  'BINDING AND ENTRY OF HIV VIRION',
#  'VPU MEDIATED DEGRADATION OF CD4',
#  'TCR SIGNALING',
#  'DOWNSTREAM TCR SIGNALING',
#  'PHOSPHORYLATION OF CD3 AND TCR ZETA CHAINS',
#  'TRANSLOCATION OF ZAP-70 TO IMMUNOLOGICAL SYNAPSE',
#  'GENERATION OF SECOND MESSENGER MOLECULES',
#  'COSTIMULATION BY THE CD28 FAMILY',
#  'PD-1 SIGNALING',
#  'SIGNALING BY INTERLEUKINS',
#  'OTHER INTERLEUKIN SIGNALING',
#  'ANTIMICROBIAL PEPTIDES',
#  'T-CELL ANTIGEN RECEPTOR (TCR) PATHWAY DURING STAPHYLOCOCCUS AUREUS INFECTION',
#  'TYROBP CAUSAL NETWORK',
#  'VIRAL ACUTE MYOCARDITIS',
#  'CYTOKINES AND INFLAMMATORY RESPONSE',
#  'T-CELL ANTIGEN RECEPTOR (TCR) SIGNALING PATHWAY',
#  'REGULATION OF COMPLEMENT CASCADE',
#  'DENGUE-2 INTERACTIONS WITH COMPLEMENT AND COAGULATION CASCADES',
#  'COMPLEMENT AND COAGULATION CASCADES',
#  'MITOCHONDRIAL BIOGENESIS',
#  'ORGANELLE BIOGENESIS AND MAINTENANCE',
#  'TRANSCRIPTIONAL ACTIVATION OF MITOCHONDRIAL BIOGENESIS',
#  'NAD+ METABOLISM',
#  'NAD+ BIOSYNTHETIC PATHWAYS',
#  'HEMOSTASIS',
#  'PLATELET DEGRANULATION ',
#  'PLATELET ACTIVATION, SIGNALING AND AGGREGATION',
#  'RESPONSE TO ELEVATED PLATELET CYTOSOLIC CA2+',
#  'EPIGENETIC REGULATION OF GENE EXPRESSION',
#  'GENERIC TRANSCRIPTION PATHWAY',
#  'CELLULAR RESPONSES TO STRESS',
#  'REGULATION OF HSF1-MEDIATED HEAT SHOCK RESPONSE',
#  'CELLULAR RESPONSE TO HEAT STRESS',
#  'CIRCADIAN CLOCK',
#  'SIRT1 NEGATIVELY REGULATES RRNA EXPRESSION',
#  'NEGATIVE EPIGENETIC REGULATION OF RRNA EXPRESSION',
#  'RNA POLYMERASE II TRANSCRIPTION',
#  'GENE EXPRESSION (TRANSCRIPTION)',
#  'CELLULAR RESPONSES TO EXTERNAL STIMULI',
#  'FOXO-MEDIATED TRANSCRIPTION',
#  'REGULATION OF FOXO TRANSCRIPTIONAL ACTIVITY BY ACETYLATION',
#  'ANDROGEN RECEPTOR SIGNALING PATHWAY',
#  'ENERGY METABOLISM',
#  'STEROL REGULATORY ELEMENT-BINDING PROTEINS (SREBP) SIGNALLING',
#  'SREBF AND MIR33 IN CHOLESTEROL AND LIPID HOMEOSTASIS',
#  'MELATONIN METABOLISM AND EFFECTS',
#  'NAD METABOLISM, SIRTUINS AND AGING',
#  'SIMPLIFIED INTERACTION MAP BETWEEN LOXL4 AND OXIDATIVE STRESS PATHWAY',
#  'SOMATROPH AXIS (GH) AND ITS RELATIONSHIP TO DIETARY RESTRICTION AND AGING',
#  'CALORIC RESTRICTION AND AGING',
#  'MIRNA REGULATION OF DNA DAMAGE RESPONSE',
#  'CELL CYCLE',
#  'ADIPOGENESIS',
#  'GLUCOCORTICOID RECEPTOR PATHWAY',
#  'NUCLEAR RECEPTORS META-PATHWAY',
#  'ENDOMETRIAL CANCER',
#  'CHROMOSOMAL AND MICROSATELLITE INSTABILITY IN COLORECTAL CANCER',
#  'NON-SMALL CELL LUNG CANCER',
#  'BREAST CANCER PATHWAY',
#  'PANCREATIC ADENOCARCINOMA PATHWAY',
#  'DNA DAMAGE RESPONSE',
#  'R-HSA-9635465',
#  'R-HSA-9635486',
#  'R-HSA-9637690',
#  'R-HSA-9649948',
#  'R-HSA-9652169',
#  'R-HSA-9652817',
#  'R-HSA-9656223',
#  'R-HSA-9658195',
#  'R-HSA-9664407',
#  'R-HSA-9664417',
#  'R-HSA-9664422',
#  'R-HSA-9675108',
#  'APOPTOSIS',
#  'INTRINSIC PATHWAY FOR APOPTOSIS',
#  'FORMATION OF APOPTOSOME',
#  'CYTOCHROME C-MEDIATED APOPTOTIC RESPONSE',
#  'APOPTOTIC FACTOR-MEDIATED RESPONSE',
#  'OPIOID SIGNALLING',
#  'PHOSPHO-PLA2 PATHWAY',
#  'CA-DEPENDENT EVENTS',
#  'G-PROTEIN MEDIATED EVENTS',
#  'PLC BETA MEDIATED EVENTS',
#  'NEUROTRANSMITTER RECEPTORS AND POSTSYNAPTIC SIGNAL TRANSMISSION',
#  'TRANSMISSION ACROSS CHEMICAL SYNAPSES',
#  'NEURONAL SYSTEM',
#  'RAF-INDEPENDENT MAPK1/3 ACTIVATION',
#  'MAPK1 (ERK2) ACTIVATION',
#  'PIP3 ACTIVATES AKT SIGNALING',
#  'DEVELOPMENTAL BIOLOGY',
#  'SPRY REGULATION OF FGF SIGNALING',
#  'GOLGI CISTERNAE PERICENTRIOLAR STACK REORGANIZATION',
#  'TOLL LIKE RECEPTOR 4 (TLR4) CASCADE',
#  'MYD88:MAL(TIRAP) CASCADE INITIATED ON PLASMA MEMBRANE',
#  'MYD88-INDEPENDENT TLR4 CASCADE ',
#  'SIGNALING BY NTRKS',
#  'TOLL LIKE RECEPTOR 9 (TLR9) CASCADE',
#  'TOLL LIKE RECEPTOR 10 (TLR10) CASCADE',
#  'TOLL LIKE RECEPTOR 3 (TLR3) CASCADE',
#  'TOLL LIKE RECEPTOR 5 (TLR5) CASCADE',
#  'TOLL LIKE RECEPTOR TLR1:TLR2 CASCADE',
#  'TOLL LIKE RECEPTOR 7/8 (TLR7/8) CASCADE',
#  'TOLL LIKE RECEPTOR TLR6:TLR2 CASCADE',
#  'TOLL-LIKE RECEPTOR CASCADES',
#  'PROLONGED ERK ACTIVATION EVENTS',
#  'FRS2-MEDIATED ACTIVATION',
#  'TOLL LIKE RECEPTOR 2 (TLR2) CASCADE',
#  'SIGNALING BY NTRK1 (TRKA)',
#  'SIGNALLING TO ERKS',
#  'SIGNALING BY FGFR',
#  'NUCLEAR EVENTS (KINASE AND TRANSCRIPTION FACTOR ACTIVATION)',
#  'ERK/MAPK TARGETS',
#  'NEGATIVE REGULATION OF THE PI3K/AKT NETWORK',
#  'ERKS ARE INACTIVATED',
#  'FCGAMMA RECEPTOR (FCGR) DEPENDENT PHAGOCYTOSIS',
#  'REGULATION OF ACTIN DYNAMICS FOR PHAGOCYTIC CUP FORMATION',
#  'FC EPSILON RECEPTOR (FCERI) SIGNALING',
#  'OXIDATIVE STRESS INDUCED SENESCENCE',
#  'SENESCENCE-ASSOCIATED SECRETORY PHENOTYPE (SASP)',
#  'CELLULAR SENESCENCE',
#  'ONCOGENE INDUCED SENESCENCE',
#  'FCERI MEDIATED MAPK ACTIVATION',
#  'SIGNALING BY GPCR',
#  'L1CAM INTERACTIONS',
#  'NCAM SIGNALING FOR NEURITE OUT-GROWTH',
#  'GPCR DOWNSTREAM SIGNALLING',
#  'G ALPHA (Q) SIGNALLING EVENTS',
#  'G ALPHA (I) SIGNALLING EVENTS',
#  'AXON GUIDANCE',
#  'RECYCLING PATHWAY OF L1',
#  'POST NMDA RECEPTOR ACTIVATION EVENTS',
#  'CREB1 PHOSPHORYLATION THROUGH NMDA RECEPTOR-MEDIATED ACTIVATION OF RAS SIGNALING',
#  'ACTIVATION OF NMDA RECEPTORS AND POSTSYNAPTIC EVENTS',
#  'RSK ACTIVATION',
#  'SIGNAL TRANSDUCTION BY L1',
#  'INTERLEUKIN-17 SIGNALING',
#  'MAPK TARGETS/ NUCLEAR EVENTS MEDIATED BY MAP KINASES',
#  'MAP KINASE ACTIVATION',
#  'ACTIVATION OF THE AP-1 FAMILY OF TRANSCRIPTION FACTORS',
#  'THROMBIN SIGNALLING THROUGH PROTEINASE ACTIVATED RECEPTORS (PARS)',
#  'PROGRAMMED CELL DEATH',
#  'NEGATIVE REGULATION OF FGFR1 SIGNALING',
#  'NEGATIVE REGULATION OF FGFR2 SIGNALING',
#  'NEGATIVE REGULATION OF FGFR3 SIGNALING',
#  'NEGATIVE REGULATION OF FGFR4 SIGNALING',
#  'SIGNALING BY FGFR1',
#  'SIGNALING BY FGFR2',
#  'SIGNALING BY FGFR3',
#  'SIGNALING BY FGFR4',
#  'DISEASES OF SIGNAL TRANSDUCTION',
#  'RHO GTPASES ACTIVATE WASPS AND WAVES',
#  'RHO GTPASES ACTIVATE NADPH OXIDASES',
#  'RAF/MAP KINASE CASCADE',
#  'MAP2K AND MAPK ACTIVATION',
#  'NEGATIVE FEEDBACK REGULATION OF MAPK PATHWAY',
#  'NEGATIVE REGULATION OF MAPK PATHWAY',
#  'MAPK FAMILY SIGNALING CASCADES',
#  'MAPK1/MAPK3 SIGNALING',
#  'NEUTROPHIL DEGRANULATION',
#  'SIGNALING BY MODERATE KINASE ACTIVITY BRAF MUTANTS',
#  'SIGNALING BY HIGH-KINASE ACTIVITY BRAF MUTANTS',
#  'SIGNALING BY RAS MUTANTS',
#  'SIGNALING BY BRAF AND RAF FUSIONS',
#  'PARADOXICAL ACTIVATION OF RAF SIGNALING BY KINASE INACTIVE BRAF',
#  'ONCOGENIC MAPK SIGNALING',
#  'PTEN REGULATION',
#  'PI5P, PP2A AND IER3 REGULATE PI3K/AKT SIGNALING',
#  'MITOTIC PROPHASE',
#  'M PHASE',
#  'CELL CYCLE, MITOTIC',
#  'SIGNAL ATTENUATION',
#  'INSULIN RECEPTOR SIGNALLING CASCADE',
#  'SIGNALING BY INSULIN RECEPTOR',
#  'ADVANCED GLYCOSYLATION ENDPRODUCT RECEPTOR SIGNALING',
#  'GASTRIN-CREB SIGNALLING PATHWAY VIA PKC AND MAPK',
#  'TRANSCRIPTIONAL REGULATION BY RUNX2',
#  'ESR-MEDIATED SIGNALING',
#  'RUNX2 REGULATES OSTEOBLAST DIFFERENTIATION',
#  'RUNX2 REGULATES BONE DEVELOPMENT',
#  'REGULATION OF PTEN GENE TRANSCRIPTION',
#  'INTRACELLULAR SIGNALING BY SECOND MESSENGERS',
#  'SIGNALING BY NUCLEAR RECEPTORS',
#  'SIGNALING BY RECEPTOR TYROSINE KINASES',
#  'EXTRA-NUCLEAR ESTROGEN SIGNALING',
#  'TRIF(TICAM1)-MEDIATED TLR4 SIGNALING ',
#  'FLT3 SIGNALING',
#  'REGULATION OF THE APOPTOSOME ACTIVITY',
#  'ESTROGEN-STIMULATED SIGNALING THROUGH PRKCZ',
#  'ESTROGEN-DEPENDENT NUCLEAR EVENTS DOWNSTREAM OF ESR-MEMBRANE SIGNALING',
#  'TRAF6 MEDIATED INDUCTION OF NFKB AND MAP KINASES UPON TLR7/8 OR 9 ACTIVATION',
#  'MYD88 DEPENDENT CASCADE INITIATED ON ENDOSOME',
#  'MYD88 CASCADE INITIATED ON PLASMA MEMBRANE',
#  'GROWTH HORMONE RECEPTOR SIGNALING',
#  'IL-5 SIGNALING PATHWAY',
#  'OSTEOPONTIN SIGNALING',
#  'REGULATION OF TOLL-LIKE RECEPTOR SIGNALING PATHWAY',
#  'PHYSIOLOGICAL AND PATHOLOGICAL HYPERTROPHY OF THE HEART',
#  'ANGIOGENESIS',
#  'MICRORNAS IN CARDIOMYOCYTE HYPERTROPHY',
#  'TYPE II DIABETES MELLITUS',
#  'HEART DEVELOPMENT',
#  'INTEGRIN-MEDIATED CELL ADHESION',
#  'IL-1 SIGNALING PATHWAY',
#  'INTEGRATED BREAST CANCER PATHWAY',
#  'ANGIOGENESIS OVERVIEW',
#  'RANKL-RANK (RECEPTOR ACTIVATOR OF NFKB (LIGAND)) SIGNALING PATHWAY',
#  'HUMAN THYROID STIMULATING HORMONE (TSH) SIGNALING PATHWAY',
#  'LEPTIN SIGNALING PATHWAY',
#  'FOLLICLE STIMULATING HORMONE (FSH) SIGNALING PATHWAY',
#  'TNF RELATED WEAK INDUCER OF APOPTOSIS (TWEAK) SIGNALING PATHWAY',
#  'PROLACTIN SIGNALING PATHWAY',
#  'IL-7 SIGNALING PATHWAY',
#  'ALZHEIMERS DISEASE',
#  'IL17 SIGNALING PATHWAY',
#  'ENDOTHELIN PATHWAYS',
#  'IL-9 SIGNALING PATHWAY',
#  'THYMIC STROMAL LYMPHOPOIETIN (TSLP) SIGNALING PATHWAY',
#  'SIGNALING PATHWAYS IN GLIOBLASTOMA',
#  'ANDROGEN RECEPTOR NETWORK IN PROSTATE CANCER',
#  'B CELL RECEPTOR SIGNALING PATHWAY',
#  'TNF ALPHA SIGNALING PATHWAY',
#  'AGE-RAGE PATHWAY',
#  'INTERLEUKIN-11 SIGNALING PATHWAY',
#  'CORTICOTROPIN-RELEASING HORMONE SIGNALING PATHWAY',
#  'ONCOSTATIN M SIGNALING PATHWAY',
#  'BRAIN-DERIVED NEUROTROPHIC FACTOR (BDNF) SIGNALING PATHWAY',
#  'SPINAL CORD INJURY',
#  'ALPHA 6 BETA 4 SIGNALING PATHWAY',
#  'PDGF PATHWAY',
#  'ARYL HYDROCARBON RECEPTOR',
#  'NIFEDIPINE ACTIVITY',
#  'JAK-STAT',
#  'SIGNAL TRANSDUCTION OF S1P RECEPTOR',
#  'EBV LMP1 SIGNALING',
#  'COMMON PATHWAYS UNDERLYING DRUG ADDICTION',
#  'STRUCTURAL PATHWAY OF INTERLEUKIN 1 (IL-1)',
#  'CARDIAC HYPERTROPHIC RESPONSE',
#  'BLADDER CANCER',
#  'IL-3 SIGNALING PATHWAY',
#  'APOPTOSIS-RELATED NETWORK DUE TO ALTERED NOTCH3 IN OVARIAN CANCER',
#  'TCA CYCLE NUTRIENT UTILIZATION AND INVASIVENESS OF OVARIAN CANCER',
#  'KIT RECEPTOR SIGNALING PATHWAY',
#  'FOCAL ADHESION',
#  'SIGNALING OF HEPATOCYTE GROWTH FACTOR RECEPTOR',
#  'MFAP5-MEDIATED OVARIAN CANCER CELL MOTILITY AND INVASIVENESS',
#  'RAC1-PAK1-P38-MMP2 PATHWAY',
#  'WNT SIGNALING PATHWAY',
#  'TGF-BETA SIGNALING PATHWAY',
#  'HYPOTHESIZED PATHWAYS IN PATHOGENESIS OF CARDIOVASCULAR DISEASE',
#  'BDNF-TRKB SIGNALING',
#  'ASSOCIATION BETWEEN PHYSICO-CHEMICAL FEATURES AND TOXICITY ASSOCIATED PATHWAYS',
#  'MAPK SIGNALING PATHWAY',
#  'MAPK AND NFKB SIGNALLING PATHWAYS INHIBITED BY YERSINIA YOPJ',
#  'ERK PATHWAY IN HUNTINGTON,S DISEASE',
#  'TOLL-LIKE RECEPTOR SIGNALING',
#  'TGF-B SIGNALING IN THYROID CELLS FOR EPITHELIAL-MESENCHYMAL TRANSITION',
#  '4-HYDROXYTAMOXIFEN, DEXAMETHASONE, AND RETINOIC ACIDS REGULATION OF P27 EXPRESSION',
#  'VEGFA-VEGFR2 SIGNALING PATHWAY',
#  'ANGIOPOIETIN LIKE PROTEIN 8 REGULATORY PATHWAY',
#  'CHEMOKINE SIGNALING PATHWAY',
#  'ESC PLURIPOTENCY PATHWAYS',
#  'FOCAL ADHESION-PI3K-AKT-MTOR-SIGNALING PATHWAY',
#  'IL-4 SIGNALING PATHWAY',
#  'PROTEIN ALKYLATION LEADING TO LIVER FIBROSIS',
#  'MIRNA REGULATION OF PROSTATE CANCER SIGNALING PATHWAYS',
#  'PRION DISEASE PATHWAY',
#  'PI3K-AKT SIGNALING PATHWAY',
#  'MET IN TYPE 1 PAPILLARY RENAL CELL CARCINOMA',
#  'EBOLA VIRUS PATHWAY ON HOST',
#  'MAPK CASCADE',
#  'RAS SIGNALING',
#  'EPITHELIAL TO MESENCHYMAL TRANSITION IN COLORECTAL CANCER',
#  'INHIBITION OF EXOSOME BIOGENESIS AND SECRETION BY MANUMYCIN A IN CRPC CELLS',
#  'NEOVASCULARISATION PROCESSES',
#  'NON-GENOMIC ACTIONS OF 1,25 DIHYDROXYVITAMIN D3',
#  'EGF-EGFR SIGNALING PATHWAY',
#  'LTF DANGER SIGNAL RESPONSE PATHWAY',
#  'RESISTIN AS A REGULATOR OF INFLAMMATION',
#  'RELATIONSHIP BETWEEN INFLAMMATION, COX-2 AND EGFR',
#  'INSULIN SIGNALING',
#  'IL-2 SIGNALING PATHWAY',
#  'REGULATION OF ACTIN CYTOSKELETON',
#  'EPO RECEPTOR SIGNALING',
#  'SENESCENCE AND AUTOPHAGY IN CANCER',
#  'ERBB SIGNALING PATHWAY',
#  'DNA DAMAGE RESPONSE (ONLY ATM DEPENDENT)',
#  'ESTROGEN SIGNALING PATHWAY',
#  'VITAMIN A AND CAROTENOID METABOLISM',
#  'SEROTONIN HTR1 GROUP AND FOS PATHWAY',
#  'SEROTONIN RECEPTOR 2 AND ELK-SRF-GATA4 SIGNALING',
#  'SEROTONIN RECEPTOR 4-6-7 AND NR3C SIGNALING',
#  'TOLL-LIKE RECEPTOR SIGNALING PATHWAY',
#  'CLASS A/1 (RHODOPSIN-LIKE RECEPTORS)',
#  'PEPTIDE LIGAND-BINDING RECEPTORS',
#  'VASOPRESSIN-LIKE RECEPTORS',
#  'GPCR LIGAND BINDING',
#  'MYOMETRIAL RELAXATION AND CONTRACTION PATHWAYS',
#  'ION TRANSPORT BY P-TYPE ATPASES',
#  'ION CHANNEL TRANSPORT',
#  'R-HSA-9660826',
#  'R-HSA-9664424',
#  'NUCLEOTIDE-BINDING DOMAIN, LEUCINE RICH REPEAT CONTAINING RECEPTOR (NLR) SIGNALING PATHWAYS',
#  'INFLAMMASOMES',
#  'THE NLRP3 INFLAMMASOME',
#  'NUCLEOTIDE-BINDING OLIGOMERIZATION DOMAIN (NOD) PATHWAY',
#  'SIGNALING BY PDGF',
#  'DISSOLUTION OF FIBRIN CLOT',
#  'BLOOD CLOTTING CASCADE',
#  'NOTCH1 REGULATION OF HUMAN ENDOTHELIAL CELL CALCIFICATION',
#  'DENGUE-2 INTERACTIONS WITH BLOOD CLOTTING CASCADE',
#  'FIBRIN COMPLEMENT RECEPTOR 3 SIGNALING PATHWAY',
#  'ENDOCHONDRAL OSSIFICATION',
#  'BMAL1:CLOCK,NPAS2 ACTIVATES CIRCADIAN GENE EXPRESSION',
#  'EXTRACELLULAR MATRIX ORGANIZATION',
#  'SIGNALING BY TGF-BETA RECEPTOR COMPLEX',
#  'TRANSCRIPTIONAL ACTIVITY OF SMAD2/SMAD3:SMAD4 HETEROTRIMER',
#  'SMAD2/SMAD3:SMAD4 HETEROTRIMER REGULATES TRANSCRIPTION',
#  'ECM PROTEOGLYCANS',
#  'SIGNALING BY TGF-BETA FAMILY MEMBERS',
#  'TRANSCRIPTIONAL ACTIVITY OF SMAD2-SMAD3-SMAD4 HETEROTRIMER',
#  'BMAL1-CLOCK,NPAS2 ACTIVATES CIRCADIAN GENE EXPRESSION',
#  'PHOTODYNAMIC THERAPY-INDUCED HIF-1 SURVIVAL SIGNALING',
#  'MIRNA REGULATION OF P53 PATHWAY IN PROSTATE CANCER',
#  'TGF-BETA RECEPTOR SIGNALING',
#  'TERMINAL PATHWAY OF COMPLEMENT',
#  'ACTIVATION OF C3 AND C5',
#  'ALLOGRAFT REJECTION',
#  'OXIDATIVE DAMAGE',
#  'COMPLEMENT ACTIVATION',
#  'ROS AND RNS PRODUCTION IN PHAGOCYTES',
#  'EVENTS ASSOCIATED WITH PHAGOCYTOLYTIC ACTIVITY OF PMN CELLS',
#  'BENZENE METABOLISM',
#  'INTERLEUKIN-10 SIGNALING',
#  'HEMATOPOIETIC STEM CELL DIFFERENTIATION',
#  'LUNG FIBROSIS',
#  'CHEMOKINE RECEPTORS BIND CHEMOKINES',
#  'ATF4 ACTIVATES GENES IN RESPONSE TO ENDOPLASMIC RETICULUM  STRESS',
#  'PERK REGULATES GENE EXPRESSION',
#  'UNFOLDED PROTEIN RESPONSE (UPR)',
#  'INTERLEUKIN-4 AND INTERLEUKIN-13 SIGNALING',
#  'ATF4 ACTIVATES GENES',
#  'ECTODERM DIFFERENTIATION',
#  'IL1 AND MEGAKARYOCYTES IN OBESITY',
#  'NONALCOHOLIC FATTY LIVER DISEASE',
#  'PLATELET-MEDIATED INTERACTIONS WITH VASCULAR AND CIRCULATING CELLS',
#  'INTERLEUKIN-2 FAMILY SIGNALING',
#  'INTERLEUKIN-3, INTERLEUKIN-5 AND GM-CSF SIGNALING',
#  'RUNX1 AND FOXP3 CONTROL THE DEVELOPMENT OF REGULATORY T LYMPHOCYTES (TREGS)',
#  'TRANSCRIPTIONAL REGULATION BY RUNX1',
#  'INTERLEUKIN-2 SIGNALING',
#  'INTERLEUKIN RECEPTOR SHC SIGNALING',
#  'T-CELL RECEPTOR AND CO-STIMULATORY SIGNALING',
#  'ARYL HYDROCARBON RECEPTOR PATHWAY',
#  'PHOTODYNAMIC THERAPY-INDUCED AP-1 SURVIVAL SIGNALING.',
#  'PHOTODYNAMIC THERAPY-INDUCED NF-KB SURVIVAL SIGNALING',
#  'CONTROL OF IMMUNE TOLERANCE BY VASOACTIVE INTESTINALPEPTIDE',
#  'INFLAMMATORY RESPONSE PATHWAY',
#  'ER TO GOLGI ANTEROGRADE TRANSPORT',
#  'COPII-MEDIATED VESICLE TRANSPORT',
#  'MHC CLASS II ANTIGEN PRESENTATION',
#  'ASPARAGINE N-LINKED GLYCOSYLATION',
#  'CARGO CONCENTRATION IN THE ER',
#  'TRANSPORT TO THE GOLGI AND SUBSEQUENT MODIFICATION',
#  'MIR-TARGETED GENES IN EPITHELIUM - TARBASE',
#  'MIR-TARGETED GENES IN LEUKOCYTES - TARBASE',
#  'MIR-TARGETED GENES IN LYMPHOCYTES - TARBASE',
#  'MIR-TARGETED GENES IN MUSCLE CELL - TARBASE',
#  'INTERLEUKIN-12 FAMILY SIGNALING',
#  'INTERFERON GAMMA SIGNALING',
#  'REGULATION OF IFNG SIGNALING',
#  'GENE AND PROTEIN EXPRESSION BY JAK-STAT SIGNALING AFTER INTERLEUKIN-12 STIMULATION',
#  'INTERLEUKIN-12 SIGNALING',
#  'INTERFERON SIGNALING',
#  'PROTEASOME DEGRADATION',
#  'RIG-I-LIKE RECEPTOR SIGNALING',
#  'DEVELOPMENT AND HETEROGENEITY OF THE ILC FAMILY',
#  'NO-CGMP-PKG MEDIATED NEUROPROTECTION',
#  'HYPERTROPHY MODEL',
#  'TYPE II INTERFERON SIGNALING (IFNG)',
#  'R-HSA-9662834',
#  'R-HSA-9662851',
#  'R-HSA-9664433',
#  'SIGNALLING TO RAS',
#  'NOD1/2 SIGNALING PATHWAY',
#  'P38MAPK EVENTS',
#  'SIGNALING BY VEGF',
#  'ACTIVATION OF PPARGC1A (PGC-1ALPHA) BY PHOSPHORYLATION',
#  'TRANSCRIPTIONAL REGULATION BY TP53',
#  'NETRIN-1 SIGNALING',
#  'DSCAM INTERACTIONS',
#  'SIGNAL AMPLIFICATION',
#  'PLATELET HOMEOSTASIS',
#  'ADP SIGNALLING THROUGH P2Y PURINOCEPTOR 1',
#  'PLATELET SENSITIZATION BY LDL',
#  'VEGFA-VEGFR2 PATHWAY',
#  'ACTIVATED TAK1 MEDIATES P38 MAPK ACTIVATION',
#  'REGULATION OF MRNA STABILITY BY PROTEINS THAT BIND AU-RICH ELEMENTS',
#  'KSRP (KHSRP) BINDS AND DESTABILIZES MRNA',
#  'MYOGENESIS',
#  'REGULATION OF TP53 ACTIVITY',
#  'REGULATION OF TP53 ACTIVITY THROUGH PHOSPHORYLATION',
#  'METABOLISM OF RNA',
#  'PARKINSONS DISEASE PATHWAY',
#  'CARDIAC PROGENITOR DIFFERENTIATION',
#  'AMYOTROPHIC LATERAL SCLEROSIS (ALS)',
#  'PHOTODYNAMIC THERAPY-INDUCED NFE2L2 (NRF2) SURVIVAL SIGNALING',
#  'HEPATITIS C AND HEPATOCELLULAR CARCINOMA',
#  'CANONICAL AND NON-CANONICAL TGF-B SIGNALING',
#  'P38 MAPK SIGNALING PATHWAY',
#  'OXIDATIVE STRESS',
#  'THERMOGENESIS',
#  'MIRNAS INVOLVEMENT IN THE IMMUNE RESPONSE IN SEPSIS',
#  'VITAMIN D IN INFLAMMATORY DISEASES',
#  'INTERFERON TYPE I SIGNALING PATHWAYS',
#  'MONOAMINE TRANSPORT',
#  'INTERLEUKIN-1 FAMILY SIGNALING',
#  'INTERLEUKIN-18 SIGNALING',
#  'STRIATED MUSCLE CONTRACTION',
#  'MUSCLE CONTRACTION',
#  'STRIATED MUSCLE CONTRACTION PATHWAY',
#  'R-HSA-9675143',
#  'METABOLISM',
#  'METABOLISM OF VITAMINS AND COFACTORS',
#  'VISUAL PHOTOTRANSDUCTION',
#  'RETINOID CYCLE DISEASE EVENTS',
#  'THE CANONICAL RETINOID CYCLE IN RODS (TWILIGHT VISION)',
#  'DISEASES ASSOCIATED WITH VISUAL TRANSDUCTION',
#  'NON-INTEGRIN MEMBRANE-ECM INTERACTIONS',
#  'METABOLISM OF FAT-SOLUBLE VITAMINS',
#  'RETINOID METABOLISM AND TRANSPORT',
#  'AMYLOID FIBER FORMATION',
#  'METABOLISM OF NUCLEOTIDES',
#  'PYRIMIDINE CATABOLISM',
#  'PURINE CATABOLISM',
#  'NUCLEOBASE CATABOLISM',
#  'PYRIMIDINE METABOLISM',
#  'ALTERNATIVE COMPLEMENT ACTIVATION',
#  'IMMUNOREGULATORY INTERACTIONS BETWEEN A LYMPHOID AND A NON-LYMPHOID CELL',
#  'REGULATION OF INSULIN-LIKE GROWTH FACTOR (IGF) TRANSPORT AND UPTAKE BY INSULIN-LIKE GROWTH FACTOR BINDING PROTEINS (IGFBPS)',
#  'POST-TRANSLATIONAL PROTEIN PHOSPHORYLATION',
#  'MITOTIC METAPHASE AND ANAPHASE',
#  'INITIATION OF NUCLEAR ENVELOPE REFORMATION',
#  'NUCLEAR ENVELOPE REASSEMBLY',
#  'MITOTIC ANAPHASE',
#  'TRANSCRIPTIONAL REGULATION OF WHITE ADIPOCYTE DIFFERENTIATION',
#  'TNFR1-INDUCED PROAPOPTOTIC SIGNALING',
#  'REGULATION OF TNFR1 SIGNALING',
#  'TNFR1-INDUCED NFKAPPAB SIGNALING PATHWAY',
#  'TNFR1-MEDIATED CERAMIDE PRODUCTION',
#  'TNFR2 NON-CANONICAL NF-KB PATHWAY',
#  'DEATH RECEPTOR SIGNALLING',
#  'TNF SIGNALING',
#  'MATRIX METALLOPROTEINASES',
#  'POLYCYSTIC KIDNEY DISEASE PATHWAY',
#  'MAMMARY GLAND DEVELOPMENT PATHWAY - EMBRYONIC DEVELOPMENT (STAGE 1 OF 4)',
#  'FAS LIGAND (FASL) PATHWAY AND STRESS INDUCTION OF HEAT SHOCK PROTEINS (HSP) REGULATION',
#  'EV RELEASE FROM CARDIAC CELLS AND THEIR FUNCTIONAL EFFECTS',
#  'TRANSCRIPTION FACTOR REGULATION IN ADIPOGENESIS',
#  'ROLE ALTERED GLYCOLYSATION OF MUC1 IN TUMOUR MICROENVIRONMENT',
#  'SUDDEN INFANT DEATH SYNDROME (SIDS) SUSCEPTIBILITY PATHWAYS',
#  'DDX58/IFIH1-MEDIATED INDUCTION OF INTERFERON-ALPHA/BETA',
#  'INTERFERON ALPHA/BETA SIGNALING',
#  'REGULATION OF IFNA SIGNALING',
#  'TRAF6 MEDIATED IRF7 ACTIVATION',
#  'FACTORS INVOLVED IN MEGAKARYOCYTE DEVELOPMENT AND PLATELET PRODUCTION',
#  'R-HSA-8853884',
#  'ACTIVATION OF NOXA AND TRANSLOCATION TO MITOCHONDRIA',
#  'ACTIVATION OF BH3-ONLY PROTEINS',
#  'ACTIVATION OF PUMA AND TRANSLOCATION TO MITOCHONDRIA',
#  'SIGNALING BY NOTCH',
#  'PRE-NOTCH TRANSCRIPTION AND TRANSLATION',
#  'PRE-NOTCH EXPRESSION AND PROCESSING',
#  'FORMATION OF SENESCENCE-ASSOCIATED HETEROCHROMATIN FOCI (SAHF)',
#  'DNA DAMAGE/TELOMERE STRESS INDUCED SENESCENCE',
#  'SUMOYLATION',
#  'SUMO E3 LIGASES SUMOYLATE TARGET PROTEINS',
#  'SUMOYLATION OF TRANSCRIPTION FACTORS',
#  'AUTODEGRADATION OF THE E3 UBIQUITIN LIGASE COP1',
#  'CHAPERONIN-MEDIATED PROTEIN FOLDING',
#  'ASSOCIATION OF TRIC/CCT WITH TARGET PROTEINS DURING BIOSYNTHESIS',
#  'PROTEIN FOLDING',
#  'MITOTIC G2-G2/M PHASES',
#  'TP53 REGULATES METABOLIC GENES',
#  'TP53 REGULATES TRANSCRIPTION OF CELL DEATH GENES',
#  'OVARIAN TUMOR DOMAIN PROTEASES',
#  'DNA DOUBLE-STRAND BREAK REPAIR',
#  'RECRUITMENT AND ATM-MEDIATED PHOSPHORYLATION OF REPAIR AND SIGNALING PROTEINS AT DNA DOUBLE STRAND BREAKS',
#  'DNA DOUBLE STRAND BREAK RESPONSE',
#  'TP53 REGULATES TRANSCRIPTION OF CELL CYCLE GENES',
#  'TP53 REGULATES TRANSCRIPTION OF DNA REPAIR GENES',
#  'TP53 REGULATES TRANSCRIPTION OF GENES INVOLVED IN CYTOCHROME C RELEASE',
#  'TP53 REGULATES TRANSCRIPTION OF SEVERAL ADDITIONAL CELL DEATH GENES WHOSE SPECIFIC ROLES IN P53-DEPENDENT APOPTOSIS REMAIN UNCERTAIN',
#  'TP53 REGULATES TRANSCRIPTION OF CASPASE ACTIVATORS AND CASPASES',
#  'TP53 REGULATES TRANSCRIPTION OF DEATH RECEPTORS AND LIGANDS',
#  'TP53 REGULATES TRANSCRIPTION OF GENES INVOLVED IN G2 CELL CYCLE ARREST',
#  'TP53 REGULATES TRANSCRIPTION OF ADDITIONAL CELL CYCLE GENES WHOSE EXACT ROLE IN THE P53 PATHWAY REMAIN UNCERTAIN',
#  'TP53 REGULATES TRANSCRIPTION OF GENES INVOLVED IN G1 CELL CYCLE ARREST',
#  'REGULATION OF TP53 EXPRESSION',
#  'REGULATION OF TP53 DEGRADATION',
#  'REGULATION OF TP53 ACTIVITY THROUGH ACETYLATION',
#  'REGULATION OF TP53 ACTIVITY THROUGH ASSOCIATION WITH CO-FACTORS',
#  'REGULATION OF TP53 ACTIVITY THROUGH METHYLATION',
#  'REGULATION OF TP53 EXPRESSION AND DEGRADATION',
#  'PI5P REGULATES TP53 ACETYLATION',
#  'G2/M TRANSITION',
#  'G2/M DNA DAMAGE CHECKPOINT',
#  'G2/M CHECKPOINTS',
#  'STABILIZATION OF P53',
#  'TRANSCRIPTIONAL ACTIVATION OF P53 RESPONSIVE GENES  ',
#  'P53-DEPENDENT G1 DNA DAMAGE RESPONSE',
#  'P53-DEPENDENT G1/S DNA DAMAGE CHECKPOINT',
#  'G1/S DNA DAMAGE CHECKPOINTS',
#  'CELL CYCLE CHECKPOINTS',
#  'TRANSCRIPTIONAL  ACTIVATION OF  CELL CYCLE INHIBITOR P21 ',
#  'DNA REPAIR',
#  'THE ROLE OF GTSE1 IN G2/M PROGRESSION AFTER G2 CHECKPOINT',
#  'TRANSCRIPTIONAL REGULATION BY RUNX3',
#  'RUNX3 REGULATES CDKN1A TRANSCRIPTION',
#  'AMP-ACTIVATED PROTEIN KINASE (AMPK) SIGNALING',
#  'MIRNAS INVOLVED IN DNA DAMAGE RESPONSE',
#  'FLUOROPYRIMIDINE ACTIVITY',
#  'TP53 NETWORK',
#  'APOPTOSIS MODULATION AND SIGNALING',
#  'METASTATIC BRAIN TUMOR',
#  'GASTRIC CANCER NETWORK 2',
#  'RETINOBLASTOMA GENE IN CANCER',
#  'ATM SIGNALING PATHWAY',
#  'MAMMARY GLAND DEVELOPMENT PATHWAY - INVOLUTION (STAGE 4 OF 4)',
#  'COPPER HOMEOSTASIS',
#  'PATHWAYS AFFECTED IN ADENOID CYSTIC CARCINOMA',
#  'LNCRNA-MEDIATED MECHANISMS OF THERAPEUTIC RESISTANCE',
#  'WNT SIGNALING PATHWAY AND PLURIPOTENCY',
#  'HEREDITARY LEIOMYOMATOSIS AND RENAL CELL CARCINOMA PATHWAY',
#  'ULTRACONSERVED REGION 339 MODULATION OF TUMOR SUPPRESSOR MICRORNAS IN CANCER',
#  'FERROPTOSIS',
#  'THE EFFECT OF PROGERIN ON THE INVOLVED GENES IN HUTCHINSON-GILFORD PROGERIA SYNDROME',
#  'MICRORNA NETWORK ASSOCIATED WITH CHRONIC LYMPHOCYTIC LEUKEMIA',
#  'G1 TO S CELL CYCLE CONTROL',
#  'REGULATION OF GENE EXPRESSION BY HYPOXIA-INDUCIBLE FACTOR',
#  'CELLULAR RESPONSE TO HYPOXIA',
#  'VEGF LIGAND-RECEPTOR INTERACTIONS',
#  'VEGF BINDS TO VEGFR LEADING TO RECEPTOR DIMERIZATION',
#  'VEGFR2 MEDIATED CELL PROLIFERATION',
#  'TRANSCRIPTIONAL REGULATION BY THE AP-2 (TFAP2) FAMILY OF TRANSCRIPTION FACTORS',
#  'TFAP2 (AP-2) FAMILY REGULATES TRANSCRIPTION OF GROWTH FACTORS AND THEIR RECEPTORS',
#  'QUERCETIN AND NF-KB- AP-1 INDUCED CELL APOPTOSIS',
#  'REGULATION OF HYPOXIA-INDUCIBLE FACTOR (HIF) BY OXYGEN',
#  'DIFFERENTIATION PATHWAY',
#  'MICRORNA FOR TARGETING CANCER GROWTH AND VASCULARIZATION IN GLIOBLASTOMA',
#  'AMPLIFICATION AND EXPANSION OF ONCOGENIC PATHWAYS AS METASTATIC TRAITS',
#  'ROBO4 AND VEGF SIGNALING PATHWAYS CROSSTALK',
#  'PATHWAYS IN CLEAR CELL RENAL CELL CARCINOMA',
#  'TYPE 2 PAPILLARY RENAL CELL CARCINOMA',
#  'ACTIVATION OF BAD AND TRANSLOCATION TO MITOCHONDRIA ',
#  'SIGNALING BY ERBB2',
#  'DOWNREGULATION OF ERBB2:ERBB3 SIGNALING',
#  'TRANSLOCATION OF SLC2A4 (GLUT4) TO THE PLASMA MEMBRANE',
#  'TETRAHYDROBIOPTERIN (BH4) SYNTHESIS, RECYCLING, SALVAGE AND REGULATION',
#  'MTOR SIGNALLING',
#  'REGULATION OF BETA-CELL DEVELOPMENT',
#  'SIGNALING BY WNT',
#  'AKT PHOSPHORYLATES TARGETS IN THE CYTOSOL',
#  'AKT PHOSPHORYLATES TARGETS IN THE NUCLEUS',
#  'TCF DEPENDENT SIGNALING IN RESPONSE TO WNT',
#  'METABOLISM OF NITRIC OXIDE: ENOS ACTIVATION AND REGULATION',
#  'ENOS ACTIVATION',
#  'REGULATION OF GENE EXPRESSION IN BETA CELLS',
#  'AKT-MEDIATED INACTIVATION OF FOXO1A',
#  'PI3K/AKT SIGNALING IN CANCER',
#  'INTEGRIN ALPHAIIB BETA3 SIGNALING',
#  'DEACTIVATION OF THE BETA-CATENIN TRANSACTIVATING COMPLEX',
#  'CD28 CO-STIMULATION',
#  'CD28 DEPENDENT PI3K/AKT SIGNALING',
#  'CTLA4 INHIBITORY SIGNALING',
#  'G BETA:GAMMA SIGNALLING THROUGH PI3KGAMMA',
#  'G-PROTEIN BETA:GAMMA SIGNALLING',
#  'BUTYRATE RESPONSE FACTOR 1 (BRF1) BINDS AND DESTABILIZES MRNA',
#  'MITOTIC G1-G1/S PHASES',
#  'VEGFR2 MEDIATED VASCULAR PERMEABILITY',
#  'CONSTITUTIVE SIGNALING BY AKT1 E17K IN CANCER',
#  'CYCLIN E ASSOCIATED EVENTS DURING G1/S TRANSITION ',
#  'G1/S TRANSITION',
#  'S PHASE',
#  'CYCLIN A:CDK2-ASSOCIATED EVENTS AT S PHASE ENTRY',
#  'PLATELET AGGREGATION (PLUG FORMATION)',
#  'SIGNALING BY PTK6',
#  'PTK6 REGULATES RTKS AND THEIR EFFECTORS AKT1 AND DOK1',
#  'DOWNREGULATION OF ERBB2 SIGNALING',
#  'RAB GEFS EXCHANGE GTP FOR GDP ON RABS',
#  'RUNX2 REGULATES GENES INVOLVED IN CELL MIGRATION',
#  'REGULATION OF PTEN STABILITY AND ACTIVITY',
#  'METABOLISM OF COFACTORS',
#  'SIGNALING BY NON-RECEPTOR TYROSINE KINASES',
#  'RAB REGULATION OF TRAFFICKING',
#  'SIGNALING BY NOTCH4',
#  'NEGATIVE REGULATION OF NOTCH4 SIGNALING',
#  'REGULATION OF LOCALIZATION OF FOXO TRANSCRIPTION FACTORS',
#  'TARGET OF RAPAMYCIN (TOR) SIGNALING',
#  'TFS REGULATE MIRNAS RELATED TO CARDIAC HYPERTROPHY',
#  'REGULATION OF MICROTUBULE CYTOSKELETON',
#  'PRIMARY FOCAL SEGMENTAL GLOMERULOSCLEROSIS FSGS',
#  'EXTRACELLULAR VESICLE-MEDIATED SIGNALING IN RECIPIENT CELLS',
#  'MECP2 AND ASSOCIATED RETT SYNDROME',
#  'WNT-BETA-CATENIN SIGNALING PATHWAY IN LEUKEMIA',
#  'PI3K-AKT-MTOR SIGNALING PATHWAY AND THERAPEUTIC OPPORTUNITIES',
#  'FACTORS AND PATHWAYS AFFECTING INSULIN-LIKE GROWTH FACTOR (IGF1)-AKT SIGNALING',
#  'REGULATION OF APOPTOSIS BY PARATHYROID HORMONE-RELATED PROTEIN',
#  'LEPTIN INSULIN OVERLAP',
#  'LIPID METABOLISM PATHWAY',
#  'STEATOSIS AOP',
#  'PI3K-AKT-MTOR - VITD3 SIGNALLING',
#  'NOTCH SIGNALING PATHWAY',
#  'R-HSA-1227990',
#  'R-HSA-9609646',
#  'R-HSA-9609690',
#  'R-HSA-9664565',
#  'R-HSA-9665348',
#  'R-HSA-9665686',
#  'CONSTITUTIVE SIGNALING BY LIGAND-RESPONSIVE EGFR CANCER VARIANTS',
#  'SIGNALING BY ERBB4',
#  'SHC1 EVENTS IN ERBB2 SIGNALING',
#  'PLCG1 EVENTS IN ERBB2 SIGNALING',
#  'SIGNALING BY EGFR IN CANCER',
#  'SIGNALING BY EGFR',
#  'GRB2 EVENTS IN EGFR SIGNALING',
#  'GAB1 SIGNALOSOME',
#  'SHC1 EVENTS IN EGFR SIGNALING',
#  'EGFR DOWNREGULATION',
#  'GRB2 EVENTS IN ERBB2 SIGNALING',
#  'PI3K EVENTS IN ERBB2 SIGNALING',
#  'EGFR INTERACTS WITH PHOSPHOLIPASE C-GAMMA',
#  'EGFR TRANSACTIVATION BY GASTRIN',
#  'CONSTITUTIVE SIGNALING BY ABERRANT PI3K IN CANCER',
#  'CONSTITUTIVE SIGNALING BY EGFRVIII',
#  'SIGNALING BY EGFRVIII IN CANCER',
#  'SIGNALING BY LIGAND-RESPONSIVE EGFR VARIANTS IN CANCER',
#  'SIGNALING BY OVEREXPRESSED WILD-TYPE EGFR IN CANCER',
#  'INHIBITION OF SIGNALING BY OVEREXPRESSED EGFR',
#  'ERBB2 REGULATES CELL MOTILITY',
#  'ERBB2 ACTIVATES PTK6 SIGNALING',
#  'PTK6 PROMOTES HIF1A STABILIZATION',
#  'SIGNALING BY NOTCH3',
#  'NOTCH3 ACTIVATION AND TRANSMISSION OF SIGNAL TO THE NUCLEUS',
#  'HAIR FOLLICLE DEVELOPMENT- INDUCTION (PART 1 OF 3)',
#  'MAMMARY GLAND DEVELOPMENT PATHWAY - PREGNANCY AND LACTATION (STAGE 3 OF 4)',
#  'BMP SIGNALING PATHWAY IN EYELID DEVELOPMENT',
#  'EXTRACELLULAR VESICLES IN THE CROSSTALK OF CARDIAC CELLS',
#  'R-HSA-9660821',
#  'INTERLEUKIN-6 SIGNALING',
#  'MAPK3 (ERK1) ACTIVATION',
#  'INTERLEUKIN-6 FAMILY SIGNALING',
#  'TLR4 SIGNALING AND TOLERANCE',
#  'NCRNAS INVOLVED IN STAT3 SIGNALING IN HEPATOCELLULAR CARCINOMA',
#  'ELASTIC FIBRE FORMATION',
#  'INFLUENZA LIFE CYCLE',
#  'INFLUENZA VIRUS INDUCED APOPTOSIS',
#  'CELL SURFACE INTERACTIONS AT THE VASCULAR WALL',
#  'MOLECULES ASSOCIATED WITH ELASTIC FIBRES',
#  'DOWNREGULATION OF TGF-BETA RECEPTOR SIGNALING',
#  'TGF-BETA RECEPTOR SIGNALING ACTIVATES SMADS',
#  'TGF-BETA RECEPTOR SIGNALING IN EMT (EPITHELIAL TO MESENCHYMAL TRANSITION)',
#  'SYNDECAN INTERACTIONS',
#  'LOSS OF FUNCTION OF SMAD2/3 IN CANCER',
#  'SIGNALING BY TGF-BETA RECEPTOR COMPLEX IN CANCER',
#  'SMAD2/3 PHOSPHORYLATION MOTIF MUTANTS IN CANCER',
#  'LOSS OF FUNCTION OF TGFBR2 IN CANCER',
#  'TGFBR2 MSI FRAMESHIFT MUTANTS IN CANCER',
#  'TGFBR2 KINASE DOMAIN MUTANTS IN CANCER',
#  'TGFBR1 KD MUTANTS IN CANCER',
#  'LOSS OF FUNCTION OF TGFBR1 IN CANCER',
#  'TGFBR1 LBD MUTANTS IN CANCER',
#  'UCH PROTEINASES',
#  'REGULATION OF RUNX3 EXPRESSION AND ACTIVITY',
#  'RUNX3 REGULATES P14-ARF',
#  'ENDODERM DIFFERENTIATION',
#  'DOPAMINERGIC NEUROGENESIS',
#  'VITAMIN D RECEPTOR PATHWAY',
#  'NRF2 PATHWAY',
#  'INTEGRATION OF ENERGY METABOLISM',
#  'INSULIN PROCESSING',
#  'SYNTHESIS, SECRETION, AND DEACYLATION OF GHRELIN',
#  'REGULATION OF INSULIN SECRETION',
#  'COPI-MEDIATED ANTEROGRADE TRANSPORT',
#  'IRS ACTIVATION',
#  'INSULIN RECEPTOR RECYCLING',
#  'FOXO-MEDIATED TRANSCRIPTION OF OXIDATIVE STRESS, METABOLIC AND NEURONAL GENES',
#  'CORI CYCLE',
#  'WHITE FAT CELL DIFFERENTIATION',
#  'GLUCOSE HOMEOSTASIS',
#  'DETOXIFICATION OF REACTIVE OXYGEN SPECIES',
#  'PEROXISOMAL PROTEIN IMPORT',
#  'PROTEIN LOCALIZATION',
#  'TRYPTOPHAN METABOLISM',
#  'ER-PHAGOSOME PATHWAY',
#  'ANTIGEN PROCESSING-CROSS PRESENTATION',
#  'CASPASE ACTIVATION VIA DEATH RECEPTORS IN THE PRESENCE OF LIGAND',
#  'TRIF-MEDIATED PROGRAMMED CELL DEATH',
#  'DISEASES OF IMMUNE SYSTEM',
#  'CASPASE ACTIVATION VIA EXTRINSIC APOPTOTIC SIGNALLING PATHWAY',
#  'DISEASES ASSOCIATED WITH THE TLR SIGNALING CASCADE',
#  'MYD88 DEFICIENCY (TLR2/4)',
#  'IRAK4 DEFICIENCY (TLR2/4)',
#  'REGULATION OF TLR BY ENDOGENOUS LIGAND',
#  'ACTIVATION OF IRF3/IRF7 MEDIATED BY TBK1/IKK EPSILON',
#  'IKK COMPLEX RECRUITMENT MEDIATED BY RIP1',
#  'TRAF6-MEDIATED INDUCTION OF TAK1 COMPLEX WITHIN TLR4 COMPLEX',
#  'IRAK2 MEDIATED ACTIVATION OF TAK1 COMPLEX UPON TLR7/8 OR 9 STIMULATION',
#  'CLASS I MHC MEDIATED ANTIGEN PROCESSING & PRESENTATION',
#  'PATHOGENIC ESCHERICHIA COLI INFECTION',
#  'SIMPLIFIED DEPICTION OF MYD88 DISTINCT INPUT-OUTPUT PATHWAY',
#  'NANOMATERIAL INDUCED INFLAMMASOME ACTIVATION',
#  'APOE AND MIR-146 IN INFLAMMATION AND ATHEROSCLEROSIS',
#  'SIGNALING BY SCF-KIT',
#  'COLLAGEN DEGRADATION',
#  'DEGRADATION OF THE EXTRACELLULAR MATRIX',
#  'COLLAGEN FORMATION',
#  'ACTIVATION OF MATRIX METALLOPROTEINASES',
#  'ASSEMBLY OF COLLAGEN FIBRILS AND OTHER MULTIMERIC STRUCTURES',
#  'EPH-EPHRIN SIGNALING',
#  'EPH-EPHRIN MEDIATED REPULSION OF CELLS',
#  'R-HSA-9669938',
#  'R-HSA-9670439',
#  'R-HSA-9671555',
#  'R-HSA-9673767',
#  'R-HSA-9673770',
#  'BH3-ONLY PROTEINS ASSOCIATE WITH AND INACTIVATE ANTI-APOPTOTIC BCL-2 MEMBERS',
#  'SIGNALING BY FGFR IN DISEASE',
#  'INTERLEUKIN-7 SIGNALING',
#  'SIGNALING BY CYTOSOLIC FGFR1 FUSION MUTANTS',
#  'FGFR1 MUTANT RECEPTOR ACTIVATION',
#  'DOWNSTREAM SIGNAL TRANSDUCTION',
#  'SIGNALLING TO STAT3',
#  'SIGNALING BY LEPTIN',
#  'POU5F1 (OCT4), SOX2, NANOG ACTIVATE GENES RELATED TO PROLIFERATION',
#  'TRANSCRIPTIONAL REGULATION OF PLURIPOTENT STEM CELLS',
#  'SIGNALING BY FGFR1 IN DISEASE',
#  'SIGNALING BY MET',
#  'PTK6 ACTIVATES STAT3',
#  'INTERLEUKIN-20 FAMILY SIGNALING',
#  'MET ACTIVATES STAT3',
#  'INTERLEUKIN-15 SIGNALING',
#  'INTERLEUKIN-35 SIGNALLING',
#  'INTERLEUKIN-9 SIGNALING',
#  'INTERLEUKIN-37 SIGNALING',
#  'INTERLEUKIN-23 SIGNALING',
#  'INTERLEUKIN-27 SIGNALING',
#  'INTERLEUKIN-21 SIGNALING',
#  'TRANSCRIPTIONAL REGULATION OF GRANULOPOIESIS',
#  'CELL DIFFERENTIATION - INDEX EXPANDED',
#  'CELL DIFFERENTIATION - INDEX',
#  'ESTROGEN RECEPTOR PATHWAY',
#  'DEVELOPMENT OF PULMONARY DENDRITIC CELLS AND MACROPHAGE SUBSETS',
#  'PDGFR-BETA PATHWAY',
#  'HDAC6 INTERACTIONS',
#  'SEROTONIN RECEPTOR 2 AND STAT3 SIGNALING',
#  'R-HSA-9664323',
#  'INTEGRATED LUNG CANCER PATHWAY',
#  'R-HSA-9664420',
#  'R-HSA-9673324',
#  'ACTIVATION OF BIM AND TRANSLOCATION TO MITOCHONDRIA ',
#  'ACTIVATION OF BMF AND TRANSLOCATION TO MITOCHONDRIA',
#  'NRAGE SIGNALS DEATH THROUGH JNK',
#  'P75 NTR RECEPTOR-MEDIATED SIGNALLING',
#  'CELL DEATH SIGNALLING VIA NRAGE, NRIF AND NADE',
#  'NRIF SIGNALS CELL DEATH FROM THE NUCLEUS',
#  'JNK (C-JUN KINASES) PHOSPHORYLATION AND  ACTIVATION MEDIATED BY ACTIVATED HUMAN TAK1',
#  'INTERLEUKIN-38 SIGNALING',
#  'OSTEOCLAST SIGNALING',
#  'NANOPARTICLE TRIGGERED REGULATED NECROSIS',
#  'NLR PROTEINS',
#  'PHYTOCHEMICAL ACTIVITY ON NRF2 TRANSCRIPTIONAL ACTIVATION',
#  'WNT SIGNALING IN KIDNEY DISEASE',
#  'ETHANOL METABOLISM RESULTING IN PRODUCTION OF ROS BY CYP2E1',
#  'AOP CYP2E1 ACTIVATION LEADING TO NEURODEGENERATION',
#  'WNT SIGNALING',
#  'NRF2-ARE REGULATION',
#  'SYNTHESIS, SECRETION, AND INACTIVATION OF GLUCAGON-LIKE PEPTIDE-1 (GLP-1)',
#  'INCRETIN SYNTHESIS, SECRETION, AND INACTIVATION',
#  'DIFFERENTIATION OF WHITE AND BROWN ADIPOCYTE',
#  'LEPTIN AND ADIPONECTIN',
#  'ANDROGEN BIOSYNTHESIS',
#  'GLUCOCORTICOID BIOSYNTHESIS',
#  'METABOLISM OF STEROID HORMONES',
#  'G-PROTEIN ACTIVATION',
#  'PEPTIDE HORMONE BIOSYNTHESIS',
#  'BIOLOGICAL OXIDATIONS',
#  'CYTOCHROME P450 - ARRANGED BY SUBSTRATE TYPE',
#  'PHASE I - FUNCTIONALIZATION OF COMPOUNDS',
#  'ENDOGENOUS STEROLS',
#  'G ALPHA (S) SIGNALLING EVENTS',
#  'METABOLISM OF LIPIDS',
#  'METABOLIC DISORDERS OF BIOLOGICAL OXIDATION ENZYMES',
#  'DEFECTIVE ACTH CAUSES OBESITY AND PRO-OPIOMELANOCORTININ DEFICIENCY (POMCD)',
#  'DISEASES OF METABOLISM',
#  'METABOLISM OF STEROIDS',
#  'SEROTONIN AND ANXIETY',
#  'REGULATION BY C-FLIP',
#  'RIPK1-MEDIATED REGULATED NECROSIS',
#  'REGULATED NECROSIS',
#  'CASP8 ACTIVITY IS INHIBITED',
#  'REGULATION OF NECROPTOTIC CELL DEATH',
#  'DIMERIZATION OF PROCASPASE-8',
#  'FASL/ CD95L SIGNALING',
#  'NANOMATERIAL INDUCED APOPTOSIS',
#  'APOPTOSIS MODULATION BY HSP70',
#  'PI3K CASCADE',
#  'IRS-MEDIATED SIGNALLING',
#  'GPVI-MEDIATED ACTIVATION CASCADE',
#  'PI3K EVENTS IN ERBB4 SIGNALING',
#  'PI METABOLISM',
#  'PHOSPHOLIPID METABOLISM',
#  'CELL-CELL COMMUNICATION',
#  'SYNTHESIS OF PIPS AT THE PLASMA MEMBRANE',
#  'PI3K/AKT ACTIVATION',
#  'ROLE OF PHOSPHOLIPIDS IN PHAGOCYTOSIS',
#  'TIE2 SIGNALING',
#  'DAP12 INTERACTIONS',
#  'SIGNALING BY TYPE 1 INSULIN-LIKE GROWTH FACTOR 1 RECEPTOR (IGF1R)',
#  'DAP12 SIGNALING',
#  'IGF1R SIGNALING CASCADE',
#  'IRS-RELATED EVENTS TRIGGERED BY IGF1R',
#  'ROLE OF LAT2/NTAL/LAB ON CALCIUM MOBILIZATION',
#  'NEPHRIN FAMILY INTERACTIONS',
#  'DOWNSTREAM SIGNALING OF ACTIVATED FGFR1',
#  'PI-3K CASCADE:FGFR1',
#  'PI-3K CASCADE:FGFR2',
#  'DOWNSTREAM SIGNALING OF ACTIVATED FGFR2',
#  'DOWNSTREAM SIGNALING OF ACTIVATED FGFR3',
#  'PI-3K CASCADE:FGFR3',
#  'DOWNSTREAM SIGNALING OF ACTIVATED FGFR4',
#  'PI-3K CASCADE:FGFR4',
#  'SIGNALING BY FGFR2 IN DISEASE',
#  'SIGNALING BY FGFR4 IN DISEASE',
#  'SIGNALING BY FGFR3 IN DISEASE',
#  'MET ACTIVATES PI3K/AKT SIGNALING',
#  'SIGNALING BY FGFR3 FUSIONS IN CANCER',
#  'SIGNALING BY FGFR3 POINT MUTANTS IN CANCER',
#  'RET SIGNALING',
#  'SIGNALING BY NTRK2 (TRKB)',
#  'SIGNALING BY ERYTHROPOIETIN',
#  'ERYTHROPOIETIN ACTIVATES PHOSPHOINOSITIDE-3-KINASE (PI3K)',
#  'ACTIVATED NTRK2 SIGNALS THROUGH PI3K',
#  'SIGNALING BY NTRK3 (TRKC)',
#  'REGULATION OF SIGNALING BY CBL',
#  'ACTIVATED NTRK3 SIGNALS THROUGH PI3K',
#  'MICROGLIA PATHOGEN PHAGOCYTOSIS PATHWAY',
#  'G13 SIGNALING PATHWAY',
#  'TNF RECEPTOR SUPERFAMILY (TNFSF) MEMBERS MEDIATING NON-CANONICAL NF-KB PATHWAY',
#  'ERYTHROCYTES TAKE UP CARBON DIOXIDE AND RELEASE OXYGEN',
#  'ERYTHROCYTES TAKE UP OXYGEN AND RELEASE CARBON DIOXIDE',
#  'REVERSIBLE HYDRATION OF CARBON DIOXIDE',
#  'O2/CO2 EXCHANGE IN ERYTHROCYTES',
#  'RECYCLING OF BILE ACIDS AND SALTS',
#  'PLASMA LIPOPROTEIN ASSEMBLY, REMODELING, AND CLEARANCE',
#  'METABOLISM OF PORPHYRINS',
#  'HEME BIOSYNTHESIS',
#  'HEME DEGRADATION',
#  'BILE ACID AND BILE SALT METABOLISM',
#  'SCAVENGING OF HEME FROM PLASMA',
#  'BINDING AND UPTAKE OF LIGANDS BY SCAVENGER RECEPTORS',
#  'TRANSPORT OF VITAMINS, NUCLEOSIDES, AND RELATED MOLECULES',
#  'SLC-MEDIATED TRANSMEMBRANE TRANSPORT',
#  'TRANSPORT OF ORGANIC ANIONS',
#  'PLASMA LIPOPROTEIN REMODELING',
#  'HDL REMODELING',
#  'DOWNSTREAM SIGNALING EVENTS OF B CELL RECEPTOR (BCR)',
#  'ACTIVATION OF NF-KAPPAB IN B CELLS',
#  'ZBP1(DAI) MEDIATED INDUCTION OF TYPE I IFNS',
#  'RIP-MEDIATED NFKB ACTIVATION VIA ZBP1',
#  'CYTOSOLIC SENSORS OF PATHOGEN-ASSOCIATED DNA ',
#  'P75NTR SIGNALS VIA NF-KB',
#  'REGULATED PROTEOLYSIS OF P75NTR',
#  'NF-KB IS ACTIVATED AND SIGNALS SURVIVAL',
#  'FCERI MEDIATED NF-KB ACTIVATION',
#  'DEX/H-BOX HELICASES ACTIVATE TYPE I IFN AND INFLAMMATORY CYTOKINES PRODUCTION ',
#  'PKMTS METHYLATE HISTONE LYSINES',
#  'CHROMATIN MODIFYING ENZYMES',
#  'TAK1 ACTIVATES NFKB BY PHOSPHORYLATION AND ACTIVATION OF IKKS COMPLEX',
#  'INTERLEUKIN-1 PROCESSING',
#  'SUMOYLATION OF IMMUNE RESPONSE PROTEINS',
#  'CHROMATIN ORGANIZATION',
#  'IKBA VARIANT LEADS TO EDA-ID',
#  'DECTIN-1 MEDIATED NONCANONICAL NF-KB SIGNALING',
#  'CLEC7A (DECTIN-1) SIGNALING',
#  'C-TYPE LECTIN RECEPTORS (CLRS)',
#  'CD209 (DC-SIGN) SIGNALING',
#  'CLEC7A/INFLAMMASOME PATHWAY',
#  'INTERLEUKIN-1 SIGNALING',
#  'TRAF6 MEDIATED NF-KB ACTIVATION',
#  'SIGNALING BY THE B CELL RECEPTOR (BCR)',
#  'SELENIUM METABOLISM AND SELENOPROTEINS',
#  'INITIATION OF TRANSCRIPTION AND TRANSLATION ELONGATION AT THE HIV-1 LTR',
#  'SUPRESSION OF HMGB1 MEDIATED INFLAMMATION BY THBD',
#  'SIGNALING BY ROBO RECEPTORS',
#  'PEPTIDE GPCRS',
#  'GPCRS, CLASS A RHODOPSIN-LIKE',
#  'INOSITOL PHOSPHATE METABOLISM',
#  'SYNTHESIS OF IP3 AND IP4 IN THE CYTOSOL',
#  'PTEN LOSS OF FUNCTION IN CANCER',
#  'REGULATION OF PTEN MRNA TRANSLATION',
#  'REGULATION OF PTEN LOCALIZATION',
#  'TRANSCRIPTIONAL REGULATION BY MECP2',
#  'HEMATOPOIETIC STEM CELL GENE REGULATION BY GABP ALPHA-BETA COMPLEX',
#  'NUCLEAR SIGNALING BY ERBB4',
#  'NUCLEAR RECEPTOR TRANSCRIPTION PATHWAY',
#  'SUMOYLATION OF INTRACELLULAR RECEPTORS',
#  'RUNX1 REGULATES ESTROGEN RECEPTOR MEDIATED TRANSCRIPTION',
#  'RUNX1 REGULATES TRANSCRIPTION OF GENES INVOLVED IN WNT SIGNALING',
#  'REGULATION OF RUNX2 EXPRESSION AND ACTIVITY',
#  'ESTROGEN-DEPENDENT GENE EXPRESSION',
#  'NUCLEAR RECEPTORS',
#  'MAMMARY GLAND DEVELOPMENT PATHWAY - PUBERTY (STAGE 2 OF 4)',
#  'ARMS-MEDIATED ACTIVATION',
#  'P130CAS LINKAGE TO MAPK SIGNALING FOR INTEGRINS',
#  'PTK6 REGULATES RHO GTPASES, RAS GTPASE AND MAP KINASES',
#  'MET ACTIVATES RAP1 AND RAC1',
#  'MET RECEPTOR RECYCLING',
#  'MET PROMOTES CELL MOTILITY',
#  'RETT SYNDROME CAUSING GENES',
#  'NEDDYLATION',
#  'R-HSA-9031628',
#  'SEROTONIN AND ANXIETY-RELATED EVENTS',
#  'PLC-GAMMA1 SIGNALLING',
#  'RETROGRADE NEUROTROPHIN SIGNALLING',
#  'ACTIVATION OF TRKA RECEPTORS',
#  'NGF-INDEPENDANT TRKA ACTIVATION',
#  'TRKA ACTIVATION BY NGF',
#  'SIGNALLING TO P38 VIA RIT AND RIN',
#  'GPCRS, OTHER',
#  'INTEGRIN CELL SURFACE INTERACTIONS',
#  'MAPK6-MAPK4 SIGNALING',
#  'HSP90 CHAPERONE CYCLE FOR STEROID HORMONE RECEPTORS (SHR)',
#  'RHO GTPASES ACTIVATE PKNS',
#  'ACTIVATED PKN1 STIMULATES TRANSCRIPTION OF AR (ANDROGEN RECEPTOR) REGULATED GENES KLK2 AND KLK3',
#  'GLYCOSAMINOGLYCAN METABOLISM',
#  'HYALURONAN METABOLISM',
#  'HYALURONAN UPTAKE AND DEGRADATION',
#  'METABOLISM OF CARBOHYDRATES',
#  'R-HSA-9639288',
#  'MTORC1-MEDIATED SIGNALLING',
#  'HSF1-DEPENDENT TRANSACTIVATION',
#  'ENERGY DEPENDENT REGULATION OF MTOR BY LKB1-AMPK',
#  'ATM SIGNALING NETWORK IN DEVELOPMENT AND DISEASE',
#  'R-HSA-9659787',
#  ...]

# %%
gene_to_pathway_results = {}
gene_to_pathway_genes = list(gene_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'pathway_count' : 0
    }

for index, row in gene_to_pathways.iterrows():
    gene_to_pathway_results[row['output_name']]['pathway_count'] = gene_to_pathway_results[row['output_name']]['pathway_count'] + 1

gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['pathway_count'], reverse = True))

    
gene_to_pathway_results
# Out:
# {'IMMUNE SYSTEM': {'pathway_count': 132},
#  'SIGNAL TRANSDUCTION': {'pathway_count': 111},
#  'CYTOKINE SIGNALING IN IMMUNE SYSTEM': {'pathway_count': 98},
#  'SIGNALING BY INTERLEUKINS': {'pathway_count': 76},
#  'DISEASE': {'pathway_count': 74},
#  'INNATE IMMUNE SYSTEM': {'pathway_count': 63},
#  'GENERIC TRANSCRIPTION PATHWAY': {'pathway_count': 54},
#  'RNA POLYMERASE II TRANSCRIPTION': {'pathway_count': 54},
#  'GENE EXPRESSION (TRANSCRIPTION)': {'pathway_count': 54},
#  'METABOLISM OF PROTEINS': {'pathway_count': 53},
#  'PI3K-AKT SIGNALING PATHWAY': {'pathway_count': 41},
#  'DISEASES OF SIGNAL TRANSDUCTION': {'pathway_count': 38},
#  'ADAPTIVE IMMUNE SYSTEM': {'pathway_count': 37},
#  'HEMOSTASIS': {'pathway_count': 37},
#  'DEVELOPMENTAL BIOLOGY': {'pathway_count': 37},
#  'SIGNALING BY RECEPTOR TYROSINE KINASES': {'pathway_count': 37},
#  'POST-TRANSLATIONAL PROTEIN MODIFICATION': {'pathway_count': 36},
#  'INTERLEUKIN-4 AND INTERLEUKIN-13 SIGNALING': {'pathway_count': 36},
#  'INFECTIOUS DISEASE': {'pathway_count': 33},
#  'REGULATION OF TOLL-LIKE RECEPTOR SIGNALING PATHWAY': {'pathway_count': 32},
#  'JAK-STAT': {'pathway_count': 32},
#  'VEGFA-VEGFR2 SIGNALING PATHWAY': {'pathway_count': 32},
#  'SIGNALING BY GPCR': {'pathway_count': 31},
#  'CELLULAR RESPONSES TO STRESS': {'pathway_count': 30},
#  'CELLULAR RESPONSES TO EXTERNAL STIMULI': {'pathway_count': 30},
#  'INTRACELLULAR SIGNALING BY SECOND MESSENGERS': {'pathway_count': 30},
#  'PIP3 ACTIVATES AKT SIGNALING': {'pathway_count': 29},
#  'GPCR DOWNSTREAM SIGNALLING': {'pathway_count': 28},
#  'FOCAL ADHESION-PI3K-AKT-MTOR-SIGNALING PATHWAY': {'pathway_count': 28},
#  'TOLL-LIKE RECEPTOR SIGNALING PATHWAY': {'pathway_count': 28},
#  'APOPTOSIS': {'pathway_count': 27},
#  'NEUTROPHIL DEGRANULATION': {'pathway_count': 27},
#  'SPINAL CORD INJURY': {'pathway_count': 27},
#  'PLATELET ACTIVATION, SIGNALING AND AGGREGATION': {'pathway_count': 26},
#  'BREAST CANCER PATHWAY': {'pathway_count': 24},
#  'TOLL-LIKE RECEPTOR CASCADES': {'pathway_count': 24},
#  'SENESCENCE AND AUTOPHAGY IN CANCER': {'pathway_count': 24},
#  'METABOLISM': {'pathway_count': 24},
#  'VIRAL ACUTE MYOCARDITIS': {'pathway_count': 23},
#  'ADIPOGENESIS': {'pathway_count': 23},
#  'PANCREATIC ADENOCARCINOMA PATHWAY': {'pathway_count': 23},
#  'MAPK SIGNALING PATHWAY': {'pathway_count': 23},
#  'T-CELL ANTIGEN RECEPTOR (TCR) SIGNALING PATHWAY': {'pathway_count': 22},
#  'NUCLEAR RECEPTORS META-PATHWAY': {'pathway_count': 22},
#  'MAPK FAMILY SIGNALING CASCADES': {'pathway_count': 22},
#  'LEPTIN SIGNALING PATHWAY': {'pathway_count': 22},
#  'PROLACTIN SIGNALING PATHWAY': {'pathway_count': 22},
#  'BRAIN-DERIVED NEUROTROPHIC FACTOR (BDNF) SIGNALING PATHWAY': {'pathway_count': 22},
#  'DNA DAMAGE RESPONSE (ONLY ATM DEPENDENT)': {'pathway_count': 22},
#  'GPCR LIGAND BINDING': {'pathway_count': 22},
#  'ALLOGRAFT REJECTION': {'pathway_count': 22},
#  'TOLL LIKE RECEPTOR 4 (TLR4) CASCADE': {'pathway_count': 21},
#  'CLASS A/1 (RHODOPSIN-LIKE RECEPTORS)': {'pathway_count': 21},
#  'PI3K/AKT SIGNALING IN CANCER': {'pathway_count': 21},
#  'R-HSA-9675108': {'pathway_count': 20},
#  'NEGATIVE REGULATION OF THE PI3K/AKT NETWORK': {'pathway_count': 20},
#  'G ALPHA (I) SIGNALLING EVENTS': {'pathway_count': 20},
#  'AXON GUIDANCE': {'pathway_count': 20},
#  'MAPK1/MAPK3 SIGNALING': {'pathway_count': 20},
#  'FLT3 SIGNALING': {'pathway_count': 20},
#  'ONCOSTATIN M SIGNALING PATHWAY': {'pathway_count': 20},
#  'INTERLEUKIN-10 SIGNALING': {'pathway_count': 20},
#  'NONALCOHOLIC FATTY LIVER DISEASE': {'pathway_count': 20},
#  'INTERFERON SIGNALING': {'pathway_count': 20},
#  'T-CELL ANTIGEN RECEPTOR (TCR) PATHWAY DURING STAPHYLOCOCCUS AUREUS INFECTION': {'pathway_count': 19},
#  'ANDROGEN RECEPTOR SIGNALING PATHWAY': {'pathway_count': 19},
#  'PI5P, PP2A AND IER3 REGULATE PI3K/AKT SIGNALING': {'pathway_count': 19},
#  'FOCAL ADHESION': {'pathway_count': 19},
#  'CHEMOKINE SIGNALING PATHWAY': {'pathway_count': 19},
#  'PEPTIDE LIGAND-BINDING RECEPTORS': {'pathway_count': 19},
#  'TRANSCRIPTIONAL REGULATION BY TP53': {'pathway_count': 19},
#  'HEPATITIS C AND HEPATOCELLULAR CARCINOMA': {'pathway_count': 19},
#  'SUDDEN INFANT DEATH SYNDROME (SIDS) SUSCEPTIBILITY PATHWAYS': {'pathway_count': 19},
#  'FOLATE METABOLISM': {'pathway_count': 18},
#  'DEUBIQUITINATION': {'pathway_count': 18},
#  'RAF/MAP KINASE CASCADE': {'pathway_count': 18},
#  'ESR-MEDIATED SIGNALING': {'pathway_count': 18},
#  'SIGNALING BY NUCLEAR RECEPTORS': {'pathway_count': 18},
#  'THYMIC STROMAL LYMPHOPOIETIN (TSLP) SIGNALING PATHWAY': {'pathway_count': 18},
#  'B CELL RECEPTOR SIGNALING PATHWAY': {'pathway_count': 18},
#  'AGE-RAGE PATHWAY': {'pathway_count': 18},
#  'KIT RECEPTOR SIGNALING PATHWAY': {'pathway_count': 18},
#  'RAC1-PAK1-P38-MMP2 PATHWAY': {'pathway_count': 18},
#  'EGF-EGFR SIGNALING PATHWAY': {'pathway_count': 18},
#  'IL-2 SIGNALING PATHWAY': {'pathway_count': 18},
#  'LUNG FIBROSIS': {'pathway_count': 18},
#  'CELL CYCLE': {'pathway_count': 17},
#  'ENDOMETRIAL CANCER': {'pathway_count': 17},
#  'PROGRAMMED CELL DEATH': {'pathway_count': 17},
#  'MICRORNAS IN CARDIOMYOCYTE HYPERTROPHY': {'pathway_count': 17},
#  'SIGNALING PATHWAYS IN GLIOBLASTOMA': {'pathway_count': 17},
#  'IL-3 SIGNALING PATHWAY': {'pathway_count': 17},
#  'TGF-BETA SIGNALING PATHWAY': {'pathway_count': 17},
#  'EBOLA VIRUS PATHWAY ON HOST': {'pathway_count': 17},
#  'ERBB SIGNALING PATHWAY': {'pathway_count': 17},
#  'EXTRACELLULAR MATRIX ORGANIZATION': {'pathway_count': 17},
#  'PHOTODYNAMIC THERAPY-INDUCED AP-1 SURVIVAL SIGNALING.': {'pathway_count': 17},
#  'SELENIUM MICRONUTRIENT NETWORK': {'pathway_count': 16},
#  'VESICLE-MEDIATED TRANSPORT': {'pathway_count': 16},
#  'CHROMOSOMAL AND MICROSATELLITE INSTABILITY IN COLORECTAL CANCER': {'pathway_count': 16},
#  'MYD88:MAL(TIRAP) CASCADE INITIATED ON PLASMA MEMBRANE': {'pathway_count': 16},
#  'MYD88-INDEPENDENT TLR4 CASCADE ': {'pathway_count': 16},
#  'TOLL LIKE RECEPTOR TLR1:TLR2 CASCADE': {'pathway_count': 16},
#  'TOLL LIKE RECEPTOR TLR6:TLR2 CASCADE': {'pathway_count': 16},
#  'TOLL LIKE RECEPTOR 2 (TLR2) CASCADE': {'pathway_count': 16},
#  'TRIF(TICAM1)-MEDIATED TLR4 SIGNALING ': {'pathway_count': 16},
#  'IL-4 SIGNALING PATHWAY': {'pathway_count': 16},
#  'FIBRIN COMPLEMENT RECEPTOR 3 SIGNALING PATHWAY': {'pathway_count': 16},
#  'PHOTODYNAMIC THERAPY-INDUCED NF-KB SURVIVAL SIGNALING': {'pathway_count': 16},
#  'MIRNAS INVOLVEMENT IN THE IMMUNE RESPONSE IN SEPSIS': {'pathway_count': 16},
#  'INTERLEUKIN-1 FAMILY SIGNALING': {'pathway_count': 16},
#  'VITAMIN B12 METABOLISM': {'pathway_count': 15},
#  'NON-SMALL CELL LUNG CANCER': {'pathway_count': 15},
#  'R-HSA-9658195': {'pathway_count': 15},
#  'SIGNALING BY NTRKS': {'pathway_count': 15},
#  'TOLL LIKE RECEPTOR 9 (TLR9) CASCADE': {'pathway_count': 15},
#  'TOLL LIKE RECEPTOR 7/8 (TLR7/8) CASCADE': {'pathway_count': 15},
#  'CELLULAR SENESCENCE': {'pathway_count': 15},
#  'EXTRA-NUCLEAR ESTROGEN SIGNALING': {'pathway_count': 15},
#  'TRAF6 MEDIATED INDUCTION OF NFKB AND MAP KINASES UPON TLR7/8 OR 9 ACTIVATION': {'pathway_count': 15},
#  'MYD88 DEPENDENT CASCADE INITIATED ON ENDOSOME': {'pathway_count': 15},
#  'RANKL-RANK (RECEPTOR ACTIVATOR OF NFKB (LIGAND)) SIGNALING PATHWAY': {'pathway_count': 15},
#  'CORTICOTROPIN-RELEASING HORMONE SIGNALING PATHWAY': {'pathway_count': 15},
#  'EPITHELIAL TO MESENCHYMAL TRANSITION IN COLORECTAL CANCER': {'pathway_count': 15},
#  'INSULIN SIGNALING': {'pathway_count': 15},
#  'INTERLEUKIN-3, INTERLEUKIN-5 AND GM-CSF SIGNALING': {'pathway_count': 15},
#  'CONSTITUTIVE SIGNALING BY ABERRANT PI3K IN CANCER': {'pathway_count': 15},
#  'VITAMIN D RECEPTOR PATHWAY': {'pathway_count': 15},
#  'MEMBRANE TRAFFICKING': {'pathway_count': 14},
#  'CYTOKINES AND INFLAMMATORY RESPONSE': {'pathway_count': 14},
#  'PLATELET DEGRANULATION ': {'pathway_count': 14},
#  'RESPONSE TO ELEVATED PLATELET CYTOSOLIC CA2+': {'pathway_count': 14},
#  'TOLL LIKE RECEPTOR 3 (TLR3) CASCADE': {'pathway_count': 14},
#  'HUMAN THYROID STIMULATING HORMONE (TSH) SIGNALING PATHWAY': {'pathway_count': 14},
#  'BLADDER CANCER': {'pathway_count': 14},
#  'RAS SIGNALING': {'pathway_count': 14},
#  'NON-GENOMIC ACTIONS OF 1,25 DIHYDROXYVITAMIN D3': {'pathway_count': 14},
#  'TRANSCRIPTIONAL REGULATION BY RUNX1': {'pathway_count': 14},
#  'INTERFERON GAMMA SIGNALING': {'pathway_count': 14},
#  'INTERFERON TYPE I SIGNALING PATHWAYS': {'pathway_count': 14},
#  'SIGNALING BY NOTCH': {'pathway_count': 14},
#  'IL-6 SIGNALING PATHWAY': {'pathway_count': 13},
#  'MIRNA REGULATION OF DNA DAMAGE RESPONSE': {'pathway_count': 13},
#  'DNA DAMAGE RESPONSE': {'pathway_count': 13},
#  'IL-5 SIGNALING PATHWAY': {'pathway_count': 13},
#  'TNF RELATED WEAK INDUCER OF APOPTOSIS (TWEAK) SIGNALING PATHWAY': {'pathway_count': 13},
#  'INTERLEUKIN-11 SIGNALING PATHWAY': {'pathway_count': 13},
#  'PROTEIN ALKYLATION LEADING TO LIVER FIBROSIS': {'pathway_count': 13},
#  'MIRNA REGULATION OF PROSTATE CANCER SIGNALING PATHWAYS': {'pathway_count': 13},
#  'INTERLEUKIN-2 FAMILY SIGNALING': {'pathway_count': 13},
#  'MIR-TARGETED GENES IN LYMPHOCYTES - TARBASE': {'pathway_count': 13},
#  'DEATH RECEPTOR SIGNALLING': {'pathway_count': 13},
#  'SUMOYLATION': {'pathway_count': 13},
#  'SUMO E3 LIGASES SUMOYLATE TARGET PROTEINS': {'pathway_count': 13},
#  'SIGNALING BY PTK6': {'pathway_count': 13},
#  'SIGNALING BY NON-RECEPTOR TYROSINE KINASES': {'pathway_count': 13},
#  'UB-SPECIFIC PROCESSING PROTEASES': {'pathway_count': 12},
#  'COSTIMULATION BY THE CD28 FAMILY': {'pathway_count': 12},
#  'TOLL LIKE RECEPTOR 10 (TLR10) CASCADE': {'pathway_count': 12},
#  'TOLL LIKE RECEPTOR 5 (TLR5) CASCADE': {'pathway_count': 12},
#  'SIGNALING BY NTRK1 (TRKA)': {'pathway_count': 12},
#  'MYD88 CASCADE INITIATED ON PLASMA MEMBRANE': {'pathway_count': 12},
#  'IL-1 SIGNALING PATHWAY': {'pathway_count': 12},
#  'ANDROGEN RECEPTOR NETWORK IN PROSTATE CANCER': {'pathway_count': 12},
#  'ARYL HYDROCARBON RECEPTOR': {'pathway_count': 12},
#  'ESC PLURIPOTENCY PATHWAYS': {'pathway_count': 12},
#  'MIR-TARGETED GENES IN MUSCLE CELL - TARBASE': {'pathway_count': 12},
#  'SIGNALING BY VEGF': {'pathway_count': 12},
#  'VEGFA-VEGFR2 PATHWAY': {'pathway_count': 12},
#  'TRANSCRIPTIONAL REGULATION BY RUNX3': {'pathway_count': 12},
#  'DIFFERENTIATION PATHWAY': {'pathway_count': 12},
#  'CELL SURFACE INTERACTIONS AT THE VASCULAR WALL': {'pathway_count': 12},
#  'SIGNALING BY SCF-KIT': {'pathway_count': 12},
#  'METABOLISM OF LIPIDS': {'pathway_count': 12},
#  'HUMAN COMPLEMENT SYSTEM': {'pathway_count': 11},
#  'CLATHRIN-MEDIATED ENDOCYTOSIS': {'pathway_count': 11},
#  'FC EPSILON RECEPTOR (FCERI) SIGNALING': {'pathway_count': 11},
#  'CELL CYCLE, MITOTIC': {'pathway_count': 11},
#  'INTEGRATED BREAST CANCER PATHWAY': {'pathway_count': 11},
#  'ANGIOGENESIS OVERVIEW': {'pathway_count': 11},
#  'TNF ALPHA SIGNALING PATHWAY': {'pathway_count': 11},
#  'CARDIAC HYPERTROPHIC RESPONSE': {'pathway_count': 11},
#  'ASSOCIATION BETWEEN PHYSICO-CHEMICAL FEATURES AND TOXICITY ASSOCIATED PATHWAYS': {'pathway_count': 11},
#  'MET IN TYPE 1 PAPILLARY RENAL CELL CARCINOMA': {'pathway_count': 11},
#  'LTF DANGER SIGNAL RESPONSE PATHWAY': {'pathway_count': 11},
#  'TGF-BETA RECEPTOR SIGNALING': {'pathway_count': 11},
#  'HEMATOPOIETIC STEM CELL DIFFERENTIATION': {'pathway_count': 11},
#  'CHEMOKINE RECEPTORS BIND CHEMOKINES': {'pathway_count': 11},
#  'RIG-I-LIKE RECEPTOR SIGNALING': {'pathway_count': 11},
#  'REGULATION OF TP53 ACTIVITY': {'pathway_count': 11},
#  'INTERFERON ALPHA/BETA SIGNALING': {'pathway_count': 11},
#  'APOPTOSIS MODULATION AND SIGNALING': {'pathway_count': 11},
#  'PATHWAYS IN CLEAR CELL RENAL CELL CARCINOMA': {'pathway_count': 11},
#  'SIGNALING BY RHO GTPASES': {'pathway_count': 10},
#  'CARGO RECOGNITION FOR CLATHRIN-MEDIATED ENDOCYTOSIS': {'pathway_count': 10},
#  'TCR SIGNALING': {'pathway_count': 10},
#  'CELLULAR RESPONSE TO HEAT STRESS': {'pathway_count': 10},
#  'FOXO-MEDIATED TRANSCRIPTION': {'pathway_count': 10},
#  'SENESCENCE-ASSOCIATED SECRETORY PHENOTYPE (SASP)': {'pathway_count': 10},
#  'TRANSCRIPTIONAL REGULATION BY RUNX2': {'pathway_count': 10},
#  'IL-7 SIGNALING PATHWAY': {'pathway_count': 10},
#  'APOPTOSIS-RELATED NETWORK DUE TO ALTERED NOTCH3 IN OVARIAN CANCER': {'pathway_count': 10},
#  'ANGIOPOIETIN LIKE PROTEIN 8 REGULATORY PATHWAY': {'pathway_count': 10},
#  'RESISTIN AS A REGULATOR OF INFLAMMATION': {'pathway_count': 10},
#  'REGULATION OF ACTIN CYTOSKELETON': {'pathway_count': 10},
#  'SIGNALING BY PDGF': {'pathway_count': 10},
#  'IL1 AND MEGAKARYOCYTES IN OBESITY': {'pathway_count': 10},
#  'NOTCH SIGNALING PATHWAY': {'pathway_count': 10},
#  'EXTRACELLULAR VESICLES IN THE CROSSTALK OF CARDIAC CELLS': {'pathway_count': 10},
#  'CLASS I MHC MEDIATED ANTIGEN PROCESSING & PRESENTATION': {'pathway_count': 10},
#  'PEPTIDE HORMONE METABOLISM': {'pathway_count': 9},
#  'RHO GTPASE EFFECTORS': {'pathway_count': 9},
#  'TRANSPORT OF SMALL MOLECULES': {'pathway_count': 9},
#  'DOWNSTREAM TCR SIGNALING': {'pathway_count': 9},
#  'PTEN REGULATION': {'pathway_count': 9},
#  'WNT SIGNALING PATHWAY': {'pathway_count': 9},
#  'TOLL-LIKE RECEPTOR SIGNALING': {'pathway_count': 9},
#  'ESTROGEN SIGNALING PATHWAY': {'pathway_count': 9},
#  'ENDOCHONDRAL OSSIFICATION': {'pathway_count': 9},
#  'CONTROL OF IMMUNE TOLERANCE BY VASOACTIVE INTESTINALPEPTIDE': {'pathway_count': 9},
#  'MIR-TARGETED GENES IN EPITHELIUM - TARBASE': {'pathway_count': 9},
#  'TYPE II INTERFERON SIGNALING (IFNG)': {'pathway_count': 9},
#  'CARDIAC PROGENITOR DIFFERENTIATION': {'pathway_count': 9},
#  'IMMUNOREGULATORY INTERACTIONS BETWEEN A LYMPHOID AND A NON-LYMPHOID CELL': {'pathway_count': 9},
#  'REGULATION OF INSULIN-LIKE GROWTH FACTOR (IGF) TRANSPORT AND UPTAKE BY INSULIN-LIKE GROWTH FACTOR BINDING PROTEINS (IGFBPS)': {'pathway_count': 9},
#  'DDX58/IFIH1-MEDIATED INDUCTION OF INTERFERON-ALPHA/BETA': {'pathway_count': 9},
#  'PATHWAYS AFFECTED IN ADENOID CYSTIC CARCINOMA': {'pathway_count': 9},
#  'G1 TO S CELL CYCLE CONTROL': {'pathway_count': 9},
#  'DOWNSTREAM SIGNAL TRANSDUCTION': {'pathway_count': 9},
#  'PDGFR-BETA PATHWAY': {'pathway_count': 9},
#  'INTEGRATED LUNG CANCER PATHWAY': {'pathway_count': 9},
#  'CYTOSOLIC SENSORS OF PATHOGEN-ASSOCIATED DNA ': {'pathway_count': 9},
#  'INTERLEUKIN-1 SIGNALING': {'pathway_count': 9},
#  'SIGNALING BY THE B CELL RECEPTOR (BCR)': {'pathway_count': 9},
#  'CIRCADIAN CLOCK': {'pathway_count': 8},
#  'INTRINSIC PATHWAY FOR APOPTOSIS': {'pathway_count': 8},
#  'OXIDATIVE STRESS INDUCED SENESCENCE': {'pathway_count': 8},
#  'G ALPHA (Q) SIGNALLING EVENTS': {'pathway_count': 8},
#  'INTERLEUKIN-17 SIGNALING': {'pathway_count': 8},
#  'MAP KINASE ACTIVATION': {'pathway_count': 8},
#  'ESTROGEN-DEPENDENT NUCLEAR EVENTS DOWNSTREAM OF ESR-MEMBRANE SIGNALING': {'pathway_count': 8},
#  'GROWTH HORMONE RECEPTOR SIGNALING': {'pathway_count': 8},
#  'INTEGRIN-MEDIATED CELL ADHESION': {'pathway_count': 8},
#  'EBV LMP1 SIGNALING': {'pathway_count': 8},
#  'SIGNALING OF HEPATOCYTE GROWTH FACTOR RECEPTOR': {'pathway_count': 8},
#  'PRION DISEASE PATHWAY': {'pathway_count': 8},
#  'EPO RECEPTOR SIGNALING': {'pathway_count': 8},
#  'NUCLEOTIDE-BINDING DOMAIN, LEUCINE RICH REPEAT CONTAINING RECEPTOR (NLR) SIGNALING PATHWAYS': {'pathway_count': 8},
#  'SIGNALING BY TGF-BETA RECEPTOR COMPLEX': {'pathway_count': 8},
#  'SIGNALING BY TGF-BETA FAMILY MEMBERS': {'pathway_count': 8},
#  'INTERLEUKIN RECEPTOR SHC SIGNALING': {'pathway_count': 8},
#  'T-CELL RECEPTOR AND CO-STIMULATORY SIGNALING': {'pathway_count': 8},
#  'ARYL HYDROCARBON RECEPTOR PATHWAY': {'pathway_count': 8},
#  'INFLAMMATORY RESPONSE PATHWAY': {'pathway_count': 8},
#  'DEVELOPMENT AND HETEROGENEITY OF THE ILC FAMILY': {'pathway_count': 8},
#  'R-HSA-9662851': {'pathway_count': 8},
#  'R-HSA-9664433': {'pathway_count': 8},
#  'AMYOTROPHIC LATERAL SCLEROSIS (ALS)': {'pathway_count': 8},
#  'TRANSCRIPTIONAL REGULATION OF WHITE ADIPOCYTE DIFFERENTIATION': {'pathway_count': 8},
#  'OVARIAN TUMOR DOMAIN PROTEASES': {'pathway_count': 8},
#  'REGULATION OF TP53 DEGRADATION': {'pathway_count': 8},
#  'REGULATION OF TP53 EXPRESSION AND DEGRADATION': {'pathway_count': 8},
#  'CELL CYCLE CHECKPOINTS': {'pathway_count': 8},
#  'DNA REPAIR': {'pathway_count': 8},
#  'AMP-ACTIVATED PROTEIN KINASE (AMPK) SIGNALING': {'pathway_count': 8},
#  'TP53 NETWORK': {'pathway_count': 8},
#  'RETINOBLASTOMA GENE IN CANCER': {'pathway_count': 8},
#  'COPPER HOMEOSTASIS': {'pathway_count': 8},
#  'SIGNALING BY ERBB2': {'pathway_count': 8},
#  'MITOTIC G1-G1/S PHASES': {'pathway_count': 8},
#  'PRIMARY FOCAL SEGMENTAL GLOMERULOSCLEROSIS FSGS': {'pathway_count': 8},
#  'SIGNALING BY EGFR': {'pathway_count': 8},
#  'ER-PHAGOSOME PATHWAY': {'pathway_count': 8},
#  'ANTIGEN PROCESSING-CROSS PRESENTATION': {'pathway_count': 8},
#  'DISEASES OF IMMUNE SYSTEM': {'pathway_count': 8},
#  'DISEASES ASSOCIATED WITH THE TLR SIGNALING CASCADE': {'pathway_count': 8},
#  'SIGNALING BY MET': {'pathway_count': 8},
#  'GPVI-MEDIATED ACTIVATION CASCADE': {'pathway_count': 8},
#  'CELL-CELL COMMUNICATION': {'pathway_count': 8},
#  'REGULATION OF SIGNALING BY CBL': {'pathway_count': 8},
#  'COMPLEMENT CASCADE': {'pathway_count': 7},
#  'OVERVIEW OF NANOPARTICLE EFFECTS': {'pathway_count': 7},
#  'ORGANELLE BIOGENESIS AND MAINTENANCE': {'pathway_count': 7},
#  'REGULATION OF HSF1-MEDIATED HEAT SHOCK RESPONSE': {'pathway_count': 7},
#  'STEROL REGULATORY ELEMENT-BINDING PROTEINS (SREBP) SIGNALLING': {'pathway_count': 7},
#  'SIGNALING BY FGFR': {'pathway_count': 7},
#  'FCGAMMA RECEPTOR (FCGR) DEPENDENT PHAGOCYTOSIS': {'pathway_count': 7},
#  'SIGNALING BY FGFR1': {'pathway_count': 7},
#  'INSULIN RECEPTOR SIGNALLING CASCADE': {'pathway_count': 7},
#  'SIGNALING BY INSULIN RECEPTOR': {'pathway_count': 7},
#  'ANGIOGENESIS': {'pathway_count': 7},
#  'ALZHEIMERS DISEASE': {'pathway_count': 7},
#  'ALPHA 6 BETA 4 SIGNALING PATHWAY': {'pathway_count': 7},
#  'NEOVASCULARISATION PROCESSES': {'pathway_count': 7},
#  'RELATIONSHIP BETWEEN INFLAMMATION, COX-2 AND EGFR': {'pathway_count': 7},
#  'PHOTODYNAMIC THERAPY-INDUCED HIF-1 SURVIVAL SIGNALING': {'pathway_count': 7},
#  'MIRNA REGULATION OF P53 PATHWAY IN PROSTATE CANCER': {'pathway_count': 7},
#  'PLATELET-MEDIATED INTERACTIONS WITH VASCULAR AND CIRCULATING CELLS': {'pathway_count': 7},
#  'REGULATION OF TP53 ACTIVITY THROUGH PHOSPHORYLATION': {'pathway_count': 7},
#  'VITAMIN D IN INFLAMMATORY DISEASES': {'pathway_count': 7},
#  'TRANSCRIPTION FACTOR REGULATION IN ADIPOGENESIS': {'pathway_count': 7},
#  'P53-DEPENDENT G1 DNA DAMAGE RESPONSE': {'pathway_count': 7},
#  'P53-DEPENDENT G1/S DNA DAMAGE CHECKPOINT': {'pathway_count': 7},
#  'G1/S DNA DAMAGE CHECKPOINTS': {'pathway_count': 7},
#  'WNT SIGNALING PATHWAY AND PLURIPOTENCY': {'pathway_count': 7},
#  'TRANSCRIPTIONAL REGULATION BY THE AP-2 (TFAP2) FAMILY OF TRANSCRIPTION FACTORS': {'pathway_count': 7},
#  'SIGNALING BY WNT': {'pathway_count': 7},
#  'CD28 CO-STIMULATION': {'pathway_count': 7},
#  'CD28 DEPENDENT PI3K/AKT SIGNALING': {'pathway_count': 7},
#  'G1/S TRANSITION': {'pathway_count': 7},
#  'PI3K-AKT-MTOR - VITD3 SIGNALLING': {'pathway_count': 7},
#  'SIGNALING BY ERBB4': {'pathway_count': 7},
#  'R-HSA-9669938': {'pathway_count': 7},
#  'R-HSA-9670439': {'pathway_count': 7},
#  'SIGNALING BY FGFR IN DISEASE': {'pathway_count': 7},
#  'FGFR1 MUTANT RECEPTOR ACTIVATION': {'pathway_count': 7},
#  'SIGNALING BY FGFR1 IN DISEASE': {'pathway_count': 7},
#  'P75 NTR RECEPTOR-MEDIATED SIGNALLING': {'pathway_count': 7},
#  'MICROGLIA PATHOGEN PHAGOCYTOSIS PATHWAY': {'pathway_count': 7},
#  'C-TYPE LECTIN RECEPTORS (CLRS)': {'pathway_count': 7},
#  'ESTROGEN-DEPENDENT GENE EXPRESSION': {'pathway_count': 7},
#  'INTEGRIN CELL SURFACE INTERACTIONS': {'pathway_count': 7},
#  'R-HSA-9679506': {'pathway_count': 6},
#  'MACROAUTOPHAGY': {'pathway_count': 6},
#  'AUTOPHAGY': {'pathway_count': 6},
#  'HIV INFECTION': {'pathway_count': 6},
#  'ANTIMICROBIAL PEPTIDES': {'pathway_count': 6},
#  'TYROBP CAUSAL NETWORK': {'pathway_count': 6},
#  'REGULATION OF COMPLEMENT CASCADE': {'pathway_count': 6},
#  'DENGUE-2 INTERACTIONS WITH COMPLEMENT AND COAGULATION CASCADES': {'pathway_count': 6},
#  'COMPLEMENT AND COAGULATION CASCADES': {'pathway_count': 6},
#  'MITOCHONDRIAL BIOGENESIS': {'pathway_count': 6},
#  'ENERGY METABOLISM': {'pathway_count': 6},
#  'GLUCOCORTICOID RECEPTOR PATHWAY': {'pathway_count': 6},
#  'SIGNALING BY FGFR2': {'pathway_count': 6},
#  'SIGNALING BY FGFR3': {'pathway_count': 6},
#  'SIGNALING BY FGFR4': {'pathway_count': 6},
#  'REGULATION OF PTEN GENE TRANSCRIPTION': {'pathway_count': 6},
#  'PHYSIOLOGICAL AND PATHOLOGICAL HYPERTROPHY OF THE HEART': {'pathway_count': 6},
#  'IL-9 SIGNALING PATHWAY': {'pathway_count': 6},
#  'STRUCTURAL PATHWAY OF INTERLEUKIN 1 (IL-1)': {'pathway_count': 6},
#  'SEROTONIN HTR1 GROUP AND FOS PATHWAY': {'pathway_count': 6},
#  'INTERLEUKIN-12 FAMILY SIGNALING': {'pathway_count': 6},
#  'NO-CGMP-PKG MEDIATED NEUROPROTECTION': {'pathway_count': 6},
#  'METABOLISM OF RNA': {'pathway_count': 6},
#  'THERMOGENESIS': {'pathway_count': 6},
#  'POST-TRANSLATIONAL PROTEIN PHOSPHORYLATION': {'pathway_count': 6},
#  'POLYCYSTIC KIDNEY DISEASE PATHWAY': {'pathway_count': 6},
#  'R-HSA-8853884': {'pathway_count': 6},
#  'TP53 REGULATES TRANSCRIPTION OF CELL DEATH GENES': {'pathway_count': 6},
#  'DNA DOUBLE-STRAND BREAK REPAIR': {'pathway_count': 6},
#  'MIRNAS INVOLVED IN DNA DAMAGE RESPONSE': {'pathway_count': 6},
#  'MAMMARY GLAND DEVELOPMENT PATHWAY - INVOLUTION (STAGE 4 OF 4)': {'pathway_count': 6},
#  'TCF DEPENDENT SIGNALING IN RESPONSE TO WNT': {'pathway_count': 6},
#  'CYCLIN E ASSOCIATED EVENTS DURING G1/S TRANSITION ': {'pathway_count': 6},
#  'S PHASE': {'pathway_count': 6},
#  'CYCLIN A:CDK2-ASSOCIATED EVENTS AT S PHASE ENTRY': {'pathway_count': 6},
#  'REGULATION OF MICROTUBULE CYTOSKELETON': {'pathway_count': 6},
#  'EXTRACELLULAR VESICLE-MEDIATED SIGNALING IN RECIPIENT CELLS': {'pathway_count': 6},
#  'PI3K-AKT-MTOR SIGNALING PATHWAY AND THERAPEUTIC OPPORTUNITIES': {'pathway_count': 6},
#  'FACTORS AND PATHWAYS AFFECTING INSULIN-LIKE GROWTH FACTOR (IGF1)-AKT SIGNALING': {'pathway_count': 6},
#  'CONSTITUTIVE SIGNALING BY LIGAND-RESPONSIVE EGFR CANCER VARIANTS': {'pathway_count': 6},
#  'SIGNALING BY EGFR IN CANCER': {'pathway_count': 6},
#  'SIGNALING BY LIGAND-RESPONSIVE EGFR VARIANTS IN CANCER': {'pathway_count': 6},
#  'SIGNALING BY NOTCH3': {'pathway_count': 6},
#  'MAMMARY GLAND DEVELOPMENT PATHWAY - PREGNANCY AND LACTATION (STAGE 3 OF 4)': {'pathway_count': 6},
#  'INTERLEUKIN-6 SIGNALING': {'pathway_count': 6},
#  'INTERLEUKIN-6 FAMILY SIGNALING': {'pathway_count': 6},
#  'ENDODERM DIFFERENTIATION': {'pathway_count': 6},
#  'FOXO-MEDIATED TRANSCRIPTION OF OXIDATIVE STRESS, METABOLIC AND NEURONAL GENES': {'pathway_count': 6},
#  'WHITE FAT CELL DIFFERENTIATION': {'pathway_count': 6},
#  'REGULATION OF TLR BY ENDOGENOUS LIGAND': {'pathway_count': 6},
#  'SIGNALING BY CYTOSOLIC FGFR1 FUSION MUTANTS': {'pathway_count': 6},
#  'DAP12 INTERACTIONS': {'pathway_count': 6},
#  'SIGNALING BY TYPE 1 INSULIN-LIKE GROWTH FACTOR 1 RECEPTOR (IGF1R)': {'pathway_count': 6},
#  'DAP12 SIGNALING': {'pathway_count': 6},
#  'IGF1R SIGNALING CASCADE': {'pathway_count': 6},
#  'IRS-RELATED EVENTS TRIGGERED BY IGF1R': {'pathway_count': 6},
#  'TAK1 ACTIVATES NFKB BY PHOSPHORYLATION AND ACTIVATION OF IKKS COMPLEX': {'pathway_count': 6},
#  'TRANSCRIPTIONAL REGULATION BY MECP2': {'pathway_count': 6},
#  'NUCLEAR RECEPTOR TRANSCRIPTION PATHWAY': {'pathway_count': 6},
#  'NUCLEAR RECEPTORS': {'pathway_count': 6},
#  'MAMMARY GLAND DEVELOPMENT PATHWAY - PUBERTY (STAGE 2 OF 4)': {'pathway_count': 6},
#  'SIGNALING BY NOTCH1': {'pathway_count': 6},
#  'NOTCH1 INTRACELLULAR DOMAIN REGULATES TRANSCRIPTION': {'pathway_count': 6},
#  'ANTIGEN ACTIVATES B CELL RECEPTOR (BCR) LEADING TO GENERATION OF SECOND MESSENGERS': {'pathway_count': 6},
#  'R-HSA-9663891': {'pathway_count': 5},
#  'CALORIC RESTRICTION AND AGING': {'pathway_count': 5},
#  'TRANSMISSION ACROSS CHEMICAL SYNAPSES': {'pathway_count': 5},
#  'NEURONAL SYSTEM': {'pathway_count': 5},
#  'NUCLEAR EVENTS (KINASE AND TRANSCRIPTION FACTOR ACTIVATION)': {'pathway_count': 5},
#  'ONCOGENE INDUCED SENESCENCE': {'pathway_count': 5},
#  'L1CAM INTERACTIONS': {'pathway_count': 5},
#  'NCAM SIGNALING FOR NEURITE OUT-GROWTH': {'pathway_count': 5},
#  'MAPK TARGETS/ NUCLEAR EVENTS MEDIATED BY MAP KINASES': {'pathway_count': 5},
#  'NEGATIVE REGULATION OF FGFR1 SIGNALING': {'pathway_count': 5},
#  'HEART DEVELOPMENT': {'pathway_count': 5},
#  'FOLLICLE STIMULATING HORMONE (FSH) SIGNALING PATHWAY': {'pathway_count': 5},
#  'IL17 SIGNALING PATHWAY': {'pathway_count': 5},
#  'HYPOTHESIZED PATHWAYS IN PATHOGENESIS OF CARDIOVASCULAR DISEASE': {'pathway_count': 5},
#  'MYOMETRIAL RELAXATION AND CONTRACTION PATHWAYS': {'pathway_count': 5},
#  'NUCLEOTIDE-BINDING OLIGOMERIZATION DOMAIN (NOD) PATHWAY': {'pathway_count': 5},
#  'TRANSCRIPTIONAL ACTIVITY OF SMAD2/SMAD3:SMAD4 HETEROTRIMER': {'pathway_count': 5},
#  'SMAD2/SMAD3:SMAD4 HETEROTRIMER REGULATES TRANSCRIPTION': {'pathway_count': 5},
#  'OXIDATIVE DAMAGE': {'pathway_count': 5},
#  'RUNX1 AND FOXP3 CONTROL THE DEVELOPMENT OF REGULATORY T LYMPHOCYTES (TREGS)': {'pathway_count': 5},
#  'MIR-TARGETED GENES IN LEUKOCYTES - TARBASE': {'pathway_count': 5},
#  'REGULATION OF IFNG SIGNALING': {'pathway_count': 5},
#  'NOD1/2 SIGNALING PATHWAY': {'pathway_count': 5},
#  'REGULATION OF MRNA STABILITY BY PROTEINS THAT BIND AU-RICH ELEMENTS': {'pathway_count': 5},
#  'CANONICAL AND NON-CANONICAL TGF-B SIGNALING': {'pathway_count': 5},
#  'P38 MAPK SIGNALING PATHWAY': {'pathway_count': 5},
#  'REGULATION OF TNFR1 SIGNALING': {'pathway_count': 5},
#  'TNFR1-INDUCED NFKAPPAB SIGNALING PATHWAY': {'pathway_count': 5},
#  'TNFR2 NON-CANONICAL NF-KB PATHWAY': {'pathway_count': 5},
#  'TNF SIGNALING': {'pathway_count': 5},
#  'MAMMARY GLAND DEVELOPMENT PATHWAY - EMBRYONIC DEVELOPMENT (STAGE 1 OF 4)': {'pathway_count': 5},
#  'FAS LIGAND (FASL) PATHWAY AND STRESS INDUCTION OF HEAT SHOCK PROTEINS (HSP) REGULATION': {'pathway_count': 5},
#  'REGULATION OF IFNA SIGNALING': {'pathway_count': 5},
#  'FACTORS INVOLVED IN MEGAKARYOCYTE DEVELOPMENT AND PLATELET PRODUCTION': {'pathway_count': 5},
#  'TP53 REGULATES METABOLIC GENES': {'pathway_count': 5},
#  'RECRUITMENT AND ATM-MEDIATED PHOSPHORYLATION OF REPAIR AND SIGNALING PROTEINS AT DNA DOUBLE STRAND BREAKS': {'pathway_count': 5},
#  'DNA DOUBLE STRAND BREAK RESPONSE': {'pathway_count': 5},
#  'G2/M CHECKPOINTS': {'pathway_count': 5},
#  'STABILIZATION OF P53': {'pathway_count': 5},
#  'CELLULAR RESPONSE TO HYPOXIA': {'pathway_count': 5},
#  'TYPE 2 PAPILLARY RENAL CELL CARCINOMA': {'pathway_count': 5},
#  'CTLA4 INHIBITORY SIGNALING': {'pathway_count': 5},
#  'CONSTITUTIVE SIGNALING BY AKT1 E17K IN CANCER': {'pathway_count': 5},
#  'SIGNALING BY NOTCH4': {'pathway_count': 5},
#  'MECP2 AND ASSOCIATED RETT SYNDROME': {'pathway_count': 5},
#  'LEPTIN INSULIN OVERLAP': {'pathway_count': 5},
#  'GAB1 SIGNALOSOME': {'pathway_count': 5},
#  'EGFR DOWNREGULATION': {'pathway_count': 5},
#  'CONSTITUTIVE SIGNALING BY EGFRVIII': {'pathway_count': 5},
#  'SIGNALING BY EGFRVIII IN CANCER': {'pathway_count': 5},
#  'HAIR FOLLICLE DEVELOPMENT- INDUCTION (PART 1 OF 3)': {'pathway_count': 5},
#  'MYD88 DEFICIENCY (TLR2/4)': {'pathway_count': 5},
#  'IRAK4 DEFICIENCY (TLR2/4)': {'pathway_count': 5},
#  'ACTIVATION OF IRF3/IRF7 MEDIATED BY TBK1/IKK EPSILON': {'pathway_count': 5},
#  'IKK COMPLEX RECRUITMENT MEDIATED BY RIP1': {'pathway_count': 5},
#  'PATHOGENIC ESCHERICHIA COLI INFECTION': {'pathway_count': 5},
#  'DEGRADATION OF THE EXTRACELLULAR MATRIX': {'pathway_count': 5},
#  'R-HSA-9671555': {'pathway_count': 5},
#  'R-HSA-9673767': {'pathway_count': 5},
#  'R-HSA-9673770': {'pathway_count': 5},
#  'SIGNALING BY LEPTIN': {'pathway_count': 5},
#  'INTERLEUKIN-20 FAMILY SIGNALING': {'pathway_count': 5},
#  'TRANSCRIPTIONAL REGULATION OF GRANULOPOIESIS': {'pathway_count': 5},
#  'WNT SIGNALING': {'pathway_count': 5},
#  'PI3K CASCADE': {'pathway_count': 5},
#  'IRS-MEDIATED SIGNALLING': {'pathway_count': 5},
#  'PI3K/AKT ACTIVATION': {'pathway_count': 5},
#  'ROLE OF LAT2/NTAL/LAB ON CALCIUM MOBILIZATION': {'pathway_count': 5},
#  'SIGNALING BY ERYTHROPOIETIN': {'pathway_count': 5},
#  'ZBP1(DAI) MEDIATED INDUCTION OF TYPE I IFNS': {'pathway_count': 5},
#  'CLEC7A (DECTIN-1) SIGNALING': {'pathway_count': 5},
#  'TRAF6 MEDIATED NF-KB ACTIVATION': {'pathway_count': 5},
#  'GPCRS, CLASS A RHODOPSIN-LIKE': {'pathway_count': 5},
#  'SUMOYLATION OF INTRACELLULAR RECEPTORS': {'pathway_count': 5},
#  'CYCLIN D ASSOCIATED EVENTS IN G1': {'pathway_count': 5},
#  'G1 PHASE': {'pathway_count': 5},
#  'SIGNALING BY NOTCH1 PEST DOMAIN MUTANTS IN CANCER': {'pathway_count': 5},
#  'SIGNALING BY NOTCH1 IN CANCER': {'pathway_count': 5},
#  'CONSTITUTIVE SIGNALING BY NOTCH1 PEST DOMAIN MUTANTS': {'pathway_count': 5},
#  'SIGNALING BY NOTCH1 HD+PEST DOMAIN MUTANTS IN CANCER': {'pathway_count': 5},
#  'CONSTITUTIVE SIGNALING BY NOTCH1 HD+PEST DOMAIN MUTANTS': {'pathway_count': 5},
#  'NEURAL CREST DIFFERENTIATION': {'pathway_count': 5},
#  'REGULATION OF KIT SIGNALING': {'pathway_count': 5},
#  'PPARA ACTIVATES GENE EXPRESSION': {'pathway_count': 5},
#  'REGULATION OF LIPID METABOLISM BY PEROXISOME PROLIFERATOR-ACTIVATED RECEPTOR ALPHA (PPARALPHA)': {'pathway_count': 5},
#  'ISG15 ANTIVIRAL MECHANISM': {'pathway_count': 5},
#  'ANTIVIRAL MECHANISM BY IFN-STIMULATED GENES': {'pathway_count': 5},
#  'R-HSA-9679191': {'pathway_count': 4},
#  'METABOLISM OF ANGIOTENSINOGEN TO ANGIOTENSINS': {'pathway_count': 4},
#  'ACE INHIBITOR PATHWAY': {'pathway_count': 4},
#  'HIV LIFE CYCLE': {'pathway_count': 4},
#  'HOST INTERACTIONS OF HIV FACTORS': {'pathway_count': 4},
#  'PD-1 SIGNALING': {'pathway_count': 4},
#  'TRANSCRIPTIONAL ACTIVATION OF MITOCHONDRIAL BIOGENESIS': {'pathway_count': 4},
#  'SOMATROPH AXIS (GH) AND ITS RELATIONSHIP TO DIETARY RESTRICTION AND AGING': {'pathway_count': 4},
#  'R-HSA-9635486': {'pathway_count': 4},
#  'R-HSA-9664407': {'pathway_count': 4},
#  'R-HSA-9664417': {'pathway_count': 4},
#  'R-HSA-9664422': {'pathway_count': 4},
#  'OPIOID SIGNALLING': {'pathway_count': 4},
#  'NEUROTRANSMITTER RECEPTORS AND POSTSYNAPTIC SIGNAL TRANSMISSION': {'pathway_count': 4},
#  'SPRY REGULATION OF FGF SIGNALING': {'pathway_count': 4},
#  'SIGNALLING TO ERKS': {'pathway_count': 4},
#  'FCERI MEDIATED MAPK ACTIVATION': {'pathway_count': 4},
#  'SIGNAL TRANSDUCTION BY L1': {'pathway_count': 4},
#  'ACTIVATION OF THE AP-1 FAMILY OF TRANSCRIPTION FACTORS': {'pathway_count': 4},
#  'NEGATIVE REGULATION OF FGFR2 SIGNALING': {'pathway_count': 4},
#  'NEGATIVE REGULATION OF FGFR3 SIGNALING': {'pathway_count': 4},
#  'NEGATIVE REGULATION OF FGFR4 SIGNALING': {'pathway_count': 4},
#  'ONCOGENIC MAPK SIGNALING': {'pathway_count': 4},
#  'TYPE II DIABETES MELLITUS': {'pathway_count': 4},
#  'BDNF-TRKB SIGNALING': {'pathway_count': 4},
#  'ERK PATHWAY IN HUNTINGTON,S DISEASE': {'pathway_count': 4},
#  'SEROTONIN RECEPTOR 4-6-7 AND NR3C SIGNALING': {'pathway_count': 4},
#  'R-HSA-9660826': {'pathway_count': 4},
#  'R-HSA-9664424': {'pathway_count': 4},
#  'ECM PROTEOGLYCANS': {'pathway_count': 4},
#  'ECTODERM DIFFERENTIATION': {'pathway_count': 4},
#  'INTERLEUKIN-2 SIGNALING': {'pathway_count': 4},
#  'GENE AND PROTEIN EXPRESSION BY JAK-STAT SIGNALING AFTER INTERLEUKIN-12 STIMULATION': {'pathway_count': 4},
#  'INTERLEUKIN-12 SIGNALING': {'pathway_count': 4},
#  'NETRIN-1 SIGNALING': {'pathway_count': 4},
#  'ACTIVATED TAK1 MEDIATES P38 MAPK ACTIVATION': {'pathway_count': 4},
#  'OXIDATIVE STRESS': {'pathway_count': 4},
#  'MONOAMINE TRANSPORT': {'pathway_count': 4},
#  'AMYLOID FIBER FORMATION': {'pathway_count': 4},
#  'MATRIX METALLOPROTEINASES': {'pathway_count': 4},
#  'ROLE ALTERED GLYCOLYSATION OF MUC1 IN TUMOUR MICROENVIRONMENT': {'pathway_count': 4},
#  'TRAF6 MEDIATED IRF7 ACTIVATION': {'pathway_count': 4},
#  'ACTIVATION OF BH3-ONLY PROTEINS': {'pathway_count': 4},
#  'PRE-NOTCH TRANSCRIPTION AND TRANSLATION': {'pathway_count': 4},
#  'PRE-NOTCH EXPRESSION AND PROCESSING': {'pathway_count': 4},
#  'DNA DAMAGE/TELOMERE STRESS INDUCED SENESCENCE': {'pathway_count': 4},
#  'MITOTIC G2-G2/M PHASES': {'pathway_count': 4},
#  'TP53 REGULATES TRANSCRIPTION OF CELL CYCLE GENES': {'pathway_count': 4},
#  'TP53 REGULATES TRANSCRIPTION OF DNA REPAIR GENES': {'pathway_count': 4},
#  'TP53 REGULATES TRANSCRIPTION OF GENES INVOLVED IN CYTOCHROME C RELEASE': {'pathway_count': 4},
#  'REGULATION OF TP53 ACTIVITY THROUGH METHYLATION': {'pathway_count': 4},
#  'G2/M TRANSITION': {'pathway_count': 4},
#  'RUNX3 REGULATES CDKN1A TRANSCRIPTION': {'pathway_count': 4},
#  'GASTRIC CANCER NETWORK 2': {'pathway_count': 4},
#  'ATM SIGNALING PATHWAY': {'pathway_count': 4},
#  'FERROPTOSIS': {'pathway_count': 4},
#  'REGULATION OF GENE EXPRESSION BY HYPOXIA-INDUCIBLE FACTOR': {'pathway_count': 4},
#  'TFAP2 (AP-2) FAMILY REGULATES TRANSCRIPTION OF GROWTH FACTORS AND THEIR RECEPTORS': {'pathway_count': 4},
#  'AMPLIFICATION AND EXPANSION OF ONCOGENIC PATHWAYS AS METASTATIC TRAITS': {'pathway_count': 4},
#  'REGULATION OF BETA-CELL DEVELOPMENT': {'pathway_count': 4},
#  'INTEGRIN ALPHAIIB BETA3 SIGNALING': {'pathway_count': 4},
#  'DEACTIVATION OF THE BETA-CATENIN TRANSACTIVATING COMPLEX': {'pathway_count': 4},
#  'PLATELET AGGREGATION (PLUG FORMATION)': {'pathway_count': 4},
#  'DOWNREGULATION OF ERBB2 SIGNALING': {'pathway_count': 4},
#  'REGULATION OF APOPTOSIS BY PARATHYROID HORMONE-RELATED PROTEIN': {'pathway_count': 4},
#  'STEATOSIS AOP': {'pathway_count': 4},
#  'R-HSA-1227990': {'pathway_count': 4},
#  'R-HSA-9664565': {'pathway_count': 4},
#  'R-HSA-9665348': {'pathway_count': 4},
#  'PI3K EVENTS IN ERBB2 SIGNALING': {'pathway_count': 4},
#  'R-HSA-9660821': {'pathway_count': 4},
#  'TLR4 SIGNALING AND TOLERANCE': {'pathway_count': 4},
#  'TGF-BETA RECEPTOR SIGNALING ACTIVATES SMADS': {'pathway_count': 4},
#  'REGULATION OF RUNX3 EXPRESSION AND ACTIVITY': {'pathway_count': 4},
#  'NRF2 PATHWAY': {'pathway_count': 4},
#  'CASPASE ACTIVATION VIA DEATH RECEPTORS IN THE PRESENCE OF LIGAND': {'pathway_count': 4},
#  'CASPASE ACTIVATION VIA EXTRINSIC APOPTOTIC SIGNALLING PATHWAY': {'pathway_count': 4},
#  'SIMPLIFIED DEPICTION OF MYD88 DISTINCT INPUT-OUTPUT PATHWAY': {'pathway_count': 4},
#  'ACTIVATION OF MATRIX METALLOPROTEINASES': {'pathway_count': 4},
#  'EPH-EPHRIN SIGNALING': {'pathway_count': 4},
#  'INTERLEUKIN-7 SIGNALING': {'pathway_count': 4},
#  'INTERLEUKIN-9 SIGNALING': {'pathway_count': 4},
#  'INTERLEUKIN-37 SIGNALING': {'pathway_count': 4},
#  'R-HSA-9664323': {'pathway_count': 4},
#  'JNK (C-JUN KINASES) PHOSPHORYLATION AND  ACTIVATION MEDIATED BY ACTIVATED HUMAN TAK1': {'pathway_count': 4},
#  'NLR PROTEINS': {'pathway_count': 4},
#  'METABOLISM OF STEROIDS': {'pathway_count': 4},
#  'RIPK1-MEDIATED REGULATED NECROSIS': {'pathway_count': 4},
#  'REGULATED NECROSIS': {'pathway_count': 4},
#  'REGULATION OF NECROPTOTIC CELL DEATH': {'pathway_count': 4},
#  'PI METABOLISM': {'pathway_count': 4},
#  'PHOSPHOLIPID METABOLISM': {'pathway_count': 4},
#  'SYNTHESIS OF PIPS AT THE PLASMA MEMBRANE': {'pathway_count': 4},
#  'ROLE OF PHOSPHOLIPIDS IN PHAGOCYTOSIS': {'pathway_count': 4},
#  'TIE2 SIGNALING': {'pathway_count': 4},
#  'NEPHRIN FAMILY INTERACTIONS': {'pathway_count': 4},
#  'DOWNSTREAM SIGNALING OF ACTIVATED FGFR1': {'pathway_count': 4},
#  'PI-3K CASCADE:FGFR1': {'pathway_count': 4},
#  'RET SIGNALING': {'pathway_count': 4},
#  'SIGNALING BY NTRK2 (TRKB)': {'pathway_count': 4},
#  'ERYTHROPOIETIN ACTIVATES PHOSPHOINOSITIDE-3-KINASE (PI3K)': {'pathway_count': 4},
#  'RIP-MEDIATED NFKB ACTIVATION VIA ZBP1': {'pathway_count': 4},
#  'P75NTR SIGNALS VIA NF-KB': {'pathway_count': 4},
#  'CHROMATIN MODIFYING ENZYMES': {'pathway_count': 4},
#  'CHROMATIN ORGANIZATION': {'pathway_count': 4},
#  'SUPRESSION OF HMGB1 MEDIATED INFLAMMATION BY THBD': {'pathway_count': 4},
#  'SIGNALING BY ROBO RECEPTORS': {'pathway_count': 4},
#  'PEPTIDE GPCRS': {'pathway_count': 4},
#  'HEMATOPOIETIC STEM CELL GENE REGULATION BY GABP ALPHA-BETA COMPLEX': {'pathway_count': 4},
#  'REGULATION OF RUNX2 EXPRESSION AND ACTIVITY': {'pathway_count': 4},
#  'NEDDYLATION': {'pathway_count': 4},
#  'ATM SIGNALING NETWORK IN DEVELOPMENT AND DISEASE': {'pathway_count': 4},
#  'SCF(SKP2)-MEDIATED DEGRADATION OF P27/P21': {'pathway_count': 4},
#  'LIVER STEATOSIS AOP': {'pathway_count': 4},
#  'FORMATION OF THE BETA-CATENIN:TCF TRANSACTIVATING COMPLEX': {'pathway_count': 4},
#  'DEGRADATION OF BETA-CATENIN BY THE DESTRUCTION COMPLEX': {'pathway_count': 4},
#  'BETA-CATENIN INDEPENDENT WNT SIGNALING': {'pathway_count': 4},
#  'PARKIN-UBIQUITIN PROTEASOMAL SYSTEM PATHWAY': {'pathway_count': 4},
#  'TICAM1, RIP1-MEDIATED IKK COMPLEX RECRUITMENT ': {'pathway_count': 4},
#  'OVARIAN INFERTILITY GENES': {'pathway_count': 4},
#  'HOMOLOGY DIRECTED REPAIR': {'pathway_count': 4},
#  'HDR THROUGH HOMOLOGOUS RECOMBINATION (HRR) OR SINGLE STRAND ANNEALING (SSA)': {'pathway_count': 4},
#  'PROCESSING OF DNA DOUBLE-STRAND BREAK ENDS': {'pathway_count': 4},
#  'LISTERIA MONOCYTOGENES ENTRY INTO HOST CELLS': {'pathway_count': 4},
#  'IRON UPTAKE AND TRANSPORT': {'pathway_count': 4},
#  'R-HSA-9678108': {'pathway_count': 3},
#  'DISORDERS OF TRANSMEMBRANE TRANSPORTERS': {'pathway_count': 3},
#  'CHAPERONE MEDIATED AUTOPHAGY': {'pathway_count': 3},
#  'MICROAUTOPHAGY': {'pathway_count': 3},
#  'DEFENSINS': {'pathway_count': 3},
#  'EARLY PHASE OF HIV LIFE CYCLE': {'pathway_count': 3},
#  'THE ROLE OF NEF IN HIV-1 REPLICATION AND DISEASE PATHOGENESIS': {'pathway_count': 3},
#  'BINDING AND ENTRY OF HIV VIRION': {'pathway_count': 3},
#  'PHOSPHORYLATION OF CD3 AND TCR ZETA CHAINS': {'pathway_count': 3},
#  'NAD+ METABOLISM': {'pathway_count': 3},
#  'NAD+ BIOSYNTHETIC PATHWAYS': {'pathway_count': 3},
#  'SREBF AND MIR33 IN CHOLESTEROL AND LIPID HOMEOSTASIS': {'pathway_count': 3},
#  'NAD METABOLISM, SIRTUINS AND AGING': {'pathway_count': 3},
#  'R-HSA-9637690': {'pathway_count': 3},
#  'R-HSA-9649948': {'pathway_count': 3},
#  'APOPTOTIC FACTOR-MEDIATED RESPONSE': {'pathway_count': 3},
#  'CA-DEPENDENT EVENTS': {'pathway_count': 3},
#  'G-PROTEIN MEDIATED EVENTS': {'pathway_count': 3},
#  'PLC BETA MEDIATED EVENTS': {'pathway_count': 3},
#  'RAF-INDEPENDENT MAPK1/3 ACTIVATION': {'pathway_count': 3},
#  'MAPK1 (ERK2) ACTIVATION': {'pathway_count': 3},
#  'PROLONGED ERK ACTIVATION EVENTS': {'pathway_count': 3},
#  'REGULATION OF ACTIN DYNAMICS FOR PHAGOCYTIC CUP FORMATION': {'pathway_count': 3},
#  'POST NMDA RECEPTOR ACTIVATION EVENTS': {'pathway_count': 3},
#  'ACTIVATION OF NMDA RECEPTORS AND POSTSYNAPTIC EVENTS': {'pathway_count': 3},
#  'RHO GTPASES ACTIVATE NADPH OXIDASES': {'pathway_count': 3},
#  'SIGNALING BY MODERATE KINASE ACTIVITY BRAF MUTANTS': {'pathway_count': 3},
#  'SIGNALING BY RAS MUTANTS': {'pathway_count': 3},
#  'SIGNALING BY BRAF AND RAF FUSIONS': {'pathway_count': 3},
#  'PARADOXICAL ACTIVATION OF RAF SIGNALING BY KINASE INACTIVE BRAF': {'pathway_count': 3},
#  'M PHASE': {'pathway_count': 3},
#  'ADVANCED GLYCOSYLATION ENDPRODUCT RECEPTOR SIGNALING': {'pathway_count': 3},
#  'GASTRIN-CREB SIGNALLING PATHWAY VIA PKC AND MAPK': {'pathway_count': 3},
#  'OSTEOPONTIN SIGNALING': {'pathway_count': 3},
#  'TCA CYCLE NUTRIENT UTILIZATION AND INVASIVENESS OF OVARIAN CANCER': {'pathway_count': 3},
#  'TGF-B SIGNALING IN THYROID CELLS FOR EPITHELIAL-MESENCHYMAL TRANSITION': {'pathway_count': 3},
#  '4-HYDROXYTAMOXIFEN, DEXAMETHASONE, AND RETINOIC ACIDS REGULATION OF P27 EXPRESSION': {'pathway_count': 3},
#  'INFLAMMASOMES': {'pathway_count': 3},
#  'BLOOD CLOTTING CASCADE': {'pathway_count': 3},
#  'NOTCH1 REGULATION OF HUMAN ENDOTHELIAL CELL CALCIFICATION': {'pathway_count': 3},
#  'DENGUE-2 INTERACTIONS WITH BLOOD CLOTTING CASCADE': {'pathway_count': 3},
#  'BMAL1:CLOCK,NPAS2 ACTIVATES CIRCADIAN GENE EXPRESSION': {'pathway_count': 3},
#  'PERK REGULATES GENE EXPRESSION': {'pathway_count': 3},
#  'UNFOLDED PROTEIN RESPONSE (UPR)': {'pathway_count': 3},
#  'ASPARAGINE N-LINKED GLYCOSYLATION': {'pathway_count': 3},
#  'PROTEASOME DEGRADATION': {'pathway_count': 3},
#  'R-HSA-9662834': {'pathway_count': 3},
#  'PLATELET HOMEOSTASIS': {'pathway_count': 3},
#  'PLATELET SENSITIZATION BY LDL': {'pathway_count': 3},
#  'PHOTODYNAMIC THERAPY-INDUCED NFE2L2 (NRF2) SURVIVAL SIGNALING': {'pathway_count': 3},
#  'METABOLISM OF VITAMINS AND COFACTORS': {'pathway_count': 3},
#  'SUMOYLATION OF TRANSCRIPTION FACTORS': {'pathway_count': 3},
#  'AUTODEGRADATION OF THE E3 UBIQUITIN LIGASE COP1': {'pathway_count': 3},
#  'TP53 REGULATES TRANSCRIPTION OF DEATH RECEPTORS AND LIGANDS': {'pathway_count': 3},
#  'TP53 REGULATES TRANSCRIPTION OF GENES INVOLVED IN G1 CELL CYCLE ARREST': {'pathway_count': 3},
#  'REGULATION OF TP53 ACTIVITY THROUGH ACETYLATION': {'pathway_count': 3},
#  'G2/M DNA DAMAGE CHECKPOINT': {'pathway_count': 3},
#  'THE ROLE OF GTSE1 IN G2/M PROGRESSION AFTER G2 CHECKPOINT': {'pathway_count': 3},
#  'LNCRNA-MEDIATED MECHANISMS OF THERAPEUTIC RESISTANCE': {'pathway_count': 3},
#  'HEREDITARY LEIOMYOMATOSIS AND RENAL CELL CARCINOMA PATHWAY': {'pathway_count': 3},
#  'QUERCETIN AND NF-KB- AP-1 INDUCED CELL APOPTOSIS': {'pathway_count': 3},
#  'AKT PHOSPHORYLATES TARGETS IN THE CYTOSOL': {'pathway_count': 3},
#  'VEGFR2 MEDIATED VASCULAR PERMEABILITY': {'pathway_count': 3},
#  'PTK6 REGULATES RTKS AND THEIR EFFECTORS AKT1 AND DOK1': {'pathway_count': 3},
#  'REGULATION OF PTEN STABILITY AND ACTIVITY': {'pathway_count': 3},
#  'TFS REGULATE MIRNAS RELATED TO CARDIAC HYPERTROPHY': {'pathway_count': 3},
#  'ERBB2 REGULATES CELL MOTILITY': {'pathway_count': 3},
#  'NOTCH3 ACTIVATION AND TRANSMISSION OF SIGNAL TO THE NUCLEUS': {'pathway_count': 3},
#  'NCRNAS INVOLVED IN STAT3 SIGNALING IN HEPATOCELLULAR CARCINOMA': {'pathway_count': 3},
#  'INFLUENZA LIFE CYCLE': {'pathway_count': 3},
#  'DOWNREGULATION OF TGF-BETA RECEPTOR SIGNALING': {'pathway_count': 3},
#  'TGF-BETA RECEPTOR SIGNALING IN EMT (EPITHELIAL TO MESENCHYMAL TRANSITION)': {'pathway_count': 3},
#  'DOPAMINERGIC NEUROGENESIS': {'pathway_count': 3},
#  'SYNTHESIS, SECRETION, AND DEACYLATION OF GHRELIN': {'pathway_count': 3},
#  'PROTEIN LOCALIZATION': {'pathway_count': 3},
#  'TRAF6-MEDIATED INDUCTION OF TAK1 COMPLEX WITHIN TLR4 COMPLEX': {'pathway_count': 3},
#  'IRAK2 MEDIATED ACTIVATION OF TAK1 COMPLEX UPON TLR7/8 OR 9 STIMULATION': {'pathway_count': 3},
#  'APOE AND MIR-146 IN INFLAMMATION AND ATHEROSCLEROSIS': {'pathway_count': 3},
#  'COLLAGEN DEGRADATION': {'pathway_count': 3},
#  'COLLAGEN FORMATION': {'pathway_count': 3},
#  'EPH-EPHRIN MEDIATED REPULSION OF CELLS': {'pathway_count': 3},
#  'INTERLEUKIN-21 SIGNALING': {'pathway_count': 3},
#  'ESTROGEN RECEPTOR PATHWAY': {'pathway_count': 3},
#  'CELL DEATH SIGNALLING VIA NRAGE, NRIF AND NADE': {'pathway_count': 3},
#  'NRIF SIGNALS CELL DEATH FROM THE NUCLEUS': {'pathway_count': 3},
#  'WNT SIGNALING IN KIDNEY DISEASE': {'pathway_count': 3},
#  'AOP CYP2E1 ACTIVATION LEADING TO NEURODEGENERATION': {'pathway_count': 3},
#  'NRF2-ARE REGULATION': {'pathway_count': 3},
#  'G ALPHA (S) SIGNALLING EVENTS': {'pathway_count': 3},
#  'DISEASES OF METABOLISM': {'pathway_count': 3},
#  'NANOMATERIAL INDUCED APOPTOSIS': {'pathway_count': 3},
#  'PI-3K CASCADE:FGFR2': {'pathway_count': 3},
#  'DOWNSTREAM SIGNALING OF ACTIVATED FGFR2': {'pathway_count': 3},
#  'DOWNSTREAM SIGNALING OF ACTIVATED FGFR3': {'pathway_count': 3},
#  'PI-3K CASCADE:FGFR3': {'pathway_count': 3},
#  'DOWNSTREAM SIGNALING OF ACTIVATED FGFR4': {'pathway_count': 3},
#  'PI-3K CASCADE:FGFR4': {'pathway_count': 3},
#  'SIGNALING BY NTRK3 (TRKC)': {'pathway_count': 3},
#  'G13 SIGNALING PATHWAY': {'pathway_count': 3},
#  'DOWNSTREAM SIGNALING EVENTS OF B CELL RECEPTOR (BCR)': {'pathway_count': 3},
#  'ACTIVATION OF NF-KAPPAB IN B CELLS': {'pathway_count': 3},
#  'NF-KB IS ACTIVATED AND SIGNALS SURVIVAL': {'pathway_count': 3},
#  'FCERI MEDIATED NF-KB ACTIVATION': {'pathway_count': 3},
#  'CD209 (DC-SIGN) SIGNALING': {'pathway_count': 3},
#  'INITIATION OF TRANSCRIPTION AND TRANSLATION ELONGATION AT THE HIV-1 LTR': {'pathway_count': 3},
#  'R-HSA-9031628': {'pathway_count': 3},
#  'HSP90 CHAPERONE CYCLE FOR STEROID HORMONE RECEPTORS (SHR)': {'pathway_count': 3},
#  'RHO GTPASES ACTIVATE PKNS': {'pathway_count': 3},
#  'METABOLISM OF CARBOHYDRATES': {'pathway_count': 3},
#  'HSF1-DEPENDENT TRANSACTIVATION': {'pathway_count': 3},
#  'R-HSA-9659787': {'pathway_count': 3},
#  'R-HSA-9661069': {'pathway_count': 3},
#  'R-HSA-9675126': {'pathway_count': 3},
#  'R-HSA-9687139': {'pathway_count': 3},
#  'P75NTR RECRUITS SIGNALLING COMPLEXES': {'pathway_count': 3},
#  'TRAF6 MEDIATED IRF7 ACTIVATION IN TLR7/8 OR 9 SIGNALING': {'pathway_count': 3},
#  'G0 AND EARLY G1': {'pathway_count': 3},
#  'MAPK6/MAPK4 SIGNALING': {'pathway_count': 3},
#  'RUNX3 REGULATES WNT SIGNALING': {'pathway_count': 3},
#  'PPAR ALPHA PATHWAY': {'pathway_count': 3},
#  'IMATINIB AND CHRONIC MYELOID LEUKEMIA': {'pathway_count': 3},
#  'LNCRNA INVOLVEMENT IN CANONICAL WNT SIGNALING AND COLORECTAL CANCER': {'pathway_count': 3},
#  'NCRNAS INVOLVED IN WNT SIGNALING IN HEPATOCELLULAR CARCINOMA': {'pathway_count': 3},
#  'PROLACTIN RECEPTOR SIGNALING': {'pathway_count': 3},
#  'PECAM1 INTERACTIONS': {'pathway_count': 3},
#  'METABOLISM OF AMINO ACIDS AND DERIVATIVES': {'pathway_count': 3},
#  'TICAM1-DEPENDENT ACTIVATION OF IRF3/IRF7': {'pathway_count': 3},
#  'MECP2 REGULATES TRANSCRIPTION OF NEURONAL LIGANDS': {'pathway_count': 3},
#  'R-HSA-9664873': {'pathway_count': 3},
#  'REPRODUCTION': {'pathway_count': 3},
#  'MEIOSIS': {'pathway_count': 3},
#  'HDR THROUGH HOMOLOGOUS RECOMBINATION (HRR)': {'pathway_count': 3},
#  'MEIOTIC RECOMBINATION': {'pathway_count': 3},
#  'HEDGEHOG SIGNALING PATHWAY': {'pathway_count': 3},
#  'LRR FLII-INTERACTING PROTEIN 1 (LRRFIP1) ACTIVATES TYPE I IFN PRODUCTION': {'pathway_count': 3},
#  'NOTCH-HLH TRANSCRIPTION PATHWAY': {'pathway_count': 3},
#  'NOTCH3 INTRACELLULAR DOMAIN REGULATES TRANSCRIPTION': {'pathway_count': 3},
#  'NOTCH4 INTRACELLULAR DOMAIN REGULATES TRANSCRIPTION': {'pathway_count': 3},
#  'TRAF3-DEPENDENT IRF ACTIVATION PATHWAY': {'pathway_count': 3},
#  'NOTCH SIGNALING': {'pathway_count': 3},
#  'CILIARY LANDSCAPE': {'pathway_count': 3},
#  'APOPTOTIC EXECUTION PHASE': {'pathway_count': 3},
#  'CD28 DEPENDENT VAV1 PATHWAY': {'pathway_count': 3},
#  'TRANS-GOLGI NETWORK VESICLE BUDDING': {'pathway_count': 3},
#  'NEGATIVE REGULATION OF MET ACTIVITY': {'pathway_count': 3},
#  'INLB-MEDIATED ENTRY OF LISTERIA MONOCYTOGENES INTO HOST CELL': {'pathway_count': 3},
#  'SEMAPHORIN INTERACTIONS': {'pathway_count': 3},
#  'PPAR SIGNALING PATHWAY': {'pathway_count': 3},
#  'MESODERMAL COMMITMENT PATHWAY': {'pathway_count': 3},
#  'RHO GTPASE CYCLE': {'pathway_count': 3},
#  'INTERFERON ALPHA-BETA SIGNALING': {'pathway_count': 3},
#  'NEGATIVE REGULATORS OF DDX58/IFIH1 SIGNALING': {'pathway_count': 3},
#  'AUF1 (HNRNP D0) BINDS AND DESTABILIZES MRNA': {'pathway_count': 3},
#  'DOWNREGULATION OF SMAD2/3:SMAD4 TRANSCRIPTIONAL ACTIVITY': {'pathway_count': 3},
#  'INITIAL TRIGGERING OF COMPLEMENT': {'pathway_count': 2},
#  'R-HSA-9678110': {'pathway_count': 2},
#  'R-HSA-9646399': {'pathway_count': 2},
#  'ABC-FAMILY PROTEINS MEDIATED TRANSPORT': {'pathway_count': 2},
#  'ABC TRANSPORTER DISORDERS': {'pathway_count': 2},
#  'DEFECTIVE CFTR CAUSES CYSTIC FIBROSIS': {'pathway_count': 2},
#  'NEF-MEDIATES DOWN MODULATION OF CELL SURFACE RECEPTORS BY RECRUITING THEM TO CLATHRIN ADAPTERS': {'pathway_count': 2},
#  'VPU MEDIATED DEGRADATION OF CD4': {'pathway_count': 2},
#  'TRANSLOCATION OF ZAP-70 TO IMMUNOLOGICAL SYNAPSE': {'pathway_count': 2},
#  'GENERATION OF SECOND MESSENGER MOLECULES': {'pathway_count': 2},
#  'OTHER INTERLEUKIN SIGNALING': {'pathway_count': 2},
#  'EPIGENETIC REGULATION OF GENE EXPRESSION': {'pathway_count': 2},
#  'NEGATIVE EPIGENETIC REGULATION OF RRNA EXPRESSION': {'pathway_count': 2},
#  'REGULATION OF FOXO TRANSCRIPTIONAL ACTIVITY BY ACETYLATION': {'pathway_count': 2},
#  'SIMPLIFIED INTERACTION MAP BETWEEN LOXL4 AND OXIDATIVE STRESS PATHWAY': {'pathway_count': 2},
#  'R-HSA-9656223': {'pathway_count': 2},
#  'FRS2-MEDIATED ACTIVATION': {'pathway_count': 2},
#  'ERK/MAPK TARGETS': {'pathway_count': 2},
#  'CREB1 PHOSPHORYLATION THROUGH NMDA RECEPTOR-MEDIATED ACTIVATION OF RAS SIGNALING': {'pathway_count': 2},
#  'MAP2K AND MAPK ACTIVATION': {'pathway_count': 2},
#  'NEGATIVE REGULATION OF MAPK PATHWAY': {'pathway_count': 2},
#  'SIGNALING BY HIGH-KINASE ACTIVITY BRAF MUTANTS': {'pathway_count': 2},
#  'SIGNAL ATTENUATION': {'pathway_count': 2},
#  'RUNX2 REGULATES OSTEOBLAST DIFFERENTIATION': {'pathway_count': 2},
#  'RUNX2 REGULATES BONE DEVELOPMENT': {'pathway_count': 2},
#  'NIFEDIPINE ACTIVITY': {'pathway_count': 2},
#  'SIGNAL TRANSDUCTION OF S1P RECEPTOR': {'pathway_count': 2},
#  'COMMON PATHWAYS UNDERLYING DRUG ADDICTION': {'pathway_count': 2},
#  'MFAP5-MEDIATED OVARIAN CANCER CELL MOTILITY AND INVASIVENESS': {'pathway_count': 2},
#  'MAPK AND NFKB SIGNALLING PATHWAYS INHIBITED BY YERSINIA YOPJ': {'pathway_count': 2},
#  'MAPK CASCADE': {'pathway_count': 2},
#  'INHIBITION OF EXOSOME BIOGENESIS AND SECRETION BY MANUMYCIN A IN CRPC CELLS': {'pathway_count': 2},
#  'VITAMIN A AND CAROTENOID METABOLISM': {'pathway_count': 2},
#  'ION CHANNEL TRANSPORT': {'pathway_count': 2},
#  'THE NLRP3 INFLAMMASOME': {'pathway_count': 2},
#  'DISSOLUTION OF FIBRIN CLOT': {'pathway_count': 2},
#  'TRANSCRIPTIONAL ACTIVITY OF SMAD2-SMAD3-SMAD4 HETEROTRIMER': {'pathway_count': 2},
#  'BMAL1-CLOCK,NPAS2 ACTIVATES CIRCADIAN GENE EXPRESSION': {'pathway_count': 2},
#  'ACTIVATION OF C3 AND C5': {'pathway_count': 2},
#  'COMPLEMENT ACTIVATION': {'pathway_count': 2},
#  'ATF4 ACTIVATES GENES IN RESPONSE TO ENDOPLASMIC RETICULUM  STRESS': {'pathway_count': 2},
#  'ATF4 ACTIVATES GENES': {'pathway_count': 2},
#  'ER TO GOLGI ANTEROGRADE TRANSPORT': {'pathway_count': 2},
#  'MHC CLASS II ANTIGEN PRESENTATION': {'pathway_count': 2},
#  'TRANSPORT TO THE GOLGI AND SUBSEQUENT MODIFICATION': {'pathway_count': 2},
#  'HYPERTROPHY MODEL': {'pathway_count': 2},
#  'SIGNALLING TO RAS': {'pathway_count': 2},
#  'DSCAM INTERACTIONS': {'pathway_count': 2},
#  'KSRP (KHSRP) BINDS AND DESTABILIZES MRNA': {'pathway_count': 2},
#  'MYOGENESIS': {'pathway_count': 2},
#  'PARKINSONS DISEASE PATHWAY': {'pathway_count': 2},
#  'INTERLEUKIN-18 SIGNALING': {'pathway_count': 2},
#  'VISUAL PHOTOTRANSDUCTION': {'pathway_count': 2},
#  'THE CANONICAL RETINOID CYCLE IN RODS (TWILIGHT VISION)': {'pathway_count': 2},
#  'NON-INTEGRIN MEMBRANE-ECM INTERACTIONS': {'pathway_count': 2},
#  'METABOLISM OF NUCLEOTIDES': {'pathway_count': 2},
#  'MITOTIC METAPHASE AND ANAPHASE': {'pathway_count': 2},
#  'MITOTIC ANAPHASE': {'pathway_count': 2},
#  'TNFR1-INDUCED PROAPOPTOTIC SIGNALING': {'pathway_count': 2},
#  'TNFR1-MEDIATED CERAMIDE PRODUCTION': {'pathway_count': 2},
#  'CHAPERONIN-MEDIATED PROTEIN FOLDING': {'pathway_count': 2},
#  'ASSOCIATION OF TRIC/CCT WITH TARGET PROTEINS DURING BIOSYNTHESIS': {'pathway_count': 2},
#  'PROTEIN FOLDING': {'pathway_count': 2},
#  'TP53 REGULATES TRANSCRIPTION OF CASPASE ACTIVATORS AND CASPASES': {'pathway_count': 2},
#  'TP53 REGULATES TRANSCRIPTION OF GENES INVOLVED IN G2 CELL CYCLE ARREST': {'pathway_count': 2},
#  'REGULATION OF TP53 ACTIVITY THROUGH ASSOCIATION WITH CO-FACTORS': {'pathway_count': 2},
#  'TRANSCRIPTIONAL ACTIVATION OF P53 RESPONSIVE GENES  ': {'pathway_count': 2},
#  'TRANSCRIPTIONAL  ACTIVATION OF  CELL CYCLE INHIBITOR P21 ': {'pathway_count': 2},
#  'METASTATIC BRAIN TUMOR': {'pathway_count': 2},
#  'THE EFFECT OF PROGERIN ON THE INVOLVED GENES IN HUTCHINSON-GILFORD PROGERIA SYNDROME': {'pathway_count': 2},
#  'MICRORNA NETWORK ASSOCIATED WITH CHRONIC LYMPHOCYTIC LEUKEMIA': {'pathway_count': 2},
#  'REGULATION OF HYPOXIA-INDUCIBLE FACTOR (HIF) BY OXYGEN': {'pathway_count': 2},
#  'MICRORNA FOR TARGETING CANCER GROWTH AND VASCULARIZATION IN GLIOBLASTOMA': {'pathway_count': 2},
#  'ACTIVATION OF BAD AND TRANSLOCATION TO MITOCHONDRIA ': {'pathway_count': 2},
#  'DOWNREGULATION OF ERBB2:ERBB3 SIGNALING': {'pathway_count': 2},
#  'MTOR SIGNALLING': {'pathway_count': 2},
#  'AKT PHOSPHORYLATES TARGETS IN THE NUCLEUS': {'pathway_count': 2},
#  'REGULATION OF GENE EXPRESSION IN BETA CELLS': {'pathway_count': 2},
#  'G BETA:GAMMA SIGNALLING THROUGH PI3KGAMMA': {'pathway_count': 2},
#  'G-PROTEIN BETA:GAMMA SIGNALLING': {'pathway_count': 2},
#  'NEGATIVE REGULATION OF NOTCH4 SIGNALING': {'pathway_count': 2},
#  'TARGET OF RAPAMYCIN (TOR) SIGNALING': {'pathway_count': 2},
#  'WNT-BETA-CATENIN SIGNALING PATHWAY IN LEUKEMIA': {'pathway_count': 2},
#  'R-HSA-9609646': {'pathway_count': 2},
#  'R-HSA-9609690': {'pathway_count': 2},
#  'R-HSA-9665686': {'pathway_count': 2},
#  'SHC1 EVENTS IN ERBB2 SIGNALING': {'pathway_count': 2},
#  'PLCG1 EVENTS IN ERBB2 SIGNALING': {'pathway_count': 2},
#  'GRB2 EVENTS IN EGFR SIGNALING': {'pathway_count': 2},
#  'SHC1 EVENTS IN EGFR SIGNALING': {'pathway_count': 2},
#  'GRB2 EVENTS IN ERBB2 SIGNALING': {'pathway_count': 2},
#  'EGFR INTERACTS WITH PHOSPHOLIPASE C-GAMMA': {'pathway_count': 2},
#  'SIGNALING BY OVEREXPRESSED WILD-TYPE EGFR IN CANCER': {'pathway_count': 2},
#  'INHIBITION OF SIGNALING BY OVEREXPRESSED EGFR': {'pathway_count': 2},
#  'ERBB2 ACTIVATES PTK6 SIGNALING': {'pathway_count': 2},
#  'PTK6 PROMOTES HIF1A STABILIZATION': {'pathway_count': 2},
#  'BMP SIGNALING PATHWAY IN EYELID DEVELOPMENT': {'pathway_count': 2},
#  'MAPK3 (ERK1) ACTIVATION': {'pathway_count': 2},
#  'ELASTIC FIBRE FORMATION': {'pathway_count': 2},
#  'LOSS OF FUNCTION OF SMAD2/3 IN CANCER': {'pathway_count': 2},
#  'SIGNALING BY TGF-BETA RECEPTOR COMPLEX IN CANCER': {'pathway_count': 2},
#  'SMAD2/3 PHOSPHORYLATION MOTIF MUTANTS IN CANCER': {'pathway_count': 2},
#  'TGFBR1 KD MUTANTS IN CANCER': {'pathway_count': 2},
#  'LOSS OF FUNCTION OF TGFBR1 IN CANCER': {'pathway_count': 2},
#  'UCH PROTEINASES': {'pathway_count': 2},
#  'RUNX3 REGULATES P14-ARF': {'pathway_count': 2},
#  'INTEGRATION OF ENERGY METABOLISM': {'pathway_count': 2},
#  'REGULATION OF INSULIN SECRETION': {'pathway_count': 2},
#  'CORI CYCLE': {'pathway_count': 2},
#  'DETOXIFICATION OF REACTIVE OXYGEN SPECIES': {'pathway_count': 2},
#  'PEROXISOMAL PROTEIN IMPORT': {'pathway_count': 2},
#  'TRYPTOPHAN METABOLISM': {'pathway_count': 2},
#  'TRIF-MEDIATED PROGRAMMED CELL DEATH': {'pathway_count': 2},
#  'NANOMATERIAL INDUCED INFLAMMASOME ACTIVATION': {'pathway_count': 2},
#  'ASSEMBLY OF COLLAGEN FIBRILS AND OTHER MULTIMERIC STRUCTURES': {'pathway_count': 2},
#  'BH3-ONLY PROTEINS ASSOCIATE WITH AND INACTIVATE ANTI-APOPTOTIC BCL-2 MEMBERS': {'pathway_count': 2},
#  'SIGNALLING TO STAT3': {'pathway_count': 2},
#  'PTK6 ACTIVATES STAT3': {'pathway_count': 2},
#  'INTERLEUKIN-15 SIGNALING': {'pathway_count': 2},
#  'INTERLEUKIN-35 SIGNALLING': {'pathway_count': 2},
#  'INTERLEUKIN-27 SIGNALING': {'pathway_count': 2},
#  'DEVELOPMENT OF PULMONARY DENDRITIC CELLS AND MACROPHAGE SUBSETS': {'pathway_count': 2},
#  'NANOPARTICLE TRIGGERED REGULATED NECROSIS': {'pathway_count': 2},
#  'PHYTOCHEMICAL ACTIVITY ON NRF2 TRANSCRIPTIONAL ACTIVATION': {'pathway_count': 2},
#  'SYNTHESIS, SECRETION, AND INACTIVATION OF GLUCAGON-LIKE PEPTIDE-1 (GLP-1)': {'pathway_count': 2},
#  'INCRETIN SYNTHESIS, SECRETION, AND INACTIVATION': {'pathway_count': 2},
#  'DIFFERENTIATION OF WHITE AND BROWN ADIPOCYTE': {'pathway_count': 2},
#  'BIOLOGICAL OXIDATIONS': {'pathway_count': 2},
#  'CYTOCHROME P450 - ARRANGED BY SUBSTRATE TYPE': {'pathway_count': 2},
#  'PHASE I - FUNCTIONALIZATION OF COMPOUNDS': {'pathway_count': 2},
#  'ENDOGENOUS STEROLS': {'pathway_count': 2},
#  'SEROTONIN AND ANXIETY': {'pathway_count': 2},
#  'REGULATION BY C-FLIP': {'pathway_count': 2},
#  'CASP8 ACTIVITY IS INHIBITED': {'pathway_count': 2},
#  'DIMERIZATION OF PROCASPASE-8': {'pathway_count': 2},
#  'APOPTOSIS MODULATION BY HSP70': {'pathway_count': 2},
#  'PI3K EVENTS IN ERBB4 SIGNALING': {'pathway_count': 2},
#  'SIGNALING BY FGFR2 IN DISEASE': {'pathway_count': 2},
#  'SIGNALING BY FGFR4 IN DISEASE': {'pathway_count': 2},
#  'SIGNALING BY FGFR3 IN DISEASE': {'pathway_count': 2},
#  'MET ACTIVATES PI3K/AKT SIGNALING': {'pathway_count': 2},
#  'SIGNALING BY FGFR3 FUSIONS IN CANCER': {'pathway_count': 2},
#  'SIGNALING BY FGFR3 POINT MUTANTS IN CANCER': {'pathway_count': 2},
#  'ACTIVATED NTRK2 SIGNALS THROUGH PI3K': {'pathway_count': 2},
#  'ACTIVATED NTRK3 SIGNALS THROUGH PI3K': {'pathway_count': 2},
#  'TNF RECEPTOR SUPERFAMILY (TNFSF) MEMBERS MEDIATING NON-CANONICAL NF-KB PATHWAY': {'pathway_count': 2},
#  'BINDING AND UPTAKE OF LIGANDS BY SCAVENGER RECEPTORS': {'pathway_count': 2},
#  'SLC-MEDIATED TRANSMEMBRANE TRANSPORT': {'pathway_count': 2},
#  'DEX/H-BOX HELICASES ACTIVATE TYPE I IFN AND INFLAMMATORY CYTOKINES PRODUCTION ': {'pathway_count': 2},
#  'INTERLEUKIN-1 PROCESSING': {'pathway_count': 2},
#  'SUMOYLATION OF IMMUNE RESPONSE PROTEINS': {'pathway_count': 2},
#  'IKBA VARIANT LEADS TO EDA-ID': {'pathway_count': 2},
#  'DECTIN-1 MEDIATED NONCANONICAL NF-KB SIGNALING': {'pathway_count': 2},
#  'CLEC7A/INFLAMMASOME PATHWAY': {'pathway_count': 2},
#  'SELENIUM METABOLISM AND SELENOPROTEINS': {'pathway_count': 2},
#  'REGULATION OF PTEN LOCALIZATION': {'pathway_count': 2},
#  'NUCLEAR SIGNALING BY ERBB4': {'pathway_count': 2},
#  'RUNX1 REGULATES TRANSCRIPTION OF GENES INVOLVED IN WNT SIGNALING': {'pathway_count': 2},
#  'ARMS-MEDIATED ACTIVATION': {'pathway_count': 2},
#  'P130CAS LINKAGE TO MAPK SIGNALING FOR INTEGRINS': {'pathway_count': 2},
#  'PTK6 REGULATES RHO GTPASES, RAS GTPASE AND MAP KINASES': {'pathway_count': 2},
#  'RETT SYNDROME CAUSING GENES': {'pathway_count': 2},
#  'GPCRS, OTHER': {'pathway_count': 2},
#  'ACTIVATED PKN1 STIMULATES TRANSCRIPTION OF AR (ANDROGEN RECEPTOR) REGULATED GENES KLK2 AND KLK3': {'pathway_count': 2},
#  'TFAP2 (AP-2) FAMILY REGULATES TRANSCRIPTION OF CELL CYCLE FACTORS': {'pathway_count': 2},
#  'FOXO-MEDIATED TRANSCRIPTION OF CELL CYCLE GENES': {'pathway_count': 2},
#  'INTEGRATED CANCER PATHWAY': {'pathway_count': 2},
#  'GENOTOXICITY PATHWAY': {'pathway_count': 2},
#  'DOPAMINE METABOLISM': {'pathway_count': 2},
#  'TRANSCRIPTION OF E2F TARGETS UNDER NEGATIVE CONTROL BY DREAM COMPLEX': {'pathway_count': 2},
#  'BINDING OF TCF/LEF:CTNNB1 TO TARGET GENE PROMOTERS': {'pathway_count': 2},
#  'LET-7 INHIBITION OF ES CELL REPROGRAMMING': {'pathway_count': 2},
#  'SIGNAL REGULATORY PROTEIN FAMILY INTERACTIONS': {'pathway_count': 2},
#  'FRS-MEDIATED FGFR1 SIGNALING': {'pathway_count': 2},
#  'REGULATION OF RUNX1 EXPRESSION AND ACTIVITY': {'pathway_count': 2},
#  'STAT5 ACTIVATION': {'pathway_count': 2},
#  'ERYTHROPOIETIN ACTIVATES STAT5': {'pathway_count': 2},
#  'AMINO ACID METABOLISM': {'pathway_count': 2},
#  'TRAFFICKING AND PROCESSING OF ENDOSOMAL TLR': {'pathway_count': 2},
#  'TICAM1,TRAF6-DEPENDENT INDUCTION OF TAK1 COMPLEX': {'pathway_count': 2},
#  'HDR THROUGH SINGLE STRAND ANNEALING (SSA)': {'pathway_count': 2},
#  'RESOLUTION OF D-LOOP STRUCTURES': {'pathway_count': 2},
#  'RESOLUTION OF D-LOOP STRUCTURES THROUGH SYNTHESIS-DEPENDENT STRAND ANNEALING (SDSA)': {'pathway_count': 2},
#  'RESOLUTION OF D-LOOP STRUCTURES THROUGH HOLLIDAY JUNCTION INTERMEDIATES': {'pathway_count': 2},
#  'NONHOMOLOGOUS END-JOINING (NHEJ)': {'pathway_count': 2},
#  'HOMOLOGOUS DNA PAIRING AND STRAND EXCHANGE': {'pathway_count': 2},
#  'PRESYNAPTIC PHASE OF HOMOLOGOUS DNA PAIRING AND STRAND EXCHANGE': {'pathway_count': 2},
#  'ADHERENS JUNCTIONS INTERACTIONS': {'pathway_count': 2},
#  'CELL-CELL JUNCTION ORGANIZATION': {'pathway_count': 2},
#  'CELL JUNCTION ORGANIZATION': {'pathway_count': 2},
#  'CALMODULIN INDUCED EVENTS': {'pathway_count': 2},
#  'CAM PATHWAY': {'pathway_count': 2},
#  'DAG AND IP3 SIGNALING': {'pathway_count': 2},
#  'SIGNALING BY HEDGEHOG': {'pathway_count': 2},
#  "HEDGEHOG 'ON' STATE": {'pathway_count': 2},
#  'CD22 MEDIATED BCR REGULATION': {'pathway_count': 2},
#  'SUMOYLATION OF DNA DAMAGE RESPONSE AND REPAIR PROTEINS': {'pathway_count': 2},
#  'RORA ACTIVATES GENE EXPRESSION': {'pathway_count': 2},
#  'REGULATION OF CHOLESTEROL BIOSYNTHESIS BY SREBP (SREBF)': {'pathway_count': 2},
#  'REGULATION OF GENE EXPRESSION IN LATE STAGE (BRANCHING MORPHOGENESIS) PANCREATIC BUD PRECURSOR CELLS': {'pathway_count': 2},
#  'ACTIVATION OF GENE EXPRESSION BY SREBF (SREBP)': {'pathway_count': 2},
#  'ATTENUATION PHASE': {'pathway_count': 2},
#  'RUNX1 REGULATES TRANSCRIPTION OF GENES INVOLVED IN DIFFERENTIATION OF MYELOID CELLS': {'pathway_count': 2},
#  'RUNX3 REGULATES NOTCH SIGNALING': {'pathway_count': 2},
#  'BETA DEFENSINS': {'pathway_count': 2},
#  'METALLOPROTEASE DUBS': {'pathway_count': 2},
#  'R-HSA-9636383': {'pathway_count': 2},
#  'R-HSA-9637687': {'pathway_count': 2},
#  'LYSOSOME VESICLE BIOGENESIS': {'pathway_count': 2},
#  'ENDOSOMAL SORTING COMPLEX REQUIRED FOR TRANSPORT (ESCRT)': {'pathway_count': 2},
#  'APOPTOTIC CLEAVAGE OF CELLULAR PROTEINS': {'pathway_count': 2},
#  'NUCLEAR RECEPTORS IN LIPID METABOLISM AND TOXICITY': {'pathway_count': 2},
#  'GASTRIC ULCER FORMATION': {'pathway_count': 2},
#  'PROSTAGLANDIN SYNTHESIS AND REGULATION': {'pathway_count': 2},
#  'UBIQUITIN-DEPENDENT DEGRADATION OF CYCLIN D': {'pathway_count': 2},
#  'PTK6 REGULATES CELL CYCLE': {'pathway_count': 2},
#  'H19 ACTION RB-E2F1 SIGNALING AND CDK-BETA-CATENIN ACTIVITY': {'pathway_count': 2},
#  'FCGR ACTIVATION': {'pathway_count': 2},
#  'DECTIN-2 FAMILY': {'pathway_count': 2},
#  'MECP2 REGULATES TRANSCRIPTION FACTORS': {'pathway_count': 2},
#  'HIF1A AND PPARG REGULATION OF GLYCOLYSIS': {'pathway_count': 2},
#  'EPHB-MEDIATED FORWARD SIGNALING': {'pathway_count': 2},
#  'EPHA-MEDIATED GROWTH CONE COLLAPSE': {'pathway_count': 2},
#  'PCP/CE PATHWAY': {'pathway_count': 2},
#  'RHO GTPASES ACTIVATE FORMINS': {'pathway_count': 2},
#  'OXYGEN-DEPENDENT PROLINE HYDROXYLATION OF HYPOXIA-INDUCIBLE FACTOR ALPHA': {'pathway_count': 2},
#  'PTK6 EXPRESSION': {'pathway_count': 2},
#  'THE HUMAN IMMUNE RESPONSE TO TUBERCULOSIS': {'pathway_count': 2},
#  'ANTIGEN PRESENTATION: FOLDING, ASSEMBLY AND PEPTIDE LOADING OF CLASS I MHC': {'pathway_count': 2},
#  'STING MEDIATED INDUCTION OF HOST IMMUNE RESPONSES': {'pathway_count': 2},
#  'REGULATION OF INNATE IMMUNE RESPONSES TO CYTOSOLIC DNA': {'pathway_count': 2},
#  'MITOPHAGY': {'pathway_count': 2},
#  'PINK/PARKIN MEDIATED MITOPHAGY': {'pathway_count': 2},
#  'SIGNALING BY NOTCH2': {'pathway_count': 2},
#  'REGULATION OF MECP2 EXPRESSION AND ACTIVITY': {'pathway_count': 2},
#  'MECP2 REGULATES NEURONAL RECEPTORS AND CHANNELS': {'pathway_count': 2},
#  'ANTIGEN PROCESSING: UBIQUITINATION & PROTEASOME DEGRADATION': {'pathway_count': 2},
#  'MIR-TARGETED GENES IN SQUAMOUS CELL - TARBASE': {'pathway_count': 2},
#  'INLA-MEDIATED ENTRY OF LISTERIA MONOCYTOGENES INTO HOST CELLS': {'pathway_count': 2},
#  'ROLE OF OSX AND MIRNAS IN TOOTH DEVELOPMENT': {'pathway_count': 2},
#  'PTF1A RELATED REGULATORY PATHWAY': {'pathway_count': 2},
#  'R-HSA-9637628': {'pathway_count': 2},
#  'CANNABINOID RECEPTOR SIGNALING': {'pathway_count': 2},
#  'GP1B-IX-V ACTIVATION SIGNALLING': {'pathway_count': 2},
#  'TRANSLESION SYNTHESIS BY Y FAMILY DNA POLYMERASES BYPASSES LESIONS ON DNA TEMPLATE': {'pathway_count': 2},
#  'TERMINATION OF TRANSLESION DNA SYNTHESIS': {'pathway_count': 2},
#  'DNA DAMAGE BYPASS': {'pathway_count': 2},
#  'NF-KB ACTIVATION THROUGH FADD/RIP-1 PATHWAY MEDIATED BY CASPASE-8 AND -10': {'pathway_count': 2},
#  ...}

# %%
gene_to_bioprocess = predict_many(relevant_gene_inputs, ['BiologicalProcess'])
gene_to_bioprocess_results = {}
gene_to_bioprocess_genes = list(gene_to_bioprocess["output_name"]) # create list of genes
gene_to_bioprocess_genes = list(dict.fromkeys(gene_to_bioprocess_genes))  # remove duplicates

for gene in gene_to_bioprocess_genes: 
    gene_to_bioprocess_results[gene] = {
        'bioprocess_count' : 0
    }

for index, row in gene_to_bioprocess.iterrows():
    gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] = gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] + 1

gene_to_bioprocess_results = dict(sorted(gene_to_bioprocess_results.items(), key = lambda x: x[1]['bioprocess_count'], reverse = True))

    
# gene_to_bioprocess_results
# Out:
# Running: C-reactive protein --> output type BiologicalProcess
# Running: transmembrane serine protease 2 --> output type BiologicalProcess
# Running: angiotensin I converting enzyme 2 --> output type BiologicalProcess
# Running: CF transmembrane conductance regulator --> output type BiologicalProcess
# Running: CD4 molecule --> output type BiologicalProcess
# Running: carboxypeptidase B2 --> output type BiologicalProcess
# Running: sirtuin 4 --> output type BiologicalProcess
# Running: apolipoprotein H --> output type BiologicalProcess
# Running: sirtuin 1 --> output type BiologicalProcess
# Running: growth arrest and DNA damage inducible beta --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 1 --> output type BiologicalProcess
# Running: oxytocin/neurophysin I prepropeptide --> output type BiologicalProcess
# Running: ATPase H+/K+ transporting non-gastric alpha2 subunit --> output type BiologicalProcess
# Running: MEFV innate immuity regulator, pyrin --> output type BiologicalProcess
# Running: plasminogen activator, tissue type --> output type BiologicalProcess
# Running: Fc fragment of IgG receptor and transporter --> output type BiologicalProcess
# Running: serpin family E member 1 --> output type BiologicalProcess
# Running: complement C5 --> output type BiologicalProcess
# Running: myeloperoxidase --> output type BiologicalProcess
# Running: colony stimulating factor 3 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 2 --> output type BiologicalProcess
# Running: interleukin 2 --> output type BiologicalProcess
# Running: cathepsin C --> output type BiologicalProcess
# Running: interferon gamma --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 14 --> output type BiologicalProcess
# Running: interleukin 4 --> output type BiologicalProcess
# Running: microtubule associated protein RP/EB family member 3 --> output type BiologicalProcess
# Running: troponin T2, cardiac type --> output type BiologicalProcess
# Running: transthyretin --> output type BiologicalProcess
# Running: galectin like --> output type BiologicalProcess
# Running: zinc finger CCCH-type containing, antiviral 1 --> output type BiologicalProcess
# Running: 5', 3'-nucleotidase, cytosolic --> output type BiologicalProcess
# Running: complement C3 --> output type BiologicalProcess
# Running: SH2 domain containing 3A --> output type BiologicalProcess
# Running: fibrinogen like 2 --> output type BiologicalProcess
# Running: sirtuin 2 --> output type BiologicalProcess
# Running: tumor necrosis factor --> output type BiologicalProcess
# Running: interferon alpha 1 --> output type BiologicalProcess
# Running: tumor protein p53 --> output type BiologicalProcess
# Running: vascular endothelial growth factor A --> output type BiologicalProcess
# Running: AKT serine/threonine kinase 1 --> output type BiologicalProcess
# Running: epidermal growth factor receptor --> output type BiologicalProcess
# Running: interleukin 6 --> output type BiologicalProcess
# Running: transforming growth factor beta 1 --> output type BiologicalProcess
# Running: insulin --> output type BiologicalProcess
# Running: catalase --> output type BiologicalProcess
# Running: toll like receptor 4 --> output type BiologicalProcess
# Running: matrix metallopeptidase 9 --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 3 --> output type BiologicalProcess
# Running: interleukin 10 --> output type BiologicalProcess
# Running: cathelicidin antimicrobial peptide --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 8 --> output type BiologicalProcess
# Running: leptin --> output type BiologicalProcess
# Running: proopiomelanocortin --> output type BiologicalProcess
# Running: Fas cell surface death receptor --> output type BiologicalProcess
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type BiologicalProcess
# Running: CD40 molecule --> output type BiologicalProcess
# Running: carbonic anhydrase 2 --> output type BiologicalProcess
# Running: albumin --> output type BiologicalProcess
# Running: RELA proto-oncogene, NF-kB subunit --> output type BiologicalProcess
# Running: C-X-C motif chemokine receptor 4 --> output type BiologicalProcess
# Running: phosphatase and tensin homolog --> output type BiologicalProcess
# Running: estrogen receptor 1 --> output type BiologicalProcess
# Running: CRK proto-oncogene, adaptor protein --> output type BiologicalProcess
# Running: cytokine inducible SH2 containing protein --> output type BiologicalProcess
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type BiologicalProcess
# Running: neurotrophic receptor tyrosine kinase 1 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 5 --> output type BiologicalProcess
# Running: C-C motif chemokine receptor 5 --> output type BiologicalProcess
# Running: integrin subunit alpha M --> output type BiologicalProcess
# Running: matrix metallopeptidase 2 --> output type BiologicalProcess
# Running: androgen receptor --> output type BiologicalProcess
# Running: CD44 molecule (Indian blood group) --> output type BiologicalProcess
# Running: mechanistic target of rapamycin kinase --> output type BiologicalProcess
# Running: cyclin dependent kinase inhibitor 1A --> output type BiologicalProcess
# Running: superoxide dismutase 1 --> output type BiologicalProcess
# Running: MYD88 innate immune signal transduction adaptor --> output type BiologicalProcess
# Running: MYC proto-oncogene, bHLH transcription factor --> output type BiologicalProcess
# Running: protein tyrosine phosphatase non-receptor type 11 --> output type BiologicalProcess
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type BiologicalProcess
# Running: complement C5a receptor 1 --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 5A --> output type BiologicalProcess
# Running: tyrosine hydroxylase --> output type BiologicalProcess
# Running: C-X-C motif chemokine ligand 8 --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 4 --> output type BiologicalProcess
# Running: angiotensin I converting enzyme --> output type BiologicalProcess
# Running: interleukin 2 receptor subunit alpha --> output type BiologicalProcess
# Running: TIMP metallopeptidase inhibitor 1 --> output type BiologicalProcess
# Running: CD14 molecule --> output type BiologicalProcess
# Running: toll like receptor 3 --> output type BiologicalProcess
# Running: somatostatin --> output type BiologicalProcess
# Running: estrogen receptor 2 --> output type BiologicalProcess
# Running: ATM serine/threonine kinase --> output type BiologicalProcess
# Running: parathyroid hormone --> output type BiologicalProcess
# Running: intercellular adhesion molecule 1 --> output type BiologicalProcess
# Running: angiogenin --> output type BiologicalProcess
# Running: G protein-coupled receptor kinase 2 --> output type BiologicalProcess
# Running: CD79a molecule --> output type BiologicalProcess
# Running: cyclin dependent kinase inhibitor 2A --> output type BiologicalProcess
# Running: renin --> output type BiologicalProcess
# Running: epidermal growth factor --> output type BiologicalProcess
# Running: CREB binding protein --> output type BiologicalProcess
# Running: interleukin 13 --> output type BiologicalProcess
# Running: C-C motif chemokine receptor 2 --> output type BiologicalProcess
# Running: BRCA1 DNA repair associated --> output type BiologicalProcess
# Running: high mobility group box 1 --> output type BiologicalProcess
# Running: TNF receptor superfamily member 1A --> output type BiologicalProcess
# Running: cytotoxic T-lymphocyte associated protein 4 --> output type BiologicalProcess
# Running: CD28 molecule --> output type BiologicalProcess
# Running: toll like receptor 7 --> output type BiologicalProcess
# Running: BCL2 associated X, apoptosis regulator --> output type BiologicalProcess
# Running: rhodopsin --> output type BiologicalProcess
# Running: hepatocyte growth factor-regulated tyrosine kinase substrate --> output type BiologicalProcess
# Running: lysyl oxidase --> output type BiologicalProcess
# Running: immunoglobulin heavy constant epsilon --> output type BiologicalProcess
# Running: microtubule associated protein tau --> output type BiologicalProcess
# Running: protein tyrosine phosphatase receptor type C --> output type BiologicalProcess
# Running: peroxisome proliferator activated receptor alpha --> output type BiologicalProcess
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit beta --> output type BiologicalProcess
# Running: prostaglandin-endoperoxide synthase 2 --> output type BiologicalProcess
# Running: cyclin D1 --> output type BiologicalProcess
# Running: spleen associated tyrosine kinase --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 9 --> output type BiologicalProcess
# Running: peptidylprolyl isomerase B --> output type BiologicalProcess
# Running: C-X-C motif chemokine ligand 10 --> output type BiologicalProcess
# Running: peroxisome proliferator activated receptor gamma --> output type BiologicalProcess
# Running: activator of HSP90 ATPase activity 1 --> output type BiologicalProcess
# Running: glucose-6-phosphate isomerase --> output type BiologicalProcess
# Running: ras homolog family member A --> output type BiologicalProcess
# Running: BCR activator of RhoGEF and GTPase --> output type BiologicalProcess
# Running: hypoxia inducible factor 1 subunit alpha --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 1 --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 5 --> output type BiologicalProcess
# Running: interferon stimulated exonuclease gene 20 --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 6 --> output type BiologicalProcess
# Running: interferon regulatory factor 3 --> output type BiologicalProcess
# Running: sequestosome 1 --> output type BiologicalProcess
# Running: ceruloplasmin --> output type BiologicalProcess
# Running: cAMP responsive element binding protein 1 --> output type BiologicalProcess
# Running: apurinic/apyrimidinic endodeoxyribonuclease 1 --> output type BiologicalProcess
# Running: suppressor of cytokine signaling 3 --> output type BiologicalProcess
# Running: interleukin 1 beta --> output type BiologicalProcess
# Running: erythropoietin --> output type BiologicalProcess
# Running: heat shock protein family B (small) member 1 --> output type BiologicalProcess
# Running: adenosine deaminase --> output type BiologicalProcess
# Running: transcription elongation factor A like 1 --> output type BiologicalProcess
# Running: major histocompatibility complex, class I, E --> output type BiologicalProcess
# Running: TNF receptor superfamily member 10b --> output type BiologicalProcess
# Running: vascular cell adhesion molecule 1 --> output type BiologicalProcess
# Running: early growth response 1 --> output type BiologicalProcess
# Running: colony stimulating factor 2 --> output type BiologicalProcess
# Running: CD34 molecule --> output type BiologicalProcess
# Running: catenin beta 1 --> output type BiologicalProcess
# Running: toll like receptor 2 --> output type BiologicalProcess
# Running: integrin subunit beta 2 --> output type BiologicalProcess
# Running: aryl hydrocarbon receptor --> output type BiologicalProcess
# Running: SMAD family member 3 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 3 --> output type BiologicalProcess
# Running: CD80 molecule --> output type BiologicalProcess
# Running: phosphoinositide-3-kinase regulatory subunit 1 --> output type BiologicalProcess
# Running: C-X3-C motif chemokine ligand 1 --> output type BiologicalProcess
# Running: musculin --> output type BiologicalProcess
# Running: amyloid P component, serum --> output type BiologicalProcess
# Running: CD19 molecule --> output type BiologicalProcess
# Running: chorionic somatomammotropin hormone 1 --> output type BiologicalProcess
# Running: tripartite motif containing 25 --> output type BiologicalProcess
# Running: KIT ligand --> output type BiologicalProcess
# Running: CD36 molecule --> output type BiologicalProcess
# Running: ras homolog family member D --> output type BiologicalProcess
# Running: tyrosine aminotransferase --> output type BiologicalProcess
# Running: interleukin 9 --> output type BiologicalProcess
# Running: elastase, neutrophil expressed --> output type BiologicalProcess
# Running: baculoviral IAP repeat containing 3 --> output type BiologicalProcess
# Running: ubiquitin C --> output type BiologicalProcess
# Running: forkhead box P3 --> output type BiologicalProcess
# Running: integrin subunit alpha X --> output type BiologicalProcess
# Running: MDM2 proto-oncogene --> output type BiologicalProcess
# Running: ribosomal protein SA --> output type BiologicalProcess
# Running: protein tyrosine phosphatase non-receptor type 6 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 20 --> output type BiologicalProcess
# Running: insulin like growth factor 1 --> output type BiologicalProcess
# Running: transferrin --> output type BiologicalProcess
# Running: S100 calcium binding protein A9 --> output type BiologicalProcess
# Running: histone deacetylase 1 --> output type BiologicalProcess
# Running: nucleotide binding oligomerization domain containing 2 --> output type BiologicalProcess
# Running: X-linked Kx blood group --> output type BiologicalProcess
# Running: interferon alpha inducible protein 27 --> output type BiologicalProcess
# Running: major histocompatibility complex, class II, DR beta 1 --> output type BiologicalProcess
# Running: FYN proto-oncogene, Src family tyrosine kinase --> output type BiologicalProcess
# Running: cannabinoid receptor 1 --> output type BiologicalProcess
# Running: cholecystokinin --> output type BiologicalProcess
# Running: von Willebrand factor --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 8 --> output type BiologicalProcess
# Running: CD69 molecule --> output type BiologicalProcess
# Running: interleukin 3 --> output type BiologicalProcess
# Running: pro-platelet basic protein --> output type BiologicalProcess
# Running: prohibitin --> output type BiologicalProcess
# Running: kallikrein related peptidase 3 --> output type BiologicalProcess
# Running: notch receptor 1 --> output type BiologicalProcess
# Running: advanced glycosylation end-product specific receptor --> output type BiologicalProcess
# Running: fibroblast growth factor receptor 1 --> output type BiologicalProcess
# Running: eukaryotic translation initiation factor 2 alpha kinase 2 --> output type BiologicalProcess
# Running: inhibitor of nuclear factor kappa B kinase regulatory subunit gamma --> output type BiologicalProcess
# Running: Cbl proto-oncogene --> output type BiologicalProcess
# Running: transferrin receptor --> output type BiologicalProcess
# Running: CD8a molecule --> output type BiologicalProcess
# Running: neural cell adhesion molecule 1 --> output type BiologicalProcess
# Running: nuclear receptor subfamily 3 group C member 1 --> output type BiologicalProcess
# Running: interferon regulatory factor 1 --> output type BiologicalProcess
# Running: cyclin dependent kinase 2 --> output type BiologicalProcess
# Running: BCL2 apoptosis regulator --> output type BiologicalProcess

# %%
for key in gene_to_bioprocess_results.keys(): 
    if(('C0' in key) or ('C1' in key)): 
        try: 
            name = ht.query(key)['BiologicalProcess'][0]['name']
            gene_to_bioprocess_results[name] = gene_to_bioprocess_results[key]
            del gene_to_bioprocess_results[key]
        except: 
            pass
# Out:
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-49-33b040a635af> in <module>
# ----> 1 for key in gene_to_bioprocess_results.keys():
#       2     if(('C0' in key) or ('C1' in key)):
#       3         try:
#       4             name = ht.query(key)['BiologicalProcess'][0]['name']
#       5             gene_to_bioprocess_results[name] = gene_to_bioprocess_results[key]
#
# RuntimeError: dictionary changed size during iteration

# %%
gene_to_bioprocess_results
# Out:
# {'GROWTH': {'bioprocess_count': 159},
#  'GENE EXPRESSION': {'bioprocess_count': 131},
#  'INFLAMMATION': {'bioprocess_count': 119},
#  'IMMUNE RESPONSE': {'bioprocess_count': 116},
#  'ACTIVATION OF GLOBAL TRANSCRIPTION FROM RNA POLYMERASE II PROMOTER': {'bioprocess_count': 111},
#  'BREAKDOWN': {'bioprocess_count': 109},
#  'INNATE IMMUNE RESPONSE': {'bioprocess_count': 106},
#  'METABOLIC PROCESS': {'bioprocess_count': 104},
#  'SECRETION': {'bioprocess_count': 101},
#  'CELL POPULATION PROLIFERATION': {'bioprocess_count': 97},
#  'CONJUGATION': {'bioprocess_count': 96},
#  'PATHOGENESIS': {'bioprocess_count': 96},
#  'CATAGEN': {'bioprocess_count': 93},
#  'ANGIOGENESIS': {'bioprocess_count': 93},
#  'CELL ADHESION': {'bioprocess_count': 92},
#  'GO:0016265': {'bioprocess_count': 88},
#  'TRANSDUCTION': {'bioprocess_count': 83},
#  'EXOGEN': {'bioprocess_count': 77},
#  'AUTOPHAGY': {'bioprocess_count': 75},
#  'ACCIDENTAL CELL DEATH': {'bioprocess_count': 74},
#  'CYTOKINE AND CHEMOKINE MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 74},
#  'ALVEOLARIZATION': {'bioprocess_count': 73},
#  'CHEMOTAXIS': {'bioprocess_count': 72},
#  'POSITIVE REGULATION OF GENE EXPRESSION': {'bioprocess_count': 71},
#  'CELL EXPANSION': {'bioprocess_count': 71},
#  'MEMORY': {'bioprocess_count': 70},
#  'CELL DIFFERENTIATION': {'bioprocess_count': 68},
#  'ANTI-APOPTOSIS': {'bioprocess_count': 66},
#  'CELL CYCLE': {'bioprocess_count': 66},
#  'CELL MIGRATION': {'bioprocess_count': 64},
#  'CHEMOATTRACTION': {'bioprocess_count': 63},
#  'AGEING': {'bioprocess_count': 63},
#  'NEURAL TUBE FORMATION': {'bioprocess_count': 63},
#  'T CELL ACTIVATION': {'bioprocess_count': 62},
#  'ACTIVATION OF GENE-SPECIFIC TRANSCRIPTION': {'bioprocess_count': 62},
#  'AKT SIGNAL TRANSDUCTION': {'bioprocess_count': 62},
#  'PROTEIN ANABOLISM': {'bioprocess_count': 61},
#  'EMT': {'bioprocess_count': 61},
#  'SENSITIZATION': {'bioprocess_count': 60},
#  'PEPTIDOLYSIS': {'bioprocess_count': 59},
#  'PIGMENTATION': {'bioprocess_count': 59},
#  'ARREST OF CELL CYCLE PROGRESSION': {'bioprocess_count': 59},
#  'ACTIVATION OF NF-KAPPAB': {'bioprocess_count': 58},
#  'DOWN REGULATION OF GLOBAL TRANSCRIPTION FROM RNA POLYMERASE II PROMOTER': {'bioprocess_count': 57},
#  'CELL ACTIVATION': {'bioprocess_count': 54},
#  'IMPORT INTO CELL': {'bioprocess_count': 54},
#  'PHASE II METABOLISM': {'bioprocess_count': 54},
#  'MAST CELL ACTIVATION': {'bioprocess_count': 52},
#  'DIGESTION': {'bioprocess_count': 52},
#  'POSITIVE REGULATION OF CELL POPULATION PROLIFERATION': {'bioprocess_count': 52},
#  'PEROXISOME DIVISION': {'bioprocess_count': 49},
#  'WOUND HEALING': {'bioprocess_count': 48},
#  'ANTIGEN PRESENTATION': {'bioprocess_count': 48},
#  'LACTATION': {'bioprocess_count': 47},
#  'CELL DEVELOPMENT': {'bioprocess_count': 47},
#  'SIGNAL TRANSDUCTION': {'bioprocess_count': 47},
#  'APOPTOSIS ACTIVATOR ACTIVITY': {'bioprocess_count': 46},
#  'PHAGOCYTOSIS': {'bioprocess_count': 44},
#  'ENDOCYTIC IMPORT INTO CELL': {'bioprocess_count': 44},
#  'ACTIVATION OF MAP KINASE': {'bioprocess_count': 43},
#  'MAP KINASE CASCADE': {'bioprocess_count': 42},
#  'ACQUIRED IMMUNE RESPONSE': {'bioprocess_count': 41},
#  'G PROTEIN COUPLED RECEPTOR PROTEIN SIGNALING PATHWAY': {'bioprocess_count': 41},
#  'RESPONSE TO ENDOTOXIN': {'bioprocess_count': 41},
#  'AER': {'bioprocess_count': 40},
#  'PHOSPHATIDYLINOSITOL 3-KINASE CASCADE': {'bioprocess_count': 40},
#  'PROTEIN AMINO ACID PHOSPHORYLATION': {'bioprocess_count': 39},
#  'CYTOKINE SECRETION': {'bioprocess_count': 38},
#  'MAST CELL DEGRANULATION': {'bioprocess_count': 38},
#  'CELLULAR DNA DAMAGE RESPONSE': {'bioprocess_count': 38},
#  'REGENERATION': {'bioprocess_count': 38},
#  'CELL MATURATION': {'bioprocess_count': 36},
#  'REVERSE TRANSCRIPTION': {'bioprocess_count': 35},
#  'CALCIUM ION SIGNALING': {'bioprocess_count': 35},
#  'CLOTTING': {'bioprocess_count': 34},
#  'MACROPHAGE ACTIVATION': {'bioprocess_count': 34},
#  'CHROMOSOMAL PAIRING': {'bioprocess_count': 34},
#  'T CELL PROLIFERATION': {'bioprocess_count': 34},
#  'HYPERSENSITIVITY': {'bioprocess_count': 33},
#  'CELL CYCLE MODULATION': {'bioprocess_count': 33},
#  'LEARNING': {'bioprocess_count': 32},
#  'ANTIVIRAL RESPONSE': {'bioprocess_count': 32},
#  'POSITIVE REGULATION OF ERK CASCADE': {'bioprocess_count': 32},
#  'POSITIVE REGULATION OF ANGIOGENESIS': {'bioprocess_count': 32},
#  'LIPID METABOLIC PROCESS': {'bioprocess_count': 31},
#  'ANTI-INFLAMMATORY RESPONSE': {'bioprocess_count': 31},
#  'CELLULAR RESPONSE TO ENDOTOXIN': {'bioprocess_count': 31},
#  'DOWN REGULATION OF CELL PROLIFERATION': {'bioprocess_count': 31},
#  'IL-6 PRODUCTION': {'bioprocess_count': 30},
#  'CASPASE-INDEPENDENT APOPTOSIS': {'bioprocess_count': 30},
#  'TLR SIGNALING PATHWAY': {'bioprocess_count': 30},
#  'ACTIVATION OF I-KAPPAB KINASE/NF-KAPPAB CASCADE': {'bioprocess_count': 30},
#  'DNA REPAIR': {'bioprocess_count': 30},
#  'CELLULAR GLUCOSE METABOLIC PROCESS': {'bioprocess_count': 30},
#  'FERMENTATION': {'bioprocess_count': 30},
#  'DRUG RESISTANCE': {'bioprocess_count': 29},
#  'DOWN REGULATION OF GENE-SPECIFIC TRANSCRIPTION': {'bioprocess_count': 29},
#  'GLOBAL TRANSCRIPTION REGULATION FROM POL II PROMOTER': {'bioprocess_count': 29},
#  'BLOOD COAGULATION, PLATELET ACTIVATION': {'bioprocess_count': 28},
#  'VIRAL INFECTION': {'bioprocess_count': 28},
#  'POSITIVE REGULATION OF APOPTOTIC PROCESS': {'bioprocess_count': 28},
#  'RESPONSE TO HYPOXIA': {'bioprocess_count': 28},
#  'EXCRETION': {'bioprocess_count': 27},
#  'B CELL ACTIVATION': {'bioprocess_count': 27},
#  'DEPHOSPHORYLATION': {'bioprocess_count': 27},
#  'CELL PHYSIOLOGY': {'bioprocess_count': 27},
#  'HETEROPHIL DEGRANULATION': {'bioprocess_count': 27},
#  'POSITIVE REGULATION OF AKT SIGNALING CASCADE': {'bioprocess_count': 27},
#  'POSTTRANSCRIPTIONAL GENE SILENCING BY SIRNA': {'bioprocess_count': 26},
#  'IL-13 PRODUCTION': {'bioprocess_count': 26},
#  'COGNITION': {'bioprocess_count': 26},
#  'NEGATIVE REGULATION OF GENE EXPRESSION': {'bioprocess_count': 26},
#  'T CELL CO-STIMULATION': {'bioprocess_count': 25},
#  'IL-10 PRODUCTION': {'bioprocess_count': 25},
#  'BIOLOGICAL PROCESS': {'bioprocess_count': 25},
#  'CLEAVAGE OF PLASMINOGEN TO PLASMIN': {'bioprocess_count': 24},
#  'DNA METHYLATION': {'bioprocess_count': 24},
#  'HUMORAL IMMUNE RESPONSE': {'bioprocess_count': 24},
#  'POST-TRANSLATIONAL AMINO ACID MODIFICATION': {'bioprocess_count': 24},
#  'PROTEASOME COMPLEX DISASSEMBLY': {'bioprocess_count': 24},
#  'BONE BIOSYNTHESIS': {'bioprocess_count': 24},
#  'EXOCYTOSIS': {'bioprocess_count': 24},
#  'TISSUE REMODELING': {'bioprocess_count': 24},
#  'NEUTROPHIL CHEMOTAXIS': {'bioprocess_count': 24},
#  'DEUBIQUITINATION': {'bioprocess_count': 23},
#  'CELLULAR MRNA TRANSCRIPTION': {'bioprocess_count': 23},
#  'CTLA-8 PRODUCTION': {'bioprocess_count': 23},
#  'CHEMOKINE PRODUCTION': {'bioprocess_count': 23},
#  'DEMETHYLATION': {'bioprocess_count': 23},
#  'POSITIVE REGULATION OF PROTEIN AMINO ACID PHOSPHORYLATION': {'bioprocess_count': 23},
#  'NERVOUS SYSTEM CELL GENERATION': {'bioprocess_count': 23},
#  "3',5' CAMP-MEDIATED SIGNALING": {'bioprocess_count': 23},
#  'IMMUNE CELL MIGRATION': {'bioprocess_count': 23},
#  'POSITIVE REGULATION OF TYROSINE PHOSPHORYLATION OF STAT PROTEIN': {'bioprocess_count': 23},
#  'EMBRYO DEVELOPMENT': {'bioprocess_count': 23},
#  'IL-4 PRODUCTION': {'bioprocess_count': 22},
#  'CELL SURFACE RECEPTOR LINKED SIGNAL TRANSDUCTION': {'bioprocess_count': 22},
#  'DNA ANABOLISM': {'bioprocess_count': 22},
#  'DIAPAUSE': {'bioprocess_count': 22},
#  'EXTRACELLULAR MATRIX ORGANISATION': {'bioprocess_count': 22},
#  'BLOOD CELL BIOSYNTHESIS': {'bioprocess_count': 22},
#  'POSITIVE REGULATION OF CELL MIGRATION': {'bioprocess_count': 22},
#  'BIOLUMINESCENCE': {'bioprocess_count': 21},
#  'T CELL DEVELOPMENT': {'bioprocess_count': 21},
#  'CLASS SWITCH RECOMBINATION': {'bioprocess_count': 21},
#  'POSITIVE REGULATION OF PHOSPHATIDYLINOSITOL 3-KINASE CASCADE': {'bioprocess_count': 21},
#  'APOPTOSIS REGULATOR ACTIVITY': {'bioprocess_count': 21},
#  'REGULATION OF GENE EXPRESSION': {'bioprocess_count': 21},
#  'POSITIVE REGULATION OF IL-6 PRODUCTION': {'bioprocess_count': 21},
#  'CARRYING OF YOUNG': {'bioprocess_count': 20},
#  'GLOMERULAR FILTRATION': {'bioprocess_count': 20},
#  'CELLULAR RESPONSE TO TNF': {'bioprocess_count': 20},
#  'ACTIVATION OF CYSTEINE-TYPE ENDOPEPTIDASE ACTIVITY INVOLVED IN APOPTOTIC PROCESS': {'bioprocess_count': 20},
#  'INTRACELLULAR SIGNAL TRANSDUCTION': {'bioprocess_count': 20},
#  'B CELL RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 20},
#  'POSITIVE REGULATION OF IL-8 PRODUCTION': {'bioprocess_count': 20},
#  'OSTEOCLAST CELL DIFFERENTIATION': {'bioprocess_count': 20},
#  'CELL KILLING': {'bioprocess_count': 19},
#  'REGULATION OF IMMUNE RESPONSE': {'bioprocess_count': 19},
#  'POSITIVE REGULATION OF PEPTIDYL-TYROSINE PHOSPHORYLATION': {'bioprocess_count': 19},
#  'FATTY ACID OXIDATION': {'bioprocess_count': 19},
#  'NEURON CELL DEATH': {'bioprocess_count': 19},
#  'COSUPPRESSION': {'bioprocess_count': 19},
#  'POSITIVE REGULATION OF INFLAMMATORY RESPONSE': {'bioprocess_count': 19},
#  'BONE RESORPTION': {'bioprocess_count': 19},
#  'RESPONSE TO VIRUS': {'bioprocess_count': 19},
#  'CELL DIVISION': {'bioprocess_count': 19},
#  'G1 PHASE': {'bioprocess_count': 19},
#  'CELL-CELL SIGNALING': {'bioprocess_count': 18},
#  'BASE-EXCISION REPAIR': {'bioprocess_count': 18},
#  'ACTIVATION OF NON-CANONICAL NF-KB SIGNALING': {'bioprocess_count': 18},
#  'TNF PRODUCTION': {'bioprocess_count': 17},
#  'POSITIVE REGULATION OF BLOOD VESSEL SIZE': {'bioprocess_count': 17},
#  'AUTOLYSIN ACTIVITY': {'bioprocess_count': 17},
#  'IL-5 PRODUCTION': {'bioprocess_count': 17},
#  'IL-9 PRODUCTION': {'bioprocess_count': 17},
#  'POSITIVE REGULATION OF MAP KINASE CASCADE': {'bioprocess_count': 17},
#  'CARDIAC DEVELOPMENT': {'bioprocess_count': 17},
#  'PIECEMEAL MICROAUTOPHAGY OF THE NUCLEUS': {'bioprocess_count': 17},
#  'ANTIBACTERIAL PEPTIDE ACTIVITY': {'bioprocess_count': 17},
#  'RESPONSE TO ETHANOL': {'bioprocess_count': 17},
#  'MAST CELL MIGRATION': {'bioprocess_count': 17},
#  'DORMANCY MAINTENANCE OF SYMBIONT IN HOST': {'bioprocess_count': 17},
#  'HISTONE ACETYLATION': {'bioprocess_count': 17},
#  'MICROGLIAL CELL ACTIVATION': {'bioprocess_count': 17},
#  'OSTEOBLAST CELL DIFFERENTIATION': {'bioprocess_count': 17},
#  'POSITIVE REGULATION OF PROTEIN STABILITY': {'bioprocess_count': 17},
#  'CHROMATIN MODELING': {'bioprocess_count': 16},
#  'GENE SILENCING': {'bioprocess_count': 16},
#  'IL-12 PRODUCTION': {'bioprocess_count': 16},
#  'T CELL RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 16},
#  'CELLULAR RESPONSE TO HYPOXIA': {'bioprocess_count': 16},
#  'ADIPOCYTOKINE SIGNALING PATHWAY': {'bioprocess_count': 16},
#  'GLUCOSE IMPORT': {'bioprocess_count': 16},
#  'RESPONSE TO ACTIVITY': {'bioprocess_count': 16},
#  'KERATINIZATION': {'bioprocess_count': 16},
#  'IL-8 PRODUCTION': {'bioprocess_count': 16},
#  'PHEROMONE CATABOLIC PROCESS': {'bioprocess_count': 16},
#  'BONE MINERALIZATION': {'bioprocess_count': 16},
#  'LEUKOCYTE ADHESION': {'bioprocess_count': 16},
#  'TISSUE REGENERATION': {'bioprocess_count': 16},
#  'REGULATION OF CELLULAR TRANSCRIPTION, DNA-DEPENDENT': {'bioprocess_count': 16},
#  'GLUCOSE HOMEOSTASIS': {'bioprocess_count': 16},
#  'CELLULAR MECHANICAL STIMULUS RESPONSE': {'bioprocess_count': 16},
#  'POSITIVE REGULATION OF TNF PRODUCTION': {'bioprocess_count': 16},
#  'COMPLEMENT ACTIVATION': {'bioprocess_count': 15},
#  'ADCC': {'bioprocess_count': 15},
#  'CELL POLARIZATION': {'bioprocess_count': 15},
#  'CELL LOCALIZATION': {'bioprocess_count': 15},
#  'HISTONE MODIFICATION': {'bioprocess_count': 15},
#  'MACROPHAGE CELL DIFFERENTIATION': {'bioprocess_count': 15},
#  'PROTEIN UBIQUITINATION': {'bioprocess_count': 15},
#  'SEV RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 15},
#  'ACTIVATION OF PROTEIN KINASE C ACTIVITY': {'bioprocess_count': 15},
#  'NITRIC OXIDE MEDIATED SIGNAL TRANSDUCTION': {'bioprocess_count': 15},
#  'S PHASE': {'bioprocess_count': 15},
#  'PEPTIDYL-SERINE PHOSPHORYLATION': {'bioprocess_count': 15},
#  'RESPONSE TO CYTOKINE': {'bioprocess_count': 15},
#  'NEUTROPHIL ACTIVATION': {'bioprocess_count': 15},
#  'ASTROCYTE ACTIVATION': {'bioprocess_count': 15},
#  'GAMMA-INTERFERON-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 15},
#  'EXPORT FROM NUCLEUS': {'bioprocess_count': 15},
#  'BLOOD CIRCULATION': {'bioprocess_count': 15},
#  'CELLULAR PROTEIN METABOLIC PROCESS': {'bioprocess_count': 15},
#  'NEGATIVE REGULATION OF BLOOD VESSEL SIZE': {'bioprocess_count': 14},
#  'REGULATION OF CELL POPULATION PROLIFERATION': {'bioprocess_count': 14},
#  'REGULATION OF INFLAMMATORY RESPONSE': {'bioprocess_count': 14},
#  'TISSUE HOMEOSTASIS': {'bioprocess_count': 14},
#  'INSULIN SECRETION': {'bioprocess_count': 14},
#  'MONOCYTE ACTIVATION': {'bioprocess_count': 14},
#  'IFN-ALPHA PRODUCTION': {'bioprocess_count': 14},
#  'N SIGNALING PATHWAY': {'bioprocess_count': 14},
#  'FIBRINOLYSIS': {'bioprocess_count': 14},
#  'PLATELET DEGRANULATION': {'bioprocess_count': 14},
#  'PROTEIN SUMOLATION': {'bioprocess_count': 14},
#  'PROTEASOMAL PATHWAY': {'bioprocess_count': 14},
#  'DNA REPLICATION': {'bioprocess_count': 14},
#  'REGULATION OF ANGIOGENESIS': {'bioprocess_count': 14},
#  'CIRCADIAN PROCESS': {'bioprocess_count': 14},
#  'POSITIVE REGULATION OF PEPTIDYL-SERINE PHOSPHORYLATION': {'bioprocess_count': 14},
#  'POSITIVE REGULATION OF DNA BINDING TRANSCRIPTION FACTOR ACTIVITY': {'bioprocess_count': 14},
#  'CELLULAR SENESCENCE': {'bioprocess_count': 14},
#  'CHEMOKINE-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 14},
#  'CELLULAR RESPONSE TO IL-1': {'bioprocess_count': 14},
#  'LIPID BREAKDOWN': {'bioprocess_count': 14},
#  'POSITIVE REGULATION OF PRI-MIRNA TRANSCRIPTION BY RNA POLYMERASE II': {'bioprocess_count': 14},
#  'CELL-CELL ADHESION': {'bioprocess_count': 14},
#  'CELL LOCOMOTION': {'bioprocess_count': 14},
#  'ACTION POTENTIAL': {'bioprocess_count': 14},
#  'GO:0072608': {'bioprocess_count': 13},
#  'MUCUS PRODUCTION': {'bioprocess_count': 13},
#  'EOSINOPHIL ACTIVATION': {'bioprocess_count': 13},
#  'PROTEIN SECRETION': {'bioprocess_count': 13},
#  'NATURAL KILLER CELL ACTIVATION': {'bioprocess_count': 13},
#  'ANIMAL ORGAN DEVELOPMENT': {'bioprocess_count': 13},
#  'POSITIVE REGULATION OF T CELL PROLIFERATION': {'bioprocess_count': 13},
#  'LIVER REGENERATION': {'bioprocess_count': 13},
#  'GLUCONEOGENESIS': {'bioprocess_count': 13},
#  'TGF-BETA RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 13},
#  'RESPONSE TO INSULIN': {'bioprocess_count': 13},
#  'POSITIVE REGULATION OF BLOOD VESSEL ENDOTHELIAL CELL MIGRATION': {'bioprocess_count': 13},
#  'LIPOPOLYSACCHARIDE-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 13},
#  'ACTIN FILAMENT POLYMERIZATION': {'bioprocess_count': 13},
#  'IMMUNE CELL ACTIVATION': {'bioprocess_count': 13},
#  'CELL CHEMOTAXIS': {'bioprocess_count': 13},
#  'CELLULAR RESPONSE TO GAMMA-INTERFERON': {'bioprocess_count': 13},
#  'POSITIVE REGULATION OF B CELL PROLIFERATION': {'bioprocess_count': 13},
#  'MAST CELL PROLIFERATION': {'bioprocess_count': 13},
#  'PHOTOSYNTHESIS': {'bioprocess_count': 13},
#  'M PHASE': {'bioprocess_count': 13},
#  'RESPONSE TO IL-1': {'bioprocess_count': 13},
#  'POSITIVE REGULATION OF SMC PROLIFERATION': {'bioprocess_count': 13},
#  'CHAPERONE ACTIVITY': {'bioprocess_count': 13},
#  'LIPID ANABOLISM': {'bioprocess_count': 13},
#  'FERTILIZATION': {'bioprocess_count': 13},
#  'DEFENCE RESPONSE TO GRAM-POSITIVE BACTERIA': {'bioprocess_count': 12},
#  'T-HELPER 1 TYPE IMMUNE RESPONSE': {'bioprocess_count': 12},
#  'IL-22 PRODUCTION': {'bioprocess_count': 12},
#  'RESPONSE TO GLUCOCORTICOID': {'bioprocess_count': 12},
#  'PUPARIATION': {'bioprocess_count': 12},
#  'HEAD EVERSION': {'bioprocess_count': 12},
#  'IFN-EPSILON PRODUCTION': {'bioprocess_count': 12},
#  'RESPONSE TO E2 STIMULUS': {'bioprocess_count': 12},
#  'BLOOD CLOTTING': {'bioprocess_count': 12},
#  'CELLULAR METABOLIC PROCESS': {'bioprocess_count': 12},
#  'OLFACTION': {'bioprocess_count': 12},
#  'AXON CHEMOTAXIS': {'bioprocess_count': 12},
#  'NOCICEPTION': {'bioprocess_count': 12},
#  'CELLULAR RESPONSE TO BETA-1 INTERFERON': {'bioprocess_count': 12},
#  'NEUTROPHIL MIGRATION': {'bioprocess_count': 12},
#  'METABOLIC BURST': {'bioprocess_count': 12},
#  'ANTIMICROBIAL PEPTIDE ACTIVITY': {'bioprocess_count': 12},
#  'ANATOMICAL STRUCTURE MORPHOGENESIS': {'bioprocess_count': 12},
#  'IMMUNE CELL CHEMOTAXIS': {'bioprocess_count': 12},
#  'MONOCYTE CHEMOTAXIS': {'bioprocess_count': 12},
#  'IL-2 PRODUCTION': {'bioprocess_count': 12},
#  'RESPONSE TO IL-2': {'bioprocess_count': 12},
#  'POSITIVE REGULATION OF IL-1 BETA PRODUCTION': {'bioprocess_count': 12},
#  'TRANSDIFFERENTIATION': {'bioprocess_count': 12},
#  'NEURON DIFFERENTIATION': {'bioprocess_count': 12},
#  'VASCULAR ENDOTHELIAL GROWTH FACTOR RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 12},
#  'POSITIVE REGULATION OF IL-10 PRODUCTION': {'bioprocess_count': 12},
#  'FATTY ACID ANABOLISM': {'bioprocess_count': 12},
#  'GO:0072604': {'bioprocess_count': 12},
#  'TYPE I INTERFERON SIGNALING PATHWAY': {'bioprocess_count': 12},
#  'BIOPOLYMERISATION': {'bioprocess_count': 12},
#  'EGF RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 12},
#  'GUSTATION': {'bioprocess_count': 12},
#  'TRANSCRIPTION INITIATION FROM POL II PROMOTER': {'bioprocess_count': 12},
#  'NOTUM DEVELOPMENT': {'bioprocess_count': 11},
#  'ACUTE-PHASE RESPONSE': {'bioprocess_count': 11},
#  'SEGMENTATION': {'bioprocess_count': 11},
#  'T CELL MIGRATION': {'bioprocess_count': 11},
#  'IL-23 PRODUCTION': {'bioprocess_count': 11},
#  'GENERATION OF SPERMATOZOA': {'bioprocess_count': 11},
#  'CELL AGEING': {'bioprocess_count': 11},
#  'DOWN REGULATION OF NEURON CELL DEATH': {'bioprocess_count': 11},
#  'APOPTOSIS IN RESPONSE TO ENDOPLASMIC RETICULUM STRESS': {'bioprocess_count': 11},
#  'CHEMICAL SYNAPTIC TRANSMISSION': {'bioprocess_count': 11},
#  'DOWN REGULATION OF TUMOR NECROSIS FACTOR PRODUCTION': {'bioprocess_count': 11},
#  'POSITIVE REGULATION OF VASCULAR ENDOTHELIAL GROWTH FACTOR PRODUCTION': {'bioprocess_count': 11},
#  'B CELL PROLIFERATION': {'bioprocess_count': 11},
#  'POSITIVE REGULATION OF CLMF PRODUCTION': {'bioprocess_count': 11},
#  'POSITIVE REGULATION OF NITRIC OXIDE ANABOLISM': {'bioprocess_count': 11},
#  'B CELL DEVELOPMENT': {'bioprocess_count': 11},
#  'SWIMMING': {'bioprocess_count': 11},
#  'FATTY ACID METABOLIC PROCESS': {'bioprocess_count': 11},
#  'BIOMINERAL TISSUE DEVELOPMENT': {'bioprocess_count': 11},
#  'NEGATIVE REGULATION OF AUTOPHAGY': {'bioprocess_count': 11},
#  'DOWN REGULATION OF INTERLEUKIN-6 PRODUCTION': {'bioprocess_count': 11},
#  'ACTIVATION OF THE INHIBITOR OF KAPPA KINASE': {'bioprocess_count': 11},
#  'POSITIVE REGULATION OF MAP KINASE ACTIVITY': {'bioprocess_count': 11},
#  'POSITIVE REGULATION OF RECEPTOR SIGNALING PATHWAY VIA JAK-STAT': {'bioprocess_count': 11},
#  'CELL CYCLE CONTROL': {'bioprocess_count': 11},
#  'CELLULAR RESPONSE TO DRUG': {'bioprocess_count': 11},
#  'FRIZZLED SIGNALING PATHWAY': {'bioprocess_count': 11},
#  'PROTEIN AMINO ACID AUTOPHOSPHORYLATION': {'bioprocess_count': 11},
#  'PEPTIDYL-TYROSINE PHOSPHORYLATION': {'bioprocess_count': 11},
#  'BLOOD PRESSURE HOMEOSTASIS': {'bioprocess_count': 11},
#  'DETOXIFICATION': {'bioprocess_count': 11},
#  'HEARING': {'bioprocess_count': 11},
#  'ERYTHROCYTE CELL DIFFERENTIATION': {'bioprocess_count': 11},
#  'POSITIVE REGULATION OF TYPE I IFN PRODUCTION': {'bioprocess_count': 11},
#  'MENOPAUSE': {'bioprocess_count': 10},
#  'OPSONIZATION': {'bioprocess_count': 10},
#  'POSITIVE REGULATION OF SUPEROXIDE ANION GENERATION': {'bioprocess_count': 10},
#  'ENTRY OF VIRUS INTO HOST CELL': {'bioprocess_count': 10},
#  'CELLULAR MEMBRANE ORGANISATION': {'bioprocess_count': 10},
#  'GO:0072602': {'bioprocess_count': 10},
#  'TYPE 2 IMMUNE RESPONSE': {'bioprocess_count': 10},
#  'OIS': {'bioprocess_count': 10},
#  'TLR4 SIGNALING PATHWAY': {'bioprocess_count': 10},
#  'MATING': {'bioprocess_count': 10},
#  'POSITIVE REGULATION OF ENDOTHELIAL CELL PROLIFERATION': {'bioprocess_count': 10},
#  'DOWN REGULATION OF CELL GROWTH': {'bioprocess_count': 10},
#  'RESPONSE TO TOXIC SUBSTANCE': {'bioprocess_count': 10},
#  'FC-EPSILON RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 10},
#  'CARBOHYDRATE METABOLIC PROCESS': {'bioprocess_count': 10},
#  'INNERVATION': {'bioprocess_count': 10},
#  'EATING BEHAVIOR': {'bioprocess_count': 10},
#  'POSITIVE REGULATION OF CIT': {'bioprocess_count': 10},
#  'OXIDATION REDUCTION': {'bioprocess_count': 10},
#  'JAK-STAT SIGNAL TRANSDUCTION': {'bioprocess_count': 10},
#  'REGULATION OF CELL SHAPE': {'bioprocess_count': 10},
#  'DOWN REGULATION OF NEURON APOPTOSIS': {'bioprocess_count': 10},
#  'CELLULAR RESPONSE TO ORGANIC CYCLIC COMPOUND': {'bioprocess_count': 10},
#  'DENDRITIC CELL DIFFERENTIATION': {'bioprocess_count': 10},
#  'PLACENTA DEVELOPMENT': {'bioprocess_count': 10},
#  'IMPORT INTO NUCLEUS': {'bioprocess_count': 10},
#  'CHOLESTEROL METABOLIC PROCESS': {'bioprocess_count': 10},
#  'CITRIC ACID CYCLE': {'bioprocess_count': 10},
#  'C-JUN N-TERMINAL KINASE CASCADE': {'bioprocess_count': 10},
#  'CHEMOKINE SECRETION': {'bioprocess_count': 10},
#  'BRAIN DEVELOPMENT': {'bioprocess_count': 10},
#  'LUMEN FORMATION IN AN ANATOMICAL STRUCTURE': {'bioprocess_count': 10},
#  'PROTEIN MODIFICATION': {'bioprocess_count': 10},
#  'CELLULAR RESPONSE TO NERVE GROWTH FACTOR STIMULUS': {'bioprocess_count': 10},
#  'POSITIVE REGULATION OF IFN-BETA PRODUCTION': {'bioprocess_count': 10},
#  'IL-1-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 10},
#  'SENSE OF SIGHT': {'bioprocess_count': 10},
#  'MUSCLE CONTRACTION': {'bioprocess_count': 9},
#  'ESTABLISHMENT OF T CELL POLARITY': {'bioprocess_count': 9},
#  'EOSINOPHIL CHEMOTAXIS': {'bioprocess_count': 9},
#  'CELL-MEDIATED IMMUNITY': {'bioprocess_count': 9},
#  'TRANSMEMBRANE RECEPTOR PROTEIN TYROSINE KINASE SIGNALING PATHWAY': {'bioprocess_count': 9},
#  'RESPONSE TO ABIOTIC STRESS': {'bioprocess_count': 9},
#  'CELL CYCLE PHASE TRANSITION': {'bioprocess_count': 9},
#  'ERK CASCADE': {'bioprocess_count': 9},
#  'EAR DEVELOPMENT': {'bioprocess_count': 9},
#  'CELLULAR RESPONSE TO ACTIVE OXYGEN SPECIES': {'bioprocess_count': 9},
#  'REFLEX': {'bioprocess_count': 9},
#  'CYTOPLASMIC CALCIUM ION CONCENTRATION ELEVATION': {'bioprocess_count': 9},
#  'ENDOTHELIAL CELL ACTIVATION': {'bioprocess_count': 9},
#  'CELLULAR RESPONSE TO CYTOKINE STIMULUS': {'bioprocess_count': 9},
#  'CELLULAR HOMEOSTASIS': {'bioprocess_count': 9},
#  'LYMPHOCYTE PROLIFERATION': {'bioprocess_count': 9},
#  'MRNA STABILIZATION': {'bioprocess_count': 9},
#  'POSITIVE REGULATION OF INTERFERON-GAMMA PRODUCTION': {'bioprocess_count': 9},
#  'REGULATION OF INSULIN SECRETION': {'bioprocess_count': 9},
#  'EXTRINSIC APOPTOTIC PATHWAY': {'bioprocess_count': 9},
#  'APOPTOSIS OF NEURONAL CELLS': {'bioprocess_count': 9},
#  'STEROID ANABOLISM': {'bioprocess_count': 9},
#  'MAST CELL DIFFERENTIATION': {'bioprocess_count': 9},
#  'MACROPHAGE PROLIFERATION': {'bioprocess_count': 9},
#  'ASYMMETRIC PROTEIN LOCALISATION': {'bioprocess_count': 9},
#  'FLIGHT': {'bioprocess_count': 9},
#  'DOUBLE-STRAND BREAK REPAIR VIA HOMOLOGOUS RECOMBINATION': {'bioprocess_count': 9},
#  'BONE REMODELING': {'bioprocess_count': 9},
#  'CARTILAGE BIOGENESIS': {'bioprocess_count': 9},
#  'ENERGY HOMEOSTASIS': {'bioprocess_count': 9},
#  'LUNG DEVELOPMENT': {'bioprocess_count': 9},
#  'POSITIVE REGULATION OF CHEMOKINE PRODUCTION': {'bioprocess_count': 9},
#  'POSITIVE REGULATION OF CYTOKINE PRODUCTION INVOLVED IN INFLAMMATORY RESPONSE': {'bioprocess_count': 9},
#  'REPRODUCTION': {'bioprocess_count': 9},
#  'RELEASE OF CYTOCHROME C FROM MITOCHONDRIA': {'bioprocess_count': 9},
#  'DNA DAMAGE RESPONSE, SIGNAL TRANSDUCTION BY P53 CLASS MEDIATOR RESULTING IN CELL CYCLE ARREST': {'bioprocess_count': 9},
#  'FOLLICULAR PHASE': {'bioprocess_count': 9},
#  'POSITIVE REGULATION OF EPITHELIAL CELL PROLIFERATION': {'bioprocess_count': 9},
#  'IL-6-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 9},
#  'RESPONSE TO NUTRIENT': {'bioprocess_count': 9},
#  'MISMATCH REPAIR': {'bioprocess_count': 9},
#  'ESTABLISHMENT OF INTEGRATED PROVIRAL LATENCY': {'bioprocess_count': 9},
#  'TOLL/IL-1 RECEPTOR (TIR) DOMAIN-CONTAINING ADAPTOR-DEPENDENT TLR SIGNALING PATHWAY': {'bioprocess_count': 9},
#  'APOPTOTIC SIGNALING PATHWAY': {'bioprocess_count': 9},
#  'INOSITOL PHOSPHOLIPID-MEDIATED SIGNALING': {'bioprocess_count': 9},
#  'NEURON CHEMOTAXIS': {'bioprocess_count': 9},
#  'OOCYTE DEVELOPMENT': {'bioprocess_count': 9},
#  'RECEPTOR INTERNALIZATION': {'bioprocess_count': 9},
#  'PEPTIDYL-CYSTEINE S-NITROSYLATION': {'bioprocess_count': 8},
#  'ION TRANSPORT': {'bioprocess_count': 8},
#  'MEMBRANE TRANSPORT': {'bioprocess_count': 8},
#  'GO:0072611': {'bioprocess_count': 8},
#  'TOLERANCE INDUCTION': {'bioprocess_count': 8},
#  'TROPISM': {'bioprocess_count': 8},
#  'PROGRAMMED CELL DEATH OF T CELLS BY APOPTOSIS': {'bioprocess_count': 8},
#  'DOWN REGULATION OF ANGIOGENESIS': {'bioprocess_count': 8},
#  'RESPONSE TO HYDROGEN PEROXIDE': {'bioprocess_count': 8},
#  'DOWN REGULATION OF PROTEIN KINASE ACTIVITY': {'bioprocess_count': 8},
#  'AXON REGENERATION': {'bioprocess_count': 8},
#  'LIPID HOMEOSTASIS': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF PROTEIN IMPORT INTO CELL NUCLEUS': {'bioprocess_count': 8},
#  'RESPONSE TO ESTROGEN': {'bioprocess_count': 8},
#  'RESPONSE TO PEPTIDE HORMONE': {'bioprocess_count': 8},
#  'BLOOD PLATELET AGGREGATION': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF RECEPTOR MEDIATED ENDOCYTOSIS': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF GTPASE ACTIVITY': {'bioprocess_count': 8},
#  'GO:0072615': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF CELL GROWTH': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF PROTEIN COMPLEX ASSEMBLY': {'bioprocess_count': 8},
#  'REGULATION OF GROWTH': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF TNF ALPHA BIOSYNTHESIS': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF NEURON CELL DEATH': {'bioprocess_count': 8},
#  'LIPID OXIDATION': {'bioprocess_count': 8},
#  'GLUCOCORTICOID SECRETION': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF GLUCOSE IMPORT': {'bioprocess_count': 8},
#  'REGULATION OF SIGNAL TRANSDUCTION BY P53 CLASS MEDIATOR': {'bioprocess_count': 8},
#  'THYMIC STROMAL LYMPHOPOIETIN PRODUCTION': {'bioprocess_count': 8},
#  'HATCHING': {'bioprocess_count': 8},
#  'MONOCYTE CELL DIFFERENTIATION': {'bioprocess_count': 8},
#  'LUTEAL PHASE': {'bioprocess_count': 8},
#  'CHEWING': {'bioprocess_count': 8},
#  'HEMOSTASIS': {'bioprocess_count': 8},
#  'NEGATIVE REGULATION OF DEPENDENCE RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 8},
#  'DNA DAMAGE RESPONSE, SIGNAL TRANSDUCTION RESULTING IN INDUCTION OF APOPTOSIS': {'bioprocess_count': 8},
#  'SKELETAL DEVELOPMENT': {'bioprocess_count': 8},
#  'EXTRINSIC APOPTOTIC SIGNALING PATHWAY VIA DEATH DOMAIN RECEPTORS': {'bioprocess_count': 8},
#  'LIVER DEVELOPMENT': {'bioprocess_count': 8},
#  'CALCIUM ION IMPORT': {'bioprocess_count': 8},
#  'CELLULAR RESPONSE TO INSULIN STIMULUS': {'bioprocess_count': 8},
#  'DENDRITIC CELL CHEMOTAXIS': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF EPITHELIAL TO MESENCHYMAL TRANSITION': {'bioprocess_count': 8},
#  'MITOCHONDRIAL FUSION': {'bioprocess_count': 8},
#  'MYD88-DEPENDENT TLR SIGNALING PATHWAY': {'bioprocess_count': 8},
#  'MYD88-INDEPENDENT TLR SIGNALING PATHWAY': {'bioprocess_count': 8},
#  'CELLULAR RESPONSE TO AMYLOID-BETA': {'bioprocess_count': 8},
#  'BLASTOCYST IMPLANTATION': {'bioprocess_count': 8},
#  'DOWN REGULATION OF T CELL PROLIFERATION': {'bioprocess_count': 8},
#  'ANTIMICROBIAL HUMORAL IMMUNE RESPONSE MEDIATED BY ANTIMICROBIAL PEPTIDE': {'bioprocess_count': 8},
#  'RECEPTOR MEDIATED ENDOCYTOSIS': {'bioprocess_count': 8},
#  'PROTEIN AMINO ACID DEPHOSPHORYLATION': {'bioprocess_count': 8},
#  'MALE GONAD DEVELOPMENT': {'bioprocess_count': 8},
#  'POSITIVE REGULATION OF NEURON PROJECTION DEVELOPMENT': {'bioprocess_count': 8},
#  'INTEGRIN-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 8},
#  'CELL-MATRIX ADHESION': {'bioprocess_count': 8},
#  'G1/S TRANSITION OF MITOTIC CELL CYCLE': {'bioprocess_count': 8},
#  'ANGIOTENSIN MATURATION': {'bioprocess_count': 7},
#  'CELLULAR RESPONSE TO ENDOPLASMIC RETICULUM STRESS': {'bioprocess_count': 7},
#  'DNA HYPOMETHYLATION': {'bioprocess_count': 7},
#  'T CELL ANERGY': {'bioprocess_count': 7},
#  'CCL17 PRODUCTION': {'bioprocess_count': 7},
#  'POSITIVE REGULATION OF KINASE ACTIVITY': {'bioprocess_count': 7},
#  'REPLICATIVE SENESCENCE': {'bioprocess_count': 7},
#  'ANOIKIS': {'bioprocess_count': 7},
#  'OXIDATIVE PHOSPHORYLATION': {'bioprocess_count': 7},
#  'RESPONSE TO OXIDATIVE STRESS': {'bioprocess_count': 7},
#  'NEGATIVE REGULATION OF PROTEIN STABILITY': {'bioprocess_count': 7},
#  'SIPS': {'bioprocess_count': 7},
#  'REGULATION OF CELLULAR RESPONSE TO HEAT': {'bioprocess_count': 7},
#  'CELLULAR RESPONSE TO CDF': {'bioprocess_count': 7},
#  'ACTIVATION OF MAP KINASE KINASE ACTIVITY': {'bioprocess_count': 7},
#  'POSITIVE REGULATION OF JNK CASCADE': {'bioprocess_count': 7},
#  'MITOCHONDRIAL DIVISION': {'bioprocess_count': 7},
#  'AUTOPHAGIC CELL DEATH': {'bioprocess_count': 7},
#  'LEUKOTRIENE METABOLIC PROCESS': {'bioprocess_count': 7},
#  'AUTOPHAGY OF MITOCHONDRION': {'bioprocess_count': 7},
#  'ENDOTHELIAL CELL PROLIFERATION': {'bioprocess_count': 7},
#  'FGF RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 7},
#  'PEPTIDYL-THREONINE PHOSPHORYLATION': {'bioprocess_count': 7},
#  'FC GAMMA RECEPTOR-DEPENDENT PHAGOCYTOSIS': {'bioprocess_count': 7},
#  'CELLULAR RESPONSE TO CADMIUM': {'bioprocess_count': 7},
#  'COOPERATIVE BEHAVIOR': {'bioprocess_count': 7},
#  'TRANSCYTOSIS': {'bioprocess_count': 7},
#  'NEGATIVE REGULATION OF ENDOPEPTIDASE ACTIVITY': {'bioprocess_count': 7},
#  'CYTOSKELETAL ORGANIZATION AND BIOGENESIS': {'bioprocess_count': 7},
#  'INTEGRIN ACTIVATION': {'bioprocess_count': 7},
#  'DEVELOPMENTAL GROWTH INVOLVED IN MORPHOGENESIS': {'bioprocess_count': 7},
#  'DEPENDENCE RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 7},
#  'POSITIVE REGULATION OF CHEMOKINE ANABOLISM': {'bioprocess_count': 7},
#  'POSITIVE REGULATION OF CYTOKINE SECRETION': {'bioprocess_count': 7},
#  'ACTIVATION OF ADENYLATE CYCLASE ACTIVITY': {'bioprocess_count': 7},
#  'CELLULAR RESPONSE TO LIPOTEICHOIC ACID': {'bioprocess_count': 7},
#  'GO:0072616': {'bioprocess_count': 7},
#  'LUNG INDUCTION': {'bioprocess_count': 7},
#  'REGULATION OF CELL GROWTH': {'bioprocess_count': 7},
#  'SMOOTH MUSCLE CONTRACTION': {'bioprocess_count': 7},
#  'CACHECTIN SECRETION': {'bioprocess_count': 7},
#  'CARDIAC MUSCLE CONTRACTION': {'bioprocess_count': 7},
#  '6-PHOSPHOFRUCTOKINASE REDUCTION': {'bioprocess_count': 7},
#  'DOWN REGULATION OF PROTEIN CATABOLIC PROCESS': {'bioprocess_count': 7},
#  'IL-1 BETA PRODUCTION': {'bioprocess_count': 7},
#  'KILLER ACTIVITY': {'bioprocess_count': 7},
#  'RESPONSE TO TNF': {'bioprocess_count': 7},
#  'REGULATION OF LOCALISATION': {'bioprocess_count': 7},
#  'VASCULAR ENDOTHELIAL GROWTH FACTOR PRODUCTION': {'bioprocess_count': 7},
#  'DOWN REGULATION OF CASPASE ACTIVITY': {'bioprocess_count': 7},
#  'POSITIVE REGULATION OF NEURON APOPTOTIC PROCESS': {'bioprocess_count': 7},
#  'LYMPH VESSEL FORMATION': {'bioprocess_count': 7},
#  'IL-33 PRODUCTION': {'bioprocess_count': 7},
#  'MRNA MATURATION': {'bioprocess_count': 7},
#  'CELL CYCLE CHECKPOINT': {'bioprocess_count': 7},
#  'IN UTERO EMBRYONIC DEVELOPMENT': {'bioprocess_count': 7},
#  'RESPONSE TO ISCHEMIA': {'bioprocess_count': 7},
#  'INTRASTRAND CROSS-LINK REPAIR': {'bioprocess_count': 7},
#  'DOUBLE-STRAND BREAK REPAIR': {'bioprocess_count': 7},
#  'RESPONSE TO GAMMA RADIATION': {'bioprocess_count': 7},
#  'VASCULAR MORPHOGENESIS': {'bioprocess_count': 7},
#  'FIBROBLAST ACTIVATION': {'bioprocess_count': 7},
#  'GASTRIC EMPTYING': {'bioprocess_count': 7},
#  'COLLAGEN BREAKDOWN': {'bioprocess_count': 7},
#  'EPH RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 7},
#  'GROWTH HORMONE RECEPTOR SIGNALING PATHWAY VIA JAK-STAT': {'bioprocess_count': 7},
#  'LIPID RETENTION': {'bioprocess_count': 7},
#  'PHOSPHATIDYLINOSITOL PHOSPHORYLATION': {'bioprocess_count': 7},
#  'CELLULAR CALCIUM ION HOMEOSTASIS': {'bioprocess_count': 7},
#  'POLLINATION': {'bioprocess_count': 7},
#  'POSITIVE REGULATION OF RAS PROTEIN SIGNAL TRANSDUCTION': {'bioprocess_count': 7},
#  'DEDIFFERENTIATION': {'bioprocess_count': 7},
#  'CELLULAR IRON ION HOMEOSTASIS': {'bioprocess_count': 7},
#  'SEED MATURATION': {'bioprocess_count': 7},
#  'HEAT SHOCK PROTEIN ACTIVITY': {'bioprocess_count': 7},
#  'COMPLEMENT ACTIVATION, CLASSICAL PATHWAY': {'bioprocess_count': 6},
#  'RECEPTOR ANABOLISM': {'bioprocess_count': 6},
#  'GO:0072607': {'bioprocess_count': 6},
#  'DELAYED HYPERSENSITIVITY RESPONSE': {'bioprocess_count': 6},
#  'OLIGODENDROCYTE DIFFERENTIATION': {'bioprocess_count': 6},
#  'RESPONSE TO IL-3': {'bioprocess_count': 6},
#  'GRANULOMA FORMATION': {'bioprocess_count': 6},
#  'T CELL HOMEOSTASIS': {'bioprocess_count': 6},
#  'IL-17A PRODUCTION': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF IL-2 PRODUCTION': {'bioprocess_count': 6},
#  'RESPONSE TO CALCIFEROL': {'bioprocess_count': 6},
#  'DEFENCE RESPONSE TO GRAM-NEGATIVE BACTERIA': {'bioprocess_count': 6},
#  'RESPONSE TO HEAT': {'bioprocess_count': 6},
#  'PROTEIN ADP-RIBOSYLATION': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF LIPID ANABOLISM': {'bioprocess_count': 6},
#  'INTESTINAL ABSORPTION': {'bioprocess_count': 6},
#  'RESPONSE TO GLUCOSE': {'bioprocess_count': 6},
#  'PROTEIN AMINO ACID DEACETYLATION': {'bioprocess_count': 6},
#  'HISTONE DEACETYLATION': {'bioprocess_count': 6},
#  'DOWN REGULATION OF TRANSFORMING GROWTH FACTOR BETA RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 6},
#  'CIRCADIAN REGULATION OF GENE EXPRESSION': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF CASPASE ACTIVITY': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF MAJOR HISTOCOMPATIBILITY COMPLEX CLASS II BIOSYNTHESIS': {'bioprocess_count': 6},
#  'DOWN REGULATION OF FAT CELL DIFFERENTIATION': {'bioprocess_count': 6},
#  'CELLULAR RESPONSE TO HYDROGEN PEROXIDE': {'bioprocess_count': 6},
#  'HISTONE H3 DEACETYLATION': {'bioprocess_count': 6},
#  'MULTICELLULAR ORGANISM DEVELOPMENT': {'bioprocess_count': 6},
#  'ACTIVATION OF P38 CASCADE': {'bioprocess_count': 6},
#  'ACTIVATION OF CREB': {'bioprocess_count': 6},
#  'VASCULAR ENDOTHELIAL GROWTH FACTOR SIGNALING PATHWAY': {'bioprocess_count': 6},
#  'CELLULAR RESPONSE TO AMINO ACID STARVATION': {'bioprocess_count': 6},
#  'RESPONSE TO NICOTINE': {'bioprocess_count': 6},
#  'RESPONSE TO FOOD': {'bioprocess_count': 6},
#  'GO:0072606': {'bioprocess_count': 6},
#  'MICROTUBULE ASSEMBLY': {'bioprocess_count': 6},
#  'SMOOTH MUSCLE CELL MIGRATION': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF MONOCYTE CHEMOTAXIS': {'bioprocess_count': 6},
#  'NEGATIVE REGULATION OF APOPTOSIS OF ENDOTHELIAL CELLS': {'bioprocess_count': 6},
#  'CHEMI-MECHANICAL COUPLING': {'bioprocess_count': 6},
#  'GO:0072610': {'bioprocess_count': 6},
#  'CEREBROSPINAL FLUID SECRETION': {'bioprocess_count': 6},
#  'RESPONSE TO BACTERIA': {'bioprocess_count': 6},
#  'MACROPHAGE CHEMOTAXIS': {'bioprocess_count': 6},
#  'LYMPHOCYTE CHEMOTAXIS': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF NITRIC-OXIDE SYNTHASE BIOSYNTHETIC PROCESS': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF ACTIVATED T CELL PROLIFERATION': {'bioprocess_count': 6},
#  'REGULATION OF REGULATORY T CELL DEVELOPMENT': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF CLASS SWITCH RECOMBINATION TO IGG ISOTYPES': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF ESTABLISHMENT OF PROTEIN LOCALISATION IN PLASMA MEMBRANE': {'bioprocess_count': 6},
#  'AGGRESSION': {'bioprocess_count': 6},
#  'CELL MORPHOGENESIS': {'bioprocess_count': 6},
#  'RAS MEDIATED SIGNAL TRANSDUCTION': {'bioprocess_count': 6},
#  'RESPONSE TO MURAMYL DIPEPTIDE': {'bioprocess_count': 6},
#  'CELLULAR RESPONSE TO VASCULAR ENDOTHELIAL GROWTH FACTOR': {'bioprocess_count': 6},
#  'PROTEIN SORTING ALONG SECRETORY PATHWAY': {'bioprocess_count': 6},
#  'COLLAGEN ANABOLISM': {'bioprocess_count': 6},
#  'GERMINAL CENTER FORMATION': {'bioprocess_count': 6},
#  'RESPONSE TO IL-4': {'bioprocess_count': 6},
#  'HELPER T CELL DIFFERENTIATION': {'bioprocess_count': 6},
#  'PORE BIOSYNTHESIS': {'bioprocess_count': 6},
#  'DOWN REGULATION OF OSTEOCLAST DIFFERENTIATION': {'bioprocess_count': 6},
#  'SPORULATION': {'bioprocess_count': 6},
#  'ESTABLISHMENT OF PROTEIN LOCALISATION': {'bioprocess_count': 6},
#  'DOWN REGULATION OF VIRAL GENOME REPLICATION': {'bioprocess_count': 6},
#  'BONE GROWTH': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF DNA BINDING': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF CELL DIVISION': {'bioprocess_count': 6},
#  'NEGATIVE REGULATION OF REACTIVE OXYGEN SPECIES METABOLIC PROCESS': {'bioprocess_count': 6},
#  'MAST CELL CHEMOTAXIS': {'bioprocess_count': 6},
#  'LYMPHOCYTE ACTIVATION': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF HETEROTYPIC CELL-CELL ADHESION': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF CELL ADHESION': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF VASCULAR ASSOCIATED SMOOTH MUSCLE CELL PROLIFERATION': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF LEUKOCYTE ADHESION TO VASCULAR ENDOTHELIAL CELL': {'bioprocess_count': 6},
#  'EPITHELIAL CELL PROLIFERATION': {'bioprocess_count': 6},
#  'REGULATION OF NATURAL KILLER CELL ACTIVATION': {'bioprocess_count': 6},
#  'REGULATION OF LIPID METABOLIC PROCESS': {'bioprocess_count': 6},
#  'ESTABLISHMENT OF PROTEIN LOCALIZATION TO NUCLEUS': {'bioprocess_count': 6},
#  'ENDOPLASMIC RETICULUM OVERLOAD RESPONSE': {'bioprocess_count': 6},
#  'CELLULAR RESPONSE TO ULTRAVIOLET LIGHT STIMULUS': {'bioprocess_count': 6},
#  'CELLULAR RESPONSE TO GAMMA RADIATION': {'bioprocess_count': 6},
#  'ENDOTHELIAL CELL MIGRATION': {'bioprocess_count': 6},
#  'DEVELOPMENTAL PROCESS': {'bioprocess_count': 6},
#  'REGULATION OF TRANSCRIPTION FROM RNA POLYMERASE II PROMOTER IN RESPONSE TO HYPOXIA': {'bioprocess_count': 6},
#  'EXOSOMAL SECRETION': {'bioprocess_count': 6},
#  'REGULATION OF CELL LOCOMOTION': {'bioprocess_count': 6},
#  'APOPTOSIS OF B CELLS': {'bioprocess_count': 6},
#  'ACTIVATION OF PROTEIN KINASE B ACTIVITY': {'bioprocess_count': 6},
#  'REGULATION OF CELL MIGRATION': {'bioprocess_count': 6},
#  'DOWN REGULATION OF PROTEIN BINDING': {'bioprocess_count': 6},
#  'ACTIN DEPOLYMERIZATION': {'bioprocess_count': 6},
#  'ACTIVATION OF PHOSPHOLIPASE C ACTIVITY': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF PHOSPHORYLATION': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF FIBROBLAST PROLIFERATION': {'bioprocess_count': 6},
#  'CORTISOL SECRETION': {'bioprocess_count': 6},
#  'AUTOCRINE SIGNALING': {'bioprocess_count': 6},
#  'MYELOID CELL DIFFERENTIATION': {'bioprocess_count': 6},
#  'CELLULAR RESPONSE TO TGF-BETA STIMULUS': {'bioprocess_count': 6},
#  'RESPONSE TO AMINO ACID': {'bioprocess_count': 6},
#  'PROTEIN AMINO ACID OXIDATION': {'bioprocess_count': 6},
#  'DOWN REGULATION OF INTERFERON-GAMMA PRODUCTION': {'bioprocess_count': 6},
#  'EXTRACELLULAR MATRIX DISASSEMBLY': {'bioprocess_count': 6},
#  'ANIMAL ORGAN MATURATION': {'bioprocess_count': 6},
#  'BASOPHIL ACTIVATION': {'bioprocess_count': 6},
#  'MITOTIC CELL CYCLE SPINDLE ORIENTATION CHECKPOINT': {'bioprocess_count': 6},
#  'RESPONSE TO MORPHINE': {'bioprocess_count': 6},
#  'OOGENESIS': {'bioprocess_count': 6},
#  'HOMEOSTASIS OF NUMBER OF CELLS WITHIN A TISSUE': {'bioprocess_count': 6},
#  'POSITIVE REGULATION OF CALCIUM ION (CA2+) MOBILIZATION': {'bioprocess_count': 6},
#  'CLATHRIN COATED PIT-DEPENDENT ENDOCYTOSIS': {'bioprocess_count': 6},
#  'PROTEIN DEGRADATION TAGGING ACTIVITY': {'bioprocess_count': 6},
#  'LEVARTERENOL REUPTAKE': {'bioprocess_count': 5},
#  'NEGATIVE REGULATION OF MACROPHAGE DERIVED FOAM CELL DIFFERENTIATION': {'bioprocess_count': 5},
#  'BLOOD PRESSURE REGULATION BY RENIN-ANGIOTENSIN': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF REACTIVE OXYGEN SPECIES METABOLIC PROCESS': {'bioprocess_count': 5},
#  'PLASMACYTOID DENDRITIC CELL ACTIVATION': {'bioprocess_count': 5},
#  'T CELL SELECTION': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF PROTEIN KINASE ACTIVITY': {'bioprocess_count': 5},
#  'REGULATION OF COMPLEMENT ACTIVATION': {'bioprocess_count': 5},
#  'ANDROST-4-ENE-3,17-DIONE ANABOLISM': {'bioprocess_count': 5},
#  'CELLULAR RESPONSE TO STARVATION': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF MACROAUTOPHAGY': {'bioprocess_count': 5},
#  'DOWN REGULATION OF I-KAPPAB KINASE/NF-KAPPAB CASCADE': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF INSULIN RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 5},
#  'RESPONSE TO GROWTH FACTOR': {'bioprocess_count': 5},
#  'LEARNING OR MEMORY': {'bioprocess_count': 5},
#  'REGULATION OF PROTEIN STABILITY': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF PROTEIN ANABOLISM': {'bioprocess_count': 5},
#  'THYMUS DEVELOPMENT': {'bioprocess_count': 5},
#  'REGULATION OF DNA BINDING TRANSCRIPTION FACTOR ACTIVITY': {'bioprocess_count': 5},
#  'OVULATION': {'bioprocess_count': 5},
#  'RESPONSE TO PROGESTERONE': {'bioprocess_count': 5},
#  'RESPONSE TO COCAINE': {'bioprocess_count': 5},
#  "RESPONSE TO 3',5' CAMP": {'bioprocess_count': 5},
#  'RESPONSE TO ELECTRICAL STIMULUS': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF AUTOPHAGY': {'bioprocess_count': 5},
#  'ANTIBODY SECRETION': {'bioprocess_count': 5},
#  'DOWN REGULATION OF EXTRINSIC APOPTOTIC SIGNALING PATHWAY VIA DEATH DOMAIN RECEPTORS': {'bioprocess_count': 5},
#  'CCL2 PRODUCTION': {'bioprocess_count': 5},
#  'B CELL CO-STIMULATION': {'bioprocess_count': 5},
#  'ANIMAL ORGAN MORPHOGENESIS': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF SYNAPTIC TRANSMISSION, GLUTAMATERGIC': {'bioprocess_count': 5},
#  'NEGATIVE REGULATION OF G1/S TRANSITION OF MITOTIC CELL CYCLE': {'bioprocess_count': 5},
#  'GO:0070970': {'bioprocess_count': 5},
#  'DOWN REGULATION OF PROTEIN AMINO ACID PHOSPHORYLATION': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF CTLA-8 PRODUCTION': {'bioprocess_count': 5},
#  'RESPONSE TO ORGANIC SUBSTANCE': {'bioprocess_count': 5},
#  'CELLULAR RESPIRATION': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF OSTEOCLAST DIFFERENTIATION': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF GLYCOLYTIC PROCESS': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF PHAGOCYTOSIS': {'bioprocess_count': 5},
#  'HISTAMINE ANABOLISM': {'bioprocess_count': 5},
#  'FIBROBLAST PROLIFERATION': {'bioprocess_count': 5},
#  'MAST CELL HOMEOSTASIS': {'bioprocess_count': 5},
#  'HETEROTYPIC CELL-CELL ADHESION': {'bioprocess_count': 5},
#  'PHENOTYPIC DIMORPHISM': {'bioprocess_count': 5},
#  'BASOPHIL CELL DIFFERENTIATION': {'bioprocess_count': 5},
#  'EOSINOPHIL CELL DEVELOPMENT': {'bioprocess_count': 5},
#  'HISTONE H3 K4 METHYLATION': {'bioprocess_count': 5},
#  'ANTIBIOTIC SUSCEPTIBILITY/RESISTANCE': {'bioprocess_count': 5},
#  'ABSCISSION': {'bioprocess_count': 5},
#  'DIHYDROGEN SYNTHESIS': {'bioprocess_count': 5},
#  'REGULATION OF MYELINATION': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF OSTEOBLAST DIFFERENTIATION': {'bioprocess_count': 5},
#  'HISTONE METHYLATION': {'bioprocess_count': 5},
#  'RNA REPLICATION': {'bioprocess_count': 5},
#  'EMBRYONIC DIGESTIVE TRACT DEVELOPMENT': {'bioprocess_count': 5},
#  'MEMBRANE DEPOLARIZATION': {'bioprocess_count': 5},
#  'RESPONSE TO GM-CSF': {'bioprocess_count': 5},
#  'RESPONSE TO LIPID': {'bioprocess_count': 5},
#  'RESPONSE TO IONIC OSMOTIC STRESS': {'bioprocess_count': 5},
#  'REGULATION OF TNF SIGNALING': {'bioprocess_count': 5},
#  'REGULATION OF I-KAPPAB KINASE/NF-KAPPAB CASCADE': {'bioprocess_count': 5},
#  'DOWN REGULATION OF PROGRESSION THROUGH MITOTIC CELL CYCLE': {'bioprocess_count': 5},
#  'NITRIC-OXIDE SYNTHASE ACTIVATOR': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF GLIAL CELL PROLIFERATION': {'bioprocess_count': 5},
#  'NEGATIVE REGULATION OF APOPTOTIC SIGNALING PATHWAY': {'bioprocess_count': 5},
#  'GM-CSF PRODUCTION': {'bioprocess_count': 5},
#  'RNA BREAKDOWN': {'bioprocess_count': 5},
#  'DEFECATION BEHAVIOR': {'bioprocess_count': 5},
#  'RNA ANABOLISM': {'bioprocess_count': 5},
#  'RIBOSOME BIOGENESIS': {'bioprocess_count': 5},
#  'RESPONSE TO ELECTROMAGNETIC RADIATION STIMULUS': {'bioprocess_count': 5},
#  'REGULATION OF AUTOPHAGY': {'bioprocess_count': 5},
#  'HAEMATOPOIETIC PROGENITOR CELL DIFFERENTIATION': {'bioprocess_count': 5},
#  'BODY GROWTH': {'bioprocess_count': 5},
#  'HAEMATOPOIETIC STEM CELL DIFFERENTIATION': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF TRANSCRIPTION FROM RNA POLYMERASE II PROMOTER IN RESPONSE TO HYPOXIA': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF CELL CYCLE ARREST': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF INTRINSIC APOPTOTIC PATHWAY': {'bioprocess_count': 5},
#  'XENOBIOTIC METABOLIC PROCESS': {'bioprocess_count': 5},
#  'KIDNEY DEVELOPMENT': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF NEUROBLAST PROLIFERATION': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF MESENCHYMAL CELL PROLIFERATION': {'bioprocess_count': 5},
#  'NERVOUS SYSTEM DEVELOPMENT': {'bioprocess_count': 5},
#  'MAMMARY GLAND ALVEOLUS DEVELOPMENT': {'bioprocess_count': 5},
#  'OOCYTE MATURATION': {'bioprocess_count': 5},
#  'DRUG TRANSPORT': {'bioprocess_count': 5},
#  'ORGAN GROWTH': {'bioprocess_count': 5},
#  'REGULATION OF IMMUNE CELL ACTIVATION': {'bioprocess_count': 5},
#  'PHOSPHORYLATION': {'bioprocess_count': 5},
#  'REGULATION OF MRNA STABILITY': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF GLYCOGEN ANABOLISM': {'bioprocess_count': 5},
#  'NITRIC-OXIDE SYNTHASE REGULATOR': {'bioprocess_count': 5},
#  'ACTIVATION OF PROTEIN LOCALIZATION IN NUCLEUS': {'bioprocess_count': 5},
#  'ERBB2 SIGNALING PATHWAY': {'bioprocess_count': 5},
#  'PEPTIDYL-TYROSINE AUTOPHOSPHORYLATION': {'bioprocess_count': 5},
#  'DOWN REGULATION OF EPIDERMAL GROWTH FACTOR RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF BONE RESORPTION': {'bioprocess_count': 5},
#  'CELLULAR RESPONSE TO E2 STIMULUS': {'bioprocess_count': 5},
#  'DIGESTIVE RUMINATION': {'bioprocess_count': 5},
#  'NEURON PROJECTION DEVELOPMENT': {'bioprocess_count': 5},
#  'RECEPTOR BREAKDOWN': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF PROTEIN SECRETION': {'bioprocess_count': 5},
#  'SMAD PROTEIN SIGNAL TRANSDUCTION': {'bioprocess_count': 5},
#  'OOCYTE GROWTH': {'bioprocess_count': 5},
#  'INTERPHASE': {'bioprocess_count': 5},
#  'AUTOPHAGIC VACUOLE ASSEMBLY': {'bioprocess_count': 5},
#  'REGULATION OF APPETITE': {'bioprocess_count': 5},
#  'STEM CELL DIFFERENTIATION': {'bioprocess_count': 5},
#  'ASTROCYTE DIFFERENTIATION': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF MITOSIS': {'bioprocess_count': 5},
#  'RESPONSE TO FATTY ACID': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF INTERFERON-ALPHA PRODUCTION': {'bioprocess_count': 5},
#  'RESPONSE TO AMYLOID-BETA': {'bioprocess_count': 5},
#  'REGULATION OF BODY GROWTH': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF N SIGNALING PATHWAY': {'bioprocess_count': 5},
#  'DOWN REGULATION OF VASCULAR SMOOTH MUSCLE CELL PROLIFERATION': {'bioprocess_count': 5},
#  'REGULATION OF CIRCADIAN RHYTHM': {'bioprocess_count': 5},
#  'DNA HYPERMETHYLATION': {'bioprocess_count': 5},
#  'STIMULATORY C-TYPE LECTIN RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 5},
#  'POSITIVE REGULATION OF OLIGODENDROCYTE DIFFERENTIATION': {'bioprocess_count': 5},
#  'B CELL HOMEOSTASIS': {'bioprocess_count': 5},
#  'PEPTIDYL-TYROSINE DEPHOSPHORYLATION': {'bioprocess_count': 5},
#  'INTRACELLULAR STEROID HORMONE RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 5},
#  'ACTIN CYTOSKELETON ORGANISATION': {'bioprocess_count': 5},
#  'REGULATION OF ACTIN CYTOSKELETON ORGANISATION': {'bioprocess_count': 5},
#  'FORMATE ANABOLISM': {'bioprocess_count': 5},
#  'DARK ADAPTATION': {'bioprocess_count': 5},
#  'RESPONSE TO NUTRIENT LEVELS': {'bioprocess_count': 5},
#  'SPATIAL LEARNING': {'bioprocess_count': 5},
#  'ACTIN CYTOSKELETON REMODELING': {'bioprocess_count': 5},
#  'NITROGEN FIXATION': {'bioprocess_count': 5},
#  'DOUBLE-STRAND BREAK REPAIR VIA NONHOMOLOGOUS END JOINING': {'bioprocess_count': 5},
#  'RHO MEDIATED SIGNAL TRANSDUCTION': {'bioprocess_count': 5},
#  'VIGS': {'bioprocess_count': 5},
#  'BARR BODY FORMATION': {'bioprocess_count': 5},
#  'APOPTOTIC CELL CLEARANCE': {'bioprocess_count': 5},
#  'IMMUNE SYSTEM PROCESS': {'bioprocess_count': 5},
#  'MICROTUBULE CYTOSKELETON ORGANISATION': {'bioprocess_count': 5},
#  'POLYUBIQUITIN': {'bioprocess_count': 5},
#  'IMMUNE CELL MIGRATION DURING INFLAMMATORY RESPONSE': {'bioprocess_count': 5},
#  'NEGATIVE REGULATION OF LIPID STORAGE': {'bioprocess_count': 4},
#  'REGULATION OF CYTOKINE PRODUCTION': {'bioprocess_count': 4},
#  'BICARBONATE TRANSPORT': {'bioprocess_count': 4},
#  "CELLULAR RESPONSE TO 3',5' CAMP": {'bioprocess_count': 4},
#  'CHLORIDE TRANSMEMBRANE TRANSPORT': {'bioprocess_count': 4},
#  'T CELL CHEMOTAXIS': {'bioprocess_count': 4},
#  'RESPONSE TO IL-6': {'bioprocess_count': 4},
#  'T CELL MEDIATED APOPTOSIS': {'bioprocess_count': 4},
#  'IL-15-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF CALCIUM-MEDIATED SIGNALING': {'bioprocess_count': 4},
#  'REGULATION OF CALCIUM ION TRANSPORT': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO GM-CSF STIMULUS': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO GLUCOSE STIMULUS': {'bioprocess_count': 4},
#  'ASPARTATE TRANSMEMBRANE TRANSPORT': {'bioprocess_count': 4},
#  'AMINO ACID TRANSPORT': {'bioprocess_count': 4},
#  'TRIACYLGLYCEROL METABOLIC PROCESS': {'bioprocess_count': 4},
#  'REGULATION OF METABOLIC PROCESS': {'bioprocess_count': 4},
#  'CHROMATIN SILENCING AT RDNA': {'bioprocess_count': 4},
#  'CHROMATIN MODIFICATION': {'bioprocess_count': 4},
#  'INHIBITION OF NF-KAPPAB TRANSCRIPTION FACTOR': {'bioprocess_count': 4},
#  'DOWN REGULATION OF PHOSPHORYLATION': {'bioprocess_count': 4},
#  'DNA DAMAGE RESPONSE, SIGNAL TRANSDUCTION BY P53 CLASS MEDIATOR RESULTING IN INDUCTION OF APOPTOSIS': {'bioprocess_count': 4},
#  'DOWN REGULATION OF TRANSCRIPTION FACTOR ACTIVITY': {'bioprocess_count': 4},
#  'DOWN REGULATION OF PROTEIN KINASE B SIGNALING CASCADE': {'bioprocess_count': 4},
#  'NEGATIVE REGULATION OF ANDROGEN RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO IONISING RADIATION': {'bioprocess_count': 4},
#  'DOWN REGULATION OF INTRINSIC APOPTOTIC SIGNALING PATHWAY IN RESPONSE TO OXIDATIVE STRESS': {'bioprocess_count': 4},
#  'CELLULAR LOCALISATION': {'bioprocess_count': 4},
#  'PKC SIGNAL TRANSDUCTION': {'bioprocess_count': 4},
#  'DOWN REGULATION OF GROWTH': {'bioprocess_count': 4},
#  'MELANIN ANABOLISM': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF MACROPHAGE CHEMOTAXIS': {'bioprocess_count': 4},
#  'SAPK CASCADE': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF CARDIAC MUSCLE CELL PROLIFERATION': {'bioprocess_count': 4},
#  'GIVING BIRTH': {'bioprocess_count': 4},
#  'RESPONSE TO AMPHETAMINE': {'bioprocess_count': 4},
#  'ATP ANABOLISM': {'bioprocess_count': 4},
#  'DOWN REGULATION OF PROTEOLYSIS': {'bioprocess_count': 4},
#  'PDGF RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'DOWN REGULATION OF CELL MIGRATION': {'bioprocess_count': 4},
#  'NEGATIVE REGULATION OF WOUND HEALING': {'bioprocess_count': 4},
#  'COMPLEMENT RECEPTOR MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'CELLULAR DETOXIFICATION OF SUPEROXIDE RADICALS': {'bioprocess_count': 4},
#  'COLONY STIMULATING FACTOR 3 (GRANULOCYTE) PRODUCTION': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF ACTIN FILAMENT POLYMERIZATION': {'bioprocess_count': 4},
#  'CCL5 PRODUCTION': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO FGF STIMULUS': {'bioprocess_count': 4},
#  'LOCOMOTION': {'bioprocess_count': 4},
#  'IL-2-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF ANTIBODY SECRETION': {'bioprocess_count': 4},
#  'IL-12-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF AMYLOID-BETA FORMATION': {'bioprocess_count': 4},
#  'MITOCHONDRIAL TRANSPORT': {'bioprocess_count': 4},
#  'CHOLESTEROL ESTERIFICATION': {'bioprocess_count': 4},
#  'REGULATION OF CELL DIFFERENTIATION': {'bioprocess_count': 4},
#  'REGULATION OF MAST CELL DIFFERENTIATION': {'bioprocess_count': 4},
#  'DNA DAMAGE CHECKPOINT': {'bioprocess_count': 4},
#  'CHONDROCYTE DIFFERENTIATION': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF ERYTHROCYTE DIFFERENTIATION': {'bioprocess_count': 4},
#  'NEGATIVE REGULATION OF CANONICAL WNT RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'CHEMOKINESIS': {'bioprocess_count': 4},
#  'RESPONSE TO IL-12': {'bioprocess_count': 4},
#  'DOWN REGULATION OF ACUTE INFLAMMATORY RESPONSE': {'bioprocess_count': 4},
#  'T-HELPER 2 CELL CYTOKINE PRODUCTION': {'bioprocess_count': 4},
#  'NEGATIVE REGULATION OF EXTRINSIC APOPTOTIC SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'ACTIVATION OF CYCLIN-DEPENDENT PROTEIN KINASE ACTIVITY': {'bioprocess_count': 4},
#  'STEREOTAXIS': {'bioprocess_count': 4},
#  'CELL-CELL ADHESION INVOLVED IN FLOCCULATION': {'bioprocess_count': 4},
#  'AMYLOID-BETA CLEARANCE': {'bioprocess_count': 4},
#  'ADIPOCYTE CELL DIFFERENTIATION': {'bioprocess_count': 4},
#  'CHROMATIN SILENCING': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO OXIDATIVE STRESS': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO HEPATOCYTE GROWTH FACTOR STIMULUS': {'bioprocess_count': 4},
#  'MUSCLE ATROPHY': {'bioprocess_count': 4},
#  'RESPONSE TO CHITIN': {'bioprocess_count': 4},
#  'ACTIVATION OF PHOSPHOLIPASE A2 ACTIVITY': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF FEVER GENERATION': {'bioprocess_count': 4},
#  'DOWN REGULATION OF BLOOD VESSEL ENDOTHELIAL CELL MIGRATION': {'bioprocess_count': 4},
#  'DOWN REGULATION OF MYOBLAST DIFFERENTIATION': {'bioprocess_count': 4},
#  'DOWN REGULATION OF NEUROGENESIS': {'bioprocess_count': 4},
#  'LEUKOCYTE TETHERING OR ROLLING': {'bioprocess_count': 4},
#  'DOWN REGULATION OF LIPID CATABOLIC PROCESS': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO AMINO ACID': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO NICOTINE': {'bioprocess_count': 4},
#  'NECROPTOSIS SIGNALING': {'bioprocess_count': 4},
#  'DOWN REGULATION OF GENE SILENCING BY MIRNA, PRODUCTION OF MIRNAS': {'bioprocess_count': 4},
#  'RESPONSE TO DOUBLE-STRANDED RNA': {'bioprocess_count': 4},
#  'ACTIVATED T CELL PROLIFERATION': {'bioprocess_count': 4},
#  'NATURAL KILLER CELL DEVELOPMENT': {'bioprocess_count': 4},
#  'C1157563': {'bioprocess_count': 4},
#  'C1157980': {'bioprocess_count': 4},
#  'CELL CYCLE CYTOKINESIS': {'bioprocess_count': 4},
#  'SPHINGOLIPID METABOLIC PROCESS': {'bioprocess_count': 4},
#  'T CELL LINEAGE COMMITMENT': {'bioprocess_count': 4},
#  'DNA DAMAGE RESPONSE, SIGNAL TRANSDUCTION BY P53 CLASS MEDIATOR RESULTING IN TRANSCRIPTION OF P21 CLASS MEDIATOR': {'bioprocess_count': 4},
#  'ACTIVATION OF NECROPTOSIS': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF RELEASE OF CYTOCHROME C FROM MITOCHONDRIA': {'bioprocess_count': 4},
#  'INDUCTION OF APOPTOSIS BY INTRACELLULAR SIGNALS': {'bioprocess_count': 4},
#  'ACTIVATION OF MICRORNA BIOGENESIS': {'bioprocess_count': 4},
#  'MUSCLE HYPERTROPHY': {'bioprocess_count': 4},
#  'INDUCTION OF POSITIVE CHEMOTAXIS': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF CELL MIGRATION INVOLVED IN SPROUTING ANGIOGENESIS': {'bioprocess_count': 4},
#  'INVASIVE FILAMENTOUS GROWTH': {'bioprocess_count': 4},
#  'G2 PHASE': {'bioprocess_count': 4},
#  'PRENYLATION': {'bioprocess_count': 4},
#  'CLATHRIN-INDEPENDENT PINOCYTOSIS': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF CELL CYCLE': {'bioprocess_count': 4},
#  'NITRIC OXIDE ANABOLISM': {'bioprocess_count': 4},
#  'INSULIN RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'DOWN REGULATION OF MACROAUTOPHAGY': {'bioprocess_count': 4},
#  'DOWN REGULATION OF PROTEIN UBIQUITINATION': {'bioprocess_count': 4},
#  'TARGET OF RAPAMYCIN SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'DOWN REGULATION OF CELL SIZE': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF VASOCONSTRICTION': {'bioprocess_count': 4},
#  'IGF RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO EGF STIMULUS': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO OX-LDL PARTICLE STIMULUS': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF G1/S TRANSITION OF MITOTIC CELL CYCLE': {'bioprocess_count': 4},
#  'REGULATION OF ERK CASCADE': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF CANONICAL WNT RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'PARACRINE SIGNALING': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF B CELL ACTIVATION': {'bioprocess_count': 4},
#  'AORTIC VALVE MORPHOGENESIS': {'bioprocess_count': 4},
#  'PHYSIOLOGICAL RESPONSE TO WOUNDING': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF PHOSPHATIDYLINOSITOL 3-KINASE ACTIVITY': {'bioprocess_count': 4},
#  'DOWN REGULATION OF EPITHELIAL CELL PROLIFERATION': {'bioprocess_count': 4},
#  'FATTY ACID TRANSPORT': {'bioprocess_count': 4},
#  'ERYTHROCYTE AGGREGATION': {'bioprocess_count': 4},
#  'MONOAMINE TRANSPORT': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF CELL DIFFERENTIATION': {'bioprocess_count': 4},
#  'REGULATION OF SYNAPTIC PLASTICITY': {'bioprocess_count': 4},
#  'MICTURITION': {'bioprocess_count': 4},
#  'RESPONSE TO VITAMIN E': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO GROWTH FACTOR STIMULUS': {'bioprocess_count': 4},
#  'CELLULAR OXIDANT DETOXIFICATION': {'bioprocess_count': 4},
#  'ACTIVATION OF INNATE IMMUNE RESPONSE': {'bioprocess_count': 4},
#  'I-KAPPAB PHOSPHORYLATION': {'bioprocess_count': 4},
#  'DOWN REGULATION OF ERK1 AND ERK2 CASCADE': {'bioprocess_count': 4},
#  'NEGATIVE REGULATION OF INTRINSIC APOPTOTIC PATHWAY': {'bioprocess_count': 4},
#  'INTRACELLULAR RECEPTOR MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'IL-9-MEDIATED SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'DOWN REGULATION OF GLYCOLYSIS': {'bioprocess_count': 4},
#  'REGULATION OF MITOCHONDRIAL ENVELOPE PERMEABILITY': {'bioprocess_count': 4},
#  'MODULATION OF CHEMICAL SYNAPTIC TRANSMISSION': {'bioprocess_count': 4},
#  'T-HELPER 17 TYPE IMMUNE RESPONSE': {'bioprocess_count': 4},
#  'ANTIBACTERIAL HUMORAL RESPONSE': {'bioprocess_count': 4},
#  'RHYTHM': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO RETINOIC ACID': {'bioprocess_count': 4},
#  'HORMONE SECRETION': {'bioprocess_count': 4},
#  'ALDOSTERONE SECRETION': {'bioprocess_count': 4},
#  'LIPOPROTEIN TRANSPORT': {'bioprocess_count': 4},
#  'PHOSPHATIDYLINOSITOL ANABOLISM': {'bioprocess_count': 4},
#  'HIBERNATION': {'bioprocess_count': 4},
#  'METAPHASE': {'bioprocess_count': 4},
#  'ODONTOGENESIS OF DENTIN-CONTAINING TOOTH': {'bioprocess_count': 4},
#  'RESPONSE TO STEROID HORMONE': {'bioprocess_count': 4},
#  'RETINA HOMEOSTASIS': {'bioprocess_count': 4},
#  'CELL NUCLEUS LOCALIZATION': {'bioprocess_count': 4},
#  'CELLULAR DEFENCE RESPONSE': {'bioprocess_count': 4},
#  'ESTROGEN RECEPTOR SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF SMOOTH MUSCLE CELL MIGRATION': {'bioprocess_count': 4},
#  'CEREBRAL CORTEX DEVELOPMENT': {'bioprocess_count': 4},
#  'SIALYLATION': {'bioprocess_count': 4},
#  'PRE-MRNA SPLICING FACTOR ACTIVITY': {'bioprocess_count': 4},
#  'PHOTOPERIODISM': {'bioprocess_count': 4},
#  'REGULATION OF PHOSPHATIDYLINOSITOL 3-KINASE ACTIVITY': {'bioprocess_count': 4},
#  'RESPONSE TO IMMOBILISATION STRESS': {'bioprocess_count': 4},
#  'RESPONSE TO CORTICOSTERONE': {'bioprocess_count': 4},
#  'RESPONSE TO AXON INJURY': {'bioprocess_count': 4},
#  'CALCIUM ION TRANSPORT': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF T CELL MIGRATION': {'bioprocess_count': 4},
#  'PHAGOCYTOSIS, ENGULFMENT': {'bioprocess_count': 4},
#  'AXON MORPHOGENESIS': {'bioprocess_count': 4},
#  'MAST CELL CYTOKINE PRODUCTION': {'bioprocess_count': 4},
#  'POST-EMBRYONIC DEVELOPMENT': {'bioprocess_count': 4},
#  'POSITIVE REGULATION OF STRESS FIBER ASSEMBLY': {'bioprocess_count': 4},
#  'RIBOSOMAL LARGE SUBUNIT EXPORT FROM CELL NUCLEUS': {'bioprocess_count': 4},
#  'ANIMAL ORGAN REGENERATION': {'bioprocess_count': 4},
#  'CELLULAR RESPONSE TO HEAT': {'bioprocess_count': 4},
#  'BETA-CATENIN-TCF COMPLEX ASSEMBLY': {'bioprocess_count': 4},
#  'HORMONE MEDIATED SIGNALLING': {'bioprocess_count': 4},
#  'KIT SIGNALING PATHWAY': {'bioprocess_count': 4},
#  'EMBRYONIC HAEMATOPOIESIS': {'bioprocess_count': 4},
#  'ECTOPIC GERM CELL PROGRAMMED CELL DEATH': {'bioprocess_count': 4},
#  'BIOFILM FORMATION': {'bioprocess_count': 4},
#  'BLOOD VESSEL REMODELING': {'bioprocess_count': 4},
#  'INFLAMMATORY RESPONSE TO ANTIGENIC STIMULUS': {'bioprocess_count': 4},
#  'ACIDIFICATION': {'bioprocess_count': 4},
#  ...}

# %%
gene_to_pathway_df = pd.DataFrame(gene_to_pathway_results).transpose()
gene_to_bioprocess_df = pd.DataFrame(gene_to_bioprocess_results).transpose()
gene_to_pathway_df.to_csv('COVID_custom_symptoms_gene_to_pathways_2020_09_10.csv', index = True)
gene_to_bioprocess_df.to_csv('COVID_custom_symptoms_gene_to_bioprocesses_2020_09_10.csv', index = True)

# %% [markdown]
# ## Extra / Notes

# %%
BDKRB1 = ht.query('BDKRB1')['Gene'][0]
# df = predict_many([BDKRB1], [])
fc = FindConnection(input_obj=BDKRB1, output_obj='Disease', intermediate_nodes=None)
fc.connect(verbose=False)
df = fc.display_table_view()
print(list(df['output_name']))
# Out:
# ['C0429381', 'C0948249', 'C1457887', 'C0085094', 'C0028778', 'C0277785', 'C0277785', 'C0027651', 'C0699748', 'C1155266', 'C0178264', 'D003921', 'D006930', 'D007249', 'D010146', 'D013163', 'D057772', 'DOID:0050155', 'DOID:60001', 'DOID:0080355', 'DOID:0111745', 'DOID:0080577', 'DOID:0080639', 'DOID:0080747', 'NERVE DEGENERATION', 'NERVE DEGENERATION', 'HEART ATTACK', 'HEART ATTACK', 'ALPS', 'GENERALIZED MULTIPLE SCLEROSIS', 'COMPLICATIONS OF DIABETES MELLITUS', 'CA', 'CA', 'CARDIOVASCULAR DISEASE', 'CARDIOVASCULAR DISEASE', 'DIABETIC KIDNEY DISEASE', 'BLOOD PRESSURE, HIGH', 'BLOOD PRESSURE, HIGH', 'BLOOD PRESSURE, HIGH', 'AUTOIMMUNE BOWEL DISORDER', 'AUTOIMMUNE BOWEL DISORDER', 'TRAUMATIC BRAIN INJURY', 'HYPERALGESIA', 'HYPERALGESIA', 'CHRONIC HEPATITIS C', 'EPILEPSY OF TEMPORAL LOBE', 'EPILEPSY OF TEMPORAL LOBE', 'EPILEPSY OF TEMPORAL LOBE', 'CHRONIC CONGESTIVE SPLENOMEGALY', 'DISORDER INVOLVING PAIN', 'DISORDER INVOLVING PAIN', 'DISORDER INVOLVING PAIN', 'CAD', 'CAD', 'AURA', 'MECHANICAL ALLODYNIA', 'INFLAMMATION', 'SPLENOMEGALY', 'STREPTOZOTOCIN DIABETES', 'VASCULAR SYSTEM INJURIES', 'ALLODYNIA', 'HYPERALGESIA, PRIMARY', 'HYPERALGESIA, SECONDARY', 'TACTILE ALLODYNIA', 'HYPERALGESIA, THERMAL', 'ALLOXAN DIABETES', 'DIABETES MELLITUS, EXPERIMENTAL', 'AUTOSOMAL DOMINANT DISEASE', 'CANCER OF MUSCULOSKELETAL SYSTEM', 'AD', 'FINNISH CONGENITAL NEPHROSIS', 'INDUCED MALARIA', 'BRAIN DEGENERATION', 'ANTEPARTUM SEVERE PRE-ECLAMPSIA', 'DISEASE CAUSED BY PARASITE', 'FUNGAL INFECTION', 'CANCER OF ENDOCRINE GLAND', 'ANXIETY', 'ARTERIAL SCLEROSIS', 'DISEASE OF NOSE', 'BLADDER DISEASE', 'DISEASE OF PROSTATE GLAND', 'ACCRETA, PLACENTA', 'ACUTE PNEUMONIA', 'CONNECTIVE TISSUE DISEASE', 'CHRONIC PERICEMENTITIS', 'ERYTHEMA INFECTIOSUM', 'ACQUIRED CARBOHYDRATE METABOLISM DISEASE', 'CFA', 'PRIMARY BACTERIAL INFECTIOUS DISEASE', 'DEVELOPMENTAL DISORDER OF MENTAL HEALTH', 'DEFICIENCY OF PYRUVATE KINASE', 'ESSENTIAL HYPERTENSION', 'SECONDARY HYPERTENSION', 'EDEMA, PULMONARY', 'CARDIAC DISEASE', 'CARTILAGE DISEASE', 'DISEASE OF MENTAL HEALTH', 'DISEASE OF VASCULATURE', 'CHRONIC AIRFLOW OBSTRUCTION', 'BRAIN INFARCTION OF TELENCEPHALON', 'HYPERGLYCEMIA', 'EDEMA, MACULAR', 'CANCER OF THORACIC SEGMENT OF TRUNK', 'CARDIAC FAILURE CONGESTIVE', 'PULMONARY HYPERTENSION', 'ALPHA SYNUCLEINOPATHIES', 'C1 INHIBITOR DEFICIENCY', 'AUTOIMMUNE DISEASE OF MUSCULOSKELETAL SYSTEM', 'ALLERGIC REACTION', 'CRYPTOCOCCAL MENINGITIS', 'CORONAVIRUS INFECTIOUS DISEASE', 'AGE RELATED MACULAR DEGENERATION', 'DISEASE OF URETER', 'PARALYSIS AGITANS', 'HYPERTENSION, RENOVASCULAR', 'CLUSTER, SYMPTOM', 'DISEASE OF IMMUNE SYSTEM', 'BRONCHIOLITIS', 'ASTROCYTIC NEOPLASM', 'BONE INFLAMMATION DISEASE', 'EXTRINSIC CARDIOMYOPATHY', 'DISEASE OF LIVER', 'AGNOSIA', 'DISEASE OF MALE REPRODUCTIVE SYSTEM', 'CEREBRAL INFARCTION', 'ORDINARY SMALLPOX', 'CONTAGIOUS PUSTULAR DERMATITIS', 'AUTOSOMAL RECESSIVE DISEASE', 'AUTOIMMUNE DISEASE OF CENTRAL NERVOUS SYSTEM', 'CON', 'ALLERGIC FORM OF URTICARIA', 'INFLAMMATION OF KIDNEY', 'ACUTE RESPIRATORY DISTRESS SYNDROME', 'ANGIOEDEMA', 'ATHEROGENESIS', 'DISEASE OF FEMALE GENITAL SYSTEM', 'BO', 'ANEMIA, HEMOLYTIC, CONGENITAL NONSPHEROCYTIC', 'ADENOCARCINOMA', 'COMPLEX REGIONAL PAIN SYNDROME', 'INFECTIONS, MONKEYPOX VIRUS', 'NEUROTOXICITY', 'CANCER OF MALE REPRODUCTIVE ORGAN', 'CONDITION', 'AUTOIMMUNE DISEASE', 'DEMYELINATING POLYNEUROPATHY', 'DISEASE OF EYE', 'CANCER OF COLORECTUM', 'FAMILIAL DISORDER', 'OVERNUTRITION', 'CAA, FAMILIAL', 'INFECTION, VIRAL', 'EMBOLISM, PULMONARY', 'CANCER OF PROSTATE GLAND', 'BACTERIA CAUSED DISEASE OR DISORDER', 'GLUCOSE INTOLERANCE', 'RENAL HYPERTENSION', 'ALLERGIC PURPURA', 'CONNECTIVE AND SOFT TISSUE NEOPLASM', 'COMMON WART', 'FUNGAL MENINGITIS', 'BRONCHIAL DISEASE', 'BLOOD COAGULATION DISEASE', 'ALVEOLAR CELL CARCINOMA', 'DISEASE OF INTEGUMENTAL SYSTEM', 'GLAUCOMA', 'CARCINOMA', 'GLIAL CELL TUMOR', 'CANCER OF DIGESTIVE SYSTEM', 'DEMYELINATING DISEASE', 'DISEASE OF UTERUS', 'ERYTHRASMA', 'BONE MARROW CANCER', 'URETERAL OBSTRU ...

# %%
# Out:
# {'Gene': [{'NCBIGene': '353219',
#    'name': 'kidney associated antigen 1',
#    'SYMBOL': 'KAAG1',
#    'UMLS': 'C1427257',
#    'HGNC': '21031',
#    'UNIPROTKB': 'Q9UBP8',
#    'ENSEMBL': 'ENSG00000146049',
#    'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '353219'},
#    'display': 'NCBIGene(353219) ENSEMBL(ENSG00000146049) HGNC(21031) UMLS(C1427257) UNIPROTKB(Q9UBP8) SYMBOL(KAAG1)',
#    'type': 'Gene'},
#   {'NCBIGene': '5312',
#    'name': 'polycystic kidney disease 3 (autosomal dominant)',
#    'SYMBOL': 'PKD3',
#    'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5312'},
#    'display': 'NCBIGene(5312) SYMBOL(PKD3)',
#    'type': 'Gene'},
#   {'NCBIGene': '8132',
#    'name': 'polycystic kidney disease, infantile severe, with tuberous sclerosis',
#    'SYMBOL': 'PKDTS',
#    'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '8132'},
#    'display': 'NCBIGene(8132) SYMBOL(PKDTS)',
#    'type': 'Gene'}],
#  'SequenceVariant': [],
#  'ChemicalSubstance': [{'DRUGBANK': 'DB10639',
#    'name': 'Kidney bean',
#    'primary': {'identifier': 'DRUGBANK',
#     'cls': 'ChemicalSubstance',
#     'value': 'DB10639'},
#    'display': 'DRUGBANK(DB10639) name(Kidney bean)',
#    'type': 'ChemicalSubstance'},
#   {'CHEMBL.COMPOUND': 'CHEMBL1200797',
#    'name': 'TECHNETIUM TC 99M SUCCIMER',
#    'primary': {'identifier': 'CHEMBL.COMPOUND',
#     'cls': 'ChemicalSubstance',
#     'value': 'CHEMBL1200797'},
#    'display': 'CHEMBL.COMPOUND(CHEMBL1200797) name(TECHNETIUM TC 99M SUCCIMER)',
#    'type': 'ChemicalSubstance'}],
#  'Disease': [{'MONDO': 'MONDO:0021163',
#    'UMLS': 'C0022665',
#    'name': 'kidney neoplasm',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0021163'},
#    'display': 'MONDO(MONDO:0021163) UMLS(C0022665) name(kidney neoplasm)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0003720',
#    'DOID': 'DOID:5982',
#    'UMLS': 'C0238208',
#    'name': 'kidney fibrosarcoma',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0003720'},
#    'display': 'MONDO(MONDO:0003720) DOID(DOID:5982) UMLS(C0238208) name(kidney fibrosarcoma)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0005206',
#    'DOID': 'DOID:4451',
#    'UMLS': 'C1378703',
#    'name': 'renal carcinoma',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0005206'},
#    'display': 'MONDO(MONDO:0005206) DOID(DOID:4451) UMLS(C1378703) name(renal carcinoma)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0005240',
#    'DOID': 'DOID:557',
#    'UMLS': 'C0022658',
#    'name': 'kidney disease',
#    'MESH': 'D007674',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0005240'},
#    'display': 'MONDO(MONDO:0005240) DOID(DOID:557) UMLS(C0022658) MESH(D007674) name(kidney disease)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0001343',
#    'DOID': 'DOID:11705',
#    'name': 'impaired renal function disease',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0001343'},
#    'display': 'MONDO(MONDO:0001343) DOID(DOID:11705) name(impaired renal function disease)',
#    'type': 'Disease'}],
#  'PhenotypicFeature': [{'UMLS': 'C0238207',
#    'HP': 'HP:0000086',
#    'name': 'Ectopic kidney',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0238207'},
#    'display': 'UMLS(C0238207) HP(HP:0000086) name(Ectopic kidney)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C0542519',
#    'HP': 'HP:0000104',
#    'name': 'Renal agenesis',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0542519'},
#    'display': 'UMLS(C0542519) HP(HP:0000104) name(Renal agenesis)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C0341698',
#    'HP': 'HP:0012585',
#    'name': 'Renal atrophy',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0341698'},
#    'display': 'UMLS(C0341698) HP(HP:0012585) name(Renal atrophy)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C0542518',
#    'HP': 'HP:0000105',
#    'name': 'Enlarged kidney',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0542518'},
#    'display': 'UMLS(C0542518) HP(HP:0000105) name(Enlarged kidney)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C0221353',
#    'HP': 'HP:0000085',
#    'MESH': 'D000069337',
#    'name': 'Horseshoe kidney',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0221353'},
#    'display': 'UMLS(C0221353) HP(HP:0000085) MESH(D000069337) name(Horseshoe kidney)',
#    'type': 'PhenotypicFeature'}],
#  'MolecularActivity': [{'GO': 'GO:0008519',
#    'RHEA': 'RHEA:28747',
#    'REACT': 'R-HSA-444393 "RhCG mediates ammonium influx into kidney collecting duct cells"',
#    'name': 'ammonium transmembrane transporter activity',
#    'primary': {'identifier': 'GO',
#     'cls': 'MolecularActivity',
#     'value': 'GO:0008519'},
#    'display': 'GO(GO:0008519) RHEA(RHEA:28747) REACT(R-HSA-444393 "RhCG mediates ammonium influx into kidney collecting duct cells") name(ammonium transmembrane transporter activity)',
#    'type': 'MolecularActivity'},
#   {'GO': 'GO:0015204',
#    'RHEA': 'RHEA:32799',
#    'REACT': 'R-HSA-444126 "HUT2 and HUT11 mediate urea transport in kidney and erythrocytes respectively"',
#    'name': 'urea transmembrane transporter activity',
#    'primary': {'identifier': 'GO',
#     'cls': 'MolecularActivity',
#     'value': 'GO:0015204'},
#    'display': 'GO(GO:0015204) RHEA(RHEA:32799) REACT(R-HSA-444126 "HUT2 and HUT11 mediate urea transport in kidney and erythrocytes respectively") name(urea transmembrane transporter activity)',
#    'type': 'MolecularActivity'},
#   {'GO': 'GO:0015101',
#    'REACT': 'R-HSA-2161500 "abacavir [extracellular] => abacavir [cytosol]"',
#    'name': 'organic cation transmembrane transporter activity',
#    'primary': {'identifier': 'GO',
#     'cls': 'MolecularActivity',
#     'value': 'GO:0015101'},
#    'display': 'GO(GO:0015101) REACT(R-HSA-2161500 "abacavir [extracellular] => abacavir [cytosol]") name(organic cation transmembrane transporter activity)',
#    'type': 'MolecularActivity'}],
#  'BiologicalProcess': [{'GO': 'GO:0072116',
#    'name': 'pronephros formation',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0072116'},
#    'display': 'GO(GO:0072116) name(pronephros formation)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:1901723',
#    'name': 'negative regulation of cell proliferation involved in kidney development',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:1901723'},
#    'display': 'GO(GO:1901723) name(negative regulation of cell proliferation involved in kidney development)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0061289',
#    'name': 'Wnt signaling pathway involved in kidney development',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0061289'},
#    'display': 'GO(GO:0061289) name(Wnt signaling pathway involved in kidney development)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0072118',
#    'name': 'pronephros structural organization',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0072118'},
#    'display': 'GO(GO:0072118) name(pronephros structural organization)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0060993',
#    'name': 'kidney morphogenesis',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0060993'},
#    'display': 'GO(GO:0060993) name(kidney morphogenesis)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0060993',
#    'name': 'kidney morphogenesis',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0060993'},
#    'display': 'GO(GO:0060993) name(kidney morphogenesis)',
#    'type': 'BiologicalProcess'},
#   {'name': 'kidney development',
#    'primary': {'identifier': 'name',
#     'cls': 'BiologicalProcess',
#     'value': 'kidney development'},
#    'display': 'name(kidney development)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0001822',
#    'name': 'kidney development',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0001822'},
#    'display': 'GO(GO:0001822) name(kidney development)',
#    'type': 'BiologicalProcess'},
#   {'name': 'Kidney Concentrating Ability',
#    'primary': {'identifier': 'name',
#     'cls': 'BiologicalProcess',
#     'value': 'Kidney Concentrating Ability'},
#    'display': 'name(Kidney Concentrating Ability)',
#    'type': 'BiologicalProcess'}],
#  'CellularComponent': [],
#  'Pathway': [{'name': 'Kidney Function',
#    'primary': {'identifier': 'name',
#     'cls': 'Pathway',
#     'value': 'Kidney Function'},
#    'display': 'name(Kidney Function)',
#    'type': 'Pathway'}],
#  'AnatomicalEntity': [{'UBERON': 'UBERON:0007132',
#    'name': 'head kidney',
#    'primary': {'identifier': 'UBERON',
#     'cls': 'AnatomicalEntity',
#     'value': 'UBERON:0007132'},
#    'display': 'UBERON(UBERON:0007132) name(head kidney)',
#    'type': 'AnatomicalEntity'},
#   {'UBERON': 'UBERON:0000081',
#    'UMLS': 'C0231049',
#    'name': 'metanephros',
#    'primary': {'identifier': 'UBERON',
#     'cls': 'AnatomicalEntity',
#     'value': 'UBERON:0000081'},
#    'display': 'UBERON(UBERON:0000081) UMLS(C0231049) name(metanephros)',
#    'type': 'AnatomicalEntity'},
#   {'UBERON': 'UBERON:0002113',
#    'UMLS': 'C0022646',
#    'MESH': 'D007668',
#    'name': 'kidney',
#    'primary': {'identifier': 'UBERON',
#     'cls': 'AnatomicalEntity',
#     'value': 'UBERON:0002113'},
#    'display': 'UBERON(UBERON:0002113) UMLS(C0022646) MESH(D007668) name(kidney)',
#    'type': 'AnatomicalEntity'},
#   {'UBERON': 'UBERON:0004819',
#    'name': 'kidney epithelium',
#    'primary': {'identifier': 'UBERON',
#     'cls': 'AnatomicalEntity',
#     'value': 'UBERON:0004819'},
#    'display': 'UBERON(UBERON:0004819) name(kidney epithelium)',
#    'type': 'AnatomicalEntity'},
#   {'UBERON': 'UBERON:0003644',
#    'name': 'kidney arterial blood vessel',
#    'primary': {'identifier': 'UBERON',
#     'cls': 'AnatomicalEntity',
#     'value': 'UBERON:0003644'},
#    'display': 'UBERON(UBERON:0003644) name(kidney arterial blood vessel)',
#    'type': 'AnatomicalEntity'}],
#  'Cell': [{'CL': 'CL:0000650',
#    'name': 'mesangial cell',
#    'primary': {'identifier': 'CL', 'cls': 'Cell', 'value': 'CL:0000650'},
#    'display': 'CL(CL:0000650) name(mesangial cell)',
#    'type': 'Cell'},
#   {'CL': 'CL:0002306',
#    'name': 'epithelial cell of proximal tubule',
#    'primary': {'identifier': 'CL', 'cls': 'Cell', 'value': 'CL:0002306'},
#    'display': 'CL(CL:0002306) name(epithelial cell of proximal tubule)',
#    'type': 'Cell'},
#   {'CL': 'CL:1000494',
#    'name': 'nephron tubule epithelial cell',
#    'primary': {'identifier': 'CL', 'cls': 'Cell', 'value': 'CL:1000494'},
#    'display': 'CL(CL:1000494) name(nephron tubule epithelial cell)',
#    'type': 'Cell'},
#   {'CL': 'CL:0002305',
#    'name': 'epithelial cell of distal tubule',
#    'primary': {'identifier': 'CL', 'cls': 'Cell', 'value': 'CL:0002305'},
#    'display': 'CL(CL:0002305) name(epithelial cell of distal tubule)',
#    'type': 'Cell'},
#   {'CL': 'CL:1000702',
#    'name': 'kidney pelvis smooth muscle cell',
#    'primary': {'identifier': 'CL', 'cls': 'Cell', 'value': 'CL:1000702'},
#    'display': 'CL(CL:1000702) name(kidney pelvis smooth muscle cell)',
#    'type': 'Cell'}]}
