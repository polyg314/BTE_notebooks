# %% [markdown]
# # BTE -- Question #2 -- Use Case Workflow

# %% [markdown]
# ## 0. Uploads, Functions, and Parameters

# %%
# Import pandas and biothings explorers modules
import pandas as pd
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %%
# set list constant that represents every node type available in BTE
ALL_NODE_TYPES = ['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature']

# %%
# predict_many funciton will be used to run many BTE queries and return results as a single table
def predict_many(input_object_list, output_type_list, intermediate_node_list = ''):
    df_list = []
    for input_object in input_object_list: 
        for output_type in output_type_list: 
            if(len(intermediate_node_list) > 0):
                for inter in intermediate_node_list:
                    try: 
                        print("Running: " + input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type )
                        fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        rows = df.shape[0]
                        if(rows > 0):
                            df_list.append(df)
                    except:
                        print(input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type + ' FAILED')
            else:
                try:
                    print("Running: " + input_object['name'] + ' --> output type ' + output_type )
                    fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=None)
                    fc.connect(verbose=False)
                    df = fc.display_table_view()
                    rows = df.shape[0]
                    if(rows > 0):
                        df_list.append(df)
                except:
                    print(input_object['name'] + ' --> output type ' + output_type + ' FAILED')

    if(len(df_list) > 0):
        return pd.concat(df_list)
    else:
        return None

# %%
# max_one_step_genes represents the number of genes returned from direct disease -> gene query 
# that will be included in results. Genes with most occurrences will be included over those with less
max_one_step_genes = 50

# max_two_step_genes represents the number of genes returned from disease -> intermediate node -> gene query 
max_two_step_genes = 200

# set disease name
disease_name = 'severe acute respiratory syndrome'

# set disease output files
disease_csv_file = 'COVID-19_BTE_2020_09_09.csv'
disease_symptoms_csv = 'COVID-19_Symptoms_2020_09_09.csv'
disease_csv_weighted_file = 'COVID-19_BTE_weighted_2020_09_09.csv'

# %% [markdown]
# ## 1. Get Disease Symptoms and Symptom Information

# %% [markdown]
# ### 1.1 Get Disease

# %%
# run hint query to get disease input
disease = ht.query('severe acute respiratory syndrome')['Disease'][0]
print(disease)
# Out:
# {'MONDO': 'MONDO:0005091', 'DOID': 'DOID:2945', 'UMLS': 'C1175175', 'name': 'severe acute respiratory syndrome', 'MESH': 'D045169', 'ORPHANET': '140896', 'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'MONDO:0005091'}, 'display': 'MONDO(MONDO:0005091) DOID(DOID:2945) ORPHANET(140896) UMLS(C1175175) MESH(D045169) name(severe acute respiratory syndrome)', 'type': 'Disease'}

# %% [markdown]
# ### 1.2 Get 'PhenotypicFeatures' Related to Disease

# %%
# get phenotypes (signs and symptoms) related to diesase
fc = FindConnection(input_obj=disease, output_obj='PhenotypicFeature', intermediate_nodes=None)
fc.connect(verbose=False)
disease_to_phenotypicFeature = fc.display_table_view()
disease_to_phenotypicFeature
# Out:
#                                       input input_type       pred1  \
# 0   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 1   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 2   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 3   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 4   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 5   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 6   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 7   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 8   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 9   ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 10  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 11  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 12  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 13  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 14  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 15  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 16  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 17  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 18  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 19  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 20  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 21  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 22  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 23  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 24  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 25  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 26  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 27  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 28  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 29  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 30  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 31  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
#
#    pred1_source           pred1_api pred1_pubmed        output_type  \
# 0          None         BioLink API         None  PhenotypicFeature
# 1           hpo  mydisease.info API         None  PhenotypicFeature
# 2          None         BioLink API         None  PhenotypicFeature
# 3           hpo  mydisease.info API         None  PhenotypicFeature
# 4          None         BioLink API         None  PhenotypicFeature
# 5           hpo  mydisease.info API         None  PhenotypicFeature
# 6          None         BioLink API         None  PhenotypicFeature
# 7           hpo  mydisease.info API         None  PhenotypicFeature
# 8          None         BioLink API         None  PhenotypicFeature
# 9           hpo  mydisease.info API         None  PhenotypicFeature
# 10         None         BioLink API         None  PhenotypicFeature
# 11          hpo  mydisease.info API         None  PhenotypicFeature
# 12         None         BioLink API         None  PhenotypicFeature
# 13          hpo  mydisease.info API         None  PhenotypicFeature
# 14         None         BioLink API         None  PhenotypicFeature
# 15          hpo  mydisease.info API         None  PhenotypicFeature
# 16         None         BioLink API         None  PhenotypicFeature
# 17          hpo  mydisease.info API         None  PhenotypicFeature
# 18         None         BioLink API         None  PhenotypicFeature
# 19          hpo  mydisease.info API         None  PhenotypicFeature
# 20         None         BioLink API         None  PhenotypicFeature
# 21          hpo  mydisease.info API         None  PhenotypicFeature
# 22         None         BioLink API         None  PhenotypicFeature
# 23          hpo  mydisease.info API         None  PhenotypicFeature
# 24         None         BioLink API         None  PhenotypicFeature
# 25          hpo  mydisease.info API         None  PhenotypicFeature
# 26         None         BioLink API         None  PhenotypicFeature
# 27          hpo  mydisease.info API         None  PhenotypicFeature
# 28         None         BioLink API         None  PhenotypicFeature
# 29          hpo  mydisease.info API         None  PhenotypicFeature
# 30         None         BioLink API         None  PhenotypicFeature
# 31          hpo  mydisease.info API         None  PhenotypicFeature
#
#                                           output_name      output_id
# 0                           DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 1                           DECREASED IMMUNE FUNCTION  UMLS:C0021051
# 2                                ABNORMAL TISSUE MASS  UMLS:C0027651
# 3                                ABNORMAL TISSUE MASS  UMLS:C0027651
# 4                                               COUGH  UMLS:C0010200
# 5                                               COUGH  UMLS:C0010200
# 6                                           HYPOXEMIA  UMLS:C0700292
# 7                                           HYPOXEMIA  UMLS:C0700292
# 8                              BREATHING DIFFICULTIES  UMLS:C0476273
# 9                              BREATHING DIFFICULTIES  UMLS:C0476273
# 10                                 ABNORMAL BREATHING  UMLS:C0013404
# 11                                 ABNORMAL BREATHING  UMLS:C0013404
# 12                                  DIABETES MELLITUS  UMLS:C0011849
# 13                                  DIABETES MELLITUS  UMLS:C0011849
# 14           ABNORMALITY OF THE CARDIOVASCULAR SYSTEM  UMLS:C0243050
# 15           ABNORMALITY OF THE CARDIOVASCULAR SYSTEM  UMLS:C0243050
# 16                                              FEVER  UMLS:C0015967
# 17                                              FEVER  UMLS:C0015967
# 18  RESPIRATORY DISTRESS NECESSITATING MECHANICAL ...  UMLS:C4025279
# 19  RESPIRATORY DISTRESS NECESSITATING MECHANICAL ...  UMLS:C4025279
# 20                                        PHARYNGITIS  HP:HP:0025439
# 21                                        PHARYNGITIS  HP:HP:0025439
# 22                                        MUSCLE ACHE  UMLS:C0231528
# 23                                        MUSCLE ACHE  UMLS:C0231528
# 24                               ACUTE KIDNEY FAILURE  UMLS:C0022660
# 25                               ACUTE KIDNEY FAILURE  UMLS:C0022660
# 26                         ACUTE INFECTIOUS PNEUMONIA  UMLS:C4023112
# 27                         ACUTE INFECTIOUS PNEUMONIA  UMLS:C4023112
# 28                               CHRONIC LUNG DISEASE  UMLS:C0746102
# 29                               CHRONIC LUNG DISEASE  UMLS:C0746102
# 30                                           HEADACHE  UMLS:C0018681
# 31                                           HEADACHE  UMLS:C0018681

# %%
# Print equivalent names for the disease input
print('Note: all equivalent names for the disease input are as follows:')
for name in fc.fc.display_node_info(disease_name)['equivalent_ids']['name']: print(name)
# Out:
# Note: all equivalent names for the disease input are as follows:
# ACUTE RESPIRATORY CORONAVIRUS INFECTION
# SARS
# SARS CORONAVIRUS CAUSED DISEASE OR DISORDER
# SARS CORONAVIRUS DISEASE OR DISORDER
# SARS CORONAVIRUS INFECTIOUS DISEASE
# SARS-COV INFECTION
# SEVERE ACUTE RESPIRATORY SYNDROME

# %%
# create dictionary of symptom HPIDs, nad symptom names (with synonyms)
symptom_dict = {}
for index, row in disease_to_phenotypicFeature.iterrows():
    output_name = disease_to_phenotypicFeature['output_name'][index]
    items = fc.fc.G[disease_name][output_name].values()
    for item in items: 
#         print(item)
        if('frequency' in item['info']):
            freq = [_item['info']['frequency'] for _item in fc.fc.G[disease_name][output_name].values() if "frequency" in _item["info"]][0][0]
            freq_value = ht.query(freq)['PhenotypicFeature'][0]['name']
        else: 
            freq_value = 'Unknown'
                    
        symptom_dict[fc.fc.display_node_info(output_name)['equivalent_ids']['HP'][0]] = {
            "names": fc.fc.display_node_info(output_name)['equivalent_ids']['name'],
            "frequency": freq_value,
        }
# print(symptom_dict)
symptom_dict
# Out:
# {'HP:0002721': {'names': ['DECREASED IMMUNE FUNCTION',
#    'IMMUNE DEFICIENCY',
#    'IMMUNODEFICIENCY'],
#   'frequency': 'Frequent'},
#  'HP:0002664': {'names': ['ABNORMAL TISSUE MASS',
#    'CANCER',
#    'NEOPLASIA',
#    'NEOPLASM',
#    'ONCOLOGICAL ABNORMALITY',
#    'ONCOLOGY',
#    'TUMOR',
#    'TUMOUR'],
#   'frequency': 'Occasional'},
#  'HP:0012735': {'names': ['COUGH', 'COUGHING'], 'frequency': 'Very frequent'},
#  'HP:0012418': {'names': ['HYPOXEMIA', 'HYPOXIA', 'LOW BLOOD OXYGEN LEVEL'],
#   'frequency': 'Occasional'},
#  'HP:0002098': {'names': ['BREATHING DIFFICULTIES',
#    'DIFFICULTY BREATHING',
#    'RESPIRATORY DIFFICULTIES',
#    'RESPIRATORY DISTRESS',
#    'SHORT OF BREATH',
#    'SHORTNESS OF BREATH'],
#   'frequency': 'Frequent'},
#  'HP:0002094': {'names': ['ABNORMAL BREATHING',
#    'BREATHING DIFFICULTY',
#    'DIFFICULT TO BREATHE',
#    'DYSPNEA',
#    'DYSPNOEA',
#    'TROUBLE BREATHING'],
#   'frequency': 'Frequent'},
#  'HP:0000819': {'names': ['DIABETES MELLITUS'], 'frequency': 'Occasional'},
#  'HP:0001626': {'names': ['ABNORMALITY OF THE CARDIOVASCULAR SYSTEM',
#    'CARDIOVASCULAR ABNORMALITY',
#    'CARDIOVASCULAR DISEASE'],
#   'frequency': 'Occasional'},
#  'HP:0001945': {'names': ['FEVER', 'HYPERTHERMIA', 'PYREXIA'],
#   'frequency': 'Frequent'},
#  'HP:0004887': {'names': ['RESPIRATORY DISTRESS NECESSITATING MECHANICAL VENTILATION',
#    'RESPIRATORY DISTRESS REQUIRING ENDOTRACHEAL INTUBATION',
#    'RESPIRATORY DISTRESS REQUIRING MECHANICAL VENTILATION',
#    'RESPIRATORY FAILURE REQUIRING ASSISTED VENTILATION'],
#   'frequency': 'Occasional'},
#  'HP:0025439': {'names': ['PHARYNGITIS'], 'frequency': 'Occasional'},
#  'HP:0003326': {'names': ['MUSCLE ACHE', 'MUSCLE PAIN', 'MYALGIA', 'MYALGIAS'],
#   'frequency': 'Frequent'},
#  'HP:0001919': {'names': ['ACUTE KIDNEY FAILURE',
#    'ACUTE KIDNEY INJURY',
#    'ACUTE RENAL FAILURE'],
#   'frequency': 'Very rare'},
#  'HP:0011949': {'names': ['ACUTE INFECTIOUS PNEUMONIA'],
#   'frequency': 'Occasional'},
#  'HP:0006528': {'names': ['CHRONIC LUNG DISEASE'], 'frequency': 'Occasional'},
#  'HP:0002315': {'names': ['HEADACHE', 'HEADACHES'], 'frequency': 'Frequent'}}

# %%
bc = ht.query('Blood clotting')['PhenotypicFeature'][0]
# print(bc)
# cs = ht.query('cytokine storm')['PhenotypicFeature'][0]
# print(cs)

symptom_dict[bc['HP']] = { 'names' : [bc['name'].upper()], 'frequency': 'Unknown'} # need to get synonyms
# symptom_dict[cs['HP']] = { 'names' : [cs['name'].upper()], 'frequency': 'Unknown'}
symptom_dict
# ht.query(bc['HP'])['PhenotypicFeature']
# Out:
# {'HP:0002721': {'names': ['DECREASED IMMUNE FUNCTION',
#    'IMMUNE DEFICIENCY',
#    'IMMUNODEFICIENCY'],
#   'frequency': 'Frequent'},
#  'HP:0002664': {'names': ['ABNORMAL TISSUE MASS',
#    'CANCER',
#    'NEOPLASIA',
#    'NEOPLASM',
#    'ONCOLOGICAL ABNORMALITY',
#    'ONCOLOGY',
#    'TUMOR',
#    'TUMOUR'],
#   'frequency': 'Occasional'},
#  'HP:0012735': {'names': ['COUGH', 'COUGHING'], 'frequency': 'Very frequent'},
#  'HP:0012418': {'names': ['HYPOXEMIA', 'HYPOXIA', 'LOW BLOOD OXYGEN LEVEL'],
#   'frequency': 'Occasional'},
#  'HP:0002098': {'names': ['BREATHING DIFFICULTIES',
#    'DIFFICULTY BREATHING',
#    'RESPIRATORY DIFFICULTIES',
#    'RESPIRATORY DISTRESS',
#    'SHORT OF BREATH',
#    'SHORTNESS OF BREATH'],
#   'frequency': 'Frequent'},
#  'HP:0002094': {'names': ['ABNORMAL BREATHING',
#    'BREATHING DIFFICULTY',
#    'DIFFICULT TO BREATHE',
#    'DYSPNEA',
#    'DYSPNOEA',
#    'TROUBLE BREATHING'],
#   'frequency': 'Frequent'},
#  'HP:0000819': {'names': ['DIABETES MELLITUS'], 'frequency': 'Occasional'},
#  'HP:0001626': {'names': ['ABNORMALITY OF THE CARDIOVASCULAR SYSTEM',
#    'CARDIOVASCULAR ABNORMALITY',
#    'CARDIOVASCULAR DISEASE'],
#   'frequency': 'Occasional'},
#  'HP:0001945': {'names': ['FEVER', 'HYPERTHERMIA', 'PYREXIA'],
#   'frequency': 'Frequent'},
#  'HP:0004887': {'names': ['RESPIRATORY DISTRESS NECESSITATING MECHANICAL VENTILATION',
#    'RESPIRATORY DISTRESS REQUIRING ENDOTRACHEAL INTUBATION',
#    'RESPIRATORY DISTRESS REQUIRING MECHANICAL VENTILATION',
#    'RESPIRATORY FAILURE REQUIRING ASSISTED VENTILATION'],
#   'frequency': 'Occasional'},
#  'HP:0025439': {'names': ['PHARYNGITIS'], 'frequency': 'Occasional'},
#  'HP:0003326': {'names': ['MUSCLE ACHE', 'MUSCLE PAIN', 'MYALGIA', 'MYALGIAS'],
#   'frequency': 'Frequent'},
#  'HP:0001919': {'names': ['ACUTE KIDNEY FAILURE',
#    'ACUTE KIDNEY INJURY',
#    'ACUTE RENAL FAILURE'],
#   'frequency': 'Very rare'},
#  'HP:0011949': {'names': ['ACUTE INFECTIOUS PNEUMONIA'],
#   'frequency': 'Occasional'},
#  'HP:0006528': {'names': ['CHRONIC LUNG DISEASE'], 'frequency': 'Occasional'},
#  'HP:0002315': {'names': ['HEADACHE', 'HEADACHES'], 'frequency': 'Frequent'},
#  'HP:0001977': {'names': ['ABNORMAL THROMBOSIS'], 'frequency': 'Unknown'}}

# %%
# create list of HPIDs and Symptoms for later use
disease_symptom_hpids = list(symptom_dict.keys())
disease_symptoms = []
for entry in list(symptom_dict.values()): disease_symptoms = disease_symptoms + entry['names']


# create dict of HPIDs : symptoms for use in assembling final results
symptom_to_hpid_dict = {}
for key,value in symptom_dict.items(): 
    for name in value['names']:
        symptom_to_hpid_dict[name] = key

# %%
# add "edges out" counts from each phenotype to any node type, to get a rough estimate of how prevalent a phenotype is
phenotype_inputs = []
for hpid in disease_symptom_hpids: 
    try: 
        phenotype_input = ht.query(hpid)['PhenotypicFeature'][0]
        all_edges_out_df = predict_many([phenotype_input], ALL_NODE_TYPES)
        symptom_dict[hpid]['edges_out_count'] = all_edges_out_df.shape[0]
    except: 
        print(hpid + ' Failed')

print(symptom_dict)
# Out:
# Running: Immunodeficiency --> output type Gene
# Running: Immunodeficiency --> output type SequenceVariant
# Running: Immunodeficiency --> output type ChemicalSubstance
# Running: Immunodeficiency --> output type Disease
# Running: Immunodeficiency --> output type MolecularActivity
# Running: Immunodeficiency --> output type BiologicalProcess
# Running: Immunodeficiency --> output type CellularComponent
# Running: Immunodeficiency --> output type Pathway
# Running: Immunodeficiency --> output type AnatomicalEntity
# Running: Immunodeficiency --> output type PhenotypicFeature
# Running: Neoplasm --> output type Gene
# Running: Neoplasm --> output type SequenceVariant
# Running: Neoplasm --> output type ChemicalSubstance
# Running: Neoplasm --> output type Disease
# Running: Neoplasm --> output type MolecularActivity
# Running: Neoplasm --> output type BiologicalProcess
# Running: Neoplasm --> output type CellularComponent
# Running: Neoplasm --> output type Pathway
# Running: Neoplasm --> output type AnatomicalEntity
# Running: Neoplasm --> output type PhenotypicFeature
# Running: Cough --> output type Gene
# Running: Cough --> output type SequenceVariant
# Running: Cough --> output type ChemicalSubstance
# Running: Cough --> output type Disease
# Running: Cough --> output type MolecularActivity
# Running: Cough --> output type BiologicalProcess
# Running: Cough --> output type CellularComponent
# Running: Cough --> output type Pathway
# Running: Cough --> output type AnatomicalEntity
# Running: Cough --> output type PhenotypicFeature
# Running: Hypoxemia --> output type Gene
# Running: Hypoxemia --> output type SequenceVariant
# Running: Hypoxemia --> output type ChemicalSubstance
# Running: Hypoxemia --> output type Disease
# Running: Hypoxemia --> output type MolecularActivity
# Running: Hypoxemia --> output type BiologicalProcess
# Running: Hypoxemia --> output type CellularComponent
# Running: Hypoxemia --> output type Pathway
# Running: Hypoxemia --> output type AnatomicalEntity
# Running: Hypoxemia --> output type PhenotypicFeature
# Running: Respiratory distress --> output type Gene
# Running: Respiratory distress --> output type SequenceVariant
# Running: Respiratory distress --> output type ChemicalSubstance
# Running: Respiratory distress --> output type Disease
# Running: Respiratory distress --> output type MolecularActivity
# Running: Respiratory distress --> output type BiologicalProcess
# Running: Respiratory distress --> output type CellularComponent
# Running: Respiratory distress --> output type Pathway
# Running: Respiratory distress --> output type AnatomicalEntity
# Running: Respiratory distress --> output type PhenotypicFeature
# Running: Dyspnea --> output type Gene
# Running: Dyspnea --> output type SequenceVariant
# Running: Dyspnea --> output type ChemicalSubstance
# Running: Dyspnea --> output type Disease
# Running: Dyspnea --> output type MolecularActivity
# Running: Dyspnea --> output type BiologicalProcess
# Running: Dyspnea --> output type CellularComponent
# Running: Dyspnea --> output type Pathway
# Running: Dyspnea --> output type AnatomicalEntity
# Running: Dyspnea --> output type PhenotypicFeature
# Running: Diabetes mellitus --> output type Gene
# Running: Diabetes mellitus --> output type SequenceVariant
# Running: Diabetes mellitus --> output type ChemicalSubstance
# Running: Diabetes mellitus --> output type Disease
# Running: Diabetes mellitus --> output type MolecularActivity
# Running: Diabetes mellitus --> output type BiologicalProcess
# Running: Diabetes mellitus --> output type CellularComponent
# Running: Diabetes mellitus --> output type Pathway
# Running: Diabetes mellitus --> output type AnatomicalEntity
# Running: Diabetes mellitus --> output type PhenotypicFeature
# Running: Abnormality of the cardiovascular system --> output type Gene
# Running: Abnormality of the cardiovascular system --> output type SequenceVariant
# Running: Abnormality of the cardiovascular system --> output type ChemicalSubstance
# Running: Abnormality of the cardiovascular system --> output type Disease
# Running: Abnormality of the cardiovascular system --> output type MolecularActivity
# Running: Abnormality of the cardiovascular system --> output type BiologicalProcess
# Running: Abnormality of the cardiovascular system --> output type CellularComponent
# Running: Abnormality of the cardiovascular system --> output type Pathway
# Running: Abnormality of the cardiovascular system --> output type AnatomicalEntity
# Running: Abnormality of the cardiovascular system --> output type PhenotypicFeature
# Running: Fever --> output type Gene
# Running: Fever --> output type SequenceVariant
# Running: Fever --> output type ChemicalSubstance
# Running: Fever --> output type Disease
# Running: Fever --> output type MolecularActivity
# Running: Fever --> output type BiologicalProcess
# Running: Fever --> output type CellularComponent
# Running: Fever --> output type Pathway
# Running: Fever --> output type AnatomicalEntity
# Running: Fever --> output type PhenotypicFeature
# Running: Respiratory failure requiring assisted ventilation --> output type Gene
# Running: Respiratory failure requiring assisted ventilation --> output type SequenceVariant
# Running: Respiratory failure requiring assisted ventilation --> output type ChemicalSubstance
# Running: Respiratory failure requiring assisted ventilation --> output type Disease
# Running: Respiratory failure requiring assisted ventilation --> output type MolecularActivity
# Running: Respiratory failure requiring assisted ventilation --> output type BiologicalProcess
# Running: Respiratory failure requiring assisted ventilation --> output type CellularComponent
# Running: Respiratory failure requiring assisted ventilation --> output type Pathway
# Running: Respiratory failure requiring assisted ventilation --> output type AnatomicalEntity
# Running: Respiratory failure requiring assisted ventilation --> output type PhenotypicFeature
# Running: Pharyngitis --> output type Gene
# Running: Pharyngitis --> output type SequenceVariant
# Running: Pharyngitis --> output type ChemicalSubstance
# Running: Pharyngitis --> output type Disease
# Running: Pharyngitis --> output type MolecularActivity
# Running: Pharyngitis --> output type BiologicalProcess
# Running: Pharyngitis --> output type CellularComponent
# Running: Pharyngitis --> output type Pathway
# Running: Pharyngitis --> output type AnatomicalEntity
# Running: Pharyngitis --> output type PhenotypicFeature
# Running: Myalgia --> output type Gene
# Running: Myalgia --> output type SequenceVariant
# Running: Myalgia --> output type ChemicalSubstance
# Running: Myalgia --> output type Disease
# Running: Myalgia --> output type MolecularActivity
# Running: Myalgia --> output type BiologicalProcess
# Running: Myalgia --> output type CellularComponent
# Running: Myalgia --> output type Pathway
# Running: Myalgia --> output type AnatomicalEntity
# Running: Myalgia --> output type PhenotypicFeature
# Running: Acute kidney injury --> output type Gene
# Running: Acute kidney injury --> output type SequenceVariant
# Running: Acute kidney injury --> output type ChemicalSubstance
# Running: Acute kidney injury --> output type Disease
# Running: Acute kidney injury --> output type MolecularActivity
# Running: Acute kidney injury --> output type BiologicalProcess
# Running: Acute kidney injury --> output type CellularComponent
# Running: Acute kidney injury --> output type Pathway
# Running: Acute kidney injury --> output type AnatomicalEntity
# Running: Acute kidney injury --> output type PhenotypicFeature
# Running: Acute infectious pneumonia --> output type Gene
# Running: Acute infectious pneumonia --> output type SequenceVariant
# Running: Acute infectious pneumonia --> output type ChemicalSubstance
# Running: Acute infectious pneumonia --> output type Disease
# Running: Acute infectious pneumonia --> output type MolecularActivity
# Running: Acute infectious pneumonia --> output type BiologicalProcess
# Running: Acute infectious pneumonia --> output type CellularComponent
# Running: Acute infectious pneumonia --> output type Pathway
# Running: Acute infectious pneumonia --> output type AnatomicalEntity
# Running: Acute infectious pneumonia --> output type PhenotypicFeature
# Running: Chronic lung disease --> output type Gene
# Running: Chronic lung disease --> output type SequenceVariant
# Running: Chronic lung disease --> output type ChemicalSubstance
# Running: Chronic lung disease --> output type Disease
# Running: Chronic lung disease --> output type MolecularActivity
# Running: Chronic lung disease --> output type BiologicalProcess
# Running: Chronic lung disease --> output type CellularComponent
# Running: Chronic lung disease --> output type Pathway
# Running: Chronic lung disease --> output type AnatomicalEntity
# Running: Chronic lung disease --> output type PhenotypicFeature
# Running: Headache --> output type Gene
# Running: Headache --> output type SequenceVariant
# Running: Headache --> output type ChemicalSubstance
# Running: Headache --> output type Disease
# Running: Headache --> output type MolecularActivity
# Running: Headache --> output type BiologicalProcess
# Running: Headache --> output type CellularComponent
# Running: Headache --> output type Pathway
# Running: Headache --> output type AnatomicalEntity
# Running: Headache --> output type PhenotypicFeature
# Running: Abnormal thrombosis --> output type Gene
# Running: Abnormal thrombosis --> output type SequenceVariant
# Running: Abnormal thrombosis --> output type ChemicalSubstance
# Running: Abnormal thrombosis --> output type Disease
# Running: Abnormal thrombosis --> output type MolecularActivity
# Running: Abnormal thrombosis --> output type BiologicalProcess
# Running: Abnormal thrombosis --> output type CellularComponent
# Running: Abnormal thrombosis --> output type Pathway
# Running: Abnormal thrombosis --> output type AnatomicalEntity
# Running: Abnormal thrombosis --> output type PhenotypicFeature
# {'HP:0002721': {'names': ['DECREASED IMMUNE FUNCTION', 'IMMUNE DEFICIENCY', 'IMMUNODEFICIENCY'], 'frequency': 'Frequent', 'edges_out_count': 444}, 'HP:0002664': {'names': ['ABNORMAL TISSUE MASS', 'CANCER', 'NEOPLASIA', 'NEOPLASM', 'ONCOLOGICAL ABNORMALITY', 'ONCOLOGY', 'TUMOR', 'TUMOUR'], 'frequency': 'Occasional', 'edges_out_count': 516}, 'HP:0012735': {'names': ['COUGH', 'COUGHING'], 'frequency': 'Very frequent', 'edges_out_count': 254}, 'HP:0012418': {'names': ['HYPOXEMIA', 'HYPOXIA', 'LOW BLOOD OXYGEN LEVEL'], 'frequency': 'Occasional', 'edges_out_count': 42}, 'HP:0002098': {'names': ['BREATHING DIFFICULTIES', 'DIFFICULTY BREATHING', 'RESPIRATORY DIFFICULTIES', 'RESPIRATORY DISTRESS', 'SHORT OF BREATH', 'SHORTNESS OF BREATH'], 'frequency': 'Frequent', 'edges_out_count': 970}, 'HP:0002094': {'names': ['ABNORMAL BREATHING', 'BREATHING DIFFICULTY', 'DIFFICULT TO BREATHE', 'DYSPNEA', 'DYSPNOEA', 'TROUBLE BREATHING'], 'frequency': 'Frequent', 'edges_out_count': 970}, 'HP:0000819': {'names': ['DIABETES MELLITUS'], 'frequency': 'Occasional', 'edges_out_count': 442}, 'HP:0001626': {'names': ['ABNORMALITY OF THE CARDIOVASCULAR SYSTEM', 'CARDIOVASCULAR ABNORMALITY', 'CARDIOVASCULAR DISEASE'], 'frequency': 'Occasional', 'edges_out_count': 152}, 'HP:0001945': {'names': ['FEVER', 'HYPERTHERMIA', 'PYREXIA'], 'frequency': 'Frequent', 'edges_out_count': 467}, 'HP:0004887': {'names': ['RESPIRATORY DISTRESS NECESSITATING MECHANICAL VENTILATION', 'RESPIRATORY DISTRESS REQUIRING ENDOTRACHEAL INTUBATION', 'RESPIRATORY DISTRESS REQUIRING MECHANICAL VENTILATION', 'RESPIRATORY FAILURE REQUIRING ASSISTED VENTILATION'], 'frequency': 'Occasional', 'edges_out_count': 37}, 'HP:0025439': {'names': ['PHARYNGITIS'], 'frequency': 'Occasional', 'edges_out_count': 16}, 'HP:0003326': {'names': ['MUSCLE ACHE', 'MUSCLE PAIN', 'MYALGIA', 'MYALGIAS'], 'frequency': 'Frequent', 'edges_out_count': 346}, 'HP:0001919': {'names': ['ACUTE KIDNEY FAILURE', 'ACUTE KIDNEY INJURY', 'ACUTE RENAL FAILURE'], 'frequency': 'Very rare', 'edges_out_count': 64}, 'HP:0011949': {'names': ['ACUTE INFECTIOUS PNEUMONIA'], 'frequency': 'Occasional', 'edges_out_count': 11}, 'HP:0006528': {'names': ['CHRONIC LUNG DISEASE'], 'frequency': 'Occasional', 'edges_out_count': 54}, 'HP:0002315': {'names': ['HEADACHE', 'HEADACHES'], 'frequency': 'Frequent', 'edges_out_count': 411}, 'HP:0001977': {'names': ['ABNORMAL THROMBOSIS'], 'frequency': 'Unknown', 'edges_out_count': 52}}

# %%
# convert symptom dictionary to dataframe and sort by edges out and frequency 
disease_symptom_df = pd.DataFrame.from_dict(symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptom_df = pd.concat([disease_symptom_df[disease_symptom_df["frequency"] == "Very frequent"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Frequent"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Occasional"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Rare"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Unknown"]
              ])
disease_symptom_df
# Out:
#                                                         names      frequency  \
# HP:0012735                                  [COUGH, COUGHING]  Very frequent
# HP:0003326      [MUSCLE ACHE, MUSCLE PAIN, MYALGIA, MYALGIAS]       Frequent
# HP:0002315                              [HEADACHE, HEADACHES]       Frequent
# HP:0002721  [DECREASED IMMUNE FUNCTION, IMMUNE DEFICIENCY,...       Frequent
# HP:0001945                     [FEVER, HYPERTHERMIA, PYREXIA]       Frequent
# HP:0002098  [BREATHING DIFFICULTIES, DIFFICULTY BREATHING,...       Frequent
# HP:0002094  [ABNORMAL BREATHING, BREATHING DIFFICULTY, DIF...       Frequent
# HP:0011949                       [ACUTE INFECTIOUS PNEUMONIA]     Occasional
# HP:0025439                                      [PHARYNGITIS]     Occasional
# HP:0004887  [RESPIRATORY DISTRESS NECESSITATING MECHANICAL...     Occasional
# HP:0012418       [HYPOXEMIA, HYPOXIA, LOW BLOOD OXYGEN LEVEL]     Occasional
# HP:0006528                             [CHRONIC LUNG DISEASE]     Occasional
# HP:0001626  [ABNORMALITY OF THE CARDIOVASCULAR SYSTEM, CAR...     Occasional
# HP:0000819                                [DIABETES MELLITUS]     Occasional
# HP:0002664  [ABNORMAL TISSUE MASS, CANCER, NEOPLASIA, NEOP...     Occasional
# HP:0001977                              [ABNORMAL THROMBOSIS]        Unknown
#
#             edges_out_count
# HP:0012735              254
# HP:0003326              346
# HP:0002315              411
# HP:0002721              444
# HP:0001945              467
# HP:0002098              970
# HP:0002094              970
# HP:0011949               11
# HP:0025439               16
# HP:0004887               37
# HP:0012418               42
# HP:0006528               54
# HP:0001626              152
# HP:0000819              442
# HP:0002664              516
# HP:0001977               52

# %%
disease_symptom_df.to_csv(disease_symptoms_csv, index = True)

# %% [markdown]
# ## 2. Get Genes Directly Related to Disease

# %%
# find genes directly related to disease
fc = FindConnection(input_obj=disease, output_obj='Gene', intermediate_nodes=None)
fc.connect(verbose=False)
disease_to_genes = fc.display_table_view()
disease_to_genes = disease_to_genes[~disease_to_genes['output_id'].str.contains('UMLS')]
disease_to_genes
# Out:
#                                         input input_type       pred1  \
# 0     ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 1     ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 2     ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 3     ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 4     ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# ...                                       ...        ...         ...
# 1499  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 1500  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 1501  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 1502  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
# 1503  ACUTE RESPIRATORY CORONAVIRUS INFECTION    Disease  related_to
#
#      pred1_source                   pred1_api pred1_pubmed output_type  \
# 0         DISEASE                DISEASES API         None        Gene
# 1         DISEASE                DISEASES API         None        Gene
# 2         DISEASE                DISEASES API         None        Gene
# 3         DISEASE                DISEASES API         None        Gene
# 4         DISEASE                DISEASES API         None        Gene
# ...           ...                         ...          ...         ...
# 1499      scibite  Automat CORD19 Scibite API         None        Gene
# 1500      scibite  Automat CORD19 Scibite API         None        Gene
# 1501      scibite  Automat CORD19 Scibite API         None        Gene
# 1502      scibite  Automat CORD19 Scibite API         None        Gene
# 1503      scibite  Automat CORD19 Scibite API         None        Gene
#
#      output_name           output_id
# 0       18S_rRNA     SYMBOL:18S_rRNA
# 1       28S_rRNA     SYMBOL:28S_rRNA
# 2          BISPR  NCBIGene:105221694
# 3          DALIR  NCBIGene:104940698
# 4       DLG2-AS1  NCBIGene:100302690
# ...          ...                 ...
# 1499       CAPN2        NCBIGene:824
# 1500       AGBL1     NCBIGene:123624
# 1501        RTN2       NCBIGene:6253
# 1502      NPIPB3      NCBIGene:23117
# 1503      RASSF7       NCBIGene:8045
#
# [1409 rows x 9 columns]

# %%
# create dictionary of gene reults whereby each Gene has values for the number of occurrences of the gene in results
# and the number of publications connecting the disease -> gene directly
disease_to_gene_results = {}
disease_to_gene_genes = list(disease_to_genes["output_name"]) # create list of genes
disease_to_gene_genes = list(dict.fromkeys(disease_to_gene_genes))  # remove duplicates

for gene in disease_to_gene_genes: 
    disease_to_gene_results[gene] = {
        'gene_count' : 0,
        'publications': []
    }

for index, row in disease_to_genes.iterrows():
    disease_to_gene_results[row['output_name']]['gene_count'] = disease_to_gene_results[row['output_name']]['gene_count'] + 1
    if(row['pred1_pubmed'] != None): 
        disease_to_gene_results[row['output_name']]['publications'] = disease_to_gene_results[row['output_name']]['publications'] + row['pred1_pubmed'].split(",")

disease_to_gene_results = dict(sorted(disease_to_gene_results.items(), key = lambda x: x[1]['gene_count'], reverse = True))

for key,value in disease_to_gene_results.items(): 
    disease_to_gene_results[key]['publications'] = list(dict.fromkeys(disease_to_gene_results[key]['publications']))
    
    
disease_to_gene_results
# Out:
# {'ACE2': {'gene_count': 6,
#   'publications': ['17558469', '20573835', '14754895']},
#  'CTSL': {'gene_count': 5,
#   'publications': ['16998715', '20466822', '20573835']},
#  'ACE': {'gene_count': 4, 'publications': []},
#  'CCL2': {'gene_count': 3, 'publications': ['19258635']},
#  'IFNA1': {'gene_count': 3,
#   'publications': ['15607755', '15764169', '20462354']},
#  'PPIB': {'gene_count': 3, 'publications': []},
#  'DPP4': {'gene_count': 3, 'publications': []},
#  'CD40': {'gene_count': 3, 'publications': ['20737960', '14633439']},
#  'SFTPA2': {'gene_count': 3, 'publications': ['11254606', '16128400']},
#  'TMPRSS2': {'gene_count': 3, 'publications': []},
#  'SFTPA1': {'gene_count': 3, 'publications': ['11254606', '16128400']},
#  'TNF': {'gene_count': 3,
#   'publications': ['19995578',
#    '24852119',
#    '14527349',
#    '14633438',
#    '16672072']},
#  'SARS2': {'gene_count': 3, 'publications': []},
#  'CD4': {'gene_count': 2, 'publications': ['17872527']},
#  'ICAM3': {'gene_count': 2, 'publications': []},
#  'CTSG': {'gene_count': 2, 'publications': []},
#  'PLAT': {'gene_count': 2, 'publications': ['23435290']},
#  'TGFB1': {'gene_count': 2, 'publications': ['14527349', '14633438']},
#  'MPO': {'gene_count': 2, 'publications': ['28874670']},
#  'NFKB1': {'gene_count': 2, 'publications': []},
#  'MAPK14': {'gene_count': 2, 'publications': []},
#  'SELL': {'gene_count': 2, 'publications': []},
#  'SH2D3A': {'gene_count': 2, 'publications': []},
#  'CD68': {'gene_count': 2, 'publications': []},
#  'CCL27': {'gene_count': 2, 'publications': []},
#  'POU5F1': {'gene_count': 2, 'publications': []},
#  'SDCBP': {'gene_count': 2, 'publications': []},
#  'SPECC1': {'gene_count': 2, 'publications': []},
#  'USP14': {'gene_count': 2, 'publications': []},
#  'MYOM2': {'gene_count': 2, 'publications': []},
#  'HPN': {'gene_count': 2, 'publications': []},
#  'ZCRB1': {'gene_count': 2, 'publications': []},
#  'REN': {'gene_count': 2, 'publications': []},
#  'TNFRSF10B': {'gene_count': 2, 'publications': ['15080302']},
#  'PLIN2': {'gene_count': 2, 'publications': []},
#  'TMPRSS11D': {'gene_count': 2, 'publications': []},
#  'CCR2': {'gene_count': 2,
#   'publications': ['15729771', '22061641', '23916257']},
#  'CCR5': {'gene_count': 2,
#   'publications': ['15012999', '15177445', '20457517']},
#  'HPGDS': {'gene_count': 2, 'publications': []},
#  'ALB': {'gene_count': 2, 'publications': ['15132787']},
#  'HSP90B1': {'gene_count': 2, 'publications': []},
#  'ANPEP': {'gene_count': 2, 'publications': []},
#  'BCL2L1': {'gene_count': 2, 'publications': []},
#  'IL13': {'gene_count': 2, 'publications': []},
#  'CXCL10': {'gene_count': 2, 'publications': []},
#  'CXCL8': {'gene_count': 2, 'publications': []},
#  'CD34': {'gene_count': 2, 'publications': []},
#  'CD209': {'gene_count': 2, 'publications': []},
#  'CLEC4M': {'gene_count': 2, 'publications': []},
#  'SH2D3C': {'gene_count': 2, 'publications': []},
#  'RCHY1': {'gene_count': 2, 'publications': []},
#  'TRIM55': {'gene_count': 2, 'publications': []},
#  'PPP1CA': {'gene_count': 2, 'publications': []},
#  'CLEC4G': {'gene_count': 2, 'publications': []},
#  'TBK1': {'gene_count': 2, 'publications': []},
#  'TMPRSS11A': {'gene_count': 2, 'publications': []},
#  'LCK': {'gene_count': 2, 'publications': []},
#  'RPS2': {'gene_count': 2, 'publications': []},
#  'IL19': {'gene_count': 2, 'publications': []},
#  'USP7': {'gene_count': 2, 'publications': []},
#  'CTSB': {'gene_count': 2, 'publications': []},
#  'ANXA2': {'gene_count': 2, 'publications': ['20015551']},
#  'FAS': {'gene_count': 2, 'publications': ['23629954']},
#  'STAT1': {'gene_count': 2, 'publications': []},
#  'CXCL9': {'gene_count': 2, 'publications': ['19258635']},
#  'CD55': {'gene_count': 2, 'publications': []},
#  'EZR': {'gene_count': 2, 'publications': []},
#  'MAPKAPK2': {'gene_count': 2, 'publications': []},
#  'ATF6': {'gene_count': 2, 'publications': []},
#  'PLAU': {'gene_count': 2, 'publications': []},
#  'SRC': {'gene_count': 2, 'publications': []},
#  'PLP2': {'gene_count': 2, 'publications': []},
#  'SLC15A1': {'gene_count': 2, 'publications': []},
#  'GNL1': {'gene_count': 2, 'publications': []},
#  'ISG15': {'gene_count': 2, 'publications': []},
#  'IFNB1': {'gene_count': 2, 'publications': []},
#  'SQSTM1': {'gene_count': 2, 'publications': []},
#  'BAD': {'gene_count': 2, 'publications': []},
#  'PPP1CB': {'gene_count': 2, 'publications': []},
#  'MAPK8': {'gene_count': 2, 'publications': []},
#  'HLA-A': {'gene_count': 2, 'publications': []},
#  'DUSP8': {'gene_count': 2, 'publications': []},
#  'MX1': {'gene_count': 2, 'publications': ['15766558']},
#  'FKBP1A': {'gene_count': 2, 'publications': []},
#  'MASP2': {'gene_count': 2, 'publications': ['19405982']},
#  'CDCA7L': {'gene_count': 2, 'publications': []},
#  'CXCR4': {'gene_count': 2, 'publications': ['20443225', '21109432']},
#  'CREB1': {'gene_count': 2, 'publications': []},
#  'ENDOU': {'gene_count': 2, 'publications': []},
#  'PRF1': {'gene_count': 2, 'publications': []},
#  'MYD88': {'gene_count': 2, 'publications': []},
#  'PSMC6': {'gene_count': 2, 'publications': []},
#  'SENP6': {'gene_count': 2, 'publications': []},
#  'CISH': {'gene_count': 2, 'publications': ['15175287']},
#  'TICAM2': {'gene_count': 2, 'publications': []},
#  'C4B': {'gene_count': 2, 'publications': []},
#  'PPIA': {'gene_count': 2, 'publications': []},
#  'EIF3F': {'gene_count': 2, 'publications': []},
#  'TYK2': {'gene_count': 2, 'publications': []},
#  'RPS6KA1': {'gene_count': 2, 'publications': []},
#  'KPNA2': {'gene_count': 2, 'publications': []},
#  'MYCBP2': {'gene_count': 2, 'publications': []},
#  'TRAF3': {'gene_count': 2, 'publications': []},
#  'IKBKE': {'gene_count': 2, 'publications': []},
#  'IRF3': {'gene_count': 2, 'publications': []},
#  'CCL5': {'gene_count': 2, 'publications': []},
#  'CCL3': {'gene_count': 2, 'publications': []},
#  'VEGFA': {'gene_count': 2, 'publications': ['20211432']},
#  'PLP1': {'gene_count': 2, 'publications': []},
#  'FURIN': {'gene_count': 2, 'publications': []},
#  'PSMD2': {'gene_count': 2, 'publications': ['26713109']},
#  'RARA': {'gene_count': 2, 'publications': ['1604060']},
#  'ERVK-10': {'gene_count': 2,
#   'publications': ['15667124',
#    '17168761',
#    '17977841',
#    '20103835',
#    '18852458']},
#  'HFM1': {'gene_count': 2, 'publications': ['12917423', '22935448']},
#  '18S_rRNA': {'gene_count': 1, 'publications': []},
#  '28S_rRNA': {'gene_count': 1, 'publications': []},
#  'BISPR': {'gene_count': 1, 'publications': []},
#  'DALIR': {'gene_count': 1, 'publications': []},
#  'DLG2-AS1': {'gene_count': 1, 'publications': []},
#  'DLX6-AS1': {'gene_count': 1, 'publications': []},
#  'ARF5': {'gene_count': 1, 'publications': []},
#  'M6PR': {'gene_count': 1, 'publications': []},
#  'CFTR': {'gene_count': 1, 'publications': []},
#  'PRSS21': {'gene_count': 1, 'publications': []},
#  'CX3CL1': {'gene_count': 1, 'publications': []},
#  'CDH17': {'gene_count': 1, 'publications': []},
#  'GABARAPL2': {'gene_count': 1, 'publications': []},
#  'OTUD5': {'gene_count': 1, 'publications': []},
#  'CTTNBP2': {'gene_count': 1, 'publications': []},
#  'CEACAM1': {'gene_count': 1, 'publications': []},
#  'TNFRSF1A': {'gene_count': 1, 'publications': []},
#  'TBX21': {'gene_count': 1, 'publications': []},
#  'ERLEC1': {'gene_count': 1, 'publications': []},
#  'EIF2AK1': {'gene_count': 1, 'publications': []},
#  'PPP1R15A': {'gene_count': 1, 'publications': []},
#  'LAG3': {'gene_count': 1, 'publications': []},
#  'SIRT1': {'gene_count': 1, 'publications': []},
#  'MMP11': {'gene_count': 1, 'publications': []},
#  'USP18': {'gene_count': 1, 'publications': []},
#  'XBP1': {'gene_count': 1, 'publications': []},
#  'GTPBP1': {'gene_count': 1, 'publications': []},
#  'HMOX1': {'gene_count': 1, 'publications': []},
#  'GZMB': {'gene_count': 1, 'publications': []},
#  'SLC10A1': {'gene_count': 1, 'publications': []},
#  'EIF5': {'gene_count': 1, 'publications': []},
#  'BDKRB1': {'gene_count': 1, 'publications': []},
#  'PABPN1': {'gene_count': 1, 'publications': []},
#  'NFKBIA': {'gene_count': 1, 'publications': []},
#  'PSME2': {'gene_count': 1, 'publications': []},
#  'MACROD2': {'gene_count': 1, 'publications': []},
#  'AHCY': {'gene_count': 1, 'publications': []},
#  'RNF125': {'gene_count': 1, 'publications': []},
#  'TBL1X': {'gene_count': 1, 'publications': []},
#  'TIMP1': {'gene_count': 1, 'publications': []},
#  'ATP12A': {'gene_count': 1, 'publications': []},
#  'PRSS54': {'gene_count': 1, 'publications': []},
#  'STUB1': {'gene_count': 1, 'publications': []},
#  'MEFV': {'gene_count': 1, 'publications': []},
#  'MGA': {'gene_count': 1, 'publications': []},
#  'CTSH': {'gene_count': 1, 'publications': []},
#  'VPS18': {'gene_count': 1, 'publications': []},
#  'AGO2': {'gene_count': 1, 'publications': []},
#  'TNFRSF10A': {'gene_count': 1, 'publications': []},
#  'RELB': {'gene_count': 1, 'publications': []},
#  'FCGRT': {'gene_count': 1, 'publications': []},
#  'SGTA': {'gene_count': 1, 'publications': []},
#  'FBL': {'gene_count': 1, 'publications': []},
#  'MME': {'gene_count': 1, 'publications': []},
#  'BRCA1': {'gene_count': 1, 'publications': []},
#  'AGTR1': {'gene_count': 1, 'publications': []},
#  'EIF1': {'gene_count': 1, 'publications': []},
#  'ERVW-1': {'gene_count': 1, 'publications': []},
#  'CD200': {'gene_count': 1, 'publications': []},
#  'ZNF398': {'gene_count': 1, 'publications': []},
#  'TIPARP': {'gene_count': 1, 'publications': []},
#  'LPHN3': {'gene_count': 1, 'publications': []},
#  'DDX41': {'gene_count': 1, 'publications': []},
#  'H2AFY': {'gene_count': 1, 'publications': []},
#  'CDHR2': {'gene_count': 1, 'publications': []},
#  'DEFB4B': {'gene_count': 1, 'publications': []},
#  'ATG12': {'gene_count': 1, 'publications': []},
#  'EIF4E': {'gene_count': 1, 'publications': []},
#  'DROSHA': {'gene_count': 1, 'publications': []},
#  'CRIP2': {'gene_count': 1, 'publications': []},
#  'RPS6KA2': {'gene_count': 1, 'publications': []},
#  ...}

# %% [markdown]
# ## 3. Get Top Genes Related to Disease through 1 Intermediate Node

# %%
# get results for disease -> any node type -> gene
disease_to_all_nodes_to_genes = predict_many([disease],['Gene'], ALL_NODE_TYPES)
disease_to_all_nodes_to_genes.head()
# Out:
# Running: severe acute respiratory syndrome --> intermediate type Gene --> output type Gene
# API 1.1 cord_gene failed
# API 2.6 semmed_gene failed
# API 2.7 semmed_gene failed
# API 2.1 semmed_gene failed
# API 2.3 semmed_gene failed
# API 2.2 semmed_gene failed
# API 2.4 semmed_gene failed
# API 2.5 semmed_gene failed
# API 4.1 mygene failed
# API 2.8 semmed_gene failed
# API 2.9 semmed_gene failed
# API 2.10 semmed_gene failed

# %%
# Save
# %store disease_to_all_nodes_to_genes
# %store -r disease_to_all_nodes_to_genes

# %%
list(dict.fromkeys(list(disease_to_all_nodes_to_genes["node1_type"])))

# %%
# remove entries with symptoms as intermediates
indices_with_symptom_intermediates = [i for i, val in enumerate(list(disease_to_all_nodes_to_genes['node1_name'])) if val in disease_symptoms]
disease_to_all_nodes_to_genes = disease_to_all_nodes_to_genes.drop( disease_to_all_nodes_to_genes.index[indices_with_symptom_intermediates])
# remove UMLS entries - not totally gene specific
disease_to_all_nodes_to_genes = disease_to_all_nodes_to_genes[~disease_to_all_nodes_to_genes['output_id'].str.contains('UMLS')]
disease_to_all_nodes_to_genes.head()

# %%
# create dictionary of gene reults whereby each Gene has values for the number of occurrences of the gene in results
# and the number of publications connecting the disease -> intermediates -> gene
disease_to_all_nodes_to_genes_results = {}
disease_to_all_nodes_to_genes_genes = list(disease_to_all_nodes_to_genes["output_name"]) # create list of genes
disease_to_all_nodes_to_genes_genes = list(dict.fromkeys(disease_to_all_nodes_to_genes_genes))  # remove duplicates

for gene in disease_to_all_nodes_to_genes_genes: 
    disease_to_all_nodes_to_genes_results[gene] = {
        'gene_count' : 0,
        'publications': []
    }

for index, row in disease_to_all_nodes_to_genes.iterrows():
    disease_to_all_nodes_to_genes_results[row['output_name']]['gene_count'] = disease_to_all_nodes_to_genes_results[row['output_name']]['gene_count'] + 1
    if(row['pred1_pubmed'] != None): 
        disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] = disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] + row['pred1_pubmed'].split(",")
    if(row['pred2_pubmed'] != None): 
        disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] = disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] + row['pred2_pubmed'].split(",")

disease_to_all_nodes_to_genes_results = dict(sorted(disease_to_all_nodes_to_genes_results.items(), key = lambda x: x[1]['gene_count'], reverse = True))
# disease_to_all_nodes_to_genes_results

for key,value in disease_to_all_nodes_to_genes_results.items(): 
    disease_to_all_nodes_to_genes_results[key]['publications'] = list(dict.fromkeys(disease_to_all_nodes_to_genes_results[key]['publications']))
    
        
# printing top 10   
print("Top 10 Gene Occurrences : ")
{A:N['gene_count'] for (A,N) in [x for x in disease_to_all_nodes_to_genes_results.items()][:10]}

# %% [markdown]
# ## 4. Determine Genes to Further Analyze

# %%
# get list of genes based off of "max" gene parameters
disease_top_genes_list = ([A for (A,N) in [x for x in disease_to_gene_results.items()][:max_one_step_genes]]
    + [A for (A,N) in [x for x in disease_to_all_nodes_to_genes_results.items()][:max_two_step_genes]])

disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
disease_top_genes_list

# %% [markdown]
# ## 5. Get Disease Symptoms related to Genes
# Genes -> Symptoms, then filter based on disease symptoms

# %%
# get gene inputs through hint module
gene_inputs = []
for gene in disease_top_genes_list: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        gene_inputs.append(gene_input)
    except: 
        print(gene + ' Failed')

print(gene_inputs)

# %%
# get genes to symptoms, which could be represented as a phenotypic feature, biological process, or diesase
genes_to_symptoms = predict_many(gene_inputs, ['PhenotypicFeature','BiologicalProcess','Disease'])
print(genes_to_symptoms.shape)
genes_to_symptoms.head()

# %%
# filter gene -> symptoms table to only include rows where symptoms match disease symptoms
indices_with_symptom_outputs = [i for i, val in enumerate([x.upper() for x in list(genes_to_symptoms['output_name'])]) if val in disease_symptoms]
relevant_genes_to_symptoms_df = genes_to_symptoms.iloc[indices_with_symptom_outputs]
relevant_genes_to_symptoms_df.head()

# %%
# %store relevant_genes_to_symptoms_df
# %store -r relevant_genes_to_symptoms_df

# %%
# create dictionary to keep track of symptoms a gene is related to, and the number of publications relating the 
# gene to any of the disease symptoms
symptoms_results = {}
relevant_top_genes_list = list(dict.fromkeys(list(relevant_genes_to_symptoms_df["input"])))
for x in relevant_top_genes_list:
    symptoms_results[x] = {
        "related_symptoms" : [],
        "publications": []
    }
for index, row in relevant_genes_to_symptoms_df.iterrows():
    symptoms_results[row["input"]]["related_symptoms"].append(row["output_name"])
    if(row["pred1_pubmed"]):
        symptoms_results[row["input"]]["publications"] = symptoms_results[row["input"]]["publications"] + row["pred1_pubmed"].split(',')

for key,value in symptoms_results.items(): 
    symptoms_results[key]['publications'] = list(dict.fromkeys(symptoms_results[key]['publications']))
            
        
# print(symptoms_results)

# %% [markdown]
# ## 6. Get Genes Edges Out Count

# %%
# get edges out count from genes to any node type to get rough estimate of how well researched a gene is
relevant_gene_inputs = []

for gene_input in gene_inputs: 
    if(gene_input['SYMBOL'] in relevant_top_genes_list):
        relevant_gene_inputs.append(gene_input)
        
all_gene_edges_out = predict_many(relevant_gene_inputs, ALL_NODE_TYPES)
edges_out_genes_list = list(all_gene_edges_out["input"])
gene_edges_out = {x:edges_out_genes_list.count(x) for x in edges_out_genes_list}
print(gene_edges_out)

# %%
# %store gene_edges_out
# %store -r gene_edges_out

# %% [markdown]
# ## 7. Assemble Genes related to both Disease and Disease Symptoms

# %%
# assemble final dictionary that includes all metrics for gene's connections to disease (direct and through one node)
# as well as to disease symptoms
final_dict = {}

for x in relevant_top_genes_list:
    symptoms_to_hpids = [];
    for symptom in symptoms_results[x]['related_symptoms']: 
        symptoms_to_hpids.append(symptom_to_hpid_dict[symptom])
    unique_symptoms = list(dict.fromkeys(symptoms_to_hpids))
    final_dict[x] = {
        "disease_to_gene_occurrences" : disease_to_gene_results[x]['gene_count'] if x in disease_to_gene_results else 0,
        "disease_to_gene_pub_counts" : len(disease_to_gene_results[x]['publications']) if x in disease_to_gene_results else 0,
        "disease_to_int_to_gen_occurrences" : disease_to_all_nodes_to_genes_results[x]['gene_count'] if x in disease_to_all_nodes_to_genes_results else 0,
        "disease_to_int_to_gene_pubs" : len(disease_to_all_nodes_to_genes_results[x]['publications']) if x in disease_to_all_nodes_to_genes_results else 0,
        "disease_symtpoms_gene_related_to" : symptoms_results[x]['related_symptoms'],
        "disease_symtpoms_gene_related_to_count" : len(symptoms_results[x]['related_symptoms']),
        "unique_symptoms_count": len(unique_symptoms),
        "gene_to_symptoms_pub_counts" : len(symptoms_results[x]['publications']),
        "gene_edges_out": gene_edges_out[x]
    }

# %%
final_df = pd.DataFrame(final_dict).transpose()
final_df

# %%
final_df.to_csv(disease_csv_file, index = True)

# %% [markdown]
# ## 8. EXTRA --- WEIGHTING RESULTS

# %%
# Symptom Table Weighting
import math

# disease_symptom_df = disease_symptom_df.head(-1)
# disease_symptom_df

individual_symptom_scores = [];
for index,x in disease_symptom_df.iterrows():
    if(x["frequency"] == "Very frequent"):
        score = 20 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Frequent"):
        score = 15 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Occasional"):
        score = 10 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Rare"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Unknown"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    individual_symptom_scores.append(score)

# print(len(individual_symptom_scores))
disease_symptom_df["ISS"] = individual_symptom_scores
disease_symptom_df

# %%
symptom_score_dict = {}
for index, row in disease_symptom_df.iterrows():
    # print(row)
    for x in row["names"]:
        symptom_score_dict[x.lower()] = row["ISS"]

final_symptom_scores = []
for index, row in final_df.iterrows():
    current_score = 0
    current_symptoms = row["disease_symtpoms_gene_related_to"]
    for x in current_symptoms:
        singular = x.lower()[0:-1]
        plural = x.lower() + 's'
        if(x.lower() in symptom_score_dict):
            current_score = current_score + symptom_score_dict[x.lower()]
        elif(plural in symptom_score_dict):
            current_score = current_score + symptom_score_dict[plural]
        elif(singular in symptom_score_dict):
            current_score = current_score + symptom_score_dict[singular]
    final_symptom_scores.append(current_score)

final_df["final_symptom_score"] = final_symptom_scores

range_direct = max(list(final_df["disease_to_gene_occurrences"])) - min(list(final_df["disease_to_gene_occurrences"]))
min_direct = min(list(final_df["disease_to_gene_occurrences"]))

range_two_step = max(list(final_df["disease_to_int_to_gen_occurrences"])) - min(list(final_df["disease_to_int_to_gen_occurrences"]))
min_two_step = min(list(final_df["disease_to_int_to_gen_occurrences"]))

range_symptoms = max(list(final_df["final_symptom_score"])) - min(list(final_df["final_symptom_score"]))
min_symptoms = min(list(final_df["final_symptom_score"]))
relevance_score = []
for index, row in final_df.iterrows():
    current_direct = final_df["disease_to_gene_occurrences"][index]
    current_two_step = final_df["disease_to_int_to_gen_occurrences"][index]
    current_symptom = final_df["final_symptom_score"][index]
    direct_weighted = (current_direct - min_direct)/range_direct
    two_step_weighted = (current_two_step - min_two_step)/range_two_step
    symptom_weighted = (current_symptom - min_symptoms)/range_symptoms

    current_rs = ((direct_weighted + two_step_weighted)*symptom_weighted)/math.sqrt(final_df["gene_edges_out"][index])
    relevance_score.append(current_rs)

relevance_score_norm = [(float(i) - min(relevance_score))/(max(relevance_score)-min(relevance_score)) for i in relevance_score]
final_df["relevance_score"] = relevance_score_norm
# sort by relevance score
final_df = final_df.sort_values(by=['relevance_score'], ascending=False)

# %%
final_df

# %%
final_df.to_csv(disease_csv_weighted_file, index = True)

# %% [markdown]
# ## 9. Look at pathways and biological processes

# %%
gene_to_pathways = predict_many(relevant_gene_inputs, ['Pathway'])

# %%
gene_to_pathways = genes_to_pathways_df

# %%
list(dict.fromkeys(list(genes_to_pathways_df["output_name"])))

# %%
gene_to_pathway_results = {}
gene_to_pathway_genes = list(gene_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'pathway_count' : 0
    }

for index, row in gene_to_pathways.iterrows():
    gene_to_pathway_results[row['output_name']]['pathway_count'] = gene_to_pathway_results[row['output_name']]['pathway_count'] + 1

gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['pathway_count'], reverse = True))

    
gene_to_pathway_results

# %%
gene_to_bioprocess = predict_many(relevant_gene_inputs, ['BiologicalProcess'])
gene_to_bioprocess_results = {}
gene_to_bioprocess_genes = list(gene_to_bioprocess["output_name"]) # create list of genes
gene_to_bioprocess_genes = list(dict.fromkeys(gene_to_bioprocess_genes))  # remove duplicates

for gene in gene_to_bioprocess_genes: 
    gene_to_bioprocess_results[gene] = {
        'bioprocess_count' : 0
    }

for index, row in gene_to_bioprocess.iterrows():
    gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] = gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] + 1

gene_to_bioprocess_results = dict(sorted(gene_to_bioprocess_results.items(), key = lambda x: x[1]['bioprocess_count'], reverse = True))

    
# gene_to_bioprocess_results

# %%
for key, value in gene_to_bioprocess_results.items(): 
    if 'C0' in key: 
        try: 
            name = ht.query(key)['BiologicalProcess'][0]['name']
            gene_to_bioprocess_results[name] = value
            del gene_to_bioprocess_results[key]
        except: 
            pass

# %%
gene_to_bioprocess_results
