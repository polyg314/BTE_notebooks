# %% [markdown]
# # BTE -- Question #2 -- Use Case Workflow

# %%
from IPython.display import Image 
Image("disease_work_flow.png")

# %% [markdown]
# ## 0. Uploads, Functions, and Parameters

# %%
# Import pandas and biothings explorers modules
import pandas as pd
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %%
# set list constant that represents every node type available in BTE
ALL_NODE_TYPES = ['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature']

# %%
# predict_many funciton will be used to run many BTE queries and return results as a single table
def predict_many(input_object_list, output_type_list, intermediate_node_list = ''):
    df_list = []
    for input_object in input_object_list: 
        for output_type in output_type_list: 
            if(len(intermediate_node_list) > 0):
                for inter in intermediate_node_list:
                    try: 
                        print("Running: " + input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type )
                        fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        rows = df.shape[0]
                        if(rows > 0):
                            df_list.append(df)
                    except:
                        print(input_object['name'] + ' --> intermediate type ' + inter + ' --> output type ' + output_type + ' FAILED')
            else:
                try:
                    print("Running: " + input_object['name'] + ' --> output type ' + output_type )
                    fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=None)
                    fc.connect(verbose=False)
                    df = fc.display_table_view()
                    rows = df.shape[0]
                    if(rows > 0):
                        df_list.append(df)
                except:
                    print(input_object['name'] + ' --> output type ' + output_type + ' FAILED')

    if(len(df_list) > 0):
        return pd.concat(df_list)
    else:
        return None

# %%
# max_one_step_genes represents the number of genes returned from direct disease -> gene query 
# that will be included in results. Genes with most occurrences will be included over those with less
max_one_step_genes = 50

# max_two_step_genes represents the number of genes returned from disease -> intermediate node -> gene query 
max_two_step_genes = 100

# set disease name
disease_name = 'thrombophilia due to activated protein C resistance'

# set disease output files
disease_csv_file = 'Dravet_Syndrome_BTE_2020_09_09.csv'
disease_symptoms_csv = 'Dravet_Syndrome_Symptoms_2020_09_09.csv'

# %% [markdown]
# ## 1. Get Disease Symptoms and Symptom Information

# %% [markdown]
# ### 1.1 Get Disease

# %%
# run hint query to get disease input
disease = ht.query(disease_name)['Disease'][0]
print(disease)
# Out:
# {'MONDO': 'MONDO:0008560', 'UMLS': 'C1861171', 'name': 'thrombophilia due to activated protein C resistance', 'MESH': 'D020016', 'OMIM': '188055', 'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'MONDO:0008560'}, 'display': 'MONDO(MONDO:0008560) OMIM(188055) UMLS(C1861171) MESH(D020016) name(thrombophilia due to activated protein C resistance)', 'type': 'Disease'}

# %% [markdown]
# ### 1.2 Get 'PhenotypicFeatures' Related to Disease

# %%
# get phenotypes (signs and symptoms) related to diesase
fc = FindConnection(input_obj=disease, output_obj='PhenotypicFeature', intermediate_nodes=None)
fc.connect(verbose=False)
disease_to_phenotypicFeature = fc.display_table_view()
disease_to_phenotypicFeature
# Out:
#                              input input_type       pred1 pred1_source  \
# 0   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to         None
# 1   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to          hpo
# 2   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to         None
# 3   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to          hpo
# 4   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to         None
# 5   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to          hpo
# 6   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to         None
# 7   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to          hpo
# 8   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to         None
# 9   ACTIVATED PROTEIN C RESISTANCE    Disease  related_to          hpo
# 10  ACTIVATED PROTEIN C RESISTANCE    Disease  related_to          hpo
#
#              pred1_api pred1_pubmed        output_type  \
# 0          BioLink API         None  PhenotypicFeature
# 1   mydisease.info API         None  PhenotypicFeature
# 2          BioLink API         None  PhenotypicFeature
# 3   mydisease.info API         None  PhenotypicFeature
# 4          BioLink API         None  PhenotypicFeature
# 5   mydisease.info API         None  PhenotypicFeature
# 6          BioLink API         None  PhenotypicFeature
# 7   mydisease.info API         None  PhenotypicFeature
# 8          BioLink API         None  PhenotypicFeature
# 9   mydisease.info API         None  PhenotypicFeature
# 10  mydisease.info API         None  PhenotypicFeature
#
#                              output_name      output_id
# 0              BLOOD CLOT IN A DEEP VEIN  UMLS:C0149871
# 1              BLOOD CLOT IN A DEEP VEIN  UMLS:C0149871
# 2         ACTIVATED PROTEIN C RESISTANCE  UMLS:C0600433
# 3         ACTIVATED PROTEIN C RESISTANCE  UMLS:C0600433
# 4   ABNORMAL PARTIAL THROMBOPLASTIN TIME  UMLS:C0240671
# 5   ABNORMAL PARTIAL THROMBOPLASTIN TIME  UMLS:C0240671
# 6                   BLOOD HYPERVISCOSITY  UMLS:C0398623
# 7                   BLOOD HYPERVISCOSITY  UMLS:C0398623
# 8                          PRE-ECLAMPSIA  UMLS:C0032914
# 9                          PRE-ECLAMPSIA  UMLS:C0032914
# 10                    AUTOSOMAL DOMINANT  UMLS:C0443147

# %%
# Print equivalent names for the disease input
print('Note: all equivalent names for the disease input are as follows:')
for name in fc.fc.display_node_info(disease_name)['equivalent_ids']['name']: print(name)
# Out:
# Note: all equivalent names for the disease input are as follows:
# ACTIVATED PROTEIN C RESISTANCE
# APC RESISTANCE
# PCCF DEFICIENCY
# PROC COFACTOR DEFICIENCY
# RESISTANCE, APC
# THPH2
# THROMBOPHILIA 5
# THROMBOPHILIA DUE TO ACTIVATED PROTEIN C RESISTANCE
# THROMBOPHILIA DUE TO ACTIVATED PROTEIN C RESISTANCE; THPH2
# THROMBOPHILIA DUE TO DEFICIENCY OF ACTIVATED PROTEIN C COFACTOR
# THROMBOPHILIA DUE TO FACTOR 5 LEIDEN

# %%
# create dictionary of symptom HPIDs, nad symptom names (with synonyms)
symptom_dict = {}
for index, row in disease_to_phenotypicFeature.iterrows():
    output_name = disease_to_phenotypicFeature['output_name'][index]
    items = fc.fc.G[disease_name][output_name].values()
    for item in items: 
#         print(item)
        if('frequency' in item['info']):
            freq = [_item['info']['frequency'] for _item in fc.fc.G[disease_name][output_name].values() if "frequency" in _item["info"]][0][0]
            freq_value = ht.query(freq)['PhenotypicFeature'][0]['name']
        else: 
            freq_value = 'Unknown'
                    
        symptom_dict[fc.fc.display_node_info(output_name)['equivalent_ids']['HP'][0]] = {
            "names": fc.fc.display_node_info(output_name)['equivalent_ids']['name'],
            "frequency": freq_value,
        }
print(symptom_dict)
# Out:
# {'HP:0002625': {'names': ['BLOOD CLOT IN A DEEP VEIN', 'DEEP VEIN THROMBOSIS', 'DEEP VENOUS THROMBOSIS', 'MULTIPLE DEEP VENOUS THROMBOSIS'], 'frequency': 'Unknown'}, 'HP:0012175': {'names': ['ACTIVATED PROTEIN C RESISTANCE', 'RESISTANCE TO ACTIVATED PROTEIN C'], 'frequency': 'Unknown'}, 'HP:0003645': {'names': ['ABNORMAL PARTIAL THROMBOPLASTIN TIME', 'DELAYED THROMBOPLASTIN GENERATION', 'PARTIAL THROMBOPLASTIN TIME PROLONGED', 'PROLONGED ACTIVATED PARTIAL THROMBOPLASTIN TIME', 'PROLONGED PARTIAL THROMBOPLASTIN TIME', 'PROLONGED PTT'], 'frequency': 'Unknown'}, 'HP:0100724': {'names': ['BLOOD HYPERVISCOSITY', 'HYPERCOAGULABILITY', 'THROMBOPHILIA'], 'frequency': 'Unknown'}, 'HP:0100602': {'names': ['PRE-ECLAMPSIA', 'PREECLAMPSIA'], 'frequency': 'Unknown'}, 'HP:0000006': {'names': ['AUTOSOMAL DOMINANT', 'AUTOSOMAL DOMINANT FORM', 'AUTOSOMAL DOMINANT INHERITANCE', 'AUTOSOMAL DOMINANT TYPE'], 'frequency': 'Unknown'}}

# %%
# create list of HPIDs and Symptoms for later use
disease_symptom_hpids = list(symptom_dict.keys())
disease_symptoms = []
for entry in list(symptom_dict.values()): disease_symptoms = disease_symptoms + entry['names']


# create dict of HPIDs : symptoms for use in assembling final results
symptom_to_hpid_dict = {}
for key,value in symptom_dict.items(): 
    for name in value['names']:
        symptom_to_hpid_dict[name] = key

# %%
# add "edges out" counts from each phenotype to any node type, to get a rough estimate of how prevalent a phenotype is
phenotype_inputs = []
for hpid in disease_symptom_hpids: 
    try: 
        phenotype_input = ht.query(hpid)['PhenotypicFeature'][0]
        all_edges_out_df = predict_many([phenotype_input], ALL_NODE_TYPES)
        symptom_dict[hpid]['edges_out_count'] = all_edges_out_df.shape[0]
    except: 
        print(hpid + ' Failed')

print(symptom_dict)
# Out:
# Running: Deep venous thrombosis --> output type Gene
# Running: Deep venous thrombosis --> output type SequenceVariant
# Running: Deep venous thrombosis --> output type ChemicalSubstance
# Running: Deep venous thrombosis --> output type Disease
# Running: Deep venous thrombosis --> output type MolecularActivity
# Running: Deep venous thrombosis --> output type BiologicalProcess
# Running: Deep venous thrombosis --> output type CellularComponent
# Running: Deep venous thrombosis --> output type Pathway
# Running: Deep venous thrombosis --> output type AnatomicalEntity
# Running: Deep venous thrombosis --> output type PhenotypicFeature
# Running: Resistance to activated protein C --> output type Gene
# Running: Resistance to activated protein C --> output type SequenceVariant
# Running: Resistance to activated protein C --> output type ChemicalSubstance
# Running: Resistance to activated protein C --> output type Disease
# Running: Resistance to activated protein C --> output type MolecularActivity
# Running: Resistance to activated protein C --> output type BiologicalProcess
# Running: Resistance to activated protein C --> output type CellularComponent
# Running: Resistance to activated protein C --> output type Pathway
# Running: Resistance to activated protein C --> output type AnatomicalEntity
# Running: Resistance to activated protein C --> output type PhenotypicFeature
# Running: Prolonged partial thromboplastin time --> output type Gene
# Running: Prolonged partial thromboplastin time --> output type SequenceVariant
# Running: Prolonged partial thromboplastin time --> output type ChemicalSubstance
# Running: Prolonged partial thromboplastin time --> output type Disease
# Running: Prolonged partial thromboplastin time --> output type MolecularActivity
# Running: Prolonged partial thromboplastin time --> output type BiologicalProcess
# Running: Prolonged partial thromboplastin time --> output type CellularComponent
# Running: Prolonged partial thromboplastin time --> output type Pathway
# Running: Prolonged partial thromboplastin time --> output type AnatomicalEntity
# Running: Prolonged partial thromboplastin time --> output type PhenotypicFeature
# Running: Hypercoagulability --> output type Gene
# Running: Hypercoagulability --> output type SequenceVariant
# Running: Hypercoagulability --> output type ChemicalSubstance
# Running: Hypercoagulability --> output type Disease
# Running: Hypercoagulability --> output type MolecularActivity
# Running: Hypercoagulability --> output type BiologicalProcess
# Running: Hypercoagulability --> output type CellularComponent
# Running: Hypercoagulability --> output type Pathway
# Running: Hypercoagulability --> output type AnatomicalEntity
# Running: Hypercoagulability --> output type PhenotypicFeature
# Running: Preeclampsia --> output type Gene
# Running: Preeclampsia --> output type SequenceVariant
# Running: Preeclampsia --> output type ChemicalSubstance
# Running: Preeclampsia --> output type Disease
# Running: Preeclampsia --> output type MolecularActivity
# Running: Preeclampsia --> output type BiologicalProcess
# Running: Preeclampsia --> output type CellularComponent
# Running: Preeclampsia --> output type Pathway
# Running: Preeclampsia --> output type AnatomicalEntity
# Running: Preeclampsia --> output type PhenotypicFeature
# Running: Autosomal dominant inheritance --> output type Gene
# Running: Autosomal dominant inheritance --> output type SequenceVariant
# Running: Autosomal dominant inheritance --> output type ChemicalSubstance
# Running: Autosomal dominant inheritance --> output type Disease
# Running: Autosomal dominant inheritance --> output type MolecularActivity
# Running: Autosomal dominant inheritance --> output type BiologicalProcess
# Running: Autosomal dominant inheritance --> output type CellularComponent
# Running: Autosomal dominant inheritance --> output type Pathway
# Running: Autosomal dominant inheritance --> output type AnatomicalEntity
# Running: Autosomal dominant inheritance --> output type PhenotypicFeature
# {'HP:0002625': {'names': ['BLOOD CLOT IN A DEEP VEIN', 'DEEP VEIN THROMBOSIS', 'DEEP VENOUS THROMBOSIS', 'MULTIPLE DEEP VENOUS THROMBOSIS'], 'frequency': 'Unknown', 'edges_out_count': 38}, 'HP:0012175': {'names': ['ACTIVATED PROTEIN C RESISTANCE', 'RESISTANCE TO ACTIVATED PROTEIN C'], 'frequency': 'Unknown', 'edges_out_count': 4}, 'HP:0003645': {'names': ['ABNORMAL PARTIAL THROMBOPLASTIN TIME', 'DELAYED THROMBOPLASTIN GENERATION', 'PARTIAL THROMBOPLASTIN TIME PROLONGED', 'PROLONGED ACTIVATED PARTIAL THROMBOPLASTIN TIME', 'PROLONGED PARTIAL THROMBOPLASTIN TIME', 'PROLONGED PTT'], 'frequency': 'Unknown', 'edges_out_count': 76}, 'HP:0100724': {'names': ['BLOOD HYPERVISCOSITY', 'HYPERCOAGULABILITY', 'THROMBOPHILIA'], 'frequency': 'Unknown', 'edges_out_count': 47}, 'HP:0100602': {'names': ['PRE-ECLAMPSIA', 'PREECLAMPSIA'], 'frequency': 'Unknown', 'edges_out_count': 36}, 'HP:0000006': {'names': ['AUTOSOMAL DOMINANT', 'AUTOSOMAL DOMINANT FORM', 'AUTOSOMAL DOMINANT INHERITANCE', 'AUTOSOMAL DOMINANT TYPE'], 'frequency': 'Unknown', 'edges_out_count': 538}}

# %%
# convert symptom dictionary to dataframe and sort by edges out and frequency 
disease_symptom_df = pd.DataFrame.from_dict(symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptom_df = pd.concat([disease_symptom_df[disease_symptom_df["frequency"] == "Very frequent"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Frequent"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Occasional"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Rare"],
               disease_symptom_df[disease_symptom_df["frequency"] == "Unknown"]
              ])
disease_symptom_df
# Out:
#                                                         names frequency  \
# HP:0012175  [ACTIVATED PROTEIN C RESISTANCE, RESISTANCE TO...   Unknown
# HP:0100602                      [PRE-ECLAMPSIA, PREECLAMPSIA]   Unknown
# HP:0002625  [BLOOD CLOT IN A DEEP VEIN, DEEP VEIN THROMBOS...   Unknown
# HP:0100724  [BLOOD HYPERVISCOSITY, HYPERCOAGULABILITY, THR...   Unknown
# HP:0003645  [ABNORMAL PARTIAL THROMBOPLASTIN TIME, DELAYED...   Unknown
# HP:0000006  [AUTOSOMAL DOMINANT, AUTOSOMAL DOMINANT FORM, ...   Unknown
#
#             edges_out_count
# HP:0012175                4
# HP:0100602               36
# HP:0002625               38
# HP:0100724               47
# HP:0003645               76
# HP:0000006              538

# %%
disease_symptom_df.to_csv(disease_symptoms_csv, index = True)

# %% [markdown]
# ## 2. Get Genes Directly Related to Disease

# %%
# find genes directly related to disease
fc = FindConnection(input_obj=disease, output_obj='Gene', intermediate_nodes=None)
fc.connect(verbose=False)
disease_to_genes = fc.display_table_view()
disease_to_genes = disease_to_genes[~disease_to_genes['output_id'].str.contains('UMLS')]
disease_to_genes
# Out:
#                              input input_type         pred1 pred1_source  \
# 20  ACTIVATED PROTEIN C RESISTANCE    Disease  disrupted_by       SEMMED
# 21  ACTIVATED PROTEIN C RESISTANCE    Disease   affected_by       SEMMED
# 22  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       SEMMED
# 23  ACTIVATED PROTEIN C RESISTANCE    Disease     caused_by       SEMMED
# 24  ACTIVATED PROTEIN C RESISTANCE    Disease  disrupted_by       SEMMED
# 25  ACTIVATED PROTEIN C RESISTANCE    Disease   affected_by       SEMMED
# 26  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to     disgenet
# 27  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       pharos
# 29  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       SEMMED
# 30  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       SEMMED
# 31  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       SEMMED
# 32  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       SEMMED
# 33  ACTIVATED PROTEIN C RESISTANCE    Disease     caused_by       SEMMED
# 34  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       SEMMED
# 35  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       SEMMED
# 36  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to     disgenet
# 37  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to      scibite
# 39  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to         None
# 40  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to     disgenet
# 41  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       pharos
# 43  ACTIVATED PROTEIN C RESISTANCE    Disease     caused_by       SEMMED
# 44  ACTIVATED PROTEIN C RESISTANCE    Disease     caused_by       SEMMED
# 45  ACTIVATED PROTEIN C RESISTANCE    Disease     caused_by       SEMMED
# 46  ACTIVATED PROTEIN C RESISTANCE    Disease     caused_by       SEMMED
# 47  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to      scibite
# 48  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to      scibite
# 49  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to      scibite
# 50  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to      scibite
# 51  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to      scibite
#
#                      pred1_api                pred1_pubmed output_type  \
# 20          SEMMED Disease API                     7745572        Gene
# 21          SEMMED Disease API           11703344,16493484        Gene
# 22          SEMMED Disease API                     8834124        Gene
# 23          SEMMED Disease API  19036061,19764414,19803829        Gene
# 24          SEMMED Disease API                    12624624        Gene
# 25          SEMMED Disease API                    11703344        Gene
# 26          mydisease.info API                        None        Gene
# 27          Automat PHAROS API                        None        Gene
# 29          SEMMED Disease API                     7631299        Gene
# 30          SEMMED Disease API                    20161734        Gene
# 31          SEMMED Disease API                    20161734        Gene
# 32          SEMMED Disease API                    21846908        Gene
# 33          SEMMED Disease API           16315641,21846908        Gene
# 34          SEMMED Disease API                    18768782        Gene
# 35          SEMMED Disease API                    21914670        Gene
# 36          mydisease.info API                        None        Gene
# 37  Automat CORD19 Scibite API                        None        Gene
# 39                 BioLink API                        None        Gene
# 40          mydisease.info API                        None        Gene
# 41          Automat PHAROS API                        None        Gene
# 43          SEMMED Disease API                    16315641        Gene
# 44          SEMMED Disease API                    16315641        Gene
# 45          SEMMED Disease API                     9493610        Gene
# 46          SEMMED Disease API                    15637132        Gene
# 47  Automat CORD19 Scibite API                        None        Gene
# 48  Automat CORD19 Scibite API                        None        Gene
# 49  Automat CORD19 Scibite API                        None        Gene
# 50  Automat CORD19 Scibite API                        None        Gene
# 51  Automat CORD19 Scibite API                        None        Gene
#
#    output_name       output_id
# 20        CDSN   NCBIGene:1041
# 21        CDSN   NCBIGene:1041
# 22        CDSN   NCBIGene:1041
# 23        CDSN   NCBIGene:1041
# 24        CD82   NCBIGene:3732
# 25        TFPI   NCBIGene:7035
# 26        TFPI   NCBIGene:7035
# 27        TFPI   NCBIGene:7035
# 29        KLK3    NCBIGene:354
# 30    SERPINE1   NCBIGene:5054
# 31    SERPINB2   NCBIGene:5055
# 32         SSB   NCBIGene:6741
# 33         SSB   NCBIGene:6741
# 34        JAK2   NCBIGene:3717
# 35      TWIST1   NCBIGene:7291
# 36          F5   NCBIGene:2153
# 37          F5   NCBIGene:2153
# 39          F5   NCBIGene:2153
# 40       PROS1   NCBIGene:5627
# 41       PROS1   NCBIGene:5627
# 43      TUBB4B  NCBIGene:10383
# 44     NEUROD1   NCBIGene:4760
# 45          CP   NCBIGene:1356
# 46         GPI   NCBIGene:2821
# 47          F8   NCBIGene:2157
# 48        PLAT   NCBIGene:5327
# 49         PLG   NCBIGene:5340
# 50        PROC   NCBIGene:5624
# 51         LPA   NCBIGene:4018

# %%
# create dictionary of gene reults whereby each Gene has values for the number of occurrences of the gene in results
# and the number of publications connecting the disease -> gene directly
disease_to_gene_results = {}
disease_to_gene_genes = list(disease_to_genes["output_name"]) # create list of genes
disease_to_gene_genes = list(dict.fromkeys(disease_to_gene_genes))  # remove duplicates

for gene in disease_to_gene_genes: 
    disease_to_gene_results[gene] = {
        'gene_count' : 0,
        'publications': []
    }

for index, row in disease_to_genes.iterrows():
    disease_to_gene_results[row['output_name']]['gene_count'] = disease_to_gene_results[row['output_name']]['gene_count'] + 1
    if(row['pred1_pubmed'] != None): 
        disease_to_gene_results[row['output_name']]['publications'] = disease_to_gene_results[row['output_name']]['publications'] + row['pred1_pubmed'].split(",")

disease_to_gene_results = dict(sorted(disease_to_gene_results.items(), key = lambda x: x[1]['gene_count'], reverse = True))

for key,value in disease_to_gene_results.items(): 
    disease_to_gene_results[key]['publications'] = list(dict.fromkeys(disease_to_gene_results[key]['publications']))
    
    
disease_to_gene_results
# Out:
# {'CDSN': {'gene_count': 4,
#   'publications': ['7745572',
#    '11703344',
#    '16493484',
#    '8834124',
#    '19036061',
#    '19764414',
#    '19803829']},
#  'TFPI': {'gene_count': 3, 'publications': ['11703344']},
#  'F5': {'gene_count': 3, 'publications': []},
#  'SSB': {'gene_count': 2, 'publications': ['21846908', '16315641']},
#  'PROS1': {'gene_count': 2, 'publications': []},
#  'CD82': {'gene_count': 1, 'publications': ['12624624']},
#  'KLK3': {'gene_count': 1, 'publications': ['7631299']},
#  'SERPINE1': {'gene_count': 1, 'publications': ['20161734']},
#  'SERPINB2': {'gene_count': 1, 'publications': ['20161734']},
#  'JAK2': {'gene_count': 1, 'publications': ['18768782']},
#  'TWIST1': {'gene_count': 1, 'publications': ['21914670']},
#  'TUBB4B': {'gene_count': 1, 'publications': ['16315641']},
#  'NEUROD1': {'gene_count': 1, 'publications': ['16315641']},
#  'CP': {'gene_count': 1, 'publications': ['9493610']},
#  'GPI': {'gene_count': 1, 'publications': ['15637132']},
#  'F8': {'gene_count': 1, 'publications': []},
#  'PLAT': {'gene_count': 1, 'publications': []},
#  'PLG': {'gene_count': 1, 'publications': []},
#  'PROC': {'gene_count': 1, 'publications': []},
#  'LPA': {'gene_count': 1, 'publications': []}}

# %% [markdown]
# ## 3. Get Top Genes Related to Disease through 1 Intermediate Node

# %%
# get results for disease -> any node type -> gene
disease_to_all_nodes_to_genes = predict_many([disease],['Gene'], ALL_NODE_TYPES)
disease_to_all_nodes_to_genes.head()
# Out:
# Running: thrombophilia due to activated protein C resistance --> intermediate type Gene --> output type Gene
# Running: thrombophilia due to activated protein C resistance --> intermediate type SequenceVariant --> output type Gene
# Running: thrombophilia due to activated protein C resistance --> intermediate type ChemicalSubstance --> output type Gene
# API 6.1 pharos failed
# Running: thrombophilia due to activated protein C resistance --> intermediate type Disease --> output type Gene
# Running: thrombophilia due to activated protein C resistance --> intermediate type MolecularActivity --> output type Gene
# Running: thrombophilia due to activated protein C resistance --> intermediate type BiologicalProcess --> output type Gene
# Running: thrombophilia due to activated protein C resistance --> intermediate type CellularComponent --> output type Gene
# Running: thrombophilia due to activated protein C resistance --> intermediate type Pathway --> output type Gene
# Running: thrombophilia due to activated protein C resistance --> intermediate type AnatomicalEntity --> output type Gene
# Running: thrombophilia due to activated protein C resistance --> intermediate type PhenotypicFeature --> output type Gene
#                             input input_type         pred1 pred1_source  \
# 0  ACTIVATED PROTEIN C RESISTANCE    Disease    treated_by       SEMMED
# 1  ACTIVATED PROTEIN C RESISTANCE    Disease    treated_by       SEMMED
# 2  ACTIVATED PROTEIN C RESISTANCE    Disease  disrupted_by       SEMMED
# 3  ACTIVATED PROTEIN C RESISTANCE    Disease   affected_by       SEMMED
# 4  ACTIVATED PROTEIN C RESISTANCE    Disease    related_to       SEMMED
#
#             pred1_api                               pred1_pubmed node1_type  \
# 0  SEMMED Disease API                                    9974416       Gene
# 1  SEMMED Disease API                                    9974416       Gene
# 2  SEMMED Disease API                                   14515684       Gene
# 3  SEMMED Disease API  16879211,17549295,8618815,8701401,8956934       Gene
# 4  SEMMED Disease API                                   28717431       Gene
#
#   node1_name       node1_id                      pred2 pred2_source  \
# 0   C1333075  UMLS:C1333075       positively_regulates       SEMMED
# 1   C1333075  UMLS:C1333075  physically_interacts_with       SEMMED
# 2   C2985367  UMLS:C2985367       positively_regulates       SEMMED
# 3   C2985367  UMLS:C2985367       positively_regulates       SEMMED
# 4   C2985367  UMLS:C2985367       positively_regulates       SEMMED
#
#          pred2_api pred2_pubmed output_type output_name      output_id
# 0  SEMMED Gene API     10048117        Gene    C0128902  UMLS:C0128902
# 1  SEMMED Gene API     27210873        Gene          F9  NCBIGene:2158
# 2  SEMMED Gene API      7541242        Gene          F9  NCBIGene:2158
# 3  SEMMED Gene API      7541242        Gene          F9  NCBIGene:2158
# 4  SEMMED Gene API      7541242        Gene          F9  NCBIGene:2158

# %%
# Save
# %store disease_to_all_nodes_to_genes
# %store -r disease_to_all_nodes_to_genes
# Out:
# Stored 'disease_to_all_nodes_to_genes' (DataFrame)

# %%
# remove entries with symptoms as intermediates
indices_with_symptom_intermediates = [i for i, val in enumerate(list(disease_to_all_nodes_to_genes['node1_name'])) if val in disease_symptoms]
disease_to_all_nodes_to_genes = disease_to_all_nodes_to_genes.drop( disease_to_all_nodes_to_genes.index[indices_with_symptom_intermediates])
# remove UMLS entries - not totally gene specific
disease_to_all_nodes_to_genes = disease_to_all_nodes_to_genes[~disease_to_all_nodes_to_genes['output_id'].str.contains('UMLS')]
disease_to_all_nodes_to_genes.head()
# Out:
#                                input input_type         pred1 pred1_source  \
# 1663  ACTIVATED PROTEIN C RESISTANCE    Disease  disrupted_by       SEMMED
# 1664  ACTIVATED PROTEIN C RESISTANCE    Disease  disrupted_by       SEMMED
# 1665  ACTIVATED PROTEIN C RESISTANCE    Disease     caused_by       SEMMED
# 1666  ACTIVATED PROTEIN C RESISTANCE    Disease  disrupted_by       SEMMED
# 1667  ACTIVATED PROTEIN C RESISTANCE    Disease  disrupted_by       SEMMED
#
#                pred1_api pred1_pubmed node1_type node1_name       node1_id  \
# 1663  SEMMED Disease API     12624624       Gene   C1705784  UMLS:C1705784
# 1664  SEMMED Disease API     12624624       Gene   C1705784  UMLS:C1705784
# 1665  SEMMED Disease API      9405896       Gene   C0017337  UMLS:C0017337
# 1666  SEMMED Disease API     12624624       Gene       CD82  NCBIGene:3732
# 1667  SEMMED Disease API     12624624       Gene       CD82  NCBIGene:3732
#
#                           pred2 pred2_source        pred2_api pred2_pubmed  \
# 1663       negatively_regulates       SEMMED  SEMMED Gene API     27041584
# 1664  physically_interacts_with       SEMMED  SEMMED Gene API     27041584
# 1665       negatively_regulates       SEMMED  SEMMED Gene API     23152763
# 1666       negatively_regulates       SEMMED  SEMMED Gene API     27041584
# 1667  physically_interacts_with       SEMMED  SEMMED Gene API     27041584
#
#      output_type output_name       output_id
# 1663        Gene       U2AF2  NCBIGene:11338
# 1664        Gene       U2AF2  NCBIGene:11338
# 1665        Gene       U2AF2  NCBIGene:11338
# 1666        Gene       U2AF2  NCBIGene:11338
# 1667        Gene       U2AF2  NCBIGene:11338

# %%
# create dictionary of gene reults whereby each Gene has values for the number of occurrences of the gene in results
# and the number of publications connecting the disease -> intermediates -> gene
disease_to_all_nodes_to_genes_results = {}
disease_to_all_nodes_to_genes_genes = list(disease_to_all_nodes_to_genes["output_name"]) # create list of genes
disease_to_all_nodes_to_genes_genes = list(dict.fromkeys(disease_to_all_nodes_to_genes_genes))  # remove duplicates

for gene in disease_to_all_nodes_to_genes_genes: 
    disease_to_all_nodes_to_genes_results[gene] = {
        'gene_count' : 0,
        'publications': []
    }

for index, row in disease_to_all_nodes_to_genes.iterrows():
    disease_to_all_nodes_to_genes_results[row['output_name']]['gene_count'] = disease_to_all_nodes_to_genes_results[row['output_name']]['gene_count'] + 1
    if(row['pred1_pubmed'] != None): 
        disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] = disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] + row['pred1_pubmed'].split(",")
    if(row['pred2_pubmed'] != None): 
        disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] = disease_to_all_nodes_to_genes_results[row['output_name']]['publications'] + row['pred2_pubmed'].split(",")

disease_to_all_nodes_to_genes_results = dict(sorted(disease_to_all_nodes_to_genes_results.items(), key = lambda x: x[1]['gene_count'], reverse = True))
# disease_to_all_nodes_to_genes_results

for key,value in disease_to_all_nodes_to_genes_results.items(): 
    disease_to_all_nodes_to_genes_results[key]['publications'] = list(dict.fromkeys(disease_to_all_nodes_to_genes_results[key]['publications']))
    
        
# printing top 10   
print("Top 10 Gene Occurrences : ")
{A:N['gene_count'] for (A,N) in [x for x in disease_to_all_nodes_to_genes_results.items()][:10]}
# Out:
# Top 10 Gene Occurrences :
# {'TNF': 472,
#  'VEGFA': 423,
#  'AKT1': 313,
#  'ESR1': 311,
#  'INS': 283,
#  'TP53': 268,
#  'MMP9': 267,
#  'TGFB1': 259,
#  'EGFR': 255,
#  'CAT': 255}

# %% [markdown]
# ## 4. Determine Genes to Further Analyze

# %%
# get list of genes based off of "max" gene parameters
disease_top_genes_list = ([A for (A,N) in [x for x in disease_to_gene_results.items()][:max_one_step_genes]]
    + [A for (A,N) in [x for x in disease_to_all_nodes_to_genes_results.items()][:max_two_step_genes]])

disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
disease_top_genes_list
# Out:
# ['CDSN',
#  'TFPI',
#  'F5',
#  'SSB',
#  'PROS1',
#  'CD82',
#  'KLK3',
#  'SERPINE1',
#  'SERPINB2',
#  'JAK2',
#  'TWIST1',
#  'TUBB4B',
#  'NEUROD1',
#  'CP',
#  'GPI',
#  'F8',
#  'PLAT',
#  'PLG',
#  'PROC',
#  'LPA',
#  'TNF',
#  'VEGFA',
#  'AKT1',
#  'ESR1',
#  'INS',
#  'TP53',
#  'MMP9',
#  'TGFB1',
#  'EGFR',
#  'CAT',
#  'MMP2',
#  'LEP',
#  'IL6',
#  'CA2',
#  'CAMP',
#  'MTHFR',
#  'CD4',
#  'AR',
#  'IFNA1',
#  'MAPK1',
#  'FAS',
#  'PTH',
#  'STAT3',
#  'FOS',
#  'APP',
#  'CDKN1A',
#  'ALB',
#  'IL2',
#  'VWF',
#  'MPO',
#  'TLR4',
#  'CCL2',
#  'POMC',
#  'LPL',
#  'MAPK8',
#  'REN',
#  'EGF',
#  'LOX',
#  'CISH',
#  'CCND1',
#  'IL10',
#  'CD40',
#  'APOB',
#  'CRK',
#  'ACE',
#  'TH',
#  'ESR2',
#  'TIMP1',
#  'BAX',
#  'PGR',
#  'WDTC1',
#  'TCEAL1',
#  'GRK2',
#  'HSPA4',
#  'ATM',
#  'CD36',
#  'PTGS2',
#  'ERVK-10',
#  'PIK3CA',
#  'H3P16',
#  'MTOR',
#  'RHO',
#  'ABCB1',
#  'KIT',
#  'PTEN',
#  'PPARA',
#  'CXCR4',
#  'CDKN2A',
#  'IGF1',
#  'RELA',
#  'ADAMTS13',
#  'GABPA',
#  'CD44',
#  'TAT',
#  'ANG',
#  'PGF',
#  'TTR',
#  'MYC',
#  'ITGB2',
#  'BRCA1',
#  'ADA',
#  'RHOA',
#  'STAT5A',
#  'ITGAM',
#  'TF',
#  'EGR1',
#  'SST',
#  'MAPK3',
#  'SIRT1']

# %% [markdown]
# ## 5. Get Disease Symptoms related to Genes
# Genes -> Symptoms, then filter based on disease symptoms

# %%
# get gene inputs through hint module
gene_inputs = []
for gene in disease_top_genes_list: 
    try: 
        gene_input = ht.query(gene)["Gene"][0]
        gene_inputs.append(gene_input)
    except: 
        print(gene + ' Failed')

print(gene_inputs)
# Out:
# APP Failed
# [{'NCBIGene': '1041', 'name': 'corneodesmosin', 'SYMBOL': 'CDSN', 'UMLS': 'C1413299', 'HGNC': '1802', 'UNIPROTKB': 'Q15517', 'ENSEMBL': 'ENSG00000137197', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1041'}, 'display': 'NCBIGene(1041) ENSEMBL(ENSG00000137197) HGNC(1802) UMLS(C1413299) UNIPROTKB(Q15517) SYMBOL(CDSN)', 'type': 'Gene'}, {'NCBIGene': '7035', 'name': 'tissue factor pathway inhibitor', 'SYMBOL': 'TFPI', 'UMLS': 'C1420705', 'HGNC': '11760', 'UNIPROTKB': 'P10646', 'ENSEMBL': 'ENSG00000003436', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7035'}, 'display': 'NCBIGene(7035) ENSEMBL(ENSG00000003436) HGNC(11760) UMLS(C1420705) UNIPROTKB(P10646) SYMBOL(TFPI)', 'type': 'Gene'}, {'NCBIGene': '2153', 'name': 'coagulation factor V', 'SYMBOL': 'F5', 'UMLS': 'C1414509', 'HGNC': '3542', 'UNIPROTKB': 'P12259', 'ENSEMBL': 'ENSG00000198734', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2153'}, 'display': 'NCBIGene(2153) ENSEMBL(ENSG00000198734) HGNC(3542) UMLS(C1414509) UNIPROTKB(P12259) SYMBOL(F5)', 'type': 'Gene'}, {'NCBIGene': '6741', 'name': 'small RNA binding exonuclease protection factor La', 'SYMBOL': 'SSB', 'UMLS': 'C1420423', 'HGNC': '11316', 'UNIPROTKB': 'P05455', 'ENSEMBL': 'ENSG00000138385', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6741'}, 'display': 'NCBIGene(6741) ENSEMBL(ENSG00000138385) HGNC(11316) UMLS(C1420423) UNIPROTKB(P05455) SYMBOL(SSB)', 'type': 'Gene'}, {'NCBIGene': '5627', 'name': 'protein S', 'SYMBOL': 'PROS1', 'UMLS': 'C1418948', 'HGNC': '9456', 'UNIPROTKB': 'P07225', 'ENSEMBL': 'ENSG00000184500', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5627'}, 'display': 'NCBIGene(5627) ENSEMBL(ENSG00000184500) HGNC(9456) UMLS(C1418948) UNIPROTKB(P07225) SYMBOL(PROS1)', 'type': 'Gene'}, {'NCBIGene': '3732', 'name': 'CD82 molecule', 'SYMBOL': 'CD82', 'UMLS': 'C0812444', 'HGNC': '6210', 'UNIPROTKB': 'P27701', 'ENSEMBL': 'ENSG00000085117', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3732'}, 'display': 'NCBIGene(3732) ENSEMBL(ENSG00000085117) HGNC(6210) UMLS(C0812444) UNIPROTKB(P27701) SYMBOL(CD82)', 'type': 'Gene'}, {'NCBIGene': '354', 'name': 'kallikrein related peptidase 3', 'SYMBOL': 'KLK3', 'UMLS': 'C1366489', 'HGNC': '6364', 'UNIPROTKB': 'P07288', 'ENSEMBL': 'ENSG00000142515', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '354'}, 'display': 'NCBIGene(354) ENSEMBL(ENSG00000142515) HGNC(6364) UMLS(C1366489) UNIPROTKB(P07288) SYMBOL(KLK3)', 'type': 'Gene'}, {'NCBIGene': '5054', 'name': 'serpin family E member 1', 'SYMBOL': 'SERPINE1', 'UMLS': 'C1418252', 'HGNC': '8583', 'UNIPROTKB': 'P05121', 'ENSEMBL': 'ENSG00000106366', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5054'}, 'display': 'NCBIGene(5054) ENSEMBL(ENSG00000106366) HGNC(8583) UMLS(C1418252) UNIPROTKB(P05121) SYMBOL(SERPINE1)', 'type': 'Gene'}, {'NCBIGene': '5055', 'name': 'serpin family B member 2', 'SYMBOL': 'SERPINB2', 'UMLS': 'C1418253', 'HGNC': '8584', 'UNIPROTKB': 'P05120', 'ENSEMBL': 'ENSG00000197632', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5055'}, 'display': 'NCBIGene(5055) ENSEMBL(ENSG00000197632) HGNC(8584) UMLS(C1418253) UNIPROTKB(P05120) SYMBOL(SERPINB2)', 'type': 'Gene'}, {'NCBIGene': '3717', 'name': 'Janus kinase 2', 'SYMBOL': 'JAK2', 'UMLS': 'C1334291', 'HGNC': '6192', 'UNIPROTKB': 'O60674', 'ENSEMBL': 'ENSG00000096968', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3717'}, 'display': 'NCBIGene(3717) ENSEMBL(ENSG00000096968) HGNC(6192) UMLS(C1334291) UNIPROTKB(O60674) SYMBOL(JAK2)', 'type': 'Gene'}, {'NCBIGene': '7291', 'name': 'twist family bHLH transcription factor 1', 'SYMBOL': 'TWIST1', 'UMLS': 'C1421244', 'HGNC': '12428', 'UNIPROTKB': 'Q15672', 'ENSEMBL': 'ENSG00000122691', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7291'}, 'display': 'NCBIGene(7291) ENSEMBL(ENSG00000122691) HGNC(12428) UMLS(C1421244) UNIPROTKB(Q15672) SYMBOL(TWIST1)', ...

# %%
# get genes to symptoms, which could be represented as a phenotypic feature, biological process, or diesase
genes_to_symptoms = predict_many(gene_inputs, ['PhenotypicFeature','BiologicalProcess','Disease'])
print(genes_to_symptoms.shape)
genes_to_symptoms.head()
# Out:
# Running: corneodesmosin --> output type PhenotypicFeature
# Running: corneodesmosin --> output type BiologicalProcess
# Running: corneodesmosin --> output type Disease
# Running: tissue factor pathway inhibitor --> output type PhenotypicFeature
# Running: tissue factor pathway inhibitor --> output type BiologicalProcess
# Running: tissue factor pathway inhibitor --> output type Disease
# Running: coagulation factor V --> output type PhenotypicFeature
# Running: coagulation factor V --> output type BiologicalProcess
# Running: coagulation factor V --> output type Disease
# Running: small RNA binding exonuclease protection factor La --> output type PhenotypicFeature
# Running: small RNA binding exonuclease protection factor La --> output type BiologicalProcess
# Running: small RNA binding exonuclease protection factor La --> output type Disease
# Running: protein S --> output type PhenotypicFeature
# Running: protein S --> output type BiologicalProcess
# Running: protein S --> output type Disease
# Running: CD82 molecule --> output type PhenotypicFeature
# Running: CD82 molecule --> output type BiologicalProcess
# Running: CD82 molecule --> output type Disease
# Running: kallikrein related peptidase 3 --> output type PhenotypicFeature
# Running: kallikrein related peptidase 3 --> output type BiologicalProcess
# Running: kallikrein related peptidase 3 --> output type Disease
# Running: serpin family E member 1 --> output type PhenotypicFeature
# Running: serpin family E member 1 --> output type BiologicalProcess
# Running: serpin family E member 1 --> output type Disease
# Running: serpin family B member 2 --> output type PhenotypicFeature
# Running: serpin family B member 2 --> output type BiologicalProcess
# Running: serpin family B member 2 --> output type Disease
# Running: Janus kinase 2 --> output type PhenotypicFeature
# Running: Janus kinase 2 --> output type BiologicalProcess
# Running: Janus kinase 2 --> output type Disease
# Running: twist family bHLH transcription factor 1 --> output type PhenotypicFeature
# Running: twist family bHLH transcription factor 1 --> output type BiologicalProcess
# Running: twist family bHLH transcription factor 1 --> output type Disease
# Running: tubulin beta 4B class IVb --> output type PhenotypicFeature
# Running: tubulin beta 4B class IVb --> output type BiologicalProcess
# Running: tubulin beta 4B class IVb --> output type Disease
# Running: neuronal differentiation 1 --> output type PhenotypicFeature
# Running: neuronal differentiation 1 --> output type BiologicalProcess
# Running: neuronal differentiation 1 --> output type Disease
# Running: ceruloplasmin --> output type PhenotypicFeature
# Running: ceruloplasmin --> output type BiologicalProcess
# Running: ceruloplasmin --> output type Disease
# Running: glucose-6-phosphate isomerase --> output type PhenotypicFeature
# Running: glucose-6-phosphate isomerase --> output type BiologicalProcess
# Running: glucose-6-phosphate isomerase --> output type Disease
# Running: coagulation factor VIII --> output type PhenotypicFeature
# Running: coagulation factor VIII --> output type BiologicalProcess
# Running: coagulation factor VIII --> output type Disease
# Running: plasminogen activator, tissue type --> output type PhenotypicFeature
# Running: plasminogen activator, tissue type --> output type BiologicalProcess
# Running: plasminogen activator, tissue type --> output type Disease
# Running: plasminogen --> output type PhenotypicFeature
# Running: plasminogen --> output type BiologicalProcess
# Running: plasminogen --> output type Disease
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type PhenotypicFeature
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type BiologicalProcess
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type Disease
# Running: lipoprotein(a) --> output type PhenotypicFeature
# Running: lipoprotein(a) --> output type BiologicalProcess
# Running: lipoprotein(a) --> output type Disease
# Running: tumor necrosis factor --> output type PhenotypicFeature
# Running: tumor necrosis factor --> output type BiologicalProcess
# Running: tumor necrosis factor --> output type Disease
# Running: vascular endothelial growth factor A --> output type PhenotypicFeature
# Running: vascular endothelial growth factor A --> output type BiologicalProcess
# Running: vascular endothelial growth factor A --> output type Disease
# Running: AKT serine/threonine kinase 1 --> output type PhenotypicFeature
# Running: AKT serine/threonine kinase 1 --> output type BiologicalProcess
# Running: AKT serine/threonine kinase 1 --> output type Disease
# Running: estrogen receptor 1 --> output type PhenotypicFeature
# Running: estrogen receptor 1 --> output type BiologicalProcess
# Running: estrogen receptor 1 --> output type Disease
# Running: insulin --> output type PhenotypicFeature
# Running: insulin --> output type BiologicalProcess
# Running: insulin --> output type Disease
# Running: tumor protein p53 --> output type PhenotypicFeature
# Running: tumor protein p53 --> output type BiologicalProcess
# Running: tumor protein p53 --> output type Disease
# Running: matrix metallopeptidase 9 --> output type PhenotypicFeature
# Running: matrix metallopeptidase 9 --> output type BiologicalProcess
# Running: matrix metallopeptidase 9 --> output type Disease
# Running: transforming growth factor beta 1 --> output type PhenotypicFeature
# Running: transforming growth factor beta 1 --> output type BiologicalProcess
# Running: transforming growth factor beta 1 --> output type Disease
# Running: epidermal growth factor receptor --> output type PhenotypicFeature
# Running: epidermal growth factor receptor --> output type BiologicalProcess
# Running: epidermal growth factor receptor --> output type Disease
# Running: catalase --> output type PhenotypicFeature
# Running: catalase --> output type BiologicalProcess
# Running: catalase --> output type Disease
# Running: matrix metallopeptidase 2 --> output type PhenotypicFeature
# Running: matrix metallopeptidase 2 --> output type BiologicalProcess
# Running: matrix metallopeptidase 2 --> output type Disease
# Running: leptin --> output type PhenotypicFeature
# Running: leptin --> output type BiologicalProcess
# Running: leptin --> output type Disease
# Running: interleukin 6 --> output type PhenotypicFeature
# Running: interleukin 6 --> output type BiologicalProcess
# Running: interleukin 6 --> output type Disease
# Running: carbonic anhydrase 2 --> output type PhenotypicFeature
# Running: carbonic anhydrase 2 --> output type BiologicalProcess
# Running: carbonic anhydrase 2 --> output type Disease
# Running: cathelicidin antimicrobial peptide --> output type PhenotypicFeature
# Running: cathelicidin antimicrobial peptide --> output type BiologicalProcess
# Running: cathelicidin antimicrobial peptide --> output type Disease
# Running: methylenetetrahydrofolate reductase --> output type PhenotypicFeature
# Running: methylenetetrahydrofolate reductase --> output type BiologicalProcess
# Running: methylenetetrahydrofolate reductase --> output type Disease
# Running: CD4 molecule --> output type PhenotypicFeature
# Running: CD4 molecule --> output type BiologicalProcess
# Running: CD4 molecule --> output type Disease
# Running: androgen receptor --> output type PhenotypicFeature
# Running: androgen receptor --> output type BiologicalProcess
# Running: androgen receptor --> output type Disease
# Running: interferon alpha 1 --> output type PhenotypicFeature
# Running: interferon alpha 1 --> output type BiologicalProcess
# Running: interferon alpha 1 --> output type Disease
# Running: mitogen-activated protein kinase 1 --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 1 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 1 --> output type Disease
# Running: Fas cell surface death receptor --> output type PhenotypicFeature
# Running: Fas cell surface death receptor --> output type BiologicalProcess
# Running: Fas cell surface death receptor --> output type Disease
# Running: parathyroid hormone --> output type PhenotypicFeature
# Running: parathyroid hormone --> output type BiologicalProcess
# Running: parathyroid hormone --> output type Disease
# Running: signal transducer and activator of transcription 3 --> output type PhenotypicFeature
# Running: signal transducer and activator of transcription 3 --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 3 --> output type Disease
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type PhenotypicFeature
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type BiologicalProcess
# Running: Fos proto-oncogene, AP-1 transcription factor subunit --> output type Disease
# Running: cyclin dependent kinase inhibitor 1A --> output type PhenotypicFeature
# Running: cyclin dependent kinase inhibitor 1A --> output type BiologicalProcess
# Running: cyclin dependent kinase inhibitor 1A --> output type Disease
# Running: albumin --> output type PhenotypicFeature
# Running: albumin --> output type BiologicalProcess
# Running: albumin --> output type Disease
# Running: interleukin 2 --> output type PhenotypicFeature
# Running: interleukin 2 --> output type BiologicalProcess
# Running: interleukin 2 --> output type Disease
# Running: von Willebrand factor --> output type PhenotypicFeature
# Running: von Willebrand factor --> output type BiologicalProcess
# Running: von Willebrand factor --> output type Disease
# Running: myeloperoxidase --> output type PhenotypicFeature
# Running: myeloperoxidase --> output type BiologicalProcess
# Running: myeloperoxidase --> output type Disease
# Running: toll like receptor 4 --> output type PhenotypicFeature
# Running: toll like receptor 4 --> output type BiologicalProcess
# Running: toll like receptor 4 --> output type Disease
# Running: C-C motif chemokine ligand 2 --> output type PhenotypicFeature
# Running: C-C motif chemokine ligand 2 --> output type BiologicalProcess
# Running: C-C motif chemokine ligand 2 --> output type Disease
# Running: proopiomelanocortin --> output type PhenotypicFeature
# Running: proopiomelanocortin --> output type BiologicalProcess
# Running: proopiomelanocortin --> output type Disease
# Running: lipoprotein lipase --> output type PhenotypicFeature
# Running: lipoprotein lipase --> output type BiologicalProcess
# Running: lipoprotein lipase --> output type Disease
# Running: mitogen-activated protein kinase 8 --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 8 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 8 --> output type Disease
# Running: renin --> output type PhenotypicFeature
# Running: renin --> output type BiologicalProcess
# Running: renin --> output type Disease
# Running: epidermal growth factor --> output type PhenotypicFeature
# Running: epidermal growth factor --> output type BiologicalProcess
# Running: epidermal growth factor --> output type Disease
# Running: lysyl oxidase --> output type PhenotypicFeature
# Running: lysyl oxidase --> output type BiologicalProcess
# Running: lysyl oxidase --> output type Disease
# Running: cytokine inducible SH2 containing protein --> output type PhenotypicFeature
# Running: cytokine inducible SH2 containing protein --> output type BiologicalProcess
# Running: cytokine inducible SH2 containing protein --> output type Disease
# Running: cyclin D1 --> output type PhenotypicFeature
# Running: cyclin D1 --> output type BiologicalProcess
# Running: cyclin D1 --> output type Disease
# Running: interleukin 10 --> output type PhenotypicFeature
# Running: interleukin 10 --> output type BiologicalProcess
# Running: interleukin 10 --> output type Disease
# Running: CD40 molecule --> output type PhenotypicFeature
# Running: CD40 molecule --> output type BiologicalProcess
# Running: CD40 molecule --> output type Disease
# Running: apolipoprotein B --> output type PhenotypicFeature
# Running: apolipoprotein B --> output type BiologicalProcess
# Running: apolipoprotein B --> output type Disease
# Running: CRK proto-oncogene, adaptor protein --> output type PhenotypicFeature
# Running: CRK proto-oncogene, adaptor protein --> output type BiologicalProcess
# Running: CRK proto-oncogene, adaptor protein --> output type Disease
# Running: angiotensin I converting enzyme --> output type PhenotypicFeature
# Running: angiotensin I converting enzyme --> output type BiologicalProcess
# Running: angiotensin I converting enzyme --> output type Disease
# Running: tyrosine hydroxylase --> output type PhenotypicFeature
# Running: tyrosine hydroxylase --> output type BiologicalProcess
# Running: tyrosine hydroxylase --> output type Disease
# Running: estrogen receptor 2 --> output type PhenotypicFeature
# Running: estrogen receptor 2 --> output type BiologicalProcess
# Running: estrogen receptor 2 --> output type Disease
# Running: TIMP metallopeptidase inhibitor 1 --> output type PhenotypicFeature
# Running: TIMP metallopeptidase inhibitor 1 --> output type BiologicalProcess
# Running: TIMP metallopeptidase inhibitor 1 --> output type Disease
# Running: BCL2 associated X, apoptosis regulator --> output type PhenotypicFeature
# Running: BCL2 associated X, apoptosis regulator --> output type BiologicalProcess
# Running: BCL2 associated X, apoptosis regulator --> output type Disease
# Running: progesterone receptor --> output type PhenotypicFeature
# Running: progesterone receptor --> output type BiologicalProcess
# Running: progesterone receptor --> output type Disease
# Running: WD and tetratricopeptide repeats 1 --> output type PhenotypicFeature
# Running: WD and tetratricopeptide repeats 1 --> output type BiologicalProcess
# Running: WD and tetratricopeptide repeats 1 --> output type Disease
# Running: transcription elongation factor A like 1 --> output type PhenotypicFeature
# Running: transcription elongation factor A like 1 --> output type BiologicalProcess
# Running: transcription elongation factor A like 1 --> output type Disease
# Running: G protein-coupled receptor kinase 2 --> output type PhenotypicFeature
# Running: G protein-coupled receptor kinase 2 --> output type BiologicalProcess
# Running: G protein-coupled receptor kinase 2 --> output type Disease
# Running: heat shock protein family A (Hsp70) member 4 --> output type PhenotypicFeature
# Running: heat shock protein family A (Hsp70) member 4 --> output type BiologicalProcess
# Running: heat shock protein family A (Hsp70) member 4 --> output type Disease
# Running: ATM serine/threonine kinase --> output type PhenotypicFeature
# Running: ATM serine/threonine kinase --> output type BiologicalProcess
# Running: ATM serine/threonine kinase --> output type Disease
# Running: CD36 molecule --> output type PhenotypicFeature
# Running: CD36 molecule --> output type BiologicalProcess
# Running: CD36 molecule --> output type Disease
# Running: prostaglandin-endoperoxide synthase 2 --> output type PhenotypicFeature
# Running: prostaglandin-endoperoxide synthase 2 --> output type BiologicalProcess
# Running: prostaglandin-endoperoxide synthase 2 --> output type Disease
# Running: endogenous retrovirus group K member 10 --> output type PhenotypicFeature
# Running: endogenous retrovirus group K member 10 --> output type BiologicalProcess
# Running: endogenous retrovirus group K member 10 --> output type Disease
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type PhenotypicFeature
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type BiologicalProcess
# Running: phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha --> output type Disease
# Running: H3 histone pseudogene 16 --> output type PhenotypicFeature
# Running: H3 histone pseudogene 16 --> output type BiologicalProcess
# Running: H3 histone pseudogene 16 --> output type Disease
# Running: mechanistic target of rapamycin kinase --> output type PhenotypicFeature
# Running: mechanistic target of rapamycin kinase --> output type BiologicalProcess
# Running: mechanistic target of rapamycin kinase --> output type Disease
# Running: rhodopsin --> output type PhenotypicFeature
# Running: rhodopsin --> output type BiologicalProcess
# Running: rhodopsin --> output type Disease
# Running: ATP binding cassette subfamily B member 1 --> output type PhenotypicFeature
# Running: ATP binding cassette subfamily B member 1 --> output type BiologicalProcess
# Running: ATP binding cassette subfamily B member 1 --> output type Disease
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type PhenotypicFeature
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type BiologicalProcess
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type Disease
# Running: phosphatase and tensin homolog --> output type PhenotypicFeature
# Running: phosphatase and tensin homolog --> output type BiologicalProcess
# Running: phosphatase and tensin homolog --> output type Disease
# Running: peroxisome proliferator activated receptor alpha --> output type PhenotypicFeature
# Running: peroxisome proliferator activated receptor alpha --> output type BiologicalProcess
# Running: peroxisome proliferator activated receptor alpha --> output type Disease
# Running: C-X-C motif chemokine receptor 4 --> output type PhenotypicFeature
# Running: C-X-C motif chemokine receptor 4 --> output type BiologicalProcess
# Running: C-X-C motif chemokine receptor 4 --> output type Disease
# Running: cyclin dependent kinase inhibitor 2A --> output type PhenotypicFeature
# Running: cyclin dependent kinase inhibitor 2A --> output type BiologicalProcess
# Running: cyclin dependent kinase inhibitor 2A --> output type Disease
# Running: insulin like growth factor 1 --> output type PhenotypicFeature
# Running: insulin like growth factor 1 --> output type BiologicalProcess
# Running: insulin like growth factor 1 --> output type Disease
# Running: RELA proto-oncogene, NF-kB subunit --> output type PhenotypicFeature
# Running: RELA proto-oncogene, NF-kB subunit --> output type BiologicalProcess
# Running: RELA proto-oncogene, NF-kB subunit --> output type Disease
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type PhenotypicFeature
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type BiologicalProcess
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type Disease
# Running: GA binding protein transcription factor subunit alpha --> output type PhenotypicFeature
# Running: GA binding protein transcription factor subunit alpha --> output type BiologicalProcess
# Running: GA binding protein transcription factor subunit alpha --> output type Disease
# Running: CD44 molecule (Indian blood group) --> output type PhenotypicFeature
# Running: CD44 molecule (Indian blood group) --> output type BiologicalProcess
# Running: CD44 molecule (Indian blood group) --> output type Disease
# Running: tyrosine aminotransferase --> output type PhenotypicFeature
# Running: tyrosine aminotransferase --> output type BiologicalProcess
# Running: tyrosine aminotransferase --> output type Disease
# Running: angiogenin --> output type PhenotypicFeature
# Running: angiogenin --> output type BiologicalProcess
# Running: angiogenin --> output type Disease
# Running: placental growth factor --> output type PhenotypicFeature
# Running: placental growth factor --> output type BiologicalProcess
# Running: placental growth factor --> output type Disease
# Running: transthyretin --> output type PhenotypicFeature
# Running: transthyretin --> output type BiologicalProcess
# Running: transthyretin --> output type Disease
# Running: MYC proto-oncogene, bHLH transcription factor --> output type PhenotypicFeature
# Running: MYC proto-oncogene, bHLH transcription factor --> output type BiologicalProcess
# Running: MYC proto-oncogene, bHLH transcription factor --> output type Disease
# Running: integrin subunit beta 2 --> output type PhenotypicFeature
# Running: integrin subunit beta 2 --> output type BiologicalProcess
# Running: integrin subunit beta 2 --> output type Disease
# Running: BRCA1 DNA repair associated --> output type PhenotypicFeature
# Running: BRCA1 DNA repair associated --> output type BiologicalProcess
# Running: BRCA1 DNA repair associated --> output type Disease
# Running: adenosine deaminase --> output type PhenotypicFeature
# Running: adenosine deaminase --> output type BiologicalProcess
# Running: adenosine deaminase --> output type Disease
# Running: ras homolog family member A --> output type PhenotypicFeature
# Running: ras homolog family member A --> output type BiologicalProcess
# Running: ras homolog family member A --> output type Disease
# Running: signal transducer and activator of transcription 5A --> output type PhenotypicFeature
# Running: signal transducer and activator of transcription 5A --> output type BiologicalProcess
# Running: signal transducer and activator of transcription 5A --> output type Disease
# Running: integrin subunit alpha M --> output type PhenotypicFeature
# Running: integrin subunit alpha M --> output type BiologicalProcess
# Running: integrin subunit alpha M --> output type Disease
# Running: transferrin --> output type PhenotypicFeature
# Running: transferrin --> output type BiologicalProcess
# Running: transferrin --> output type Disease
# Running: early growth response 1 --> output type PhenotypicFeature
# Running: early growth response 1 --> output type BiologicalProcess
# Running: early growth response 1 --> output type Disease
# Running: somatostatin --> output type PhenotypicFeature
# Running: somatostatin --> output type BiologicalProcess
# Running: somatostatin --> output type Disease
# Running: mitogen-activated protein kinase 3 --> output type PhenotypicFeature
# Running: mitogen-activated protein kinase 3 --> output type BiologicalProcess
# Running: mitogen-activated protein kinase 3 --> output type Disease
# Running: sirtuin 1 --> output type PhenotypicFeature
# Running: sirtuin 1 --> output type BiologicalProcess
# Running: sirtuin 1 --> output type Disease
# (156106, 9)
#   input input_type       pred1 pred1_source    pred1_api pred1_pubmed  \
# 0  CDSN       Gene  related_to         None  BioLink API         None
# 1  CDSN       Gene  related_to         None  BioLink API         None
# 2  CDSN       Gene  related_to         None  BioLink API         None
# 3  CDSN       Gene  related_to         None  BioLink API         None
# 4  CDSN       Gene  related_to         None  BioLink API         None
#
#          output_type                          output_name      output_id
# 0  PhenotypicFeature                DECREASED BODY HEIGHT  UMLS:C0349588
# 1  PhenotypicFeature                         BRITTLE HAIR  UMLS:C4072837
# 2  PhenotypicFeature  DECREASED NUMBER OF SCALP FOLLICLES  UMLS:C1857042
# 3  PhenotypicFeature                               ASTHMA  UMLS:C0004096
# 4  PhenotypicFeature                             ERYTHEMA  UMLS:C0041834

# %%
# filter gene -> symptoms table to only include rows where symptoms match disease symptoms
indices_with_symptom_outputs = [i for i, val in enumerate([x.upper() for x in list(genes_to_symptoms['output_name'])]) if val in disease_symptoms]
relevant_genes_to_symptoms_df = genes_to_symptoms.iloc[indices_with_symptom_outputs]
relevant_genes_to_symptoms_df.head()
# Out:
#     input input_type       pred1 pred1_source        pred1_api  \
# 119  CDSN       Gene    disrupts       SEMMED  SEMMED Gene API
# 120  CDSN       Gene      causes       SEMMED  SEMMED Gene API
# 121  CDSN       Gene  related_to       SEMMED  SEMMED Gene API
# 122  CDSN       Gene     affects       SEMMED  SEMMED Gene API
# 151  CDSN       Gene      causes       SEMMED  SEMMED Gene API
#
#                    pred1_pubmed output_type                     output_name  \
# 119                     7745572     Disease  ACTIVATED PROTEIN C RESISTANCE
# 120  19036061,19764414,19803829     Disease  ACTIVATED PROTEIN C RESISTANCE
# 121                     8834124     Disease  ACTIVATED PROTEIN C RESISTANCE
# 122           11703344,16493484     Disease  ACTIVATED PROTEIN C RESISTANCE
# 151                     2146503     Disease            DEEP VEIN THROMBOSIS
#
#                output_id
# 119  MONDO:MONDO:0008560
# 120  MONDO:MONDO:0008560
# 121  MONDO:MONDO:0008560
# 122  MONDO:MONDO:0008560
# 151        UMLS:C0149871

# %%
# %store relevant_genes_to_symptoms_df
# %store -r relevant_genes_to_symptoms_df
# Out:
# Stored 'relevant_genes_to_symptoms_df' (DataFrame)

# %%
# create dictionary to keep track of symptoms a gene is related to, and the number of publications relating the 
# gene to any of the disease symptoms
symptoms_results = {}
relevant_top_genes_list = list(dict.fromkeys(list(relevant_genes_to_symptoms_df["input"])))
for x in relevant_top_genes_list:
    symptoms_results[x] = {
        "related_symptoms" : [],
        "publications": []
    }
for index, row in relevant_genes_to_symptoms_df.iterrows():
    symptoms_results[row["input"]]["related_symptoms"].append(row["output_name"])
    if(row["pred1_pubmed"]):
        symptoms_results[row["input"]]["publications"] = symptoms_results[row["input"]]["publications"] + row["pred1_pubmed"].split(',')

for key,value in symptoms_results.items(): 
    symptoms_results[key]['publications'] = list(dict.fromkeys(symptoms_results[key]['publications']))
            
        
# print(symptoms_results)

# %% [markdown]
# ## 6. Get Genes Edges Out Count

# %%
# get edges out count from genes to any node type to get rough estimate of how well researched a gene is
relevant_gene_inputs = []

for gene_input in gene_inputs: 
    if(gene_input['SYMBOL'] in relevant_top_genes_list):
        relevant_gene_inputs.append(gene_input)
        
all_gene_edges_out = predict_many(relevant_gene_inputs, ALL_NODE_TYPES)
edges_out_genes_list = list(all_gene_edges_out["input"])
gene_edges_out = {x:edges_out_genes_list.count(x) for x in edges_out_genes_list}
print(gene_edges_out)
# Out:
# Running: corneodesmosin --> output type Gene
# Running: corneodesmosin --> output type SequenceVariant
# Running: corneodesmosin --> output type ChemicalSubstance
# Running: corneodesmosin --> output type Disease
# Running: corneodesmosin --> output type MolecularActivity
# Running: corneodesmosin --> output type BiologicalProcess
# Running: corneodesmosin --> output type CellularComponent
# Running: corneodesmosin --> output type Pathway
# Running: corneodesmosin --> output type AnatomicalEntity
# Running: corneodesmosin --> output type PhenotypicFeature
# Running: tissue factor pathway inhibitor --> output type Gene
# Running: tissue factor pathway inhibitor --> output type SequenceVariant
# Running: tissue factor pathway inhibitor --> output type ChemicalSubstance
# Running: tissue factor pathway inhibitor --> output type Disease
# Running: tissue factor pathway inhibitor --> output type MolecularActivity
# Running: tissue factor pathway inhibitor --> output type BiologicalProcess
# Running: tissue factor pathway inhibitor --> output type CellularComponent
# Running: tissue factor pathway inhibitor --> output type Pathway
# Running: tissue factor pathway inhibitor --> output type AnatomicalEntity
# Running: tissue factor pathway inhibitor --> output type PhenotypicFeature
# Running: coagulation factor V --> output type Gene
# Running: coagulation factor V --> output type SequenceVariant
# Running: coagulation factor V --> output type ChemicalSubstance
# Running: coagulation factor V --> output type Disease
# Running: coagulation factor V --> output type MolecularActivity
# Running: coagulation factor V --> output type BiologicalProcess
# Running: coagulation factor V --> output type CellularComponent
# Running: coagulation factor V --> output type Pathway
# Running: coagulation factor V --> output type AnatomicalEntity
# Running: coagulation factor V --> output type PhenotypicFeature
# Running: small RNA binding exonuclease protection factor La --> output type Gene
# Running: small RNA binding exonuclease protection factor La --> output type SequenceVariant
# Running: small RNA binding exonuclease protection factor La --> output type ChemicalSubstance
# Running: small RNA binding exonuclease protection factor La --> output type Disease
# Running: small RNA binding exonuclease protection factor La --> output type MolecularActivity
# Running: small RNA binding exonuclease protection factor La --> output type BiologicalProcess
# Running: small RNA binding exonuclease protection factor La --> output type CellularComponent
# Running: small RNA binding exonuclease protection factor La --> output type Pathway
# Running: small RNA binding exonuclease protection factor La --> output type AnatomicalEntity
# Running: small RNA binding exonuclease protection factor La --> output type PhenotypicFeature
# Running: protein S --> output type Gene
# Running: protein S --> output type SequenceVariant
# Running: protein S --> output type ChemicalSubstance
# Running: protein S --> output type Disease
# Running: protein S --> output type MolecularActivity
# Running: protein S --> output type BiologicalProcess
# Running: protein S --> output type CellularComponent
# Running: protein S --> output type Pathway
# Running: protein S --> output type AnatomicalEntity
# Running: protein S --> output type PhenotypicFeature
# Running: CD82 molecule --> output type Gene
# Running: CD82 molecule --> output type SequenceVariant
# Running: CD82 molecule --> output type ChemicalSubstance
# Running: CD82 molecule --> output type Disease
# Running: CD82 molecule --> output type MolecularActivity
# Running: CD82 molecule --> output type BiologicalProcess
# Running: CD82 molecule --> output type CellularComponent
# Running: CD82 molecule --> output type Pathway
# Running: CD82 molecule --> output type AnatomicalEntity
# Running: CD82 molecule --> output type PhenotypicFeature
# Running: kallikrein related peptidase 3 --> output type Gene
# Running: kallikrein related peptidase 3 --> output type SequenceVariant
# Running: kallikrein related peptidase 3 --> output type ChemicalSubstance
# Running: kallikrein related peptidase 3 --> output type Disease
# Running: kallikrein related peptidase 3 --> output type MolecularActivity
# Running: kallikrein related peptidase 3 --> output type BiologicalProcess
# Running: kallikrein related peptidase 3 --> output type CellularComponent
# Running: kallikrein related peptidase 3 --> output type Pathway
# Running: kallikrein related peptidase 3 --> output type AnatomicalEntity
# Running: kallikrein related peptidase 3 --> output type PhenotypicFeature
# Running: serpin family E member 1 --> output type Gene
# Running: serpin family E member 1 --> output type SequenceVariant
# Running: serpin family E member 1 --> output type ChemicalSubstance
# Running: serpin family E member 1 --> output type Disease
# Running: serpin family E member 1 --> output type MolecularActivity
# Running: serpin family E member 1 --> output type BiologicalProcess
# Running: serpin family E member 1 --> output type CellularComponent
# Running: serpin family E member 1 --> output type Pathway
# Running: serpin family E member 1 --> output type AnatomicalEntity
# Running: serpin family E member 1 --> output type PhenotypicFeature
# Running: serpin family B member 2 --> output type Gene
# Running: serpin family B member 2 --> output type SequenceVariant
# Running: serpin family B member 2 --> output type ChemicalSubstance
# Running: serpin family B member 2 --> output type Disease
# Running: serpin family B member 2 --> output type MolecularActivity
# Running: serpin family B member 2 --> output type BiologicalProcess
# Running: serpin family B member 2 --> output type CellularComponent
# Running: serpin family B member 2 --> output type Pathway
# Running: serpin family B member 2 --> output type AnatomicalEntity
# Running: serpin family B member 2 --> output type PhenotypicFeature
# Running: Janus kinase 2 --> output type Gene
# Running: Janus kinase 2 --> output type SequenceVariant
# Running: Janus kinase 2 --> output type ChemicalSubstance
# Running: Janus kinase 2 --> output type Disease
# Running: Janus kinase 2 --> output type MolecularActivity
# Running: Janus kinase 2 --> output type BiologicalProcess
# Running: Janus kinase 2 --> output type CellularComponent
# Running: Janus kinase 2 --> output type Pathway
# Running: Janus kinase 2 --> output type AnatomicalEntity
# Running: Janus kinase 2 --> output type PhenotypicFeature
# Running: twist family bHLH transcription factor 1 --> output type Gene
# Running: twist family bHLH transcription factor 1 --> output type SequenceVariant
# Running: twist family bHLH transcription factor 1 --> output type ChemicalSubstance
# Running: twist family bHLH transcription factor 1 --> output type Disease
# Running: twist family bHLH transcription factor 1 --> output type MolecularActivity
# Running: twist family bHLH transcription factor 1 --> output type BiologicalProcess
# Running: twist family bHLH transcription factor 1 --> output type CellularComponent
# Running: twist family bHLH transcription factor 1 --> output type Pathway
# Running: twist family bHLH transcription factor 1 --> output type AnatomicalEntity
# Running: twist family bHLH transcription factor 1 --> output type PhenotypicFeature
# Running: tubulin beta 4B class IVb --> output type Gene
# Running: tubulin beta 4B class IVb --> output type SequenceVariant
# Running: tubulin beta 4B class IVb --> output type ChemicalSubstance
# Running: tubulin beta 4B class IVb --> output type Disease
# Running: tubulin beta 4B class IVb --> output type MolecularActivity
# Running: tubulin beta 4B class IVb --> output type BiologicalProcess
# Running: tubulin beta 4B class IVb --> output type CellularComponent
# Running: tubulin beta 4B class IVb --> output type Pathway
# Running: tubulin beta 4B class IVb --> output type AnatomicalEntity
# Running: tubulin beta 4B class IVb --> output type PhenotypicFeature
# Running: neuronal differentiation 1 --> output type Gene
# Running: neuronal differentiation 1 --> output type SequenceVariant
# Running: neuronal differentiation 1 --> output type ChemicalSubstance
# Running: neuronal differentiation 1 --> output type Disease
# Running: neuronal differentiation 1 --> output type MolecularActivity
# Running: neuronal differentiation 1 --> output type BiologicalProcess
# Running: neuronal differentiation 1 --> output type CellularComponent
# Running: neuronal differentiation 1 --> output type Pathway
# Running: neuronal differentiation 1 --> output type AnatomicalEntity
# Running: neuronal differentiation 1 --> output type PhenotypicFeature
# Running: ceruloplasmin --> output type Gene
# Running: ceruloplasmin --> output type SequenceVariant
# Running: ceruloplasmin --> output type ChemicalSubstance
# Running: ceruloplasmin --> output type Disease
# Running: ceruloplasmin --> output type MolecularActivity
# Running: ceruloplasmin --> output type BiologicalProcess
# Running: ceruloplasmin --> output type CellularComponent
# Running: ceruloplasmin --> output type Pathway
# Running: ceruloplasmin --> output type AnatomicalEntity
# Running: ceruloplasmin --> output type PhenotypicFeature
# Running: glucose-6-phosphate isomerase --> output type Gene
# Running: glucose-6-phosphate isomerase --> output type SequenceVariant
# Running: glucose-6-phosphate isomerase --> output type ChemicalSubstance
# Running: glucose-6-phosphate isomerase --> output type Disease
# Running: glucose-6-phosphate isomerase --> output type MolecularActivity
# Running: glucose-6-phosphate isomerase --> output type BiologicalProcess
# Running: glucose-6-phosphate isomerase --> output type CellularComponent
# Running: glucose-6-phosphate isomerase --> output type Pathway
# Running: glucose-6-phosphate isomerase --> output type AnatomicalEntity
# Running: glucose-6-phosphate isomerase --> output type PhenotypicFeature
# Running: coagulation factor VIII --> output type Gene
# Running: coagulation factor VIII --> output type SequenceVariant
# Running: coagulation factor VIII --> output type ChemicalSubstance
# Running: coagulation factor VIII --> output type Disease
# Running: coagulation factor VIII --> output type MolecularActivity
# Running: coagulation factor VIII --> output type BiologicalProcess
# Running: coagulation factor VIII --> output type CellularComponent
# Running: coagulation factor VIII --> output type Pathway
# Running: coagulation factor VIII --> output type AnatomicalEntity
# Running: coagulation factor VIII --> output type PhenotypicFeature
# Running: plasminogen activator, tissue type --> output type Gene
# Running: plasminogen activator, tissue type --> output type SequenceVariant
# Running: plasminogen activator, tissue type --> output type ChemicalSubstance
# Running: plasminogen activator, tissue type --> output type Disease
# Running: plasminogen activator, tissue type --> output type MolecularActivity
# Running: plasminogen activator, tissue type --> output type BiologicalProcess
# Running: plasminogen activator, tissue type --> output type CellularComponent
# Running: plasminogen activator, tissue type --> output type Pathway
# Running: plasminogen activator, tissue type --> output type AnatomicalEntity
# Running: plasminogen activator, tissue type --> output type PhenotypicFeature
# Running: plasminogen --> output type Gene
# Running: plasminogen --> output type SequenceVariant
# Running: plasminogen --> output type ChemicalSubstance
# Running: plasminogen --> output type Disease
# Running: plasminogen --> output type MolecularActivity
# Running: plasminogen --> output type BiologicalProcess
# Running: plasminogen --> output type CellularComponent
# Running: plasminogen --> output type Pathway
# Running: plasminogen --> output type AnatomicalEntity
# Running: plasminogen --> output type PhenotypicFeature
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type Gene
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type SequenceVariant
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type ChemicalSubstance
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type Disease
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type MolecularActivity
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type BiologicalProcess
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type CellularComponent
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type Pathway
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type AnatomicalEntity
# Running: protein C, inactivator of coagulation factors Va and VIIIa --> output type PhenotypicFeature
# Running: lipoprotein(a) --> output type Gene
# Running: lipoprotein(a) --> output type SequenceVariant
# Running: lipoprotein(a) --> output type ChemicalSubstance
# Running: lipoprotein(a) --> output type Disease
# Running: lipoprotein(a) --> output type MolecularActivity
# Running: lipoprotein(a) --> output type BiologicalProcess
# Running: lipoprotein(a) --> output type CellularComponent
# Running: lipoprotein(a) --> output type Pathway
# Running: lipoprotein(a) --> output type AnatomicalEntity
# Running: lipoprotein(a) --> output type PhenotypicFeature
# Running: AKT serine/threonine kinase 1 --> output type Gene
# Running: AKT serine/threonine kinase 1 --> output type SequenceVariant
# Running: AKT serine/threonine kinase 1 --> output type ChemicalSubstance
# Running: AKT serine/threonine kinase 1 --> output type Disease
# Running: AKT serine/threonine kinase 1 --> output type MolecularActivity
# Running: AKT serine/threonine kinase 1 --> output type BiologicalProcess
# Running: AKT serine/threonine kinase 1 --> output type CellularComponent
# Running: AKT serine/threonine kinase 1 --> output type Pathway
# Running: AKT serine/threonine kinase 1 --> output type AnatomicalEntity
# Running: AKT serine/threonine kinase 1 --> output type PhenotypicFeature
# Running: transforming growth factor beta 1 --> output type Gene
# Running: transforming growth factor beta 1 --> output type SequenceVariant
# Running: transforming growth factor beta 1 --> output type ChemicalSubstance
# Running: transforming growth factor beta 1 --> output type Disease
# Running: transforming growth factor beta 1 --> output type MolecularActivity
# Running: transforming growth factor beta 1 --> output type BiologicalProcess
# Running: transforming growth factor beta 1 --> output type CellularComponent
# Running: transforming growth factor beta 1 --> output type Pathway
# Running: transforming growth factor beta 1 --> output type AnatomicalEntity
# Running: transforming growth factor beta 1 --> output type PhenotypicFeature
# Running: epidermal growth factor receptor --> output type Gene
# Running: epidermal growth factor receptor --> output type SequenceVariant
# Running: epidermal growth factor receptor --> output type ChemicalSubstance
# Running: epidermal growth factor receptor --> output type Disease
# Running: epidermal growth factor receptor --> output type MolecularActivity
# Running: epidermal growth factor receptor --> output type BiologicalProcess
# Running: epidermal growth factor receptor --> output type CellularComponent
# Running: epidermal growth factor receptor --> output type Pathway
# Running: epidermal growth factor receptor --> output type AnatomicalEntity
# Running: epidermal growth factor receptor --> output type PhenotypicFeature
# Running: matrix metallopeptidase 2 --> output type Gene
# Running: matrix metallopeptidase 2 --> output type SequenceVariant
# Running: matrix metallopeptidase 2 --> output type ChemicalSubstance
# Running: matrix metallopeptidase 2 --> output type Disease
# Running: matrix metallopeptidase 2 --> output type MolecularActivity
# Running: matrix metallopeptidase 2 --> output type BiologicalProcess
# Running: matrix metallopeptidase 2 --> output type CellularComponent
# Running: matrix metallopeptidase 2 --> output type Pathway
# Running: matrix metallopeptidase 2 --> output type AnatomicalEntity
# Running: matrix metallopeptidase 2 --> output type PhenotypicFeature
# Running: methylenetetrahydrofolate reductase --> output type Gene
# Running: methylenetetrahydrofolate reductase --> output type SequenceVariant
# Running: methylenetetrahydrofolate reductase --> output type ChemicalSubstance
# Running: methylenetetrahydrofolate reductase --> output type Disease
# Running: methylenetetrahydrofolate reductase --> output type MolecularActivity
# Running: methylenetetrahydrofolate reductase --> output type BiologicalProcess
# Running: methylenetetrahydrofolate reductase --> output type CellularComponent
# Running: methylenetetrahydrofolate reductase --> output type Pathway
# Running: methylenetetrahydrofolate reductase --> output type AnatomicalEntity
# Running: methylenetetrahydrofolate reductase --> output type PhenotypicFeature
# Running: interferon alpha 1 --> output type Gene
# Running: interferon alpha 1 --> output type SequenceVariant
# Running: interferon alpha 1 --> output type ChemicalSubstance
# Running: interferon alpha 1 --> output type Disease
# Running: interferon alpha 1 --> output type MolecularActivity
# Running: interferon alpha 1 --> output type BiologicalProcess
# Running: interferon alpha 1 --> output type CellularComponent
# Running: interferon alpha 1 --> output type Pathway
# Running: interferon alpha 1 --> output type AnatomicalEntity
# Running: interferon alpha 1 --> output type PhenotypicFeature
# Running: parathyroid hormone --> output type Gene
# Running: parathyroid hormone --> output type SequenceVariant
# Running: parathyroid hormone --> output type ChemicalSubstance
# Running: parathyroid hormone --> output type Disease
# Running: parathyroid hormone --> output type MolecularActivity
# Running: parathyroid hormone --> output type BiologicalProcess
# Running: parathyroid hormone --> output type CellularComponent
# Running: parathyroid hormone --> output type Pathway
# Running: parathyroid hormone --> output type AnatomicalEntity
# Running: parathyroid hormone --> output type PhenotypicFeature
# Running: von Willebrand factor --> output type Gene
# Running: von Willebrand factor --> output type SequenceVariant
# Running: von Willebrand factor --> output type ChemicalSubstance
# Running: von Willebrand factor --> output type Disease
# Running: von Willebrand factor --> output type MolecularActivity
# Running: von Willebrand factor --> output type BiologicalProcess
# Running: von Willebrand factor --> output type CellularComponent
# Running: von Willebrand factor --> output type Pathway
# Running: von Willebrand factor --> output type AnatomicalEntity
# Running: von Willebrand factor --> output type PhenotypicFeature
# Running: cytokine inducible SH2 containing protein --> output type Gene
# Running: cytokine inducible SH2 containing protein --> output type SequenceVariant
# Running: cytokine inducible SH2 containing protein --> output type ChemicalSubstance
# Running: cytokine inducible SH2 containing protein --> output type Disease
# Running: cytokine inducible SH2 containing protein --> output type MolecularActivity
# Running: cytokine inducible SH2 containing protein --> output type BiologicalProcess
# Running: cytokine inducible SH2 containing protein --> output type CellularComponent
# Running: cytokine inducible SH2 containing protein --> output type Pathway
# Running: cytokine inducible SH2 containing protein --> output type AnatomicalEntity
# Running: cytokine inducible SH2 containing protein --> output type PhenotypicFeature
# Running: angiotensin I converting enzyme --> output type Gene
# Running: angiotensin I converting enzyme --> output type SequenceVariant
# Running: angiotensin I converting enzyme --> output type ChemicalSubstance
# Running: angiotensin I converting enzyme --> output type Disease
# Running: angiotensin I converting enzyme --> output type MolecularActivity
# Running: angiotensin I converting enzyme --> output type BiologicalProcess
# Running: angiotensin I converting enzyme --> output type CellularComponent
# Running: angiotensin I converting enzyme --> output type Pathway
# Running: angiotensin I converting enzyme --> output type AnatomicalEntity
# Running: angiotensin I converting enzyme --> output type PhenotypicFeature
# Running: G protein-coupled receptor kinase 2 --> output type Gene
# Running: G protein-coupled receptor kinase 2 --> output type SequenceVariant
# Running: G protein-coupled receptor kinase 2 --> output type ChemicalSubstance
# Running: G protein-coupled receptor kinase 2 --> output type Disease
# Running: G protein-coupled receptor kinase 2 --> output type MolecularActivity
# Running: G protein-coupled receptor kinase 2 --> output type BiologicalProcess
# Running: G protein-coupled receptor kinase 2 --> output type CellularComponent
# Running: G protein-coupled receptor kinase 2 --> output type Pathway
# Running: G protein-coupled receptor kinase 2 --> output type AnatomicalEntity
# Running: G protein-coupled receptor kinase 2 --> output type PhenotypicFeature
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type Gene
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type SequenceVariant
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type ChemicalSubstance
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type Disease
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type MolecularActivity
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type BiologicalProcess
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type CellularComponent
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type Pathway
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type AnatomicalEntity
# Running: KIT proto-oncogene, receptor tyrosine kinase --> output type PhenotypicFeature
# Running: phosphatase and tensin homolog --> output type Gene
# Running: phosphatase and tensin homolog --> output type SequenceVariant
# Running: phosphatase and tensin homolog --> output type ChemicalSubstance
# Running: phosphatase and tensin homolog --> output type Disease
# Running: phosphatase and tensin homolog --> output type MolecularActivity
# Running: phosphatase and tensin homolog --> output type BiologicalProcess
# Running: phosphatase and tensin homolog --> output type CellularComponent
# Running: phosphatase and tensin homolog --> output type Pathway
# Running: phosphatase and tensin homolog --> output type AnatomicalEntity
# Running: phosphatase and tensin homolog --> output type PhenotypicFeature
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type Gene
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type SequenceVariant
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type ChemicalSubstance
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type Disease
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type MolecularActivity
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type BiologicalProcess
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type CellularComponent
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type Pathway
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type AnatomicalEntity
# Running: ADAM metallopeptidase with thrombospondin type 1 motif 13 --> output type PhenotypicFeature
# Running: tyrosine aminotransferase --> output type Gene
# Running: tyrosine aminotransferase --> output type SequenceVariant
# Running: tyrosine aminotransferase --> output type ChemicalSubstance
# Running: tyrosine aminotransferase --> output type Disease
# Running: tyrosine aminotransferase --> output type MolecularActivity
# Running: tyrosine aminotransferase --> output type BiologicalProcess
# Running: tyrosine aminotransferase --> output type CellularComponent
# Running: tyrosine aminotransferase --> output type Pathway
# Running: tyrosine aminotransferase --> output type AnatomicalEntity
# Running: tyrosine aminotransferase --> output type PhenotypicFeature
# Running: transferrin --> output type Gene
# Running: transferrin --> output type SequenceVariant
# Running: transferrin --> output type ChemicalSubstance
# Running: transferrin --> output type Disease
# Running: transferrin --> output type MolecularActivity
# Running: transferrin --> output type BiologicalProcess
# Running: transferrin --> output type CellularComponent
# Running: transferrin --> output type Pathway
# Running: transferrin --> output type AnatomicalEntity
# Running: transferrin --> output type PhenotypicFeature
# {'CDSN': 960, 'TFPI': 1275, 'F5': 1001, 'SSB': 1380, 'PROS1': 705, 'CD82': 1676, 'KLK3': 2156, 'SERPINE1': 1935, 'SERPINB2': 1297, 'JAK2': 2975, 'TWIST1': 3211, 'TUBB4B': 2542, 'NEUROD1': 2477, 'CP': 2682, 'GPI': 3194, 'F8': 1148, 'PLAT': 2526, 'PLG': 1275, 'PROC': 821, 'LPA': 1428, 'AKT1': 16400, 'TGFB1': 9079, 'EGFR': 9004, 'MMP2': 7392, 'MTHFR': 1639, 'IFNA1': 7673, 'PTH': 4705, 'VWF': 1607, 'CISH': 6348, 'ACE': 2842, 'GRK2': 4431, 'KIT': 4843, 'PTEN': 5807, 'ADAMTS13': 760, 'TAT': 2926, 'TF': 2821}

# %%
# %store gene_edges_out
# %store -r gene_edges_out
# Out:
# Stored 'gene_edges_out' (dict)

# %% [markdown]
# ## 7. Assemble Genes related to both Disease and Disease Symptoms

# %%
# assemble final dictionary that includes all metrics for gene's connections to disease (direct and through one node)
# as well as to disease symptoms
final_dict = {}

for x in relevant_top_genes_list:
    symptoms_to_hpids = [];
    for symptom in symptoms_results[x]['related_symptoms']: 
        symptoms_to_hpids.append(symptom_to_hpid_dict[symptom])
    unique_symptoms = list(dict.fromkeys(symptoms_to_hpids))
    final_dict[x] = {
        "disease_to_gene_occurrences" : disease_to_gene_results[x]['gene_count'] if x in disease_to_gene_results else 0,
        "disease_to_gene_pub_counts" : len(disease_to_gene_results[x]['publications']) if x in disease_to_gene_results else 0,
        "disease_to_int_to_gen_occurrences" : disease_to_all_nodes_to_genes_results[x]['gene_count'] if x in disease_to_all_nodes_to_genes_results else 0,
        "disease_to_int_to_gene_pubs" : len(disease_to_all_nodes_to_genes_results[x]['publications']) if x in disease_to_all_nodes_to_genes_results else 0,
        "disease_symtpoms_gene_related_to" : symptoms_results[x]['related_symptoms'],
        "disease_symtpoms_gene_related_to_count" : len(symptoms_results[x]['related_symptoms']),
        "unique_symptoms_count": len(unique_symptoms),
        "gene_to_symptoms_pub_counts" : len(symptoms_results[x]['publications']),
        "gene_edges_out": gene_edges_out[x]
    }

# %%
final_df = pd.DataFrame(final_dict).transpose()
final_df
# Out:
#          disease_to_gene_occurrences disease_to_gene_pub_counts  \
# CDSN                               4                          7
# TFPI                               3                          1
# F5                                 3                          0
# SSB                                2                          2
# PROS1                              2                          0
# CD82                               1                          1
# KLK3                               1                          1
# SERPINE1                           1                          1
# SERPINB2                           1                          1
# JAK2                               1                          1
# TWIST1                             1                          1
# TUBB4B                             1                          1
# NEUROD1                            1                          1
# CP                                 1                          1
# GPI                                1                          1
# F8                                 1                          0
# PLAT                               1                          0
# PLG                                1                          0
# PROC                               1                          0
# LPA                                1                          0
# AKT1                               0                          0
# TGFB1                              0                          0
# EGFR                               0                          0
# MMP2                               0                          0
# MTHFR                              0                          0
# IFNA1                              0                          0
# PTH                                0                          0
# VWF                                0                          0
# CISH                               0                          0
# ACE                                0                          0
# GRK2                               0                          0
# KIT                                0                          0
# PTEN                               0                          0
# ADAMTS13                           0                          0
# TAT                                0                          0
# TF                                 0                          0
#
#          disease_to_int_to_gen_occurrences disease_to_int_to_gene_pubs  \
# CDSN                                   227                         560
# TFPI                                   176                         322
# F5                                      64                          87
# SSB                                    104                         208
# PROS1                                   73                         126
# CD82                                    41                          80
# KLK3                                   144                         483
# SERPINE1                               217                         399
# SERPINB2                               170                         332
# JAK2                                   101                         202
# TWIST1                                  89                         259
# TUBB4B                                 148                         282
# NEUROD1                                148                         289
# CP                                     121                         220
# GPI                                    171                         627
# F8                                     127                         266
# PLAT                                   176                         591
# PLG                                     94                         121
# PROC                                    56                          77
# LPA                                    115                         304
# AKT1                                   313                        1341
# TGFB1                                  259                         950
# EGFR                                   255                        1737
# MMP2                                   242                         532
# MTHFR                                  216                         441
# IFNA1                                  205                         909
# PTH                                    198                         572
# VWF                                    188                         260
# CISH                                   164                         612
# ACE                                    159                         274
# GRK2                                   151                         450
# KIT                                    143                         379
# PTEN                                   143                         628
# ADAMTS13                               135                         203
# TAT                                    132                         246
# TF                                     121                         223
#
#                            disease_symtpoms_gene_related_to  \
# CDSN      [ACTIVATED PROTEIN C RESISTANCE, ACTIVATED PRO...
# TFPI      [ACTIVATED PROTEIN C RESISTANCE, ACTIVATED PRO...
# F5        [ABNORMAL PARTIAL THROMBOPLASTIN TIME, BLOOD C...
# SSB       [ACTIVATED PROTEIN C RESISTANCE, ACTIVATED PRO...
# PROS1     [BLOOD HYPERVISCOSITY, BLOOD CLOT IN A DEEP VE...
# CD82                       [ACTIVATED PROTEIN C RESISTANCE]
# KLK3      [DEEP VEIN THROMBOSIS, ACTIVATED PROTEIN C RES...
# SERPINE1  [DEEP VEIN THROMBOSIS, ACTIVATED PROTEIN C RES...
# SERPINB2                   [ACTIVATED PROTEIN C RESISTANCE]
# JAK2      [DEEP VEIN THROMBOSIS, DEEP VEIN THROMBOSIS, A...
# TWIST1    [AUTOSOMAL DOMINANT, AUTOSOMAL DOMINANT, ACTIV...
# TUBB4B                     [ACTIVATED PROTEIN C RESISTANCE]
# NEUROD1                    [ACTIVATED PROTEIN C RESISTANCE]
# CP                         [ACTIVATED PROTEIN C RESISTANCE]
# GPI       [ACTIVATED PROTEIN C RESISTANCE, DEEP VEIN THR...
# F8        [ABNORMAL PARTIAL THROMBOPLASTIN TIME, DEEP VE...
# PLAT      [BLOOD HYPERVISCOSITY, DEEP VEIN THROMBOSIS, D...
# PLG       [DEEP VEIN THROMBOSIS, DEEP VEIN THROMBOSIS, A...
# PROC      [BLOOD CLOT IN A DEEP VEIN, BLOOD HYPERVISCOSI...
# LPA       [DEEP VEIN THROMBOSIS, DEEP VEIN THROMBOSIS, A...
# AKT1                            [BLOOD CLOT IN A DEEP VEIN]
# TGFB1            [AUTOSOMAL DOMINANT, DEEP VEIN THROMBOSIS]
# EGFR                                 [DEEP VEIN THROMBOSIS]
# MMP2           [DEEP VEIN THROMBOSIS, DEEP VEIN THROMBOSIS]
# MTHFR     [ABNORMAL PARTIAL THROMBOPLASTIN TIME, DEEP VE...
# IFNA1                                [DEEP VEIN THROMBOSIS]
# PTH                                    [AUTOSOMAL DOMINANT]
# VWF            [DEEP VEIN THROMBOSIS, DEEP VEIN THROMBOSIS]
# CISH                                 [DEEP VEIN THROMBOSIS]
# ACE                                  [DEEP VEIN THROMBOSIS]
# GRK2                                 [DEEP VEIN THROMBOSIS]
# KIT                                    [AUTOSOMAL DOMINANT]
# PTEN      [AUTOSOMAL DOMINANT, AUTOSOMAL DOMINANT, AUTOS...
# ADAMTS13       [DEEP VEIN THROMBOSIS, DEEP VEIN THROMBOSIS]
# TAT                                  [DEEP VEIN THROMBOSIS]
# TF                                   [DEEP VEIN THROMBOSIS]
#
#          disease_symtpoms_gene_related_to_count unique_symptoms_count  \
# CDSN                                          8                     2
# TFPI                                          5                     2
# F5                                            9                     5
# SSB                                           2                     1
# PROS1                                         6                     3
# CD82                                          1                     1
# KLK3                                          2                     2
# SERPINE1                                      2                     2
# SERPINB2                                      1                     1
# JAK2                                          3                     2
# TWIST1                                        3                     2
# TUBB4B                                        1                     1
# NEUROD1                                       1                     1
# CP                                            1                     1
# GPI                                           2                     2
# F8                                            4                     3
# PLAT                                          4                     3
# PLG                                           3                     2
# PROC                                          5                     3
# LPA                                           3                     2
# AKT1                                          1                     1
# TGFB1                                         2                     2
# EGFR                                          1                     1
# MMP2                                          2                     1
# MTHFR                                         5                     2
# IFNA1                                         1                     1
# PTH                                           1                     1
# VWF                                           2                     1
# CISH                                          1                     1
# ACE                                           1                     1
# GRK2                                          1                     1
# KIT                                           1                     1
# PTEN                                          4                     2
# ADAMTS13                                      2                     1
# TAT                                           1                     1
# TF                                            1                     1
#
#          gene_to_symptoms_pub_counts gene_edges_out
# CDSN                              13            960
# TFPI                               1           1275
# F5                                 9           1001
# SSB                                2           1380
# PROS1                             14            705
# CD82                               1           1676
# KLK3                               2           2156
# SERPINE1                           2           1935
# SERPINB2                           1           1297
# JAK2                               2           2975
# TWIST1                             5           3211
# TUBB4B                             1           2542
# NEUROD1                            1           2477
# CP                                 1           2682
# GPI                                2           3194
# F8                                 7           1148
# PLAT                               1           2526
# PLG                                1           1275
# PROC                               6            821
# LPA                                1           1428
# AKT1                               0          16400
# TGFB1                              4           9079
# EGFR                               1           9004
# MMP2                               2           7392
# MTHFR                              5           1639
# IFNA1                              1           7673
# PTH                                4           4705
# VWF                                1           1607
# CISH                               1           6348
# ACE                                1           2842
# GRK2                               1           4431
# KIT                                0           4843
# PTEN                              16           5807
# ADAMTS13                           2            760
# TAT                                1           2926
# TF                                 1           2821

# %%
final_df.to_csv(disease_csv_file, index = True)

# %% [markdown]
# ## 8. Look at pathways and biological processes

# %%
# pathways
gene_to_pathways = predict_many(relevant_gene_inputs, ['Pathway'])
gene_to_pathway_results = {}
gene_to_pathway_genes = list(gene_to_pathways["output_name"]) # create list of genes
gene_to_pathway_genes = list(dict.fromkeys(gene_to_pathway_genes))  # remove duplicates

for gene in gene_to_pathway_genes: 
    gene_to_pathway_results[gene] = {
        'pathway_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_pathways.iterrows():
    gene_to_pathway_results[row['output_name']]['pathway_count'] = gene_to_pathway_results[row['output_name']]['pathway_count'] + 1
    gene_to_pathway_results[row['output_name']]['genes_related'].append(row['input'])
    

gene_to_pathway_results = dict(sorted(gene_to_pathway_results.items(), key = lambda x: x[1]['pathway_count'], reverse = True))

    
gene_to_pathway_results

# %%
gene_to_bioprocess = predict_many(relevant_gene_inputs, ['BiologicalProcess'])
gene_to_bioprocess_results = {}
gene_to_bioprocess_genes = list(gene_to_bioprocess["output_name"]) # create list of genes
gene_to_bioprocess_genes = list(dict.fromkeys(gene_to_bioprocess_genes))  # remove duplicates

for gene in gene_to_bioprocess_genes: 
    gene_to_bioprocess_results[gene] = {
        'bioprocess_count' : 0,
        "genes_related" : []
    }

for index, row in gene_to_bioprocess.iterrows():
    gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] = gene_to_bioprocess_results[row['output_name']]['bioprocess_count'] + 1
    gene_to_bioprocess_results[row['output_name']]['genes_related'].append(row['input'])
    
gene_to_bioprocess_results = dict(sorted(gene_to_bioprocess_results.items(), key = lambda x: x[1]['bioprocess_count'], reverse = True))

for key in gene_to_bioprocess_results.keys(): 
    if(('C0' in key) or ('C1' in key)): 
        try: 
            name = ht.query(key)['BiologicalProcess'][0]['name']
            gene_to_bioprocess_results[name] = gene_to_bioprocess_results[key]
            del gene_to_bioprocess_results[key]
        except: 
            pass

# %%
gene_to_pathway_df = pd.DataFrame(gene_to_pathway_results).transpose()
gene_to_bioprocess_df = pd.DataFrame(gene_to_bioprocess_results).transpose()
gene_to_pathway_df.to_csv('Dravet_Syndrome_gene_to_pathways_2020_09_14.csv', index = True)
gene_to_bioprocess_df.to_csv('Dravet_Syndrome_gene_to_bioprocesses_2020_09_14.csv', index = True)
