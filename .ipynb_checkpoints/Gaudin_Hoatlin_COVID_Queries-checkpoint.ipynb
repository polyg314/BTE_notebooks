# %% [markdown]
# # COVID-19 Related Queries for BTE Use Case Exploration

# %%
import pandas as pd
## Load BTE
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

## Functions that will be used
# Check for every intermediate node type in Predict funciton
def predict_many(input_object, intermediate_node_list, output_type):
    df_list = []
    for inter in intermediate_node_list:
        try: 
            print("Intermediate Node type running:")
            print(inter)
            fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
            fc.connect(verbose=False)
            df = fc.display_table_view()
            rows = df.shape[0]
            if(rows > 0):
                df_list.append(df)
        except:
            print("FAILED")
    if(len(df_list) > 0):
        return pd.concat(df_list)
    else:
        return None
    
# all intermediate node types

node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                   'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                   'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %% [markdown]
# ## 1.1 TMPRSS2 -> NAFAMOSTAT
# ### In what ways can the TMPRSS2 Gene be connected to NAFAMOSTAT?
# ### 1.1 Query

# %%
tmprss2 = ht.query("TMPRSS2")['Gene'][0]

all_tmprss2_predictions = predict_many(tmprss2,node_type_list,'ChemicalSubstance')
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# Intermediate Node type running:
# Disease
# API 8.7 pharos failed
# API 8.4 pharos failed
# API 8.15 pharos failed
# API 8.1 pharos failed
# API 8.14 pharos failed
# API 8.12 pharos failed
# API 8.2 pharos failed
# API 8.6 pharos failed
# API 8.13 pharos failed
# API 8.10 pharos failed
# API 8.3 pharos failed
# API 8.5 pharos failed
# API 8.11 pharos failed
# API 8.8 pharos failed
# API 8.9 pharos failed
# API 8.17 pharos failed
# API 8.22 pharos failed
# API 8.16 pharos failed
# API 8.18 pharos failed
# API 8.21 pharos failed
# API 8.23 pharos failed
# API 8.20 pharos failed
# API 8.25 pharos failed
# API 8.19 pharos failed
# API 8.36 pharos failed
# API 8.31 pharos failed
# API 8.32 pharos failed
# API 8.33 pharos failed
# API 8.26 pharos failed
# API 8.35 pharos failed
# API 8.29 pharos failed
# API 8.34 pharos failed
# API 8.37 pharos failed
# API 8.24 pharos failed
# API 8.27 pharos failed
# API 8.30 pharos failed
# API 8.28 pharos failed
# API 8.38 pharos failed
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature

# %% [markdown]
# ### 1.1 Results table

# %%
## FUT 175 (Futhan) is another name for Nafamostat 
all_tmprss2_predictions[(all_tmprss2_predictions["output_name"] == "FUT 175")]
# Out:
#          input input_type                      pred1 pred1_source  \
# 30984  TMPRSS2       Gene  physically_interacts_with         None
# 2405   TMPRSS2       Gene                 related_to      scibite
# 2406   TMPRSS2       Gene                 related_to     scigraph
# 2407   TMPRSS2       Gene  physically_interacts_with     drugbank
# 43018  TMPRSS2       Gene                 related_to      scibite
# 43019  TMPRSS2       Gene                 related_to          CTD
#
#                          pred1_api  \
# 30984                  BioLink API
# 2405    Automat CORD19 Scibite API
# 2406   Automat CORD19 Scigraph API
# 2407               MyChem.info API
# 43018   Automat CORD19 Scibite API
# 43019                      CTD API
#
#                                        pred1_pubmed         node1_type  \
# 30984                                      32296183               Gene
# 2405                                           None  ChemicalSubstance
# 2406                                           None  ChemicalSubstance
# 2407                                           None  ChemicalSubstance
# 43018                                          None            Disease
# 43019  24027332|24227843|27550352|27733646|28778717            Disease
#
#                            node1_name             node1_id  \
# 30984                             TNF        NCBIGene:7124
# 2405                         CAMOSTAT        name:CAMOSTAT
# 2406                         CAMOSTAT        name:CAMOSTAT
# 2407                         CAMOSTAT        name:CAMOSTAT
# 43018  CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719
# 43019  CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719
#
#                            pred2 pred2_source                   pred2_api  \
# 30984  physically_interacts_with         None                   DGIdb API
# 2405        negatively_regulates       SEMMED         SEMMED Chemical API
# 2406        negatively_regulates       SEMMED         SEMMED Chemical API
# 2407        negatively_regulates       SEMMED         SEMMED Chemical API
# 43018                 related_to      scibite  Automat CORD19 Scibite API
# 43019                 related_to      scibite  Automat CORD19 Scibite API
#
#       pred2_pubmed        output_type output_name     output_id
# 30984         None  ChemicalSubstance     FUT 175  name:FUT 175
# 2405       9322090  ChemicalSubstance     FUT 175  name:FUT 175
# 2406       9322090  ChemicalSubstance     FUT 175  name:FUT 175
# 2407       9322090  ChemicalSubstance     FUT 175  name:FUT 175
# 43018         None  ChemicalSubstance     FUT 175  name:FUT 175
# 43019         None  ChemicalSubstance     FUT 175  name:FUT 175

# %% [markdown]
# ## 1.2 Question: Is the only way to get from TMPRSS2 to Blood Coagulation through Nafamostat (Fut 175)?

# %%
tmprss2_to_blood_coagulation = predict_many(tmprss2,node_type_list,'BiologicalProcess')
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# Intermediate Node type running:
# Disease
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature

# %% [markdown]
# #### TMPRSS2 to Blood Coagulation through any node type:

# %%
tmprss2_to_blood_coagulation[tmprss2_to_blood_coagulation['output_name'].str.contains('COAGULATION', regex=False)]
# Out:
#          input input_type                      pred1  \
# 4950   TMPRSS2       Gene  physically_interacts_with
# 8807   TMPRSS2       Gene  physically_interacts_with
# 8808   TMPRSS2       Gene  physically_interacts_with
# 8809   TMPRSS2       Gene  physically_interacts_with
# 8810   TMPRSS2       Gene  physically_interacts_with
# 364    TMPRSS2       Gene                 related_to
# 1117   TMPRSS2       Gene                 related_to
# 1118   TMPRSS2       Gene                 related_to
# 1119   TMPRSS2       Gene                 related_to
# 1120   TMPRSS2       Gene                 related_to
# 5379   TMPRSS2       Gene                     causes
# 5380   TMPRSS2       Gene                 related_to
# 5381   TMPRSS2       Gene                     causes
# 5382   TMPRSS2       Gene                 related_to
# 5383   TMPRSS2       Gene                 related_to
# 5384   TMPRSS2       Gene                 related_to
# 5385   TMPRSS2       Gene                     treats
# 5386   TMPRSS2       Gene                 related_to
# 5387   TMPRSS2       Gene                    affects
# 5388   TMPRSS2       Gene                     treats
# 5389   TMPRSS2       Gene                 related_to
# 5390   TMPRSS2       Gene                    affects
# 5391   TMPRSS2       Gene                 related_to
# 5392   TMPRSS2       Gene                 related_to
# 5393   TMPRSS2       Gene                 related_to
# 5394   TMPRSS2       Gene                 related_to
# 5395   TMPRSS2       Gene                 related_to
# 5396   TMPRSS2       Gene                 related_to
# 5397   TMPRSS2       Gene                 related_to
# 5398   TMPRSS2       Gene                 related_to
# 5399   TMPRSS2       Gene                 related_to
# 5400   TMPRSS2       Gene                 related_to
# 5401   TMPRSS2       Gene                 related_to
# 11905  TMPRSS2       Gene                 related_to
# 12746  TMPRSS2       Gene                 related_to
# 12747  TMPRSS2       Gene                 related_to
# 12748  TMPRSS2       Gene                 related_to
# 12749  TMPRSS2       Gene                 related_to
# 907    TMPRSS2       Gene     functional_association
# 97     TMPRSS2       Gene     functional_association
# 98     TMPRSS2       Gene     functional_association
# 330    TMPRSS2       Gene                 related_to
#
#                           pred1_source                    pred1_api  \
# 4950                            SEMMED              SEMMED Gene API
# 8807                            SEMMED              SEMMED Gene API
# 8808                              None                  BioLink API
# 8809                              None                  BioLink API
# 8810                              None                  BioLink API
# 364                           scigraph  Automat CORD19 Scigraph API
# 1117                           scibite   Automat CORD19 Scibite API
# 1118                          scigraph  Automat CORD19 Scigraph API
# 1119                           scibite   Automat CORD19 Scibite API
# 1120                          scigraph  Automat CORD19 Scigraph API
# 5379                            SEMMED              SEMMED Gene API
# 5380                            SEMMED              SEMMED Gene API
# 5381                            SEMMED              SEMMED Gene API
# 5382                            SEMMED              SEMMED Gene API
# 5383                            SEMMED              SEMMED Gene API
# 5384                            SEMMED              SEMMED Gene API
# 5385                            SEMMED              SEMMED Gene API
# 5386                            SEMMED              SEMMED Gene API
# 5387                            SEMMED              SEMMED Gene API
# 5388                            SEMMED              SEMMED Gene API
# 5389                            SEMMED              SEMMED Gene API
# 5390                            SEMMED              SEMMED Gene API
# 5391                          disgenet           mydisease.info API
# 5392                           scibite   Automat CORD19 Scibite API
# 5393                            pharos           Automat PHAROS API
# 5394                             hetio            Automat Hetio API
# 5395                               CTD                      CTD API
# 5396                           DISEASE                 DISEASES API
# 5397                            SEMMED              SEMMED Gene API
# 5398                            SEMMED              SEMMED Gene API
# 5399                            SEMMED              SEMMED Gene API
# 5400                            SEMMED              SEMMED Gene API
# 5401                           DISEASE                 DISEASES API
# 11905                           SEMMED              SEMMED Gene API
# 12746                           SEMMED              SEMMED Gene API
# 12747                         scigraph  Automat CORD19 Scigraph API
# 12748                          DISEASE                 DISEASES API
# 12749                          DISEASE                 DISEASES API
# 907                             entrez              MyGene.info API
# 97                              entrez              MyGene.info API
# 98                              entrez              MyGene.info API
# 330    Translator Text Mining Provider                CORD Gene API
#
#                                             pred1_pubmed         node1_type  \
# 4950                                            20713528               Gene
# 8807                                   18500259,28282546               Gene
# 8808                                            32296183               Gene
# 8809                                            32296183               Gene
# 8810                                            32296183               Gene
# 364                                                 None  ChemicalSubstance
# 1117                                                None  ChemicalSubstance
# 1118                                                None  ChemicalSubstance
# 1119                                                None  ChemicalSubstance
# 1120                                                None  ChemicalSubstance
# 5379                                            20160063            Disease
# 5380   18065961,20473283,21307934,27272561,28618395,2...            Disease
# 5381                                            23472063            Disease
# 5382                                            26859937            Disease
# 5383                                            28023903            Disease
# 5384                                            25939480            Disease
# 5385                                   16951139,17224639            Disease
# 5386                                   20478527,29127096            Disease
# 5387                                            20478527            Disease
# 5388   17334343,20303538,23201468,24266818,25520876,2...            Disease
# 5389   16254181,16983328,17021644,17079440,17108102,1...            Disease
# 5390   17334351,23535644,24659477,24764242,27276682,2...            Disease
# 5391                                                None            Disease
# 5392                                                None            Disease
# 5393                                                None            Disease
# 5394                                                None            Disease
# 5395                 18798265|25735316|28783165|29610475            Disease
# 5396                                                None            Disease
# 5397        17527075,18338334,23370768,26764246,28467610            Disease
# 5398                          18483239,23018874,23515404            Disease
# 5399                          18483239,23018874,23515404            Disease
# 5400                                   19642730,26859937            Disease
# 5401                                                None            Disease
# 11905                         18483239,23018874,23515404            Disease
# 12746                         18483239,23018874,23515404            Disease
# 12747                                               None            Disease
# 12748                                               None            Disease
# 12749                                               None            Disease
# 907                                    21068237,24227843  BiologicalProcess
# 97                                              21068237  CellularComponent
# 98                            19056867,19199708,23533145  CellularComponent
# 330                                                 None   AnatomicalEntity
#
#                                   node1_name               node1_id  \
# 4950                                C0017337          UMLS:C0017337
# 8807                                    PTEN          NCBIGene:5728
# 8808                                    PLP2          NCBIGene:5355
# 8809                                     TNF          NCBIGene:7124
# 8810                                  IGFBP5          NCBIGene:3488
# 364                              CHEBI:35222      CHEBI:CHEBI:35222
# 1117                                 FUT 175           name:FUT 175
# 1118                                 FUT 175           name:FUT 175
# 1119                                 FUT 175           name:FUT 175
# 1120                                 FUT 175           name:FUT 175
# 5379                                C0027651          UMLS:C0027651
# 5380                                C0027651          UMLS:C0027651
# 5381                                C0028778          UMLS:C0028778
# 5382                                C0005001          UMLS:C0005001
# 5383                                C0242656          UMLS:C0242656
# 5384                                C0699748          UMLS:C0699748
# 5385                       TUMOR PROGRESSION         MONDO:C0178874
# 5386                       TUMOR PROGRESSION         MONDO:C0178874
# 5387                       TUMOR PROGRESSION         MONDO:C0178874
# 5388          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5389          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5390          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5391          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5392          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5393          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5394          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5395          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5396          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5397                                  CANCER    MONDO:MONDO:0005070
# 5398                     DISEASE OR DISORDER    MONDO:MONDO:0000001
# 5399                     DISEASE OR DISORDER    MONDO:MONDO:0000001
# 5400                             HYPERPLASIA    MONDO:MONDO:0005043
# 5401                                LYMPHOMA    MONDO:MONDO:0005062
# 11905                    DISEASE OR DISORDER    MONDO:MONDO:0000001
# 12746                    DISEASE OR DISORDER    MONDO:MONDO:0000001
# 12747                      SYNDROMIC DISEASE    MONDO:MONDO:0002254
# 12748                          BREAST CANCER    MONDO:MONDO:0007254
# 12749  ASYMPTOMATIC INFLAMMATORY PROSTATITIS    MONDO:MONDO:0005280
# 907                              PROTEOLYSIS          GO:GO:0006508
# 97                           PLASMA MEMBRANE          GO:GO:0005886
# 98                     EXTRACELLULAR EXOSOME          GO:GO:0070062
# 330                           UBERON:0002367  UBERON:UBERON:0002367
#
#             pred2                     pred2_source  \
# 4950      affects                           SEMMED
# 8807   related_to  Translator Text Mining Provider
# 8808   related_to  Translator Text Mining Provider
# 8809   related_to  Translator Text Mining Provider
# 8810   related_to  Translator Text Mining Provider
# 364    related_to  Translator Text Mining Provider
# 1117      affects                           SEMMED
# 1118      affects                           SEMMED
# 1119     disrupts                           SEMMED
# 1120     disrupts                           SEMMED
# 5379      affects                           SEMMED
# 5380      affects                           SEMMED
# 5381      affects                           SEMMED
# 5382      affects                           SEMMED
# 5383      affects                           SEMMED
# 5384      affects                           SEMMED
# 5385      affects                           SEMMED
# 5386      affects                           SEMMED
# 5387      affects                           SEMMED
# 5388      affects                           SEMMED
# 5389      affects                           SEMMED
# 5390      affects                           SEMMED
# 5391      affects                           SEMMED
# 5392      affects                           SEMMED
# 5393      affects                           SEMMED
# 5394      affects                           SEMMED
# 5395      affects                           SEMMED
# 5396      affects                           SEMMED
# 5397      affects                           SEMMED
# 5398      affects                           SEMMED
# 5399   related_to  Translator Text Mining Provider
# 5400      affects                           SEMMED
# 5401      affects                           SEMMED
# 11905     affects                           SEMMED
# 12746  related_to  Translator Text Mining Provider
# 12747  related_to  Translator Text Mining Provider
# 12748  related_to  Translator Text Mining Provider
# 12749  related_to  Translator Text Mining Provider
# 907    related_to  Translator Text Mining Provider
# 97     related_to  Translator Text Mining Provider
# 98     related_to  Translator Text Mining Provider
# 330    related_to  Translator Text Mining Provider
#
#                          pred2_api  \
# 4950               SEMMED Gene API
# 8807                 CORD Gene API
# 8808                 CORD Gene API
# 8809                 CORD Gene API
# 8810                 CORD Gene API
# 364              CORD Chemical API
# 1117           SEMMED Chemical API
# 1118           SEMMED Chemical API
# 1119           SEMMED Chemical API
# 1120           SEMMED Chemical API
# 5379            SEMMED Disease API
# 5380            SEMMED Disease API
# 5381            SEMMED Disease API
# 5382            SEMMED Disease API
# 5383            SEMMED Disease API
# 5384            SEMMED Disease API
# 5385            SEMMED Disease API
# 5386            SEMMED Disease API
# 5387            SEMMED Disease API
# 5388            SEMMED Disease API
# 5389            SEMMED Disease API
# 5390            SEMMED Disease API
# 5391            SEMMED Disease API
# 5392            SEMMED Disease API
# 5393            SEMMED Disease API
# 5394            SEMMED Disease API
# 5395            SEMMED Disease API
# 5396            SEMMED Disease API
# 5397            SEMMED Disease API
# 5398            SEMMED Disease API
# 5399              CORD Disease API
# 5400            SEMMED Disease API
# 5401            SEMMED Disease API
# 11905           SEMMED Disease API
# 12746             CORD Disease API
# 12747             CORD Disease API
# 12748             CORD Disease API
# 12749             CORD Disease API
# 907    CORD Biological Process API
# 97     CORD Cellular Component API
# 98     CORD Cellular Component API
# 330               CORD Anatomy API
#
#                                             pred2_pubmed        output_type  \
# 4950   11410270,11841337,16612563,16676068,16862193,1...  BiologicalProcess
# 8807                                                None  BiologicalProcess
# 8808                                                None  BiologicalProcess
# 8809                                                None  BiologicalProcess
# 8810                                                None  BiologicalProcess
# 364                                                 None  BiologicalProcess
# 1117                                             3443413  BiologicalProcess
# 1118                                             3443413  BiologicalProcess
# 1119                                             3443413  BiologicalProcess
# 1120                                             3443413  BiologicalProcess
# 5379             15567466,3296452,365211,3660345,7310230  BiologicalProcess
# 5380             15567466,3296452,365211,3660345,7310230  BiologicalProcess
# 5381                                             3657605  BiologicalProcess
# 5382                                             9817329  BiologicalProcess
# 5383                                             1409507  BiologicalProcess
# 5384   10899102,10980358,11154116,1428796,15104934,15...  BiologicalProcess
# 5385        19818470,20062932,24345495,26408927,28246607  BiologicalProcess
# 5386        19818470,20062932,24345495,26408927,28246607  BiologicalProcess
# 5387        19818470,20062932,24345495,26408927,28246607  BiologicalProcess
# 5388                                             9817329  BiologicalProcess
# 5389                                             9817329  BiologicalProcess
# 5390                                             9817329  BiologicalProcess
# 5391                                             9817329  BiologicalProcess
# 5392                                             9817329  BiologicalProcess
# 5393                                             9817329  BiologicalProcess
# 5394                                             9817329  BiologicalProcess
# 5395                                             9817329  BiologicalProcess
# 5396                                             9817329  BiologicalProcess
# 5397   11516455,134199,20079834,21042204,22566229,228...  BiologicalProcess
# 5398   12041790,13778492,15025804,15166942,15276651,1...  BiologicalProcess
# 5399                                                None  BiologicalProcess
# 5400                                   11019978,16999230  BiologicalProcess
# 5401                                             3473163  BiologicalProcess
# 11905                                            5752485  BiologicalProcess
# 12746                                               None  BiologicalProcess
# 12747                                               None  BiologicalProcess
# 12748                                               None  BiologicalProcess
# 12749                                               None  BiologicalProcess
# 907                                                 None  BiologicalProcess
# 97                                                  None  BiologicalProcess
# 98                                                  None  BiologicalProcess
# 330                                                 None  BiologicalProcess
#
#                  output_name                   output_id
# 4950       BLOOD COAGULATION      name:BLOOD COAGULATION
# 8807             COAGULATION               GO:GO:0050817
# 8808             COAGULATION               GO:GO:0050817
# 8809             COAGULATION               GO:GO:0050817
# 8810             COAGULATION               GO:GO:0050817
# 364              COAGULATION               GO:GO:0050817
# 1117       BLOOD COAGULATION      name:BLOOD COAGULATION
# 1118       BLOOD COAGULATION      name:BLOOD COAGULATION
# 1119       BLOOD COAGULATION      name:BLOOD COAGULATION
# 1120       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5379       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5380       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5381       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5382       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5383       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5384       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5385       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5386       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5387       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5388       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5389       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5390       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5391       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5392       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5393       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5394       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5395       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5396       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5397       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5398       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5399       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5400       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5401       BLOOD COAGULATION      name:BLOOD COAGULATION
# 11905  HEMOLYMPH COAGULATION  name:HEMOLYMPH COAGULATION
# 12746            COAGULATION               GO:GO:0050817
# 12747            COAGULATION               GO:GO:0050817
# 12748            COAGULATION               GO:GO:0050817
# 12749            COAGULATION               GO:GO:0050817
# 907              COAGULATION               GO:GO:0050817
# 97               COAGULATION               GO:GO:0050817
# 98               COAGULATION               GO:GO:0050817
# 330              COAGULATION               GO:GO:0050817

# %% [markdown]
# #### TMPRSS2 to Blood Coagulation through any ChemicalSubstance type node:

# %%
tmprss2_to_blood_coagulation[(tmprss2_to_blood_coagulation['node1_type'] == "ChemicalSubstance") & (tmprss2_to_blood_coagulation['output_name'].str.contains('COAGULATION', regex=False))]
# Out:
#         input input_type       pred1 pred1_source  \
# 364   TMPRSS2       Gene  related_to     scigraph
# 1117  TMPRSS2       Gene  related_to      scibite
# 1118  TMPRSS2       Gene  related_to     scigraph
# 1119  TMPRSS2       Gene  related_to      scibite
# 1120  TMPRSS2       Gene  related_to     scigraph
#
#                         pred1_api pred1_pubmed         node1_type  \
# 364   Automat CORD19 Scigraph API         None  ChemicalSubstance
# 1117   Automat CORD19 Scibite API         None  ChemicalSubstance
# 1118  Automat CORD19 Scigraph API         None  ChemicalSubstance
# 1119   Automat CORD19 Scibite API         None  ChemicalSubstance
# 1120  Automat CORD19 Scigraph API         None  ChemicalSubstance
#
#        node1_name           node1_id       pred2  \
# 364   CHEBI:35222  CHEBI:CHEBI:35222  related_to
# 1117      FUT 175       name:FUT 175     affects
# 1118      FUT 175       name:FUT 175     affects
# 1119      FUT 175       name:FUT 175    disrupts
# 1120      FUT 175       name:FUT 175    disrupts
#
#                          pred2_source            pred2_api pred2_pubmed  \
# 364   Translator Text Mining Provider    CORD Chemical API         None
# 1117                           SEMMED  SEMMED Chemical API      3443413
# 1118                           SEMMED  SEMMED Chemical API      3443413
# 1119                           SEMMED  SEMMED Chemical API      3443413
# 1120                           SEMMED  SEMMED Chemical API      3443413
#
#             output_type        output_name               output_id
# 364   BiologicalProcess        COAGULATION           GO:GO:0050817
# 1117  BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION
# 1118  BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION
# 1119  BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION
# 1120  BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION

# %% [markdown]
# 1.2 NOTES: Tables show that TMPRSS2 -> coagulation can also be found through 'CHEBI:35222' Chemical Substance, as well as through many other node types that are not drugs

# %%
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'TMPRSS2' and 'ChemicalSubstance'.                   Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: Disease
#
#
#
# ========== QUERY #1 -- fetch all Disease entities linked to TMPRSS2 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because TMPRSS2 is of type 'Gene', BTE will query our meta-KG for APIs that can take 'Gene' as input and 'Disease' as output
#
# BTE found 10 apis:
#
# API 1. semmed_gene(13 API calls)
# API 2. scibite(1 API call)
# API 3. ctd(1 API call)
# API 4. DISEASES(1 API call)
# API 5. cord_gene(1 API call)
# API 6. biolink(1 API call)
# API 7. mydisease(1 API call)
# API 8. scigraph(1 API call)
# API 9. pharos(1 API call)
# API 10. hetio(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 1.7: https://biothings.ncats.io/semmedgene/query?fields=positively_regulated_by (POST -d q=C1336641&scopes=umls)
# API 1.11: https://biothings.ncats.io/semmedgene/query?fields=affected_by (POST -d q=C1336641&scopes=umls)
# API 1.12: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulates (POST -d q=C1336641&scopes=umls)
# API 1.9: https://biothings.ncats.io/semmedgene/query?fields=treats (POST -d q=C1336641&scopes=umls)
# API 1.8: https://biothings.ncats.io/semmedgene/query?fields=prevents (POST -d q=C1336641&scopes=umls)
# API 1.6: https://biothings.ncats.io/semmedgene/query?fields=causes (POST -d q=C1336641&scopes=umls)
# API 1.10: https://biothings.ncats.io/semmedgene/query?fields=related_to (POST -d q=C1336641&scopes=umls)
# API 6.1: https://biothings.ncats.io/cord_gene/query?fields=associated_with (POST -d q=11876&scopes=hgnc)
# API 1.13: https://biothings.ncats.io/semmedgene/query?fields=affects (POST -d q=C1336641&scopes=umls)
# API 9.1: https://mydisease.info/v1/query?fields=disgenet.xrefs.umls&size=250 (POST -d q=7113&scopes=disgenet.genes_related_to_disease.gene_id)
# API 4.1: http://ctdbase.org/tools/batchQuery.go?inputType=gene&report=diseases_curated&format=json&inputTerms=7113
# API 8.1: https://automat.renci.org/cord19_scigraph_v2/gene/disease/NCBIGene:7113
# API 3.1: https://automat.renci.org/cord19_scibite_v2/gene/disease/NCBIGene:7113
# API 2.1: https://automat.renci.org/hetio/gene/disease/NCBIGene:7113
# API 10.1: https://automat.renci.org/pharos/gene/disease/NCBIGene:7113
# API 7.1: https://api.monarchinitiative.org/api/bioentity/gene/NCBIGene:7113/diseases?rows=200
# API 1.5: https://biothings.ncats.io/semmedgene/query?fields=negatively_regulated_by (POST -d q=C1336641&scopes=umls)
# API 1.2: https://biothings.ncats.io/semmedgene/query?fields=disrupts (POST -d q=C1336641&scopes=umls)
# API 1.4: https://biothings.ncats.io/semmedgene/query?fields=disrupted_by (POST -d q=C1336641&scopes=umls)
# API 1.3: https://biothings.ncats.io/semmedgene/query?fields=physically_interacts_with (POST -d q=C1336641&scopes=umls)
# API 1.1: https://biothings.ncats.io/semmedgene/query?fields=positively_regulates (POST -d q=C1336641&scopes=umls)
# API 5.1: https://pending.biothings.io/DISEASES/query?fields=DISEASES.doid&size=250 (POST -d q=TMPRSS2&scopes=DISEASES.associatedWith.symbol)
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 semmed_gene: No hits
# API 1.2 semmed_gene: No hits
# API 1.3 semmed_gene: No hits
# API 3.1 scibite: 6 hits
# API 1.4 semmed_gene: No hits
# API 5.1 DISEASES: 18 hits
# API 1.5 semmed_gene: No hits
# API 1.6 semmed_gene: 3 hits
# API 1.7 semmed_gene: No hits
# API 10.1 pharos: 1 hits
# API 2.1 hetio: 2 hits
# API 7.1 biolink: 1 hits
# API 9.1 mydisease: 2 hits
# API 1.8 semmed_gene: No hits
# API 1.9 semmed_gene: 2 hits
# API 8.1 scigraph: 7 hits
# API 1.10 semmed_gene: 22 hits
# API 1.11 semmed_gene: No hits
# API 6.1 cord_gene: No hits
# API 1.12 semmed_gene: No hits
# API 1.13 semmed_gene: 4 hits
# API 4.1 ctd: 6 hits
#
# After id-to-object translation, BTE retrieved 51 unique objects.
#
#
# ========== QUERY #2.1 -- fetch all ChemicalSubstance entities linked to Disease entites ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because None is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'ChemicalSubstance' as output
#
# BTE found 8 apis:
#
# API 1. scibite(38 API calls)
# API 2. mychem(2 API calls)
# API 3. hmdb(38 API calls)
# API 4. scigraph(38 API calls)
# API 5. mydisease(1 API call)
# API 6. semmed_disease(15 API calls)
# API 7. cord_disease(1 API call)
# API 8. pharos(38 API calls)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 3.2: https://automat.renci.org/hmdb/disease/chemical_substance/C0029925
# API 3.6: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005089
# API 3.11: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0021259
# API 3.4: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0008315
# API 3.9: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005003
# API 3.20: https://automat.renci.org/hmdb/disease/chemical_substance/C0040715
# API 3.1: https://automat.renci.org/hmdb/disease/chemical_substance/MESH:C000657245
# API 3.19: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005062
# API 3.18: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0008903
# API 3.26: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005020
# API 3.22: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005812
# API 3.10: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005105
# API 3.8: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005043
# API 3.12: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005082
# API 3.3: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0007254
# API 3.5: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0100096
# API 3.7: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0010828
# API 3.16: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005008
# API 3.13: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0025028
# API 4.1: https://mydisease.info/v1/query?fields=ctd.chemical_related_to_disease (POST -d q=D004194,D008545,D000072716,D006965,C563991,D054243,D007410,D011471,D009369,D045169,D012509,D014777,D007251,D011472,D012512,D010051,D013577,C000657245,D002277,D050500,D018352,D007938,D008223&scopes=mondo.xrefs.mesh, disgenet.xrefs.mesh)
# API 3.24: https://automat.renci.org/hmdb/disease/chemical_substance/C0596263
# API 3.31: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005159
# API 3.33: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0009831
# API 3.28: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005719
# API 3.25: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005108
# API 3.15: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005091
# API 3.30: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0001187
# API 3.29: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0018048
# API 3.23: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0012817
# API 3.37: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0004992
# API 3.36: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0000001
# API 3.21: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0002254
# API 3.32: https://automat.renci.org/hmdb/disease/chemical_substance/MESH:D000072716
# API 3.38: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005059
# API 3.34: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0008170
# API 3.27: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0004993
# API 3.35: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005280
# API 3.17: https://automat.renci.org/hmdb/disease/chemical_substance/MONDO:0005070
# API 1.5: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0100096
# API 3.14: https://automat.renci.org/hmdb/disease/chemical_substance/C0178874
# API 1.10: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005105
# API 1.1: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MESH:C000657245
# API 8.3: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0007254
# API 8.3 pharos failed
# API 8.2: https://automat.renci.org/pharos/disease/chemical_substance/C0029925
# API 8.2 pharos failed
# API 1.6: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005089
# API 8.1: https://automat.renci.org/pharos/disease/chemical_substance/MESH:C000657245
# API 8.1 pharos failed
# API 8.4: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0008315
# API 8.4 pharos failed
# API 8.6: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005089
# API 8.6 pharos failed
# API 8.8: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005043
# API 8.8 pharos failed
# API 8.7: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0010828
# API 8.7 pharos failed
# API 8.5: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0100096
# API 8.5 pharos failed
# API 8.9: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005003
# API 8.9 pharos failed
# API 1.9: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005003
# API 1.7: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0010828
# API 1.14: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/C0178874
# API 1.29: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0018048
# API 1.19: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005062
# API 1.35: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005280
# API 1.30: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0001187
# API 1.18: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0008903
# API 1.20: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/C0040715
# API 1.24: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/C0596263
# API 1.3: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0007254
# API 1.28: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005719
# API 1.31: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005159
# API 1.23: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0012817
# API 1.37: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0004992
# API 1.2: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/C0029925
# API 1.11: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0021259
# API 1.36: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0000001
# API 1.16: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005008
# API 1.33: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0009831
# API 1.12: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005082
# API 1.21: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0002254
# API 1.4: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0008315
# API 1.26: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005020
# API 1.17: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005070
# API 1.38: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005059
# API 1.32: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MESH:D000072716
# API 1.13: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0025028
# API 1.15: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005091
# API 1.8: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005043
# API 1.22: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005812
# API 1.34: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0008170
# API 1.25: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0005108
# API 1.27: https://automat.renci.org/cord19_scibite_v2/disease/chemical_substance/MONDO:0004993
# API 5.9: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005003
# API 5.11: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0021259
# API 5.5: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0100096
# API 5.23: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0012817
# API 5.22: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005812
# API 5.15: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005091
# API 5.3: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0007254
# API 5.4: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0008315
# API 5.1: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MESH:C000657245
# API 5.12: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005082
# API 5.20: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/C0040715
# API 5.14: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/C0178874
# API 5.18: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0008903
# API 5.16: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005008
# API 8.15: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005091
# API 8.15 pharos failed
# API 8.13: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0025028
# API 8.13 pharos failed
# API 8.10: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005105
# API 8.10 pharos failed
# API 8.12: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005082
# API 8.12 pharos failed
# API 8.16: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005008
# API 8.16 pharos failed
# API 8.14: https://automat.renci.org/pharos/disease/chemical_substance/C0178874
# API 8.14 pharos failed
# API 5.2: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/C0029925
# API 5.24: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/C0596263
# API 5.30: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0001187
# API 5.7: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0010828
# API 8.18: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0008903
# API 8.18 pharos failed
# API 8.17: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005070
# API 8.17 pharos failed
# API 8.11: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0021259
# API 8.11 pharos failed
# API 5.28: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005719
# API 5.13: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0025028
# API 5.6: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005089
# API 5.29: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0018048
# API 5.21: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0002254
# API 5.31: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005159
# API 7.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:1324,DOID:10283,DOID:0050686,DOID:0050861,DOID:8469,DOID:934,DOID:2394,DOID:1909,DOID:14654,DOID:225,DOID:1240,DOID:5295,DOID:305,DOID:13206,DOID:1793,DOID:4,DOID:3369,DOID:0110408,DOID:10286,DOID:2526,DOID:1612,DOID:2945,DOID:9256,DOID:0080600,DOID:0060058,DOID:1115,DOID:14566,DOID:11054&scopes=doid)
# API 8.30: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0001187
# API 8.30 pharos failed
# API 8.19: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005062
# API 8.19 pharos failed
# API 8.24: https://automat.renci.org/pharos/disease/chemical_substance/C0596263
# API 8.24 pharos failed
# API 8.28: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005719
# API 8.28 pharos failed
# API 8.27: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0004993
# API 8.27 pharos failed
# API 8.25: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005108
# API 8.25 pharos failed
# API 8.23: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0012817
# API 8.23 pharos failed
# API 8.21: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0002254
# API 8.21 pharos failed
# API 8.33: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0009831
# API 8.33 pharos failed
# API 8.29: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0018048
# API 8.29 pharos failed
# API 8.26: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005020
# API 8.26 pharos failed
# API 8.32: https://automat.renci.org/pharos/disease/chemical_substance/MESH:D000072716
# API 8.32 pharos failed
# API 8.20: https://automat.renci.org/pharos/disease/chemical_substance/C0040715
# API 8.20 pharos failed
# API 8.31: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005159
# API 8.31 pharos failed
# API 8.22: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005812
# API 8.22 pharos failed
# API 5.25: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005108
# API 5.26: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005020
# API 8.35: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005280
# API 8.35 pharos failed
# API 8.36: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0000001
# API 8.36 pharos failed
# API 8.38: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0005059
# API 8.38 pharos failed
# API 8.37: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0004992
# API 8.37 pharos failed
# API 8.34: https://automat.renci.org/pharos/disease/chemical_substance/MONDO:0008170
# API 8.34 pharos failed
# API 6.2: https://biothings.ncats.io/semmed/query?fields=disrupted_by (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.1: https://biothings.ncats.io/semmed/query?fields=physically_interacts_with (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.4: https://biothings.ncats.io/semmed/query?fields=prevented_by (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.5: https://biothings.ncats.io/semmed/query?fields=derives_from (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 5.19: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005062
# API 5.27: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0004993
# API 5.32: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MESH:D000072716
# API 5.34: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0008170
# API 5.36: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0000001
# API 5.17: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005070
# API 5.33: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0009831
# API 5.38: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005059
# API 5.35: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005280
# API 5.37: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0004992
# API 6.3: https://biothings.ncats.io/semmed/query?fields=coexists_with (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.6: https://biothings.ncats.io/semmed/query?fields=caused_by (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.7: https://biothings.ncats.io/semmed/query?fields=negatively_regulates (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 5.10: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005105
# API 5.8: https://automat.renci.org/cord19_scigraph_v2/disease/chemical_substance/MONDO:0005043
# API 6.8: https://biothings.ncats.io/semmed/query?fields=treated_by (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.11: https://biothings.ncats.io/semmed/query?fields=positively_regulates (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.13: https://biothings.ncats.io/semmed/query?fields=derives_info (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.10: https://biothings.ncats.io/semmed/query?fields=affects (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.12: https://biothings.ncats.io/semmed/query?fields=affected_by (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.14: https://biothings.ncats.io/semmed/query?fields=negatively_regulated_by (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.15: https://biothings.ncats.io/semmed/query?fields=positively_regulated_by (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
# API 6.9: https://biothings.ncats.io/semmed/query?fields=related_to (POST -d q=C0029925,C0684249,C0553580,C0020507,C0012860,C0153658,C0920779,C0149521,C0033581,C0023418,C0277565,C0600139,C0272285,C0039082,C0677930,C0005684,C0012634,C0266999,C0007112,C0028778,C0178874,C0699748,C1442161,C0025202,C0936223,C0007097,C1720796,C0033578,C1175175,C1565321,C0040715,C0596263,C0376358,C1838601,C0005001,C0006826,C0242656,CN971653,CN236628,C0334001,C0024299,C0027651,C1319315&scopes=umls)
#
#
# ==== Step #3: Output normalization ====
#
# API 2.1 mychem: 61 hits
# API 3.1 hmdb: No hits
# API 3.2 hmdb: No hits
# API 3.3 hmdb: No hits
# API 3.4 hmdb: No hits
# API 3.5 hmdb: No hits
# API 3.6 hmdb: 1 hits
# API 3.7 hmdb: No hits
# API 3.8 hmdb: No hits
# API 3.9 hmdb: 1 hits
# API 3.10 hmdb: 1 hits
# API 3.11 hmdb: No hits
# API 3.12 hmdb: No hits
# API 3.13 hmdb: No hits
# API 3.14 hmdb: No hits
# API 3.15 hmdb: No hits
# API 3.16 hmdb: No hits
# API 3.17 hmdb: No hits
# API 3.18 hmdb: No hits
# API 3.19 hmdb: No hits
# API 3.20 hmdb: No hits
# API 3.21 hmdb: No hits
# API 3.22 hmdb: No hits
# API 3.23 hmdb: No hits
# API 3.24 hmdb: No hits
# API 3.25 hmdb: 2 hits
# API 3.26 hmdb: No hits
# API 3.27 hmdb: No hits
# API 3.28 hmdb: No hits
# API 3.29 hmdb: No hits
# API 3.30 hmdb: No hits
# API 3.31 hmdb: 30 hits
# API 3.32 hmdb: No hits
# API 3.33 hmdb: No hits
# API 3.34 hmdb: No hits
# API 3.35 hmdb: No hits
# API 3.36 hmdb: No hits
# API 3.37 hmdb: No hits
# API 3.38 hmdb: 35 hits
# API 6.1 semmed_disease: 2 hits
# API 6.2 semmed_disease: No hits
# API 2.2 mychem: 19 hits
# API 1.1 scibite: No hits
# API 1.2 scibite: No hits
# API 1.3 scibite: No hits
# API 1.4 scibite: 24 hits
# API 1.5 scibite: No hits
# API 1.6 scibite: 5 hits
# API 1.7 scibite: No hits
# API 1.8 scibite: 23 hits
# API 1.9 scibite: 2 hits
# API 1.10 scibite: 25 hits
# API 1.11 scibite: No hits
# API 1.12 scibite: No hits
# API 1.13 scibite: 8 hits
# API 1.14 scibite: No hits
# API 1.15 scibite: 50 hits
# API 1.16 scibite: No hits
# API 1.17 scibite: 67 hits
# API 1.18 scibite: No hits
# API 1.19 scibite: 24 hits
# API 1.20 scibite: No hits
# API 1.21 scibite: No hits
# API 1.22 scibite: 44 hits
# API 1.23 scibite: 2 hits
# API 1.24 scibite: No hits
# API 1.25 scibite: 224 hits
# API 1.26 scibite: 8 hits
# API 1.27 scibite: 201 hits
# API 1.28 scibite: 32 hits
# API 1.29 scibite: 4 hits
# API 1.30 scibite: No hits
# API 1.31 scibite: No hits
# API 1.32 scibite: No hits
# API 1.33 scibite: No hits
# API 1.34 scibite: 17 hits
# API 1.35 scibite: 5 hits
# API 1.36 scibite: No hits
# API 1.37 scibite: No hits
# API 1.38 scibite: 45 hits
# API 6.3 semmed_disease: 6 hits
# API 7.1 cord_disease: 2595 hits
# API 5.1 scigraph: No hits
# API 5.2 scigraph: No hits
# API 5.3 scigraph: 157 hits
# API 5.4 scigraph: 117 hits
# API 5.5 scigraph: 13 hits
# API 5.6 scigraph: 163 hits
# API 5.7 scigraph: No hits
# API 5.8 scigraph: 389 hits
# API 5.9 scigraph: 191 hits
# API 5.10 scigraph: 192 hits
# API 5.11 scigraph: 19 hits
# API 5.12 scigraph: No hits
# API 5.13 scigraph: 175 hits
# API 5.14 scigraph: No hits
# API 5.15 scigraph: 42 hits
# API 5.16 scigraph: 2 hits
# API 5.17 scigraph: 704 hits
# API 5.18 scigraph: 97 hits
# API 5.19 scigraph: 523 hits
# API 5.20 scigraph: No hits
# API 5.21 scigraph: 320 hits
# API 5.22 scigraph: 126 hits
# API 5.23 scigraph: 188 hits
# API 5.24 scigraph: No hits
# API 5.25 scigraph: 252 hits
# API 5.26 scigraph: 239 hits
# API 5.27 scigraph: 374 hits
# API 5.28 scigraph: No hits
# API 5.29 scigraph: 161 hits
# API 5.30 scigraph: 15 hits
# API 5.31 scigraph: 141 hits
# API 5.32 scigraph: No hits
# API 5.33 scigraph: 39 hits
# API 5.34 scigraph: 40 hits
# API 5.35 scigraph: 257 hits
# API 5.36 scigraph: No hits
# API 5.37 scigraph: 712 hits
# API 5.38 scigraph: 309 hits
# API 6.4 semmed_disease: No hits
# API 6.5 semmed_disease: No hits
# API 6.6 semmed_disease: No hits
# API 6.7 semmed_disease: 10 hits
# API 6.8 semmed_disease: No hits
# API 6.9 semmed_disease: 8547 hits
# API 6.10 semmed_disease: 9024 hits
# API 6.11 semmed_disease: No hits
# API 6.12 semmed_disease: No hits
# API 6.13 semmed_disease: No hits
# API 6.14 semmed_disease: No hits
# API 4.1 mydisease: 540 hits
# API 6.15 semmed_disease: No hits
#
# After id-to-object translation, BTE retrieved 6938 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 51 unique Disease nodes
# In the #2 query, BTE found 6938 unique ChemicalSubstance nodes
#          input input_type       pred1 pred1_source        pred1_api  \
# 0      TMPRSS2       Gene      causes       SEMMED  SEMMED Gene API
# 1      TMPRSS2       Gene  related_to       SEMMED  SEMMED Gene API
# 2      TMPRSS2       Gene  related_to       SEMMED  SEMMED Gene API
# 3      TMPRSS2       Gene  related_to       SEMMED  SEMMED Gene API
# 4      TMPRSS2       Gene  related_to       SEMMED  SEMMED Gene API
# ...        ...        ...         ...          ...              ...
# 44307  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
# 44308  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
# 44309  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
# 44310  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
# 44311  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
#
#                      pred1_pubmed node1_type           node1_name  \
# 0               21575865,23918607    Disease             C0012860
# 1                        25939480    Disease             C0699748
# 2                        25939480    Disease             C0699748
# 3      18483239,23018874,23515404    Disease  DISEASE OR DISORDER
# 4      18483239,23018874,23515404    Disease  DISEASE OR DISORDER
# ...                           ...        ...                  ...
# 44307                        None    Disease       OVARIAN CANCER
# 44308                        None    Disease       OVARIAN CANCER
# 44309                        None    Disease       OVARIAN CANCER
# 44310                        None    Disease       OVARIAN CANCER
# 44311                        None    Disease       OVARIAN CANCER
#
#                   node1_id                      pred2  \
# 0            UMLS:C0012860  physically_interacts_with
# 1            UMLS:C0699748                 related_to
# 2            UMLS:C0699748                    affects
# 3      MONDO:MONDO:0000001                 related_to
# 4      MONDO:MONDO:0000001                    affects
# ...                    ...                        ...
# 44307  MONDO:MONDO:0008170                 related_to
# 44308  MONDO:MONDO:0008170                 related_to
# 44309  MONDO:MONDO:0008170                 related_to
# 44310  MONDO:MONDO:0008170                 related_to
# 44311  MONDO:MONDO:0008170                 related_to
#
#                           pred2_source                   pred2_api  \
# 0                               SEMMED          SEMMED Disease API
# 1                               SEMMED          SEMMED Disease API
# 2                               SEMMED          SEMMED Disease API
# 3                               SEMMED          SEMMED Disease API
# 4                               SEMMED          SEMMED Disease API
# ...                                ...                         ...
# 44307                          scibite  Automat CORD19 Scibite API
# 44308  Translator Text Mining Provider            CORD Disease API
# 44309  Translator Text Mining Provider            CORD Disease API
# 44310  Translator Text Mining Provider            CORD Disease API
# 44311  Translator Text Mining Provider            CORD Disease API
#
#                              pred2_pubmed        output_type  \
# 0                                28526682  ChemicalSubstance
# 1       19240704,25780879,2669810,9444919  ChemicalSubstance
# 2              19925501,26552778,27083109  ChemicalSubstance
# 3                        16481388,9554116  ChemicalSubstance
# 4      22569402,28049188,28865409,9130585  ChemicalSubstance
# ...                                   ...                ...
# 44307                                None  ChemicalSubstance
# 44308                                None  ChemicalSubstance
# 44309                                None  ChemicalSubstance
# 44310                                None  ChemicalSubstance
# 44311                                None  ChemicalSubstance
#
#                         output_name                          output_id
# 0                          C0001697                      UMLS:C0001697
# 1                          C0001697                      UMLS:C0001697
# 2                          C0001697                      UMLS:C0001697
# 3                          C0001697                      UMLS:C0001697
# 4                          C0001697                      UMLS:C0001697
# ...                             ...                                ...
# 44307                  CHEMBL389143       CHEMBL.COMPOUND:CHEMBL389143
# 44308                   CHEBI:25357                  CHEBI:CHEBI:25357
# 44309                   CHEBI:24684                  CHEBI:CHEBI:24684
# 44310  LYSOPHOSPHATIDYLETHANOLAMINE  name:LYSOPHOSPHATIDYLETHANOLAMINE
# 44311              CHLOROPHENOTHANE              name:CHLOROPHENOTHANE
#
# [43234 rows x 16 columns]

# %%
# Out:
#          input input_type       pred1 pred1_source        pred1_api  \
# 0      TMPRSS2       Gene      causes       SEMMED  SEMMED Gene API
# 1      TMPRSS2       Gene  related_to       SEMMED  SEMMED Gene API
# 2      TMPRSS2       Gene  related_to       SEMMED  SEMMED Gene API
# 3      TMPRSS2       Gene  related_to       SEMMED  SEMMED Gene API
# 4      TMPRSS2       Gene  related_to       SEMMED  SEMMED Gene API
# ...        ...        ...         ...          ...              ...
# 44307  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
# 44308  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
# 44309  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
# 44310  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
# 44311  TMPRSS2       Gene  related_to      DISEASE     DISEASES API
#
#                      pred1_pubmed node1_type           node1_name  \
# 0               21575865,23918607    Disease             C0012860
# 1                        25939480    Disease             C0699748
# 2                        25939480    Disease             C0699748
# 3      18483239,23018874,23515404    Disease  DISEASE OR DISORDER
# 4      18483239,23018874,23515404    Disease  DISEASE OR DISORDER
# ...                           ...        ...                  ...
# 44307                        None    Disease       OVARIAN CANCER
# 44308                        None    Disease       OVARIAN CANCER
# 44309                        None    Disease       OVARIAN CANCER
# 44310                        None    Disease       OVARIAN CANCER
# 44311                        None    Disease       OVARIAN CANCER
#
#                   node1_id                      pred2  \
# 0            UMLS:C0012860  physically_interacts_with
# 1            UMLS:C0699748                 related_to
# 2            UMLS:C0699748                    affects
# 3      MONDO:MONDO:0000001                 related_to
# 4      MONDO:MONDO:0000001                    affects
# ...                    ...                        ...
# 44307  MONDO:MONDO:0008170                 related_to
# 44308  MONDO:MONDO:0008170                 related_to
# 44309  MONDO:MONDO:0008170                 related_to
# 44310  MONDO:MONDO:0008170                 related_to
# 44311  MONDO:MONDO:0008170                 related_to
#
#                           pred2_source                   pred2_api  \
# 0                               SEMMED          SEMMED Disease API
# 1                               SEMMED          SEMMED Disease API
# 2                               SEMMED          SEMMED Disease API
# 3                               SEMMED          SEMMED Disease API
# 4                               SEMMED          SEMMED Disease API
# ...                                ...                         ...
# 44307                          scibite  Automat CORD19 Scibite API
# 44308  Translator Text Mining Provider            CORD Disease API
# 44309  Translator Text Mining Provider            CORD Disease API
# 44310  Translator Text Mining Provider            CORD Disease API
# 44311  Translator Text Mining Provider            CORD Disease API
#
#                              pred2_pubmed        output_type  \
# 0                                28526682  ChemicalSubstance
# 1       19240704,25780879,2669810,9444919  ChemicalSubstance
# 2              19925501,26552778,27083109  ChemicalSubstance
# 3                        16481388,9554116  ChemicalSubstance
# 4      22569402,28049188,28865409,9130585  ChemicalSubstance
# ...                                   ...                ...
# 44307                                None  ChemicalSubstance
# 44308                                None  ChemicalSubstance
# 44309                                None  ChemicalSubstance
# 44310                                None  ChemicalSubstance
# 44311                                None  ChemicalSubstance
#
#                         output_name                          output_id
# 0                          C0001697                      UMLS:C0001697
# 1                          C0001697                      UMLS:C0001697
# 2                          C0001697                      UMLS:C0001697
# 3                          C0001697                      UMLS:C0001697
# 4                          C0001697                      UMLS:C0001697
# ...                             ...                                ...
# 44307                  CHEMBL389143       CHEMBL.COMPOUND:CHEMBL389143
# 44308                   CHEBI:25357                  CHEBI:CHEBI:25357
# 44309                   CHEBI:24684                  CHEBI:CHEBI:24684
# 44310  LYSOPHOSPHATIDYLETHANOLAMINE  name:LYSOPHOSPHATIDYLETHANOLAMINE
# 44311              CHLOROPHENOTHANE              name:CHLOROPHENOTHANE
#
# [43234 rows x 16 columns]

# %%
# Out:
#          input input_type       pred1 pred1_source  \
# 43018  TMPRSS2       Gene  related_to      scibite
# 43019  TMPRSS2       Gene  related_to          CTD
#
#                         pred1_api  \
# 43018  Automat CORD19 Scibite API
# 43019                     CTD API
#
#                                        pred1_pubmed node1_type  \
# 43018                                          None    Disease
# 43019  24027332|24227843|27550352|27733646|28778717    Disease
#
#                            node1_name             node1_id       pred2  \
# 43018  CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719  related_to
# 43019  CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719  related_to
#
#       pred2_source                   pred2_api pred2_pubmed  \
# 43018      scibite  Automat CORD19 Scibite API         None
# 43019      scibite  Automat CORD19 Scibite API         None
#
#              output_type output_name     output_id
# 43018  ChemicalSubstance     FUT 175  name:FUT 175
# 43019  ChemicalSubstance     FUT 175  name:FUT 175
