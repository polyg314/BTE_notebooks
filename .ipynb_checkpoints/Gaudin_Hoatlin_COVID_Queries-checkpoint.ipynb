# %% [markdown]
# # COVID-19 Related Queries for BTE Use Case Exploration

# %% [markdown]
# # TABLE OF CONTENTS
#
# ## 1 TMPRSS2 Related Queries
# ###  &emsp; 1.1 TMPRSS2 -> NAFAMOSTAT
# ####  &emsp; &emsp; 1.1.1 TMPRSS2 -> NAFAMOSTAT Query
# ####  &emsp; &emsp; 1.1.2 TMPRSS2 -> NAFAMOSTAT Results table
# ###  &emsp; 1.2 Question: Is the only way to get from TMPRSS2 to Blood Coagulation through Nafamostat (Fut 175)?
# #### &emsp;&emsp; 1.2.1 TMPRSS2 to Blood Coagulation through any node type
# #### &emsp;&emsp; 1.2.2 TMPRSS2 to Blood Coagulation through any ChemicalSubstance type node
# ### &emsp; 1.3 TMPRSS2 -> Camostat
# #### &emsp;&emsp; 1.3.1 In what ways can the TMPRSS2 Gene be connected to Camostat?
# ## 2 CAMOSTAT Related Queries
# ### &emsp; 2.1 Camostat to Protease Activity
# #### &emsp;&emsp;  2.1.1 Camostat to Protease Activity Query
# #### &emsp;&emsp; 2.1.2 Camostat to Protease Activity Results
# ### &emsp; 2.2 Camostat to Protease Related Genes
# #### &emsp;&emsp; 2.2.1 Camostat to Protease Related Genes Query
# #### &emsp;&emsp; 2.2.2 Camostat to Protease Related Genes Results
# ### &emsp; 2.3 Camostat to Coagulation
# #### &emsp;&emsp; 2.3.1 Camostat to Coagulation Results

# %% [markdown]
# # 1 TMPRSS2 Related Queries¶

# %%
## First get all the functions set up
import pandas as pd
## Load BTE
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

## Functions that will be used
# Check for every intermediate node type in Predict funciton
def predict_many(input_object, intermediate_node_list, output_type):
    df_list = []
    for inter in intermediate_node_list:
        try: 
            print("Intermediate Node type running:")
            print(inter)
            fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
            fc.connect(verbose=False)
            df = fc.display_table_view()
            rows = df.shape[0]
            if(rows > 0):
                df_list.append(df)
        except:
            print("FAILED")
    if(len(df_list) > 0):
        return pd.concat(df_list)
    else:
        return None
    
# all intermediate node types

node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                   'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                   'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %% [markdown]
# ## 1.1 TMPRSS2 -> NAFAMOSTAT
# ### In what ways can the TMPRSS2 Gene be connected to NAFAMOSTAT?
# ### 1.1.1 TMPRSS2 -> NAFAMOSTAT Query

# %%
tmprss2 = ht.query("TMPRSS2")['Gene'][0]

all_tmprss2_predictions = predict_many(tmprss2,node_type_list,'ChemicalSubstance')
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# Intermediate Node type running:
# Disease
# API 8.7 pharos failed
# API 8.4 pharos failed
# API 8.15 pharos failed
# API 8.1 pharos failed
# API 8.14 pharos failed
# API 8.12 pharos failed
# API 8.2 pharos failed
# API 8.6 pharos failed
# API 8.13 pharos failed
# API 8.10 pharos failed
# API 8.3 pharos failed
# API 8.5 pharos failed
# API 8.11 pharos failed
# API 8.8 pharos failed
# API 8.9 pharos failed
# API 8.17 pharos failed
# API 8.22 pharos failed
# API 8.16 pharos failed
# API 8.18 pharos failed
# API 8.21 pharos failed
# API 8.23 pharos failed
# API 8.20 pharos failed
# API 8.25 pharos failed
# API 8.19 pharos failed
# API 8.36 pharos failed
# API 8.31 pharos failed
# API 8.32 pharos failed
# API 8.33 pharos failed
# API 8.26 pharos failed
# API 8.35 pharos failed
# API 8.29 pharos failed
# API 8.34 pharos failed
# API 8.37 pharos failed
# API 8.24 pharos failed
# API 8.27 pharos failed
# API 8.30 pharos failed
# API 8.28 pharos failed
# API 8.38 pharos failed
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature

# %% [markdown]
# ### 1.1.2 TMPRSS2 -> NAFAMOSTAT Results table

# %%
## FUT 175 (Futhan) is another name for Nafamostat 
all_tmprss2_predictions[(all_tmprss2_predictions["output_name"] == "FUT 175")]
# Out:
#          input input_type                      pred1 pred1_source  \
# 30984  TMPRSS2       Gene  physically_interacts_with         None
# 2405   TMPRSS2       Gene                 related_to      scibite
# 2406   TMPRSS2       Gene                 related_to     scigraph
# 2407   TMPRSS2       Gene  physically_interacts_with     drugbank
# 43018  TMPRSS2       Gene                 related_to      scibite
# 43019  TMPRSS2       Gene                 related_to          CTD
#
#                          pred1_api  \
# 30984                  BioLink API
# 2405    Automat CORD19 Scibite API
# 2406   Automat CORD19 Scigraph API
# 2407               MyChem.info API
# 43018   Automat CORD19 Scibite API
# 43019                      CTD API
#
#                                        pred1_pubmed         node1_type  \
# 30984                                      32296183               Gene
# 2405                                           None  ChemicalSubstance
# 2406                                           None  ChemicalSubstance
# 2407                                           None  ChemicalSubstance
# 43018                                          None            Disease
# 43019  24027332|24227843|27550352|27733646|28778717            Disease
#
#                            node1_name             node1_id  \
# 30984                             TNF        NCBIGene:7124
# 2405                         CAMOSTAT        name:CAMOSTAT
# 2406                         CAMOSTAT        name:CAMOSTAT
# 2407                         CAMOSTAT        name:CAMOSTAT
# 43018  CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719
# 43019  CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719
#
#                            pred2 pred2_source                   pred2_api  \
# 30984  physically_interacts_with         None                   DGIdb API
# 2405        negatively_regulates       SEMMED         SEMMED Chemical API
# 2406        negatively_regulates       SEMMED         SEMMED Chemical API
# 2407        negatively_regulates       SEMMED         SEMMED Chemical API
# 43018                 related_to      scibite  Automat CORD19 Scibite API
# 43019                 related_to      scibite  Automat CORD19 Scibite API
#
#       pred2_pubmed        output_type output_name     output_id
# 30984         None  ChemicalSubstance     FUT 175  name:FUT 175
# 2405       9322090  ChemicalSubstance     FUT 175  name:FUT 175
# 2406       9322090  ChemicalSubstance     FUT 175  name:FUT 175
# 2407       9322090  ChemicalSubstance     FUT 175  name:FUT 175
# 43018         None  ChemicalSubstance     FUT 175  name:FUT 175
# 43019         None  ChemicalSubstance     FUT 175  name:FUT 175

# %% [markdown]
# ## 1.2 Question: Is the only way to get from TMPRSS2 to Blood Coagulation through Nafamostat (Fut 175)?

# %%
tmprss2_to_blood_coagulation = predict_many(tmprss2,node_type_list,'BiologicalProcess')
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# Intermediate Node type running:
# Disease
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature

# %% [markdown]
# ### 1.2.1 TMPRSS2 to Blood Coagulation through any node type:

# %%
tmprss2_to_blood_coagulation[tmprss2_to_blood_coagulation['output_name'].str.contains('COAGULATION', regex=False)]
# Out:
#          input input_type                      pred1  \
# 4950   TMPRSS2       Gene  physically_interacts_with
# 8807   TMPRSS2       Gene  physically_interacts_with
# 8808   TMPRSS2       Gene  physically_interacts_with
# 8809   TMPRSS2       Gene  physically_interacts_with
# 8810   TMPRSS2       Gene  physically_interacts_with
# 364    TMPRSS2       Gene                 related_to
# 1117   TMPRSS2       Gene                 related_to
# 1118   TMPRSS2       Gene                 related_to
# 1119   TMPRSS2       Gene                 related_to
# 1120   TMPRSS2       Gene                 related_to
# 5379   TMPRSS2       Gene                     causes
# 5380   TMPRSS2       Gene                 related_to
# 5381   TMPRSS2       Gene                     causes
# 5382   TMPRSS2       Gene                 related_to
# 5383   TMPRSS2       Gene                 related_to
# 5384   TMPRSS2       Gene                 related_to
# 5385   TMPRSS2       Gene                     treats
# 5386   TMPRSS2       Gene                 related_to
# 5387   TMPRSS2       Gene                    affects
# 5388   TMPRSS2       Gene                     treats
# 5389   TMPRSS2       Gene                 related_to
# 5390   TMPRSS2       Gene                    affects
# 5391   TMPRSS2       Gene                 related_to
# 5392   TMPRSS2       Gene                 related_to
# 5393   TMPRSS2       Gene                 related_to
# 5394   TMPRSS2       Gene                 related_to
# 5395   TMPRSS2       Gene                 related_to
# 5396   TMPRSS2       Gene                 related_to
# 5397   TMPRSS2       Gene                 related_to
# 5398   TMPRSS2       Gene                 related_to
# 5399   TMPRSS2       Gene                 related_to
# 5400   TMPRSS2       Gene                 related_to
# 5401   TMPRSS2       Gene                 related_to
# 11905  TMPRSS2       Gene                 related_to
# 12746  TMPRSS2       Gene                 related_to
# 12747  TMPRSS2       Gene                 related_to
# 12748  TMPRSS2       Gene                 related_to
# 12749  TMPRSS2       Gene                 related_to
# 907    TMPRSS2       Gene     functional_association
# 97     TMPRSS2       Gene     functional_association
# 98     TMPRSS2       Gene     functional_association
# 330    TMPRSS2       Gene                 related_to
#
#                           pred1_source                    pred1_api  \
# 4950                            SEMMED              SEMMED Gene API
# 8807                            SEMMED              SEMMED Gene API
# 8808                              None                  BioLink API
# 8809                              None                  BioLink API
# 8810                              None                  BioLink API
# 364                           scigraph  Automat CORD19 Scigraph API
# 1117                           scibite   Automat CORD19 Scibite API
# 1118                          scigraph  Automat CORD19 Scigraph API
# 1119                           scibite   Automat CORD19 Scibite API
# 1120                          scigraph  Automat CORD19 Scigraph API
# 5379                            SEMMED              SEMMED Gene API
# 5380                            SEMMED              SEMMED Gene API
# 5381                            SEMMED              SEMMED Gene API
# 5382                            SEMMED              SEMMED Gene API
# 5383                            SEMMED              SEMMED Gene API
# 5384                            SEMMED              SEMMED Gene API
# 5385                            SEMMED              SEMMED Gene API
# 5386                            SEMMED              SEMMED Gene API
# 5387                            SEMMED              SEMMED Gene API
# 5388                            SEMMED              SEMMED Gene API
# 5389                            SEMMED              SEMMED Gene API
# 5390                            SEMMED              SEMMED Gene API
# 5391                          disgenet           mydisease.info API
# 5392                           scibite   Automat CORD19 Scibite API
# 5393                            pharos           Automat PHAROS API
# 5394                             hetio            Automat Hetio API
# 5395                               CTD                      CTD API
# 5396                           DISEASE                 DISEASES API
# 5397                            SEMMED              SEMMED Gene API
# 5398                            SEMMED              SEMMED Gene API
# 5399                            SEMMED              SEMMED Gene API
# 5400                            SEMMED              SEMMED Gene API
# 5401                           DISEASE                 DISEASES API
# 11905                           SEMMED              SEMMED Gene API
# 12746                           SEMMED              SEMMED Gene API
# 12747                         scigraph  Automat CORD19 Scigraph API
# 12748                          DISEASE                 DISEASES API
# 12749                          DISEASE                 DISEASES API
# 907                             entrez              MyGene.info API
# 97                              entrez              MyGene.info API
# 98                              entrez              MyGene.info API
# 330    Translator Text Mining Provider                CORD Gene API
#
#                                             pred1_pubmed         node1_type  \
# 4950                                            20713528               Gene
# 8807                                   18500259,28282546               Gene
# 8808                                            32296183               Gene
# 8809                                            32296183               Gene
# 8810                                            32296183               Gene
# 364                                                 None  ChemicalSubstance
# 1117                                                None  ChemicalSubstance
# 1118                                                None  ChemicalSubstance
# 1119                                                None  ChemicalSubstance
# 1120                                                None  ChemicalSubstance
# 5379                                            20160063            Disease
# 5380   18065961,20473283,21307934,27272561,28618395,2...            Disease
# 5381                                            23472063            Disease
# 5382                                            26859937            Disease
# 5383                                            28023903            Disease
# 5384                                            25939480            Disease
# 5385                                   16951139,17224639            Disease
# 5386                                   20478527,29127096            Disease
# 5387                                            20478527            Disease
# 5388   17334343,20303538,23201468,24266818,25520876,2...            Disease
# 5389   16254181,16983328,17021644,17079440,17108102,1...            Disease
# 5390   17334351,23535644,24659477,24764242,27276682,2...            Disease
# 5391                                                None            Disease
# 5392                                                None            Disease
# 5393                                                None            Disease
# 5394                                                None            Disease
# 5395                 18798265|25735316|28783165|29610475            Disease
# 5396                                                None            Disease
# 5397        17527075,18338334,23370768,26764246,28467610            Disease
# 5398                          18483239,23018874,23515404            Disease
# 5399                          18483239,23018874,23515404            Disease
# 5400                                   19642730,26859937            Disease
# 5401                                                None            Disease
# 11905                         18483239,23018874,23515404            Disease
# 12746                         18483239,23018874,23515404            Disease
# 12747                                               None            Disease
# 12748                                               None            Disease
# 12749                                               None            Disease
# 907                                    21068237,24227843  BiologicalProcess
# 97                                              21068237  CellularComponent
# 98                            19056867,19199708,23533145  CellularComponent
# 330                                                 None   AnatomicalEntity
#
#                                   node1_name               node1_id  \
# 4950                                C0017337          UMLS:C0017337
# 8807                                    PTEN          NCBIGene:5728
# 8808                                    PLP2          NCBIGene:5355
# 8809                                     TNF          NCBIGene:7124
# 8810                                  IGFBP5          NCBIGene:3488
# 364                              CHEBI:35222      CHEBI:CHEBI:35222
# 1117                                 FUT 175           name:FUT 175
# 1118                                 FUT 175           name:FUT 175
# 1119                                 FUT 175           name:FUT 175
# 1120                                 FUT 175           name:FUT 175
# 5379                                C0027651          UMLS:C0027651
# 5380                                C0027651          UMLS:C0027651
# 5381                                C0028778          UMLS:C0028778
# 5382                                C0005001          UMLS:C0005001
# 5383                                C0242656          UMLS:C0242656
# 5384                                C0699748          UMLS:C0699748
# 5385                       TUMOR PROGRESSION         MONDO:C0178874
# 5386                       TUMOR PROGRESSION         MONDO:C0178874
# 5387                       TUMOR PROGRESSION         MONDO:C0178874
# 5388          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5389          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5390          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5391          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5392          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5393          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5394          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5395          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5396          MALIGNANT NEOPLASM OF PROSTATE    MONDO:MONDO:0008315
# 5397                                  CANCER    MONDO:MONDO:0005070
# 5398                     DISEASE OR DISORDER    MONDO:MONDO:0000001
# 5399                     DISEASE OR DISORDER    MONDO:MONDO:0000001
# 5400                             HYPERPLASIA    MONDO:MONDO:0005043
# 5401                                LYMPHOMA    MONDO:MONDO:0005062
# 11905                    DISEASE OR DISORDER    MONDO:MONDO:0000001
# 12746                    DISEASE OR DISORDER    MONDO:MONDO:0000001
# 12747                      SYNDROMIC DISEASE    MONDO:MONDO:0002254
# 12748                          BREAST CANCER    MONDO:MONDO:0007254
# 12749  ASYMPTOMATIC INFLAMMATORY PROSTATITIS    MONDO:MONDO:0005280
# 907                              PROTEOLYSIS          GO:GO:0006508
# 97                           PLASMA MEMBRANE          GO:GO:0005886
# 98                     EXTRACELLULAR EXOSOME          GO:GO:0070062
# 330                           UBERON:0002367  UBERON:UBERON:0002367
#
#             pred2                     pred2_source  \
# 4950      affects                           SEMMED
# 8807   related_to  Translator Text Mining Provider
# 8808   related_to  Translator Text Mining Provider
# 8809   related_to  Translator Text Mining Provider
# 8810   related_to  Translator Text Mining Provider
# 364    related_to  Translator Text Mining Provider
# 1117      affects                           SEMMED
# 1118      affects                           SEMMED
# 1119     disrupts                           SEMMED
# 1120     disrupts                           SEMMED
# 5379      affects                           SEMMED
# 5380      affects                           SEMMED
# 5381      affects                           SEMMED
# 5382      affects                           SEMMED
# 5383      affects                           SEMMED
# 5384      affects                           SEMMED
# 5385      affects                           SEMMED
# 5386      affects                           SEMMED
# 5387      affects                           SEMMED
# 5388      affects                           SEMMED
# 5389      affects                           SEMMED
# 5390      affects                           SEMMED
# 5391      affects                           SEMMED
# 5392      affects                           SEMMED
# 5393      affects                           SEMMED
# 5394      affects                           SEMMED
# 5395      affects                           SEMMED
# 5396      affects                           SEMMED
# 5397      affects                           SEMMED
# 5398      affects                           SEMMED
# 5399   related_to  Translator Text Mining Provider
# 5400      affects                           SEMMED
# 5401      affects                           SEMMED
# 11905     affects                           SEMMED
# 12746  related_to  Translator Text Mining Provider
# 12747  related_to  Translator Text Mining Provider
# 12748  related_to  Translator Text Mining Provider
# 12749  related_to  Translator Text Mining Provider
# 907    related_to  Translator Text Mining Provider
# 97     related_to  Translator Text Mining Provider
# 98     related_to  Translator Text Mining Provider
# 330    related_to  Translator Text Mining Provider
#
#                          pred2_api  \
# 4950               SEMMED Gene API
# 8807                 CORD Gene API
# 8808                 CORD Gene API
# 8809                 CORD Gene API
# 8810                 CORD Gene API
# 364              CORD Chemical API
# 1117           SEMMED Chemical API
# 1118           SEMMED Chemical API
# 1119           SEMMED Chemical API
# 1120           SEMMED Chemical API
# 5379            SEMMED Disease API
# 5380            SEMMED Disease API
# 5381            SEMMED Disease API
# 5382            SEMMED Disease API
# 5383            SEMMED Disease API
# 5384            SEMMED Disease API
# 5385            SEMMED Disease API
# 5386            SEMMED Disease API
# 5387            SEMMED Disease API
# 5388            SEMMED Disease API
# 5389            SEMMED Disease API
# 5390            SEMMED Disease API
# 5391            SEMMED Disease API
# 5392            SEMMED Disease API
# 5393            SEMMED Disease API
# 5394            SEMMED Disease API
# 5395            SEMMED Disease API
# 5396            SEMMED Disease API
# 5397            SEMMED Disease API
# 5398            SEMMED Disease API
# 5399              CORD Disease API
# 5400            SEMMED Disease API
# 5401            SEMMED Disease API
# 11905           SEMMED Disease API
# 12746             CORD Disease API
# 12747             CORD Disease API
# 12748             CORD Disease API
# 12749             CORD Disease API
# 907    CORD Biological Process API
# 97     CORD Cellular Component API
# 98     CORD Cellular Component API
# 330               CORD Anatomy API
#
#                                             pred2_pubmed        output_type  \
# 4950   11410270,11841337,16612563,16676068,16862193,1...  BiologicalProcess
# 8807                                                None  BiologicalProcess
# 8808                                                None  BiologicalProcess
# 8809                                                None  BiologicalProcess
# 8810                                                None  BiologicalProcess
# 364                                                 None  BiologicalProcess
# 1117                                             3443413  BiologicalProcess
# 1118                                             3443413  BiologicalProcess
# 1119                                             3443413  BiologicalProcess
# 1120                                             3443413  BiologicalProcess
# 5379             15567466,3296452,365211,3660345,7310230  BiologicalProcess
# 5380             15567466,3296452,365211,3660345,7310230  BiologicalProcess
# 5381                                             3657605  BiologicalProcess
# 5382                                             9817329  BiologicalProcess
# 5383                                             1409507  BiologicalProcess
# 5384   10899102,10980358,11154116,1428796,15104934,15...  BiologicalProcess
# 5385        19818470,20062932,24345495,26408927,28246607  BiologicalProcess
# 5386        19818470,20062932,24345495,26408927,28246607  BiologicalProcess
# 5387        19818470,20062932,24345495,26408927,28246607  BiologicalProcess
# 5388                                             9817329  BiologicalProcess
# 5389                                             9817329  BiologicalProcess
# 5390                                             9817329  BiologicalProcess
# 5391                                             9817329  BiologicalProcess
# 5392                                             9817329  BiologicalProcess
# 5393                                             9817329  BiologicalProcess
# 5394                                             9817329  BiologicalProcess
# 5395                                             9817329  BiologicalProcess
# 5396                                             9817329  BiologicalProcess
# 5397   11516455,134199,20079834,21042204,22566229,228...  BiologicalProcess
# 5398   12041790,13778492,15025804,15166942,15276651,1...  BiologicalProcess
# 5399                                                None  BiologicalProcess
# 5400                                   11019978,16999230  BiologicalProcess
# 5401                                             3473163  BiologicalProcess
# 11905                                            5752485  BiologicalProcess
# 12746                                               None  BiologicalProcess
# 12747                                               None  BiologicalProcess
# 12748                                               None  BiologicalProcess
# 12749                                               None  BiologicalProcess
# 907                                                 None  BiologicalProcess
# 97                                                  None  BiologicalProcess
# 98                                                  None  BiologicalProcess
# 330                                                 None  BiologicalProcess
#
#                  output_name                   output_id
# 4950       BLOOD COAGULATION      name:BLOOD COAGULATION
# 8807             COAGULATION               GO:GO:0050817
# 8808             COAGULATION               GO:GO:0050817
# 8809             COAGULATION               GO:GO:0050817
# 8810             COAGULATION               GO:GO:0050817
# 364              COAGULATION               GO:GO:0050817
# 1117       BLOOD COAGULATION      name:BLOOD COAGULATION
# 1118       BLOOD COAGULATION      name:BLOOD COAGULATION
# 1119       BLOOD COAGULATION      name:BLOOD COAGULATION
# 1120       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5379       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5380       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5381       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5382       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5383       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5384       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5385       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5386       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5387       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5388       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5389       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5390       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5391       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5392       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5393       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5394       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5395       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5396       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5397       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5398       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5399       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5400       BLOOD COAGULATION      name:BLOOD COAGULATION
# 5401       BLOOD COAGULATION      name:BLOOD COAGULATION
# 11905  HEMOLYMPH COAGULATION  name:HEMOLYMPH COAGULATION
# 12746            COAGULATION               GO:GO:0050817
# 12747            COAGULATION               GO:GO:0050817
# 12748            COAGULATION               GO:GO:0050817
# 12749            COAGULATION               GO:GO:0050817
# 907              COAGULATION               GO:GO:0050817
# 97               COAGULATION               GO:GO:0050817
# 98               COAGULATION               GO:GO:0050817
# 330              COAGULATION               GO:GO:0050817

# %% [markdown]
# ### 1.2.2 TMPRSS2 to Blood Coagulation through any ChemicalSubstance type node:

# %%
tmprss2_to_blood_coagulation[(tmprss2_to_blood_coagulation['node1_type'] == "ChemicalSubstance") & (tmprss2_to_blood_coagulation['output_name'].str.contains('COAGULATION', regex=False))]
# Out:
#         input input_type       pred1 pred1_source  \
# 364   TMPRSS2       Gene  related_to     scigraph
# 1117  TMPRSS2       Gene  related_to      scibite
# 1118  TMPRSS2       Gene  related_to     scigraph
# 1119  TMPRSS2       Gene  related_to      scibite
# 1120  TMPRSS2       Gene  related_to     scigraph
#
#                         pred1_api pred1_pubmed         node1_type  \
# 364   Automat CORD19 Scigraph API         None  ChemicalSubstance
# 1117   Automat CORD19 Scibite API         None  ChemicalSubstance
# 1118  Automat CORD19 Scigraph API         None  ChemicalSubstance
# 1119   Automat CORD19 Scibite API         None  ChemicalSubstance
# 1120  Automat CORD19 Scigraph API         None  ChemicalSubstance
#
#        node1_name           node1_id       pred2  \
# 364   CHEBI:35222  CHEBI:CHEBI:35222  related_to
# 1117      FUT 175       name:FUT 175     affects
# 1118      FUT 175       name:FUT 175     affects
# 1119      FUT 175       name:FUT 175    disrupts
# 1120      FUT 175       name:FUT 175    disrupts
#
#                          pred2_source            pred2_api pred2_pubmed  \
# 364   Translator Text Mining Provider    CORD Chemical API         None
# 1117                           SEMMED  SEMMED Chemical API      3443413
# 1118                           SEMMED  SEMMED Chemical API      3443413
# 1119                           SEMMED  SEMMED Chemical API      3443413
# 1120                           SEMMED  SEMMED Chemical API      3443413
#
#             output_type        output_name               output_id
# 364   BiologicalProcess        COAGULATION           GO:GO:0050817
# 1117  BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION
# 1118  BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION
# 1119  BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION
# 1120  BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION

# %% [markdown]
# 1.2 NOTES: Tables show that TMPRSS2 -> coagulation can also be found through 'CHEBI:35222' Chemical Substance, as well as through many other node types that are not drugs

# %% [markdown]
# ## 1.3 TMPRSS2 -> Camostat
# ### 1.3.1 In what ways can the TMPRSS2 Gene be connected to Camostat?

# %%
all_tmprss2_predictions[all_tmprss2_predictions["output_name"] == "CAMOSTAT"]
# Out:
#          input input_type                      pred1 pred1_source  \
# 3172   TMPRSS2       Gene       negatively_regulates       SEMMED
# 3173   TMPRSS2       Gene  physically_interacts_with       SEMMED
# 3174   TMPRSS2       Gene  physically_interacts_with         None
# 3175   TMPRSS2       Gene  physically_interacts_with         None
# 3176   TMPRSS2       Gene  physically_interacts_with         None
# 42864  TMPRSS2       Gene                 related_to      scibite
# 42865  TMPRSS2       Gene                 related_to     scigraph
# 42866  TMPRSS2       Gene                 related_to          CTD
# 42867  TMPRSS2       Gene                 related_to      DISEASE
# 42868  TMPRSS2       Gene                 related_to      scibite
# 42869  TMPRSS2       Gene                 related_to          CTD
# 42870  TMPRSS2       Gene                 related_to      scibite
# 42871  TMPRSS2       Gene                 related_to     scigraph
# 42872  TMPRSS2       Gene                 related_to      scibite
# 42873  TMPRSS2       Gene                 related_to      scibite
# 42874  TMPRSS2       Gene                 related_to      scibite
# 42875  TMPRSS2       Gene                 related_to     scigraph
#
#                          pred1_api  \
# 3172               SEMMED Gene API
# 3173               SEMMED Gene API
# 3174                   BioLink API
# 3175                   BioLink API
# 3176                   BioLink API
# 42864   Automat CORD19 Scibite API
# 42865  Automat CORD19 Scigraph API
# 42866                      CTD API
# 42867                 DISEASES API
# 42868   Automat CORD19 Scibite API
# 42869                      CTD API
# 42870   Automat CORD19 Scibite API
# 42871  Automat CORD19 Scigraph API
# 42872   Automat CORD19 Scibite API
# 42873   Automat CORD19 Scibite API
# 42874   Automat CORD19 Scibite API
# 42875  Automat CORD19 Scigraph API
#
#                                        pred1_pubmed node1_type  \
# 3172                                       25221645       Gene
# 3173                                       25520876       Gene
# 3174                                       21068237       Gene
# 3175                                           None       Gene
# 3176                                           None       Gene
# 42864                                          None    Disease
# 42865                                          None    Disease
# 42866                    22496216|24227843|30626688    Disease
# 42867                                          None    Disease
# 42868                                          None    Disease
# 42869  24027332|24227843|27550352|27733646|28778717    Disease
# 42870                                          None    Disease
# 42871                                          None    Disease
# 42872                                          None    Disease
# 42873                                          None    Disease
# 42874                                          None    Disease
# 42875                                          None    Disease
#
#                                        node1_name             node1_id  \
# 3172                                     C1710301        UMLS:C1710301
# 3173                                     C1710301        UMLS:C1710301
# 3174                                         ACE2       NCBIGene:59272
# 3175                                      TMPRSS4       NCBIGene:56649
# 3176                                      TMPRSS4       NCBIGene:56649
# 42864           SEVERE ACUTE RESPIRATORY SYNDROME  MONDO:MONDO:0005091
# 42865           SEVERE ACUTE RESPIRATORY SYNDROME  MONDO:MONDO:0005091
# 42866           SEVERE ACUTE RESPIRATORY SYNDROME  MONDO:MONDO:0005091
# 42867           SEVERE ACUTE RESPIRATORY SYNDROME  MONDO:MONDO:0005091
# 42868              CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719
# 42869              CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719
# 42870                    VIRAL INFECTIOUS DISEASE  MONDO:MONDO:0005108
# 42871                    VIRAL INFECTIOUS DISEASE  MONDO:MONDO:0005108
# 42872                        CHRONIC PANCREATITIS  MONDO:MONDO:0005003
# 42873                        CHRONIC PANCREATITIS  MONDO:MONDO:0005003
# 42874                        CHRONIC PANCREATITIS  MONDO:MONDO:0005003
# 42875  HEPARIN-INDUCED THROMBOCYTOPENIA (DISEASE)  MONDO:MONDO:0018048
#
#                       pred2 pred2_source                    pred2_api  \
# 3172   negatively_regulates       SEMMED              SEMMED Gene API
# 3173   negatively_regulates       SEMMED              SEMMED Gene API
# 3174             related_to     scigraph  Automat CORD19 Scigraph API
# 3175             related_to      scibite   Automat CORD19 Scibite API
# 3176             related_to     scigraph  Automat CORD19 Scigraph API
# 42864            related_to      scibite   Automat CORD19 Scibite API
# 42865            related_to      scibite   Automat CORD19 Scibite API
# 42866            related_to      scibite   Automat CORD19 Scibite API
# 42867            related_to      scibite   Automat CORD19 Scibite API
# 42868            related_to      scibite   Automat CORD19 Scibite API
# 42869            related_to      scibite   Automat CORD19 Scibite API
# 42870            related_to      scibite   Automat CORD19 Scibite API
# 42871            related_to      scibite   Automat CORD19 Scibite API
# 42872               affects       SEMMED           SEMMED Disease API
# 42873            related_to      scibite   Automat CORD19 Scibite API
# 42874            related_to     scigraph  Automat CORD19 Scigraph API
# 42875            related_to     scigraph  Automat CORD19 Scigraph API
#
#             pred2_pubmed        output_type output_name      output_id
# 3172   24027332,25666761  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 3173   24027332,25666761  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 3174                None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 3175                None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 3176                None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42864               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42865               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42866               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42867               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42868               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42869               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42870               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42871               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42872  15946137,16834971  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42873               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42874               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT
# 42875               None  ChemicalSubstance    CAMOSTAT  name:CAMOSTAT

# %% [markdown]
# # 2 CAMOSTAT Related Queries

# %% [markdown]
# ## 2.1 Camostat to Protease Activity
# ### 2.1.1 Camostat to Protease Activity Query

# %%
camostat = ht.query("CAMOSTAT")["ChemicalSubstance"][0]

# %%
## while not used (yet), serine_protease_activity shows BiologicalProcess nodes could be used as the output type
serine_protease_activity = ht.query("protease")['BiologicalProcess'][0]
serine_protease_activity
# Out:
# {'name': 'serine protease activity',
#  'UMLS': 'C1150239',
#  'primary': {'identifier': 'UMLS',
#   'cls': 'BiologicalProcess',
#   'value': 'C1150239'},
#  'display': 'UMLS(C1150239) name(serine protease activity)',
#  'type': 'BiologicalProcess'}

# %%
camastat_BP_query_results = predict_many(camostat, node_type_list, 'BiologicalProcess')
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# Intermediate Node type running:
# Disease
# API 8.1 pharos failed
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature

# %% [markdown]
# ### 2.1.2 Camostat to Protease Activity Results

# %%
camastat_BP_query_results[camastat_BP_query_results["output_name"].str.contains('PROTEASE', regex=False)]
# Out:
#          input         input_type                      pred1 pred1_source  \
# 3888  CAMOSTAT  ChemicalSubstance                 related_to     scigraph
# 6508  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 6509  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 1197  CAMOSTAT  ChemicalSubstance  physically_interacts_with       SEMMED
# 1198  CAMOSTAT  ChemicalSubstance       negatively_regulates       SEMMED
# 1199  CAMOSTAT  ChemicalSubstance  physically_interacts_with       SEMMED
# 1200  CAMOSTAT  ChemicalSubstance       negatively_regulates       SEMMED
# 1257  CAMOSTAT  ChemicalSubstance  physically_interacts_with       SEMMED
# 1258  CAMOSTAT  ChemicalSubstance       negatively_regulates       SEMMED
# 946   CAMOSTAT  ChemicalSubstance                     treats       SEMMED
# 947   CAMOSTAT  ChemicalSubstance                 related_to      scibite
#
#                         pred1_api     pred1_pubmed         node1_type  \
# 3888  Automat CORD19 Scigraph API             None               Gene
# 6508                      CTD API         20023007               Gene
# 6509                      CTD API         27773435               Gene
# 1197          SEMMED Chemical API         21541544  ChemicalSubstance
# 1198          SEMMED Chemical API         21528279  ChemicalSubstance
# 1199          SEMMED Chemical API         21541544  ChemicalSubstance
# 1200          SEMMED Chemical API         21528279  ChemicalSubstance
# 1257          SEMMED Chemical API         21541544  ChemicalSubstance
# 1258          SEMMED Chemical API         21528279  ChemicalSubstance
# 946           SEMMED Chemical API  15796165,229707            Disease
# 947    Automat CORD19 Scibite API             None            Disease
#
#                         node1_name                           node1_id  \
# 3888                          DPP4                      NCBIGene:1803
# 6508                           TNF                      NCBIGene:7124
# 6509                           TNF                      NCBIGene:7124
# 1197  SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 1198  SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 1199  SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 1200  SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 1257  SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 1258  SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 946                   PANCREATITIS                MONDO:MONDO:0004982
# 947                   PANCREATITIS                MONDO:MONDO:0004982
#
#            pred2 pred2_source            pred2_api               pred2_pubmed  \
# 3888    disrupts       SEMMED      SEMMED Gene API                   20155839
# 6508    disrupts       SEMMED      SEMMED Gene API                   27491710
# 6509    disrupts       SEMMED      SEMMED Gene API                   27491710
# 1197     affects       SEMMED  SEMMED Chemical API  20536561,23624075,7665170
# 1198     affects       SEMMED  SEMMED Chemical API  20536561,23624075,7665170
# 1199    disrupts       SEMMED  SEMMED Chemical API           22143069,2884198
# 1200    disrupts       SEMMED  SEMMED Chemical API           22143069,2884198
# 1257    disrupts       SEMMED  SEMMED Chemical API                    2992505
# 1258    disrupts       SEMMED  SEMMED Chemical API                    2992505
# 946   related_to       SEMMED   SEMMED Disease API                     159836
# 947   related_to       SEMMED   SEMMED Disease API                     159836
#
#             output_type                      output_name  \
# 3888  BiologicalProcess         SERINE PROTEASE ACTIVITY
# 6508  BiologicalProcess  SUMO-SPECIFIC PROTEASE ACTIVITY
# 6509  BiologicalProcess  SUMO-SPECIFIC PROTEASE ACTIVITY
# 1197  BiologicalProcess         SERINE PROTEASE ACTIVITY
# 1198  BiologicalProcess         SERINE PROTEASE ACTIVITY
# 1199  BiologicalProcess         SERINE PROTEASE ACTIVITY
# 1200  BiologicalProcess         SERINE PROTEASE ACTIVITY
# 1257  BiologicalProcess       CYSTEINE PROTEASE ACTIVITY
# 1258  BiologicalProcess       CYSTEINE PROTEASE ACTIVITY
# 946   BiologicalProcess         SERINE PROTEASE ACTIVITY
# 947   BiologicalProcess         SERINE PROTEASE ACTIVITY
#
#                                  output_id
# 3888         name:SERINE PROTEASE ACTIVITY
# 6508  name:SUMO-SPECIFIC PROTEASE ACTIVITY
# 6509  name:SUMO-SPECIFIC PROTEASE ACTIVITY
# 1197         name:SERINE PROTEASE ACTIVITY
# 1198         name:SERINE PROTEASE ACTIVITY
# 1199         name:SERINE PROTEASE ACTIVITY
# 1200         name:SERINE PROTEASE ACTIVITY
# 1257       name:CYSTEINE PROTEASE ACTIVITY
# 1258       name:CYSTEINE PROTEASE ACTIVITY
# 946          name:SERINE PROTEASE ACTIVITY
# 947          name:SERINE PROTEASE ACTIVITY

# %% [markdown]
# ## 2.2 Camostat to Protease Related Genes
# ### 2.2.1 Camostat to Protease Related Genes Query

# %%
camastat_Gene_query_results = predict_many(camostat, node_type_list, 'Gene')
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# Intermediate Node type running:
# Disease
# API 8.1 pharos failed
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature

# %%
#camastat_Gene_query_results
# Out:
#          input         input_type                 pred1 pred1_source  \
# 0     CAMOSTAT  ChemicalSubstance  negatively_regulates       SEMMED
# 1     CAMOSTAT  ChemicalSubstance  negatively_regulates       SEMMED
# 2     CAMOSTAT  ChemicalSubstance  negatively_regulates       SEMMED
# 3     CAMOSTAT  ChemicalSubstance            related_to          CTD
# 4     CAMOSTAT  ChemicalSubstance            related_to          CTD
# ...        ...                ...                   ...          ...
# 8343  CAMOSTAT  ChemicalSubstance              disrupts       SEMMED
# 8344  CAMOSTAT  ChemicalSubstance              disrupts       SEMMED
# 8345  CAMOSTAT  ChemicalSubstance              disrupts       SEMMED
# 8346  CAMOSTAT  ChemicalSubstance              disrupts       SEMMED
# 8347  CAMOSTAT  ChemicalSubstance              disrupts       SEMMED
#
#                 pred1_api       pred1_pubmed         node1_type  \
# 0     SEMMED Chemical API           11291936               Gene
# 1     SEMMED Chemical API           11291936               Gene
# 2     SEMMED Chemical API           11291936               Gene
# 3                 CTD API  25766432,27773435               Gene
# 4                 CTD API           26599507               Gene
# ...                   ...                ...                ...
# 8343  SEMMED Chemical API            6205521  BiologicalProcess
# 8344  SEMMED Chemical API            6205521  BiologicalProcess
# 8345  SEMMED Chemical API            6205521  BiologicalProcess
# 8346  SEMMED Chemical API            6205521  BiologicalProcess
# 8347  SEMMED Chemical API            6205521  BiologicalProcess
#
#             node1_name               node1_id                      pred2  \
# 0             C2985149          UMLS:C2985149       negatively_regulates
# 1             C2985149          UMLS:C2985149  physically_interacts_with
# 2             C2985149          UMLS:C2985149       positively_regulates
# 3                 CCN2          NCBIGene:1490       negatively_regulates
# 4                SMAD2          NCBIGene:4087       positively_regulates
# ...                ...                    ...                        ...
# 8343  TRYPSIN ACTIVITY  name:TRYPSIN ACTIVITY                   disrupts
# 8344  TRYPSIN ACTIVITY  name:TRYPSIN ACTIVITY                   disrupts
# 8345  TRYPSIN ACTIVITY  name:TRYPSIN ACTIVITY                   disrupts
# 8346  TRYPSIN ACTIVITY  name:TRYPSIN ACTIVITY                    affects
# 8347  TRYPSIN ACTIVITY  name:TRYPSIN ACTIVITY                   disrupts
#
#      pred2_source                      pred2_api  \
# 0          SEMMED                SEMMED Gene API
# 1          SEMMED                SEMMED Gene API
# 2          SEMMED                SEMMED Gene API
# 3          SEMMED                SEMMED Gene API
# 4          SEMMED                SEMMED Gene API
# ...           ...                            ...
# 8343       SEMMED  SEMMED Biological Process API
# 8344       SEMMED  SEMMED Biological Process API
# 8345       SEMMED  SEMMED Biological Process API
# 8346       SEMMED  SEMMED Biological Process API
# 8347       SEMMED  SEMMED Biological Process API
#
#                                       pred2_pubmed output_type output_name  \
# 0              11306691,12381730,12514171,18562499        Gene    C1705556
# 1     10226149,10777731,10962016,11306691,12514171        Gene    C1705556
# 2                                 1338049,15978904        Gene    C1705556
# 3                                         24288211        Gene    C1705556
# 4                                         27184078        Gene    C1705556
# ...                                            ...         ...         ...
# 8343                                      16339296        Gene    C0054756
# 8344                                       1707846        Gene    C0078939
# 8345                                      11853759        Gene    C0532449
# 8346                                       6831491        Gene    C0052502
# 8347                                      19812526        Gene      SPINK1
#
#           output_id
# 0     UMLS:C1705556
# 1     UMLS:C1705556
# 2     UMLS:C1705556
# 3     UMLS:C1705556
# 4     UMLS:C1705556
# ...             ...
# 8343  UMLS:C0054756
# 8344  UMLS:C0078939
# 8345  UMLS:C0532449
# 8346  UMLS:C0052502
# 8347  NCBIGene:6690
#
# [55289 rows x 16 columns]

# %%
## which fo the camastat_Gene_query_results have protease-related activity? 
gene_list = list(camastat_Gene_query_results["output_name"])
gene_list = list(dict.fromkeys(gene_list))
# print(gene_list)
print(len(gene_list))
## Would be nice if there was way to search UMLS id types.. ie UMLS:C0052502
# Out:
# 11829

# %%
## list genes with "protease" in full name. this genes will be used to intersect the camastat_Gene_query_results
#### Need to come up with a quicker way to do this
gene_list2 = gene_list[9907:]
protease_related_genes_identified = []
index = 9907
for gene_name in gene_list2:
    if(index % 100 == 0):
#         print("Index")
#         print(index)
    current_query = ht.query(gene_name)
    if(len(current_query['Gene']) > 0):
        if(('PROTEASE' in current_query['Gene'][0]['name']) or ('protease' in current_query['Gene'][0]['name'])):
            print(gene_name)
            protease_related_genes_identified.append(gene_name)
    index = index + 1

# %%
protease_related_genes_identified = ['PRSS2','PRSS3','TMPRSS4','PRSS8','TMPRSS13','PRSS55','TMPRSS12','ST14','TMPRSS9','TMPRSS2','TMPRSS11D','TMPRSS11A','PRSS1','PRSS50','PRSS27','PRSS12','TMPRSS15','PRSS58','PRSS23','PRSS57']

# %% [markdown]
# ### 2.2.2 Camostat to Protease Related Genes Results

# %%
camastat_Gene_query_results[camastat_Gene_query_results["output_name"].isin(protease_related_genes_identified)]
# Out:
#          input         input_type                      pred1 pred1_source  \
# 2198  CAMOSTAT  ChemicalSubstance  physically_interacts_with     drugbank
# 2199  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2200  CAMOSTAT  ChemicalSubstance  physically_interacts_with         None
# 2201  CAMOSTAT  ChemicalSubstance                 related_to       pharos
# 2202  CAMOSTAT  ChemicalSubstance  physically_interacts_with     drugbank
# ...        ...                ...                        ...          ...
# 5488  CAMOSTAT  ChemicalSubstance                   disrupts       SEMMED
# 6567  CAMOSTAT  ChemicalSubstance                   disrupts       SEMMED
# 7046  CAMOSTAT  ChemicalSubstance                   disrupts       SEMMED
# 7811  CAMOSTAT  ChemicalSubstance                   disrupts       SEMMED
# 7813  CAMOSTAT  ChemicalSubstance                   disrupts       SEMMED
#
#                 pred1_api    pred1_pubmed         node1_type node1_name  \
# 2198      MyChem.info API  143965,7629790               Gene      PRSS1
# 2199      MyChem.info API            None               Gene      PRSS1
# 2200            DGIdb API            None               Gene      PRSS1
# 2201   Automat PHAROS API            None               Gene      PRSS1
# 2202      MyChem.info API  143965,7629790               Gene      PRSS1
# ...                   ...             ...                ...        ...
# 5488  SEMMED Chemical API        21541544  BiologicalProcess     GROWTH
# 6567  SEMMED Chemical API        21541544  BiologicalProcess     GROWTH
# 7046  SEMMED Chemical API        21541544  BiologicalProcess     GROWTH
# 7811  SEMMED Chemical API        21541544  BiologicalProcess     GROWTH
# 7813  SEMMED Chemical API        21541544  BiologicalProcess     GROWTH
#
#            node1_id                      pred2 pred2_source  \
# 2198  NCBIGene:5644  physically_interacts_with         None
# 2199  NCBIGene:5644  physically_interacts_with         None
# 2200  NCBIGene:5644  physically_interacts_with         None
# 2201  NCBIGene:5644  physically_interacts_with         None
# 2202  NCBIGene:5644  physically_interacts_with         None
# ...             ...                        ...          ...
# 5488    name:GROWTH                   disrupts       SEMMED
# 6567    name:GROWTH                   disrupts       SEMMED
# 7046    name:GROWTH                   disrupts       SEMMED
# 7811    name:GROWTH                    affects       SEMMED
# 7813    name:GROWTH                    affects       SEMMED
#
#                           pred2_api                         pred2_pubmed  \
# 2198                    BioLink API                                 None
# 2199                    BioLink API                                 None
# 2200                    BioLink API                                 None
# 2201                    BioLink API                                 None
# 2202                    BioLink API                                 None
# ...                             ...                                  ...
# 5488  SEMMED Biological Process API                             26993610
# 6567  SEMMED Biological Process API                             20303767
# 7046  SEMMED Biological Process API                             11708800
# 7811  SEMMED Biological Process API  14654438,17892472,18389234,27190239
# 7813  SEMMED Biological Process API                             27983914
#
#      output_type output_name       output_id
# 2198        Gene       PRSS2   NCBIGene:5645
# 2199        Gene       PRSS2   NCBIGene:5645
# 2200        Gene       PRSS2   NCBIGene:5645
# 2201        Gene       PRSS2   NCBIGene:5645
# 2202        Gene       PRSS3   NCBIGene:5646
# ...          ...         ...             ...
# 5488        Gene     TMPRSS4  NCBIGene:56649
# 6567        Gene   TMPRSS11D   NCBIGene:9407
# 7046        Gene        ST14   NCBIGene:6768
# 7811        Gene       PRSS1   NCBIGene:5644
# 7813        Gene       PRSS8   NCBIGene:5652
#
# [150 rows x 16 columns]

# %% [markdown]
# ## 2.3 Camostat to Coagulation
# ### 2.3.1 Camostat to Coagulation Results

# %%
camastat_caog_BP_query_results = camastat_BP_query_results[camastat_BP_query_results["output_name"].str.contains("COAGULATION")]
camastat_caog_BP_query_results
# Out:
#          input         input_type                      pred1 pred1_source  \
# 2717  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2718  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2719  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 2720  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2721  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 2722  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2723  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 2724  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2751  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2752  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2753  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2754  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 2922  CAMOSTAT  ChemicalSubstance  physically_interacts_with  drugcentral
# 2923  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 2924  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 2925  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 2926  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 4860  CAMOSTAT  ChemicalSubstance                 related_to          CTD
# 20    CAMOSTAT  ChemicalSubstance  physically_interacts_with       SEMMED
# 21    CAMOSTAT  ChemicalSubstance  physically_interacts_with       SEMMED
# 22    CAMOSTAT  ChemicalSubstance  physically_interacts_with       SEMMED
# 23    CAMOSTAT  ChemicalSubstance       negatively_regulates       SEMMED
# 24    CAMOSTAT  ChemicalSubstance  physically_interacts_with       SEMMED
# 25    CAMOSTAT  ChemicalSubstance       negatively_regulates       SEMMED
# 26    CAMOSTAT  ChemicalSubstance  physically_interacts_with       SEMMED
# 27    CAMOSTAT  ChemicalSubstance       negatively_regulates       SEMMED
# 28    CAMOSTAT  ChemicalSubstance       positively_regulates       SEMMED
# 29    CAMOSTAT  ChemicalSubstance       negatively_regulates       SEMMED
# 30    CAMOSTAT  ChemicalSubstance       negatively_regulates       SEMMED
# 3     CAMOSTAT  ChemicalSubstance                     treats       SEMMED
# 4     CAMOSTAT  ChemicalSubstance                   disrupts       SEMMED
# 5     CAMOSTAT  ChemicalSubstance                     treats       SEMMED
# 6     CAMOSTAT  ChemicalSubstance                 related_to      scibite
# 11    CAMOSTAT  ChemicalSubstance                   disrupts       SEMMED
#
#                        pred1_api     pred1_pubmed         node1_type  \
# 2717             MyChem.info API             None               Gene
# 2718             MyChem.info API             None               Gene
# 2719                     CTD API         27773435               Gene
# 2720             MyChem.info API             None               Gene
# 2721                     CTD API         27773435               Gene
# 2722             MyChem.info API             None               Gene
# 2723                     CTD API         25766432               Gene
# 2724             MyChem.info API             None               Gene
# 2751             MyChem.info API             None               Gene
# 2752             MyChem.info API             None               Gene
# 2753             MyChem.info API             None               Gene
# 2754                     CTD API         25766432               Gene
# 2922             MyChem.info API             None               Gene
# 2923                     CTD API         27773435               Gene
# 2924                     CTD API         25766432               Gene
# 2925                     CTD API         20023007               Gene
# 2926                     CTD API         27773435               Gene
# 4860                     CTD API         25766432               Gene
# 20           SEMMED Chemical API          6202931  ChemicalSubstance
# 21           SEMMED Chemical API          2909420  ChemicalSubstance
# 22           SEMMED Chemical API         21541544  ChemicalSubstance
# 23           SEMMED Chemical API         21528279  ChemicalSubstance
# 24           SEMMED Chemical API         21541544  ChemicalSubstance
# 25           SEMMED Chemical API         21528279  ChemicalSubstance
# 26           SEMMED Chemical API         21541544  ChemicalSubstance
# 27           SEMMED Chemical API         21528279  ChemicalSubstance
# 28           SEMMED Chemical API         21541544  ChemicalSubstance
# 29           SEMMED Chemical API          9322090  ChemicalSubstance
# 30           SEMMED Chemical API          9322090  ChemicalSubstance
# 3            SEMMED Chemical API          6386547            Disease
# 4            SEMMED Chemical API          8352567            Disease
# 5            SEMMED Chemical API  15796165,229707            Disease
# 6     Automat CORD19 Scibite API             None            Disease
# 11           SEMMED Chemical API         21541544  BiologicalProcess
#
#                         node1_name                           node1_id  \
# 2717                            F2                      NCBIGene:2147
# 2718                           PLG                      NCBIGene:5340
# 2719                           PLG                      NCBIGene:5340
# 2720                           PLG                      NCBIGene:5340
# 2721                           PLG                      NCBIGene:5340
# 2722                         HGFAC                      NCBIGene:3083
# 2723                        COL1A1                      NCBIGene:1277
# 2724                            F2                      NCBIGene:2147
# 2751                            F2                      NCBIGene:2147
# 2752                            F2                      NCBIGene:2147
# 2753                            F2                      NCBIGene:2147
# 2754                      SERPINE1                      NCBIGene:5054
# 2922                           PLG                      NCBIGene:5340
# 2923                           PLG                      NCBIGene:5340
# 2924                      SERPINE1                      NCBIGene:5054
# 2925                           TNF                      NCBIGene:7124
# 2926                           TNF                      NCBIGene:7124
# 4860                      SERPINE1                      NCBIGene:5054
# 20                        C0001128                      UMLS:C0001128
# 21                        C0309049                      UMLS:C0309049
# 22    SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 23    SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 24    SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 25    SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 26    SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 27    SERINE PROTEINASE INHIBITORS  name:SERINE PROTEINASE INHIBITORS
# 28                    FLUOROURACIL                  name:FLUOROURACIL
# 29                         FUT 175                       name:FUT 175
# 30                         FUT 175                       name:FUT 175
# 3                         C0241863                      UMLS:C0241863
# 4                         C0598934                      UMLS:C0598934
# 5                     PANCREATITIS                MONDO:MONDO:0004982
# 6                     PANCREATITIS                MONDO:MONDO:0004982
# 11                          GROWTH                        name:GROWTH
#
#                        pred2                     pred2_source  \
# 2717  functional_association                           entrez
# 2718              related_to  Translator Text Mining Provider
# 2719              related_to  Translator Text Mining Provider
# 2720  functional_association                           entrez
# 2721  functional_association                           entrez
# 2722  functional_association                           entrez
# 2723  functional_association                           entrez
# 2724  functional_association                           entrez
# 2751  functional_association                           entrez
# 2752  functional_association                           entrez
# 2753  functional_association                           entrez
# 2754  functional_association                           entrez
# 2922              related_to  Translator Text Mining Provider
# 2923              related_to  Translator Text Mining Provider
# 2924              related_to  Translator Text Mining Provider
# 2925              related_to  Translator Text Mining Provider
# 2926              related_to  Translator Text Mining Provider
# 4860  functional_association                           entrez
# 20                   affects                           SEMMED
# 21                   affects                           SEMMED
# 22                   affects                           SEMMED
# 23                   affects                           SEMMED
# 24      negatively_regulates                           SEMMED
# 25      negatively_regulates                           SEMMED
# 26                related_to                           SEMMED
# 27                related_to                           SEMMED
# 28                   affects                           SEMMED
# 29                   affects                           SEMMED
# 30                  disrupts                           SEMMED
# 3                     causes                           SEMMED
# 4                    affects                           SEMMED
# 5                    affects                           SEMMED
# 6                    affects                           SEMMED
# 11                   affects                           SEMMED
#
#                           pred2_api                        pred2_pubmed  \
# 2717                MyGene.info API                                None
# 2718                  CORD Gene API                                None
# 2719                  CORD Gene API                                None
# 2720                MyGene.info API                             1986355
# 2721                MyGene.info API                             1986355
# 2722                MyGene.info API                            21873635
# 2723                MyGene.info API                                None
# 2724                MyGene.info API                                None
# 2751                MyGene.info API                            12855810
# 2752                MyGene.info API                            21873635
# 2753                MyGene.info API                             9038223
# 2754                MyGene.info API                             9207454
# 2922                  CORD Gene API                                None
# 2923                  CORD Gene API                                None
# 2924                  CORD Gene API                                None
# 2925                  CORD Gene API                                None
# 2926                  CORD Gene API                                None
# 4860                MyGene.info API                             1695900
# 20              SEMMED Chemical API  11213446,13965658,19544672,8191412
# 21              SEMMED Chemical API            10573178,15730339,347136
# 22              SEMMED Chemical API  10615009,24201825,27717901,9271817
# 23              SEMMED Chemical API  10615009,24201825,27717901,9271817
# 24              SEMMED Chemical API                            10922378
# 25              SEMMED Chemical API                            10922378
# 26              SEMMED Chemical API                            23308198
# 27              SEMMED Chemical API                            23308198
# 28              SEMMED Chemical API                            12356422
# 29              SEMMED Chemical API                             3443413
# 30              SEMMED Chemical API                             3443413
# 3                SEMMED Disease API                             7051410
# 4                SEMMED Disease API                   10656446,23889169
# 5                SEMMED Disease API                    15552881,7268608
# 6                SEMMED Disease API                    15552881,7268608
# 11    SEMMED Biological Process API                   11535960,23233658
#
#             output_type                               output_name  \
# 2717  BiologicalProcess                         BLOOD COAGULATION
# 2718  BiologicalProcess                         BLOOD COAGULATION
# 2719  BiologicalProcess                         BLOOD COAGULATION
# 2720  BiologicalProcess                         BLOOD COAGULATION
# 2721  BiologicalProcess                         BLOOD COAGULATION
# 2722  BiologicalProcess                         BLOOD COAGULATION
# 2723  BiologicalProcess                         BLOOD COAGULATION
# 2724  BiologicalProcess      BLOOD COAGULATION, INTRINSIC PATHWAY
# 2751  BiologicalProcess           REGULATION OF BLOOD COAGULATION
# 2752  BiologicalProcess  POSITIVE REGULATION OF BLOOD COAGULATION
# 2753  BiologicalProcess  POSITIVE REGULATION OF BLOOD COAGULATION
# 2754  BiologicalProcess  POSITIVE REGULATION OF BLOOD COAGULATION
# 2922  BiologicalProcess                               COAGULATION
# 2923  BiologicalProcess                               COAGULATION
# 2924  BiologicalProcess                               COAGULATION
# 2925  BiologicalProcess                               COAGULATION
# 2926  BiologicalProcess                               COAGULATION
# 4860  BiologicalProcess  NEGATIVE REGULATION OF BLOOD COAGULATION
# 20    BiologicalProcess                         BLOOD COAGULATION
# 21    BiologicalProcess                         BLOOD COAGULATION
# 22    BiologicalProcess                         BLOOD COAGULATION
# 23    BiologicalProcess                         BLOOD COAGULATION
# 24    BiologicalProcess                         BLOOD COAGULATION
# 25    BiologicalProcess                         BLOOD COAGULATION
# 26    BiologicalProcess                         BLOOD COAGULATION
# 27    BiologicalProcess                         BLOOD COAGULATION
# 28    BiologicalProcess                         BLOOD COAGULATION
# 29    BiologicalProcess                         BLOOD COAGULATION
# 30    BiologicalProcess                         BLOOD COAGULATION
# 3     BiologicalProcess                         BLOOD COAGULATION
# 4     BiologicalProcess                         BLOOD COAGULATION
# 5     BiologicalProcess                         BLOOD COAGULATION
# 6     BiologicalProcess                         BLOOD COAGULATION
# 11    BiologicalProcess                         BLOOD COAGULATION
#
#                    output_id
# 2717           GO:GO:0007596
# 2718           GO:GO:0007596
# 2719           GO:GO:0007596
# 2720           GO:GO:0007596
# 2721           GO:GO:0007596
# 2722           GO:GO:0007596
# 2723           GO:GO:0007596
# 2724           GO:GO:0007597
# 2751           GO:GO:0030193
# 2752           GO:GO:0030194
# 2753           GO:GO:0030194
# 2754           GO:GO:0030194
# 2922           GO:GO:0050817
# 2923           GO:GO:0050817
# 2924           GO:GO:0050817
# 2925           GO:GO:0050817
# 2926           GO:GO:0050817
# 4860           GO:GO:0030195
# 20    name:BLOOD COAGULATION
# 21    name:BLOOD COAGULATION
# 22    name:BLOOD COAGULATION
# 23    name:BLOOD COAGULATION
# 24    name:BLOOD COAGULATION
# 25    name:BLOOD COAGULATION
# 26    name:BLOOD COAGULATION
# 27    name:BLOOD COAGULATION
# 28    name:BLOOD COAGULATION
# 29    name:BLOOD COAGULATION
# 30    name:BLOOD COAGULATION
# 3     name:BLOOD COAGULATION
# 4     name:BLOOD COAGULATION
# 5     name:BLOOD COAGULATION
# 6     name:BLOOD COAGULATION
# 11    name:BLOOD COAGULATION

# %%
camastat_caog_genes = camastat_caog_BP_query_results[camastat_caog_BP_query_results['node1_type'] == "Gene"]

# %%
camastat_caog_genes_names = list(camastat_caog_genes["node1_name"])

camastat_caog_genes_names = list(dict.fromkeys(camastat_caog_genes_names))

print("IDENTIFIED GENES")
print(camastat_caog_genes_names)


coag_protease_related_genes_identified = []
for gene_name in camastat_caog_genes_names :
    current_query = ht.query(gene_name)
    if(len(current_query['Gene']) > 0):
        print(current_query['Gene'][0])
        if(('PROTEASE' in current_query['Gene'][0]['name']) or ('protease' in current_query['Gene'][0]['name'])):
            print(gene_name)
            coag_protease_related_genes_identified.append(gene_name)
            
## NONE OF THE GENES HAD "PROTEASE IN NAME"
# Out:
# IDENTIFIED GENES
# ['F2', 'PLG', 'HGFAC', 'COL1A1', 'SERPINE1', 'TNF']
# {'NCBIGene': '2147', 'name': 'coagulation factor II, thrombin', 'SYMBOL': 'F2', 'UMLS': 'C1414504', 'HGNC': '3535', 'UNIPROTKB': 'P00734', 'ENSEMBL': 'ENSG00000180210', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '2147'}, 'display': 'NCBIGene(2147) ENSEMBL(ENSG00000180210) HGNC(3535) UMLS(C1414504) UNIPROTKB(P00734) SYMBOL(F2)', 'type': 'Gene'}
# {'NCBIGene': '5340', 'name': 'plasminogen', 'SYMBOL': 'PLG', 'UMLS': 'C1367553', 'HGNC': '9071', 'UNIPROTKB': 'P00747', 'ENSEMBL': 'ENSG00000122194', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5340'}, 'display': 'NCBIGene(5340) ENSEMBL(ENSG00000122194) HGNC(9071) UMLS(C1367553) UNIPROTKB(P00747) SYMBOL(PLG)', 'type': 'Gene'}
# {'NCBIGene': '3083', 'name': 'HGF activator', 'SYMBOL': 'HGFAC', 'UMLS': 'C1415534', 'HGNC': '4894', 'UNIPROTKB': 'Q04756', 'ENSEMBL': 'ENSG00000109758', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3083'}, 'display': 'NCBIGene(3083) ENSEMBL(ENSG00000109758) HGNC(4894) UMLS(C1415534) UNIPROTKB(Q04756) SYMBOL(HGFAC)', 'type': 'Gene'}
# {'NCBIGene': '1277', 'name': 'collagen type I alpha 1 chain', 'SYMBOL': 'COL1A1', 'UMLS': 'C1332772', 'HGNC': '2197', 'UNIPROTKB': 'P02452', 'ENSEMBL': 'ENSG00000108821', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1277'}, 'display': 'NCBIGene(1277) ENSEMBL(ENSG00000108821) HGNC(2197) UMLS(C1332772) UNIPROTKB(P02452) SYMBOL(COL1A1)', 'type': 'Gene'}
# {'NCBIGene': '5054', 'name': 'serpin family E member 1', 'SYMBOL': 'SERPINE1', 'UMLS': 'C1418252', 'HGNC': '8583', 'UNIPROTKB': 'P05121', 'ENSEMBL': 'ENSG00000106366', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5054'}, 'display': 'NCBIGene(5054) ENSEMBL(ENSG00000106366) HGNC(8583) UMLS(C1418252) UNIPROTKB(P05121) SYMBOL(SERPINE1)', 'type': 'Gene'}
# {'NCBIGene': '7124', 'name': 'tumor necrosis factor', 'SYMBOL': 'TNF', 'UMLS': 'C0812246', 'HGNC': '11892', 'UNIPROTKB': 'P01375', 'ENSEMBL': 'ENSG00000204490', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7124'}, 'display': 'NCBIGene(7124) ENSEMBL(ENSG00000204490) HGNC(11892) UMLS(C0812246) UNIPROTKB(P01375) SYMBOL(TNF)', 'type': 'Gene'}

# %% [markdown]
# ## 3 COVID-19 Related Queries
# ### 3.1 COVID-19 -> Proteases -> Drugs Query

# %%
covid19 = ht.query("COVID-19")['Disease'][0]
covid_gene_drug = predict_many(covid19, ['Gene'], 'ChemicalSubstance')
covid_genes_names = list(covid_gene_drug ["node1_name"])
covid_genes_names = list(dict.fromkeys(covid_genes_names))
print("IDENTIFIED GENES")
print(covid_genes_names)
covid_protease_related_genes_identified = []
for gene_name in covid_genes_names :
    current_query = ht.query(gene_name)
    if(len(current_query['Gene']) > 0):
#         print(current_query['Gene'][0])
        if(('PROTEASE' in current_query['Gene'][0]['name']) or ('protease' in current_query['Gene'][0]['name'])):
            print(gene_name)
            covid_protease_related_genes_identified.append(gene_name)
# Out:
# IDENTIFIED GENES
# ['ACE2', 'CRP', 'TMPRSS2', 'TH', 'MARS1', 'SON', 'POR']
# {'NCBIGene': '59272', 'name': 'angiotensin I converting enzyme 2', 'SYMBOL': 'ACE2', 'UMLS': 'C1422064', 'HGNC': '13557', 'UNIPROTKB': 'Q9BYF1', 'ENSEMBL': 'ENSG00000130234', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'}, 'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)', 'type': 'Gene'}
# {'NCBIGene': '1401', 'name': 'C-reactive protein', 'SYMBOL': 'CRP', 'UMLS': 'C1413716', 'HGNC': '2367', 'UNIPROTKB': 'P02741', 'ENSEMBL': 'ENSG00000132693', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1401'}, 'display': 'NCBIGene(1401) ENSEMBL(ENSG00000132693) HGNC(2367) UMLS(C1413716) UNIPROTKB(P02741) SYMBOL(CRP)', 'type': 'Gene'}
# {'NCBIGene': '7113', 'name': 'transmembrane serine protease 2', 'SYMBOL': 'TMPRSS2', 'UMLS': 'C1336641', 'HGNC': '11876', 'UNIPROTKB': 'O15393', 'ENSEMBL': 'ENSG00000184012', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7113'}, 'display': 'NCBIGene(7113) ENSEMBL(ENSG00000184012) HGNC(11876) UMLS(C1336641) UNIPROTKB(O15393) SYMBOL(TMPRSS2)', 'type': 'Gene'}
# TMPRSS2
# {'NCBIGene': '7054', 'name': 'tyrosine hydroxylase', 'SYMBOL': 'TH', 'UMLS': 'C1420718', 'HGNC': '11782', 'UNIPROTKB': 'P07101', 'ENSEMBL': 'ENSG00000180176', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7054'}, 'display': 'NCBIGene(7054) ENSEMBL(ENSG00000180176) HGNC(11782) UMLS(C1420718) UNIPROTKB(P07101) SYMBOL(TH)', 'type': 'Gene'}
# {'NCBIGene': '4141', 'name': 'methionyl-tRNA synthetase 1', 'SYMBOL': 'MARS1', 'UMLS': 'C1417035', 'HGNC': '6898', 'UNIPROTKB': 'P56192', 'ENSEMBL': 'ENSG00000166986', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4141'}, 'display': 'NCBIGene(4141) ENSEMBL(ENSG00000166986) HGNC(6898) UMLS(C1417035) UNIPROTKB(P56192) SYMBOL(MARS1)', 'type': 'Gene'}
# {'NCBIGene': '6651', 'name': 'SON DNA and RNA binding protein', 'SYMBOL': 'SON', 'UMLS': 'C1420310', 'HGNC': '11183', 'UNIPROTKB': 'P18583', 'ENSEMBL': 'ENSG00000159140', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '6651'}, 'display': 'NCBIGene(6651) ENSEMBL(ENSG00000159140) HGNC(11183) UMLS(C1420310) UNIPROTKB(P18583) SYMBOL(SON)', 'type': 'Gene'}
# {'NCBIGene': '5447', 'name': 'cytochrome p450 oxidoreductase', 'SYMBOL': 'POR', 'UMLS': 'C1335232', 'HGNC': '9208', 'UNIPROTKB': 'P16435', 'ENSEMBL': 'ENSG00000127948', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5447'}, 'display': 'NCBIGene(5447) ENSEMBL(ENSG00000127948) HGNC(9208) UMLS(C1335232) UNIPROTKB(P16435) SYMBOL(POR)', 'type': 'Gene'}

# %%
covid_protease_related_genes_identified
# Out:
# ['TMPRSS2']

# %%
### COVID-19 ---> TMPRSS2 ----> DRUGS 
covid_gene_drug[covid_gene_drug["node1_name"] == "TMPRSS2"]
# Out:
#          input input_type       pred1 pred1_source  \
# 17    COVID-19    Disease  related_to     scigraph
# 33    COVID-19    Disease  related_to     scigraph
# 38    COVID-19    Disease  related_to     scigraph
# 45    COVID-19    Disease  related_to     scigraph
# 61    COVID-19    Disease  related_to     scigraph
# 75    COVID-19    Disease  related_to     scigraph
# 84    COVID-19    Disease  related_to     scigraph
# 340   COVID-19    Disease  related_to     scigraph
# 345   COVID-19    Disease  related_to     scigraph
# 361   COVID-19    Disease  related_to     scigraph
# 362   COVID-19    Disease  related_to     scigraph
# 363   COVID-19    Disease  related_to     scigraph
# 376   COVID-19    Disease  related_to     scigraph
# 954   COVID-19    Disease  related_to     scigraph
# 1001  COVID-19    Disease  related_to     scigraph
# 1504  COVID-19    Disease  related_to     scigraph
# 1946  COVID-19    Disease  related_to     scigraph
# 1957  COVID-19    Disease  related_to     scigraph
# 1958  COVID-19    Disease  related_to     scigraph
# 2423  COVID-19    Disease  related_to     scigraph
# 2833  COVID-19    Disease  related_to     scigraph
# 2834  COVID-19    Disease  related_to     scigraph
# 2835  COVID-19    Disease  related_to     scigraph
# 2836  COVID-19    Disease  related_to     scigraph
# 2837  COVID-19    Disease  related_to     scigraph
# 2838  COVID-19    Disease  related_to     scigraph
# 2839  COVID-19    Disease  related_to     scigraph
# 2840  COVID-19    Disease  related_to     scigraph
# 2841  COVID-19    Disease  related_to     scigraph
# 2842  COVID-19    Disease  related_to     scigraph
# 2843  COVID-19    Disease  related_to     scigraph
# 2844  COVID-19    Disease  related_to     scigraph
# 2845  COVID-19    Disease  related_to     scigraph
# 2846  COVID-19    Disease  related_to     scigraph
# 2847  COVID-19    Disease  related_to     scigraph
# 2848  COVID-19    Disease  related_to     scigraph
# 2849  COVID-19    Disease  related_to     scigraph
# 2850  COVID-19    Disease  related_to     scigraph
# 2851  COVID-19    Disease  related_to     scigraph
# 2852  COVID-19    Disease  related_to     scigraph
# 2853  COVID-19    Disease  related_to     scigraph
# 2854  COVID-19    Disease  related_to     scigraph
# 2855  COVID-19    Disease  related_to     scigraph
# 2856  COVID-19    Disease  related_to     scigraph
# 2857  COVID-19    Disease  related_to     scigraph
# 2858  COVID-19    Disease  related_to     scigraph
# 2859  COVID-19    Disease  related_to     scigraph
#
#                         pred1_api pred1_pubmed node1_type node1_name  \
# 17    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 33    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 38    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 45    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 61    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 75    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 84    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 340   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 345   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 361   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 362   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 363   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 376   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 954   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1001  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1504  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1946  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1957  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1958  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2423  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2833  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2834  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2835  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2836  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2837  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2838  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2839  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2840  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2841  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2842  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2843  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2844  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2845  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2846  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2847  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2848  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2849  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2850  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2851  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2852  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2853  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2854  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2855  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2856  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2857  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2858  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2859  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
#
#            node1_id                      pred2  \
# 17    NCBIGene:7113                 related_to
# 33    NCBIGene:7113                 related_to
# 38    NCBIGene:7113                 related_to
# 45    NCBIGene:7113                 related_to
# 61    NCBIGene:7113                 related_to
# 75    NCBIGene:7113                 related_to
# 84    NCBIGene:7113                 related_to
# 340   NCBIGene:7113                 related_to
# 345   NCBIGene:7113                 related_to
# 361   NCBIGene:7113                 related_to
# 362   NCBIGene:7113                 related_to
# 363   NCBIGene:7113  physically_interacts_with
# 376   NCBIGene:7113                 related_to
# 954   NCBIGene:7113                 related_to
# 1001  NCBIGene:7113                 related_to
# 1504  NCBIGene:7113                 related_to
# 1946  NCBIGene:7113       negatively_regulates
# 1957  NCBIGene:7113  physically_interacts_with
# 1958  NCBIGene:7113       positively_regulates
# 2423  NCBIGene:7113                 related_to
# 2833  NCBIGene:7113                 related_to
# 2834  NCBIGene:7113                 related_to
# 2835  NCBIGene:7113                 related_to
# 2836  NCBIGene:7113                 related_to
# 2837  NCBIGene:7113                 related_to
# 2838  NCBIGene:7113                 related_to
# 2839  NCBIGene:7113                 related_to
# 2840  NCBIGene:7113                 related_to
# 2841  NCBIGene:7113                 related_to
# 2842  NCBIGene:7113                 related_to
# 2843  NCBIGene:7113                 related_to
# 2844  NCBIGene:7113                 related_to
# 2845  NCBIGene:7113                 related_to
# 2846  NCBIGene:7113                 related_to
# 2847  NCBIGene:7113                 related_to
# 2848  NCBIGene:7113                 related_to
# 2849  NCBIGene:7113                 related_to
# 2850  NCBIGene:7113                 related_to
# 2851  NCBIGene:7113                 related_to
# 2852  NCBIGene:7113                 related_to
# 2853  NCBIGene:7113                 related_to
# 2854  NCBIGene:7113                 related_to
# 2855  NCBIGene:7113                 related_to
# 2856  NCBIGene:7113                 related_to
# 2857  NCBIGene:7113                 related_to
# 2858  NCBIGene:7113  physically_interacts_with
# 2859  NCBIGene:7113       positively_regulates
#
#                          pred2_source                    pred2_api  \
# 17                           scigraph  Automat CORD19 Scigraph API
# 33                           scigraph  Automat CORD19 Scigraph API
# 38                           scigraph  Automat CORD19 Scigraph API
# 45                           scigraph  Automat CORD19 Scigraph API
# 61                           scigraph  Automat CORD19 Scigraph API
# 75                           scigraph  Automat CORD19 Scigraph API
# 84                           scigraph  Automat CORD19 Scigraph API
# 340                          scigraph  Automat CORD19 Scigraph API
# 345                          scigraph  Automat CORD19 Scigraph API
# 361                           scibite   Automat CORD19 Scibite API
# 362                          scigraph  Automat CORD19 Scigraph API
# 363                          drugbank              MyChem.info API
# 376                          scigraph  Automat CORD19 Scigraph API
# 954                           chembio          Automat CHEMBIO API
# 1001  Translator Text Mining Provider                CORD Gene API
# 1504                          chembio          Automat CHEMBIO API
# 1946                           SEMMED              SEMMED Gene API
# 1957                           SEMMED              SEMMED Gene API
# 1958                           SEMMED              SEMMED Gene API
# 2423                         scigraph  Automat CORD19 Scigraph API
# 2833                          scibite   Automat CORD19 Scibite API
# 2834                          scibite   Automat CORD19 Scibite API
# 2835                          scibite   Automat CORD19 Scibite API
# 2836                         scigraph  Automat CORD19 Scigraph API
# 2837                         scigraph  Automat CORD19 Scigraph API
# 2838                         scigraph  Automat CORD19 Scigraph API
# 2839                           pharos           Automat PHAROS API
# 2840                           pharos           Automat PHAROS API
# 2841                           pharos           Automat PHAROS API
# 2842                          scibite   Automat CORD19 Scibite API
# 2843                          scibite   Automat CORD19 Scibite API
# 2844                          scibite   Automat CORD19 Scibite API
# 2845                          scibite   Automat CORD19 Scibite API
# 2846                          scibite   Automat CORD19 Scibite API
# 2847                          scibite   Automat CORD19 Scibite API
# 2848                         scigraph  Automat CORD19 Scigraph API
# 2849                          scibite   Automat CORD19 Scibite API
# 2850                          scibite   Automat CORD19 Scibite API
# 2851                          scibite   Automat CORD19 Scibite API
# 2852                          scibite   Automat CORD19 Scibite API
# 2853                         scigraph  Automat CORD19 Scigraph API
# 2854                         scigraph  Automat CORD19 Scigraph API
# 2855                         scigraph  Automat CORD19 Scigraph API
# 2856                          chembio          Automat CHEMBIO API
# 2857                          chembio          Automat CHEMBIO API
# 2858                           SEMMED              SEMMED Gene API
# 2859                           SEMMED              SEMMED Gene API
#
#                              pred2_pubmed        output_type  \
# 17                                   None  ChemicalSubstance
# 33                                   None  ChemicalSubstance
# 38                                   None  ChemicalSubstance
# 45                                   None  ChemicalSubstance
# 61                                   None  ChemicalSubstance
# 75                                   None  ChemicalSubstance
# 84                                   None  ChemicalSubstance
# 340                                  None  ChemicalSubstance
# 345                                  None  ChemicalSubstance
# 361                                  None  ChemicalSubstance
# 362                                  None  ChemicalSubstance
# 363                                  None  ChemicalSubstance
# 376                                  None  ChemicalSubstance
# 954                                  None  ChemicalSubstance
# 1001                                 None  ChemicalSubstance
# 1504                                 None  ChemicalSubstance
# 1946                             26026052  ChemicalSubstance
# 1957  21796535,24109594,24727384,25170998  ChemicalSubstance
# 1958                             11322890  ChemicalSubstance
# 2423                                 None  ChemicalSubstance
# 2833                                 None  ChemicalSubstance
# 2834                                 None  ChemicalSubstance
# 2835                                 None  ChemicalSubstance
# 2836                                 None  ChemicalSubstance
# 2837                                 None  ChemicalSubstance
# 2838                                 None  ChemicalSubstance
# 2839                                 None  ChemicalSubstance
# 2840                                 None  ChemicalSubstance
# 2841                                 None  ChemicalSubstance
# 2842                                 None  ChemicalSubstance
# 2843                                 None  ChemicalSubstance
# 2844                                 None  ChemicalSubstance
# 2845                                 None  ChemicalSubstance
# 2846                                 None  ChemicalSubstance
# 2847                                 None  ChemicalSubstance
# 2848                                 None  ChemicalSubstance
# 2849                                 None  ChemicalSubstance
# 2850                                 None  ChemicalSubstance
# 2851                                 None  ChemicalSubstance
# 2852                                 None  ChemicalSubstance
# 2853                                 None  ChemicalSubstance
# 2854                                 None  ChemicalSubstance
# 2855                                 None  ChemicalSubstance
# 2856                                 None  ChemicalSubstance
# 2857                                 None  ChemicalSubstance
# 2858                             23472063  ChemicalSubstance
# 2859                             20147525  ChemicalSubstance
#
#                                             output_name  \
# 17                                          CHEBI:26667
# 33                                          CHEBI:36080
# 38                                          CHEBI:22587
# 45                                          CHEBI:35222
# 61                                          CHEBI:17089
# 75                                          CHEBI:33709
# 84                                          CHEBI:37670
# 340                                             AREQUIN
# 345                                            L-SERINE
# 361                                            CAMOSTAT
# 362                                            CAMOSTAT
# 363                                            CAMOSTAT
# 376                                             PEPTIDE
# 954                                     ISOCHAMAEJASMIN
# 1001                                        CHEBI:50113
# 1504                                  PSI-RHODOMYRTOXIN
# 1946                             INTERFERING RNA, SMALL
# 1957                                          ANDROGENS
# 1958                                          ANDROGENS
# 2423                                           ARGININE
# 2833                                       CHEMBL423112
# 2834                                       CHEMBL129157
# 2835                                      CHEMBL2110589
# 2836                                        CHEBI:64152
# 2837                                        CHEBI:64926
# 2838                                         CHEBI:9765
# 2839                                      CHEMBL1229259
# 2840                                      CHEMBL1809251
# 2841                                      CHEMBL1809250
# 2842                                           APC-3316
# 2843                                FIBRINOLYSIN, HUMAN
# 2844                                          APROTININ
# 2845                                 NEOANDROGRAPHOLIDE
# 2846                                      PIVAMPICILLIN
# 2847                                            FUT 175
# 2848                                            FUT 175
# 2849                                    (+)-TETRANDRINE
# 2850                                      FANGCHINOLINE
# 2851                                         HETACILLIN
# 2852                                         BROMHEXINE
# 2853                                           CYSTEINE
# 2854                                          LEUPEPTIN
# 2855                                   ARGININE RESIDUE
# 2856  4-(2-OXO-1-PYRROLIDINYL)BENZOIC ACID [2-(2-FUR...
# 2857  N-[(5S,6S,9S)-8-(CYCLOPROPYLMETHYL)-5-METHOXY-...
# 2858                             5' UNTRANSLATED REGION
# 2859                                            EB 1089
#
#                                               output_id
# 17                                    CHEBI:CHEBI:26667
# 33                                    CHEBI:CHEBI:36080
# 38                                    CHEBI:CHEBI:22587
# 45                                    CHEBI:CHEBI:35222
# 61                                    CHEBI:CHEBI:17089
# 75                                    CHEBI:CHEBI:33709
# 84                                    CHEBI:CHEBI:37670
# 340                                        name:AREQUIN
# 345                                       name:L-SERINE
# 361                                       name:CAMOSTAT
# 362                                       name:CAMOSTAT
# 363                                       name:CAMOSTAT
# 376                                        name:PEPTIDE
# 954                                name:ISOCHAMAEJASMIN
# 1001                                  CHEBI:CHEBI:50113
# 1504                             name:PSI-RHODOMYRTOXIN
# 1946                        name:INTERFERING RNA, SMALL
# 1957                                     name:ANDROGENS
# 1958                                     name:ANDROGENS
# 2423                                      name:ARGININE
# 2833                       CHEMBL.COMPOUND:CHEMBL423112
# 2834                       CHEMBL.COMPOUND:CHEMBL129157
# 2835                      CHEMBL.COMPOUND:CHEMBL2110589
# 2836                                  CHEBI:CHEBI:64152
# 2837                                  CHEBI:CHEBI:64926
# 2838                                   CHEBI:CHEBI:9765
# 2839                      CHEMBL.COMPOUND:CHEMBL1229259
# 2840                      CHEMBL.COMPOUND:CHEMBL1809251
# 2841                      CHEMBL.COMPOUND:CHEMBL1809250
# 2842                                      name:APC-3316
# 2843                           name:FIBRINOLYSIN, HUMAN
# 2844                                     name:APROTININ
# 2845                            name:NEOANDROGRAPHOLIDE
# 2846                                 name:PIVAMPICILLIN
# 2847                                       name:FUT 175
# 2848                                       name:FUT 175
# 2849                               name:(+)-TETRANDRINE
# 2850                                 name:FANGCHINOLINE
# 2851                                    name:HETACILLIN
# 2852                                    name:BROMHEXINE
# 2853                                      name:CYSTEINE
# 2854                                     name:LEUPEPTIN
# 2855                              name:ARGININE RESIDUE
# 2856  name:4-(2-OXO-1-PYRROLIDINYL)BENZOIC ACID [2-(...
# 2857  name:N-[(5S,6S,9S)-8-(CYCLOPROPYLMETHYL)-5-MET...
# 2858                        name:5' UNTRANSLATED REGION
# 2859                                       name:EB 1089

# %%
## Coronavirus genes
corona = ht.query("CORONAVINAE INFECTIOUS DISEASE")['Disease'][0]
corona
# Out:
# {'MONDO': 'MONDO:0005719',
#  'name': 'Coronavinae infectious disease',
#  'MESH': 'D018352',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0005719'},
#  'display': 'MONDO(MONDO:0005719) MESH(D018352) name(Coronavinae infectious disease)',
#  'type': 'Disease'}

# %%
corona_gene_drug = predict_many(corona, ['Gene'], 'ChemicalSubstance')
corona_genes_names = list(corona_gene_drug ["node1_name"])
corona_genes_names = list(dict.fromkeys(corona_genes_names))
print("IDENTIFIED GENES")
print(corona_genes_names)
corona_protease_related_genes_identified = []
for gene_name in corona_genes_names :
    current_query = ht.query(gene_name)
    if(len(current_query['Gene']) > 0):
#         print(current_query['Gene'][0])
        if(('PROTEASE' in current_query['Gene'][0]['name']) or ('protease' in current_query['Gene'][0]['name'])):
            print(gene_name)
            corona_protease_related_genes_identified.append(gene_name)
# Out:
# Intermediate Node type running:
# Gene
# IDENTIFIED GENES
# ['ISG15', 'USP14', 'SH2D3A', 'IRF3', 'GLI2', 'IFNB1', 'IFNA2', 'CXCL10', 'DEFB4A', 'RNASEL', 'C5AR1', 'PLP2', 'ACE2', 'DPP4', 'ADA', 'TMPRSS2', 'FURIN', 'CD9', 'SKP2', 'CD151', 'SARS2', 'IL32', 'UPF1', 'ABL2', 'CTSL', 'ABL1', 'SHH', 'SPECC1', 'PPP1CA', 'MYOM2', 'SH2D3C', 'HFM1', 'LGALSL', 'PRSS2', 'TMPRSS4', 'TPCN2', 'IRAK3', 'PEPD', 'CEACAM5', 'KRT18', 'PRDX3', 'TPCN1', 'PCP2', 'IGHV1-69', 'KPNA4']
# TMPRSS2
# PRSS2
# TMPRSS4

# %%
covid_gene_drug[covid_gene_drug["node1_name"].isin(corona_protease_related_genes_identified)]
# Out:
#          input input_type       pred1 pred1_source  \
# 17    COVID-19    Disease  related_to     scigraph
# 33    COVID-19    Disease  related_to     scigraph
# 38    COVID-19    Disease  related_to     scigraph
# 45    COVID-19    Disease  related_to     scigraph
# 61    COVID-19    Disease  related_to     scigraph
# 75    COVID-19    Disease  related_to     scigraph
# 84    COVID-19    Disease  related_to     scigraph
# 340   COVID-19    Disease  related_to     scigraph
# 345   COVID-19    Disease  related_to     scigraph
# 361   COVID-19    Disease  related_to     scigraph
# 362   COVID-19    Disease  related_to     scigraph
# 363   COVID-19    Disease  related_to     scigraph
# 376   COVID-19    Disease  related_to     scigraph
# 954   COVID-19    Disease  related_to     scigraph
# 1001  COVID-19    Disease  related_to     scigraph
# 1504  COVID-19    Disease  related_to     scigraph
# 1946  COVID-19    Disease  related_to     scigraph
# 1957  COVID-19    Disease  related_to     scigraph
# 1958  COVID-19    Disease  related_to     scigraph
# 2423  COVID-19    Disease  related_to     scigraph
# 2833  COVID-19    Disease  related_to     scigraph
# 2834  COVID-19    Disease  related_to     scigraph
# 2835  COVID-19    Disease  related_to     scigraph
# 2836  COVID-19    Disease  related_to     scigraph
# 2837  COVID-19    Disease  related_to     scigraph
# 2838  COVID-19    Disease  related_to     scigraph
# 2839  COVID-19    Disease  related_to     scigraph
# 2840  COVID-19    Disease  related_to     scigraph
# 2841  COVID-19    Disease  related_to     scigraph
# 2842  COVID-19    Disease  related_to     scigraph
# 2843  COVID-19    Disease  related_to     scigraph
# 2844  COVID-19    Disease  related_to     scigraph
# 2845  COVID-19    Disease  related_to     scigraph
# 2846  COVID-19    Disease  related_to     scigraph
# 2847  COVID-19    Disease  related_to     scigraph
# 2848  COVID-19    Disease  related_to     scigraph
# 2849  COVID-19    Disease  related_to     scigraph
# 2850  COVID-19    Disease  related_to     scigraph
# 2851  COVID-19    Disease  related_to     scigraph
# 2852  COVID-19    Disease  related_to     scigraph
# 2853  COVID-19    Disease  related_to     scigraph
# 2854  COVID-19    Disease  related_to     scigraph
# 2855  COVID-19    Disease  related_to     scigraph
# 2856  COVID-19    Disease  related_to     scigraph
# 2857  COVID-19    Disease  related_to     scigraph
# 2858  COVID-19    Disease  related_to     scigraph
# 2859  COVID-19    Disease  related_to     scigraph
#
#                         pred1_api pred1_pubmed node1_type node1_name  \
# 17    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 33    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 38    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 45    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 61    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 75    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 84    Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 340   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 345   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 361   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 362   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 363   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 376   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 954   Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1001  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1504  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1946  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1957  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 1958  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2423  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2833  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2834  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2835  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2836  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2837  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2838  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2839  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2840  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2841  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2842  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2843  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2844  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2845  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2846  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2847  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2848  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2849  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2850  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2851  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2852  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2853  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2854  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2855  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2856  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2857  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2858  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
# 2859  Automat CORD19 Scigraph API         None       Gene    TMPRSS2
#
#            node1_id                      pred2  \
# 17    NCBIGene:7113                 related_to
# 33    NCBIGene:7113                 related_to
# 38    NCBIGene:7113                 related_to
# 45    NCBIGene:7113                 related_to
# 61    NCBIGene:7113                 related_to
# 75    NCBIGene:7113                 related_to
# 84    NCBIGene:7113                 related_to
# 340   NCBIGene:7113                 related_to
# 345   NCBIGene:7113                 related_to
# 361   NCBIGene:7113                 related_to
# 362   NCBIGene:7113                 related_to
# 363   NCBIGene:7113  physically_interacts_with
# 376   NCBIGene:7113                 related_to
# 954   NCBIGene:7113                 related_to
# 1001  NCBIGene:7113                 related_to
# 1504  NCBIGene:7113                 related_to
# 1946  NCBIGene:7113       negatively_regulates
# 1957  NCBIGene:7113  physically_interacts_with
# 1958  NCBIGene:7113       positively_regulates
# 2423  NCBIGene:7113                 related_to
# 2833  NCBIGene:7113                 related_to
# 2834  NCBIGene:7113                 related_to
# 2835  NCBIGene:7113                 related_to
# 2836  NCBIGene:7113                 related_to
# 2837  NCBIGene:7113                 related_to
# 2838  NCBIGene:7113                 related_to
# 2839  NCBIGene:7113                 related_to
# 2840  NCBIGene:7113                 related_to
# 2841  NCBIGene:7113                 related_to
# 2842  NCBIGene:7113                 related_to
# 2843  NCBIGene:7113                 related_to
# 2844  NCBIGene:7113                 related_to
# 2845  NCBIGene:7113                 related_to
# 2846  NCBIGene:7113                 related_to
# 2847  NCBIGene:7113                 related_to
# 2848  NCBIGene:7113                 related_to
# 2849  NCBIGene:7113                 related_to
# 2850  NCBIGene:7113                 related_to
# 2851  NCBIGene:7113                 related_to
# 2852  NCBIGene:7113                 related_to
# 2853  NCBIGene:7113                 related_to
# 2854  NCBIGene:7113                 related_to
# 2855  NCBIGene:7113                 related_to
# 2856  NCBIGene:7113                 related_to
# 2857  NCBIGene:7113                 related_to
# 2858  NCBIGene:7113  physically_interacts_with
# 2859  NCBIGene:7113       positively_regulates
#
#                          pred2_source                    pred2_api  \
# 17                           scigraph  Automat CORD19 Scigraph API
# 33                           scigraph  Automat CORD19 Scigraph API
# 38                           scigraph  Automat CORD19 Scigraph API
# 45                           scigraph  Automat CORD19 Scigraph API
# 61                           scigraph  Automat CORD19 Scigraph API
# 75                           scigraph  Automat CORD19 Scigraph API
# 84                           scigraph  Automat CORD19 Scigraph API
# 340                          scigraph  Automat CORD19 Scigraph API
# 345                          scigraph  Automat CORD19 Scigraph API
# 361                           scibite   Automat CORD19 Scibite API
# 362                          scigraph  Automat CORD19 Scigraph API
# 363                          drugbank              MyChem.info API
# 376                          scigraph  Automat CORD19 Scigraph API
# 954                           chembio          Automat CHEMBIO API
# 1001  Translator Text Mining Provider                CORD Gene API
# 1504                          chembio          Automat CHEMBIO API
# 1946                           SEMMED              SEMMED Gene API
# 1957                           SEMMED              SEMMED Gene API
# 1958                           SEMMED              SEMMED Gene API
# 2423                         scigraph  Automat CORD19 Scigraph API
# 2833                          scibite   Automat CORD19 Scibite API
# 2834                          scibite   Automat CORD19 Scibite API
# 2835                          scibite   Automat CORD19 Scibite API
# 2836                         scigraph  Automat CORD19 Scigraph API
# 2837                         scigraph  Automat CORD19 Scigraph API
# 2838                         scigraph  Automat CORD19 Scigraph API
# 2839                           pharos           Automat PHAROS API
# 2840                           pharos           Automat PHAROS API
# 2841                           pharos           Automat PHAROS API
# 2842                          scibite   Automat CORD19 Scibite API
# 2843                          scibite   Automat CORD19 Scibite API
# 2844                          scibite   Automat CORD19 Scibite API
# 2845                          scibite   Automat CORD19 Scibite API
# 2846                          scibite   Automat CORD19 Scibite API
# 2847                          scibite   Automat CORD19 Scibite API
# 2848                         scigraph  Automat CORD19 Scigraph API
# 2849                          scibite   Automat CORD19 Scibite API
# 2850                          scibite   Automat CORD19 Scibite API
# 2851                          scibite   Automat CORD19 Scibite API
# 2852                          scibite   Automat CORD19 Scibite API
# 2853                         scigraph  Automat CORD19 Scigraph API
# 2854                         scigraph  Automat CORD19 Scigraph API
# 2855                         scigraph  Automat CORD19 Scigraph API
# 2856                          chembio          Automat CHEMBIO API
# 2857                          chembio          Automat CHEMBIO API
# 2858                           SEMMED              SEMMED Gene API
# 2859                           SEMMED              SEMMED Gene API
#
#                              pred2_pubmed        output_type  \
# 17                                   None  ChemicalSubstance
# 33                                   None  ChemicalSubstance
# 38                                   None  ChemicalSubstance
# 45                                   None  ChemicalSubstance
# 61                                   None  ChemicalSubstance
# 75                                   None  ChemicalSubstance
# 84                                   None  ChemicalSubstance
# 340                                  None  ChemicalSubstance
# 345                                  None  ChemicalSubstance
# 361                                  None  ChemicalSubstance
# 362                                  None  ChemicalSubstance
# 363                                  None  ChemicalSubstance
# 376                                  None  ChemicalSubstance
# 954                                  None  ChemicalSubstance
# 1001                                 None  ChemicalSubstance
# 1504                                 None  ChemicalSubstance
# 1946                             26026052  ChemicalSubstance
# 1957  21796535,24109594,24727384,25170998  ChemicalSubstance
# 1958                             11322890  ChemicalSubstance
# 2423                                 None  ChemicalSubstance
# 2833                                 None  ChemicalSubstance
# 2834                                 None  ChemicalSubstance
# 2835                                 None  ChemicalSubstance
# 2836                                 None  ChemicalSubstance
# 2837                                 None  ChemicalSubstance
# 2838                                 None  ChemicalSubstance
# 2839                                 None  ChemicalSubstance
# 2840                                 None  ChemicalSubstance
# 2841                                 None  ChemicalSubstance
# 2842                                 None  ChemicalSubstance
# 2843                                 None  ChemicalSubstance
# 2844                                 None  ChemicalSubstance
# 2845                                 None  ChemicalSubstance
# 2846                                 None  ChemicalSubstance
# 2847                                 None  ChemicalSubstance
# 2848                                 None  ChemicalSubstance
# 2849                                 None  ChemicalSubstance
# 2850                                 None  ChemicalSubstance
# 2851                                 None  ChemicalSubstance
# 2852                                 None  ChemicalSubstance
# 2853                                 None  ChemicalSubstance
# 2854                                 None  ChemicalSubstance
# 2855                                 None  ChemicalSubstance
# 2856                                 None  ChemicalSubstance
# 2857                                 None  ChemicalSubstance
# 2858                             23472063  ChemicalSubstance
# 2859                             20147525  ChemicalSubstance
#
#                                             output_name  \
# 17                                          CHEBI:26667
# 33                                          CHEBI:36080
# 38                                          CHEBI:22587
# 45                                          CHEBI:35222
# 61                                          CHEBI:17089
# 75                                          CHEBI:33709
# 84                                          CHEBI:37670
# 340                                             AREQUIN
# 345                                            L-SERINE
# 361                                            CAMOSTAT
# 362                                            CAMOSTAT
# 363                                            CAMOSTAT
# 376                                             PEPTIDE
# 954                                     ISOCHAMAEJASMIN
# 1001                                        CHEBI:50113
# 1504                                  PSI-RHODOMYRTOXIN
# 1946                             INTERFERING RNA, SMALL
# 1957                                          ANDROGENS
# 1958                                          ANDROGENS
# 2423                                           ARGININE
# 2833                                       CHEMBL423112
# 2834                                       CHEMBL129157
# 2835                                      CHEMBL2110589
# 2836                                        CHEBI:64152
# 2837                                        CHEBI:64926
# 2838                                         CHEBI:9765
# 2839                                      CHEMBL1229259
# 2840                                      CHEMBL1809251
# 2841                                      CHEMBL1809250
# 2842                                           APC-3316
# 2843                                FIBRINOLYSIN, HUMAN
# 2844                                          APROTININ
# 2845                                 NEOANDROGRAPHOLIDE
# 2846                                      PIVAMPICILLIN
# 2847                                            FUT 175
# 2848                                            FUT 175
# 2849                                    (+)-TETRANDRINE
# 2850                                      FANGCHINOLINE
# 2851                                         HETACILLIN
# 2852                                         BROMHEXINE
# 2853                                           CYSTEINE
# 2854                                          LEUPEPTIN
# 2855                                   ARGININE RESIDUE
# 2856  4-(2-OXO-1-PYRROLIDINYL)BENZOIC ACID [2-(2-FUR...
# 2857  N-[(5S,6S,9S)-8-(CYCLOPROPYLMETHYL)-5-METHOXY-...
# 2858                             5' UNTRANSLATED REGION
# 2859                                            EB 1089
#
#                                               output_id
# 17                                    CHEBI:CHEBI:26667
# 33                                    CHEBI:CHEBI:36080
# 38                                    CHEBI:CHEBI:22587
# 45                                    CHEBI:CHEBI:35222
# 61                                    CHEBI:CHEBI:17089
# 75                                    CHEBI:CHEBI:33709
# 84                                    CHEBI:CHEBI:37670
# 340                                        name:AREQUIN
# 345                                       name:L-SERINE
# 361                                       name:CAMOSTAT
# 362                                       name:CAMOSTAT
# 363                                       name:CAMOSTAT
# 376                                        name:PEPTIDE
# 954                                name:ISOCHAMAEJASMIN
# 1001                                  CHEBI:CHEBI:50113
# 1504                             name:PSI-RHODOMYRTOXIN
# 1946                        name:INTERFERING RNA, SMALL
# 1957                                     name:ANDROGENS
# 1958                                     name:ANDROGENS
# 2423                                      name:ARGININE
# 2833                       CHEMBL.COMPOUND:CHEMBL423112
# 2834                       CHEMBL.COMPOUND:CHEMBL129157
# 2835                      CHEMBL.COMPOUND:CHEMBL2110589
# 2836                                  CHEBI:CHEBI:64152
# 2837                                  CHEBI:CHEBI:64926
# 2838                                   CHEBI:CHEBI:9765
# 2839                      CHEMBL.COMPOUND:CHEMBL1229259
# 2840                      CHEMBL.COMPOUND:CHEMBL1809251
# 2841                      CHEMBL.COMPOUND:CHEMBL1809250
# 2842                                      name:APC-3316
# 2843                           name:FIBRINOLYSIN, HUMAN
# 2844                                     name:APROTININ
# 2845                            name:NEOANDROGRAPHOLIDE
# 2846                                 name:PIVAMPICILLIN
# 2847                                       name:FUT 175
# 2848                                       name:FUT 175
# 2849                               name:(+)-TETRANDRINE
# 2850                                 name:FANGCHINOLINE
# 2851                                    name:HETACILLIN
# 2852                                    name:BROMHEXINE
# 2853                                      name:CYSTEINE
# 2854                                     name:LEUPEPTIN
# 2855                              name:ARGININE RESIDUE
# 2856  name:4-(2-OXO-1-PYRROLIDINYL)BENZOIC ACID [2-(...
# 2857  name:N-[(5S,6S,9S)-8-(CYCLOPROPYLMETHYL)-5-MET...
# 2858                        name:5' UNTRANSLATED REGION
# 2859                                       name:EB 1089

# %%
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'camostat' and 'Gene'.                   Paths will have 1 intermediate node.
#
# Intermediate node #1 will have these type constraints: None
#
#
#
# ========== QUERY #1 -- fetch all None entities linked to camostat ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because camostat is of type 'ChemicalSubstance', BTE will query our meta-KG for APIs that can take 'ChemicalSubstance' as input and 'None' as output
# We are sorry! We couln't find any APIs which can do the type of query for you!
#
# ==========
# ========== Final assembly of results ==========
# ==========

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 4 PROTEASE_ACTIVITY -> Genes -> ChemicalSubstances

# %%
serine_protease_activity = ht.query("protease")['BiologicalProcess'][0]
serine_protease_activity

serine_protease_activity_to_genes_to_drugs = predict_many(serine_protease_activity,['Gene'],'ChemicalSubstance')
# Out:
# Intermediate Node type running:
# Gene

# %%
serine_protease_activity_to_genes_to_drugs
# corona_gene_drug = predict_many(corona, ['Gene'], 'ChemicalSubstance')
SP_genes_names = list(serine_protease_activity_to_genes_to_drugs["node1_name"])
SP_genes_names = list(dict.fromkeys(SP_genes_names))
SP_genes_names
# len(serine_protease_activity_to_genes_to_drugs["node1_name"])
print("IDENTIFIED GENES")
print(SP_genes_names)
sp_protease_related_genes_identified = []
for gene_name in SP_genes_names :
    current_query = ht.query(gene_name)
    if(len(current_query['Gene']) > 0):
        print(current_query['Gene'][0])
        if(('PROTEASE' in current_query['Gene'][0]['name']) or ('protease' in current_query['Gene'][0]['name'])):
            print(gene_name)
            sp_protease_related_genes_identified.append(gene_name)
# Out:
# IDENTIFIED GENES
# ['C3541331', 'ERCC8', 'CSH1', 'ADRA1D', 'DPP4', 'HSPA9', 'MAS1', 'KLK3', 'HTRA1', 'C2987243', 'C3889133']
# {'NCBIGene': '1161', 'name': 'ERCC excision repair 8, CSA ubiquitin ligase complex subunit', 'SYMBOL': 'ERCC8', 'UMLS': 'C1414440', 'HGNC': '3439', 'UNIPROTKB': 'Q13216', 'ENSEMBL': 'ENSG00000049167', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1161'}, 'display': 'NCBIGene(1161) ENSEMBL(ENSG00000049167) HGNC(3439) UMLS(C1414440) UNIPROTKB(Q13216) SYMBOL(ERCC8)', 'type': 'Gene'}
# {'NCBIGene': '1442', 'name': 'chorionic somatomammotropin hormone 1', 'SYMBOL': 'CSH1', 'UMLS': 'C1413752', 'HGNC': '2440', 'UNIPROTKB': 'P0DML2', 'ENSEMBL': 'ENSG00000136488', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1442'}, 'display': 'NCBIGene(1442) ENSEMBL(ENSG00000136488) HGNC(2440) UMLS(C1413752) UNIPROTKB(P0DML2) SYMBOL(CSH1)', 'type': 'Gene'}
# {'NCBIGene': '146', 'name': 'adrenoceptor alpha 1D', 'SYMBOL': 'ADRA1D', 'UMLS': 'C1412260', 'HGNC': '280', 'UNIPROTKB': 'P25100', 'ENSEMBL': 'ENSG00000171873', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '146'}, 'display': 'NCBIGene(146) ENSEMBL(ENSG00000171873) HGNC(280) UMLS(C1412260) UNIPROTKB(P25100) SYMBOL(ADRA1D)', 'type': 'Gene'}
# {'NCBIGene': '1803', 'name': 'dipeptidyl peptidase 4', 'SYMBOL': 'DPP4', 'UMLS': 'C1414141', 'HGNC': '3009', 'UNIPROTKB': 'P27487', 'ENSEMBL': 'ENSG00000197635', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '1803'}, 'display': 'NCBIGene(1803) ENSEMBL(ENSG00000197635) HGNC(3009) UMLS(C1414141) UNIPROTKB(P27487) SYMBOL(DPP4)', 'type': 'Gene'}
# {'NCBIGene': '3313', 'name': 'heat shock protein family A (Hsp70) member 9', 'SYMBOL': 'HSPA9', 'UMLS': 'C1825549', 'HGNC': '5244', 'UNIPROTKB': 'P38646', 'ENSEMBL': 'ENSG00000113013', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '3313'}, 'display': 'NCBIGene(3313) ENSEMBL(ENSG00000113013) HGNC(5244) UMLS(C1825549) UNIPROTKB(P38646) SYMBOL(HSPA9)', 'type': 'Gene'}
# {'NCBIGene': '4142', 'name': 'MAS1 proto-oncogene, G protein-coupled receptor', 'SYMBOL': 'MAS1', 'UMLS': 'C0812372', 'HGNC': '6899', 'UNIPROTKB': 'P04201', 'ENSEMBL': 'ENSG00000130368', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '4142'}, 'display': 'NCBIGene(4142) ENSEMBL(ENSG00000130368) HGNC(6899) UMLS(C0812372) UNIPROTKB(P04201) SYMBOL(MAS1)', 'type': 'Gene'}
# {'NCBIGene': '354', 'name': 'kallikrein related peptidase 3', 'SYMBOL': 'KLK3', 'UMLS': 'C1366489', 'HGNC': '6364', 'UNIPROTKB': 'P07288', 'ENSEMBL': 'ENSG00000142515', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '354'}, 'display': 'NCBIGene(354) ENSEMBL(ENSG00000142515) HGNC(6364) UMLS(C1366489) UNIPROTKB(P07288) SYMBOL(KLK3)', 'type': 'Gene'}
# {'NCBIGene': '5654', 'name': 'HtrA serine peptidase 1', 'SYMBOL': 'HTRA1', 'UMLS': 'C1825552', 'HGNC': '9476', 'UNIPROTKB': 'Q92743', 'ENSEMBL': 'ENSG00000166033', 'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '5654'}, 'display': 'NCBIGene(5654) ENSEMBL(ENSG00000166033) HGNC(9476) UMLS(C1825552) UNIPROTKB(Q92743) SYMBOL(HTRA1)', 'type': 'Gene'}

# %%
# Out:
# [{'name': 'Lower lung field',
#   'UMLS': 'C0934576',
#   'primary': {'identifier': 'UMLS',
#    'cls': 'AnatomicalEntity',
#    'value': 'C0934576'},
#   'display': 'UMLS(C0934576) name(Lower lung field)',
#   'type': 'AnatomicalEntity'},
#  {'name': 'Middle lung field',
#   'UMLS': 'C0929434',
#   'primary': {'identifier': 'UMLS',
#    'cls': 'AnatomicalEntity',
#    'value': 'C0929434'},
#   'display': 'UMLS(C0929434) name(Middle lung field)',
#   'type': 'AnatomicalEntity'},
#  {'name': 'Lung field',
#   'UMLS': 'C0225759',
#   'primary': {'identifier': 'UMLS',
#    'cls': 'AnatomicalEntity',
#    'value': 'C0225759'},
#   'display': 'UMLS(C0225759) name(Lung field)',
#   'type': 'AnatomicalEntity'},
#  {'name': 'Lung surface',
#   'UMLS': 'C0736258',
#   'primary': {'identifier': 'UMLS',
#    'cls': 'AnatomicalEntity',
#    'value': 'C0736258'},
#   'display': 'UMLS(C0736258) name(Lung surface)',
#   'type': 'AnatomicalEntity'},
#  {'name': 'Extravascular Lung Water',
#   'UMLS': 'C0015380',
#   'primary': {'identifier': 'UMLS',
#    'cls': 'AnatomicalEntity',
#    'value': 'C0015380'},
#   'display': 'UMLS(C0015380) name(Extravascular Lung Water)',
#   'type': 'AnatomicalEntity'}]
