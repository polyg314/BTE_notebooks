# %% [markdown]
# # TABLE OF CONTENTS
#
# ## 1 USE CASE: COVID-19
# ###  &emsp; 1.1 What genes are connected to COVID-19?
# ####  &emsp; &emsp; 1.1.1 COVID-19 -> Genes (determine directly related)
# ####  &emsp; &emsp; 1.1.2 COVID-19 -> All intermediate node types -> Genes
# ###  &emsp; 1.2 What are the symptoms that are related to COVID-19?
# ####  &emsp; &emsp; 1.2.1 COVID-19 -> Symptoms (PhenotypicFeature, BiologicalProcess)
# ###  &emsp; 1.3 Which of the genes related to COVID-19 are related to symptoms of COVID-19?
# ####  &emsp; &emsp; 1.3.1 Genes (from 1.1) -> Symptoms (From 1.2.1)
# ####  &emsp; &emsp; 1.3.2 Genes (from 1.1) -> [Drugs, SequenceVariant, Pathways, MolecularActivity] -> Symptoms (From 1.2.1)
# ###  &emsp; 1.4 What proteins/genes are in pathways of known COVID-19 related genes? Which of these can be related to symptoms?
# ####  &emsp; &emsp; 1.4.1 Genes (from 1.1.1) -> Pathways -> Genes
# ####  &emsp; &emsp; 1.4.2 COVID-19 Symptoms -> Pathways -> Genes
# ###  &emsp; 1.5 In what way can co-occurrence data from COHD EHR data (conditions, drugs, and procedures) be used to further identify or establish genes associated with COVID-19?
# ####  &emsp; &emsp; 1.5.1 Co-occurence of related conditions (parent diseases, siblings) and drugs
# ####  &emsp; &emsp; 1.5.2 Co-occurrence of related drugs and related symptoms

# %%
###### CODE SETUP 

## First get all the functions set up
import pandas as pd
import requests
import difflib
import math

# import itables.interactive
# from itables import show
# import itables.options as opt
# opt.maxBytes = 10000000


## Load BTE
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

## Functions that will be used
# Check for every intermediate node type in Predict funciton
def predict_many(input_object, intermediate_node_list, output_type):
    df_list = []
    for inter in intermediate_node_list:
        try: 
            print("Intermediate Node type running:")
            print(inter)
            fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
            fc.connect(verbose=False)
            df = fc.display_table_view()
            rows = df.shape[0]
            if(rows > 0):
                df_list.append(df)
        except:
            print("FAILED")
    if(len(df_list) > 0):
        return pd.concat(df_list)
    else:
        return None
    
# all intermediate node types

node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                   'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                   'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %% [markdown]
# ## 1.1 What genes are connected to COVID-19?

# %% [markdown]
# ### 1.1.1 COVID-19 -> Genes (determine directly related)

# %%
## get COVID-19
covid19 = ht.query("COVID-19")['Disease'][0]
covid19
# Out:
# {'MONDO': 'MONDO:0100096',
#  'DOID': 'DOID:0080600',
#  'name': 'COVID-19',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0100096'},
#  'display': 'MONDO(MONDO:0100096) DOID(DOID:0080600) name(COVID-19)',
#  'type': 'Disease'}

# %%
fc = FindConnection(input_obj=covid19, output_obj='Gene', intermediate_nodes=None)
fc.connect(verbose=True)
covid19_to_genes = fc.display_table_view()
covid19_to_genes
# Out:
# ==========
# ========== QUERY PARAMETER SUMMARY ==========
# ==========
#
# BTE will find paths that join 'COVID-19' and 'Gene'.                   Paths will have 0 intermediate node.
#
#
#
# ========== QUERY #1 -- fetch all Gene entities linked to COVID-19 ==========
# ==========
#
# ==== Step #1: Query path planning ====
#
# Because COVID-19 is of type 'Disease', BTE will query our meta-KG for APIs that can take 'Disease' as input and 'Gene' as output
#
# BTE found 8 apis:
#
# API 1. mgi_gene2phenotype(1 API call)
# API 2. hetio(1 API call)
# API 3. pharos(1 API call)
# API 4. scibite(1 API call)
# API 5. cord_disease(1 API call)
# API 6. biolink(1 API call)
# API 7. DISEASES(1 API call)
# API 8. scigraph(1 API call)
#
#
# ==== Step #2: Query path execution ====
# NOTE: API requests are dispatched in parallel, so the list of APIs below is ordered by query time.
#
# API 5.1: https://biothings.ncats.io/cord_disease/query?fields=associated_with (POST -d q=DOID:0080600&scopes=doid)
# API 6.1: https://api.monarchinitiative.org/api/bioentity/disease/MONDO:0100096/genes?rows=200
# API 1.1: https://pending.biothings.io/mgigene2phenotype/query?fields=_id&size=300 (POST -d q=DOID:0080600&scopes=mgi.associated_with_disease.doid)
# API 7.1: https://pending.biothings.io/DISEASES/query?fields=DISEASES.associatedWith (POST -d q=DOID:0080600&scopes=DISEASES.doid)
# API 3.1: https://automat.renci.org/pharos/disease/gene/MONDO:0100096
# API 8.1: https://automat.renci.org/cord19-scigraph/disease/gene/MONDO:0100096
# API 4.1: https://automat.renci.org/cord19-scibite/disease/gene/MONDO:0100096
# API 2.1: https://automat.renci.org/hetio/disease/gene/MONDO:0100096
#
#
# ==== Step #3: Output normalization ====
#
# API 1.1 mgi_gene2phenotype: No hits
# API 7.1 DISEASES: 2 hits
# API 8.1 scigraph: 7 hits
# API 3.1 pharos: No hits
# API 5.1 cord_disease: No hits
# API 4.1 scibite: No hits
# API 2.1 hetio: No hits
# API 6.1 biolink: No hits
#
# After id-to-object translation, BTE retrieved 8 unique objects.
#
# ==========
# ========== Final assembly of results ==========
# ==========
#
#
# In the #1 query, BTE found 8 unique Gene nodes
#       input input_type       pred1 pred1_source                    pred1_api  \
# 0  COVID-19    Disease  related_to      DISEASE                 DISEASES API
# 1  COVID-19    Disease  related_to      DISEASE                 DISEASES API
# 2  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 3  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 4  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 5  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 6  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 7  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 8  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
#
#   pred1_pubmed output_type output_name        output_id
# 0         None        Gene        EID2  NCBIGene:163126
# 1         None        Gene        ACE2   NCBIGene:59272
# 2         None        Gene        ACE2   NCBIGene:59272
# 3         None        Gene       MARS1    NCBIGene:4141
# 4         None        Gene         SON    NCBIGene:6651
# 5         None        Gene          TH    NCBIGene:7054
# 6         None        Gene     TMPRSS2    NCBIGene:7113
# 7         None        Gene         POR    NCBIGene:5447
# 8         None        Gene         CRP    NCBIGene:1401

# %%
i = list(covid19_to_genes["output_name"])
d = {x:i.count(x) for x in i}
sorted_genes_covid_2_genes = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
sorted_genes_covid_2_genes
# Out:
# {'EID2': 1,
#  'MARS1': 1,
#  'SON': 1,
#  'TH': 1,
#  'TMPRSS2': 1,
#  'POR': 1,
#  'CRP': 1,
#  'ACE2': 2}

# %% [markdown]
# ### 1.1.2 COVID-19 -> All intermediate node types -> Genes

# %%
covid_allNodes_Genes = predict_many(covid19,node_type_list,'Gene')
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# API 2.1 pharos failed
# Intermediate Node type running:
# Disease
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature

# %%
## Genes identified = HUGE NUMBER (13562)
len(list(covid_allNodes_Genes["output_name"]))
# Out:
# 14066

# %%
i = list(covid_allNodes_Genes["output_name"])
d = {x:i.count(x) for x in i}
sorted_genes_covid_2_allNodes_2_genes = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
for x in list(reversed(list(sorted_genes_covid_2_allNodes_2_genes)))[0:50]:
    print(str(x) + ": " + str(sorted_genes_covid_2_allNodes_2_genes[x]))
# Out:
# TNF: 44
# CYP3A4: 33
# CAT: 32
# INS: 27
# C0017337: 26
# C0014442: 26
# CYP2D6: 25
# AKT1: 25
# ANG: 24
# IL6: 23
# ABCB1: 22
# TP53: 19
# FOS: 18
# C1705556: 18
# MAPK1: 18
# ACE2: 18
# ACE: 18
# CYP1A2: 17
# C0010762: 17
# HIF1A: 17
# AR: 17
# SQSTM1: 17
# APP: 17
# TLR9: 16
# PPIG: 16
# ALB: 16
# CDKN1A: 16
# TH: 16
# C0164786: 16
# CD4: 16
# SOD1: 15
# VEGFA: 15
# CYP2C9: 15
# IL1B: 15
# BAX: 15
# LEP: 15
# C1705526: 15
# EGFR: 15
# IFNA1: 15
# RELA: 15
# CAMP: 15
# C0010531: 15
# C0030956: 15
# SOD2: 14
# EPO: 14
# MPO: 14
# MTOR: 14
# MAPK8: 14
# CA2: 14
# CASP3: 14

# %%
## store top 50 genes
top_50_related_genes_covid_2_allNodes_2_genes = list(reversed(list(sorted_genes_covid_2_allNodes_2_genes)))[0:50]
top_50_related_genes_covid_2_allNodes_2_genes = top_50_related_genes_covid_2_allNodes_2_genes + list(sorted_genes_covid_2_genes.keys())
top_50_related_genes_covid_2_allNodes_2_genes = list(dict.fromkeys(top_50_related_genes_covid_2_allNodes_2_genes))
top_50_related_genes_covid_2_allNodes_2_genes
# Out:
# ['TNF',
#  'CYP3A4',
#  'CAT',
#  'INS',
#  'C0017337',
#  'C0014442',
#  'CYP2D6',
#  'AKT1',
#  'ANG',
#  'IL6',
#  'ABCB1',
#  'TP53',
#  'FOS',
#  'C1705556',
#  'MAPK1',
#  'ACE2',
#  'ACE',
#  'CYP1A2',
#  'C0010762',
#  'HIF1A',
#  'AR',
#  'SQSTM1',
#  'APP',
#  'TLR9',
#  'PPIG',
#  'ALB',
#  'CDKN1A',
#  'TH',
#  'C0164786',
#  'CD4',
#  'SOD1',
#  'VEGFA',
#  'CYP2C9',
#  'IL1B',
#  'BAX',
#  'LEP',
#  'C1705526',
#  'EGFR',
#  'IFNA1',
#  'RELA',
#  'CAMP',
#  'C0010531',
#  'C0030956',
#  'SOD2',
#  'EPO',
#  'MPO',
#  'MTOR',
#  'MAPK8',
#  'CA2',
#  'CASP3',
#  'EID2',
#  'MARS1',
#  'SON',
#  'TMPRSS2',
#  'POR',
#  'CRP']

# %%
top_genes_pub_counts = {}
for index, row in covid_allNodes_Genes.iterrows():
    if row["output_name"] in top_50_related_genes_covid_2_allNodes_2_genes:
        current_pubcount = 0
        if(row["pred1_pubmed"] != None):
            current_pubcount = current_pubcount + row["pred1_pubmed"].count(",") + 1
        if(row["pred2_pubmed"] != None):
            current_pubcount = current_pubcount + row["pred2_pubmed"].count(",") + 1
        if row["output_name"] in top_genes_pub_counts:
            top_genes_pub_counts[row["output_name"]] = top_genes_pub_counts[row["output_name"]] + current_pubcount
        else: 
            top_genes_pub_counts[row["output_name"]] = current_pubcount

top_genes_pub_counts
# for x in top_50_related_genes_covid_2_allNodes_2_genes:
# Out:
# {'C0014442': 331,
#  'C0017337': 196,
#  'C0030956': 38,
#  'C0010531': 66,
#  'ACE': 32,
#  'ANG': 78,
#  'ACE2': 24,
#  'APP': 21,
#  'CAMP': 71,
#  'MAPK1': 40,
#  'RELA': 32,
#  'CAT': 98,
#  'TMPRSS2': 3,
#  'INS': 53,
#  'C1705556': 146,
#  'MARS1': 5,
#  'AKT1': 51,
#  'IFNA1': 15,
#  'TNF': 114,
#  'CD4': 10,
#  'EGFR': 8,
#  'CASP3': 75,
#  'C0164786': 27,
#  'C1705526': 31,
#  'CYP2D6': 18,
#  'FOS': 34,
#  'TH': 541,
#  'SQSTM1': 45,
#  'CDKN1A': 29,
#  'ALB': 9,
#  'AR': 11,
#  'LEP': 20,
#  'CA2': 80,
#  'MAPK8': 24,
#  'MTOR': 21,
#  'TP53': 42,
#  'MPO': 33,
#  'BAX': 30,
#  'PPIG': 45,
#  'EPO': 26,
#  'HIF1A': 205,
#  'POR': 15,
#  'IL1B': 39,
#  'IL6': 58,
#  'TLR9': 15,
#  'C0010762': 80,
#  'CYP1A2': 25,
#  'CYP3A4': 69,
#  'CYP2C9': 11,
#  'ABCB1': 25,
#  'VEGFA': 150,
#  'CRP': 0,
#  'SOD1': 26,
#  'SON': 2,
#  'SOD2': 40}

# %% [markdown]
# ## 1.2 What are the symptoms that are related to COVID-19?

# %% [markdown]
# ### COVID-19 -> PhenotypicFeature

# %%
fc = FindConnection(input_obj=covid19, output_obj='PhenotypicFeature', intermediate_nodes=None)
fc.connect(verbose=False)
covid19_2_phentoypic_feature = fc.display_table_view()
covid19_2_phentoypic_feature

## no results
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
## try more broad "corona" look at coronaviruses in general 
corona = ht.query("CORONAVINAE INFECTIOUS DISEASE")['Disease'][0]
corona
# Out:
# {'MONDO': 'MONDO:0005719',
#  'name': 'Coronavinae infectious disease',
#  'MESH': 'D018352',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0005719'},
#  'display': 'MONDO(MONDO:0005719) MESH(D018352) name(Coronavinae infectious disease)',
#  'type': 'Disease'}

# %%
fc = FindConnection(input_obj=corona, output_obj='PhenotypicFeature', intermediate_nodes=None)
fc.connect(verbose=False)
covid19_2_phentoypic_feature = fc.display_table_view()
covid19_2_phentoypic_feature

## no results
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### COVID-19 -> BiologicalProcess

# %%
fc = FindConnection(input_obj=covid19, output_obj='BiologicalProcess', intermediate_nodes=None)
fc.connect(verbose=False)
covid19_2_biologicalProcess = fc.display_table_view()
covid19_2_biologicalProcess
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# try broader corona family again 
fc = FindConnection(input_obj=corona, output_obj='BiologicalProcess', intermediate_nodes=None)
fc.connect(verbose=False)
covid19_2_biologicalProcess = fc.display_table_view()
covid19_2_biologicalProcess
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Determine symptoms from: http://www.diseasesdatabase.com/relationships.asp?glngUserChoice=60833&bytRel=2&blnBW=0&strBB=LR&blnClassSort=255&Key={A27BEC6F-30C5-4893-BB0F-9FEB5589DEB3}

# %%
# Symptoms and signs:
    
# Cough
#    Coughing
# Diarrhoea
#     Loose stools
#     Diarrhea
# Myalgia
#     Myodynia
#     Muscle pain
# Pyrexia
#     Body temperature increased
#     Febrile
#     Fever
#     Hyperthermia
# Taste disturbance
#     Ageusia
#     Dysgeusia
#     Hypogeusia
#     Parageusia


# Haematological abnormalities:
# Lymphocytopenia
#     Lymphopenia
#     Lymphocyte count low (peripheral blood)

# Biochemical abnormalities:
# Lactate dehydrogenase levels raised (plasma or serum)
#     LDH raised

# Cardiac and vascular conditions:
# Myocarditis

# Inflammatory conditions:
# Pneumonia
#     Pneumonitis
#     Pulmonary inflammation


symptom_and_phenotype_list = ['Cough','Coughing','Diarrhoea','Loose stools','Diarrhea','Myalgia','Myodynia',
                              'Muscle pain','Pyrexia','Body temperature increased','Febrile','Fever','Hyperthermia',
                              'Taste disturbance','Ageusia','Dysgeusia','Hypogeusia','Parageusia','Lymphocytopenia',
                              'Lymphopenia','Lymphocyte count low (peripheral blood)',
                              'Lactate dehydrogenase levels raised (plasma or serum)','LDH raised','Myocarditis',
                              'Pneumonia','Pneumonitis','Pulmonary inflammation']



symptom_and_phenotype_list = [x.lower() for x in symptom_and_phenotype_list]
symptom_and_phenotype_list
# symptom_and_phenotype_list
# Out:
# ['cough',
#  'coughing',
#  'diarrhoea',
#  'loose stools',
#  'diarrhea',
#  'myalgia',
#  'myodynia',
#  'muscle pain',
#  'pyrexia',
#  'body temperature increased',
#  'febrile',
#  'fever',
#  'hyperthermia',
#  'taste disturbance',
#  'ageusia',
#  'dysgeusia',
#  'hypogeusia',
#  'parageusia',
#  'lymphocytopenia',
#  'lymphopenia',
#  'lymphocyte count low (peripheral blood)',
#  'lactate dehydrogenase levels raised (plasma or serum)',
#  'ldh raised',
#  'myocarditis',
#  'pneumonia',
#  'pneumonitis',
#  'pulmonary inflammation']

# %% [markdown]
# ## 1.2.3 Determine Symptoms thru HPO API:
# https://hpo.jax.org/webjars/swagger-ui/3.20.9/index.html?url=/api/hpo/docs/#/Search/search

# %%
disease_name = 'coronavirus'
r = requests.get('https://hpo.jax.org/api/hpo/search/?q=' + disease_name)
res = r.json()
# print(res)
# pick result, base 0
result_number = 0
disease_id = res['diseases'][result_number]['diseaseId']

r = requests.get("http://hpo.jax.org/api/hpo/disease/" + disease_id)
res = r.json()
# print(res)
HP_IDs = []
for x in res['catTermsMap']:
    for y in x["terms"]:
        print(y["name"].lower())
        print(y["ontologyId"])
        HP_IDs.append(y["ontologyId"])

symptoms = []
for x in HP_IDs: 
    r = requests.get('https://biothings.ncats.io/hpo/phenotype/' + x)
    res = r.json()
    if(('_id' in res) & ('name' in res)):
        symptoms.append(res['name'].lower())
    if('synonym' in res):
        for z in res['synonym']:
            if('EXACT' in z):
                name = z.split('"')[1].lower()
                if name not in symptoms: 
                    symptoms.append(name)
        
        

print(symptoms)
# Out:
# pharyngitis
# HP:0025439
# fever
# HP:0001945
# diabetes mellitus
# HP:0000819
# acute kidney injury
# HP:0001919
# immunodeficiency
# HP:0002721
# headache
# HP:0002315
# respiratory distress
# HP:0002098
# dyspnea
# HP:0002094
# respiratory failure requiring assisted ventilation
# HP:0004887
# acute infectious pneumonia
# HP:0011949
# cough
# HP:0012735
# chronic lung disease
# HP:0006528
# hypoxemia
# HP:0012418
# myalgia
# HP:0003326
# ['pharyngitis', 'fever', 'hyperthermia', 'pyrexia', 'diabetes mellitus', 'acute kidney injury', 'acute kidney failure', 'acute renal failure', 'immunodeficiency', 'decreased immune function', 'immune deficiency', 'headache', 'headaches', 'respiratory distress', 'breathing difficulties', 'difficulty breathing', 'respiratory difficulties', 'dyspnea', 'abnormal breathing', 'breathing difficulty', 'difficult to breathe', 'dyspnoea', 'trouble breathing', 'respiratory failure requiring assisted ventilation', 'respiratory distress necessitating mechanical ventilation', 'respiratory distress requiring endotracheal intubation', 'respiratory distress requiring mechanical ventilation', 'acute infectious pneumonia', 'cough', 'coughing', 'chronic lung disease', 'hypoxemia', 'low blood oxygen level', 'myalgia', 'muscle ache', 'muscle pain']

# %%
del symptoms[symptoms.index('diabetes mellitus')]
symptom_and_phenotype_list = symptoms

symptom_and_phenotype_list.append('blood coagulation')
symptom_and_phenotype_list.append('coagulation')
symptom_and_phenotype_list.append('blood clotting')
symptom_and_phenotype_list
# Out:
# ['pharyngitis',
#  'fever',
#  'hyperthermia',
#  'pyrexia',
#  'acute kidney injury',
#  'acute kidney failure',
#  'acute renal failure',
#  'immunodeficiency',
#  'decreased immune function',
#  'immune deficiency',
#  'headache',
#  'headaches',
#  'respiratory distress',
#  'breathing difficulties',
#  'difficulty breathing',
#  'respiratory difficulties',
#  'dyspnea',
#  'abnormal breathing',
#  'breathing difficulty',
#  'difficult to breathe',
#  'dyspnoea',
#  'trouble breathing',
#  'respiratory failure requiring assisted ventilation',
#  'respiratory distress necessitating mechanical ventilation',
#  'respiratory distress requiring endotracheal intubation',
#  'respiratory distress requiring mechanical ventilation',
#  'acute infectious pneumonia',
#  'cough',
#  'coughing',
#  'chronic lung disease',
#  'hypoxemia',
#  'low blood oxygen level',
#  'myalgia',
#  'muscle ache',
#  'muscle pain',
#  'blood coagulation',
#  'coagulation',
#  'blood clotting']

# %% [markdown]
# ### 1.3 Which of the genes related to COVID-19 are related to symptoms of COVID-19?

# %% [markdown]
# ### 1.3.1 Genes (from 1.1) -> Symptoms (From 1.2.1)
#
# #### 1.3.1.1 Gene -> Phenotype type "symptoms"

# %%
df_list = []
for x in top_50_related_genes_covid_2_allNodes_2_genes: 
#     print(x)
    try: 
        gene = ht.query(x)["Gene"][0]
        fc = FindConnection(input_obj=gene, output_obj='PhenotypicFeature', intermediate_nodes=None)
        fc.connect(verbose=False)
        df = fc.display_table_view()
        rows = df.shape[0]
        if(rows > 0):
            df_list.append(df)
    except:
        print(str(x) + " FAILED")
if(len(df_list) > 0):
    top50gene_2_phenotypicFeature = pd.concat(df_list)
# Out:
# C0017337 FAILED
# C0014442 FAILED
# C1705556 FAILED
# C0010762 FAILED
# C0164786 FAILED
# C1705526 FAILED
# C0010531 FAILED
# C0030956 FAILED

# %%
top50gene_2_phenotypicFeature.shape
# Out:
# (1400, 9)

# %%
## Get names for HP ids
HP_ids = top50gene_2_phenotypicFeature[top50gene_2_phenotypicFeature["output_name"].str.contains("HP:",regex=False)]["output_name"]
HP_ids = list(HP_ids)
HP_ids = list(dict.fromkeys(HP_ids))
len(HP_ids)
HP_dict = {}
for x in HP_ids: 
    HP_ID = x.split(':')[1]
    r = requests.get('https://biothings.ncats.io/hpo/phenotype/HP%3A' + HP_ID)
    res = r.json()
    if(('_id' in res) & ('name' in res)):
        HP_dict[res['_id']] = res['name'].lower()

# %%
def get_similar_phen_indices(list1,list2,similarity):
    res = [] 
    i = 0
    while (i < len(list1)):
        append_i = False
        lookup = list1[i].lower()
        if('HP:' in list1[i]):
            if(list1[i]  in HP_dict):
                lookup = HP_dict[list1[i]]
        for j in list2:
                if(difflib.SequenceMatcher(None,lookup,j).ratio() > similarity):
    #                 if(i < 3):
                    print("Matched similar terms:")
                    print(lookup + ' and ' + j)
#                     print()
                    append_i = True
        if(append_i): 
            res.append(i) 
        i += 1
    print(len(res))
    return(res)

# %%
phen_indices = get_similar_phen_indices(list(top50gene_2_phenotypicFeature["output_name"]),symptom_and_phenotype_list,0.9)
# Out:
# Matched similar terms:
# dyspnea and dyspnea
# Matched similar terms:
# dyspnea and dyspnoea
# Matched similar terms:
# fever and fever
# Matched similar terms:
# dyspnea and dyspnea
# Matched similar terms:
# dyspnea and dyspnoea
# Matched similar terms:
# headache and headache
# Matched similar terms:
# headache and headaches
# Matched similar terms:
# immunodeficiency and immunodeficiency
# Matched similar terms:
# immunodeficiency and immune deficiency
# Matched similar terms:
# myalgia and myalgia
# Matched similar terms:
# dyspnea and dyspnea
# Matched similar terms:
# dyspnea and dyspnoea
# Matched similar terms:
# headache and headache
# Matched similar terms:
# headache and headaches
# Matched similar terms:
# fever and fever
# Matched similar terms:
# dyspnea and dyspnea
# Matched similar terms:
# dyspnea and dyspnoea
# Matched similar terms:
# cough and cough
# Matched similar terms:
# dyspnea and dyspnea
# Matched similar terms:
# dyspnea and dyspnoea
# 12

# %%
phen_top_50 = top50gene_2_phenotypicFeature.iloc[phen_indices,:]
# phen_top_50
for index in range(phen_top_50.shape[0]):
#     if("HP:" in row['output_name']):
#     print(index)
    if(phen_top_50.iloc[index]["output_name"] in HP_dict):
        phen_top_50.iloc[index]["output_name"] = HP_dict[phen_top_50.iloc[index]["output_name"]]

phen_top_50
# Out:
#      input input_type       pred1 pred1_source    pred1_api  \
# 6      ANG       Gene  related_to         None  BioLink API
# 22    TP53       Gene  related_to         None  BioLink API
# 47    TP53       Gene  related_to         None  BioLink API
# 96    TP53       Gene  related_to         None  BioLink API
# 5      FOS       Gene  related_to         None  BioLink API
# 39     FOS       Gene  related_to         None  BioLink API
# 50  SQSTM1       Gene  related_to         None  BioLink API
# 43     APP       Gene  related_to         None  BioLink API
# 19      TH       Gene  related_to         None  BioLink API
# 24    SOD1       Gene  related_to         None  BioLink API
# 5    MARS1       Gene  related_to         None  BioLink API
# 8    MARS1       Gene  related_to         None  BioLink API
#
#                                          pred1_pubmed        output_type  \
# 6                                                None  PhenotypicFeature
# 22                                               None  PhenotypicFeature
# 47                                               None  PhenotypicFeature
# 96                                               None  PhenotypicFeature
# 5                                                None  PhenotypicFeature
# 39                                               None  PhenotypicFeature
# 50                                               None  PhenotypicFeature
# 43                                               None  PhenotypicFeature
# 19  10407773,9732974,0011551,21937992,20430833,252...  PhenotypicFeature
# 24                                               None  PhenotypicFeature
# 5                                                None  PhenotypicFeature
# 8                                                None  PhenotypicFeature
#
#          output_name      output_id
# 6            dyspnea  HP:HP:0002094
# 22             fever  HP:HP:0001945
# 47           dyspnea  HP:HP:0002094
# 96          headache  HP:HP:0002315
# 5   immunodeficiency  HP:HP:0002721
# 39           myalgia  HP:HP:0003326
# 50           dyspnea  HP:HP:0002094
# 43          headache  HP:HP:0002315
# 19             fever  HP:HP:0001945
# 24           dyspnea  HP:HP:0002094
# 5              cough  HP:HP:0012735
# 8            dyspnea  HP:HP:0002094

# %% [markdown]
# #### 1.3.1.2  Gene -> Bioprocess type "symptoms"

# %%
df_list = []
for x in top_50_related_genes_covid_2_allNodes_2_genes: 
#     print(x)
    try: 
        gene = ht.query(x)["Gene"][0]
        fc = FindConnection(input_obj=gene, output_obj='BiologicalProcess', intermediate_nodes=None)
        fc.connect(verbose=False)
        df = fc.display_table_view()
        rows = df.shape[0]
        if(rows > 0):
            df_list.append(df)
    except:
        print(str(x) + " FAILED")
if(len(df_list) > 0):
    top50gene_2_bioprocesses = pd.concat(df_list)
# Out:
# C0017337 FAILED
# C0014442 FAILED
# C1705556 FAILED
# C0010762 FAILED
# C0164786 FAILED
# C1705526 FAILED
# C0010531 FAILED
# C0030956 FAILED

# %%
top50gene_2_bioprocesses.shape
# Out:
# (17958, 9)

# %%
## Get names for go ids
go_ids = top50gene_2_bioprocesses[top50gene_2_bioprocesses["output_name"].str.contains("go:",regex=False)]["output_name"]
go_ids = list(go_ids)
go_ids = list(dict.fromkeys(go_ids))
len(go_ids)
go_dict = {}
for x in go_ids: 
    go_ID = x.split(':')[1]
    r = requests.get('https://biothings.ncats.io/go_bp/geneset/GO%3A' + go_ID)
    res = r.json()
    if('name' in res):
        go_dict[res['_id']] = res['name'].lower()

# %%
def get_similar_bp_indices(list1,list2,similarity):
    res = [] 
    i = 0
    while (i < len(list1)):
        append_i = False
        lookup = list1[i].lower()
        if('go:' in list1[i]):
            if list1[i] in go_dict:
                lookup = go_dict[list1[i]]
        for j in list2:
                if(difflib.SequenceMatcher(None,lookup,j).ratio() > similarity):
    #                 if(i < 3):
                    print("Matched similar terms:")
                    print(lookup + ' and ' + j)
#                     print()
                    append_i = True
        if(append_i): 
            res.append(i) 
        i += 1
    print(len(res))
    return(res)

# %%
bp_indices = get_similar_bp_indices(list(top50gene_2_bioprocesses["output_name"]),symptom_and_phenotype_list,0.9)
# Out:
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# 12

# %%
bioprocess_top_50 = top50gene_2_bioprocesses.iloc[bp_indices,:]
bioprocess_top_50
# Out:
#       input input_type                   pred1  \
# 1164    TNF       Gene              related_to
# 840     INS       Gene              related_to
# 847     INS       Gene              related_to
# 821    AKT1       Gene              related_to
# 358     IL6       Gene              related_to
# 576   MAPK1       Gene              related_to
# 4       ALB       Gene                 affects
# 516   VEGFA       Gene                disrupts
# 615   IFNA1       Gene  functional_association
# 129     EPO       Gene              related_to
# 390   MAPK8       Gene              related_to
# 36      CRP       Gene              related_to
#
#                          pred1_source        pred1_api     pred1_pubmed  \
# 1164  Translator Text Mining Provider    CORD Gene API             None
# 840   Translator Text Mining Provider    CORD Gene API             None
# 847   Translator Text Mining Provider    CORD Gene API             None
# 821   Translator Text Mining Provider    CORD Gene API             None
# 358   Translator Text Mining Provider    CORD Gene API             None
# 576   Translator Text Mining Provider    CORD Gene API             None
# 4                              SEMMED  SEMMED Gene API  7511495,9215020
# 516                            SEMMED  SEMMED Gene API         22532265
# 615                            entrez  MyGene.info API             None
# 129   Translator Text Mining Provider    CORD Gene API             None
# 390   Translator Text Mining Provider    CORD Gene API             None
# 36    Translator Text Mining Provider    CORD Gene API             None
#
#             output_type        output_name               output_id
# 1164  BiologicalProcess        COAGULATION           GO:GO:0050817
# 840   BiologicalProcess        COAGULATION           GO:GO:0050817
# 847   BiologicalProcess  BLOOD COAGULATION           GO:GO:0007596
# 821   BiologicalProcess        COAGULATION           GO:GO:0050817
# 358   BiologicalProcess        COAGULATION           GO:GO:0050817
# 576   BiologicalProcess        COAGULATION           GO:GO:0050817
# 4     BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION
# 516   BiologicalProcess  BLOOD COAGULATION  name:BLOOD COAGULATION
# 615   BiologicalProcess  BLOOD COAGULATION           GO:GO:0007596
# 129   BiologicalProcess        COAGULATION           GO:GO:0050817
# 390   BiologicalProcess        COAGULATION           GO:GO:0050817
# 36    BiologicalProcess        COAGULATION           GO:GO:0050817

# %% [markdown]
# #### 1.3.1.3  Gene -> Disease type "symptoms"

# %%
df_list = []
for x in top_50_related_genes_covid_2_allNodes_2_genes: 
#     print(x)
    try: 
        gene = ht.query(x)["Gene"][0]
        fc = FindConnection(input_obj=gene, output_obj='Disease', intermediate_nodes=None)
        fc.connect(verbose=False)
        df = fc.display_table_view()
        rows = df.shape[0]
        if(rows > 0):
            df_list.append(df)
    except:
        print(str(x) + " FAILED")
if(len(df_list) > 0):
    top50gene_2_diseases = pd.concat(df_list)

top50gene_2_diseases.shape
# Out:
# C0017337 FAILED
# C0014442 FAILED
# C1705556 FAILED
# C0010762 FAILED
# C0164786 FAILED
# C1705526 FAILED
# C0010531 FAILED
# C0030956 FAILED
# (48223, 9)

# %%
def get_similar_disease_indices(list1,list2,similarity):
    res = [] 
    i = 0
    while (i < len(list1)):
        append_i = False
        lookup = list1[i].lower()
#         if('go:' in list1[i]):
#             if list1[i] in go_dict:
#                 lookup = go_dict[list1[i]]
        for j in list2:
                if(difflib.SequenceMatcher(None,lookup,j).ratio() > similarity):
    #                 if(i < 3):
#                     print("Matched similar terms:")
#                     print(lookup + ' and ' + j)
#                     print()
                    append_i = True
        if(append_i): 
            res.append(i) 
        i += 1
    print(len(res))
    return(res)

# %%
disease_indices = get_similar_disease_indices(list(top50gene_2_diseases["output_name"]),symptom_and_phenotype_list,0.9)
# Out:
# 118

# %%
# top50gene_2_diseases
relevant_top50gene_2_diseases = top50gene_2_diseases.iloc[disease_indices,:]
relevant_top50gene_2_diseases
# Out:
#      input input_type       pred1 pred1_source                    pred1_api  \
# 1539   TNF       Gene    disrupts       SEMMED              SEMMED Gene API
# 1540   TNF       Gene      causes       SEMMED              SEMMED Gene API
# 1541   TNF       Gene     affects       SEMMED              SEMMED Gene API
# 1542   TNF       Gene  related_to     disgenet           mydisease.info API
# 2150   TNF       Gene      causes       SEMMED              SEMMED Gene API
# ...    ...        ...         ...          ...                          ...
# 1175   CA2       Gene     affects       SEMMED              SEMMED Gene API
# 1177   CA2       Gene     affects       SEMMED              SEMMED Gene API
# 402    CRP       Gene  related_to      DISEASE                 DISEASES API
# 403    CRP       Gene  related_to     scigraph  Automat CORD19 Scigraph API
# 796    CRP       Gene  related_to     scigraph  Automat CORD19 Scigraph API
#
#                                            pred1_pubmed output_type  \
# 1539                  1443236,16300807,22673618,9094446     Disease
# 1540  10701765,15373964,16460809,1714101,17374708,17...     Disease
# 1541  11593333,12879338,15855300,15965498,17967442,1...     Disease
# 1542                                               None     Disease
# 2150                                           21426732     Disease
# ...                                                 ...         ...
# 1175                           11936556,3109731,4022197     Disease
# 1177                                            4061632     Disease
# 402                                                None     Disease
# 403                                                None     Disease
# 796                                                None     Disease
#
#                output_name            output_id
# 1539                 FEVER       MONDO:C0015967
# 1540                 FEVER       MONDO:C0015967
# 1541                 FEVER       MONDO:C0015967
# 1542                 FEVER       MONDO:C0015967
# 2150              COUGHING       MONDO:C0010200
# ...                    ...                  ...
# 1175                 FEVER       MONDO:C0015967
# 1177  ACUTE KIDNEY FAILURE  MONDO:MONDO:0002492
# 402            PHARYNGITIS  MONDO:MONDO:0002258
# 403            PHARYNGITIS  MONDO:MONDO:0002258
# 796   ACUTE KIDNEY FAILURE  MONDO:MONDO:0002492
#
# [118 rows x 9 columns]

# %%
i = list(top50gene_2_diseases.iloc[disease_indices,:]["input"])
d = {x:i.count(x) for x in i}
sorted_genes_from_symptoms = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
for x in list(reversed(list(sorted_genes_from_symptoms)))[0:50]:
    print(str(x) + ": " + str(sorted_genes_from_symptoms[x]))
# Out:
# TNF: 12
# INS: 9
# VEGFA: 8
# IL6: 8
# EPO: 6
# LEP: 6
# CAMP: 5
# BAX: 5
# ALB: 5
# ACE: 5
# TP53: 5
# IFNA1: 4
# CRP: 3
# MPO: 3
# EGFR: 3
# SOD1: 3
# CDKN1A: 3
# FOS: 3
# CA2: 2
# MAPK8: 2
# SOD2: 2
# IL1B: 2
# CYP2C9: 2
# PPIG: 2
# CYP2D6: 2
# CAT: 2
# CD4: 1
# TH: 1
# TLR9: 1
# AR: 1
# ACE2: 1
# AKT1: 1

# %%
# Out:
# ['disrupts',
#  'causes',
#  'affects',
#  'related_to',
#  'causes',
#  'causes',
#  'related_to',
#  'related_to',
#  'causes',
#  'related_to',
#  'related_to',
#  'related_to',
#  'disrupts',
#  'related_to',
#  'causes',
#  'causes',
#  'affects',
#  'treats',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'affects',
#  'related_to',
#  'related_to',
#  'related_to',
#  'affects',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'affects',
#  'related_to',
#  'causes',
#  'related_to',
#  'related_to',
#  'related_to',
#  'disrupts',
#  'related_to',
#  'disrupts',
#  'causes',
#  'related_to',
#  'treats',
#  'related_to',
#  'disrupts',
#  'causes',
#  'causes',
#  'affects',
#  'related_to',
#  'related_to',
#  'related_to',
#  'causes',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'prevents',
#  'related_to',
#  'related_to',
#  'disrupts',
#  'related_to',
#  'causes',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'affects',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'disrupts',
#  'affects',
#  'related_to',
#  'related_to',
#  'related_to',
#  'causes',
#  'affects',
#  'treats',
#  'related_to',
#  'treats',
#  'affects',
#  'related_to',
#  'related_to',
#  'related_to',
#  'causes',
#  'treats',
#  'affects',
#  'treats',
#  'causes',
#  'affects',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'causes',
#  'causes',
#  'causes',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'related_to',
#  'causes',
#  'affects',
#  'affects',
#  'affects',
#  'related_to',
#  'related_to',
#  'related_to']

# %%
causes_df = relevant_top50gene_2_diseases[relevant_top50gene_2_diseases["pred1"] == "causes"]
i = list(causes_df["input"])
causes_dict = {x:i.count(x) for x in i}
causes_dict
# Out:
# {'TNF': 4,
#  'INS': 2,
#  'FOS': 1,
#  'ACE': 1,
#  'PPIG': 1,
#  'ALB': 1,
#  'CDKN1A': 1,
#  'VEGFA': 1,
#  'LEP': 1,
#  'IFNA1': 1,
#  'CAMP': 1,
#  'EPO': 3,
#  'MAPK8': 1}

# %% [markdown]
# **How to Interpret above**: Of the top genes associated with COVID-19, the above are genes that are known to cause symptoms described as symptoms in COVID-19

# %% [markdown]
# ## Assembly of Results

# %%
all_gene_connections = pd.concat([bioprocess_top_50,phen_top_50,relevant_top50gene_2_diseases])
all_gene_connections["output_name"] = all_gene_connections["output_name"].str.lower()
all_gene_connections
# Out:
#      input input_type       pred1                     pred1_source  \
# 1164   TNF       Gene  related_to  Translator Text Mining Provider
# 840    INS       Gene  related_to  Translator Text Mining Provider
# 847    INS       Gene  related_to  Translator Text Mining Provider
# 821   AKT1       Gene  related_to  Translator Text Mining Provider
# 358    IL6       Gene  related_to  Translator Text Mining Provider
# ...    ...        ...         ...                              ...
# 1175   CA2       Gene     affects                           SEMMED
# 1177   CA2       Gene     affects                           SEMMED
# 402    CRP       Gene  related_to                          DISEASE
# 403    CRP       Gene  related_to                         scigraph
# 796    CRP       Gene  related_to                         scigraph
#
#                         pred1_api              pred1_pubmed  \
# 1164                CORD Gene API                      None
# 840                 CORD Gene API                      None
# 847                 CORD Gene API                      None
# 821                 CORD Gene API                      None
# 358                 CORD Gene API                      None
# ...                           ...                       ...
# 1175              SEMMED Gene API  11936556,3109731,4022197
# 1177              SEMMED Gene API                   4061632
# 402                  DISEASES API                      None
# 403   Automat CORD19 Scigraph API                      None
# 796   Automat CORD19 Scigraph API                      None
#
#             output_type           output_name            output_id
# 1164  BiologicalProcess           coagulation        GO:GO:0050817
# 840   BiologicalProcess           coagulation        GO:GO:0050817
# 847   BiologicalProcess     blood coagulation        GO:GO:0007596
# 821   BiologicalProcess           coagulation        GO:GO:0050817
# 358   BiologicalProcess           coagulation        GO:GO:0050817
# ...                 ...                   ...                  ...
# 1175            Disease                 fever       MONDO:C0015967
# 1177            Disease  acute kidney failure  MONDO:MONDO:0002492
# 402             Disease           pharyngitis  MONDO:MONDO:0002258
# 403             Disease           pharyngitis  MONDO:MONDO:0002258
# 796             Disease  acute kidney failure  MONDO:MONDO:0002492
#
# [142 rows x 9 columns]

# %%
# all_gene_connections
top_symptom_pub_counts = {}
for index, row in all_gene_connections.iterrows():
#     if row["input_name"] in top_50_related_genes_covid_2_allNodes_2_genes:
    current_pubcount = 0
    if(row["pred1_pubmed"] != None):
        current_pubcount = current_pubcount + row["pred1_pubmed"].count(",") + 1
    if row["input"] in top_symptom_pub_counts:
        top_symptom_pub_counts[row["input"]] = top_symptom_pub_counts[row["input"]] + current_pubcount
    else: 
        top_symptom_pub_counts[row["input"]] = current_pubcount

top_symptom_pub_counts
# Out:
# {'TNF': 37,
#  'INS': 6,
#  'AKT1': 1,
#  'IL6': 5,
#  'MAPK1': 0,
#  'ALB': 5,
#  'VEGFA': 10,
#  'IFNA1': 10,
#  'EPO': 6,
#  'MAPK8': 2,
#  'CRP': 0,
#  'ANG': 0,
#  'TP53': 4,
#  'FOS': 3,
#  'SQSTM1': 0,
#  'APP': 0,
#  'TH': 9,
#  'SOD1': 2,
#  'MARS1': 0,
#  'CAT': 1,
#  'CYP2D6': 1,
#  'ACE2': 0,
#  'ACE': 4,
#  'AR': 1,
#  'TLR9': 0,
#  'PPIG': 3,
#  'CDKN1A': 3,
#  'CD4': 0,
#  'CYP2C9': 1,
#  'IL1B': 0,
#  'BAX': 5,
#  'LEP': 8,
#  'EGFR': 1,
#  'CAMP': 6,
#  'SOD2': 0,
#  'MPO': 1,
#  'CA2': 4}

# %%
print(sorted_genes_covid_2_allNodes_2_genes['INS'])

results_dict = {}
for i in range(all_gene_connections.shape[0]):
    if(all_gene_connections.iloc[i]["input"] in results_dict):
        results_dict[all_gene_connections.iloc[i]["input"]]["symptoms_associated"].append(all_gene_connections.iloc[i]["output_name"])
    else:
        results_dict[all_gene_connections.iloc[i]["input"]] = {
            "two_step_associations_to_covid" : sorted_genes_covid_2_allNodes_2_genes[all_gene_connections.iloc[i]["input"]],
            "direct_associations_to_covid" : sorted_genes_covid_2_genes[all_gene_connections.iloc[i]["input"]] if all_gene_connections.iloc[i]["input"] in sorted_genes_covid_2_genes else 0,
            "symptoms_associated" : [all_gene_connections.iloc[i]["output_name"]]
        }
    
print(results_dict)
# Out:
# 27
# {'TNF': {'two_step_associations_to_covid': 44, 'direct_associations_to_covid': 0, 'symptoms_associated': ['coagulation', 'fever', 'fever', 'fever', 'fever', 'coughing', 'acute kidney failure', 'acute kidney failure', 'acute kidney failure', 'hypoxemia', 'pharyngitis', 'pharyngitis', 'pharyngitis']}, 'INS': {'two_step_associations_to_covid': 27, 'direct_associations_to_covid': 0, 'symptoms_associated': ['coagulation', 'blood coagulation', 'coughing', 'fever', 'fever', 'chronic lung disease', 'acute kidney failure', 'acute kidney failure', 'acute kidney failure', 'acute kidney failure', 'pharyngitis']}, 'AKT1': {'two_step_associations_to_covid': 25, 'direct_associations_to_covid': 0, 'symptoms_associated': ['coagulation', 'fever']}, 'IL6': {'two_step_associations_to_covid': 23, 'direct_associations_to_covid': 0, 'symptoms_associated': ['coagulation', 'acute kidney failure', 'acute kidney failure', 'acute kidney failure', 'fever', 'fever', 'headache', 'pharyngitis', 'pharyngitis']}, 'MAPK1': {'two_step_associations_to_covid': 18, 'direct_associations_to_covid': 0, 'symptoms_associated': ['coagulation']}, 'ALB': {'two_step_associations_to_covid': 16, 'direct_associations_to_covid': 0, 'symptoms_associated': ['blood coagulation', 'fever', 'fever', 'pharyngitis', 'acute kidney failure', 'acute kidney failure']}, 'VEGFA': {'two_step_associations_to_covid': 15, 'direct_associations_to_covid': 0, 'symptoms_associated': ['blood coagulation', 'chronic lung disease', 'chronic lung disease', 'coughing', 'coughing', 'acute kidney failure', 'acute kidney failure', 'acute kidney failure', 'hypoxemia']}, 'IFNA1': {'two_step_associations_to_covid': 15, 'direct_associations_to_covid': 0, 'symptoms_associated': ['blood coagulation', 'fever', 'fever', 'fever', 'acute kidney failure']}, 'EPO': {'two_step_associations_to_covid': 14, 'direct_associations_to_covid': 0, 'symptoms_associated': ['coagulation', 'dyspnea', 'fever', 'hypoxemia', 'acute kidney failure', 'acute kidney failure', 'acute kidney failure']}, 'MAPK8': {'two_step_associations_to_covid': 14, 'direct_associations_to_covid': 0, 'symptoms_associated': ['coagulation', 'fever', 'fever']}, 'CRP': {'two_step_associations_to_covid': 10, 'direct_associations_to_covid': 1, 'symptoms_associated': ['coagulation', 'pharyngitis', 'pharyngitis', 'acute kidney failure']}, 'ANG': {'two_step_associations_to_covid': 24, 'direct_associations_to_covid': 0, 'symptoms_associated': ['dyspnea']}, 'TP53': {'two_step_associations_to_covid': 19, 'direct_associations_to_covid': 0, 'symptoms_associated': ['fever', 'dyspnea', 'headache', 'acute kidney failure', 'acute kidney failure', 'acute kidney failure', 'fever', 'pharyngitis']}, 'FOS': {'two_step_associations_to_covid': 18, 'direct_associations_to_covid': 0, 'symptoms_associated': ['immunodeficiency', 'myalgia', 'headache', 'headache', 'coughing']}, 'SQSTM1': {'two_step_associations_to_covid': 17, 'direct_associations_to_covid': 0, 'symptoms_associated': ['dyspnea']}, 'APP': {'two_step_associations_to_covid': 17, 'direct_associations_to_covid': 0, 'symptoms_associated': ['headache']}, 'TH': {'two_step_associations_to_covid': 16, 'direct_associations_to_covid': 1, 'symptoms_associated': ['fever', 'pharyngitis']}, 'SOD1': {'two_step_associations_to_covid': 15, 'direct_associations_to_covid': 0, 'symptoms_associated': ['dyspnea', 'acute kidney failure', 'acute kidney failure', 'acute kidney failure']}, 'MARS1': {'two_step_associations_to_covid': 7, 'direct_associations_to_covid': 1, 'symptoms_associated': ['cough', 'dyspnea']}, 'CAT': {'two_step_associations_to_covid': 32, 'direct_associations_to_covid': 0, 'symptoms_associated': ['fever', 'acute kidney failure']}, 'CYP2D6': {'two_step_associations_to_covid': 25, 'direct_associations_to_covid': 0, 'symptoms_associated': ['acute kidney failure', 'acute kidney failure']}, 'ACE2': {'two_step_associations_to_covid': 18, 'direct_associations_to_covid': 2, 'symptoms_associated': ['acute kidney failure']}, 'ACE': {'two ...

# %%
def get_connection_normalizing_count(gene):
    count = 0
    input_object = ht.query(gene)['Gene'][0]
    for x in node_type_list:
        fc = FindConnection(input_obj=input_object, output_obj=x, intermediate_nodes=None)
        fc.connect(verbose=False)
        df = fc.display_table_view()
        rows = df.shape[0]
        count = count + rows
    return(count)
        
TNF_count = get_connection_normalizing_count('TNF')
print(TNF_count)
# Out:
# 19385

# %%
connection_dict = {}
for key in results_dict:
    connection_dict[key] = get_connection_normalizing_count(key)

# %%
dataframe_input = []

for key in results_dict:
    connections_count = connection_dict[key]
    current_result = {'gene': key, 
                      "direct_disease_assoc": results_dict[key]["direct_associations_to_covid"], 
                      "two_step_assoc_to_disease": results_dict[key]["two_step_associations_to_covid"],
                      "two_step_pub_count": top_genes_pub_counts[key],
                      "disease_symptoms_gene_is_associated_with": results_dict[key]["symptoms_associated"],
                      "symptoms_associated_count": len(results_dict[key]["symptoms_associated"]),
                      "disease_symptom_gene_pub_count": top_symptom_pub_counts[key],
                      "causes_symptom_count": causes_dict[key] if key in causes_dict else 0,
                      "relevance_score": ((results_dict[key]["direct_associations_to_covid"]*10 +
                                          results_dict[key]["two_step_associations_to_covid"] + 
                                          round(top_genes_pub_counts[key] / 3) + 
                                          round(top_symptom_pub_counts[key]) + 
                                          (causes_dict[key] if key in causes_dict else 0)*20 + 
                                          len(results_dict[key]["symptoms_associated"])*10)
                                          /connections_count)
                     }
    dataframe_input.append(current_result)
    
final_df = pd.DataFrame(dataframe_input)
final_df = final_df.sort_values(by=['relevance_score'], ascending=False)
final_df
# Out:
#       gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 8      EPO                     0                         14
# 21    ACE2                     2                         18
# 35     MPO                     0                         14
# 16      TH                     1                         16
# 18   MARS1                     1                          7
# 24    TLR9                     0                         16
# 22     ACE                     0                         18
# 11     ANG                     0                         24
# 25    PPIG                     0                         16
# 10     CRP                     1                         10
# 17    SOD1                     0                         15
# 29    IL1B                     0                         15
# 34    SOD2                     0                         14
# 5      ALB                     0                         16
# 20  CYP2D6                     0                         25
# 3      IL6                     0                         23
# 28  CYP2C9                     0                         15
# 1      INS                     0                         27
# 14  SQSTM1                     0                         17
# 31     LEP                     0                         15
# 0      TNF                     0                         44
# 6    VEGFA                     0                         15
# 19     CAT                     0                         32
# 30     BAX                     0                         15
# 13     FOS                     0                         18
# 7    IFNA1                     0                         15
# 33    CAMP                     0                         15
# 26  CDKN1A                     0                         16
# 9    MAPK8                     0                         14
# 12    TP53                     0                         19
# 15     APP                     0                         17
# 32    EGFR                     0                         15
# 23      AR                     0                         17
# 36     CA2                     0                         14
# 2     AKT1                     0                         25
# 27     CD4                     0                         16
# 4    MAPK1                     0                         18
#
#     two_step_pub_count           disease_symptoms_gene_is_associated_with  \
# 8                   26  [coagulation, dyspnea, fever, hypoxemia, acute...
# 21                  24                             [acute kidney failure]
# 35                  33  [hypoxemia, acute kidney failure, acute kidney...
# 16                 541                               [fever, pharyngitis]
# 18                   5                                   [cough, dyspnea]
# 24                  15                                      [pharyngitis]
# 22                  32  [acute kidney failure, acute kidney failure, c...
# 11                  78                                          [dyspnea]
# 25                  45                      [fever, acute kidney failure]
# 10                   0  [coagulation, pharyngitis, pharyngitis, acute ...
# 17                  26  [dyspnea, acute kidney failure, acute kidney f...
# 29                  39                               [fever, pharyngitis]
# 34                  40                                 [fever, hypoxemia]
# 5                    9  [blood coagulation, fever, fever, pharyngitis,...
# 20                  18       [acute kidney failure, acute kidney failure]
# 3                   58  [coagulation, acute kidney failure, acute kidn...
# 28                  11       [acute kidney failure, acute kidney failure]
# 1                   53  [coagulation, blood coagulation, coughing, fev...
# 14                  45                                          [dyspnea]
# 31                  20  [fever, fever, acute kidney failure, acute kid...
# 0                  114  [coagulation, fever, fever, fever, fever, coug...
# 6                  150  [blood coagulation, chronic lung disease, chro...
# 19                  98                      [fever, acute kidney failure]
# 30                  30  [fever, fever, acute kidney failure, acute kid...
# 13                  34  [immunodeficiency, myalgia, headache, headache...
# 7                   15  [blood coagulation, fever, fever, fever, acute...
# 33                  71  [fever, fever, headache, pharyngitis, pharyngi...
# 26                  29  [fever, acute kidney failure, chronic lung dis...
# 9                   24                        [coagulation, fever, fever]
# 12                  42  [fever, dyspnea, headache, acute kidney failur...
# 15                  21                                         [headache]
# 32                   8  [acute kidney failure, acute kidney failure, a...
# 23                  11                             [acute kidney failure]
# 36                  80                      [fever, acute kidney failure]
# 2                   51                               [coagulation, fever]
# 27                  10                                      [pharyngitis]
# 4                   40                                      [coagulation]
#
#     symptoms_associated_count  disease_symptom_gene_pub_count  \
# 8                           7                               6
# 21                          1                               0
# 35                          3                               1
# 16                          2                               9
# 18                          2                               0
# 24                          1                               0
# 22                          5                               4
# 11                          1                               0
# 25                          2                               3
# 10                          4                               0
# 17                          4                               2
# 29                          2                               0
# 34                          2                               0
# 5                           6                               5
# 20                          2                               1
# 3                           9                               5
# 28                          2                               1
# 1                          11                               6
# 14                          1                               0
# 31                          6                               8
# 0                          13                              37
# 6                           9                              10
# 19                          2                               1
# 30                          5                               5
# 13                          5                               3
# 7                           5                              10
# 33                          5                               6
# 26                          3                               3
# 9                           3                               2
# 12                          8                               4
# 15                          1                               0
# 32                          3                               1
# 23                          1                               1
# 36                          2                               4
# 2                           2                               1
# 27                          1                               0
# 4                           1                               0
#
#     causes_symptom_count  relevance_score
# 8                      3         0.073509
# 21                     0         0.066986
# 35                     0         0.050450
# 16                     0         0.041778
# 18                     0         0.041183
# 24                     0         0.040000
# 22                     1         0.037184
# 11                     0         0.034345
# 25                     1         0.029088
# 10                     0         0.028143
# 17                     0         0.027638
# 29                     0         0.026172
# 34                     0         0.024802
# 5                      1         0.024425
# 20                     0         0.023204
# 3                      0         0.023045
# 28                     0         0.021265
# 1                      2         0.021034
# 14                     0         0.019905
# 31                     1         0.019194
# 0                      4         0.016972
# 6                      1         0.016582
# 19                     0         0.016279
# 30                     0         0.016145
# 13                     1         0.014765
# 7                      1         0.013364
# 33                     1         0.011067
# 26                     1         0.010989
# 9                      1         0.009880
# 12                     0         0.008373
# 15                     0         0.006426
# 32                     0         0.005532
# 23                     0         0.004676
# 36                     0         0.003890
# 2                      0         0.003859
# 27                     0         0.003663
# 4                      0         0.003510

# %%
final_df
# Out:
#       gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 21    ACE2                     2                         18
# 8      EPO                     0                         14
# 16      TH                     1                         16
# 35     MPO                     0                         14
# 18   MARS1                     1                          7
# 24    TLR9                     0                         16
# 11     ANG                     0                         24
# 22     ACE                     0                         18
# 25    PPIG                     0                         16
# 29    IL1B                     0                         15
# 10     CRP                     1                         10
# 34    SOD2                     0                         14
# 20  CYP2D6                     0                         25
# 17    SOD1                     0                         15
# 14  SQSTM1                     0                         17
# 5      ALB                     0                         16
# 28  CYP2C9                     0                         15
# 1      INS                     0                         27
# 19     CAT                     0                         32
# 3      IL6                     0                         23
# 0      TNF                     0                         44
# 31     LEP                     0                         15
# 6    VEGFA                     0                         15
# 13     FOS                     0                         18
# 30     BAX                     0                         15
# 7    IFNA1                     0                         15
# 26  CDKN1A                     0                         16
# 33    CAMP                     0                         15
# 9    MAPK8                     0                         14
# 15     APP                     0                         17
# 12    TP53                     0                         19
# 23      AR                     0                         17
# 32    EGFR                     0                         15
# 36     CA2                     0                         14
# 2     AKT1                     0                         25
# 4    MAPK1                     0                         18
# 27     CD4                     0                         16
#
#     two_step_pub_count           disease_symptoms_gene_is_associated_with  \
# 21                  24                             [acute kidney failure]
# 8                   26  [coagulation, dyspnea, fever, hypoxemia, acute...
# 16                 541                               [fever, pharyngitis]
# 35                  33  [hypoxemia, acute kidney failure, acute kidney...
# 18                   5                                   [cough, dyspnea]
# 24                  15                                      [pharyngitis]
# 11                  78                                          [dyspnea]
# 22                  32  [acute kidney failure, acute kidney failure, c...
# 25                  45                      [fever, acute kidney failure]
# 29                  39                               [fever, pharyngitis]
# 10                   0  [coagulation, pharyngitis, pharyngitis, acute ...
# 34                  40                                 [fever, hypoxemia]
# 20                  18       [acute kidney failure, acute kidney failure]
# 17                  26  [dyspnea, acute kidney failure, acute kidney f...
# 14                  45                                          [dyspnea]
# 5                    9  [blood coagulation, fever, fever, pharyngitis,...
# 28                  11       [acute kidney failure, acute kidney failure]
# 1                   53  [coagulation, blood coagulation, coughing, fev...
# 19                  98                      [fever, acute kidney failure]
# 3                   58  [coagulation, acute kidney failure, acute kidn...
# 0                  114  [coagulation, fever, fever, fever, fever, coug...
# 31                  20  [fever, fever, acute kidney failure, acute kid...
# 6                  150  [blood coagulation, chronic lung disease, chro...
# 13                  34  [immunodeficiency, myalgia, headache, headache...
# 30                  30  [fever, fever, acute kidney failure, acute kid...
# 7                   15  [blood coagulation, fever, fever, fever, acute...
# 26                  29  [fever, acute kidney failure, chronic lung dis...
# 33                  71  [fever, fever, headache, pharyngitis, pharyngi...
# 9                   24                        [coagulation, fever, fever]
# 15                  21                                         [headache]
# 12                  42  [fever, dyspnea, headache, acute kidney failur...
# 23                  11                             [acute kidney failure]
# 32                   8  [acute kidney failure, acute kidney failure, a...
# 36                  80                      [fever, acute kidney failure]
# 2                   51                               [coagulation, fever]
# 4                   40                                      [coagulation]
# 27                  10                                      [pharyngitis]
#
#     symptoms_associated_count  disease_symptom_gene_pub_count  \
# 21                          1                               0
# 8                           7                               6
# 16                          2                               9
# 35                          3                               1
# 18                          2                               0
# 24                          1                               0
# 11                          1                               0
# 22                          5                               4
# 25                          2                               3
# 29                          2                               0
# 10                          4                               0
# 34                          2                               0
# 20                          2                               1
# 17                          4                               2
# 14                          1                               0
# 5                           6                               5
# 28                          2                               1
# 1                          11                               6
# 19                          2                               1
# 3                           9                               5
# 0                          13                              37
# 31                          6                               8
# 6                           9                              10
# 13                          5                               3
# 30                          5                               5
# 7                           5                              10
# 26                          3                               3
# 33                          5                               6
# 9                           3                               2
# 15                          1                               0
# 12                          8                               4
# 23                          1                               1
# 32                          3                               1
# 36                          2                               4
# 2                           2                               1
# 4                           1                               0
# 27                          1                               0
#
#     causes_symptom_count  relevance_score
# 21                     0         0.071770
# 8                      3         0.054092
# 16                     0         0.040533
# 35                     0         0.034234
# 18                     0         0.033791
# 24                     0         0.032258
# 11                     0         0.030910
# 22                     1         0.026354
# 25                     1         0.024371
# 29                     0         0.019629
# 10                     0         0.019231
# 34                     0         0.018470
# 20                     0         0.017849
# 17                     0         0.017588
# 14                     0         0.017062
# 5                      1         0.015970
# 28                     0         0.014886
# 1                      2         0.014127
# 19                     0         0.014007
# 3                      0         0.013961
# 0                      4         0.012948
# 31                     1         0.012912
# 6                      1         0.011742
# 13                     1         0.010423
# 30                     0         0.010091
# 7                      1         0.009355
# 26                     1         0.008485
# 33                     1         0.008180
# 9                      1         0.007477
# 15                     0         0.005292
# 12                     0         0.004938
# 23                     0         0.003800
# 32                     0         0.003500
# 36                     0         0.003172
# 2                      0         0.003124
# 4                      0         0.002996
# 27                     0         0.002905

# %% [markdown]
# ## 1.4 What proteins/genes are in pathways of known COVID-19 related genes? Which of these can be related to symptoms?
# ### 1.4.1 Genes (from 1.1.1) -> Pathways -> Genes

# %% [markdown]
# ### 1.4.2 COVID-19 Symptoms -> Pathways -> Genes

# %%
for x in symptom_and_phenotype_list:
#     print(x)
    if(ht.query(x)['PhenotypicFeature']):
        print(ht.query(x)['PhenotypicFeature'])

# %%
disease_symptom_list = []
for x in symptom_and_phenotype_list:
#     print(x)
    res = ht.query(x)['Disease']
    if(res):
        for y in res:
            if y['name'].lower() == x:
                disease_symptom_list.append(y)
disease_symptom_list
# Out:
# [{'MONDO': 'MONDO:0002258',
#   'DOID': 'DOID:2275',
#   'UMLS': 'C0031350',
#   'name': 'pharyngitis',
#   'MESH': 'D010612',
#   'primary': {'identifier': 'MONDO',
#    'cls': 'Disease',
#    'value': 'MONDO:0002258'},
#   'display': 'MONDO(MONDO:0002258) DOID(DOID:2275) UMLS(C0031350) MESH(D010612) name(pharyngitis)',
#   'type': 'Disease'},
#  {'MONDO': 'C0015967',
#   'UMLS': 'C0015967',
#   'name': 'Fever',
#   'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'C0015967'},
#   'display': 'MONDO(C0015967) UMLS(C0015967) name(Fever)',
#   'type': 'Disease'},
#  {'MONDO': 'MONDO:0002492',
#   'DOID': 'DOID:3021',
#   'UMLS': 'C0022660',
#   'name': 'acute kidney failure',
#   'MESH': 'D058186',
#   'primary': {'identifier': 'MONDO',
#    'cls': 'Disease',
#    'value': 'MONDO:0002492'},
#   'display': 'MONDO(MONDO:0002492) DOID(DOID:3021) UMLS(C0022660) MESH(D058186) name(acute kidney failure)',
#   'type': 'Disease'},
#  {'MONDO': 'C0018681',
#   'UMLS': 'C0018681',
#   'name': 'Headache',
#   'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'C0018681'},
#   'display': 'MONDO(C0018681) UMLS(C0018681) name(Headache)',
#   'type': 'Disease'},
#  {'MONDO': 'C0476273',
#   'UMLS': 'C0476273',
#   'name': 'Respiratory distress',
#   'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'C0476273'},
#   'display': 'MONDO(C0476273) UMLS(C0476273) name(Respiratory distress)',
#   'type': 'Disease'},
#  {'MONDO': 'C0013404',
#   'UMLS': 'C0013404',
#   'name': 'Dyspnea',
#   'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'C0013404'},
#   'display': 'MONDO(C0013404) UMLS(C0013404) name(Dyspnea)',
#   'type': 'Disease'},
#  {'MONDO': 'C0010200',
#   'UMLS': 'C0010200',
#   'name': 'Coughing',
#   'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'C0010200'},
#   'display': 'MONDO(C0010200) UMLS(C0010200) name(Coughing)',
#   'type': 'Disease'},
#  {'MONDO': 'C0746102',
#   'UMLS': 'C0746102',
#   'name': 'Chronic lung disease',
#   'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'C0746102'},
#   'display': 'MONDO(C0746102) UMLS(C0746102) name(Chronic lung disease)',
#   'type': 'Disease'},
#  {'MONDO': 'C0700292',
#   'UMLS': 'C0700292',
#   'name': 'Hypoxemia',
#   'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'C0700292'},
#   'display': 'MONDO(C0700292) UMLS(C0700292) name(Hypoxemia)',
#   'type': 'Disease'}]

# %%
symptom_and_phenotype_list
# Out:
# ['pharyngitis',
#  'fever',
#  'hyperthermia',
#  'pyrexia',
#  'diabetes mellitus',
#  'acute kidney injury',
#  'acute kidney failure',
#  'acute renal failure',
#  'immunodeficiency',
#  'decreased immune function',
#  'immune deficiency',
#  'headache',
#  'headaches',
#  'respiratory distress',
#  'breathing difficulties',
#  'difficulty breathing',
#  'respiratory difficulties',
#  'dyspnea',
#  'abnormal breathing',
#  'breathing difficulty',
#  'difficult to breathe',
#  'dyspnoea',
#  'trouble breathing',
#  'respiratory failure requiring assisted ventilation',
#  'respiratory distress necessitating mechanical ventilation',
#  'respiratory distress requiring endotracheal intubation',
#  'respiratory distress requiring mechanical ventilation',
#  'acute infectious pneumonia',
#  'cough',
#  'coughing',
#  'chronic lung disease',
#  'hypoxemia',
#  'low blood oxygen level',
#  'myalgia',
#  'muscle ache',
#  'muscle pain']
