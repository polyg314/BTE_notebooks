# %%
import gene_symptoms_question_functions as gsf
import importlib
import requests
importlib.reload(gsf)

from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %%
def get_disease_symptoms(disease_name):
    r = requests.get('http://mydisease.info/v1/query?q=hpo.disease_name:"' + disease_name + '"&fields=hpo')
    res = r.json()
    # print(res)
    result_number = 0
    disease_info = res['hits'][result_number]
    print("disease symptoms for:")
    print(disease_info['hpo']['disease_name'])
    symptoms = []
    hp_ids = []
    hp_symptom_dict = {}
    for x in disease_info['hpo']['phenotype_related_to_disease']:
        # print(x)
#         print(x['aspect'])
#         if((x['aspect'].lower() == 'p')):
        if('frequency' in x):
            r1 = requests.get('https://biothings.ncats.io/hpo/phenotype/' + x['frequency'])
            res1 = r1.json()
#                 print(res1)
#             print(res1['name'])
# #                 in this case, only list symptoms if they are "frequent" or more. 
#             if 'very frequent' in res1['name'].lower():
            r = requests.get('https://biothings.ncats.io/hpo/phenotype/' + x['hpo_id'])
            res = r.json()
#             print(res['name'])
            if(('_id' in res) & ('name' in res)):
                symptoms.append(res['name'].lower())
                hp_ids.append(res['_id'])
                hp_symptom_dict[res['_id']] = {
                    'names' : [res['name'].lower()],
                    'frequency' : res1['name'],
                    'edges_out_count' : 0
                }
            if('synonym' in res):
                for z in res['synonym']:
                    if('EXACT' in z):
                        name = z.split('"')[1].lower()
                        if name not in symptoms: 
                            symptoms.append(name)
                            hp_symptom_dict[res['_id']].append(name)

    print(symptoms)
    return([symptoms,hp_ids,hp_symptom_dict])

# %%
current_symtpoms = get_disease_symptoms("Xeroderma Pigmentosum")
xp_symptom_dict = current_symtpoms[2]
symptom_list = current_symtpoms[0]
# Out:
# disease symptoms for:
# Xeroderma pigmentosum
# ['cryptorchidism', 'hypogonadism', 'abnormality of the dentition', 'microcephaly', 'hearing impairment', 'sensorineural hearing impairment', 'strabismus', 'keratitis', 'blepharitis', 'cataract', 'conjunctival telangiectasia', 'photophobia', 'entropion', 'optic atrophy', 'ectropion', 'dry skin', 'hyperkeratosis', 'thin skin', 'cutaneous photosensitivity', 'melanocytic nevus', 'telangiectasia', 'poikiloderma', 'hypermelanotic macule', 'hypopigmented skin patches', 'pterygium', 'thickened skin', 'seizure', 'ataxia', 'spasticity', 'reduced tendon reflexes', 'freckling', 'failure to thrive', 'alopecia', 'fever', 'abnormality of extrapyramidal motor function', 'cerebral cortical atrophy', 'eeg abnormality', 'developmental regression', 'neoplasm', 'delayed skeletal maturation', 'arthralgia', 'melanoma', 'aminoaciduria', 'short stature', 'dermal atrophy', 'craniofacial hyperostosis', 'intellectual disability, progressive', 'opacification of the corneal stroma', 'decreased testicular size', 'ankyloblepharon', 'peripheral neuropathy', 'flat nasal alae', 'erythema', 'fatigue', 'macule', 'papilloma', 'neoplasm of the eye', 'cognitive impairment', 'telangiectasia of the skin']

# %%
disease_name = "XERODERMA PIGMENTOSUM"

def get_symtpom_prevalence(hp_symptom_dict):
    for key in hp_symptom_dict:
        edges_out_count = 0
        for y in ['Disease','BiologicalProcess','PhenotypicFeature']:
            if y == 'PhenotypicFeature':
                a = ht.query(key)[y]
                if len(a) > 0: 
                    b = a[0]
                    try: 
                        fc = FindConnection(input_obj=b, output_obj='Disease', intermediate_nodes=None)
                        fc.connect(verbose=False)
                        df = fc.display_table_view()
                        print("phen")
                        print(hp_symptom_dict[key])
                        print(df.shape[0])
                        if(df.shape[0] > 0):
                            df = df[df["output_name"] != disease_name]
                            edges_out_count = edges_out_count + df.shape[0]
#                         print(df.shape)
                    except: 
                        print("Nope")
            if y == 'Disease' or y == 'BiologicalProcess':
                for z in hp_symptom_dict[key]["names"]:
                    a = ht.query(z)[y]
                    for b in a: 
                        if b['name'] == z:
                            print('match')
                            print(b)
                            print(z)
                            try: 
                                fc = FindConnection(input_obj=b, output_obj='Disease', intermediate_nodes=None)
                                fc.connect(verbose=False)
                                df = fc.display_table_view()
                                print("BD")
                                print(df.shape[0])
                                if(df.shape[0] > 0):
                                    df = df[df["output_name"] != disease_name]
                                    edges_out_count = edges_out_count + df.shape[0]
    #                             print(df.shape)
                            except: 
                                print("Nope")

        hp_symptom_dict[key]["edges_out_count"] = edges_out_count
    return(hp_symptom_dict)
            
xp_symptom_dict = get_symtpom_prevalence(xp_symptom_dict)
# Out:
# BD
# 0
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['cryptorchidism'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 345
# BD
# 231
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# phen
# {'names': ['hypogonadism'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 219
# BD
# 39
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['abnormality of the dentition'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 243
# BD
# 0
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# phen
# {'names': ['microcephaly'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 318
# BD
# 0
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['hearing impairment'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 323
# BD
# 0
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['sensorineural hearing impairment'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 343
# Nope
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['strabismus'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 331
# BD
# 105
# API 3.9 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# phen
# {'names': ['keratitis'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 108
# Nope
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['blepharitis'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 49
# BD
# 0
# API 3.13 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['cataract'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 346
# BD
# 1
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['conjunctival telangiectasia'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 28
# BD
# 0
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['photophobia'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 327
# Nope
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['entropion'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 37
# BD
# 0
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['optic atrophy'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 385
# Nope
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['ectropion'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 74
# BD
# 0
# API 3.19 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# phen
# {'names': ['dry skin'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 218
# BD
# 276
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['hyperkeratosis'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 215
# BD
# 0
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['thin skin'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 130
# BD
# 0
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['cutaneous photosensitivity'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 136
# BD
# 40
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# phen
# {'names': ['melanocytic nevus'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 164
# BD
# 5
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['telangiectasia'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 165
# BD
# 0
# API 3.13 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['poikiloderma'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 36
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['hypermelanotic macule'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 71
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# phen
# {'names': ['hypopigmented skin patches'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 90
# BD
# 0
# API 3.10 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# phen
# {'names': ['pterygium'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 48
# BD
# 0
# API 3.11 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['thickened skin'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 150
# BD
# 15
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['seizure'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 270
# BD
# 0
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['ataxia'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 305
# BD
# 0
# API 3.7 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['spasticity'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 321
# BD
# 0
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['reduced tendon reflexes'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 160
# BD
# 0
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# phen
# {'names': ['freckling'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 52
# BD
# 0
# API 3.1 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['failure to thrive'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 367
# BD
# 0
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# phen
# {'names': ['alopecia'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 293
# BD
# 474
# BD
# 0
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['fever'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 273
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['abnormality of extrapyramidal motor function'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 185
# API 3.1 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# phen
# {'names': ['cerebral cortical atrophy'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 692
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['eeg abnormality'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 277
# BD
# 0
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# phen
# {'names': ['developmental regression'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 305
# Nope
# BD
# 0
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['neoplasm'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 125
# BD
# 0
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# phen
# {'names': ['delayed skeletal maturation'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 352
# BD
# 469
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# phen
# {'names': ['arthralgia'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 266
# Nope
# BD
# 0
# API 3.1 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['melanoma'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 65
# BD
# 0
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# phen
# {'names': ['aminoaciduria'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 211
# BD
# 0
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['short stature'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 272
# API 3.7 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['dermal atrophy'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 144
# API 3.9 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['craniofacial hyperostosis'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 32
# BD
# 0
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['intellectual disability, progressive'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 133
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# phen
# {'names': ['opacification of the corneal stroma'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 167
# API 3.10 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# phen
# {'names': ['decreased testicular size'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 188
# BD
# 4
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# phen
# {'names': ['ankyloblepharon'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 21
# BD
# 313
# API 3.6 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['peripheral neuropathy'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 335
# API 3.7 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# phen
# {'names': ['flat nasal alae'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 3
# BD
# 180
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# phen
# {'names': ['erythema'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 194
# BD
# 515
# BD
# 0
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['fatigue'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 236
# BD
# 378
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['macule'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 100
# BD
# 38
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# phen
# {'names': ['papilloma'], 'frequency': 'Frequent', 'edges_out_count': 0}
# 36
# BD
# 0
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# phen
# {'names': ['neoplasm of the eye'], 'frequency': 'Occasional', 'edges_out_count': 0}
# 32
# BD
# 0
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# phen
# {'names': ['cognitive impairment'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 217
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# phen
# {'names': ['telangiectasia of the skin'], 'frequency': 'Very frequent', 'edges_out_count': 0}
# 78

# %%
xp_symptom_dict
# Out:
# {'HP:0000028': {'names': ['cryptorchidism'],
#   'frequency': 'Frequent',
#   'edges_out_count': 345},
#  'HP:0000135': {'names': ['hypogonadism'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 450},
#  'HP:0000164': {'names': ['abnormality of the dentition'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 282},
#  'HP:0000252': {'names': ['microcephaly'],
#   'frequency': 'Occasional',
#   'edges_out_count': 318},
#  'HP:0000365': {'names': ['hearing impairment'],
#   'frequency': 'Occasional',
#   'edges_out_count': 323},
#  'HP:0000407': {'names': ['sensorineural hearing impairment'],
#   'frequency': 'Frequent',
#   'edges_out_count': 343},
#  'HP:0000486': {'names': ['strabismus'],
#   'frequency': 'Frequent',
#   'edges_out_count': 331},
#  'HP:0000491': {'names': ['keratitis'],
#   'frequency': 'Frequent',
#   'edges_out_count': 213},
#  'HP:0000498': {'names': ['blepharitis'],
#   'frequency': 'Occasional',
#   'edges_out_count': 49},
#  'HP:0000518': {'names': ['cataract'],
#   'frequency': 'Frequent',
#   'edges_out_count': 346},
#  'HP:0000524': {'names': ['conjunctival telangiectasia'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 29},
#  'HP:0000613': {'names': ['photophobia'],
#   'frequency': 'Occasional',
#   'edges_out_count': 327},
#  'HP:0000621': {'names': ['entropion'],
#   'frequency': 'Occasional',
#   'edges_out_count': 37},
#  'HP:0000648': {'names': ['optic atrophy'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 385},
#  'HP:0000656': {'names': ['ectropion'],
#   'frequency': 'Occasional',
#   'edges_out_count': 74},
#  'HP:0000958': {'names': ['dry skin'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 218},
#  'HP:0000962': {'names': ['hyperkeratosis'],
#   'frequency': 'Frequent',
#   'edges_out_count': 491},
#  'HP:0000963': {'names': ['thin skin'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 130},
#  'HP:0000992': {'names': ['cutaneous photosensitivity'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 136},
#  'HP:0000995': {'names': ['melanocytic nevus'],
#   'frequency': 'Occasional',
#   'edges_out_count': 204},
#  'HP:0001009': {'names': ['telangiectasia'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 170},
#  'HP:0001029': {'names': ['poikiloderma'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 36},
#  'HP:0001034': {'names': ['hypermelanotic macule'],
#   'frequency': 'Frequent',
#   'edges_out_count': 71},
#  'HP:0001053': {'names': ['hypopigmented skin patches'],
#   'frequency': 'Frequent',
#   'edges_out_count': 90},
#  'HP:0001059': {'names': ['pterygium'],
#   'frequency': 'Occasional',
#   'edges_out_count': 48},
#  'HP:0001072': {'names': ['thickened skin'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 150},
#  'HP:0001250': {'names': ['seizure'],
#   'frequency': 'Occasional',
#   'edges_out_count': 285},
#  'HP:0001251': {'names': ['ataxia'],
#   'frequency': 'Occasional',
#   'edges_out_count': 305},
#  'HP:0001257': {'names': ['spasticity'],
#   'frequency': 'Occasional',
#   'edges_out_count': 321},
#  'HP:0001315': {'names': ['reduced tendon reflexes'],
#   'frequency': 'Occasional',
#   'edges_out_count': 160},
#  'HP:0001480': {'names': ['freckling'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 52},
#  'HP:0001508': {'names': ['failure to thrive'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 367},
#  'HP:0001596': {'names': ['alopecia'],
#   'frequency': 'Occasional',
#   'edges_out_count': 293},
#  'HP:0001945': {'names': ['fever'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 747},
#  'HP:0002071': {'names': ['abnormality of extrapyramidal motor function'],
#   'frequency': 'Occasional',
#   'edges_out_count': 185},
#  'HP:0002120': {'names': ['cerebral cortical atrophy'],
#   'frequency': 'Occasional',
#   'edges_out_count': 692},
#  'HP:0002353': {'names': ['eeg abnormality'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 277},
#  'HP:0002376': {'names': ['developmental regression'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 305},
#  'HP:0002664': {'names': ['neoplasm'],
#   'frequency': 'Occasional',
#   'edges_out_count': 125},
#  'HP:0002750': {'names': ['delayed skeletal maturation'],
#   'frequency': 'Occasional',
#   'edges_out_count': 352},
#  'HP:0002829': {'names': ['arthralgia'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 735},
#  'HP:0002861': {'names': ['melanoma'],
#   'frequency': 'Frequent',
#   'edges_out_count': 65},
#  'HP:0003355': {'names': ['aminoaciduria'],
#   'frequency': 'Occasional',
#   'edges_out_count': 211},
#  'HP:0004322': {'names': ['short stature'],
#   'frequency': 'Occasional',
#   'edges_out_count': 272},
#  'HP:0004334': {'names': ['dermal atrophy'],
#   'frequency': 'Frequent',
#   'edges_out_count': 144},
#  'HP:0004493': {'names': ['craniofacial hyperostosis'],
#   'frequency': 'Occasional',
#   'edges_out_count': 32},
#  'HP:0006887': {'names': ['intellectual disability, progressive'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 133},
#  'HP:0007759': {'names': ['opacification of the corneal stroma'],
#   'frequency': 'Occasional',
#   'edges_out_count': 167},
#  'HP:0008734': {'names': ['decreased testicular size'],
#   'frequency': 'Occasional',
#   'edges_out_count': 188},
#  'HP:0009755': {'names': ['ankyloblepharon'],
#   'frequency': 'Occasional',
#   'edges_out_count': 25},
#  'HP:0009830': {'names': ['peripheral neuropathy'],
#   'frequency': 'Occasional',
#   'edges_out_count': 648},
#  'HP:0010649': {'names': ['flat nasal alae'],
#   'frequency': 'Occasional',
#   'edges_out_count': 3},
#  'HP:0010783': {'names': ['erythema'],
#   'frequency': 'Frequent',
#   'edges_out_count': 374},
#  'HP:0012378': {'names': ['fatigue'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 751},
#  'HP:0012733': {'names': ['macule'],
#   'frequency': 'Frequent',
#   'edges_out_count': 478},
#  'HP:0012740': {'names': ['papilloma'],
#   'frequency': 'Frequent',
#   'edges_out_count': 74},
#  'HP:0100012': {'names': ['neoplasm of the eye'],
#   'frequency': 'Occasional',
#   'edges_out_count': 32},
#  'HP:0100543': {'names': ['cognitive impairment'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 217},
#  'HP:0100585': {'names': ['telangiectasia of the skin'],
#   'frequency': 'Very frequent',
#   'edges_out_count': 78}}

# %%
list(df["output_name"].str.contains('XER'))
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
result = ht.query('fever')['Disease']
for g in result: 
    if g['name'] == 'fever':
        print(g)

# %%
x = 'optic atrophy'
print(x)
a = ht.query(x)["Disease"]
print(a)
if len(a) > 0: 
    b = a[0]
    try: 
        fc = FindConnection(input_obj=b, output_obj='Disease', intermediate_nodes=None)
        fc.connect(verbose=False)
        df = fc.display_table_view()
        print(df.shape)
    except: 
        pass
# Out:
# optic atrophy
# [{'MONDO': 'MONDO:0003608', 'DOID': 'DOID:5723', 'UMLS': 'C1744705', 'name': 'optic atrophy', 'MESH': 'D009896', 'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'MONDO:0003608'}, 'display': 'MONDO(MONDO:0003608) DOID(DOID:5723) UMLS(C1744705) MESH(D009896) name(optic atrophy)', 'type': 'Disease'}, {'MONDO': 'MONDO:0024569', 'name': 'optic atrophy 8', 'OMIM': '616648', 'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'MONDO:0024569'}, 'display': 'MONDO(MONDO:0024569) OMIM(616648) name(optic atrophy 8)', 'type': 'Disease'}, {'MONDO': 'MONDO:0009786', 'name': 'optic atrophy 6', 'MESH': 'C537127', 'OMIM': '258500', 'ORPHANET': '99012', 'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'MONDO:0009786'}, 'display': 'MONDO(MONDO:0009786) OMIM(258500) ORPHANET(99012) MESH(C537127) name(optic atrophy 6)', 'type': 'Disease'}, {'MONDO': 'MONDO:0011536', 'UMLS': 'C1854430', 'name': 'optic atrophy 4', 'MESH': 'C565343', 'OMIM': '605293', 'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'MONDO:0011536'}, 'display': 'MONDO(MONDO:0011536) OMIM(605293) UMLS(C1854430) MESH(C565343) name(optic atrophy 4)', 'type': 'Disease'}, {'MONDO': 'MONDO:0001084', 'DOID': 'DOID:10627', 'UMLS': 'C0155291', 'name': 'primary optic atrophy', 'primary': {'identifier': 'MONDO', 'cls': 'Disease', 'value': 'MONDO:0001084'}, 'display': 'MONDO(MONDO:0001084) DOID(DOID:10627) UMLS(C0155291) name(primary optic atrophy)', 'type': 'Disease'}]

# %%
df
# Out:
#                                    input input_type          pred1  \
# 0  CONJUNCTIVAL TELANGIECTASIA (DISEASE)    Disease  coexists_with
#
#   pred1_source           pred1_api pred1_pubmed output_type  \
# 0       SEMMED  SEMMED Disease API       627106     Disease
#
#          output_name            output_id
# 0  SYNDROMIC DISEASE  MONDO:MONDO:0002254

# %%
ht.query('fever')
# Out:
# {'Gene': [{'NCBIGene': '101910199',
#    'name': 'Plasmodium falciparum fever episodes QTL1',
#    'SYMBOL': 'PFFE1',
#    'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '101910199'},
#    'display': 'NCBIGene(101910199) SYMBOL(PFFE1)',
#    'type': 'Gene'}],
#  'SequenceVariant': [],
#  'ChemicalSubstance': [{'CHEMBL.COMPOUND': 'CHEMBL2108816',
#    'name': 'YELLOW FEVER VACCINE',
#    'primary': {'identifier': 'CHEMBL.COMPOUND',
#     'cls': 'ChemicalSubstance',
#     'value': 'CHEMBL2108816'},
#    'display': 'CHEMBL.COMPOUND(CHEMBL2108816) name(YELLOW FEVER VACCINE)',
#    'type': 'ChemicalSubstance'},
#   {'DRUGBANK': 'DB10805',
#    'name': 'Yellow Fever Vaccine',
#    'primary': {'identifier': 'DRUGBANK',
#     'cls': 'ChemicalSubstance',
#     'value': 'DB10805'},
#    'display': 'DRUGBANK(DB10805) name(Yellow Fever Vaccine)',
#    'type': 'ChemicalSubstance'},
#   {'CHEMBL.COMPOUND': 'CHEMBL2108762',
#    'name': 'ROCKY MOUNTAIN SPOTTED FEVER VACCINE',
#    'primary': {'identifier': 'CHEMBL.COMPOUND',
#     'cls': 'ChemicalSubstance',
#     'value': 'CHEMBL2108762'},
#    'display': 'CHEMBL.COMPOUND(CHEMBL2108762) name(ROCKY MOUNTAIN SPOTTED FEVER VACCINE)',
#    'type': 'ChemicalSubstance'},
#   {'CHEMBL.COMPOUND': 'CHEMBL2108770',
#    'name': 'SCARLET FEVER STREPTOCOCCUS TOXIN',
#    'primary': {'identifier': 'CHEMBL.COMPOUND',
#     'cls': 'ChemicalSubstance',
#     'value': 'CHEMBL2108770'},
#    'display': 'CHEMBL.COMPOUND(CHEMBL2108770) name(SCARLET FEVER STREPTOCOCCUS TOXIN)',
#    'type': 'ChemicalSubstance'},
#   {'name': 'Yellow fever vaccines',
#    'primary': {'identifier': 'name',
#     'cls': 'ChemicalSubstance',
#     'value': 'Yellow fever vaccines'},
#    'display': 'name(Yellow fever vaccines)',
#    'type': 'ChemicalSubstance'}],
#  'Disease': [{'MONDO': 'MONDO:0005683',
#    'DOID': 'DOID:11077',
#    'UMLS': 'C0006309',
#    'name': 'brucellosis',
#    'MESH': 'D002006',
#    'ORPHANET': '1304',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0005683'},
#    'display': 'MONDO(MONDO:0005683) DOID(DOID:11077) ORPHANET(1304) UMLS(C0006309) MESH(D002006) name(brucellosis)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0001195',
#    'DOID': 'DOID:11104',
#    'UMLS': 'C0038041',
#    'name': 'spotted fever',
#    'MESH': 'D000073605',
#    'ORPHANET': '102022',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0001195'},
#    'display': 'MONDO(MONDO:0001195) DOID(DOID:11104) ORPHANET(102022) UMLS(C0038041) MESH(D000073605) name(spotted fever)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0018626',
#    'DOID': 'DOID:3055',
#    'UMLS': 'C0343375',
#    'name': 'paratyphoid fever',
#    'MESH': 'D010284',
#    'ORPHANET': '443227',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0018626'},
#    'display': 'MONDO(MONDO:0018626) DOID(DOID:3055) ORPHANET(443227) UMLS(C0343375) MESH(D010284) name(paratyphoid fever)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0020533',
#    'DOID': 'DOID:13238',
#    'UMLS': 'CN207435',
#    'name': 'streptobacillary rat-bite fever',
#    'ORPHANET': '99905',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0020533'},
#    'display': 'MONDO(MONDO:0020533) DOID(DOID:13238) ORPHANET(99905) UMLS(CN207435) name(streptobacillary rat-bite fever)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0020501',
#    'DOID': 'DOID:12287',
#    'UMLS': 'C1304456',
#    'name': 'Crimean-Congo hemorrhagic fever',
#    'MESH': 'D006479',
#    'ORPHANET': '99827',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0020501'},
#    'display': 'MONDO(MONDO:0020501) DOID(DOID:12287) ORPHANET(99827) UMLS(C1304456) MESH(D006479) name(Crimean-Congo hemorrhagic fever)',
#    'type': 'Disease'}],
#  'PhenotypicFeature': [{'UMLS': 'C0239574',
#    'HP': 'HP:0011134',
#    'name': 'Low-grade fever',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0239574'},
#    'display': 'UMLS(C0239574) HP(HP:0011134) name(Low-grade fever)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C0015967',
#    'HP': 'HP:0001945',
#    'MESH': 'D005334',
#    'name': 'Fever',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0015967'},
#    'display': 'UMLS(C0015967) HP(HP:0001945) MESH(D005334) name(Fever)',
#    'type': 'PhenotypicFeature'},
#   {'HP': 'HP:0032894',
#    'name': 'Seizure precipitated by febrile infection',
#    'primary': {'identifier': 'HP',
#     'cls': 'PhenotypicFeature',
#     'value': 'HP:0032894'},
#    'display': 'HP(HP:0032894) name(Seizure precipitated by febrile infection)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C0847614',
#    'HP': 'HP:0003193',
#    'MESH': 'D065631',
#    'name': 'Allergic rhinitis',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0847614'},
#    'display': 'UMLS(C0847614) HP(HP:0003193) MESH(D065631) name(Allergic rhinitis)',
#    'type': 'PhenotypicFeature'},
#   {'UMLS': 'C0277799',
#    'HP': 'HP:0001954',
#    'name': 'Recurrent fever',
#    'primary': {'identifier': 'UMLS',
#     'cls': 'PhenotypicFeature',
#     'value': 'C0277799'},
#    'display': 'UMLS(C0277799) HP(HP:0001954) name(Recurrent fever)',
#    'type': 'PhenotypicFeature'}],
#  'MolecularActivity': [],
#  'BiologicalProcess': [{'GO': 'GO:0031621',
#    'name': 'negative regulation of fever generation',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0031621'},
#    'display': 'GO(GO:0031621) name(negative regulation of fever generation)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0031622',
#    'name': 'positive regulation of fever generation',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0031622'},
#    'display': 'GO(GO:0031622) name(positive regulation of fever generation)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0001660',
#    'name': 'fever generation',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0001660'},
#    'display': 'GO(GO:0001660) name(fever generation)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0031620',
#    'name': 'regulation of fever generation',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0031620'},
#    'display': 'GO(GO:0031620) name(regulation of fever generation)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0100011',
#    'name': 'positive regulation of fever generation by prostaglandin secretion',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0100011'},
#    'display': 'GO(GO:0100011) name(positive regulation of fever generation by prostaglandin secretion)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0001660',
#    'name': 'fever generation',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0001660'},
#    'display': 'GO(GO:0001660) name(fever generation)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0031620',
#    'name': 'regulation of fever generation',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0031620'},
#    'display': 'GO(GO:0031620) name(regulation of fever generation)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0031622',
#    'name': 'positive regulation of fever generation',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0031622'},
#    'display': 'GO(GO:0031622) name(positive regulation of fever generation)',
#    'type': 'BiologicalProcess'},
#   {'GO': 'GO:0071812',
#    'name': 'positive regulation of fever generation by positive regulation of prostaglandin secretion',
#    'primary': {'identifier': 'GO',
#     'cls': 'BiologicalProcess',
#     'value': 'GO:0071812'},
#    'display': 'GO(GO:0071812) name(positive regulation of fever generation by positive regulation of prostaglandin secretion)',
#    'type': 'BiologicalProcess'}],
#  'CellularComponent': [],
#  'Pathway': [],
#  'AnatomicalEntity': [],
#  'Cell': []}

# %%
'telangiectasia of the skin'.upper()
# Out:
# 'TELANGIECTASIA OF THE SKIN'

# %%
# get disease 
xp = ht.query("Xeroderma Pigmentosum")['Disease'][0]
xp
# Out:
# {'MONDO': 'MONDO:0019600',
#  'DOID': 'DOID:0050427',
#  'UMLS': 'C0043346',
#  'name': 'xeroderma pigmentosum',
#  'MESH': 'D014983',
#  'ORPHANET': '910',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0019600'},
#  'display': 'MONDO(MONDO:0019600) DOID(DOID:0050427) ORPHANET(910) UMLS(C0043346) MESH(D014983) name(xeroderma pigmentosum)',
#  'type': 'Disease'}

# %%
xp_to_symp = FindConnection(input_obj=xp, output_obj='Disease', intermediate_nodes=None)
fc.connect(verbose=False)
df = fc.display_table_view()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
xp_to_symp = FindConnection(input_obj=xp, output_obj='PhenotypicFeature', intermediate_nodes=None)
fc.connect(verbose=False)
df = fc.display_table_view()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
xp_to_symp = FindConnection(input_obj=xp, output_obj='BiologicalProcess', intermediate_nodes=None)
fc.connect(verbose=False)
df = fc.display_table_view()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Out:
# {'Gene': [],
#  'SequenceVariant': [],
#  'ChemicalSubstance': [],
#  'Disease': [{'MONDO': 'MONDO:0019600',
#    'DOID': 'DOID:0050427',
#    'UMLS': 'C0043346',
#    'name': 'xeroderma pigmentosum',
#    'MESH': 'D014983',
#    'ORPHANET': '910',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0019600'},
#    'display': 'MONDO(MONDO:0019600) DOID(DOID:0050427) ORPHANET(910) UMLS(C0043346) MESH(D014983) name(xeroderma pigmentosum)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0010210',
#    'DOID': 'DOID:0110843',
#    'UMLS': 'C0268135',
#    'name': 'xeroderma pigmentosum group A',
#    'OMIM': '278700',
#    'ORPHANET': '276249',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0010210'},
#    'display': 'MONDO(MONDO:0010210) DOID(DOID:0110843) OMIM(278700) ORPHANET(276249) UMLS(C0268135) name(xeroderma pigmentosum group A)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0010211',
#    'DOID': 'DOID:0110844',
#    'UMLS': 'C2752147',
#    'name': 'xeroderma pigmentosum group C',
#    'MESH': 'C567886',
#    'OMIM': '278720',
#    'ORPHANET': '276255',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0010211'},
#    'display': 'MONDO(MONDO:0010211) DOID(DOID:0110844) OMIM(278720) ORPHANET(276255) UMLS(C2752147) MESH(C567886) name(xeroderma pigmentosum group C)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0010212',
#    'DOID': 'DOID:0110845',
#    'UMLS': 'C0268138',
#    'name': 'xeroderma pigmentosum group D',
#    'MESH': 'C562591',
#    'OMIM': '278730',
#    'ORPHANET': '276258',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0010212'},
#    'display': 'MONDO(MONDO:0010212) DOID(DOID:0110845) OMIM(278730) ORPHANET(276258) UMLS(C0268138) MESH(C562591) name(xeroderma pigmentosum group D)',
#    'type': 'Disease'},
#   {'MONDO': 'MONDO:0010213',
#    'DOID': 'DOID:0110846',
#    'UMLS': 'C1848411',
#    'name': 'xeroderma pigmentosum group E',
#    'MESH': 'C564732',
#    'OMIM': '278740',
#    'ORPHANET': '276261',
#    'primary': {'identifier': 'MONDO',
#     'cls': 'Disease',
#     'value': 'MONDO:0010213'},
#    'display': 'MONDO(MONDO:0010213) DOID(DOID:0110846) OMIM(278740) ORPHANET(276261) UMLS(C1848411) MESH(C564732) name(xeroderma pigmentosum group E)',
#    'type': 'Disease'}],
#  'MolecularActivity': [],
#  'BiologicalProcess': [],
#  'CellularComponent': [],
#  'Pathway': [],
#  'AnatomicalEntity': [],
#  'PhenotypicFeature': []}
