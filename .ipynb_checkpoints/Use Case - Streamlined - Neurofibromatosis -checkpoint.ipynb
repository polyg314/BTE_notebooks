# %% [markdown]
# ## Imports

# %%
## main functions
import gene_symptoms_question_functions as gsf
## importlib makes sure functions from packages get refreshed
import importlib
import requests
importlib.reload(gsf)
import pandas as pd
import math
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %% [markdown]
# ## Set disease and output names

# %%
disease_name = 'Neurofibromatosis'
output_csv = "Neurofibromatosis_2020-08-27.csv"
symptom_csv = "Neurofibromatosis_Symptoms_2020-08-27.csv"

# %% [markdown]
# ## Get disease

# %%
disease_name = disease_name.lower()
disease = ht.query(disease_name)['Disease'][0]
disease
# Out:
# {'MONDO': 'MONDO:0021061',
#  'DOID': 'DOID:8712',
#  'UMLS': 'C0162678',
#  'name': 'neurofibromatosis',
#  'MESH': 'D017253',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0021061'},
#  'display': 'MONDO(MONDO:0021061) DOID(DOID:8712) UMLS(C0162678) MESH(D017253) name(neurofibromatosis)',
#  'type': 'Disease'}

# %% [markdown]
# ## Get disease symptoms

# %%
# get disease symptoms
disease_symptoms_list = gsf.get_disease_symptoms(disease_name)
disease_symptoms = disease_symptoms_list[0]
disease_symptom_hpids = disease_symptoms_list[1]
disease_symptom_dict = disease_symptoms_list[2]
disease_symptoms
disease_symptom_hpids
# Out:
# ['epicanthus', 'Epicanthal fold', 'Epicanthal folds', 'Epicanthic folds', 'Eye folds', 'Palpebronasal fold', 'Plica palpebronasalis', 'Prominent eye folds', 'short stature', 'Decreased body height', 'Height less than 3rd percentile', 'Short stature', 'Small stature', 'Stature below 3rd percentile', 'low posterior hairline', 'Low hairline at back of neck', 'Low posterior hair line', 'prominent nasolabial fold', 'Deep laugh lines', 'Deep nasolabial crease', 'Deep nasolabial fold', 'Deep nasolabial groove', 'Deep smile lines', 'Nasolabial crease, prominent', 'Prominent laugh lines', 'Prominent nasolabial groove', 'Prominent smile lines', 'superior pectus carinatum', 'Pectus carinatum superiorly', 'thick vermilion border', 'Full lips', 'Increased volume of lip', 'Increased volume of lip vermillion', 'Plump lips', 'Prominent lips', 'Thick lips', 'pectus excavatum of inferior sternum', 'Pectus excavatum inferiorly', 'hypertelorism', 'Excessive orbital separation', 'Increased distance between eye sockets', 'Increased distance between eyes', 'Increased interpupillary distance', 'Ocular hypertelorism', 'Wide-set eyes', 'Widely spaced eyes', 'Widened interpupillary distance', 'specific learning disability', 'axillary freckling', 'multiple cafe-au-lait spots', 'muscle weakness', 'Muscle weakness', 'Muscular weakness', 'macrocephaly', 'Increased size of cranium', 'Increased size of skull', 'Large head', 'Large head circumference', 'Macrocrania', 'Megacephaly', 'pulmonic stenosis', 'Narrowing of pulmonic valve', 'Pulmonary stenosis', 'Pulmonary valve stenosis', 'Pulmonic valve stenosis', 'posteriorly rotated ears', 'Ear, posterior angulation, increased', 'Ears rotated toward back of head', 'Posteriorly angulated ears', 'Posteriorly rotated', 'Posteriorly rotated auricles', 'Posteriorly-angulated ears', 'Posteriorly-rotated ears', 'intellectual disability', 'Intellectual disability', 'Mental deficiency', 'Mental retardation', 'Mental retardation, nonspecific', 'Mental-retardation', 'Nonprogressive intellectual disability', 'Nonprogressive mental retardation', 'neuroblastoma', 'Cancer of early nerve cells', 'neurofibromas', 'Neurofibromata', 'Neurofibromatosis', 'downslanted palpebral fissures', 'Antimongoloid eye slant', 'Antimongoloid slant of palpebral fissures', 'Antimongoloid slanted palpebral fissures', 'Down slanting palpebral fissures', 'Down-slanted palpebral fissures', 'Down-slanting palpebral fissure', 'Down-slanting palpebral fissures', 'Downslanting palpebral fissure', 'Downslanting palpebral fissures', 'Downward slanted palpebral fissures', 'Downward slanting of the opening between the eyelids', 'Downward slanting palpebral fissures', 'Downward-slanting palpebral fissures', 'Palpebral fissures down-slanted', 'delayed speech and language development', 'Deficiency of speech development', 'Delayed language development', 'Delayed speech', 'Delayed speech acquisition', 'Delayed speech and language development', 'Delayed speech development', 'Impaired speech and language development', 'Impaired speech development', 'Language delay', 'Language delayed', 'Language development deficit', 'Late-onset speech development', 'Poor language development', 'Speech and language delay', 'Speech and language difficulties', 'Speech delay', 'scoliosis', 'secundum atrial septal defect', 'Atrial septal defect, ostium secundum type', 'Ostium secundum atrial septal defect', 'Patent ostium secundum', 'global developmental delay', 'Delayed cognitive development', 'Delayed development', 'Delayed developmental milestones', 'Delayed intellectual development', 'Delayed milestones', 'Delayed psychomotor development', 'Developmental delay', 'Developmental delay in early childhood', 'Developmental delay, global', 'Developmental retardation', 'Lack of psychomotor development', 'Motor and developmental delay', 'Psychomotor delay', 'Psychomotor development deficiency', 'Psychomotor development failure', 'Psychomotor developmental delay', 'Retarded development', 'Ret ...
# ['HP:0000286',
#  'HP:0004322',
#  'HP:0002162',
#  'HP:0005272',
#  'HP:0000917',
#  'HP:0012471',
#  'HP:0000915',
#  'HP:0000316',
#  'HP:0001328',
#  'HP:0000997',
#  'HP:0007565',
#  'HP:0001324',
#  'HP:0000256',
#  'HP:0001642',
#  'HP:0000358',
#  'HP:0001249',
#  'HP:0003006',
#  'HP:0001067',
#  'HP:0000494',
#  'HP:0000750',
#  'HP:0002650',
#  'HP:0001684',
#  'HP:0001263',
#  'HP:0000272',
#  'HP:0000470',
#  'HP:0011800',
#  'HP:0005280',
#  'HP:0000508',
#  'HP:0000767',
#  'HP:0030052',
#  'HP:0002967',
#  'HP:0009732',
#  'HP:0009734',
#  'HP:0000465',
#  'HP:0000028',
#  'HP:0009737',
#  'HP:0000369']

# %% [markdown]
# ## Get Symptom Prevalence - based off edges out counts

# %%
disease_symptom_dict = gsf.get_symtpom_prevalence(disease_symptom_dict, disease_name) 
disease_symptoms_df = pd.DataFrame.from_dict(disease_symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptoms_df = pd.concat([disease_symptoms_df[disease_symptoms_df["frequency"] == "Very frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Occasional"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Rare"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Unknown"]
              ])
# Out:
# HP:0000286
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (288, 9)
# OKKKk
# 288
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (361, 9)
# ok edge phen to dis
# 649
# edges out
# 649
# HP:0004322
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (444, 9)
# OKKKk
# 444
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (381, 9)
# ok edge phen to dis
# 825
# edges out
# 1148
# HP:0002162
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (85, 9)
# OKKKk
# 85
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (153, 9)
# ok edge phen to dis
# 238
# edges out
# 238
# HP:0005272
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (16, 9)
# OKKKk
# 16
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (12, 9)
# ok edge phen to dis
# 28
# edges out
# 28
# HP:0000917
# Cannot connect to host myvariant.info:443 ssl:default [nodename nor servname provided, or not known]
# Cannot connect to host mydisease.info:80 ssl:default [nodename nor servname provided, or not known]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Too many open files]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Too many open files]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Too many open files]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Too many open files]
# Cannot connect to host mygene.info:443 ssl:default [nodename nor servname provided, or not known]
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (6, 9)
# OKKKk
# 6
# API 1.2 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (6, 9)
# ok edge phen to dis
# 12
# edges out
# 12
# HP:0012471
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (92, 9)
# OKKKk
# 92
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (167, 9)
# ok edge phen to dis
# 259
# edges out
# 259
# HP:0000915
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (8, 9)
# OKKKk
# 8
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (8, 9)
# ok edge phen to dis
# 16
# edges out
# 16
# HP:0000316
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (357, 9)
# OKKKk
# 357
# API 1.14 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# (356, 9)
# ok edge phen to dis
# 713
# edges out
# 713
# HP:0001328
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# gene
# (189, 9)
# OKKKk
# 189
# API 1.10 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (201, 9)
# ok edge phen to dis
# 390
# edges out
# 390
# HP:0000997
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (11, 9)
# OKKKk
# 11
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (14, 9)
# ok edge phen to dis
# 25
# edges out
# 25
# HP:0007565
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (62, 9)
# OKKKk
# 62
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (49, 9)
# ok edge phen to dis
# 111
# edges out
# 111
# HP:0001324
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (238, 9)
# OKKKk
# 238
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (366, 9)
# ok edge phen to dis
# 604
# edges out
# 1022
# HP:0000256
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (325, 9)
# OKKKk
# 325
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (389, 9)
# ok edge phen to dis
# 714
# edges out
# 714
# HP:0001642
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (113, 9)
# OKKKk
# 113
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (205, 9)
# ok edge phen to dis
# 318
# edges out
# 318
# HP:0000358
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (245, 9)
# OKKKk
# 245
# API 1.13 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (402, 9)
# ok edge phen to dis
# 647
# edges out
# 647
# HP:0001249
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (550, 9)
# OKKKk
# 550
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (387, 9)
# ok edge phen to dis
# 937
# edges out
# 937
# HP:0003006
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (36, 9)
# OKKKk
# 36
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (31, 9)
# ok edge phen to dis
# 67
# Nope
# edges out
# 1705
# HP:0001067
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (14, 9)
# OKKKk
# 14
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (20, 9)
# ok edge phen to dis
# 34
# edges out
# 34
# HP:0000494
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (280, 9)
# OKKKk
# 280
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (362, 9)
# ok edge phen to dis
# 642
# edges out
# 642
# HP:0000750
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (307, 9)
# OKKKk
# 307
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# (370, 9)
# ok edge phen to dis
# 677
# edges out
# 677
# HP:0002650
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (333, 9)
# OKKKk
# 333
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# (347, 9)
# ok edge phen to dis
# 680
# edges out
# 680
# HP:0001684
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# gene
# (12, 9)
# OKKKk
# 12
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (35, 9)
# ok edge phen to dis
# 47
# edges out
# 47
# HP:0001263
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (517, 9)
# OKKKk
# 517
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (406, 9)
# ok edge phen to dis
# 923
# edges out
# 1006
# HP:0000272
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (280, 9)
# OKKKk
# 280
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (412, 9)
# ok edge phen to dis
# 692
# edges out
# 692
# HP:0000470
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# gene
# (284, 9)
# OKKKk
# 284
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (360, 9)
# ok edge phen to dis
# 644
# edges out
# 661
# HP:0011800
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (188, 9)
# OKKKk
# 188
# API 1.15 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# (410, 9)
# ok edge phen to dis
# 598
# edges out
# 598
# HP:0005280
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (307, 9)
# OKKKk
# 307
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (378, 9)
# ok edge phen to dis
# 685
# edges out
# 685
# HP:0000508
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (309, 9)
# OKKKk
# 309
# API 1.15 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# (372, 9)
# ok edge phen to dis
# 681
# edges out
# 681
# HP:0000767
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (254, 9)
# OKKKk
# 254
# API 1.1 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (397, 9)
# ok edge phen to dis
# 651
# edges out
# 651
# HP:0030052
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (2, 9)
# OKKKk
# 2
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (6, 9)
# ok edge phen to dis
# 8
# edges out
# 8
# HP:0002967
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (53, 9)
# OKKKk
# 53
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (92, 9)
# ok edge phen to dis
# 145
# edges out
# 145
# HP:0009732
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# gene
# (3, 9)
# OKKKk
# 3
# API 1.4 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (7, 9)
# ok edge phen to dis
# 10
# edges out
# 10
# HP:0009734
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (7, 9)
# OKKKk
# 7
# API 1.1 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# (10, 9)
# ok edge phen to dis
# 17
# Nope
# edges out
# 29
# HP:0000465
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (94, 9)
# OKKKk
# 94
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (192, 9)
# ok edge phen to dis
# 286
# edges out
# 286
# HP:0000028
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (331, 9)
# OKKKk
# 331
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# (365, 9)
# ok edge phen to dis
# 696
# edges out
# 696
# HP:0009737
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# gene
# (3, 9)
# OKKKk
# 3
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# (16, 9)
# ok edge phen to dis
# 19
# edges out
# 19
# HP:0000369
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (324, 9)
# OKKKk
# 324
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (387, 9)
# ok edge phen to dis
# 711
# edges out
# 711

# %% [markdown]
# ## Calculate Individual Symptom Scores

# %%
individual_symptom_scores = [];
for index,x in disease_symptoms_df.iterrows():
    if(x["frequency"] == "Very frequent"):
        score = 20 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Frequent"):
        score = 15 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Occasional"):
        score = 10 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Rare"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Unknown"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    individual_symptom_scores.append(score)

# print(len(individual_symptom_scores))
disease_symptoms_df["ISS"] = individual_symptom_scores

# %% [markdown]
# ## Symptoms Table

# %%
disease_symptoms_df
# Out:
#                                                         names frequency  \
# HP:0030052     [inguinal freckling, Freckles in groin region]   Unknown
# HP:0009732                           [plexiform neurofibroma]   Unknown
# HP:0000917  [superior pectus carinatum, Pectus carinatum s...   Unknown
# HP:0000915  [pectus excavatum of inferior sternum, Pectus ...   Unknown
# HP:0009737                   [lisch nodules, Iris hamartomas]   Unknown
# HP:0000997                               [axillary freckling]   Unknown
# HP:0005272  [prominent nasolabial fold, Deep laugh lines, ...   Unknown
# HP:0009734                 [optic nerve glioma, Optic glioma]   Unknown
# HP:0001067  [neurofibromas, Neurofibromata, Neurofibromato...   Unknown
# HP:0001684  [secundum atrial septal defect, Atrial septal ...   Unknown
# HP:0007565                      [multiple cafe-au-lait spots]   Unknown
# HP:0002967            [cubitus valgus, Outward turned elbows]   Unknown
# HP:0002162  [low posterior hairline, Low hairline at back ...   Unknown
# HP:0012471  [thick vermilion border, Full lips, Increased ...   Unknown
# HP:0000465  [webbed neck, Neck webbing, Pterygium colli, W...   Unknown
# HP:0001642  [pulmonic stenosis, Narrowing of pulmonic valv...   Unknown
# HP:0001328                     [specific learning disability]   Unknown
# HP:0011800  [midface retrusion, Decreased size of midface,...   Unknown
# HP:0000494  [downslanted palpebral fissures, Antimongoloid...   Unknown
# HP:0000358  [posteriorly rotated ears, Ear, posterior angu...   Unknown
# HP:0000286  [epicanthus, Epicanthal fold, Epicanthal folds...   Unknown
# HP:0000767                   [pectus excavatum, Funnel chest]   Unknown
# HP:0000470  [short neck, Cervical shortening, Decreased ce...   Unknown
# HP:0000750  [delayed speech and language development, Defi...   Unknown
# HP:0002650                                        [scoliosis]   Unknown
# HP:0000508  [ptosis, Blepharoptosis, Drooping upper eyelid...   Unknown
# HP:0005280  [depressed nasal bridge, Depressed bridge of n...   Unknown
# HP:0000272  [malar flattening, Decreased size of malar bon...   Unknown
# HP:0000028  [cryptorchidism, Cryptorchism, Undescended tes...   Unknown
# HP:0000369  [low-set ears, Low set ears, Low-set ears, Low...   Unknown
# HP:0000316  [hypertelorism, Excessive orbital separation, ...   Unknown
# HP:0000256  [macrocephaly, Increased size of cranium, Incr...   Unknown
# HP:0001249  [intellectual disability, Intellectual disabil...   Unknown
# HP:0001263  [global developmental delay, Delayed cognitive...   Unknown
# HP:0001324  [muscle weakness, Muscle weakness, Muscular we...   Unknown
# HP:0004322  [short stature, Decreased body height, Height ...   Unknown
# HP:0003006       [neuroblastoma, Cancer of early nerve cells]   Unknown
#
#             edges_out_count       ISS
# HP:0030052                8  1.767767
# HP:0009732               10  1.581139
# HP:0000917               12  1.443376
# HP:0000915               16  1.250000
# HP:0009737               19  1.147079
# HP:0000997               25  1.000000
# HP:0005272               28  0.944911
# HP:0009734               29  0.928477
# HP:0001067               34  0.857493
# HP:0001684               47  0.729325
# HP:0007565              111  0.474579
# HP:0002967              145  0.415227
# HP:0002162              238  0.324102
# HP:0012471              259  0.310685
# HP:0000465              286  0.295656
# HP:0001642              318  0.280386
# HP:0001328              390  0.253185
# HP:0011800              598  0.204465
# HP:0000494              642  0.197334
# HP:0000358              647  0.196570
# HP:0000286              649  0.196267
# HP:0000767              651  0.195965
# HP:0000470              661  0.194477
# HP:0000750              677  0.192166
# HP:0002650              680  0.191741
# HP:0000508              681  0.191600
# HP:0005280              685  0.191040
# HP:0000272              692  0.190071
# HP:0000028              696  0.189525
# HP:0000369              711  0.187515
# HP:0000316              713  0.187251
# HP:0000256              714  0.187120
# HP:0001249              937  0.163343
# HP:0001263             1006  0.157642
# HP:0001324             1022  0.156403
# HP:0004322             1148  0.147570
# HP:0003006             1705  0.121090

# %%
disease_symptoms_df.to_csv(symptom_csv, index = False)

# %% [markdown]
# ## Get Disease -> Gene (no intermediates)

# %%
disease_disease_to_genes_dict = gsf.get_disease_to_gene_results(disease)
disease_disease_to_genes_dict
# Out:
# running disease -> gene
# {'sorted_disease_to_genes': {'MGI:97306': 1,
#   'MGI:97307': 1,
#   'CHGA': 1,
#   'TSC2': 1,
#   'CCND1': 1,
#   'KITLG': 1,
#   'MSH6': 1,
#   'EVI2A': 1,
#   'RAF1': 1,
#   'PGLS': 1,
#   'KRAS': 1,
#   'PDGFRA': 1,
#   'MDM2': 1,
#   'TMEM127': 1,
#   'UTP6': 1,
#   'TAOK1': 1,
#   'PDGFRB': 1,
#   'RHEB': 1,
#   'SLC9A3R1': 1,
#   'MAP2K2': 1,
#   'SYP': 1,
#   'PIK3CA': 1,
#   'SDHA': 1,
#   'EGF': 1,
#   'DHH': 1,
#   'TP53': 1,
#   'ERBB2': 1,
#   'RASA1': 1,
#   'EGFR': 1,
#   'NOTCH1': 1,
#   'RASA2': 1,
#   'SST': 1,
#   'KIT': 1,
#   'TSC1': 1,
#   'SPRED1': 1,
#   'SDHAF2': 1,
#   'MAP2K1': 1,
#   'CD34': 1,
#   'TCHP': 1,
#   'SAV1': 1,
#   'OLIG2': 1,
#   'EVI2B': 1,
#   'MEN1': 1,
#   'EPB41': 1,
#   'ANO1': 1,
#   'MAX': 1,
#   'NLGN3': 1,
#   'MSN': 1,
#   'MTOR': 1,
#   'SDHC': 1,
#   'NES': 1,
#   'FABP7': 1,
#   'SHOC2': 1,
#   'NRAS': 1,
#   'PTEN': 1,
#   'AMOT': 1,
#   'ATRX': 1,
#   'SRC': 1,
#   'SDHB': 1,
#   'SDHD': 1,
#   'LATS2': 1,
#   'MOB1A': 1,
#   'SOX10': 1,
#   'MAP2K7': 1,
#   'CDC42': 1,
#   'RDX': 1,
#   'SOS1': 1,
#   'IDH1': 1,
#   'VPRBP': 1,
#   'MECP2': 1,
#   'NFIC': 1,
#   'SCHIP1': 1,
#   'TBL1XR1': 1,
#   'HRAS': 1,
#   'FAM131B': 1,
#   'KIAA1549': 1,
#   'CDKN2A': 1,
#   'WWTR1': 1,
#   'WWC1': 1,
#   'NTRK1': 1,
#   'ENO2': 1,
#   'LATS1': 1,
#   'AKT1': 1,
#   'GFAP': 1,
#   'YAP1': 1,
#   'MYC': 1,
#   '7841': 1,
#   'EGR1': 1,
#   'EGR2': 1,
#   'FOSB': 1,
#   'FOS': 1,
#   'GNL3': 1,
#   'NFASC': 1,
#   'POLE': 1,
#   'RAC2': 1,
#   'NMS': 1,
#   'NFS1': 1,
#   'FIG4': 1,
#   'VAV1': 1,
#   'CREBBP': 1,
#   'ARID1B': 1,
#   'CDKN2D': 1,
#   'F9': 1,
#   'APEX1': 1,
#   'REG1A': 1,
#   'CHRFAM7A': 1,
#   'VHL': 1,
#   'RHOA': 1,
#   'SNW1': 1,
#   'COQ6': 1,
#   'NGFR': 1,
#   'IQCJ': 1,
#   'PRR30': 1,
#   'KLC1': 1,
#   'CRYBB2': 1,
#   'AP1B1': 1,
#   'LSR': 1,
#   'OMG': 2,
#   'SMARCB1': 2,
#   'SUZ12': 2,
#   'PTPN11': 2,
#   'RET': 2,
#   'SPINK5': 2,
#   'EZR': 2,
#   'VEGFA': 2,
#   'SPRY1': 2,
#   'LZTR1': 3,
#   'NF2': 3,
#   'NF1': 8},
#  'one_step_genes_pub_counts': {'MGI:97306': 0,
#   'MGI:97307': 0,
#   'LZTR1': 0,
#   'CHGA': 0,
#   'TSC2': 0,
#   'CCND1': 0,
#   'KITLG': 0,
#   'MSH6': 0,
#   'EVI2A': 0,
#   'OMG': 0,
#   'RAF1': 0,
#   'PGLS': 0,
#   'KRAS': 0,
#   'PDGFRA': 0,
#   'MDM2': 0,
#   'TMEM127': 0,
#   'UTP6': 0,
#   'TAOK1': 0,
#   'PDGFRB': 0,
#   'RHEB': 0,
#   'SLC9A3R1': 0,
#   'MAP2K2': 0,
#   'SMARCB1': 0,
#   'SYP': 0,
#   'PIK3CA': 0,
#   'SDHA': 0,
#   'EGF': 0,
#   'DHH': 0,
#   'TP53': 0,
#   'ERBB2': 0,
#   'RASA1': 0,
#   'EGFR': 0,
#   'NOTCH1': 0,
#   'RASA2': 0,
#   'SST': 0,
#   'KIT': 0,
#   'TSC1': 0,
#   'SPRED1': 0,
#   'SDHAF2': 0,
#   'MAP2K1': 0,
#   'CD34': 0,
#   'SUZ12': 0,
#   'TCHP': 0,
#   'SAV1': 0,
#   'OLIG2': 0,
#   'EVI2B': 0,
#   'MEN1': 0,
#   'PTPN11': 1,
#   'NF2': 1,
#   'EPB41': 0,
#   'ANO1': 0,
#   'RET': 1,
#   'NF1': 10,
#   'MAX': 0,
#   'NLGN3': 0,
#   'SPINK5': 0,
#   'MSN': 0,
#   'MTOR': 0,
#   'EZR': 0,
#   'SDHC': 0,
#   'NES': 0,
#   'FABP7': 0,
#   'SHOC2': 0,
#   'NRAS': 0,
#   'PTEN': 0,
#   'AMOT': 0,
#   'ATRX': 0,
#   'SRC': 0,
#   'SDHB': 0,
#   'SDHD': 0,
#   'LATS2': 0,
#   'MOB1A': 0,
#   'SOX10': 0,
#   'MAP2K7': 0,
#   'CDC42': 0,
#   'RDX': 0,
#   'SOS1': 0,
#   'IDH1': 0,
#   'VPRBP': 0,
#   'MECP2': 0,
#   'NFIC': 0,
#   'SCHIP1': 0,
#   'TBL1XR1': 0,
#   'HRAS': 0,
#   'FAM131B': 0,
#   'KIAA1549': 0,
#   'CDKN2A': 0,
#   'WWTR1': 0,
#   'WWC1': 0,
#   'NTRK1': 0,
#   'ENO2': 0,
#   'LATS1': 0,
#   'AKT1': 0,
#   'GFAP': 0,
#   'VEGFA': 0,
#   'YAP1': 0,
#   'MYC': 0,
#   'SPRY1': 0,
#   '7841': 0,
#   'EGR1': 0,
#   'EGR2': 0,
#   'FOSB': 0,
#   'FOS': 0,
#   'GNL3': 0,
#   'NFASC': 0,
#   'POLE': 0,
#   'RAC2': 0,
#   'NMS': 0,
#   'NFS1': 0,
#   'FIG4': 0,
#   'VAV1': 0,
#   'CREBBP': 1,
#   'ARID1B': 1,
#   'CDKN2D': 1,
#   'F9': 1,
#   'APEX1': 1,
#   'REG1A': 1,
#   'CHRFAM7A': 1,
#   'VHL': 1,
#   'RHOA': 1,
#   'SNW1': 1,
#   'COQ6': 0,
#   'NGFR': 1,
#   'IQCJ': 0,
#   'PRR30': 0,
#   'KLC1': 0,
#   'CRYBB2': 0,
#   'AP1B1': 0,
#   'LSR': 0},
#  'disease_to_genes_list': ['NF1',
#   'NF2',
#   'LZTR1',
#   'SPRY1',
#   'VEGFA',
#   'EZR',
#   'SPINK5',
#   'RET',
#   'PTPN11',
#   'SUZ12',
#   'SMARCB1',
#   'OMG',
#   'LSR',
#   'AP1B1',
#   'CRYBB2',
#   'KLC1',
#   'PRR30',
#   'IQCJ',
#   'NGFR',
#   'COQ6',
#   'SNW1',
#   'RHOA',
#   'VHL',
#   'CHRFAM7A',
#   'REG1A',
#   'APEX1',
#   'F9',
#   'CDKN2D',
#   'ARID1B',
#   'CREBBP',
#   'VAV1',
#   'FIG4',
#   'NFS1',
#   'NMS',
#   'RAC2',
#   'POLE',
#   'NFASC',
#   'GNL3',
#   'FOS',
#   'FOSB',
#   'EGR2',
#   'EGR1',
#   '7841',
#   'MYC',
#   'YAP1',
#   'GFAP',
#   'AKT1',
#   'LATS1',
#   'ENO2',
#   'NTRK1',
#   'WWC1',
#   'WWTR1',
#   'CDKN2A',
#   'KIAA1549',
#   'FAM131B',
#   'HRAS',
#   'TBL1XR1',
#   'SCHIP1',
#   'NFIC',
#   'MECP2',
#   'VPRBP',
#   'IDH1',
#   'SOS1',
#   'RDX',
#   'CDC42',
#   'MAP2K7',
#   'SOX10',
#   'MOB1A',
#   'LATS2',
#   'SDHD',
#   'SDHB',
#   'SRC',
#   'ATRX',
#   'AMOT',
#   'PTEN',
#   'NRAS',
#   'SHOC2',
#   'FABP7',
#   'NES',
#   'SDHC',
#   'MTOR',
#   'MSN',
#   'NLGN3',
#   'MAX',
#   'ANO1',
#   'EPB41',
#   'MEN1',
#   'EVI2B',
#   'OLIG2',
#   'SAV1',
#   'TCHP',
#   'CD34',
#   'MAP2K1',
#   'SDHAF2',
#   'SPRED1',
#   'TSC1',
#   'KIT',
#   'SST',
#   'RASA2',
#   'NOTCH1',
#   'EGFR',
#   'RASA1',
#   'ERBB2',
#   'TP53',
#   'DHH',
#   'EGF',
#   'SDHA',
#   'PIK3CA',
#   'SYP',
#   'MAP2K2',
#   'SLC9A3R1',
#   'RHEB',
#   'PDGFRB',
#   'TAOK1',
#   'UTP6',
#   'TMEM127',
#   'MDM2',
#   'PDGFRA',
#   'KRAS',
#   'PGLS',
#   'RAF1',
#   'EVI2A',
#   'MSH6',
#   'KITLG',
#   'CCND1',
#   'TSC2',
#   'CHGA',
#   'MGI:97307',
#   'MGI:97306']}

# %% [markdown]
# ## Get Disease -> intermediate_node (any except those matching symptoms) -> Gene

# %%
# get results using intermediates 
node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %%
disease_disease_all_nodes_genes = gsf.predict_many(disease, node_type_list, 'Gene')

# Save an object to a file
# %store disease_disease_all_nodes_genes
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# API 1.1 pharos failed
# Intermediate Node type running:
# Disease
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature
# Stored 'disease_disease_all_nodes_genes' (DataFrame)

# %%
# Restore the object
# %store -r disease_disease_all_nodes_genes
disease_disease_all_nodes_genes
# Out:
#                  input input_type       pred1  \
# 0    NEUROFIBROMATOSIS    Disease  related_to
# 1    NEUROFIBROMATOSIS    Disease  related_to
# 2    NEUROFIBROMATOSIS    Disease  related_to
# 4    NEUROFIBROMATOSIS    Disease  related_to
# 5    NEUROFIBROMATOSIS    Disease  related_to
# ..                 ...        ...         ...
# 888  NEUROFIBROMATOSIS    Disease  related_to
# 889  NEUROFIBROMATOSIS    Disease  related_to
# 890  NEUROFIBROMATOSIS    Disease  related_to
# 891  NEUROFIBROMATOSIS    Disease  related_to
# 892  NEUROFIBROMATOSIS    Disease  related_to
#
#                         pred1_source           pred1_api pred1_pubmed  \
# 0                            DISEASE        DISEASES API         None
# 1                           disgenet  mydisease.info API         None
# 2                             pharos  Automat PHAROS API         None
# 4                            DISEASE        DISEASES API         None
# 5                           disgenet  mydisease.info API         None
# ..                               ...                 ...          ...
# 888  Translator Text Mining Provider    CORD Disease API         None
# 889  Translator Text Mining Provider    CORD Disease API         None
# 890  Translator Text Mining Provider    CORD Disease API         None
# 891  Translator Text Mining Provider    CORD Disease API         None
# 892  Translator Text Mining Provider    CORD Disease API         None
#
#            node1_type node1_name               node1_id          pred2  \
# 0                Gene      LZTR1          NCBIGene:8216  homologous_to
# 1                Gene      LZTR1          NCBIGene:8216  homologous_to
# 2                Gene      LZTR1          NCBIGene:8216  homologous_to
# 4                Gene      LZTR1          NCBIGene:8216     related_to
# 5                Gene      LZTR1          NCBIGene:8216     related_to
# ..                ...        ...                    ...            ...
# 888  AnatomicalEntity     KIDNEY  UBERON:UBERON:0002113     related_to
# 889  AnatomicalEntity     KIDNEY  UBERON:UBERON:0002113     related_to
# 890  AnatomicalEntity     KIDNEY  UBERON:UBERON:0002113     related_to
# 891  AnatomicalEntity     KIDNEY  UBERON:UBERON:0002113     related_to
# 892  AnatomicalEntity     KIDNEY  UBERON:UBERON:0002113     related_to
#
#                         pred2_source         pred2_api pred2_pubmed  \
# 0                               None   MyGene.info API         None
# 1                               None   MyGene.info API         None
# 2                               None   MyGene.info API         None
# 4    Translator Text Mining Provider     CORD Gene API         None
# 5    Translator Text Mining Provider     CORD Gene API         None
# ..                               ...               ...          ...
# 888  Translator Text Mining Provider  CORD Anatomy API         None
# 889  Translator Text Mining Provider  CORD Anatomy API         None
# 890  Translator Text Mining Provider  CORD Anatomy API         None
# 891  Translator Text Mining Provider  CORD Anatomy API         None
# 892  Translator Text Mining Provider  CORD Anatomy API         None
#
#     output_type output_name       output_id
# 0          Gene     1914113     MGI:1914113
# 1          Gene     1914113     MGI:1914113
# 2          Gene     1914113     MGI:1914113
# 4          Gene        KRAS   NCBIGene:3845
# 5          Gene        KRAS   NCBIGene:3845
# ..          ...         ...             ...
# 888        Gene        IL10   NCBIGene:3586
# 889        Gene        DKK1  NCBIGene:22943
# 890        Gene       SMAD6   NCBIGene:4091
# 891        Gene        PRKN   NCBIGene:5071
# 892        Gene        PAEP   NCBIGene:5047
#
# [561582 rows x 16 columns]

# %%
## Remove UMLS "Genes"  (not gene specific) 
disease_disease_all_nodes_genes = disease_disease_all_nodes_genes[~disease_disease_all_nodes_genes['output_id'].str.contains('UMLS')]

# %%
max_2_step_genes = 100
disease_disease_to_node_to_genes_dict = gsf.get_disease_to_node_to_gene_results(disease_disease_all_nodes_genes, max_2_step_genes, disease_symptoms, disease_symptom_hpids)
# %store disease_disease_to_node_to_genes_dict
# Out:
# finding intermediate nodes that are symptoms
# removing symptom intermediates
# getting gene counts from 371783 gene entries
# sorting counts dictionary
# top genes occurrence counts:
# TP53: 1008
# TNF: 902
# AKT1: 898
# VEGFA: 862
# EGFR: 842
# PTEN: 672
# MAPK1: 665
# TGFB1: 635
# CDKN2A: 630
# KIT: 619
# MMP9: 595
# CAT: 569
# CDKN1A: 551
# MTOR: 547
# INS: 541
# PIK3CA: 523
# STAT3: 510
# MMP2: 502
# MAPK8: 485
# TCEAL1: 484
# CAMP: 483
# H3P16: 482
# NF1: 481
# CD4: 472
# LEP: 468
# BRAF: 462
# IFNA1: 461
# ESR1: 459
# FOS: 454
# CCND1: 449
# CA2: 425
# AR: 424
# FAS: 417
# IL2: 414
# PTH: 412
# MYC: 411
# CXCR4: 398
# IL6: 397
# RHO: 395
# CRK: 394
# APP: 391
# BCR: 380
# POMC: 379
# IFI27: 378
# PSMD9: 377
# PIK3CB: 375
# BAX: 371
# ZNRD2: 371
# CD44: 362
# GRK2: 359
# ATM: 359
# BRCA1: 357
# TMED7: 353
# RET: 352
# DCTN6: 351
# SNRPE: 350
# NF2: 349
# EGF: 348
# PTPN11: 345
# ERBB2: 342
# HRAS: 341
# MDM2: 337
# RHOD: 336
# SST: 332
# TH: 324
# CCL2: 323
# STAT5A: 322
# BCL2: 322
# ANG: 321
# LOX: 315
# ZHX2: 315
# MAPK3: 314
# REN: 311
# RHOA: 309
# CISH: 308
# TERT: 304
# RAF1: 303
# GABPA: 300
# TLR4: 298
# NOTCH1: 298
# CDK4: 290
# SOD1: 289
# CD34: 287
# ALB: 283
# FASN: 283
# KDR: 282
# RELA: 279
# HIF1A: 278
# BIRC5: 277
# RB1: 275
# HSPA4: 274
# TP63: 274
# TIMP1: 273
# CD40: 272
# SIRT1: 271
# EGR1: 269
# FGF2: 267
# EPO: 265
# NTRK1: 265
# SP1: 264
# getting publicaiton counts
# Stored 'disease_disease_to_node_to_genes_dict' (dict)

# %% [markdown]
# ## Combine genes from one and two step processes then get rid of any duplicates

# %%
# %store -r disease_disease_to_node_to_genes_dict
disease_top_genes_list = disease_disease_to_genes_dict["disease_to_genes_list"] + disease_disease_to_node_to_genes_dict["top_related_genes_to_disease"]
disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
# top_genes_list

# %% [markdown]
# ## Get Genes -> Symtoms, filtered by those related to Disease

# %%
disease_relevant_genes_to_symptoms_df = gsf.determined_genes_to_symptoms(disease_top_genes_list, disease_symptoms)
# relevant_genes_to_symptoms_df
# Out:
# Genes -> PhenotypicFeatures
# VPRBP FAILED
# MGI:97307 FAILED
# MGI:97306 FAILED
# APP FAILED
# Genes -> Bioprocesses
# VPRBP FAILED
# MGI:97307 FAILED
# MGI:97306 FAILED
# APP FAILED
# Genes -> Diseases
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# VPRBP FAILED
# MGI:97307 FAILED
# MGI:97306 FAILED
# APP FAILED
# 179

# %%
# %store disease_relevant_genes_to_symptoms_df
# Out:
# Stored 'disease_relevant_genes_to_symptoms_df' (DataFrame)

# %%
# %store -r disease_relevant_genes_to_symptoms_df
disease_relevant_genes_list = list(dict.fromkeys(list(disease_relevant_genes_to_symptoms_df["input"])))
# relevant_genes_list

# %%
disease_gene_to_symptom_pub_counts = gsf.get_gene_to_symptom_publication_counts(disease_relevant_genes_to_symptoms_df)
# gene_to_symptom_pub_counts

# %%
disease_causes_dict = gsf.create_causes_dict(disease_relevant_genes_to_symptoms_df)
# causes_dict

# %% [markdown]
# ## Get edges out from each gene
# For use in normalizing in relevance score

# %%
disease_connection_dict =  gsf.get_connection_normalizing_count(disease_relevant_genes_list,node_type_list)
# connection_dict
# Out:
# Fatal error on SSL transport
# protocol: <asyncio.sslproto.SSLProtocol object at 0x7fb046679d00>
# transport: <_SelectorSocketTransport closing fd=72>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 908, in write
#     n = self._sock.send(data)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/sslproto.py", line 685, in _process_write_backlog
#     self._transport.write(chunk)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 914, in write
#     self._fatal_error(exc, 'Fatal write error on socket transport')
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 709, in _fatal_error
#     self._force_close(exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 721, in _force_close
#     self._loop.call_soon(self._call_connection_lost, exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 719, in call_soon
#     self._check_closed()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 508, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Fatal error on SSL transport
# protocol: <asyncio.sslproto.SSLProtocol object at 0x7fb046679b50>
# transport: <_SelectorSocketTransport closing fd=71>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 908, in write
#     n = self._sock.send(data)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/sslproto.py", line 685, in _process_write_backlog
#     self._transport.write(chunk)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 914, in write
#     self._fatal_error(exc, 'Fatal write error on socket transport')
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 709, in _fatal_error
#     self._force_close(exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 721, in _force_close
#     self._loop.call_soon(self._call_connection_lost, exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 719, in call_soon
#     self._check_closed()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 508, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Fatal error on SSL transport
# protocol: <asyncio.sslproto.SSLProtocol object at 0x7fb02d739b80>
# transport: <_SelectorSocketTransport closing fd=67>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 908, in write
#     n = self._sock.send(data)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/sslproto.py", line 685, in _process_write_backlog
#     self._transport.write(chunk)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 914, in write
#     self._fatal_error(exc, 'Fatal write error on socket transport')
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 709, in _fatal_error
#     self._force_close(exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 721, in _force_close
#     self._loop.call_soon(self._call_connection_lost, exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 719, in call_soon
#     self._check_closed()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 508, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Fatal error on SSL transport
# protocol: <asyncio.sslproto.SSLProtocol object at 0x7fb02d739340>
# transport: <_SelectorSocketTransport closing fd=68>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 908, in write
#     n = self._sock.send(data)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/sslproto.py", line 685, in _process_write_backlog
#     self._transport.write(chunk)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 914, in write
#     self._fatal_error(exc, 'Fatal write error on socket transport')
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 709, in _fatal_error
#     self._force_close(exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 721, in _force_close
#     self._loop.call_soon(self._call_connection_lost, exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 719, in call_soon
#     self._check_closed()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 508, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Fatal error on SSL transport
# protocol: <asyncio.sslproto.SSLProtocol object at 0x7fb02d739040>
# transport: <_SelectorSocketTransport closing fd=70>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 908, in write
#     n = self._sock.send(data)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/sslproto.py", line 685, in _process_write_backlog
#     self._transport.write(chunk)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 914, in write
#     self._fatal_error(exc, 'Fatal write error on socket transport')
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 709, in _fatal_error
#     self._force_close(exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 721, in _force_close
#     self._loop.call_soon(self._call_connection_lost, exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 719, in call_soon
#     self._check_closed()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 508, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Fatal error on SSL transport
# protocol: <asyncio.sslproto.SSLProtocol object at 0x7fb02d7392b0>
# transport: <_SelectorSocketTransport closing fd=69>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 908, in write
#     n = self._sock.send(data)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/sslproto.py", line 685, in _process_write_backlog
#     self._transport.write(chunk)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 914, in write
#     self._fatal_error(exc, 'Fatal write error on socket transport')
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 709, in _fatal_error
#     self._force_close(exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 721, in _force_close
#     self._loop.call_soon(self._call_connection_lost, exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 719, in call_soon
#     self._check_closed()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 508, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Fatal error on SSL transport
# protocol: <asyncio.sslproto.SSLProtocol object at 0x7fb02d7396d0>
# transport: <_SelectorSocketTransport closing fd=63>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 908, in write
#     n = self._sock.send(data)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/sslproto.py", line 685, in _process_write_backlog
#     self._transport.write(chunk)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 914, in write
#     self._fatal_error(exc, 'Fatal write error on socket transport')
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 709, in _fatal_error
#     self._force_close(exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 721, in _force_close
#     self._loop.call_soon(self._call_connection_lost, exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 719, in call_soon
#     self._check_closed()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 508, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Fatal error on SSL transport
# protocol: <asyncio.sslproto.SSLProtocol object at 0x7fb02d739910>
# transport: <_SelectorSocketTransport closing fd=59>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 908, in write
#     n = self._sock.send(data)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/sslproto.py", line 685, in _process_write_backlog
#     self._transport.write(chunk)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 914, in write
#     self._fatal_error(exc, 'Fatal write error on socket transport')
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 709, in _fatal_error
#     self._force_close(exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/selector_events.py", line 721, in _force_close
#     self._loop.call_soon(self._call_connection_lost, exc)
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 719, in call_soon
#     self._check_closed()
#   File "/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py", line 508, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# ID resolution steps failed:
# gene MMP2 for node intermediate AnatomicalEntity failed

# %%
# %store disease_connection_dict
# Out:
# Stored 'disease_connection_dict' (dict)

# %%
# %store -r disease_connection_dict

# %% [markdown]
# ## Assemble final results

# %%
disease_df = gsf.assemble_final_data_frame(disease_relevant_genes_to_symptoms_df, 
                                      disease_connection_dict,
                                      disease_disease_to_genes_dict['sorted_disease_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['sorted_disease_to_all_nodes_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['top_two_step_genes_pub_counts'], 
                                      disease_gene_to_symptom_pub_counts, 
                                      disease_causes_dict,
                                      disease_symptoms_df)
disease_df
# Out:
#        gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 0       NF1                     8                        481
# 5    PTPN11                     2                        345
# 43   MAP2K2                     1                         76
# 1     LZTR1                     3                         44
# 22     SOS1                     1                         84
# ..      ...                   ...                        ...
# 125   SIRT1                     0                        271
# 120    TLR4                     0                        298
# 121     ALB                     0                        283
# 8     AP1B1                     1                         13
# 3    SPINK5                     2                        107
#
#               disease_symptoms_gene_is_associated_with  \
# 0    [cryptorchidism, cryptorchidism, decreased siz...
# 5    [cryptorchidism, cryptorchidism, cryptorchidis...
# 43   [excessive orbital separation, excessive orbit...
# 1    [decreased body height, decreased body height,...
# 22   [cryptorchidism, cryptorchidism, excessive orb...
# ..                                                 ...
# 125                          [intellectual disability]
# 120                          [intellectual disability]
# 121                          [intellectual disability]
# 8                              [decreased body height]
# 3                              [decreased body height]
#
#      symptoms_associated_count  gene_connections_count  final_symptom_score  \
# 0                           65                    1396            37.339689
# 5                           33                    2704            11.850738
# 43                          28                     820            12.471535
# 1                           12                     265             2.503304
# 22                          21                     960             6.846769
# ..                         ...                     ...                  ...
# 125                          1                    3382             0.163343
# 120                          1                    4498             0.163343
# 121                          1                    4260             0.163343
# 8                            1                     296             0.147570
# 3                            1                    1439             0.147570
#
#      relevance_score
# 0           1.000000
# 5           0.090377
# 43          0.057656
# 1           0.040884
# 22          0.030139
# ..               ...
# 125         0.000049
# 120         0.000047
# 121         0.000046
# 8           0.000000
# 3           0.000000
#
# [127 rows x 8 columns]

# %% [markdown]
# ## Save Results

# %%
disease_df.to_csv(output_csv, index = False)
