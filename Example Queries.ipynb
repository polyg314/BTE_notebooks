# %%
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %% [markdown]
# ## Example 1).
# #### Output_type should be "Gene," not "Disease"

# %%
tmprss2 = ht.query("TMPRSS2")['Gene'][0]
tmprss2
# Out:
# {'NCBIGene': '7113',
#  'name': 'transmembrane serine protease 2',
#  'SYMBOL': 'TMPRSS2',
#  'UMLS': 'C1336641',
#  'HGNC': '11876',
#  'UNIPROTKB': 'O15393',
#  'ENSEMBL': 'ENSG00000184012',
#  'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '7113'},
#  'display': 'NCBIGene(7113) ENSEMBL(ENSG00000184012) HGNC(11876) UMLS(C1336641) UNIPROTKB(O15393) SYMBOL(TMPRSS2)',
#  'type': 'Gene'}

# %%
nafamostat = ht.query("NAFAMOSTAT MESILATE")['ChemicalSubstance'][0]
nafamostat
# Out:
# {'UMLS': 'C0207682',
#  'MESH': 'C032855',
#  'name': 'nafamostat mesilate',
#  'primary': {'identifier': 'MESH',
#   'cls': 'ChemicalSubstance',
#   'value': 'C032855'},
#  'display': 'MESH(C032855) UMLS(C0207682) name(nafamostat mesilate)',
#  'type': 'ChemicalSubstance'}

# %%
fc = FindConnection(input_obj=nafamostat, output_obj=tmprss2, intermediate_nodes=['Disease'])
fc.connect(verbose=False)
fc.display_table_view()
# Out:
# API 6.1 pharos failed
#      input         input_type       pred1 pred1_source  \
# 0  FUT 175  ChemicalSubstance  related_to      scibite
# 1  FUT 175  ChemicalSubstance  related_to      scibite
# 2  FUT 175  ChemicalSubstance      treats       SEMMED
# 3  FUT 175  ChemicalSubstance    prevents       SEMMED
#
#                     pred1_api pred1_pubmed node1_type  \
# 0  Automat CORD19 Scibite API         None    Disease
# 1  Automat CORD19 Scibite API         None    Disease
# 2         SEMMED Chemical API     21521468    Disease
# 3         SEMMED Chemical API     21521468    Disease
#
#                        node1_name             node1_id       pred2  \
# 0  CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719  related_to
# 1  CORONAVINAE INFECTIOUS DISEASE  MONDO:MONDO:0005719  related_to
# 2               SYNDROMIC DISEASE  MONDO:MONDO:0002254  related_to
# 3               SYNDROMIC DISEASE  MONDO:MONDO:0002254  related_to
#
#   pred2_source                    pred2_api  \
# 0      scibite   Automat CORD19 Scibite API
# 1          CTD                      CTD API
# 2     scigraph  Automat CORD19 Scigraph API
# 3     scigraph  Automat CORD19 Scigraph API
#
#                                    pred2_pubmed output_type output_name  \
# 0                                          None     Disease     TMPRSS2
# 1  24027332|24227843|27550352|27733646|28778717     Disease     TMPRSS2
# 2                                          None     Disease     TMPRSS2
# 3                                          None     Disease     TMPRSS2
#
#        output_id
# 0  NCBIGene:7113
# 1  NCBIGene:7113
# 2  NCBIGene:7113
# 3  NCBIGene:7113

# %% [markdown]
# ## Examples 2 and 3).
# #### Note - the "output_type" always matches the intermediate note type

# %%
ACE2 = ht.query("ACE2")['Gene'][0]
ACE2
# Out:
# {'NCBIGene': '59272',
#  'name': 'angiotensin I converting enzyme 2',
#  'SYMBOL': 'ACE2',
#  'UMLS': 'C1422064',
#  'HGNC': '13557',
#  'UNIPROTKB': 'Q9BYF1',
#  'ENSEMBL': 'ENSG00000130234',
#  'primary': {'identifier': 'NCBIGene', 'cls': 'Gene', 'value': '59272'},
#  'display': 'NCBIGene(59272) ENSEMBL(ENSG00000130234) HGNC(13557) UMLS(C1422064) UNIPROTKB(Q9BYF1) SYMBOL(ACE2)',
#  'type': 'Gene'}

# %%
coagulation = ht.query("coagulation")['BiologicalProcess'][0]
coagulation
# Out:
# {'name': 'Blood coagulation',
#  'UMLS': 'C0005778',
#  'primary': {'identifier': 'UMLS',
#   'cls': 'BiologicalProcess',
#   'value': 'C0005778'},
#  'display': 'UMLS(C0005778) name(Blood coagulation)',
#  'type': 'BiologicalProcess'}

# %%
fc2 = FindConnection(input_obj=coagulation , output_obj=ACE2, intermediate_nodes=['ChemicalSubstance'])
fc2.connect(verbose=False)
fc2.display_table_view()
# Out:
#                input         input_type                 pred1 pred1_source  \
# 0  BLOOD COAGULATION  BiologicalProcess               affects       SEMMED
# 1  BLOOD COAGULATION  BiologicalProcess               affects       SEMMED
# 2  BLOOD COAGULATION  BiologicalProcess               affects       SEMMED
# 3  BLOOD COAGULATION  BiologicalProcess               affects       SEMMED
# 4  BLOOD COAGULATION  BiologicalProcess               affects       SEMMED
# 5  BLOOD COAGULATION  BiologicalProcess  negatively_regulates       SEMMED
# 6  BLOOD COAGULATION  BiologicalProcess  negatively_regulates       SEMMED
# 7  BLOOD COAGULATION  BiologicalProcess               affects       SEMMED
# 8  BLOOD COAGULATION  BiologicalProcess  negatively_regulates       SEMMED
# 9  BLOOD COAGULATION  BiologicalProcess               affects       SEMMED
#
#                        pred1_api  \
# 0  SEMMED Biological Process API
# 1  SEMMED Biological Process API
# 2  SEMMED Biological Process API
# 3  SEMMED Biological Process API
# 4  SEMMED Biological Process API
# 5  SEMMED Biological Process API
# 6  SEMMED Biological Process API
# 7  SEMMED Biological Process API
# 8  SEMMED Biological Process API
# 9  SEMMED Biological Process API
#
#                                         pred1_pubmed         node1_type  \
# 0                           10573178,15730339,347136  ChemicalSubstance
# 1                                   11497206,9409310  ChemicalSubstance
# 2                                            1138422  ChemicalSubstance
# 3           10404500,1437799,1721731,8919633,9778594  ChemicalSubstance
# 4    1138426,1165312,13989793,4287508,505398,6038099  ChemicalSubstance
# 5                                           16907931  ChemicalSubstance
# 6                                           16907931  ChemicalSubstance
# 7                                           14864440  ChemicalSubstance
# 8  11465076,11668424,1782339,22491766,28635544,68...  ChemicalSubstance
# 9  10466727,1115126,11194071,11317484,11796005,12...  ChemicalSubstance
#
#                     node1_name                          node1_id  \
# 0                     C0309049                     UMLS:C0309049
# 1                 NITRIC OXIDE                 name:NITRIC OXIDE
# 2                        WATER                        name:WATER
# 3                      ALCOHOL                      name:ALCOHOL
# 4                     ESTROGEN                     name:ESTROGEN
# 5                 ATORVASTATIN                 name:ATORVASTATIN
# 6                 ATORVASTATIN                 name:ATORVASTATIN
# 7                       CARBON                       name:CARBON
# 8  PHARMACEUTICAL PREPARATIONS  name:PHARMACEUTICAL PREPARATIONS
# 9  PHARMACEUTICAL PREPARATIONS  name:PHARMACEUTICAL PREPARATIONS
#
#                        pred2 pred2_source                    pred2_api  \
# 0  physically_interacts_with       SEMMED              SEMMED Gene API
# 1                 related_to     scigraph  Automat CORD19 Scigraph API
# 2                 related_to         hmdb             Automat HMDB API
# 3  physically_interacts_with       SEMMED              SEMMED Gene API
# 4  physically_interacts_with       SEMMED              SEMMED Gene API
# 5  physically_interacts_with       SEMMED              SEMMED Gene API
# 6       positively_regulates       SEMMED              SEMMED Gene API
# 7       positively_regulates       SEMMED              SEMMED Gene API
# 8       positively_regulates       SEMMED              SEMMED Gene API
# 9       positively_regulates       SEMMED              SEMMED Gene API
#
#   pred2_pubmed        output_type output_name       output_id
# 0     19232015  ChemicalSubstance        ACE2  NCBIGene:59272
# 1         None  ChemicalSubstance        ACE2  NCBIGene:59272
# 2         None  ChemicalSubstance        ACE2  NCBIGene:59272
# 3     26975390  ChemicalSubstance        ACE2  NCBIGene:59272
# 4     28661206  ChemicalSubstance        ACE2  NCBIGene:59272
# 5     25482567  ChemicalSubstance        ACE2  NCBIGene:59272
# 6     25482567  ChemicalSubstance        ACE2  NCBIGene:59272
# 7     26274602  ChemicalSubstance        ACE2  NCBIGene:59272
# 8     16514079  ChemicalSubstance        ACE2  NCBIGene:59272
# 9     16514079  ChemicalSubstance        ACE2  NCBIGene:59272

# %%
fc3 = FindConnection(input_obj=coagulation , output_obj=ACE2, intermediate_nodes=['Disease'])
fc3.connect(verbose=False)
fc3.display_table_view()
# Out:
#                 input         input_type    pred1 pred1_source  \
# 0   BLOOD COAGULATION  BiologicalProcess   causes       SEMMED
# 1   BLOOD COAGULATION  BiologicalProcess   causes       SEMMED
# 2   BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 3   BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 4   BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 5   BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 6   BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 7   BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 8   BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 9   BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 10  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 11  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 12  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 13  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 14  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 15  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 16  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 17  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 18  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 19  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 20  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 21  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 22  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 23  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 24  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 25  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 26  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 27  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 28  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 29  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 30  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 31  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 32  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 33  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 34  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 35  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 36  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 37  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 38  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 39  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 40  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 41  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 42  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 43  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 44  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 45  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 46  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 47  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 48  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 49  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 50  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 51  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 52  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 53  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 54  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 55  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 56  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
# 57  BLOOD COAGULATION  BiologicalProcess  affects       SEMMED
#
#                         pred1_api  \
# 0   SEMMED Biological Process API
# 1   SEMMED Biological Process API
# 2   SEMMED Biological Process API
# 3   SEMMED Biological Process API
# 4   SEMMED Biological Process API
# 5   SEMMED Biological Process API
# 6   SEMMED Biological Process API
# 7   SEMMED Biological Process API
# 8   SEMMED Biological Process API
# 9   SEMMED Biological Process API
# 10  SEMMED Biological Process API
# 11  SEMMED Biological Process API
# 12  SEMMED Biological Process API
# 13  SEMMED Biological Process API
# 14  SEMMED Biological Process API
# 15  SEMMED Biological Process API
# 16  SEMMED Biological Process API
# 17  SEMMED Biological Process API
# 18  SEMMED Biological Process API
# 19  SEMMED Biological Process API
# 20  SEMMED Biological Process API
# 21  SEMMED Biological Process API
# 22  SEMMED Biological Process API
# 23  SEMMED Biological Process API
# 24  SEMMED Biological Process API
# 25  SEMMED Biological Process API
# 26  SEMMED Biological Process API
# 27  SEMMED Biological Process API
# 28  SEMMED Biological Process API
# 29  SEMMED Biological Process API
# 30  SEMMED Biological Process API
# 31  SEMMED Biological Process API
# 32  SEMMED Biological Process API
# 33  SEMMED Biological Process API
# 34  SEMMED Biological Process API
# 35  SEMMED Biological Process API
# 36  SEMMED Biological Process API
# 37  SEMMED Biological Process API
# 38  SEMMED Biological Process API
# 39  SEMMED Biological Process API
# 40  SEMMED Biological Process API
# 41  SEMMED Biological Process API
# 42  SEMMED Biological Process API
# 43  SEMMED Biological Process API
# 44  SEMMED Biological Process API
# 45  SEMMED Biological Process API
# 46  SEMMED Biological Process API
# 47  SEMMED Biological Process API
# 48  SEMMED Biological Process API
# 49  SEMMED Biological Process API
# 50  SEMMED Biological Process API
# 51  SEMMED Biological Process API
# 52  SEMMED Biological Process API
# 53  SEMMED Biological Process API
# 54  SEMMED Biological Process API
# 55  SEMMED Biological Process API
# 56  SEMMED Biological Process API
# 57  SEMMED Biological Process API
#
#                                          pred1_pubmed node1_type  \
# 0                                            17387937    Disease
# 1                                            17387937    Disease
# 2   11521598,12686699,16336698,1704958,18436454,21...    Disease
# 3                 10949875,23646720,23685857,26576222    Disease
# 4                 10949875,23646720,23685857,26576222    Disease
# 5                                   26613657,28164653    Disease
# 6                                   26613657,28164653    Disease
# 7   10899102,10980358,11154116,1428796,15104934,15...    Disease
# 8   11007304,15564436,1745851,2018525,25281773,851...    Disease
# 9          16551218,22930343,2427412,2515600,26368621    Disease
# 10  11383556,12396004,14652070,15130939,15164603,1...    Disease
# 11  11383556,12396004,14652070,15130939,15164603,1...    Disease
# 12  11383556,12396004,14652070,15130939,15164603,1...    Disease
# 13                                           26194691    Disease
# 14                                           26194691    Disease
# 15                                           26194691    Disease
# 16                                           26194691    Disease
# 17                                           26194691    Disease
# 18                                   19381886,7800583    Disease
# 19                                   19381886,7800583    Disease
# 20                                   19381886,7800583    Disease
# 21                                   19381886,7800583    Disease
# 22                                   19381886,7800583    Disease
# 23                                  18487475,27583903    Disease
# 24                                  18487475,27583903    Disease
# 25  12041790,13778492,15025804,15166942,15276651,1...    Disease
# 26  12041790,13778492,15025804,15166942,15276651,1...    Disease
# 27  12041790,13778492,15025804,15166942,15276651,1...    Disease
# 28                          13926256,21420681,2282093    Disease
# 29                                  17785358,28595632    Disease
# 30                                  11019978,16999230    Disease
# 31         19381886,19449748,27661285,5707104,8400086    Disease
# 32         19381886,19449748,27661285,5707104,8400086    Disease
# 33         19381886,19449748,27661285,5707104,8400086    Disease
# 34         19381886,19449748,27661285,5707104,8400086    Disease
# 35         19381886,19449748,27661285,5707104,8400086    Disease
# 36         19381886,19449748,27661285,5707104,8400086    Disease
# 37         19381886,19449748,27661285,5707104,8400086    Disease
# 38                                            7017262    Disease
# 39                                            7017262    Disease
# 40                                            7017262    Disease
# 41                                            7017262    Disease
# 42                                            7017262    Disease
# 43                                           14145147    Disease
# 44                                           14145147    Disease
# 45                                           14145147    Disease
# 46                                           11044636    Disease
# 47                                           12149106    Disease
# 48                                           12149106    Disease
# 49  11019978,11331851,1907333,25024643,28216098,30...    Disease
# 50  11019978,11331851,1907333,25024643,28216098,30...    Disease
# 51                                            8889374    Disease
# 52                                            8537831    Disease
# 53                                            8537831    Disease
# 54                                            8537831    Disease
# 55                          13821254,18257465,2595805    Disease
# 56                                           26743539    Disease
# 57                                           23628972    Disease
#
#                                   node1_name             node1_id       pred2  \
# 0                                   C0221198        UMLS:C0221198    disrupts
# 1                                   C0221198        UMLS:C0221198      causes
# 2                                   C0009566        UMLS:C0009566      causes
# 3                                   C0242606        UMLS:C0242606      causes
# 4                                   C0242606        UMLS:C0242606  related_to
# 5                                   C0277785        UMLS:C0277785    prevents
# 6                                   C0277785        UMLS:C0277785  related_to
# 7                                   C0699748        UMLS:C0699748    prevents
# 8                                   C1155266        UMLS:C1155266    prevents
# 9                                   C0879626        UMLS:C0879626  related_to
# 10                              INFLAMMATION       MONDO:C0021368    disrupts
# 11                              INFLAMMATION       MONDO:C0021368  related_to
# 12                              INFLAMMATION       MONDO:C0021368     affects
# 13                    CARDIOVASCULAR DISEASE  MONDO:MONDO:0004995      causes
# 14                    CARDIOVASCULAR DISEASE  MONDO:MONDO:0004995      treats
# 15                    CARDIOVASCULAR DISEASE  MONDO:MONDO:0004995  related_to
# 16                    CARDIOVASCULAR DISEASE  MONDO:MONDO:0004995  related_to
# 17                    CARDIOVASCULAR DISEASE  MONDO:MONDO:0004995  related_to
# 18                                  DIABETES  MONDO:MONDO:0005015      causes
# 19                                  DIABETES  MONDO:MONDO:0005015  related_to
# 20                                  DIABETES  MONDO:MONDO:0005015  related_to
# 21                                  DIABETES  MONDO:MONDO:0005015  related_to
# 22                                  DIABETES  MONDO:MONDO:0005015  related_to
# 23                             HYPERGLYCEMIA  MONDO:MONDO:0002909      causes
# 24                             HYPERGLYCEMIA  MONDO:MONDO:0002909  related_to
# 25                       DISEASE OR DISORDER  MONDO:MONDO:0000001      treats
# 26                       DISEASE OR DISORDER  MONDO:MONDO:0000001  related_to
# 27                       DISEASE OR DISORDER  MONDO:MONDO:0000001  related_to
# 28                        ARTERIOLOSCLEROSIS  MONDO:MONDO:0006658  related_to
# 29  DIABETES MELLITUS, NON-INSULIN-DEPENDENT  MONDO:MONDO:0015887  related_to
# 30                               HYPERPLASIA  MONDO:MONDO:0005043  related_to
# 31                      HYPERTENSIVE DISEASE  MONDO:MONDO:0005044  related_to
# 32                      HYPERTENSIVE DISEASE  MONDO:MONDO:0005044  related_to
# 33                      HYPERTENSIVE DISEASE  MONDO:MONDO:0005044  related_to
# 34                      HYPERTENSIVE DISEASE  MONDO:MONDO:0005044  related_to
# 35                      HYPERTENSIVE DISEASE  MONDO:MONDO:0005044  related_to
# 36                      HYPERTENSIVE DISEASE  MONDO:MONDO:0005044  related_to
# 37                      HYPERTENSIVE DISEASE  MONDO:MONDO:0005044  related_to
# 38                            KIDNEY DISEASE  MONDO:MONDO:0005240  related_to
# 39                            KIDNEY DISEASE  MONDO:MONDO:0005240  related_to
# 40                            KIDNEY DISEASE  MONDO:MONDO:0005240  related_to
# 41                            KIDNEY DISEASE  MONDO:MONDO:0005240  related_to
# 42                            KIDNEY DISEASE  MONDO:MONDO:0005240  related_to
# 43                     MYOCARDIAL INFARCTION  MONDO:MONDO:0005068  related_to
# 44                     MYOCARDIAL INFARCTION  MONDO:MONDO:0005068  related_to
# 45                     MYOCARDIAL INFARCTION  MONDO:MONDO:0005068  related_to
# 46                         FUSIFORM ANEURYSM  MONDO:MONDO:0005385  related_to
# 47                    ESSENTIAL HYPERTENSION  MONDO:MONDO:0007781  related_to
# 48                    ESSENTIAL HYPERTENSION  MONDO:MONDO:0007781  related_to
# 49                        THROMBOTIC DISEASE  MONDO:MONDO:0000831  related_to
# 50                        THROMBOTIC DISEASE  MONDO:MONDO:0000831  related_to
# 51                             DYSLIPIDEMIAS  MONDO:MONDO:0015123  related_to
# 52                             ATHEROGENESIS  MONDO:MONDO:0005311  related_to
# 53                             ATHEROGENESIS  MONDO:MONDO:0005311  related_to
# 54                             ATHEROGENESIS  MONDO:MONDO:0005311  related_to
# 55                             LIVER DISEASE  MONDO:MONDO:0005154  related_to
# 56                                   MALARIA  MONDO:MONDO:0005136  related_to
# 57                          OBESITY DISORDER  MONDO:MONDO:0011122  related_to
#
#                        pred2_source                    pred2_api  \
# 0                            SEMMED              SEMMED Gene API
# 1                            SEMMED              SEMMED Gene API
# 2                            SEMMED              SEMMED Gene API
# 3                            SEMMED              SEMMED Gene API
# 4                            SEMMED              SEMMED Gene API
# 5                            SEMMED              SEMMED Gene API
# 6                            SEMMED              SEMMED Gene API
# 7                            SEMMED              SEMMED Gene API
# 8                            SEMMED              SEMMED Gene API
# 9                            SEMMED              SEMMED Gene API
# 10                           SEMMED              SEMMED Gene API
# 11                           SEMMED              SEMMED Gene API
# 12                           SEMMED              SEMMED Gene API
# 13                           SEMMED              SEMMED Gene API
# 14                           SEMMED              SEMMED Gene API
# 15                           SEMMED              SEMMED Gene API
# 16                          scibite   Automat CORD19 Scibite API
# 17                         scigraph  Automat CORD19 Scigraph API
# 18                           SEMMED              SEMMED Gene API
# 19                           SEMMED              SEMMED Gene API
# 20                          scibite   Automat CORD19 Scibite API
# 21                         scigraph  Automat CORD19 Scigraph API
# 22                          DISEASE                 DISEASES API
# 23                           SEMMED              SEMMED Gene API
# 24                          DISEASE                 DISEASES API
# 25                           SEMMED              SEMMED Gene API
# 26                           SEMMED              SEMMED Gene API
# 27  Translator Text Mining Provider                CORD Gene API
# 28                           SEMMED              SEMMED Gene API
# 29                           SEMMED              SEMMED Gene API
# 30                           SEMMED              SEMMED Gene API
# 31                           SEMMED              SEMMED Gene API
# 32                         disgenet           mydisease.info API
# 33                          scibite   Automat CORD19 Scibite API
# 34                            hetio            Automat Hetio API
# 35                         scigraph  Automat CORD19 Scigraph API
# 36                              CTD                      CTD API
# 37                          DISEASE                 DISEASES API
# 38                           SEMMED              SEMMED Gene API
# 39                          scibite   Automat CORD19 Scibite API
# 40                         scigraph  Automat CORD19 Scigraph API
# 41                          DISEASE                 DISEASES API
# 42  Translator Text Mining Provider                CORD Gene API
# 43                           SEMMED              SEMMED Gene API
# 44                          scibite   Automat CORD19 Scibite API
# 45                         scigraph  Automat CORD19 Scigraph API
# 46                           SEMMED              SEMMED Gene API
# 47                           SEMMED              SEMMED Gene API
# 48                         scigraph  Automat CORD19 Scigraph API
# 49                           SEMMED              SEMMED Gene API
# 50                          DISEASE                 DISEASES API
# 51                           SEMMED              SEMMED Gene API
# 52                          scibite   Automat CORD19 Scibite API
# 53                         scigraph  Automat CORD19 Scigraph API
# 54                          DISEASE                 DISEASES API
# 55                          DISEASE                 DISEASES API
# 56                          DISEASE                 DISEASES API
# 57                          DISEASE                 DISEASES API
#
#                                          pred2_pubmed output_type output_name  \
# 0                                            18403726     Disease        ACE2
# 1                                            18223023     Disease        ACE2
# 2                                            24270982     Disease        ACE2
# 3                                            22288735     Disease        ACE2
# 4                                            17499227     Disease        ACE2
# 5                                            20660625     Disease        ACE2
# 6                          19015603,22895019,26224885     Disease        ACE2
# 7                                            28142259     Disease        ACE2
# 8                                            27302421     Disease        ACE2
# 9                                            22198016     Disease        ACE2
# 10                                           28279521     Disease        ACE2
# 11                         22330342,23488800,28935757     Disease        ACE2
# 12                                           26224885     Disease        ACE2
# 13                                           22616805     Disease        ACE2
# 14                                           23013041     Disease        ACE2
# 15                         19014390,21099686,27965422     Disease        ACE2
# 16                                               None     Disease        ACE2
# 17                                               None     Disease        ACE2
# 18                                           22616805     Disease        ACE2
# 19       12623933,18948167,22616805,23462816,25791940     Disease        ACE2
# 20                                               None     Disease        ACE2
# 21                                               None     Disease        ACE2
# 22                                               None     Disease        ACE2
# 23                                           26389599     Disease        ACE2
# 24                                               None     Disease        ACE2
# 25                                           20111697     Disease        ACE2
# 26                         19014390,24564768,28425437     Disease        ACE2
# 27                                               None     Disease        ACE2
# 28                         17761934,25482567,28413960     Disease        ACE2
# 29                                  23462816,27312782     Disease        ACE2
# 30                                           24158104     Disease        ACE2
# 31  17761934,18367030,19014390,19927150,21099686,2...     Disease        ACE2
# 32                                               None     Disease        ACE2
# 33                                               None     Disease        ACE2
# 34                                               None     Disease        ACE2
# 35                                               None     Disease        ACE2
# 36  12075344|15833808|17473847|18391097|19221212|2...     Disease        ACE2
# 37                                               None     Disease        ACE2
# 38                         18367030,26102692,28413960     Disease        ACE2
# 39                                               None     Disease        ACE2
# 40                                               None     Disease        ACE2
# 41                                               None     Disease        ACE2
# 42                                               None     Disease        ACE2
# 43                                           17345786     Disease        ACE2
# 44                                               None     Disease        ACE2
# 45                                               None     Disease        ACE2
# 46                                           24799609     Disease        ACE2
# 47                                           17473847     Disease        ACE2
# 48                                               None     Disease        ACE2
# 49                                           20111697     Disease        ACE2
# 50                                               None     Disease        ACE2
# 51                                           21670585     Disease        ACE2
# 52                                               None     Disease        ACE2
# 53                                               None     Disease        ACE2
# 54                                               None     Disease        ACE2
# 55                                               None     Disease        ACE2
# 56                                               None     Disease        ACE2
# 57                                               None     Disease        ACE2
#
#          output_id
# 0   NCBIGene:59272
# 1   NCBIGene:59272
# 2   NCBIGene:59272
# 3   NCBIGene:59272
# 4   NCBIGene:59272
# 5   NCBIGene:59272
# 6   NCBIGene:59272
# 7   NCBIGene:59272
# 8   NCBIGene:59272
# 9   NCBIGene:59272
# 10  NCBIGene:59272
# 11  NCBIGene:59272
# 12  NCBIGene:59272
# 13  NCBIGene:59272
# 14  NCBIGene:59272
# 15  NCBIGene:59272
# 16  NCBIGene:59272
# 17  NCBIGene:59272
# 18  NCBIGene:59272
# 19  NCBIGene:59272
# 20  NCBIGene:59272
# 21  NCBIGene:59272
# 22  NCBIGene:59272
# 23  NCBIGene:59272
# 24  NCBIGene:59272
# 25  NCBIGene:59272
# 26  NCBIGene:59272
# 27  NCBIGene:59272
# 28  NCBIGene:59272
# 29  NCBIGene:59272
# 30  NCBIGene:59272
# 31  NCBIGene:59272
# 32  NCBIGene:59272
# 33  NCBIGene:59272
# 34  NCBIGene:59272
# 35  NCBIGene:59272
# 36  NCBIGene:59272
# 37  NCBIGene:59272
# 38  NCBIGene:59272
# 39  NCBIGene:59272
# 40  NCBIGene:59272
# 41  NCBIGene:59272
# 42  NCBIGene:59272
# 43  NCBIGene:59272
# 44  NCBIGene:59272
# 45  NCBIGene:59272
# 46  NCBIGene:59272
# 47  NCBIGene:59272
# 48  NCBIGene:59272
# 49  NCBIGene:59272
# 50  NCBIGene:59272
# 51  NCBIGene:59272
# 52  NCBIGene:59272
# 53  NCBIGene:59272
# 54  NCBIGene:59272
# 55  NCBIGene:59272
# 56  NCBIGene:59272
# 57  NCBIGene:59272

# %% [markdown]
# ## Example 4)
# #### Showing how "directionality" in relationship explanation is from output -> intermediate, not intermediate -> output

# %%
heparin = ht.query("heparin")['ChemicalSubstance'][0]
heparin
# Out:
# {'DRUGBANK': 'DB02322',
#  'CHEBI': 'CHEBI:43053',
#  'name': 'heparin disaccharide I-S(4-)',
#  'primary': {'identifier': 'CHEBI',
#   'cls': 'ChemicalSubstance',
#   'value': 'CHEBI:43053'},
#  'display': 'CHEBI(CHEBI:43053) DRUGBANK(DB02322) name(heparin disaccharide I-S(4-))',
#  'type': 'ChemicalSubstance'}

# %%
fc4 = FindConnection(input_obj=coagulation, output_obj=heparin, intermediate_nodes=['ChemicalSubstance'])
fc4.connect(verbose=False)
fc4_table = fc4.display_table_view()

# %%
## switch input and output
fc5 = FindConnection(input_obj=heparin, output_obj=coagulation, intermediate_nodes=['ChemicalSubstance'])
fc5.connect(verbose=False)
fc5_table = fc5.display_table_view()

# %%
## In fc4_table, BLOOD COAGULATION negatively_regulates Histamine (correct)
fc4_table[(fc4_table["node1_name"] == "HISTAMINE")]
# Out:
#                  input         input_type                 pred1 pred1_source  \
# 146  BLOOD COAGULATION  BiologicalProcess  negatively_regulates       SEMMED
# 147  BLOOD COAGULATION  BiologicalProcess  negatively_regulates       SEMMED
# 148  BLOOD COAGULATION  BiologicalProcess  negatively_regulates       SEMMED
# 149  BLOOD COAGULATION  BiologicalProcess  negatively_regulates       SEMMED
#
#                          pred1_api       pred1_pubmed         node1_type  \
# 146  SEMMED Biological Process API  10956000,11058753  ChemicalSubstance
# 147  SEMMED Biological Process API  10956000,11058753  ChemicalSubstance
# 148  SEMMED Biological Process API  10956000,11058753  ChemicalSubstance
# 149  SEMMED Biological Process API  10956000,11058753  ChemicalSubstance
#
#     node1_name        node1_id                      pred2 pred2_source  \
# 146  HISTAMINE  name:HISTAMINE  physically_interacts_with       SEMMED
# 147  HISTAMINE  name:HISTAMINE       positively_regulates       SEMMED
# 148  HISTAMINE  name:HISTAMINE              coexists_with       SEMMED
# 149  HISTAMINE  name:HISTAMINE       negatively_regulates       SEMMED
#
#                pred2_api                                       pred2_pubmed  \
# 146  SEMMED Chemical API  10736153,14457489,16857468,2785115,6186613,851...
# 147  SEMMED Chemical API                            2418707,8246198,9931190
# 148  SEMMED Chemical API                                            8887573
# 149  SEMMED Chemical API                                           10875752
#
#            output_type output_name     output_id
# 146  ChemicalSubstance     HEPARIN  name:HEPARIN
# 147  ChemicalSubstance     HEPARIN  name:HEPARIN
# 148  ChemicalSubstance     HEPARIN  name:HEPARIN
# 149  ChemicalSubstance     HEPARIN  name:HEPARIN

# %%
## In fc5_table, it appears as if Histamine negatively_regulates Blood Coagulation (incorrect)
fc5_table[(fc5_table["node1_name"] == "HISTAMINE")]
# Out:
#       input         input_type                      pred1 pred1_source  \
# 84  HEPARIN  ChemicalSubstance  physically_interacts_with       SEMMED
# 85  HEPARIN  ChemicalSubstance       positively_regulates       SEMMED
# 86  HEPARIN  ChemicalSubstance              coexists_with       SEMMED
# 87  HEPARIN  ChemicalSubstance       negatively_regulates       SEMMED
#
#               pred1_api                                       pred1_pubmed  \
# 84  SEMMED Chemical API  10736153,14457489,16857468,2785115,6186613,851...
# 85  SEMMED Chemical API                            2418707,8246198,9931190
# 86  SEMMED Chemical API                                            8887573
# 87  SEMMED Chemical API                                           10875752
#
#            node1_type node1_name        node1_id                 pred2  \
# 84  ChemicalSubstance  HISTAMINE  name:HISTAMINE  negatively_regulates
# 85  ChemicalSubstance  HISTAMINE  name:HISTAMINE  negatively_regulates
# 86  ChemicalSubstance  HISTAMINE  name:HISTAMINE  negatively_regulates
# 87  ChemicalSubstance  HISTAMINE  name:HISTAMINE  negatively_regulates
#
#    pred2_source                      pred2_api       pred2_pubmed  \
# 84       SEMMED  SEMMED Biological Process API  10956000,11058753
# 85       SEMMED  SEMMED Biological Process API  10956000,11058753
# 86       SEMMED  SEMMED Biological Process API  10956000,11058753
# 87       SEMMED  SEMMED Biological Process API  10956000,11058753
#
#           output_type        output_name               output_id
# 84  ChemicalSubstance  BLOOD COAGULATION  name:BLOOD COAGULATION
# 85  ChemicalSubstance  BLOOD COAGULATION  name:BLOOD COAGULATION
# 86  ChemicalSubstance  BLOOD COAGULATION  name:BLOOD COAGULATION
# 87  ChemicalSubstance  BLOOD COAGULATION  name:BLOOD COAGULATION
