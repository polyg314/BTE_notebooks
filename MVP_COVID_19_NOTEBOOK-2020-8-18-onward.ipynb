# %% [markdown]
# # TABLE OF CONTENTS
#
# ## 1 USE CASE: COVID-19
# ###  &emsp; 1.1 What genes are connected to COVID-19?
# ####  &emsp; &emsp; 1.1.1 COVID-19 -> Genes (determine directly related)
# ####  &emsp; &emsp; 1.1.2 COVID-19 -> All intermediate node types -> Genes
# ###  &emsp; 1.2 What are the symptoms that are related to COVID-19?
# ####  &emsp; &emsp; 1.2.1 Determine Symptoms thru MyDisease API (via HPO data)
# ###  &emsp; 1.3 Which of the genes related to COVID-19 are related to symptoms of COVID-19?
# ####  &emsp; &emsp; 1.3.1 Genes (from 1.1) -> Symptoms (From 1.2.1)
# ####  &emsp; &emsp; 1.3.2 Genes (from 1.1) -> [Drugs, SequenceVariant, Pathways, MolecularActivity] -> Symptoms (From 1.2.1)
# ###  &emsp; 1.4 Assembly of Results

# %%
###### CODE SETUP 

## First get all the functions set up
import pandas as pd
import requests
import difflib
import math


## Load BTE
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

## Functions that will be used
# Check for every intermediate node type in Predict funciton
def predict_many(input_object, intermediate_node_list, output_type):
    df_list = []
    for inter in intermediate_node_list:
        try: 
            print("Intermediate Node type running:")
            print(inter)
            fc = FindConnection(input_obj=input_object, output_obj=output_type, intermediate_nodes=[inter])
            fc.connect(verbose=False)
            df = fc.display_table_view()
            rows = df.shape[0]
            if(rows > 0):
                df_list.append(df)
        except:
            print("FAILED")
    if(len(df_list) > 0):
        return pd.concat(df_list)
    else:
        return None
    
# all intermediate node types
node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                   'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                   'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %% [markdown]
# ## 1.1 What genes are connected to COVID-19?

# %% [markdown]
# ### 1.1.1 COVID-19 -> Genes (determine directly related)

# %%
## get COVID-19
covid19 = ht.query("COVID-19")['Disease'][0]
covid19
# Out:
# {'MONDO': 'MONDO:0100096',
#  'DOID': 'DOID:0080600',
#  'name': 'COVID-19',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0100096'},
#  'display': 'MONDO(MONDO:0100096) DOID(DOID:0080600) name(COVID-19)',
#  'type': 'Disease'}

# %%
fc = FindConnection(input_obj=covid19, output_obj='Gene', intermediate_nodes=None)
fc.connect(verbose=False)
covid19_to_genes = fc.display_table_view()
covid19_to_genes
# Out:
#       input input_type       pred1 pred1_source                    pred1_api  \
# 0  COVID-19    Disease  related_to      DISEASE                 DISEASES API
# 1  COVID-19    Disease  related_to      DISEASE                 DISEASES API
# 2  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 3  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 4  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 5  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 6  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 7  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
# 8  COVID-19    Disease  related_to     scigraph  Automat CORD19 Scigraph API
#
#   pred1_pubmed output_type output_name        output_id
# 0         None        Gene        EID2  NCBIGene:163126
# 1         None        Gene        ACE2   NCBIGene:59272
# 2         None        Gene        ACE2   NCBIGene:59272
# 3         None        Gene         SON    NCBIGene:6651
# 4         None        Gene         CRP    NCBIGene:1401
# 5         None        Gene       MARS1    NCBIGene:4141
# 6         None        Gene         POR    NCBIGene:5447
# 7         None        Gene          TH    NCBIGene:7054
# 8         None        Gene     TMPRSS2    NCBIGene:7113

# %%
# keep track of number of occurrences from direct covid-19 -> gene connection
i = list(covid19_to_genes["output_name"])
d = {x:i.count(x) for x in i}
sorted_genes_covid_2_genes = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
sorted_genes_covid_2_genes
# Out:
# {'EID2': 1,
#  'SON': 1,
#  'CRP': 1,
#  'MARS1': 1,
#  'POR': 1,
#  'TH': 1,
#  'TMPRSS2': 1,
#  'ACE2': 2}

# %% [markdown]
# ### 1.1.2 COVID-19 -> All intermediate node types -> Genes

# %%
# use predict_many function to try many intermediates from one function 
covid_allNodes_Genes = predict_many(covid19, node_type_list, 'Gene')
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# API 1.1 pharos failed
# Intermediate Node type running:
# Disease
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature

# %%
## Genes identified = HUGE NUMBER (13562)
len(list(covid_allNodes_Genes["output_name"]))
# Out:
# 14066

# %%
# sort genes by the number of occurrences
i = list(covid_allNodes_Genes["output_name"])
d = {x:i.count(x) for x in i}
sorted_genes_covid_2_allNodes_2_genes = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
for x in list(reversed(list(sorted_genes_covid_2_allNodes_2_genes)))[0:100]:
    print(str(x) + ": " + str(sorted_genes_covid_2_allNodes_2_genes[x]))
# Out:
# TNF: 44
# CYP3A4: 33
# CAT: 32
# INS: 27
# C0017337: 26
# C0014442: 26
# CYP2D6: 25
# AKT1: 25
# ANG: 24
# IL6: 23
# ABCB1: 22
# TP53: 19
# C1705556: 18
# FOS: 18
# MAPK1: 18
# ACE2: 18
# ACE: 18
# HIF1A: 17
# SQSTM1: 17
# CYP1A2: 17
# C0010762: 17
# AR: 17
# APP: 17
# TLR9: 16
# CDKN1A: 16
# C0164786: 16
# TH: 16
# PPIG: 16
# CD4: 16
# ALB: 16
# SOD1: 15
# BAX: 15
# C1705526: 15
# CYP2C9: 15
# VEGFA: 15
# EGFR: 15
# LEP: 15
# IL1B: 15
# IFNA1: 15
# RELA: 15
# CAMP: 15
# C0010531: 15
# C0030956: 15
# SOD2: 14
# MTOR: 14
# MAPK8: 14
# CA2: 14
# EPO: 14
# MPO: 14
# CASP3: 14
# TTR: 14
# ERVK-10: 14
# AGTR1: 14
# C0033634: 14
# TLR7: 13
# CYP2B6: 13
# C0020364: 13
# C1142644: 13
# IL2: 13
# CCL2: 13
# C1705846: 13
# C0669372: 12
# C0208355: 12
# C3539722: 12
# CYP3A5: 12
# TLR4: 12
# MMP9: 12
# MAPK3: 12
# CXCL8: 12
# ATM: 12
# TGFB1: 12
# CXCR4: 11
# BCL2: 11
# FAS: 11
# C0033640: 11
# C2985367: 11
# CYP2E1: 11
# C0030016: 11
# C2699841: 11
# PTH: 11
# NOS3: 11
# ICAM1: 11
# MMP2: 11
# C0669365: 11
# C1709136: 11
# G6PD: 10
# CRP: 10
# STAT3: 10
# DNAH8: 10
# C1705581: 10
# C0242417: 10
# HMOX1: 10
# CYP1A1: 10
# CYP2C19: 10
# POMC: 10
# POR: 10
# C0059563: 10
# C1707177: 10
# CS: 10
# GSR: 10

# %%
## store top genes
top_related_genes_covid_2_allNodes_2_genes = list(reversed(list(sorted_genes_covid_2_allNodes_2_genes)))[0:100]
top_related_genes_covid_2_allNodes_2_genes = top_related_genes_covid_2_allNodes_2_genes + list(sorted_genes_covid_2_genes.keys())
top_related_genes_covid_2_allNodes_2_genes = list(dict.fromkeys(top_related_genes_covid_2_allNodes_2_genes))
top_related_genes_covid_2_allNodes_2_genes
# Out:
# ['TNF',
#  'CYP3A4',
#  'CAT',
#  'INS',
#  'C0017337',
#  'C0014442',
#  'CYP2D6',
#  'AKT1',
#  'ANG',
#  'IL6',
#  'ABCB1',
#  'TP53',
#  'C1705556',
#  'FOS',
#  'MAPK1',
#  'ACE2',
#  'ACE',
#  'HIF1A',
#  'SQSTM1',
#  'CYP1A2',
#  'C0010762',
#  'AR',
#  'APP',
#  'TLR9',
#  'CDKN1A',
#  'C0164786',
#  'TH',
#  'PPIG',
#  'CD4',
#  'ALB',
#  'SOD1',
#  'BAX',
#  'C1705526',
#  'CYP2C9',
#  'VEGFA',
#  'EGFR',
#  'LEP',
#  'IL1B',
#  'IFNA1',
#  'RELA',
#  'CAMP',
#  'C0010531',
#  'C0030956',
#  'SOD2',
#  'MTOR',
#  'MAPK8',
#  'CA2',
#  'EPO',
#  'MPO',
#  'CASP3',
#  'TTR',
#  'ERVK-10',
#  'AGTR1',
#  'C0033634',
#  'TLR7',
#  'CYP2B6',
#  'C0020364',
#  'C1142644',
#  'IL2',
#  'CCL2',
#  'C1705846',
#  'C0669372',
#  'C0208355',
#  'C3539722',
#  'CYP3A5',
#  'TLR4',
#  'MMP9',
#  'MAPK3',
#  'CXCL8',
#  'ATM',
#  'TGFB1',
#  'CXCR4',
#  'BCL2',
#  'FAS',
#  'C0033640',
#  'C2985367',
#  'CYP2E1',
#  'C0030016',
#  'C2699841',
#  'PTH',
#  'NOS3',
#  'ICAM1',
#  'MMP2',
#  'C0669365',
#  'C1709136',
#  'G6PD',
#  'CRP',
#  'STAT3',
#  'DNAH8',
#  'C1705581',
#  'C0242417',
#  'HMOX1',
#  'CYP1A1',
#  'CYP2C19',
#  'POMC',
#  'POR',
#  'C0059563',
#  'C1707177',
#  'CS',
#  'GSR',
#  'EID2',
#  'SON',
#  'MARS1',
#  'TMPRSS2']

# %%
# keep track of pubication counts for genes in two-step covid -> gene
top_genes_pub_counts = {}
for index, row in covid_allNodes_Genes.iterrows():
    if row["output_name"] in top_related_genes_covid_2_allNodes_2_genes:
        current_pubcount = 0
        if(row["pred1_pubmed"] != None):
            current_pubcount = current_pubcount + row["pred1_pubmed"].count(",") + 1
        if(row["pred2_pubmed"] != None):
            current_pubcount = current_pubcount + row["pred2_pubmed"].count(",") + 1
        if row["output_name"] in top_genes_pub_counts:
            top_genes_pub_counts[row["output_name"]] = top_genes_pub_counts[row["output_name"]] + current_pubcount
        else: 
            top_genes_pub_counts[row["output_name"]] = current_pubcount

top_genes_pub_counts
# Out:
# {'C1709136': 26,
#  'C0669365': 26,
#  'C1705846': 30,
#  'C0014442': 331,
#  'C0017337': 196,
#  'C0030956': 38,
#  'C0010531': 66,
#  'C0033634': 48,
#  'ACE': 32,
#  'AGTR1': 10,
#  'ANG': 78,
#  'ACE2': 24,
#  'TGFB1': 21,
#  'APP': 21,
#  'CAMP': 71,
#  'ATM': 21,
#  'ERVK-10': 24,
#  'MMP2': 23,
#  'TTR': 8,
#  'MAPK1': 40,
#  'RELA': 32,
#  'CAT': 98,
#  'TMPRSS2': 3,
#  'INS': 53,
#  'CASP3': 75,
#  'AKT1': 51,
#  'ICAM1': 14,
#  'IFNA1': 15,
#  'IL1B': 39,
#  'CXCL8': 19,
#  'IL6': 58,
#  'CCL2': 29,
#  'LEP': 20,
#  'MAPK3': 26,
#  'MMP9': 22,
#  'MPO': 33,
#  'NOS3': 19,
#  'ALB': 9,
#  'EGFR': 8,
#  'AR': 11,
#  'EPO': 26,
#  'FOS': 34,
#  'GSR': 10,
#  'TNF': 114,
#  'TLR4': 10,
#  'PTH': 4,
#  'VEGFA': 150,
#  'IL2': 12,
#  'C1705556': 146,
#  'C2699841': 20,
#  'MARS1': 5,
#  'CS': 5,
#  'CD4': 10,
#  'C1707177': 33,
#  'C0010762': 80,
#  'C0030016': 51,
#  'C0059563': 70,
#  'C1142644': 93,
#  'C0020364': 43,
#  'PPIG': 45,
#  'POR': 15,
#  'CYP1A2': 25,
#  'CYP2E1': 9,
#  'CYP3A4': 69,
#  'CYP3A5': 3,
#  'CYP2C9': 11,
#  'CYP2D6': 18,
#  'POMC': 10,
#  'TH': 541,
#  'ABCB1': 25,
#  'CYP2C19': 6,
#  'CYP2B6': 9,
#  'CYP1A1': 27,
#  'HMOX1': 41,
#  'C3539722': 27,
#  'C2985367': 43,
#  'C0033640': 41,
#  'C0208355': 27,
#  'C0242417': 60,
#  'C0669372': 27,
#  'C1705581': 14,
#  'C0164786': 27,
#  'C1705526': 31,
#  'SQSTM1': 45,
#  'DNAH8': 7,
#  'CDKN1A': 29,
#  'STAT3': 13,
#  'CA2': 80,
#  'MAPK8': 24,
#  'MTOR': 21,
#  'TP53': 42,
#  'BAX': 30,
#  'FAS': 8,
#  'HIF1A': 205,
#  'BCL2': 33,
#  'TLR7': 9,
#  'TLR9': 15,
#  'CXCR4': 16,
#  'CRP': 0,
#  'SOD1': 26,
#  'G6PD': 10,
#  'SOD2': 40,
#  'SON': 2}

# %% [markdown]
# ## 1.2 What are the symptoms that are related to COVID-19?

# %% [markdown]
# ## 1.2.1 Determine Symptoms thru MyDisease API (via HPO data)
# http://mydisease.info/v1/query?q=coronavirus&fields=hpo

# %%
# NOTE: USING "Acute respiratory coronavirus infection" - not COVID-19. This could be a source of error present
# for this use case that hopefully wont occur with other more established disease use cases. 

disease_name = 'coronavirus'
r = requests.get('http://mydisease.info/v1/query?q=' + disease_name + '&fields=hpo')
res = r.json()
result_number = 1
disease_info = res['hits'][result_number]
symptoms = []
for x in disease_info['hpo']['phenotype_related_to_disease']:
#     print(x)
    r1 = requests.get('https://biothings.ncats.io/hpo/phenotype/' + x['frequency'])
    res1 = r1.json()
#     print(res1['name'])
    # in this case, only list symptoms if they are "frequent" or more. 
    if 'frequent' in res1['name'].lower():
        r = requests.get('https://biothings.ncats.io/hpo/phenotype/' + x['hpo_id'])
        res = r.json()
#         print(res['name'])
        if(('_id' in res) & ('name' in res)):
            symptoms.append(res['name'].lower())
        if('synonym' in res):
            for z in res['synonym']:
                if('EXACT' in z):
                    name = z.split('"')[1].lower()
                    if name not in symptoms: 
                        symptoms.append(name)
                        
print(symptoms)
# Out:
# ['cough', 'coughing', 'fever', 'hyperthermia', 'pyrexia', 'dyspnea', 'abnormal breathing', 'breathing difficulty', 'difficult to breathe', 'dyspnoea', 'trouble breathing', 'respiratory distress', 'breathing difficulties', 'difficulty breathing', 'respiratory difficulties', 'headache', 'headaches', 'immunodeficiency', 'decreased immune function', 'immune deficiency', 'myalgia', 'muscle ache', 'muscle pain']

# %%
# del symptoms[symptoms.index('diabetes mellitus')]
# del symptoms[symptoms.index('acute kidney injury')]
# del symptoms[symptoms.index('acute kidney failure')]
# del symptoms[symptoms.index('acute renal failure')]
del symptoms[symptoms.index('immunodeficiency')]
del symptoms[symptoms.index('decreased immune function')]
del symptoms[symptoms.index('immune deficiency')]
symptom_and_phenotype_list = symptoms

symptom_and_phenotype_list.append('blood coagulation')
symptom_and_phenotype_list.append('coagulation')
symptom_and_phenotype_list.append('blood clotting')
symptom_and_phenotype_list
# Out:
# ['cough',
#  'coughing',
#  'fever',
#  'hyperthermia',
#  'pyrexia',
#  'dyspnea',
#  'abnormal breathing',
#  'breathing difficulty',
#  'difficult to breathe',
#  'dyspnoea',
#  'trouble breathing',
#  'respiratory distress',
#  'breathing difficulties',
#  'difficulty breathing',
#  'respiratory difficulties',
#  'headache',
#  'headaches',
#  'myalgia',
#  'muscle ache',
#  'muscle pain',
#  'blood coagulation',
#  'coagulation',
#  'blood clotting']

# %% [markdown]
# ### 1.3 Which of the genes related to COVID-19 are related to symptoms of COVID-19?

# %% [markdown]
# ### 1.3.1 Genes (from 1.1) -> Symptoms (From 1.2.1)
#
# #### 1.3.1.1 Gene -> Phenotype type "symptoms"

# %%
df_list = []
for x in top_related_genes_covid_2_allNodes_2_genes: 
#     print(x)
    try: 
        gene = ht.query(x)["Gene"][0]
        fc = FindConnection(input_obj=gene, output_obj='PhenotypicFeature', intermediate_nodes=None)
        fc.connect(verbose=False)
        df = fc.display_table_view()
        rows = df.shape[0]
        if(rows > 0):
            df_list.append(df)
    except:
        print(str(x) + " FAILED")
if(len(df_list) > 0):
    top_gene_2_phenotypicFeature = pd.concat(df_list)
# Out:
# C0017337 FAILED
# C0014442 FAILED
# C1705556 FAILED
# C0010762 FAILED
# C0164786 FAILED
# C1705526 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0010531 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0030956 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0033634 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0020364 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C1142644 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C1705846 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0669372 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0208355 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C3539722 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0033640 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C2985367 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0030016 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C2699841 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0669365 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C1709136 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C1705581 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0242417 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C0059563 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# C1707177 FAILED
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info
# 0, message='Attempt to decode JSON with unexpected mimetype: text/html', url=URL('http://mydisease.info/v1/query?fields=_id,mondo.xrefs.doid,mondo.xrefs.umls,disgenet.xrefs.umls,mondo.label,disgenet.xrefs.disease_name,mondo.xrefs.mesh,ctd.mesh,mondo.xrefs.omim,hpo.omim,hpo.orphanet,mondo.xrefs.orphanet&dotfield=true&species=human&size=5')
# Unable to fetch results from mydisease.info

# %%
top_gene_2_phenotypicFeature.shape
# Out:
# (2078, 9)

# %%
## Get names for HP ids
HP_ids = top_gene_2_phenotypicFeature[top_gene_2_phenotypicFeature["output_name"].str.contains("HP:",regex=False)]["output_name"]
HP_ids = list(HP_ids)
HP_ids = list(dict.fromkeys(HP_ids))
len(HP_ids)
HP_dict = {}
for x in HP_ids: 
    HP_ID = x.split(':')[1]
    r = requests.get('https://biothings.ncats.io/hpo/phenotype/HP%3A' + HP_ID)
    res = r.json()
    if(('_id' in res) & ('name' in res)):
        HP_dict[res['_id']] = res['name'].lower()

# %%
def get_similar_phen_indices(list1,list2,similarity):
    res = [] 
    i = 0
    while (i < len(list1)):
        append_i = False
        lookup = list1[i].lower()
        if('HP:' in list1[i]):
            if(list1[i]  in HP_dict):
                lookup = HP_dict[list1[i]]
        for j in list2:
                if(difflib.SequenceMatcher(None,lookup,j).ratio() > similarity):
                    append_i = True
        if(append_i): 
            res.append(i) 
        i += 1
    return(res)

# %%
phen_indices = get_similar_phen_indices(list(top_gene_2_phenotypicFeature["output_name"]),symptom_and_phenotype_list,0.9)

# %%
phen_top = top_gene_2_phenotypicFeature.iloc[phen_indices,:]
# phen_top
for index in range(phen_top.shape[0]):
#     if("HP:" in row['output_name']):
#     print(index)
    if(phen_top.iloc[index]["output_name"] in HP_dict):
        phen_top.iloc[index]["output_name"] = HP_dict[phen_top.iloc[index]["output_name"]]

phen_top
# Out:
#       input input_type       pred1 pred1_source              pred1_api  \
# 6       ANG       Gene  related_to         None            BioLink API
# 22     TP53       Gene  related_to         None            BioLink API
# 47     TP53       Gene  related_to         None            BioLink API
# 96     TP53       Gene  related_to         None            BioLink API
# 39      FOS       Gene  related_to         None            BioLink API
# 50   SQSTM1       Gene  related_to         None            BioLink API
# 43      APP       Gene  related_to         None            BioLink API
# 19       TH       Gene  related_to         None            BioLink API
# 24     SOD1       Gene  related_to         None            BioLink API
# 32      TTR       Gene  related_to         None            BioLink API
# 95      ATM       Gene  related_to         None            BioLink API
# 115   TGFB1       Gene  related_to         None            BioLink API
# 116   TGFB1       Gene  related_to          EBI  EBIgene2phenotype API
# 66      FAS       Gene  related_to         None            BioLink API
# 2      G6PD       Gene  related_to         None            BioLink API
# 28    STAT3       Gene  related_to         None            BioLink API
# 62    STAT3       Gene  related_to         None            BioLink API
# 5     MARS1       Gene  related_to         None            BioLink API
# 8     MARS1       Gene  related_to         None            BioLink API
#
#                                           pred1_pubmed        output_type  \
# 6                                                 None  PhenotypicFeature
# 22                                                None  PhenotypicFeature
# 47                                                None  PhenotypicFeature
# 96                                                None  PhenotypicFeature
# 39                                                None  PhenotypicFeature
# 50                                                None  PhenotypicFeature
# 43                                                None  PhenotypicFeature
# 19   10407773,9732974,0011551,21937992,20430833,252...  PhenotypicFeature
# 24                                                None  PhenotypicFeature
# 32   3479441,7839813,7914929,17503405,24555660,2383...  PhenotypicFeature
# 95                                                None  PhenotypicFeature
# 115                                           15894597  PhenotypicFeature
# 116                         10973241,11062463,15103729  PhenotypicFeature
# 66                                                None  PhenotypicFeature
# 2    24505519,21479984,2572288,27040960,8611726,794...  PhenotypicFeature
# 28                                                None  PhenotypicFeature
# 62                                                None  PhenotypicFeature
# 5                                                 None  PhenotypicFeature
# 8                                                 None  PhenotypicFeature
#
#     output_name      output_id
# 6       dyspnea  HP:HP:0002094
# 22        fever  HP:HP:0001945
# 47      dyspnea  HP:HP:0002094
# 96     headache  HP:HP:0002315
# 39      myalgia  HP:HP:0003326
# 50      dyspnea  HP:HP:0002094
# 43     headache  HP:HP:0002315
# 19        fever  HP:HP:0001945
# 24      dyspnea  HP:HP:0002094
# 32     headache  HP:HP:0002315
# 95        fever  HP:HP:0001945
# 115    headache  HP:HP:0002315
# 116    headache  HP:HP:0002315
# 66     headache  HP:HP:0002315
# 2         fever  HP:HP:0001945
# 28        cough  HP:HP:0012735
# 62        fever  HP:HP:0001945
# 5         cough  HP:HP:0012735
# 8       dyspnea  HP:HP:0002094

# %% [markdown]
# #### 1.3.1.2  Gene -> Bioprocess type "symptoms"

# %%
df_list = []
for x in top_related_genes_covid_2_allNodes_2_genes: 
#     print(x)
    try: 
        gene = ht.query(x)["Gene"][0]
        fc = FindConnection(input_obj=gene, output_obj='BiologicalProcess', intermediate_nodes=None)
        fc.connect(verbose=False)
        df = fc.display_table_view()
        rows = df.shape[0]
        if(rows > 0):
            df_list.append(df)
    except:
        print(str(x) + " FAILED")
if(len(df_list) > 0):
    top_gene_2_bioprocesses = pd.concat(df_list)
# Out:
# C0017337 FAILED
# C0014442 FAILED
# C1705556 FAILED
# C0010762 FAILED
# C0164786 FAILED
# C1705526 FAILED
# C0010531 FAILED
# C0030956 FAILED
# C0033634 FAILED
# C0020364 FAILED
# C1142644 FAILED
# C1705846 FAILED
# C0669372 FAILED
# C0208355 FAILED
# C3539722 FAILED
# C0033640 FAILED
# C2985367 FAILED
# C0030016 FAILED
# C2699841 FAILED
# C0669365 FAILED
# C1709136 FAILED
# C1705581 FAILED
# C0242417 FAILED
# C0059563 FAILED
# C1707177 FAILED

# %%
top_gene_2_bioprocesses.shape
# Out:
# (25042, 9)

# %%
## Get names for go ids
go_ids = top_gene_2_bioprocesses[top_gene_2_bioprocesses["output_name"].str.contains("go:",regex=False)]["output_name"]
go_ids = list(go_ids)
go_ids = list(dict.fromkeys(go_ids))
len(go_ids)
go_dict = {}
for x in go_ids: 
    go_ID = x.split(':')[1]
    r = requests.get('https://biothings.ncats.io/go_bp/geneset/GO%3A' + go_ID)
    res = r.json()
    if('name' in res):
        go_dict[res['_id']] = res['name'].lower()

# %%
def get_similar_bp_indices(list1,list2,similarity):
    res = [] 
    i = 0
    while (i < len(list1)):
        append_i = False
        lookup = list1[i].lower()
        if('go:' in list1[i]):
            if list1[i] in go_dict:
                lookup = go_dict[list1[i]]
        for j in list2:
                if(difflib.SequenceMatcher(None,lookup,j).ratio() > similarity):
    #                 if(i < 3):
                    print("Matched similar terms:")
                    print(lookup + ' and ' + j)
#                     print()
                    append_i = True
        if(append_i): 
            res.append(i) 
        i += 1
#     print(len(res))
    return(res)

# %%
bp_indices = get_similar_bp_indices(list(top_gene_2_bioprocesses["output_name"]),symptom_and_phenotype_list,0.9)
# Out:
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# coagulation and coagulation
# Matched similar terms:
# blood coagulation and blood coagulation
# Matched similar terms:
# coagulation and coagulation

# %%
bioprocess_top = top_gene_2_bioprocesses.iloc[bp_indices,:]
bioprocess_top
# Out:
#         input input_type                   pred1  \
# 1164      TNF       Gene              related_to
# 840       INS       Gene              related_to
# 847       INS       Gene              related_to
# 821      AKT1       Gene              related_to
# 358       IL6       Gene              related_to
# 576     MAPK1       Gene              related_to
# 4         ALB       Gene                 affects
# 516     VEGFA       Gene                disrupts
# 615     IFNA1       Gene  functional_association
# 390     MAPK8       Gene              related_to
# 129       EPO       Gene              related_to
# 134       TTR       Gene              related_to
# 12    ERVK-10       Gene                 affects
# 394       IL2       Gene              related_to
# 15       TLR4       Gene                 affects
# 36        CRP       Gene              related_to
# 11       POMC       Gene                 affects
# 348      POMC       Gene              related_to
#
#                          pred1_source        pred1_api  \
# 1164  Translator Text Mining Provider    CORD Gene API
# 840   Translator Text Mining Provider    CORD Gene API
# 847   Translator Text Mining Provider    CORD Gene API
# 821   Translator Text Mining Provider    CORD Gene API
# 358   Translator Text Mining Provider    CORD Gene API
# 576   Translator Text Mining Provider    CORD Gene API
# 4                              SEMMED  SEMMED Gene API
# 516                            SEMMED  SEMMED Gene API
# 615                            entrez  MyGene.info API
# 390   Translator Text Mining Provider    CORD Gene API
# 129   Translator Text Mining Provider    CORD Gene API
# 134   Translator Text Mining Provider    CORD Gene API
# 12                             SEMMED  SEMMED Gene API
# 394   Translator Text Mining Provider    CORD Gene API
# 15                             SEMMED  SEMMED Gene API
# 36    Translator Text Mining Provider    CORD Gene API
# 11                             SEMMED  SEMMED Gene API
# 348   Translator Text Mining Provider    CORD Gene API
#
#                    pred1_pubmed        output_type        output_name  \
# 1164                       None  BiologicalProcess        COAGULATION
# 840                        None  BiologicalProcess        COAGULATION
# 847                        None  BiologicalProcess  BLOOD COAGULATION
# 821                        None  BiologicalProcess        COAGULATION
# 358                        None  BiologicalProcess        COAGULATION
# 576                        None  BiologicalProcess        COAGULATION
# 4               7511495,9215020  BiologicalProcess  BLOOD COAGULATION
# 516                    22532265  BiologicalProcess  BLOOD COAGULATION
# 615                        None  BiologicalProcess  BLOOD COAGULATION
# 390                        None  BiologicalProcess        COAGULATION
# 129                        None  BiologicalProcess        COAGULATION
# 134                        None  BiologicalProcess        COAGULATION
# 12    18377928,25344622,5426215  BiologicalProcess  BLOOD COAGULATION
# 394                        None  BiologicalProcess        COAGULATION
# 15                     25258477  BiologicalProcess  BLOOD COAGULATION
# 36                         None  BiologicalProcess        COAGULATION
# 11                     14828546  BiologicalProcess  BLOOD COAGULATION
# 348                        None  BiologicalProcess        COAGULATION
#
#                    output_id
# 1164           GO:GO:0050817
# 840            GO:GO:0050817
# 847            GO:GO:0007596
# 821            GO:GO:0050817
# 358            GO:GO:0050817
# 576            GO:GO:0050817
# 4     name:BLOOD COAGULATION
# 516   name:BLOOD COAGULATION
# 615            GO:GO:0007596
# 390            GO:GO:0050817
# 129            GO:GO:0050817
# 134            GO:GO:0050817
# 12    name:BLOOD COAGULATION
# 394            GO:GO:0050817
# 15    name:BLOOD COAGULATION
# 36             GO:GO:0050817
# 11    name:BLOOD COAGULATION
# 348            GO:GO:0050817

# %% [markdown]
# #### 1.3.1.3  Gene -> Disease type "symptoms"

# %%
df_list = []
for x in top_related_genes_covid_2_allNodes_2_genes: 
#     print(x)
    try: 
        gene = ht.query(x)["Gene"][0]
        fc = FindConnection(input_obj=gene, output_obj='Disease', intermediate_nodes=None)
        fc.connect(verbose=False)
        df = fc.display_table_view()
        rows = df.shape[0]
        if(rows > 0):
            df_list.append(df)
    except:
        print(str(x) + " FAILED")
if(len(df_list) > 0):
    top_gene_2_diseases = pd.concat(df_list)

top_gene_2_diseases.shape
# Out:
# C0017337 FAILED
# C0014442 FAILED
# C1705556 FAILED
# C0010762 FAILED
# C0164786 FAILED
# C1705526 FAILED
# C0010531 FAILED
# C0030956 FAILED
# C0033634 FAILED
# C0020364 FAILED
# C1142644 FAILED
# C1705846 FAILED
# C0669372 FAILED
# C0208355 FAILED
# C3539722 FAILED
# C0033640 FAILED
# C2985367 FAILED
# C0030016 FAILED
# C2699841 FAILED
# C0669365 FAILED
# C1709136 FAILED
# C1705581 FAILED
# C0242417 FAILED
# C0059563 FAILED
# C1707177 FAILED
# (69502, 9)

# %%
def get_similar_disease_indices(list1,list2,similarity):
    res = [] 
    i = 0
    while (i < len(list1)):
        append_i = False
        lookup = list1[i].lower()
#         if('go:' in list1[i]):
#             if list1[i] in go_dict:
#                 lookup = go_dict[list1[i]]
        for j in list2:
                if(difflib.SequenceMatcher(None,lookup,j).ratio() > similarity):
    #                 if(i < 3):
#                     print("Matched similar terms:")
#                     print(lookup + ' and ' + j)
#                     print()
                    append_i = True
        if(append_i): 
            res.append(i) 
        i += 1
    print(len(res))
    return(res)

# %%
disease_indices = get_similar_disease_indices(list(top_gene_2_diseases["output_name"]),symptom_and_phenotype_list,0.9)
# Out:
# 64

# %%
# top_gene_2_diseases
relevant_top_gene_2_diseases = top_gene_2_diseases.iloc[disease_indices,:]
relevant_top_gene_2_diseases
# Out:
#      input input_type                 pred1 pred1_source           pred1_api  \
# 1539   TNF       Gene              disrupts       SEMMED     SEMMED Gene API
# 1540   TNF       Gene                causes       SEMMED     SEMMED Gene API
# 1541   TNF       Gene               affects       SEMMED     SEMMED Gene API
# 1542   TNF       Gene            related_to     disgenet  mydisease.info API
# 2150   TNF       Gene                causes       SEMMED     SEMMED Gene API
# ...    ...        ...                   ...          ...                 ...
# 694   POMC       Gene                causes       SEMMED     SEMMED Gene API
# 695   POMC       Gene  negatively_regulates       SEMMED     SEMMED Gene API
# 696   POMC       Gene               affects       SEMMED     SEMMED Gene API
# 697   POMC       Gene            related_to     disgenet  mydisease.info API
# 1564  POMC       Gene            related_to       SEMMED     SEMMED Gene API
#
#                                            pred1_pubmed output_type  \
# 1539                  1443236,16300807,22673618,9094446     Disease
# 1540  10701765,15373964,16460809,1714101,17374708,17...     Disease
# 1541  11593333,12879338,15855300,15965498,17967442,1...     Disease
# 1542                                               None     Disease
# 2150                                           21426732     Disease
# ...                                                 ...         ...
# 694                            14972664,6350720,9813238     Disease
# 695                     3607519,6276869,6333677,6608720     Disease
# 696   1329067,14780355,14784723,14841420,1667687,360...     Disease
# 697                                                None     Disease
# 1564                                  13235422,26465705     Disease
#
#      output_name       output_id
# 1539       FEVER  MONDO:C0015967
# 1540       FEVER  MONDO:C0015967
# 1541       FEVER  MONDO:C0015967
# 1542       FEVER  MONDO:C0015967
# 2150    COUGHING  MONDO:C0010200
# ...          ...             ...
# 694        FEVER  MONDO:C0015967
# 695        FEVER  MONDO:C0015967
# 696        FEVER  MONDO:C0015967
# 697        FEVER  MONDO:C0015967
# 1564    HEADACHE  MONDO:C0018681
#
# [64 rows x 9 columns]

# %%
i = list(top_gene_2_diseases.iloc[disease_indices,:]["input"])
d = {x:i.count(x) for x in i}
sorted_genes_from_symptoms = {k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
for x in list(reversed(list(sorted_genes_from_symptoms)))[0:100]:
    print(str(x) + ": " + str(sorted_genes_from_symptoms[x]))
# Out:
# POMC: 6
# TNF: 5
# CAMP: 3
# IFNA1: 3
# LEP: 3
# ACE: 3
# FOS: 3
# IL6: 3
# INS: 3
# STAT3: 2
# PTH: 2
# TGFB1: 2
# ERVK-10: 2
# EPO: 2
# MAPK8: 2
# VEGFA: 2
# BAX: 2
# ALB: 2
# CYP2C19: 1
# FAS: 1
# CXCL8: 1
# IL2: 1
# AGTR1: 1
# TTR: 1
# CA2: 1
# SOD2: 1
# IL1B: 1
# PPIG: 1
# CDKN1A: 1
# TP53: 1
# AKT1: 1
# CAT: 1

# %%
causes_df = relevant_top_gene_2_diseases[relevant_top_gene_2_diseases["pred1"] == "causes"]
i = list(causes_df["input"])
causes_dict = {x:i.count(x) for x in i}
causes_dict
# Out:
# {'TNF': 2,
#  'INS': 2,
#  'FOS': 1,
#  'ACE': 1,
#  'CDKN1A': 1,
#  'ALB': 1,
#  'VEGFA': 1,
#  'LEP': 1,
#  'IFNA1': 1,
#  'CAMP': 1,
#  'MAPK8': 1,
#  'EPO': 2,
#  'TGFB1': 1,
#  'STAT3': 1,
#  'POMC': 1}

# %% [markdown]
# **How to Interpret above**: Of the top genes associated with COVID-19, the above are genes that are known to cause symptoms described as symptoms in COVID-19

# %% [markdown]
# ## 1.4 Assembly of Results

# %%
## make dataframe with all genes -> symptoms
all_gene_connections = pd.concat([bioprocess_top,phen_top,relevant_top_gene_2_diseases])
all_gene_connections["output_name"] = all_gene_connections["output_name"].str.lower()
all_gene_connections
# Out:
#      input input_type                 pred1                     pred1_source  \
# 1164   TNF       Gene            related_to  Translator Text Mining Provider
# 840    INS       Gene            related_to  Translator Text Mining Provider
# 847    INS       Gene            related_to  Translator Text Mining Provider
# 821   AKT1       Gene            related_to  Translator Text Mining Provider
# 358    IL6       Gene            related_to  Translator Text Mining Provider
# ...    ...        ...                   ...                              ...
# 694   POMC       Gene                causes                           SEMMED
# 695   POMC       Gene  negatively_regulates                           SEMMED
# 696   POMC       Gene               affects                           SEMMED
# 697   POMC       Gene            related_to                         disgenet
# 1564  POMC       Gene            related_to                           SEMMED
#
#                pred1_api                                       pred1_pubmed  \
# 1164       CORD Gene API                                               None
# 840        CORD Gene API                                               None
# 847        CORD Gene API                                               None
# 821        CORD Gene API                                               None
# 358        CORD Gene API                                               None
# ...                  ...                                                ...
# 694      SEMMED Gene API                           14972664,6350720,9813238
# 695      SEMMED Gene API                    3607519,6276869,6333677,6608720
# 696      SEMMED Gene API  1329067,14780355,14784723,14841420,1667687,360...
# 697   mydisease.info API                                               None
# 1564     SEMMED Gene API                                  13235422,26465705
#
#             output_type        output_name       output_id
# 1164  BiologicalProcess        coagulation   GO:GO:0050817
# 840   BiologicalProcess        coagulation   GO:GO:0050817
# 847   BiologicalProcess  blood coagulation   GO:GO:0007596
# 821   BiologicalProcess        coagulation   GO:GO:0050817
# 358   BiologicalProcess        coagulation   GO:GO:0050817
# ...                 ...                ...             ...
# 694             Disease              fever  MONDO:C0015967
# 695             Disease              fever  MONDO:C0015967
# 696             Disease              fever  MONDO:C0015967
# 697             Disease              fever  MONDO:C0015967
# 1564            Disease           headache  MONDO:C0018681
#
# [101 rows x 9 columns]

# %%
# get pulication counts for gene -> symptoms
top_symptom_pub_counts = {}
for index, row in all_gene_connections.iterrows():
#     if row["input_name"] in top_related_genes_covid_2_allNodes_2_genes:
    current_pubcount = 0
    if(row["pred1_pubmed"] != None):
        current_pubcount = current_pubcount + row["pred1_pubmed"].count(",") + 1
    if row["input"] in top_symptom_pub_counts:
        top_symptom_pub_counts[row["input"]] = top_symptom_pub_counts[row["input"]] + current_pubcount
    else: 
        top_symptom_pub_counts[row["input"]] = current_pubcount

top_symptom_pub_counts
# Out:
# {'TNF': 33,
#  'INS': 3,
#  'AKT1': 1,
#  'IL6': 3,
#  'MAPK1': 0,
#  'ALB': 4,
#  'VEGFA': 3,
#  'IFNA1': 9,
#  'MAPK8': 2,
#  'EPO': 2,
#  'TTR': 191,
#  'ERVK-10': 5,
#  'IL2': 0,
#  'TLR4': 1,
#  'CRP': 0,
#  'POMC': 24,
#  'ANG': 0,
#  'TP53': 2,
#  'FOS': 3,
#  'SQSTM1': 0,
#  'APP': 0,
#  'TH': 9,
#  'SOD1': 0,
#  'ATM': 0,
#  'TGFB1': 6,
#  'FAS': 1,
#  'G6PD': 71,
#  'STAT3': 1,
#  'MARS1': 0,
#  'CAT': 1,
#  'ACE': 2,
#  'CDKN1A': 1,
#  'PPIG': 1,
#  'BAX': 3,
#  'LEP': 5,
#  'IL1B': 0,
#  'CAMP': 6,
#  'SOD2': 0,
#  'CA2': 3,
#  'AGTR1': 1,
#  'CXCL8': 0,
#  'PTH': 2,
#  'CYP2C19': 1}

# %%
# make dictionary for final assembly of results
results_dict = {}
for i in range(all_gene_connections.shape[0]):
    if(all_gene_connections.iloc[i]["input"] in results_dict):
        results_dict[all_gene_connections.iloc[i]["input"]]["symptoms_associated"].append(all_gene_connections.iloc[i]["output_name"])
    else:
        results_dict[all_gene_connections.iloc[i]["input"]] = {
            "two_step_associations_to_covid" : sorted_genes_covid_2_allNodes_2_genes[all_gene_connections.iloc[i]["input"]],
            "direct_associations_to_covid" : sorted_genes_covid_2_genes[all_gene_connections.iloc[i]["input"]] if all_gene_connections.iloc[i]["input"] in sorted_genes_covid_2_genes else 0,
            "symptoms_associated" : [all_gene_connections.iloc[i]["output_name"]]
        }
    
# print(results_dict)

# %%
# function that gets all connections to any node type from single gene node
def get_connection_normalizing_count(gene):
    count = 0
    input_object = ht.query(gene)['Gene'][0]
    for x in node_type_list:
        fc = FindConnection(input_obj=input_object, output_obj=x, intermediate_nodes=None)
        fc.connect(verbose=False)
        df = fc.display_table_view()
        rows = df.shape[0]
        count = count + rows
    return(count)
        
# TNF_count = get_connection_normalizing_count('TNF')
# print(TNF_count)

# %%
# dictionary that keeps track of all connections from a gene to any node type 
connection_dict = {}
for key in results_dict:
    connection_dict[key] = get_connection_normalizing_count(key)

# %%
# assmeble results into final dataframe
dataframe_input = []
for key in results_dict:
    connections_count = connection_dict[key]
    # calculate "relevance_score" based on occurrences, publication counts, gene_normalizing counts 
    relevance_score = ((((results_dict[key]["direct_associations_to_covid"]*10 
                        + results_dict[key]["two_step_associations_to_covid"]) 
                        * len(results_dict[key]["symptoms_associated"])*3) 
                        + round(top_genes_pub_counts[key] / 5) 
                        + round(top_symptom_pub_counts[key] / 5)
                        + (causes_dict[key] if key in causes_dict else 0)*20)
                        /connections_count)
    # assemble each row                                               
    current_result = {'gene': key,
                      "direct_disease_assoc": results_dict[key]["direct_associations_to_covid"], 
                      "two_step_assoc_to_disease": results_dict[key]["two_step_associations_to_covid"],
                      "two_step_pub_count": top_genes_pub_counts[key],
                      "disease_symptoms_gene_is_associated_with": results_dict[key]["symptoms_associated"],
                      "symptoms_associated_count": len(results_dict[key]["symptoms_associated"]),
                      "disease_symptom_gene_pub_count": top_symptom_pub_counts[key],
                      "causes_symptom_count": causes_dict[key] if key in causes_dict else 0,
                      "gene_connections_count": connection_dict[key],
                      "relevance_score": relevance_score
                     }
    dataframe_input.append(current_result)
    
final_df = pd.DataFrame(dataframe_input)
# sort by relevance score
final_df = final_df.sort_values(by=['relevance_score'], ascending=False)
final_df
# Out:
#        gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 28    MARS1                     1                          7
# 9       EPO                     0                         14
# 30      ACE                     0                         18
# 10      TTR                     0                         14
# 16      ANG                     0                         24
# 3       IL6                     0                         23
# 15     POMC                     0                         10
# 1       INS                     0                         27
# 26     G6PD                     0                         10
# 0       TNF                     0                         44
# 11  ERVK-10                     0                         14
# 5       ALB                     0                         16
# 18      FOS                     0                         18
# 21       TH                     1                         16
# 35     IL1B                     0                         15
# 19   SQSTM1                     0                         17
# 14      CRP                     1                         10
# 34      LEP                     0                         15
# 7     IFNA1                     0                         15
# 37     SOD2                     0                         14
# 39    AGTR1                     0                         14
# 32     PPIG                     0                         16
# 29      CAT                     0                         32
# 27    STAT3                     0                         10
# 22     SOD1                     0                         15
# 8     MAPK8                     0                         14
# 33      BAX                     0                         15
# 24    TGFB1                     0                         12
# 17     TP53                     0                         19
# 6     VEGFA                     0                         15
# 42  CYP2C19                     0                         10
# 36     CAMP                     0                         15
# 41      PTH                     0                         11
# 12      IL2                     0                         13
# 40    CXCL8                     0                         12
# 25      FAS                     0                         11
# 23      ATM                     0                         12
# 20      APP                     0                         17
# 31   CDKN1A                     0                         16
# 2      AKT1                     0                         25
# 13     TLR4                     0                         12
# 4     MAPK1                     0                         18
# 38      CA2                     0                         14
#
#     two_step_pub_count           disease_symptoms_gene_is_associated_with  \
# 28                   5                                   [cough, dyspnea]
# 9                   26                      [coagulation, dyspnea, fever]
# 30                  32                     [coughing, coughing, coughing]
# 10                   8                  [coagulation, headache, headache]
# 16                  78                                          [dyspnea]
# 3                   58              [coagulation, fever, fever, headache]
# 15                  10  [blood coagulation, coagulation, fever, fever,...
# 1                   53  [coagulation, blood coagulation, coughing, fev...
# 26                  10                                            [fever]
# 0                  114  [coagulation, fever, fever, fever, fever, coug...
# 11                  24                  [blood coagulation, fever, fever]
# 5                    9                  [blood coagulation, fever, fever]
# 18                  34            [myalgia, headache, headache, coughing]
# 21                 541                                            [fever]
# 35                  39                                            [fever]
# 19                  45                                          [dyspnea]
# 14                   0                                      [coagulation]
# 34                  20               [fever, fever, respiratory distress]
# 7                   15           [blood coagulation, fever, fever, fever]
# 37                  40                                            [fever]
# 39                  10                                         [coughing]
# 32                  45                                            [fever]
# 29                  98                                            [fever]
# 27                  13                       [cough, fever, fever, fever]
# 22                  26                                          [dyspnea]
# 8                   24                        [coagulation, fever, fever]
# 33                  30                                     [fever, fever]
# 24                  21              [headache, headache, fever, headache]
# 17                  42                  [fever, dyspnea, headache, fever]
# 6                  150            [blood coagulation, coughing, coughing]
# 42                   6                                         [headache]
# 36                  71                           [fever, fever, headache]
# 41                   4                               [headache, headache]
# 12                  12                               [coagulation, fever]
# 40                  19                                            [fever]
# 25                   8                                  [headache, fever]
# 23                  21                                            [fever]
# 20                  21                                         [headache]
# 31                  29                                            [fever]
# 2                   51                               [coagulation, fever]
# 13                  10                                [blood coagulation]
# 4                   40                                      [coagulation]
# 38                  80                                            [fever]
#
#     symptoms_associated_count  disease_symptom_gene_pub_count  \
# 28                          2                               0
# 9                           3                               2
# 30                          3                               2
# 10                          3                             191
# 16                          1                               0
# 3                           4                               3
# 15                          8                              24
# 1                           5                               3
# 26                          1                              71
# 0                           6                              33
# 11                          3                               5
# 5                           3                               4
# 18                          4                               3
# 21                          1                               9
# 35                          1                               0
# 19                          1                               0
# 14                          1                               0
# 34                          3                               5
# 7                           4                               9
# 37                          1                               0
# 39                          1                               1
# 32                          1                               1
# 29                          1                               1
# 27                          4                               1
# 22                          1                               0
# 8                           3                               2
# 33                          2                               3
# 24                          4                               6
# 17                          4                               2
# 6                           3                               3
# 42                          1                               1
# 36                          3                               6
# 41                          2                               2
# 12                          2                               0
# 40                          1                               0
# 25                          2                               1
# 23                          1                               0
# 20                          1                               0
# 31                          1                               1
# 2                           2                               1
# 13                          1                               1
# 4                           1                               0
# 38                          1                               3
#
#     causes_symptom_count  gene_connections_count  relevance_score
# 28                     0                     947         0.108765
# 9                      2                    2163         0.079057
# 30                     1                    2770         0.067870
# 10                     0                    3016         0.055040
# 16                     0                    1747         0.050372
# 3                      0                    5945         0.048612
# 15                     1                    5544         0.048160
# 1                      2                    9556         0.047823
# 26                     0                     974         0.047228
# 0                      2                   19385         0.044467
# 11                     0                    3242         0.040716
# 5                      1                    4258         0.039220
# 18                     1                    6908         0.035321
# 21                     0                    5625         0.033422
# 35                     0                    1834         0.028899
# 19                     0                    2110         0.028436
# 14                     0                    2132         0.028143
# 34                     1                    5731         0.027918
# 7                      1                    7483         0.027395
# 37                     0                    1895         0.026385
# 39                     0                    1949         0.022576
# 32                     0                    2544         0.022406
# 29                     0                    5283         0.021957
# 27                     1                    6529         0.021902
# 22                     0                    2388         0.020938
# 8                      1                    7490         0.020160
# 33                     0                    4955         0.019576
# 24                     1                    8887         0.019017
# 17                     0                   13972         0.016891
# 6                      1                   11157         0.016671
# 42                     0                    1891         0.016393
# 36                     1                   10391         0.016360
# 41                     0                    4624         0.014490
# 12                     0                    5695         0.014047
# 40                     0                    2981         0.013418
# 25                     0                    5675         0.011982
# 23                     0                    3536         0.011312
# 20                     0                    5291         0.010395
# 31                     1                    7189         0.010294
# 2                      0                   16327         0.009800
# 13                     0                    4494         0.008456
# 4                      0                   11681         0.005308
# 38                     0                   16710         0.003531

# %%
# save final df to dataframe
final_df.to_csv("covid_symptom_gene_results_100_2020-08-18.csv", index = False)
