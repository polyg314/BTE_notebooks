# %%
import pandas as pd

# %%
dravet_df =

# %%
cf_df = pd.read_csv("Cystic_Fibrosis_2020-08-27.csv")
cf_df_non_direct = cf_df[cf_df["direct_disease_assoc"] == 0]
cf_df_non_direct.to_csv("Cystic_Fibrosis_non_direct_2020-08-27.csv")
cf_df_non_direct
# Out:
#         gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 55       LOX                     0                       1215
# 82       FOS                     0                       2533
# 107     POMC                     0                       2053
# 114     RELA                     0                       2045
# 115      ATM                     0                       1187
# 125   CDKN1A                     0                       2127
# 134     BCL2                     0                       1257
# 221      BAX                     0                       1884
# 257     SOD2                     0                       1239
# 276     CD40                     0                       1561
# 281   PIK3CA                     0                       1622
# 298     SOD1                     0                       1864
# 302   TCEAL1                     0                       1665
# 343      KIT                     0                       1240
# ...

# %%
ds_df = pd.read_csv("Dravet_Syndrome_2020-08-27.csv")
ds_df_non_direct = ds_df[ds_df["direct_disease_assoc"] == 0]
ds_df_non_direct.to_csv("Dravet_Syndrome_non_direct_2020-08-27.csv")
ds_df_non_direct
# Out:
#       gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 1     GRK2                     0                         41
# 2   CYP2D6                     0                         26
# 3     BMP1                     0                         28
# 4    FGFR3                     0                         27
# 5   SLC2A1                     0                         28
# 6     MTOR                     0                         30
# 7      RET                     0                         29
# 8   PGPEP1                     0                         27
# 9      ATM                     0                         27
# 10     GPI                     0                         33
# 11   CXCR4                     0                         25
# 12    PRCP                     0                         26
# 13     INS                     0                         40
# 14     TRH                     0                         33
# 15      TH                     0                         33
# ...

# %%
eb_df = pd.read_csv("Epidermolysis_bullosa_2020-08-27.csv")
eb_df_non_direct = eb_df[eb_df["direct_disease_assoc"] == 0]
eb_df_non_direct.to_csv("Epidermolysis_bullosa_non_direct_2020-08-27.csv")
eb_df_non_direct
# Out:
#        gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 2   COL17A1                     0                          9
# 4       TNF                     0                         34
# 5      TP63                     0                          8
# 6       REN                     0                         22
# 7       ALB                     0                         12
# ..      ...                   ...                        ...
# 81     HPSE                     0                          8
# 82      BCR                     0                          8
# 83     TYMS                     0                          9
# 84    GABPA                     0                         11
# 85      EGF                     0                         10
#
#              disease_symptoms_gene_is_associated_with  \
# 2   ['corneal erosion', 'abnormal blistering of th...
# 4   ['anemia', 'anemia', 'anemia', 'anemia', 'anem...
# 5   ['blepharitis', 'blepharitis', 'blepharitis', ...
# ...

# %%
fvl_df = pd.read_csv("Factor_V_Leiden_2020-08-27.csv")
fvl_df_non_direct = fvl_df[fvl_df["direct_disease_assoc"] == 0]
fvl_df_non_direct.to_csv("Factor_V_Leiden_non_direct_2020-08-27.csv")
fvl_df_non_direct
# Out:
#       gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 1      ACE                     0                        138
# 5     PTEN                     0                        129
# 8     MMP9                     0                        244
# 9      INS                     0                        260
# 10    AKT1                     0                        297
# 11     PGF                     0                        109
# 12      TH                     0                        147
# 13    CISH                     0                        151
# 14   PTGS2                     0                        124
# 15  ADRA1D                     0                        106
# 16   MTHFR                     0                        205
#
#          disease_symptoms_gene_is_associated_with  symptoms_associated_count  \
# 1                ['preeclampsia', 'preeclampsia']                          2
# 5   ['blood clot in a deep vein', 'preeclampsia']                          2
# ...

# %%
nf_df = pd.read_csv("Neurofibromatosis_2020-08-27.csv")
nf_df_non_direct = nf_df[nf_df["direct_disease_assoc"] == 0]
nf_df_non_direct.to_csv("Neurofibromatosis_non_direct_2020-08-27.csv")
nf_df_non_direct
# Out:
#       gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 9     BRAF                     0                        267
# 24   FGFR1                     0                        174
# 37   BRCA1                     0                        213
# 44   STAT3                     0                        268
# 46   TGFB1                     0                        398
# 47    TP63                     0                        164
# 52      TH                     0                        181
# 53     LOX                     0                        229
# 55    MMP9                     0                        405
# 58     LEP                     0                        334
# 60    TERT                     0                        190
# 62      AR                     0                        252
# 63     TNF                     0                        577
# 64     INS                     0                        331
# 66     ATM                     0                        224
# ...

# %%
xp_df = pd.read_csv("xeroderma_pigmentosum_2020-08-27.csv")
xp_df_non_direct = xp_df[xp_df["direct_disease_assoc"] == 0]
xp_df_non_direct.to_csv("xeroderma_pigmentosum_non_direct_2020-08-27.csv")
xp_df_non_direct
# Out:
#        gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 20     TP63                     0                        413
# 26      KIT                     0                        437
# 27     BRAF                     0                        374
# 33      TNF                     0                        861
# 36   PIK3CA                     0                        494
# ..      ...                   ...                        ...
# 193    RELA                     0                        339
# 198    SOD1                     0                        337
# 200    TYMS                     0                        298
# 203   AHSA1                     0                        307
# 205     SP1                     0                        325
#
#               disease_symptoms_gene_is_associated_with  \
# 20   ['cryptorchidism', 'cryptorchidism', 'blephari...
# 26   ['flat, discolored area of skin', 'fatigue', '...
# 27   ['decreased body height', 'decreased body heig...
# ...
