# %% [markdown]
# ## Imports

# %%
## main functions
import gene_symptoms_question_functions as gsf
## importlib makes sure functions from packages get refreshed
import importlib
import requests
importlib.reload(gsf)
import pandas as pd
import math
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %% [markdown]
# ## Set disease and output names

# %%
disease_name = 'cystic fibrosis'
output_csv = "Cystic_Fibrosis_2020-08-27.csv"
symptom_csv = "Cystic_Fibrosis_Symptoms_2020-08-27.csv"

# %% [markdown]
# ## Get disease

# %%
# disease_name = disease_name.lower()
disease = ht.query(disease_name.lower())['Disease'][0]
disease
# Out:
# {'MONDO': 'MONDO:0009061',
#  'DOID': 'DOID:1485',
#  'UMLS': 'C0010674',
#  'name': 'cystic fibrosis',
#  'MESH': 'D003550',
#  'OMIM': '219700',
#  'ORPHANET': '586',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0009061'},
#  'display': 'MONDO(MONDO:0009061) DOID(DOID:1485) OMIM(219700) ORPHANET(586) UMLS(C0010674) MESH(D003550) name(cystic fibrosis)',
#  'type': 'Disease'}

# %% [markdown]
# ## Get disease symptoms

# %%
# get disease symptoms
disease_symptoms_list = gsf.get_disease_symptoms(disease_name)
disease_symptoms = disease_symptoms_list[0]
disease_symptom_hpids = disease_symptoms_list[1]
disease_symptom_dict = disease_symptoms_list[2]
disease_symptoms
disease_symptom_hpids
# Out:
# ['meconium ileus', 'Meconium ileus in neonates', 'recurrent bronchopulmonary infections', 'chronic lung disease', 'Chronic lung disease', 'rectal prolapse', 'Rectum protrudes through anus', 'asthma', 'Asthma', 'Bronchial asthma', 'bronchiectasis', 'Permanent enlargement of the airways of the lungs', 'male infertility', 'Male infertility', 'hypercalciuria', 'Elevated urine calcium levels', 'Hypercalcinuria', 'elevated sweat chloride', 'Elevated sweat Cl', 'Elevated sweat Cl-', 'Elevated sweat chloride', 'failure to thrive', 'Faltering weight', 'Postnatal failure to thrive', 'Weight faltering', 'exocrine pancreatic insufficiency', 'Inability to properly digest food due to lack of pancreatic digestive enzymes', 'dehydration', 'Dehydration', 'autosomal recessive inheritance', 'Autosomal recessive', 'cor pulmonale', 'recurrent pneumonia', 'Multiple pulmonary infections', 'Pneumonia, recurrent', 'Pneumonia, recurrent episodes', 'Pulmonary infection', 'Pulmonary infections', 'Recurrent pneumonia', 'Recurrent pulmonary infections', 'pulmonary infections, recurrent', 'biliary cirrhosis']
# ['HP:0004401',
#  'HP:0006538',
#  'HP:0006528',
#  'HP:0002035',
#  'HP:0002099',
#  'HP:0002110',
#  'HP:0003251',
#  'HP:0002150',
#  'HP:0012236',
#  'HP:0001508',
#  'HP:0001738',
#  'HP:0001944',
#  'HP:0000007',
#  'HP:0001648',
#  'HP:0006532',
#  'HP:0002613']

# %% [markdown]
# ## Get Symptom Prevalence - based off edges out counts

# %%
disease_symptom_dict = gsf.get_symtpom_prevalence(disease_symptom_dict, disease_name) 
disease_symptoms_df = pd.DataFrame.from_dict(disease_symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptoms_df = pd.concat([disease_symptoms_df[disease_symptoms_df["frequency"] == "Very frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Occasional"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Rare"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Unknown"]
              ])
# Out:
# HP:0004401
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (9, 9)
# OKKKk
# 9
# API 3.11 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (7, 9)
# ok edge phen to dis
# 16
# edges out
# 16
# HP:0006538
# API 3.7 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# gene
# (15, 9)
# OKKKk
# 15
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# (12, 9)
# ok edge phen to dis
# 27
# edges out
# 27
# HP:0006528
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# gene
# (25, 9)
# OKKKk
# 25
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (29, 9)
# ok edge phen to dis
# 54
# edges out
# 548
# HP:0002035
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (21, 9)
# OKKKk
# 21
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (26, 9)
# ok edge phen to dis
# 47
# edges out
# 47
# HP:0002099
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (149, 9)
# OKKKk
# 149
# API 3.3 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# (122, 9)
# ok edge phen to dis
# 271
# edges out
# 7373
# HP:0002110
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# gene
# (116, 9)
# OKKKk
# 116
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# (166, 9)
# ok edge phen to dis
# 282
# edges out
# 1098
# HP:0003251
# API 3.1 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# gene
# (23, 9)
# OKKKk
# 23
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# (53, 9)
# ok edge phen to dis
# 76
# Nope
# edges out
# 1144
# HP:0002150
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# gene
# (39, 9)
# OKKKk
# 39
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# (83, 9)
# ok edge phen to dis
# 122
# edges out
# 420
# HP:0012236
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# gene
# (11, 9)
# OKKKk
# 11
# API 3.1 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# (8, 9)
# ok edge phen to dis
# 19
# edges out
# 19
# HP:0001508
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# gene
# (311, 9)
# OKKKk
# 311
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (361, 9)
# ok edge phen to dis
# 672
# edges out
# 672
# HP:0001738
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# gene
# (49, 9)
# OKKKk
# 49
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (42, 9)
# ok edge phen to dis
# 91
# edges out
# 91
# HP:0001944
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# gene
# (95, 9)
# OKKKk
# 95
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# (104, 9)
# ok edge phen to dis
# 199
# edges out
# 1374
# HP:0000007
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (350, 9)
# OKKKk
# 350
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# (244, 9)
# ok edge phen to dis
# 594
# edges out
# 594
# HP:0001648
# API 3.13 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# gene
# (11, 9)
# OKKKk
# 11
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# (22, 9)
# ok edge phen to dis
# 33
# Nope
# edges out
# 52
# HP:0006532
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# gene
# (71, 9)
# OKKKk
# 71
# API 3.8 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# (112, 9)
# ok edge phen to dis
# 183
# edges out
# 183
# HP:0002613
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# gene
# (11, 9)
# OKKKk
# 11
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (27, 9)
# ok edge phen to dis
# 38
# edges out
# 38

# %% [markdown]
# ## Calculate Individual Symptom Scores

# %%
individual_symptom_scores = [];
for index,x in disease_symptoms_df.iterrows():
    if(x["frequency"] == "Very frequent"):
        score = 20 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Frequent"):
        score = 15 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Occasional"):
        score = 10 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Rare"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Unknown"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    individual_symptom_scores.append(score)

# print(len(individual_symptom_scores))
disease_symptoms_df["ISS"] = individual_symptom_scores

# %% [markdown]
# ## Symptoms Table

# %%
disease_symptoms_df
# Out:
#                                                         names   frequency  \
# HP:0001738  [exocrine pancreatic insufficiency, Inability ...    Frequent
# HP:0001944                         [dehydration, Dehydration]  Occasional
# HP:0004401       [meconium ileus, Meconium ileus in neonates]     Unknown
# HP:0012236  [elevated sweat chloride, Elevated sweat Cl, E...     Unknown
# HP:0006538            [recurrent bronchopulmonary infections]     Unknown
# HP:0002613                                [biliary cirrhosis]     Unknown
# HP:0002035   [rectal prolapse, Rectum protrudes through anus]     Unknown
# HP:0001648                                    [cor pulmonale]     Unknown
# HP:0006532  [recurrent pneumonia, Multiple pulmonary infec...     Unknown
# HP:0002150  [hypercalciuria, Elevated urine calcium levels...     Unknown
# HP:0006528       [chronic lung disease, Chronic lung disease]     Unknown
# HP:0000007  [autosomal recessive inheritance, Autosomal re...     Unknown
# HP:0001508  [failure to thrive, Faltering weight, Postnata...     Unknown
# HP:0002110  [bronchiectasis, Permanent enlargement of the ...     Unknown
# HP:0003251               [male infertility, Male infertility]     Unknown
# HP:0002099                 [asthma, Asthma, Bronchial asthma]     Unknown
#
#             edges_out_count       ISS
# HP:0001738               91  1.572427
# HP:0001944             1374  0.269778
# HP:0004401               16  1.250000
# HP:0012236               19  1.147079
# HP:0006538               27  0.962250
# HP:0002613               38  0.811107
# HP:0002035               47  0.729325
# HP:0001648               52  0.693375
# HP:0006532              183  0.369611
# HP:0002150              420  0.243975
# HP:0006528              548  0.213589
# HP:0000007              594  0.205152
# HP:0001508              672  0.192879
# HP:0002110             1098  0.150893
# HP:0003251             1144  0.147828
# HP:0002099             7373  0.058230

# %%
disease_symptoms_df.to_csv(symptom_csv, index = False)

# %% [markdown]
# ## Get Disease -> Gene (no intermediates)

# %%
disease_disease_to_genes_dict = gsf.get_disease_to_gene_results(disease)
disease_disease_to_genes_dict
# Out:
# running disease -> gene
# {'sorted_disease_to_genes': {'MGI:104696': 1,
#   'MGI:3605470': 1,
#   'MGI:88388': 1,
#   'CPA1': 1,
#   'CD4': 1,
#   'KCNQ1': 1,
#   'ABCC6': 1,
#   'PSMD5': 1,
#   'MAPK1': 1,
#   'XBP1': 1,
#   'HMOX1': 1,
#   'TBL1X': 1,
#   'F9': 1,
#   'CCL17': 1,
#   'STUB1': 1,
#   'AES': 1,
#   'NOD1': 1,
#   'CSF3': 1,
#   'ASIC2': 1,
#   'PANX1': 1,
#   'LTA4H': 1,
#   'IFNG': 1,
#   'GAPDH': 1,
#   'MAPK14': 1,
#   'MLH1': 1,
#   'SLC9A2': 1,
#   'MMP8': 1,
#   'ABCG2': 1,
#   'SEC61A1': 1,
#   'APOE': 1,
#   'DNAJB1': 1,
#   'CHI3L1': 1,
#   'EDEM1': 1,
#   'KIDINS220': 1,
#   'CLPS': 1,
#   'TLR2': 1,
#   'ABCC9': 1,
#   'CLCN3': 1,
#   'CDH1': 1,
#   'RAB11A': 1,
#   'KCNH2': 1,
#   'ATP4A': 1,
#   'MAPK3': 1,
#   'UFD1L': 1,
#   'TYR': 1,
#   'IL1A': 1,
#   'ABCB11': 1,
#   'SLC9A1': 1,
#   'PRKG2': 1,
#   'STAT3': 1,
#   'FGF10': 1,
#   'ICAM1': 1,
#   'KNG1': 1,
#   'RAB7A': 1,
#   'NPR3': 1,
#   'EGF': 1,
#   'ABCB4': 1,
#   'LUM': 1,
#   'FGF7': 1,
#   'TP53': 1,
#   'RAB5A': 1,
#   'MARCH6': 1,
#   'IL9': 1,
#   'GGCT': 1,
#   'SCGB1A1': 1,
#   'IL18': 1,
#   'MMAA': 1,
#   'TJP1': 1,
#   'CRYGC': 1,
#   'SLC26A2': 1,
#   'KCNMA1': 1,
#   'AMFR': 1,
#   'ACE': 1,
#   'CCR5': 1,
#   'CELA1': 1,
#   'ZSWIM2': 1,
#   'HPGDS': 1,
#   'CXCL5': 1,
#   'RHO': 1,
#   'ADH5': 1,
#   'TLR3': 1,
#   'CSF2': 1,
#   'LMTK2': 1,
#   'NOS3': 1,
#   'HSP90B1': 1,
#   'CLPX': 1,
#   'STAT6': 1,
#   'ABCA3': 1,
#   'CCL11': 1,
#   'RNASE3': 1,
#   'CXXC5': 1,
#   'CLEC7A': 1,
#   'IGF1': 1,
#   'ADORA2B': 1,
#   'IL13': 1,
#   'ADRB2': 1,
#   'CXCL10': 1,
#   'ETV5': 1,
#   'CYCS': 1,
#   'TLR10': 1,
#   'HCFC1': 1,
#   'CASP3': 1,
#   'AQP1': 1,
#   'TLR8': 1,
#   'SFTPC': 1,
#   'EEA1': 1,
#   'WDTC1': 1,
#   'DUOX1': 1,
#   'CALR': 1,
#   'DEFB103A': 1,
#   'TAC1': 1,
#   'P2RY11': 1,
#   'FOXJ1': 1,
#   'HSPA5': 1,
#   'DEFB103B': 1,
#   'PHF12': 1,
#   'NPLOC4': 1,
#   'FAM101B': 1,
#   'BEST3': 1,
#   'LAMP1': 1,
#   'ABCC5': 1,
#   'HBB': 1,
#   'HSP90AA1': 1,
#   'ADORA2A': 1,
#   'IL17F': 1,
#   'CYP3A4': 1,
#   'CAV1': 1,
#   'TSLP': 1,
#   'CLCN1': 1,
#   'SMPD1': 1,
#   'CTSB': 1,
#   'RPS3A': 1,
#   'FN1': 1,
#   'HTT': 1,
#   'OCLN': 1,
#   'ANO2': 1,
#   'ARG1': 1,
#   'ACTB': 1,
#   'CCL20': 1,
#   'PRDM10': 1,
#   'VCP': 1,
#   'ELN': 1,
#   'TLR9': 1,
#   'STAT1': 1,
#   'MTOR': 1,
#   'SLC26A1': 1,
#   'TLR1': 1,
#   'BECN1': 1,
#   'TGM2': 1,
#   'PARP1': 1,
#   'EZR': 1,
#   'ADORA1': 1,
#   'PTGS2': 1,
#   'ADCY10': 1,
#   'ATF6': 1,
#   'BGLAP': 1,
#   'S100A8': 1,
#   'S100A9': 1,
#   'PSMD4': 1,
#   'PREP': 1,
#   'PNLIP': 1,
#   'ADORA3': 1,
#   'EMD': 1,
#   'ABCC2': 1,
#   'CLCA2': 1,
#   'CD40LG': 1,
#   'JUN': 1,
#   'UBAC1': 1,
#   'BEST4': 1,
#   'SFTPD': 1,
#   'SFTPA2': 1,
#   'SRC': 1,
#   'SPDEF': 1,
#   'ALOX5': 1,
#   'TXN': 1,
#   'P2RY4': 1,
#   'ABCA1': 1,
#   'PADI4': 1,
#   'CTRC': 1,
#   'CLCN5': 1,
#   'FOXP3': 1,
#   'ABCC4': 1,
#   'SYVN1': 1,
#   'CYBB': 1,
#   'PHEX': 1,
#   'DNAJA1': 1,
#   'DDX58': 1,
#   'BRCA2': 1,
#   'TLR7': 1,
#   'SMN1': 1,
#   'SMN2': 1,
#   'CLCN4': 1,
#   'IL33': 1,
#   'RAD51': 1,
#   'CLCN7': 1,
#   'GJB2': 1,
#   'HSPD1': 1,
#   'KCNJ1': 1,
#   'GPT': 1,
#   'SLC26A6': 1,
#   'MAPK8': 1,
#   'CXCL1': 1,
#   'LTB4R': 1,
#   'NCF4': 1,
#   'MUC16': 1,
#   'ENSP00000381231': 1,
#   'CBSL': 1,
#   'CDC42': 1,
#   'GGT1': 1,
#   'NLRC4': 1,
#   'GGT2': 1,
#   'SFTPB': 1,
#   'IL1R1': 1,
#   'GCG': 1,
#   'CREB1': 1,
#   'ENSP00000387760': 1,
#   'TLR6': 1,
#   'SLC4A4': 1,
#   'PACS2': 1,
#   'PDZK1': 1,
#   'SFTPA1': 1,
#   'CD44': 1,
#   'SLC4A8': 1,
#   'MUC6': 1,
#   'HRAS': 1,
#   'PTPRC': 1,
#   'MUC20': 1,
#   'IL31RA': 1,
#   'ENSP00000417517': 1,
#   'SLC26A8': 1,
#   'BRCA1': 1,
#   'SLC4A2': 1,
#   'CXCL2': 1,
#   'GYPB': 1,
#   'HSPA8': 1,
#   'CASP1': 1,
#   'FCGR3B': 1,
#   'HHAT': 1,
#   'CLDN2': 1,
#   'TAS2R20': 1,
#   'ITGAM': 1,
#   'ATP8B1': 1,
#   'VDR': 1,
#   'TAS2R38': 1,
#   'BEST2': 1,
#   'DDIT3': 1,
#   'HECTD4': 1,
#   'UBE2J1': 1,
#   'LDLR': 1,
#   'ITGAX': 1,
#   'UPF1': 1,
#   'CCL5': 1,
#   'DNAH11': 1,
#   'GGTLC3': 1,
#   'CCL3': 1,
#   'STIM1': 1,
#   'MYC': 1,
#   'RAB7B': 1,
#   'PTGES3': 1,
#   'HSH2D': 1,
#   'NEB': 1,
#   'MUC13': 1,
#   'PRSS3P2': 1,
#   'ADSL': 1,
#   'ERICD': 1,
#   'MALAT1': 1,
#   'SAA1': 1,
#   'SAA2': 1,
#   '7314': 1,
#   '7841': 1,
#   '3156': 1,
#   '14595': 1,
#   '8081': 1,
#   '10015': 1,
#   '19378': 1,
#   '10462': 1,
#   '10508': 1,
#   '15737': 1,
#   '11095': 1,
#   '11297': 1,
#   '6185': 1,
#   '6382': 1,
#   '2229': 1,
#   'BRD4': 1,
#   'FBXO8': 1,
#   'BPY2': 1,
#   'CTBS': 1,
#   'CRYGFP': 1,
#   'LIN9': 1,
#   'CTLA4': 1,
#   'MRO': 1,
#   'DLC1': 1,
#   'CD55': 1,
#   'DBP': 1,
#   'DNER': 1,
#   'ENOPH1': 1,
#   'CDT1': 1,
#   'LINC01554': 1,
#   'MICE': 1,
#   'LINC01672': 1,
#   'TXNRD2': 1,
#   'IFNE': 1,
#   'CREBZF': 1,
#   'RNF130': 1,
#   'CFC1': 1,
#   'MITF': 1,
#   'COX2': 1,
#   'MSN': 1,
#   'MSH3': 1,
#   'LRRK2': 1,
#   'NES': 1,
#   'NFKB1': 1,
#   'NDUFB6': 1,
#   'CCDC6': 1,
#   'NBL1': 1,
#   'NAP1L1': 1,
#   'CAP1': 1,
#   'NR3C1': 1,
#   'NOL3': 1,
#   'NOVA2': 1,
#   'C12orf57': 1,
#   'MTDH': 1,
#   'MLPH': 1,
#   'MCAT': 1,
#   'FRY': 1,
#   'SPG21': 1,
#   'FBRS': 1,
#   'NFASC': 1,
#   'C1D': 1,
#   'NDUFAF3': 1,
#   'GNL3': 1,
#   'ARMC9': 1,
#   'DSC3': 1,
#   'NLRP1': 1,
#   'F7': 1,
#   'F8': 1,
#   'FASN': 1,
#   'F2R': 1,
#   'MEG8': 1,
#   'SORBS1': 1,
#   'EPO': 1,
#   'EPM2A': 1,
#   'ESD': 1,
#   'ESR2': 1,
#   'SPATA1': 1,
#   'MTSS2': 1,
#   'SCGB2B3P': 1,
#   'FOXO3': 1,
#   'FPR1': 1,
#   'FGFR1': 1,
#   'FDFT1': 1,
#   'FES': 1,
#   'PIGS': 1,
#   'PLAAT1': 1,
#   'FXN': 1,
#   'PIMREG': 1,
#   'RESF1': 1,
#   'GORAB': 1,
#   'C6orf47': 1,
#   'NSF': 1,
#   'NRP1': 1,
#   'NT5E': 1,
#   'RLN2': 1,
#   'SNORA73A': 1,
#   'OMP': 1,
#   'RNU2-5P': 1,
#   'RNU2-2P': 1,
#   'RNU2-3P': 1,
#   'RNU2-4P': 1,
#   'RNU2-1': 1,
#   'RNU4-6P': 1,
#   'RNU4-8P': 1,
#   'RNU4-3P': 1,
#   'RNU4-4P': 1,
#   'RNU4-5P': 1,
#   'RNU4-1': 1,
#   'RNU4-7P': 1,
#   'RPL26': 1,
#   'RPLP2': 1,
#   'UHMK1': 1,
#   'SEPHS1': 1,
#   'SEPHS2': 1,
#   'RPS14': 1,
#   'RPS15': 1,
#   'PCBD1': 1,
#   'RRAD': 1,
#   'RPS6': 1,
#   'RPS18': 1,
#   'RPS5': 1,
#   'RPS3': 1,
#   'RPS2': 1,
#   'PAEP': 1,
#   'SDS': 1,
#   'SERPINB6': 1,
#   'QRSL1': 1,
#   'CCL21': 1,
#   'SDHA': 1,
#   'PCYT1B': 1,
#   'PCYT1A': 1,
#   'PEA15': 1,
#   'PES1': 1,
#   'PFDN4': 1,
#   'PFAS': 1,
#   'SRSF5': 1,
#   'ABRACL': 1,
#   'PMEL': 1,
#   'SLC16A1': 1,
#   'SLC17A5': 1,
#   'SLC25A1': 1,
#   'DYM': 1,
#   'SOSTDC1': 1,
#   'GC': 1,
#   'NMS': 1,
#   'FUS': 1,
#   'MBOAT4': 1,
#   'GHR': 1,
#   'MTPN': 1,
#   'H4C6': 1,
#   'DSTN': 1,
#   'GYPA': 1,
#   'GYPC': 1,
#   'GYPE': 1,
#   'ACSS2': 1,
#   'GTF2E1': 1,
#   'GTF2E2': 1,
#   'GTF2I': 1,
#   'GATA5': 1,
#   'HJV': 1,
#   'SPAG17': 1,
#   'EMSLR': 1,
#   'PPP1R3A': 1,
#   'PPIB': 1,
#   'SEPTIN4': 1,
#   'SEPTIN5': 1,
#   'PMAIP1': 1,
#   'PLXNA3': 1,
#   'PMS2': 1,
#   'EXOSC10': 1,
#   'SNCG': 1,
#   'SOS2': 1,
#   'SMS': 1,
#   'SRL': 1,
#   'SP3': 1,
#   'SP2': 1,
#   'SSB': 1,
#   'PRB2': 1,
#   'PRF1': 1,
#   'PRKAA2': 1,
#   'PTPN6': 1,
#   'PTPN14': 1,
#   'PTGFR': 1,
#   'HACD1': 1,
#   'TWF1': 1,
#   'PSMA7': 1,
#   'PSMD8': 1,
#   'PSMD3': 1,
#   'PSMD1': 1,
#   'PSMC4': 1,
#   'PSMD2': 1,
#   'PSME3': 1,
#   'EPCAM': 1,
#   'PTGDR': 1,
#   'RAI1': 1,
#   'TCIRG1': 1,
#   'PZP': 1,
#   'TGM1': 1,
#   'TG': 1,
#   'TH': 1,
#   'TERT': 1,
#   'TERC': 1,
#   'TEP1': 1,
#   'TFCP2': 1,
#   'ADK': 1,
#   'ADM': 1,
#   'THRSP': 1,
#   'TMEFF2': 1,
#   'RFC2': 1,
#   'RFC4': 1,
#   'RFC1': 1,
#   'AKR1B1': 1,
#   'AKR1C1': 1,
#   'AKAP4': 1,
#   'MRLN': 1,
#   'TNP2': 1,
#   'AMH': 1,
#   'AMBP': 1,
#   'ARHGAP4': 1,
#   'ATP6V0A1': 1,
#   'ATP5PF': 1,
#   'RNF31': 1,
#   'B3GALNT1': 1,
#   'BCL2A1': 1,
#   'BCHE': 1,
#   'TP53INP2': 1,
#   'HMGCL': 1,
#   'SLC10A3': 1,
#   'CFI': 1,
#   'HR': 1,
#   'HSD17B4': 1,
#   'HM13': 1,
#   'SYNPR': 1,
#   'CARD16': 1,
#   'IGF1R': 1,
#   'IGKV1D-37': 1,
#   'DNAJC21': 1,
#   'FIG4': 1,
#   'EFS': 1,
#   'IK': 1,
#   'EMG1': 1,
#   'CACNA1G-AS1': 1,
#   'BTN1A1': 1,
#   'BCS1L': 1,
#   'TRGV11': 1,
#   'TRGC1': 1,
#   'TRGVB': 1,
#   'TRGV9': 1,
#   'C6': 1,
#   'C5': 1,
#   'C4B': 1,
#   'C4A': 1,
#   'CA1': 1,
#   'SPACA9': 1,
#   'CA9': 1,
#   'UBE4A': 1,
#   'UBE2V2': 1,
#   'SERPING1': 1,
#   'TYMS': 1,
#   'UBE4B': 1,
#   'CASP14': 1,
#   'CBS': 1,
#   'KRIT1': 1,
#   'XPR1': 1,
#   'YY1': 1,
#   'NANOS2': 1,
#   'LYST': 1,
#   'SYNE1': 1,
#   'OPTN': 1,
#   'ACCS': 1,
#   'PART1': 1,
#   'LIF': 1,
#   'SARS2': 1,
#   'LTA': 1,
#   'LSS': 1,
#   'LNPEP': 1,
#   'LIPC': 1,
#   'LMOD1': 1,
#   'MATN3': 1,
#   'MCC': 1,
#   'ERVK-3': 1,
#   'ERVK-2': 1,
#   'ERVK-1': 1,
#   'ERVK-11': 1,
#   'ERVK-13': 1,
#   'ERVK-18': 1,
#   'MED25': 1,
#   'PDF': 1,
#   'GDF15': 1,
#   'LPCAT3': 1,
#   'WLS': 1,
#   'DNAAF3': 1,
#   'CP': 1,
#   'WFDC2': 1,
#   'H1-9P': 1,
#   'LTB': 1,
#   'PROK2': 1,
#   'CCL18': 1,
#   'EBP': 1,
#   'CLC': 1,
#   'JAG1': 1,
#   'FLT4': 1,
#   'HLA-DQA1': 1,
#   'HOXA10': 1,
#   'LYZ': 1,
#   'MLN': 1,
#   'ASIP': 1,
#   'MPG': 1,
#   'ASPA': 1,
#   'TBX22': 1,
#   'HDAC7': 1,
#   'PPARA': 1,
#   'SST': 1,
#   'ST7': 1,
#   'ROPN1L': 1,
#   'GLE1': 1,
#   'PDE4A': 1,
#   'PRKAB1': 1,
#   'ATP2A2': 1,
#   'ADA': 1,
#   'TOM1': 1,
#   'ABCB6': 1,
#   'KLF2': 1,
#   'TUBB4B': 1,
#   'MERTK': 1,
#   'CEL': 1,
#   'KHDRBS1': 1,
#   'CEACAM3': 1,
#   'MRPS30': 1,
#   'PAPOLA': 1,
#   'ERP29': 1,
#   'SLC27A5': 1,
#   'CAPN10': 1,
#   'TMC6': 1,
#   'PDAP1': 1,
#   'TUSC2': 1,
#   'LACTB': 1,
#   'PRAP1': 1,
#   'CTRL': 1,
#   'ASPRV1': 1,
#   'CTSS': 1,
#   'CYP2D6': 1,
#   'DDT': 1,
#   'DEFA1': 1,
#   'DNAH8': 1,
#   'EPHB1': 1,
#   'PTGR1': 1,
#   'TARDBP': 1,
#   'NUP62': 1,
#   'GCA': 1,
#   'PRDX5': 1,
#   'BBS9': 1,
#   'STK39': 1,
#   'GLS': 1,
#   'UTS2R': 1,
#   'DLL1': 1,
#   'TRBV16': 1,
#   'TRBC1': 1,
#   'FFAR3': 1,
#   'FFAR2': 1,
#   'IGKV1-16': 1,
#   'GSR': 1,
#   'GSTM3': 1,
#   'HEXA': 1,
#   'HLA-DRB1': 1,
#   'HLA-E': 1,
#   'HLA-H': 1,
#   'HPGD': 1,
#   'NANOS1': 1,
#   'IFI16': 1,
#   'IGHE': 1,
#   'IL3': 1,
#   'ITGAL': 1,
#   'LCN1': 1,
#   'SMAD3': 1,
#   'MARS1': 1,
#   'MSRA': 1,
#   'NEUROD1': 1,
#   'ASAP1': 1,
#   'CYRIB': 1,
#   'PIM1': 1,
#   'PLA2G5': 1,
#   'PPARG': 1,
#   'PPP5C': 1,
#   'PPT1': 1,
#   'PSG2': 1,
#   'PSMB5': 1,
#   'PDXP': 1,
#   'MCOLN1': 1,
#   'PTEN': 1,
#   'PTHLH': 1,
#   'NLN': 1,
#   'RAB27A': 1,
#   'REG1A': 1,
#   'REN': 1,
#   'CXCL6': 1,
#   'GMCL1': 1,
#   'GMCL2': 1,
#   'SLC6A2': 1,
#   'SLC15A2': 1,
#   'SRI': 1,
#   'TRB': 1,
#   'TRBV20OR9-2': 1,
#   'TRA-TGC7-1': 1,
#   'MANEA': 1,
#   'SLTM': 1,
#   'PARP9': 1,
#   'TNS4': 1,
#   'FBF1': 1,
#   'DCLK3': 1,
#   'YARS1': 1,
#   'CAV2': 1,
#   'RNMT': 1,
#   'TNFRSF10B': 1,
#   'ASAP2': 1,
#   'SQSTM1': 1,
#   'TIMELESS': 1,
#   'CCNE2': 1,
#   'GLS2': 1,
#   'LPL': 1,
#   'CTSL': 1,
#   'PEMT': 1,
#   'MMP2': 1,
#   'CBL': 1,
#   'GSTP1': 1,
#   'GSTM1': 1,
#   'COL1A2': 1,
#   'DLEU1': 1,
#   'GPI': 1,
#   'IGFBP2': 1,
#   'CD14': 1,
#   'MET': 1,
#   'PLA2G4C': 1,
#   'TCF7L2': 1,
#   'IGFBP3': 1,
#   'CFB': 1,
#   'CA12': 1,
#   'MSC': 1,
#   'SNW1': 1,
#   'PTS': 1,
#   'FER': 1,
#   'MAX': 1,
#   'DES': 1,
#   'AIRE': 1,
#   'CAST': 1,
#   'CAPS': 1,
#   'REST': 1,
#   'NTM': 1,
#   'ERAS': 1,
#   'STS': 1,
#   'SON': 1,
#   'DAP': 1,
#   'ADO': 1,
#   'TLE5': 1,
#   'RFLNB': 1,
#   'MUC2': 1,
#   'AGTR2': 1,
#   'MTHFR': 1,
#   'CHAC1': 1,
#   'PTX3': 1,
#   'DEFB4B': 1,
#   'SCT': 2,
#   'AQP2': 2,
#   'CTSG': 2,
#   'AHSA1': 2,
#   'TIMP1': 2,
#   'ATP12A': 2,
#   'MPO': 2,
#   'IL2': 2,
#   'IL4': 2,
#   'IL5': 2,
#   'PRTN3': 2,
#   'TTR': 2,
#   'PI3': 2,
#   'MRPS7': 2,
#   'C3': 2,
#   'CFP': 2,
#   'CANX': 2,
#   'BPIFB1': 2,
#   'CRP': 2,
#   'GUCY2C': 2,
#   'LPO': 2,
#   'SLC12A2': 2,
#   'KCNN4': 2,
#   'FAM13A': 2,
#   'DNAH5': 2,
#   'CLCN2': 2,
#   'SLC26A4': 2,
#   'EGFR': 2,
#   'LY96': 2,
#   'AQP5': 2,
#   'ALB': 2,
#   'ANXA5': 2,
#   'NOD2': 2,
#   'HSPA4': 2,
#   'ABCC8': 2,
#   'F2': 2,
#   'PRSS1': 2,
#   'P2RY2': 2,
#   'KCNE3': 2,
#   'FLNC': 2,
#   'NOS2': 2,
#   'NLRP3': 2,
#   'CELA3B': 2,
#   'IL17A': 2,
#   'HMGB1': 2,
#   'KCNJ11': 2,
#   'BPIFA1': 2,
#   'GUCA2A': 2,
#   'SPINK5': 2,
#   'TFRC': 2,
#   'GOPC': 2,
#   'S100A12': 2,
#   'ATP6AP1': 2,
#   'ABCA4': 2,
#   'CLCA4': 2,
#   'MMP9': 2,
#   'LCN2': 2,
#   'MBL2': 2,
#   'AGER': 2,
#   'RNF5': 2,
#   'ANXA1': 2,
#   'TCOF1': 2,
#   'SERPINB1': 2,
#   'ASAH1': 2,
#   'APIP': 2,
#   'CCK': 2,
#   'NEDD4L': 2,
#   'IL6': 2,
#   'CXCR4': 2,
#   'BEST1': 2,
#   'RHOA': 2,
#   'MYD88': 2,
#   'TRPV4': 2,
#   'MUC7': 2,
#   'SLC9A3R2': 2,
#   'IL10': 2,
#   'DDX41': 2,
#   'EHF': 2,
#   'VIM': 2,
#   'PRSS58': 2,
#   'MMP12': 2,
#   'PPY': 2,
#   'FPR2': 2,
#   'SLC6A14': 2,
#   'ABCB1': 2,
#   'VEGFA': 2,
#   'DNAI1': 2,
#   'MUC1': 2,
#   'SLC8A3': 2,
#   'A1CF': 2,
#   'FEV': 2,
#   'FST': 2,
#   'SBDS': 2,
#   'SI': 2,
#   'H19': 2,
#   'HGS': 2,
#   'PSMB6': 2,
#   'ARC': 2,
#   'AR': 2,
#   'ASL': 2,
#   'IFNA1': 2,
#   'TST': 2,
#   'C5AR1': 2,
#   'C2': 2,
#   'CISH': 2,
#   'CPOX': 2,
#   'GABPA': 2,
#   'CD79A': 2,
#   'ERCC8': 2,
#   'CSH1': 2,
#   'ESR1': 2,
#   'APEX1': 2,
#   'HSPA9': 2,
#   'NHS': 2,
#   'FBLIM1': 2,
#   'TF': 2,
#   'KRT90P': 2,
#   'ARSB': 2,
#   'SULT1A1': 2,
#   'ST8SIA4': 2,
#   'MAPT': 2,
#   'TIRAP': 2,
#   'CYP2E1': 2,
#   'MAP6': 2,
#   'EPHX1': 2,
#   'CYP1A1': 2,
#   'STX1A': 2,
#   'FCGR2A': 2,
#   'CCL2': 3,
#   'CAT': 3,
#   'SLC9A3R1': 3,
#   'BPI': 3,
#   'PTH': 3,
#   'SPINK1': 3,
#   'DEFB1': 3,
#   'DEFB4A': 3,
#   'CXCR2': 3,
#   'PRSS8': 3,
#   'SLC26A3': 3,
#   'HP': 3,
#   'DMD': 3,
#   'VIP': 3,
#   'GSN': 3,
#   'ADRA1D': 3,
#   'REG3A': 3,
#   'ABCC1': 3,
#   'IFRD1': 3,
#   'DNASE1': 3,
#   'CD8A': 3,
#   'SERPINA1': 3,
#   'MUC4': 3,
#   'AKT1': 3,
#   'SMOX': 3,
#   'MUC5AC': 3,
#   'AHRR': 3,
#   'SLURP1': 3,
#   'HFE': 3,
#   'MAL': 3,
#   'IL1B': 4,
#   'CA2': 4,
#   'CXCR1': 4,
#   'CXCL8': 4,
#   'LEP': 4,
#   'ANO1': 4,
#   'SCNN1A': 4,
#   'SLC26A9': 4,
#   'TLR4': 4,
#   'INS': 4,
#   'TLR5': 4,
#   'FAS': 4,
#   'TNFRSF1A': 5,
#   'CLCA1': 5,
#   'VDAC1': 5,
#   'SCNN1G': 5,
#   'SLPI': 5,
#   'TNF': 5,
#   'DCTN4': 5,
#   'MUC5B': 5,
#   'ERVK-10': 5,
#   'SLC9A3': 6,
#   'SCNN1B': 6,
#   'CAMP': 7,
#   'ELANE': 7,
#   'TGFB1': 8,
#   'CFTR': 16},
#  'one_step_genes_pub_counts': {'MGI:104696': 0,
#   'MGI:3605470': 0,
#   'MGI:88388': 0,
#   'CFTR': 225,
#   'CPA1': 0,
#   'CD4': 0,
#   'KCNQ1': 0,
#   'TNFRSF1A': 2,
#   'SCT': 0,
#   'AQP2': 1,
#   'ABCC6': 0,
#   'PSMD5': 0,
#   'MAPK1': 0,
#   'XBP1': 0,
#   'HMOX1': 0,
#   'CTSG': 0,
#   'AHSA1': 0,
#   'TBL1X': 0,
#   'F9': 0,
#   'TIMP1': 1,
#   'ATP12A': 1,
#   'CCL17': 0,
#   'STUB1': 0,
#   'AES': 0,
#   'TGFB1': 12,
#   'NOD1': 0,
#   'MPO': 7,
#   'CSF3': 0,
#   'ASIC2': 0,
#   'CCL2': 2,
#   'IL2': 1,
#   'PANX1': 0,
#   'LTA4H': 0,
#   'IFNG': 0,
#   'GAPDH': 0,
#   'MAPK14': 0,
#   'IL4': 0,
#   'IL5': 0,
#   'MLH1': 0,
#   'SLC9A2': 0,
#   'PRTN3': 1,
#   'CLCA1': 2,
#   'MMP8': 0,
#   'TTR': 0,
#   'ABCG2': 0,
#   'CAT': 2,
#   'SEC61A1': 0,
#   'PI3': 0,
#   'MRPS7': 1,
#   'C3': 0,
#   'CFP': 0,
#   'CANX': 0,
#   'APOE': 0,
#   'BPIFB1': 1,
#   'DNAJB1': 0,
#   'CRP': 0,
#   'CHI3L1': 0,
#   'EDEM1': 0,
#   'KIDINS220': 0,
#   'CLPS': 0,
#   'TLR2': 0,
#   'GUCY2C': 1,
#   'ABCC9': 0,
#   'CLCN3': 0,
#   'CDH1': 0,
#   'RAB11A': 0,
#   'KCNH2': 0,
#   'LPO': 0,
#   'SLC12A2': 1,
#   'SLC9A3R1': 1,
#   'ATP4A': 0,
#   'BPI': 0,
#   'KCNN4': 1,
#   'MAPK3': 0,
#   'UFD1L': 0,
#   'TYR': 0,
#   'IL1A': 0,
#   'IL1B': 2,
#   'ABCB11': 0,
#   'SLC9A1': 0,
#   'FAM13A': 1,
#   'PRKG2': 0,
#   'STAT3': 0,
#   'FGF10': 0,
#   'ICAM1': 0,
#   'SLC9A3': 3,
#   'KNG1': 0,
#   'RAB7A': 0,
#   'NPR3': 0,
#   'DNAH5': 0,
#   'EGF': 0,
#   'VDAC1': 3,
#   'CLCN2': 1,
#   'SLC26A4': 0,
#   'ABCB4': 0,
#   'LUM': 0,
#   'FGF7': 0,
#   'TP53': 0,
#   'RAB5A': 0,
#   'MARCH6': 0,
#   'IL9': 0,
#   'GGCT': 0,
#   'EGFR': 0,
#   'SCGB1A1': 0,
#   'IL18': 0,
#   'MMAA': 0,
#   'TJP1': 0,
#   'PTH': 5,
#   'CRYGC': 0,
#   'LY96': 1,
#   'CA2': 10,
#   'SLC26A2': 0,
#   'KCNMA1': 0,
#   'AMFR': 0,
#   'ACE': 0,
#   'CCR5': 0,
#   'AQP5': 1,
#   'CELA1': 0,
#   'ZSWIM2': 0,
#   'HPGDS': 0,
#   'CXCR1': 4,
#   'ALB': 4,
#   'CXCL5': 0,
#   'RHO': 0,
#   'ADH5': 0,
#   'CAMP': 13,
#   'ANXA5': 1,
#   'SPINK1': 1,
#   'TLR3': 0,
#   'CSF2': 0,
#   'LMTK2': 0,
#   'DEFB1': 1,
#   'NOS3': 0,
#   'HSP90B1': 0,
#   'SCNN1G': 3,
#   'CLPX': 0,
#   'STAT6': 0,
#   'NOD2': 0,
#   'ABCA3': 0,
#   'CCL11': 0,
#   'RNASE3': 0,
#   'CXXC5': 0,
#   'CLEC7A': 0,
#   'IGF1': 0,
#   'HSPA4': 1,
#   'DEFB4A': 0,
#   'ABCC8': 0,
#   'ADORA2B': 0,
#   'IL13': 0,
#   'ADRB2': 0,
#   'CXCL10': 0,
#   'CXCL8': 1,
#   'ETV5': 0,
#   'CYCS': 0,
#   'F2': 0,
#   'PRSS1': 0,
#   'TLR10': 0,
#   'HCFC1': 0,
#   'P2RY2': 0,
#   'KCNE3': 1,
#   'CASP3': 0,
#   'AQP1': 0,
#   'TLR8': 0,
#   'LEP': 11,
#   'SFTPC': 0,
#   'EEA1': 0,
#   'WDTC1': 0,
#   'DUOX1': 0,
#   'CXCR2': 2,
#   'PRSS8': 0,
#   'CALR': 0,
#   'DEFB103A': 0,
#   'TAC1': 0,
#   'P2RY11': 0,
#   'FOXJ1': 0,
#   'HSPA5': 0,
#   'DEFB103B': 0,
#   'FLNC': 0,
#   'NOS2': 0,
#   'PHF12': 0,
#   'NPLOC4': 0,
#   'FAM101B': 0,
#   'BEST3': 0,
#   'LAMP1': 0,
#   'ABCC5': 0,
#   'HBB': 0,
#   'HSP90AA1': 0,
#   'ADORA2A': 0,
#   'NLRP3': 0,
#   'IL17F': 0,
#   'CYP3A4': 0,
#   'CELA3B': 0,
#   'CAV1': 0,
#   'TSLP': 0,
#   'CLCN1': 0,
#   'SMPD1': 0,
#   'SLPI': 2,
#   'IL17A': 0,
#   'HMGB1': 0,
#   'CTSB': 0,
#   'KCNJ11': 0,
#   'SCNN1B': 4,
#   'SLC26A3': 2,
#   'RPS3A': 0,
#   'BPIFA1': 0,
#   'FN1': 0,
#   'HTT': 0,
#   'OCLN': 0,
#   'ANO1': 3,
#   'HP': 1,
#   'ANO2': 0,
#   'ARG1': 0,
#   'GUCA2A': 0,
#   'ACTB': 0,
#   'CCL20': 0,
#   'PRDM10': 0,
#   'VCP': 0,
#   'ELN': 0,
#   'SPINK5': 0,
#   'TFRC': 1,
#   'SCNN1A': 5,
#   'TLR9': 0,
#   'STAT1': 0,
#   'MTOR': 0,
#   'SLC26A1': 0,
#   'DMD': 2,
#   'TLR1': 0,
#   'BECN1': 0,
#   'TGM2': 0,
#   'PARP1': 0,
#   'EZR': 0,
#   'SLC26A9': 5,
#   'ADORA1': 0,
#   'VIP': 1,
#   'PTGS2': 0,
#   'ADCY10': 0,
#   'ATF6': 0,
#   'BGLAP': 0,
#   'GOPC': 0,
#   'S100A8': 0,
#   'S100A12': 2,
#   'S100A9': 0,
#   'PSMD4': 0,
#   'PREP': 0,
#   'PNLIP': 0,
#   'ADORA3': 0,
#   'ATP6AP1': 0,
#   'EMD': 0,
#   'ABCA4': 1,
#   'ABCC2': 0,
#   'CLCA4': 0,
#   'CLCA2': 0,
#   'CD40LG': 0,
#   'JUN': 0,
#   'UBAC1': 0,
#   'BEST4': 0,
#   'SFTPD': 0,
#   'SFTPA2': 0,
#   'MMP9': 3,
#   'LCN2': 1,
#   'SRC': 0,
#   'GSN': 2,
#   'MBL2': 2,
#   'TLR4': 4,
#   'SPDEF': 0,
#   'ALOX5': 0,
#   'TXN': 0,
#   'P2RY4': 0,
#   'ABCA1': 0,
#   'AGER': 1,
#   'RNF5': 0,
#   'PADI4': 0,
#   'CTRC': 0,
#   'CLCN5': 0,
#   'FOXP3': 0,
#   'ABCC4': 0,
#   'ANXA1': 1,
#   'SYVN1': 0,
#   'TCOF1': 0,
#   'CYBB': 0,
#   'PHEX': 0,
#   'ADRA1D': 3,
#   'DNAJA1': 0,
#   'DDX58': 0,
#   'BRCA2': 0,
#   'TLR7': 0,
#   'SMN1': 0,
#   'SERPINB1': 0,
#   'SMN2': 0,
#   'CLCN4': 0,
#   'IL33': 0,
#   'ASAH1': 0,
#   'RAD51': 0,
#   'CLCN7': 0,
#   'GJB2': 0,
#   'HSPD1': 0,
#   'KCNJ1': 0,
#   'REG3A': 1,
#   'GPT': 0,
#   'SLC26A6': 0,
#   'MAPK8': 0,
#   'CXCL1': 0,
#   'APIP': 0,
#   'CCK': 1,
#   'LTB4R': 0,
#   'NCF4': 0,
#   'INS': 12,
#   'MUC16': 0,
#   'ENSP00000381231': 0,
#   'CBSL': 0,
#   'ABCC1': 2,
#   'CDC42': 0,
#   'NEDD4L': 1,
#   'GGT1': 0,
#   'IFRD1': 2,
#   'NLRC4': 0,
#   'IL6': 0,
#   'GGT2': 0,
#   'DNASE1': 1,
#   'SFTPB': 0,
#   'IL1R1': 0,
#   'CD8A': 4,
#   'CXCR4': 1,
#   'GCG': 0,
#   'CREB1': 0,
#   'ENSP00000387760': 0,
#   'TLR6': 0,
#   'SLC4A4': 0,
#   'PACS2': 0,
#   'PDZK1': 0,
#   'SFTPA1': 0,
#   'CD44': 0,
#   'TNF': 8,
#   'BEST1': 1,
#   'RHOA': 1,
#   'MYD88': 1,
#   'SLC4A8': 0,
#   'TRPV4': 1,
#   'MUC6': 0,
#   'MUC7': 2,
#   'HRAS': 0,
#   'SLC9A3R2': 0,
#   'PTPRC': 0,
#   'IL10': 2,
#   'MUC20': 0,
#   'DCTN4': 2,
#   'IL31RA': 0,
#   'SERPINA1': 0,
#   'MUC4': 0,
#   'ENSP00000417517': 0,
#   'SLC26A8': 0,
#   'BRCA1': 0,
#   'SLC4A2': 0,
#   'DDX41': 0,
#   'CXCL2': 0,
#   'GYPB': 0,
#   'HSPA8': 0,
#   'CASP1': 0,
#   'FCGR3B': 0,
#   'EHF': 1,
#   'MUC5B': 5,
#   'HHAT': 0,
#   'TLR5': 3,
#   'CLDN2': 0,
#   'TAS2R20': 0,
#   'ITGAM': 0,
#   'ATP8B1': 0,
#   'VIM': 0,
#   'PRSS58': 0,
#   'VDR': 0,
#   'TAS2R38': 0,
#   'BEST2': 0,
#   'DDIT3': 0,
#   'HECTD4': 0,
#   'UBE2J1': 0,
#   'AKT1': 2,
#   'LDLR': 0,
#   'ITGAX': 0,
#   'MMP12': 0,
#   'PPY': 0,
#   'ELANE': 6,
#   'FPR2': 0,
#   'UPF1': 0,
#   'SLC6A14': 1,
#   'CCL5': 0,
#   'DNAH11': 0,
#   'GGTLC3': 0,
#   'CCL3': 0,
#   'STIM1': 0,
#   'ABCB1': 1,
#   'SMOX': 1,
#   'VEGFA': 5,
#   'MYC': 0,
#   'RAB7B': 0,
#   'DNAI1': 0,
#   'PTGES3': 0,
#   'HSH2D': 0,
#   'NEB': 0,
#   'MUC1': 0,
#   'MUC13': 0,
#   'PRSS3P2': 0,
#   'ADSL': 0,
#   'MUC5AC': 0,
#   'ERICD': 0,
#   'MALAT1': 0,
#   'SAA1': 0,
#   'SAA2': 0,
#   'AHRR': 0,
#   'SLC8A3': 0,
#   '7314': 0,
#   '7841': 0,
#   '3156': 0,
#   '14595': 0,
#   '8081': 0,
#   '10015': 0,
#   '19378': 0,
#   '10462': 0,
#   '10508': 0,
#   '15737': 0,
#   '11095': 0,
#   '11297': 0,
#   '6185': 0,
#   '6382': 0,
#   '2229': 0,
#   'BRD4': 0,
#   'FBXO8': 0,
#   'BPY2': 0,
#   'CTBS': 0,
#   'CRYGFP': 0,
#   'LIN9': 0,
#   'CTLA4': 0,
#   'A1CF': 1,
#   'MRO': 0,
#   'DLC1': 0,
#   'CD55': 0,
#   'DBP': 0,
#   'DNER': 0,
#   'ENOPH1': 0,
#   'CDT1': 0,
#   'LINC01554': 0,
#   'MICE': 0,
#   'LINC01672': 0,
#   'TXNRD2': 0,
#   'IFNE': 0,
#   'CREBZF': 0,
#   'RNF130': 0,
#   'CFC1': 0,
#   'MITF': 0,
#   'COX2': 0,
#   'MSN': 0,
#   'MSH3': 0,
#   'FEV': 0,
#   'LRRK2': 0,
#   'NES': 0,
#   'NFKB1': 0,
#   'NDUFB6': 0,
#   'CCDC6': 0,
#   'SLURP1': 2,
#   'NBL1': 0,
#   'NAP1L1': 0,
#   'CAP1': 0,
#   'NR3C1': 0,
#   'NOL3': 0,
#   'NOVA2': 0,
#   'C12orf57': 0,
#   'MTDH': 0,
#   'MLPH': 0,
#   'MCAT': 0,
#   'FRY': 0,
#   'SPG21': 0,
#   'FBRS': 0,
#   'NFASC': 0,
#   'C1D': 0,
#   'NDUFAF3': 0,
#   'GNL3': 0,
#   'ARMC9': 0,
#   'DSC3': 0,
#   'NLRP1': 0,
#   'F7': 0,
#   'F8': 0,
#   'FASN': 0,
#   'F2R': 0,
#   'MEG8': 0,
#   'SORBS1': 0,
#   'EPO': 0,
#   'EPM2A': 0,
#   'ESD': 0,
#   'ESR2': 0,
#   'SPATA1': 0,
#   'MTSS2': 0,
#   'SCGB2B3P': 0,
#   'FOXO3': 0,
#   'FPR1': 0,
#   'FGFR1': 0,
#   'FDFT1': 0,
#   'FES': 0,
#   'PIGS': 0,
#   'PLAAT1': 0,
#   'FXN': 0,
#   'FST': 1,
#   'PIMREG': 0,
#   'RESF1': 0,
#   'GORAB': 0,
#   'C6orf47': 0,
#   'NSF': 0,
#   'NRP1': 0,
#   'NT5E': 0,
#   'RLN2': 0,
#   'SNORA73A': 0,
#   'OMP': 0,
#   'SBDS': 1,
#   'RNU2-5P': 0,
#   'RNU2-2P': 0,
#   'RNU2-3P': 0,
#   'RNU2-4P': 0,
#   'RNU2-1': 0,
#   'RNU4-6P': 0,
#   'RNU4-8P': 0,
#   'RNU4-3P': 0,
#   'RNU4-4P': 0,
#   'RNU4-5P': 0,
#   'RNU4-1': 0,
#   'RNU4-7P': 0,
#   'RPL26': 0,
#   'RPLP2': 0,
#   'UHMK1': 0,
#   'SEPHS1': 0,
#   'SEPHS2': 0,
#   'RPS14': 0,
#   'RPS15': 0,
#   'PCBD1': 0,
#   'RRAD': 0,
#   'RPS6': 0,
#   'RPS18': 0,
#   'RPS5': 0,
#   'RPS3': 0,
#   'RPS2': 0,
#   'PAEP': 0,
#   'SDS': 0,
#   'SERPINB6': 0,
#   'QRSL1': 0,
#   'CCL21': 0,
#   'SDHA': 0,
#   'PCYT1B': 0,
#   'PCYT1A': 0,
#   'PEA15': 0,
#   'PES1': 0,
#   'PFDN4': 0,
#   'PFAS': 0,
#   'SRSF5': 0,
#   'SI': 0,
#   'ABRACL': 0,
#   'PMEL': 0,
#   'SLC16A1': 0,
#   'SLC17A5': 0,
#   'SLC25A1': 0,
#   'DYM': 0,
#   'SOSTDC1': 0,
#   'GC': 0,
#   'NMS': 0,
#   'FUS': 0,
#   'MBOAT4': 0,
#   'GHR': 0,
#   'MTPN': 0,
#   'H4C6': 0,
#   'DSTN': 0,
#   'H19': 1,
#   'GYPA': 0,
#   'GYPC': 0,
#   'GYPE': 0,
#   'ACSS2': 0,
#   'GTF2E1': 0,
#   'GTF2E2': 0,
#   'GTF2I': 0,
#   'GATA5': 0,
#   'HJV': 0,
#   'HGS': 1,
#   'SPAG17': 0,
#   'EMSLR': 0,
#   'PPP1R3A': 0,
#   'PPIB': 0,
#   'SEPTIN4': 0,
#   'SEPTIN5': 0,
#   'PMAIP1': 0,
#   'PLXNA3': 0,
#   'PMS2': 0,
#   'EXOSC10': 0,
#   'SNCG': 0,
#   'SOS2': 0,
#   'SMS': 0,
#   'SRL': 0,
#   'SP3': 0,
#   'SP2': 0,
#   'SSB': 0,
#   'PRB2': 0,
#   'PRF1': 0,
#   'PRKAA2': 0,
#   'PTPN6': 0,
#   'PTPN14': 0,
#   'PTGFR': 0,
#   'HACD1': 0,
#   'TWF1': 0,
#   'PSMB6': 1,
#   'PSMA7': 0,
#   'PSMD8': 0,
#   'PSMD3': 0,
#   'PSMD1': 0,
#   'PSMC4': 0,
#   'PSMD2': 0,
#   'PSME3': 0,
#   'EPCAM': 0,
#   'PTGDR': 0,
#   'RAI1': 0,
#   'TCIRG1': 0,
#   'PZP': 0,
#   'TGM1': 0,
#   'TG': 0,
#   'TH': 0,
#   'TERT': 0,
#   'TERC': 0,
#   'TEP1': 0,
#   'TFCP2': 0,
#   'ADK': 0,
#   'ADM': 0,
#   'THRSP': 0,
#   'TMEFF2': 0,
#   'FAS': 5,
#   'RFC2': 0,
#   'RFC4': 0,
#   'RFC1': 0,
#   'AKR1B1': 0,
#   'AKR1C1': 0,
#   'AKAP4': 0,
#   'MRLN': 0,
#   'TNP2': 0,
#   'AMH': 0,
#   'AMBP': 0,
#   'ARC': 0,
#   'AR': 0,
#   'ARHGAP4': 0,
#   'ASL': 0,
#   'ATP6V0A1': 0,
#   'ATP5PF': 0,
#   'RNF31': 0,
#   'B3GALNT1': 0,
#   'BCL2A1': 0,
#   'BCHE': 0,
#   'TP53INP2': 0,
#   'HMGCL': 0,
#   'SLC10A3': 0,
#   'CFI': 0,
#   'HR': 0,
#   'HSD17B4': 0,
#   'HM13': 0,
#   'SYNPR': 0,
#   'CARD16': 0,
#   'IGF1R': 0,
#   'IFNA1': 1,
#   'IGKV1D-37': 0,
#   'DNAJC21': 0,
#   'FIG4': 0,
#   'EFS': 0,
#   'IK': 0,
#   'EMG1': 0,
#   'CACNA1G-AS1': 0,
#   'BTN1A1': 0,
#   'BCS1L': 0,
#   'TRGV11': 0,
#   'TRGC1': 0,
#   'TRGVB': 0,
#   'TRGV9': 0,
#   'TST': 0,
#   'C6': 0,
#   'C5AR1': 1,
#   'C5': 0,
#   'C4B': 0,
#   'C4A': 0,
#   'CA1': 0,
#   'SPACA9': 0,
#   'CA9': 0,
#   'UBE4A': 0,
#   'UBE2V2': 0,
#   'SERPING1': 0,
#   'TYMS': 0,
#   'C2': 1,
#   'UBE4B': 0,
#   'CASP14': 0,
#   'CBS': 0,
#   'KRIT1': 0,
#   'XPR1': 0,
#   'YY1': 0,
#   'NANOS2': 0,
#   'LYST': 0,
#   'CISH': 1,
#   'SYNE1': 0,
#   'OPTN': 0,
#   'ACCS': 0,
#   'PART1': 0,
#   'LIF': 0,
#   'SARS2': 0,
#   'LTA': 0,
#   'LSS': 0,
#   'LNPEP': 0,
#   'LIPC': 0,
#   'LMOD1': 0,
#   'MATN3': 0,
#   'MCC': 0,
#   'ERVK-3': 0,
#   'ERVK-2': 0,
#   'ERVK-1': 0,
#   'ERVK-11': 0,
#   'ERVK-13': 0,
#   'ERVK-18': 0,
#   'MED25': 0,
#   'PDF': 0,
#   'GDF15': 0,
#   'LPCAT3': 0,
#   'WLS': 0,
#   'DNAAF3': 0,
#   'CPOX': 2,
#   'CP': 0,
#   'ERVK-10': 6,
#   'WFDC2': 1,
#   'GABPA': 2,
#   'H1-9P': 1,
#   'LTB': 1,
#   'PROK2': 1,
#   'CCL18': 1,
#   'CD79A': 4,
#   'EBP': 2,
#   'ERCC8': 2,
#   'CLC': 1,
#   'CSH1': 2,
#   'JAG1': 1,
#   'ESR1': 8,
#   'FLT4': 1,
#   'HFE': 3,
#   'HLA-DQA1': 1,
#   'HOXA10': 1,
#   'APEX1': 3,
#   'HSPA9': 2,
#   'LYZ': 1,
#   'MLN': 1,
#   'ASIP': 1,
#   'MPG': 1,
#   'ASPA': 1,
#   'NHS': 1,
#   'TBX22': 2,
#   'HDAC7': 1,
#   'PPARA': 1,
#   'FBLIM1': 2,
#   'SST': 1,
#   'TF': 2,
#   'ST7': 1,
#   'ROPN1L': 1,
#   'KRT90P': 3,
#   'GLE1': 1,
#   'ARSB': 2,
#   'PDE4A': 1,
#   'PRKAB1': 1,
#   'SULT1A1': 2,
#   'ST8SIA4': 2,
#   'MAPT': 2,
#   'ATP2A2': 1,
#   'ADA': 1,
#   'TOM1': 1,
#   'ABCB6': 1,
#   'KLF2': 1,
#   'TUBB4B': 1,
#   'MERTK': 1,
#   'CEL': 1,
#   'KHDRBS1': 1,
#   'CEACAM3': 1,
#   'MRPS30': 1,
#   'PAPOLA': 1,
#   'ERP29': 1,
#   'SLC27A5': 1,
#   'CAPN10': 1,
#   'TMC6': 2,
#   'PDAP1': 1,
#   'TUSC2': 1,
#   'LACTB': 1,
#   'TIRAP': 4,
#   'PRAP1': 1,
#   'CTRL': 2,
#   'ASPRV1': 1,
#   'CTSS': 1,
#   'CYP2D6': 1,
#   'CYP2E1': 2,
#   'DDT': 1,
#   'DEFA1': 1,
#   'DNAH8': 1,
#   'EPHB1': 1,
#   'PTGR1': 1,
#   'TARDBP': 1,
#   'NUP62': 1,
#   'GCA': 2,
#   'PRDX5': 1,
#   'BBS9': 1,
#   'STK39': 1,
#   'GLS': 1,
#   'UTS2R': 1,
#   'DLL1': 1,
#   'TRBV16': 1,
#   'TRBC1': 1,
#   'FFAR3': 1,
#   'FFAR2': 1,
#   'IGKV1-16': 1,
#   'GSR': 3,
#   'GSTM3': 1,
#   'HEXA': 1,
#   'HLA-DRB1': 1,
#   'HLA-E': 2,
#   'HLA-H': 1,
#   'HPGD': 1,
#   'NANOS1': 1,
#   'IFI16': 1,
#   'IGHE': 7,
#   'IL3': 1,
#   'ITGAL': 1,
#   'LCN1': 2,
#   'SMAD3': 1,
#   'MAL': 4,
#   'MAP6': 6,
#   'MARS1': 1,
#   'MSRA': 1,
#   'NEUROD1': 1,
#   'ASAP1': 1,
#   'CYRIB': 1,
#   'PIM1': 1,
#   'PLA2G5': 1,
#   'PPARG': 1,
#   'PPP5C': 1,
#   'PPT1': 1,
#   'PSG2': 1,
#   'PSMB5': 1,
#   'PDXP': 1,
#   'MCOLN1': 2,
#   'PTEN': 1,
#   'PTHLH': 1,
#   'NLN': 1,
#   'RAB27A': 1,
#   'REG1A': 1,
#   'REN': 1,
#   'CXCL6': 1,
#   'GMCL1': 2,
#   'GMCL2': 2,
#   'SLC6A2': 1,
#   'SLC15A2': 1,
#   'SRI': 2,
#   'TRB': 1,
#   'TRBV20OR9-2': 1,
#   'TRA-TGC7-1': 1,
#   'MANEA': 1,
#   'SLTM': 4,
#   'PARP9': 1,
#   'TNS4': 1,
#   'FBF1': 4,
#   'DCLK3': 1,
#   'YARS1': 1,
#   'CAV2': 2,
#   'RNMT': 4,
#   'TNFRSF10B': 1,
#   'ASAP2': 1,
#   'SQSTM1': 1,
#   'TIMELESS': 1,
#   'CCNE2': 1,
#   'GLS2': 1,
#   'LPL': 1,
#   'EPHX1': 2,
#   'CTSL': 1,
#   'PEMT': 1,
#   'MMP2': 1,
#   'CBL': 1,
#   'CYP1A1': 2,
#   'GSTP1': 1,
#   'GSTM1': 1,
#   'COL1A2': 3,
#   'DLEU1': 1,
#   'GPI': 1,
#   'IGFBP2': 1,
#   'CD14': 2,
#   'MET': 4,
#   'PLA2G4C': 1,
#   'TCF7L2': 1,
#   'IGFBP3': 1,
#   'CFB': 1,
#   'CA12': 1,
#   'MSC': 1,
#   'SNW1': 1,
#   'PTS': 0,
#   'FER': 0,
#   'MAX': 0,
#   'DES': 0,
#   'AIRE': 0,
#   'CAST': 0,
#   'CAPS': 0,
#   'REST': 0,
#   'NTM': 0,
#   'ERAS': 0,
#   'STS': 0,
#   'SON': 0,
#   'DAP': 0,
#   'ADO': 0,
#   'TLE5': 0,
#   'RFLNB': 0,
#   'MUC2': 0,
#   'STX1A': 0,
#   'FCGR2A': 0,
#   'AGTR2': 0,
#   'MTHFR': 0,
#   'CHAC1': 0,
#   'PTX3': 0,
#   'DEFB4B': 0},
#  'disease_to_genes_list': ['CFTR',
#   'TGFB1',
#   'ELANE',
#   'CAMP',
#   'SCNN1B',
#   'SLC9A3',
#   'ERVK-10',
#   'MUC5B',
#   'DCTN4',
#   'TNF',
#   'SLPI',
#   'SCNN1G',
#   'VDAC1',
#   'CLCA1',
#   'TNFRSF1A',
#   'FAS',
#   'TLR5',
#   'INS',
#   'TLR4',
#   'SLC26A9',
#   'SCNN1A',
#   'ANO1',
#   'LEP',
#   'CXCL8',
#   'CXCR1',
#   'CA2',
#   'IL1B',
#   'MAL',
#   'HFE',
#   'SLURP1',
#   'AHRR',
#   'MUC5AC',
#   'SMOX',
#   'AKT1',
#   'MUC4',
#   'SERPINA1',
#   'CD8A',
#   'DNASE1',
#   'IFRD1',
#   'ABCC1',
#   'REG3A',
#   'ADRA1D',
#   'GSN',
#   'VIP',
#   'DMD',
#   'HP',
#   'SLC26A3',
#   'PRSS8',
#   'CXCR2',
#   'DEFB4A',
#   'DEFB1',
#   'SPINK1',
#   'PTH',
#   'BPI',
#   'SLC9A3R1',
#   'CAT',
#   'CCL2',
#   'FCGR2A',
#   'STX1A',
#   'CYP1A1',
#   'EPHX1',
#   'MAP6',
#   'CYP2E1',
#   'TIRAP',
#   'MAPT',
#   'ST8SIA4',
#   'SULT1A1',
#   'ARSB',
#   'KRT90P',
#   'TF',
#   'FBLIM1',
#   'NHS',
#   'HSPA9',
#   'APEX1',
#   'ESR1',
#   'CSH1',
#   'ERCC8',
#   'CD79A',
#   'GABPA',
#   'CPOX',
#   'CISH',
#   'C2',
#   'C5AR1',
#   'TST',
#   'IFNA1',
#   'ASL',
#   'AR',
#   'ARC',
#   'PSMB6',
#   'HGS',
#   'H19',
#   'SI',
#   'SBDS',
#   'FST',
#   'FEV',
#   'A1CF',
#   'SLC8A3',
#   'MUC1',
#   'DNAI1',
#   'VEGFA',
#   'ABCB1',
#   'SLC6A14',
#   'FPR2',
#   'PPY',
#   'MMP12',
#   'PRSS58',
#   'VIM',
#   'EHF',
#   'DDX41',
#   'IL10',
#   'SLC9A3R2',
#   'MUC7',
#   'TRPV4',
#   'MYD88',
#   'RHOA',
#   'BEST1',
#   'CXCR4',
#   'IL6',
#   'NEDD4L',
#   'CCK',
#   'APIP',
#   'ASAH1',
#   'SERPINB1',
#   'TCOF1',
#   'ANXA1',
#   'RNF5',
#   'AGER',
#   'MBL2',
#   'LCN2',
#   'MMP9',
#   'CLCA4',
#   'ABCA4',
#   'ATP6AP1',
#   'S100A12',
#   'GOPC',
#   'TFRC',
#   'SPINK5',
#   'GUCA2A',
#   'BPIFA1',
#   'KCNJ11',
#   'HMGB1',
#   'IL17A',
#   'CELA3B',
#   'NLRP3',
#   'NOS2',
#   'FLNC',
#   'KCNE3',
#   'P2RY2',
#   'PRSS1',
#   'F2',
#   'ABCC8',
#   'HSPA4',
#   'NOD2',
#   'ANXA5',
#   'ALB',
#   'AQP5',
#   'LY96',
#   'EGFR',
#   'SLC26A4',
#   'CLCN2',
#   'DNAH5',
#   'FAM13A',
#   'KCNN4',
#   'SLC12A2',
#   'LPO',
#   'GUCY2C',
#   'CRP',
#   'BPIFB1',
#   'CANX',
#   'CFP',
#   'C3',
#   'MRPS7',
#   'PI3',
#   'TTR',
#   'PRTN3',
#   'IL5',
#   'IL4',
#   'IL2',
#   'MPO',
#   'ATP12A',
#   'TIMP1',
#   'AHSA1',
#   'CTSG',
#   'AQP2',
#   'SCT',
#   'DEFB4B',
#   'PTX3',
#   'CHAC1',
#   'MTHFR',
#   'AGTR2',
#   'MUC2',
#   'RFLNB',
#   'TLE5',
#   'ADO',
#   'DAP',
#   'SON',
#   'STS',
#   'ERAS',
#   'NTM',
#   'REST',
#   'CAPS',
#   'CAST',
#   'AIRE',
#   'DES',
#   'MAX',
#   'FER',
#   'PTS',
#   'SNW1',
#   'MSC',
#   'CA12',
#   'CFB',
#   'IGFBP3',
#   'TCF7L2',
#   'PLA2G4C',
#   'MET',
#   'CD14',
#   'IGFBP2',
#   'GPI',
#   'DLEU1',
#   'COL1A2',
#   'GSTM1',
#   'GSTP1',
#   'CBL',
#   'MMP2',
#   'PEMT',
#   'CTSL',
#   'LPL',
#   'GLS2',
#   'CCNE2',
#   'TIMELESS',
#   'SQSTM1',
#   'ASAP2',
#   'TNFRSF10B',
#   'RNMT',
#   'CAV2',
#   'YARS1',
#   'DCLK3',
#   'FBF1',
#   'TNS4',
#   'PARP9',
#   'SLTM',
#   'MANEA',
#   'TRA-TGC7-1',
#   'TRBV20OR9-2',
#   'TRB',
#   'SRI',
#   'SLC15A2',
#   'SLC6A2',
#   'GMCL2',
#   'GMCL1',
#   'CXCL6',
#   'REN',
#   'REG1A',
#   'RAB27A',
#   'NLN',
#   'PTHLH',
#   'PTEN',
#   'MCOLN1',
#   'PDXP',
#   'PSMB5',
#   'PSG2',
#   'PPT1',
#   'PPP5C',
#   'PPARG',
#   'PLA2G5',
#   'PIM1',
#   'CYRIB',
#   'ASAP1',
#   'NEUROD1',
#   'MSRA',
#   'MARS1',
#   'SMAD3',
#   'LCN1',
#   'ITGAL',
#   'IL3',
#   'IGHE',
#   'IFI16',
#   'NANOS1',
#   'HPGD',
#   'HLA-H',
#   'HLA-E',
#   'HLA-DRB1',
#   'HEXA',
#   'GSTM3',
#   'GSR',
#   'IGKV1-16',
#   'FFAR2',
#   'FFAR3',
#   'TRBC1',
#   'TRBV16',
#   'DLL1',
#   'UTS2R',
#   'GLS',
#   'STK39',
#   'BBS9',
#   'PRDX5',
#   'GCA',
#   'NUP62',
#   'TARDBP',
#   'PTGR1',
#   'EPHB1',
#   'DNAH8',
#   'DEFA1',
#   'DDT',
#   'CYP2D6',
#   'CTSS',
#   'ASPRV1',
#   'CTRL',
#   'PRAP1',
#   'LACTB',
#   'TUSC2',
#   'PDAP1',
#   'TMC6',
#   'CAPN10',
#   'SLC27A5',
#   'ERP29',
#   'PAPOLA',
#   'MRPS30',
#   'CEACAM3',
#   'KHDRBS1',
#   'CEL',
#   'MERTK',
#   'TUBB4B',
#   'KLF2',
#   'ABCB6',
#   'TOM1',
#   'ADA',
#   'ATP2A2',
#   'PRKAB1',
#   'PDE4A',
#   'GLE1',
#   'ROPN1L',
#   'ST7',
#   'SST',
#   'PPARA',
#   'HDAC7',
#   'TBX22',
#   'ASPA',
#   'MPG',
#   'ASIP',
#   'MLN',
#   'LYZ',
#   'HOXA10',
#   'HLA-DQA1',
#   'FLT4',
#   'JAG1',
#   'CLC',
#   'EBP',
#   'CCL18',
#   'PROK2',
#   'LTB',
#   'H1-9P',
#   'WFDC2',
#   'CP',
#   'DNAAF3',
#   'WLS',
#   'LPCAT3',
#   'GDF15',
#   'PDF',
#   'MED25',
#   'ERVK-18',
#   'ERVK-13',
#   'ERVK-11',
#   'ERVK-1',
#   'ERVK-2',
#   'ERVK-3',
#   'MCC',
#   'MATN3',
#   'LMOD1',
#   'LIPC',
#   'LNPEP',
#   'LSS',
#   'LTA',
#   'SARS2',
#   'LIF',
#   'PART1',
#   'ACCS',
#   'OPTN',
#   'SYNE1',
#   'LYST',
#   'NANOS2',
#   'YY1',
#   'XPR1',
#   'KRIT1',
#   'CBS',
#   'CASP14',
#   'UBE4B',
#   'TYMS',
#   'SERPING1',
#   'UBE2V2',
#   'UBE4A',
#   'CA9',
#   'SPACA9',
#   'CA1',
#   'C4A',
#   'C4B',
#   'C5',
#   'C6',
#   'TRGV9',
#   'TRGVB',
#   'TRGC1',
#   'TRGV11',
#   'BCS1L',
#   'BTN1A1',
#   'CACNA1G-AS1',
#   'EMG1',
#   'IK',
#   'EFS',
#   'FIG4',
#   'DNAJC21',
#   'IGKV1D-37',
#   'IGF1R',
#   'CARD16',
#   'SYNPR',
#   'HM13',
#   'HSD17B4',
#   'HR',
#   'CFI',
#   'SLC10A3',
#   'HMGCL',
#   'TP53INP2',
#   'BCHE',
#   'BCL2A1',
#   'B3GALNT1',
#   'RNF31',
#   'ATP5PF',
#   'ATP6V0A1',
#   'ARHGAP4',
#   'AMBP',
#   'AMH',
#   'TNP2',
#   'MRLN',
#   'AKAP4',
#   'AKR1C1',
#   'AKR1B1',
#   'RFC1',
#   'RFC4',
#   'RFC2',
#   'TMEFF2',
#   'THRSP',
#   'ADM',
#   'ADK',
#   'TFCP2',
#   'TEP1',
#   'TERC',
#   'TERT',
#   'TH',
#   'TG',
#   'TGM1',
#   'PZP',
#   'TCIRG1',
#   'RAI1',
#   'PTGDR',
#   'EPCAM',
#   'PSME3',
#   'PSMD2',
#   'PSMC4',
#   'PSMD1',
#   'PSMD3',
#   'PSMD8',
#   'PSMA7',
#   'TWF1',
#   'HACD1',
#   'PTGFR',
#   'PTPN14',
#   'PTPN6',
#   'PRKAA2',
#   'PRF1',
#   'PRB2',
#   'SSB',
#   'SP2',
#   'SP3',
#   'SRL',
#   'SMS',
#   'SOS2',
#   'SNCG',
#   'EXOSC10',
#   'PMS2',
#   'PLXNA3',
#   'PMAIP1',
#   'SEPTIN5',
#   'SEPTIN4',
#   'PPIB',
#   'PPP1R3A',
#   'EMSLR',
#   'SPAG17',
#   'HJV',
#   'GATA5',
#   'GTF2I',
#   'GTF2E2',
#   'GTF2E1',
#   'ACSS2',
#   'GYPE',
#   'GYPC',
#   'GYPA',
#   'DSTN',
#   'H4C6',
#   'MTPN',
#   'GHR',
#   'MBOAT4',
#   'FUS',
#   'NMS',
#   'GC',
#   'SOSTDC1',
#   'DYM',
#   'SLC25A1',
#   'SLC17A5',
#   'SLC16A1',
#   'PMEL',
#   'ABRACL',
#   'SRSF5',
#   'PFAS',
#   'PFDN4',
#   'PES1',
#   'PEA15',
#   'PCYT1A',
#   'PCYT1B',
#   'SDHA',
#   'CCL21',
#   'QRSL1',
#   'SERPINB6',
#   'SDS',
#   'PAEP',
#   'RPS2',
#   'RPS3',
#   'RPS5',
#   'RPS18',
#   'RPS6',
#   'RRAD',
#   'PCBD1',
#   'RPS15',
#   'RPS14',
#   'SEPHS2',
#   'SEPHS1',
#   'UHMK1',
#   'RPLP2',
#   'RPL26',
#   'RNU4-7P',
#   'RNU4-1',
#   'RNU4-5P',
#   'RNU4-4P',
#   'RNU4-3P',
#   'RNU4-8P',
#   'RNU4-6P',
#   'RNU2-1',
#   'RNU2-4P',
#   'RNU2-3P',
#   'RNU2-2P',
#   'RNU2-5P',
#   'OMP',
#   'SNORA73A',
#   'RLN2',
#   'NT5E',
#   'NRP1',
#   'NSF',
#   'C6orf47',
#   'GORAB',
#   'RESF1',
#   'PIMREG',
#   'FXN',
#   'PLAAT1',
#   'PIGS',
#   'FES',
#   'FDFT1',
#   'FGFR1',
#   'FPR1',
#   'FOXO3',
#   'SCGB2B3P',
#   'MTSS2',
#   'SPATA1',
#   'ESR2',
#   'ESD',
#   'EPM2A',
#   'EPO',
#   'SORBS1',
#   'MEG8',
#   'F2R',
#   'FASN',
#   'F8',
#   'F7',
#   'NLRP1',
#   'DSC3',
#   'ARMC9',
#   'GNL3',
#   'NDUFAF3',
#   'C1D',
#   'NFASC',
#   'FBRS',
#   'SPG21',
#   'FRY',
#   'MCAT',
#   'MLPH',
#   'MTDH',
#   'C12orf57',
#   'NOVA2',
#   'NOL3',
#   'NR3C1',
#   'CAP1',
#   'NAP1L1',
#   'NBL1',
#   'CCDC6',
#   'NDUFB6',
#   'NFKB1',
#   'NES',
#   'LRRK2',
#   'MSH3',
#   'MSN',
#   'COX2',
#   'MITF',
#   'CFC1',
#   'RNF130',
#   'CREBZF',
#   'IFNE',
#   'TXNRD2',
#   'LINC01672',
#   'MICE',
#   'LINC01554',
#   'CDT1',
#   'ENOPH1',
#   'DNER',
#   'DBP',
#   'CD55',
#   'DLC1',
#   'MRO',
#   'CTLA4',
#   'LIN9',
#   'CRYGFP',
#   'CTBS',
#   'BPY2',
#   'FBXO8',
#   'BRD4',
#   '2229',
#   '6382',
#   '6185',
#   '11297',
#   '11095',
#   '15737',
#   '10508',
#   '10462',
#   '19378',
#   '10015',
#   '8081',
#   '14595',
#   '3156',
#   '7841',
#   '7314',
#   'SAA2',
#   'SAA1',
#   'MALAT1',
#   'ERICD',
#   'ADSL',
#   'PRSS3P2',
#   'MUC13',
#   'NEB',
#   'HSH2D',
#   'PTGES3',
#   'RAB7B',
#   'MYC',
#   'STIM1',
#   'CCL3',
#   'GGTLC3',
#   'DNAH11',
#   'CCL5',
#   'UPF1',
#   'ITGAX',
#   'LDLR',
#   'UBE2J1',
#   'HECTD4',
#   'DDIT3',
#   'BEST2',
#   'TAS2R38',
#   'VDR',
#   'ATP8B1',
#   'ITGAM',
#   'TAS2R20',
#   'CLDN2',
#   'HHAT',
#   'FCGR3B',
#   'CASP1',
#   'HSPA8',
#   'GYPB',
#   'CXCL2',
#   'SLC4A2',
#   'BRCA1',
#   'SLC26A8',
#   'ENSP00000417517',
#   'IL31RA',
#   'MUC20',
#   'PTPRC',
#   'HRAS',
#   'MUC6',
#   'SLC4A8',
#   'CD44',
#   'SFTPA1',
#   'PDZK1',
#   'PACS2',
#   'SLC4A4',
#   'TLR6',
#   'ENSP00000387760',
#   'CREB1',
#   'GCG',
#   'IL1R1',
#   'SFTPB',
#   'GGT2',
#   'NLRC4',
#   'GGT1',
#   'CDC42',
#   'CBSL',
#   'ENSP00000381231',
#   'MUC16',
#   'NCF4',
#   'LTB4R',
#   'CXCL1',
#   'MAPK8',
#   'SLC26A6',
#   'GPT',
#   'KCNJ1',
#   'HSPD1',
#   'GJB2',
#   'CLCN7',
#   'RAD51',
#   'IL33',
#   'CLCN4',
#   'SMN2',
#   'SMN1',
#   'TLR7',
#   'BRCA2',
#   'DDX58',
#   'DNAJA1',
#   'PHEX',
#   'CYBB',
#   'SYVN1',
#   'ABCC4',
#   'FOXP3',
#   'CLCN5',
#   'CTRC',
#   'PADI4',
#   'ABCA1',
#   'P2RY4',
#   'TXN',
#   'ALOX5',
#   'SPDEF',
#   'SRC',
#   'SFTPA2',
#   'SFTPD',
#   'BEST4',
#   'UBAC1',
#   'JUN',
#   'CD40LG',
#   'CLCA2',
#   'ABCC2',
#   'EMD',
#   'ADORA3',
#   'PNLIP',
#   'PREP',
#   'PSMD4',
#   'S100A9',
#   'S100A8',
#   'BGLAP',
#   'ATF6',
#   'ADCY10',
#   'PTGS2',
#   'ADORA1',
#   'EZR',
#   'PARP1',
#   'TGM2',
#   'BECN1',
#   'TLR1',
#   'SLC26A1',
#   'MTOR',
#   'STAT1',
#   'TLR9',
#   'ELN',
#   'VCP',
#   'PRDM10',
#   'CCL20',
#   'ACTB',
#   'ARG1',
#   'ANO2',
#   'OCLN',
#   'HTT',
#   'FN1',
#   'RPS3A',
#   'CTSB',
#   'SMPD1',
#   'CLCN1',
#   'TSLP',
#   'CAV1',
#   'CYP3A4',
#   'IL17F',
#   'ADORA2A',
#   'HSP90AA1',
#   'HBB',
#   'ABCC5',
#   'LAMP1',
#   'BEST3',
#   'FAM101B',
#   'NPLOC4',
#   'PHF12',
#   'DEFB103B',
#   'HSPA5',
#   'FOXJ1',
#   'P2RY11',
#   'TAC1',
#   'DEFB103A',
#   'CALR',
#   'DUOX1',
#   'WDTC1',
#   'EEA1',
#   'SFTPC',
#   'TLR8',
#   'AQP1',
#   'CASP3',
#   'HCFC1',
#   'TLR10',
#   'CYCS',
#   'ETV5',
#   'CXCL10',
#   'ADRB2',
#   'IL13',
#   'ADORA2B',
#   'IGF1',
#   'CLEC7A',
#   'CXXC5',
#   'RNASE3',
#   'CCL11',
#   'ABCA3',
#   'STAT6',
#   'CLPX',
#   'HSP90B1',
#   'NOS3',
#   'LMTK2',
#   'CSF2',
#   'TLR3',
#   'ADH5',
#   'RHO',
#   'CXCL5',
#   'HPGDS',
#   'ZSWIM2',
#   'CELA1',
#   'CCR5',
#   'ACE',
#   'AMFR',
#   'KCNMA1',
#   'SLC26A2',
#   'CRYGC',
#   'TJP1',
#   'MMAA',
#   'IL18',
#   'SCGB1A1',
#   'GGCT',
#   'IL9',
#   'MARCH6',
#   'RAB5A',
#   'TP53',
#   'FGF7',
#   'LUM',
#   'ABCB4',
#   'EGF',
#   'NPR3',
#   'RAB7A',
#   'KNG1',
#   'ICAM1',
#   'FGF10',
#   'STAT3',
#   'PRKG2',
#   'SLC9A1',
#   'ABCB11',
#   'IL1A',
#   'TYR',
#   'UFD1L',
#   'MAPK3',
#   'ATP4A',
#   'KCNH2',
#   'RAB11A',
#   'CDH1',
#   'CLCN3',
#   'ABCC9',
#   'TLR2',
#   'CLPS',
#   'KIDINS220',
#   'EDEM1',
#   'CHI3L1',
#   'DNAJB1',
#   'APOE',
#   'SEC61A1',
#   'ABCG2',
#   'MMP8',
#   'SLC9A2',
#   'MLH1',
#   'MAPK14',
#   'GAPDH',
#   'IFNG',
#   'LTA4H',
#   'PANX1',
#   'ASIC2',
#   'CSF3',
#   'NOD1',
#   'AES',
#   'STUB1',
#   'CCL17',
#   'F9',
#   'TBL1X',
#   'HMOX1',
#   'XBP1',
#   'MAPK1',
#   'PSMD5',
#   'ABCC6',
#   'KCNQ1',
#   'CD4',
#   'CPA1',
#   'MGI:88388',
#   'MGI:3605470',
#   'MGI:104696']}

# %% [markdown]
# ## Get Disease -> intermediate_node (any except those matching symptoms) -> Gene

# %%
# get results using intermediates 
node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %%
disease_disease_all_nodes_genes = gsf.predict_many(disease, node_type_list, 'Gene')

# Save an object to a file
# %store disease_disease_all_nodes_genes
# Out:
# Intermediate Node type running:
# Gene
# API 4.1 semmed_gene failed
# API 4.2 semmed_gene failed
# API 4.4 semmed_gene failed
# API 4.7 semmed_gene failed
# API 4.5 semmed_gene failed
# API 4.8 semmed_gene failed
# API 4.3 semmed_gene failed
# API 4.6 semmed_gene failed
# API 4.10 semmed_gene failed
# API 4.9 semmed_gene failed
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# API 4.1 pharos failed
# Intermediate Node type running:
# Disease
# API 2.2 semmed_disease failed
# API 2.1 semmed_disease failed
# API 2.7 semmed_disease failed
# API 2.6 semmed_disease failed
# API 2.3 semmed_disease failed
# API 6.1 mydisease failed
# API 2.4 semmed_disease failed
# API 2.9 semmed_disease failed
# API 2.8 semmed_disease failed
# API 2.10 semmed_disease failed
# API 2.12 semmed_disease failed
# API 2.14 semmed_disease failed
# API 2.5 semmed_disease failed
# API 2.13 semmed_disease failed
# API 2.11 semmed_disease failed
# API 2.15 semmed_disease failed
# 1 mygene.info failed
# FAILED
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# Stored 'disease_disease_all_nodes_genes' (DataFrame)

# %%
# Restore the object
# %store -r disease_disease_all_nodes_genes
disease_disease_all_nodes_genes
# Out:
#                 input input_type        pred1  \
# 0     CYSTIC FIBROSIS    Disease   related_to
# 2     CYSTIC FIBROSIS    Disease   related_to
# 3     CYSTIC FIBROSIS    Disease   related_to
# 4     CYSTIC FIBROSIS    Disease   treated_by
# 5     CYSTIC FIBROSIS    Disease  affected_by
# ...               ...        ...          ...
# 3179  CYSTIC FIBROSIS    Disease   related_to
# 3180  CYSTIC FIBROSIS    Disease   related_to
# 3181  CYSTIC FIBROSIS    Disease   related_to
# 3182  CYSTIC FIBROSIS    Disease   related_to
# 3183  CYSTIC FIBROSIS    Disease   related_to
#
#                          pred1_source           pred1_api pred1_pubmed  \
# 0                             DISEASE        DISEASES API         None
# 2     Translator Text Mining Provider    CORD Disease API         None
# 3                                None         BioLink API         None
# 4                              SEMMED  SEMMED Disease API     22613978
# 5                              SEMMED  SEMMED Disease API     26754178
# ...                               ...                 ...          ...
# 3179                              hpo  mydisease.info API         None
# 3180                              hpo  mydisease.info API         None
# 3181                              hpo  mydisease.info API         None
# 3182                              hpo  mydisease.info API         None
# 3183                              hpo  mydisease.info API         None
#
#              node1_type           node1_name       node1_id          pred2  \
# 0                  Gene                 CFTR  NCBIGene:1080  homologous_to
# 2                  Gene                 CFTR  NCBIGene:1080  homologous_to
# 3                  Gene                 CFTR  NCBIGene:1080  homologous_to
# 4                  Gene                 CFTR  NCBIGene:1080  homologous_to
# 5                  Gene                 CFTR  NCBIGene:1080  homologous_to
# ...                 ...                  ...            ...            ...
# 3179  PhenotypicFeature  AUTOSOMAL RECESSIVE  UMLS:C0441748     related_to
# 3180  PhenotypicFeature  AUTOSOMAL RECESSIVE  UMLS:C0441748     related_to
# 3181  PhenotypicFeature  AUTOSOMAL RECESSIVE  UMLS:C0441748     related_to
# 3182  PhenotypicFeature  AUTOSOMAL RECESSIVE  UMLS:C0441748     related_to
# 3183  PhenotypicFeature  AUTOSOMAL RECESSIVE  UMLS:C0441748     related_to
#
#      pred2_source              pred2_api pred2_pubmed output_type output_name  \
# 0            None        MyGene.info API         None        Gene       88388
# 2            None        MyGene.info API         None        Gene       88388
# 3            None        MyGene.info API         None        Gene       88388
# 4            None        MyGene.info API         None        Gene       88388
# 5            None        MyGene.info API         None        Gene       88388
# ...           ...                    ...          ...         ...         ...
# 3179          EBI  EBIgene2phenotype API         None        Gene      NMNAT1
# 3180          EBI  EBIgene2phenotype API         None        Gene        FKRP
# 3181          EBI  EBIgene2phenotype API         None        Gene        CRB2
# 3182          EBI  EBIgene2phenotype API         None        Gene       DOCK6
# 3183          EBI  EBIgene2phenotype API         None        Gene        P3H1
#
#             output_id
# 0           MGI:88388
# 2           MGI:88388
# 3           MGI:88388
# 4           MGI:88388
# 5           MGI:88388
# ...               ...
# 3179   NCBIGene:64802
# 3180   NCBIGene:79147
# 3181  NCBIGene:286204
# 3182   NCBIGene:57572
# 3183   NCBIGene:64175
#
# [1596364 rows x 16 columns]

# %%
## Remove UMLS "Genes"  (not gene specific) 
disease_disease_all_nodes_genes = disease_disease_all_nodes_genes[~disease_disease_all_nodes_genes['output_id'].str.contains('UMLS')]

# %%
max_2_step_genes = 100
disease_disease_to_node_to_genes_dict = gsf.get_disease_to_node_to_gene_results(disease_disease_all_nodes_genes, max_2_step_genes, disease_symptoms, disease_symptom_hpids)
# %store disease_disease_to_node_to_genes_dict
# Out:
# finding intermediate nodes that are symptoms
# removing symptom intermediates
# getting gene counts from 1104475 gene entries
# sorting counts dictionary
# top genes occurrence counts:
# TNF: 4062
# CAT: 3247
# CA2: 2670
# INS: 2468
# CAMP: 2400
# AKT1: 2180
# VEGFA: 2071
# TP53: 1946
# MAPK1: 1872
# EGFR: 1795
# IL6: 1762
# TGFB1: 1714
# TH: 1702
# IFNA1: 1672
# CD4: 1663
# ALB: 1626
# FOS: 1626
# FAS: 1570
# MPO: 1532
# APP: 1529
# IL2: 1527
# PTH: 1482
# LEP: 1468
# POMC: 1464
# WDTC1: 1432
# MMP9: 1406
# TLR4: 1374
# CISH: 1374
# MAPK8: 1358
# MUC7: 1288
# AR: 1288
# CDKN1A: 1228
# SOD1: 1206
# MCOLN1: 1203
# REN: 1188
# CCL2: 1188
# GPI: 1177
# GRK2: 1161
# ESR1: 1144
# RELA: 1136
# STAT3: 1131
# HGS: 1122
# PIK3CA: 1121
# CXCL8: 1114
# MMP2: 1111
# CASP14: 1111
# CYP3A4: 1102
# CRK: 1098
# CP: 1083
# BAX: 1066
# FASN: 1045
# TCEAL1: 1037
# RHO: 1007
# PTGS2: 1002
# PSMB6: 988
# BBS9: 983
# SST: 979
# CFTR: 976
# H3P16: 973
# MTOR: 968
# PTS: 964
# TIMP1: 956
# PPIB: 953
# IL10: 948
# CD40: 941
# EGF: 933
# TTR: 933
# SLC17A5: 929
# AHSA1: 925
# TF: 920
# GABPA: 908
# PPIG: 907
# G6PD: 906
# CSH1: 896
# IGHE: 888
# CCK: 879
# PPARA: 877
# LPL: 873
# ITGAM: 872
# PGR: 871
# PTEN: 869
# TAT: 866
# SDS: 865
# MAPK3: 857
# CCND1: 857
# ERVK-11: 846
# GC: 837
# MAPT: 829
# ABCB1: 829
# KIT: 827
# ERVK-19: 826
# CTLA4: 823
# ERVK-10: 822
# CD44: 822
# MICE: 816
# LYZ: 814
# CREBBP: 812
# CD14: 805
# DNAH8: 802
# BCL2: 802
# getting publicaiton counts
# Stored 'disease_disease_to_node_to_genes_dict' (dict)

# %% [markdown]
# ## Combine genes from one and two step processes then get rid of any duplicates

# %%
# %store -r disease_disease_to_node_to_genes_dict
disease_top_genes_list = disease_disease_to_genes_dict["disease_to_genes_list"] + disease_disease_to_node_to_genes_dict["top_related_genes_to_disease"]
disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
# top_genes_list

# %% [markdown]
# ## Get Genes -> Symtoms, filtered by those related to Disease

# %%
disease_relevant_genes_to_symptoms_df = gsf.determined_genes_to_symptoms(disease_top_genes_list, disease_symptoms)
# relevant_genes_to_symptoms_df
# Out:
# Genes -> PhenotypicFeatures
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# 11297 FAILED
# 15737 FAILED
# 10508 FAILED
# 19378 FAILED
# 14595 FAILED
# ENSP00000417517 FAILED
# ENSP00000387760 FAILED
# ENSP00000381231 FAILED
# FAM101B FAILED
# MARCH6 FAILED
# UFD1L FAILED
# AES FAILED
# MGI:88388 FAILED
# MGI:3605470 FAILED
# MGI:104696 FAILED
# APP FAILED
# Genes -> Bioprocesses
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# 11297 FAILED
# 15737 FAILED
# 10508 FAILED
# 19378 FAILED
# 14595 FAILED
# ENSP00000417517 FAILED
# ENSP00000387760 FAILED
# ENSP00000381231 FAILED
# FAM101B FAILED
# MARCH6 FAILED
# UFD1L FAILED
# AES FAILED
# MGI:88388 FAILED
# MGI:3605470 FAILED
# MGI:104696 FAILED
# APP FAILED
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Genes -> Diseases
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# 11297 FAILED
# 15737 FAILED
# 10508 FAILED
# 19378 FAILED
# 14595 FAILED
# ENSP00000417517 FAILED
# ENSP00000387760 FAILED
# ENSP00000381231 FAILED
# FAM101B FAILED
# MARCH6 FAILED
# UFD1L FAILED
# AES FAILED
# MGI:88388 FAILED
# MGI:3605470 FAILED
# MGI:104696 FAILED
# APP FAILED
# 1814

# %%
# %store disease_relevant_genes_to_symptoms_df
# Out:
# Stored 'disease_relevant_genes_to_symptoms_df' (DataFrame)

# %%
# %store -r disease_relevant_genes_to_symptoms_df
disease_relevant_genes_list = list(dict.fromkeys(list(disease_relevant_genes_to_symptoms_df["input"])))
# relevant_genes_list

# %%
disease_gene_to_symptom_pub_counts = gsf.get_gene_to_symptom_publication_counts(disease_relevant_genes_to_symptoms_df)
# gene_to_symptom_pub_counts

# %%
disease_causes_dict = gsf.create_causes_dict(disease_relevant_genes_to_symptoms_df)
# causes_dict

# %% [markdown]
# ## Get edges out from each gene
# For use in normalizing in relevance score

# %%
disease_connection_dict =  gsf.get_connection_normalizing_count(disease_relevant_genes_list,node_type_list)
# connection_dict
# Out:
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]

# %%
# %store disease_connection_dict
# Out:
# Stored 'disease_connection_dict' (dict)

# %%
# %store -r disease_connection_dict

# %% [markdown]
# ## Assemble final results

# %%
disease_df = gsf.assemble_final_data_frame(disease_relevant_genes_to_symptoms_df, 
                                      disease_connection_dict,
                                      disease_disease_to_genes_dict['sorted_disease_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['sorted_disease_to_all_nodes_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['top_two_step_genes_pub_counts'], 
                                      disease_gene_to_symptom_pub_counts, 
                                      disease_causes_dict,
                                      disease_symptoms_df)
disease_df
# Out:
#        gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 0      CFTR                    16                        976
# 27    CLCA4                     2                         36
# 1     TGFB1                     8                       1714
# 3     DCTN4                     5                        166
# 9       HFE                     3                        248
# ..      ...                   ...                        ...
# 404   SPG21                     1                        702
# 405     FRY                     1                        170
# 406   NOVA2                     1                        371
# 407    NOL3                     1                        228
# 360  PRKAA2                     1                        208
#
#               disease_symptoms_gene_is_associated_with  \
# 0    [exocrine pancreatic insufficiency, elevated s...
# 27   [elevated urine calcium levels, asthma, rectal...
# 1    [failure to thrive, elevated urine calcium lev...
# 3    [elevated urine calcium levels, asthma, rectal...
# 9    [exocrine pancreatic insufficiency, elevated u...
# ..                                                 ...
# 404                                           [asthma]
# 405                                           [asthma]
# 406                                           [asthma]
# 407                                           [asthma]
# 360                                           [asthma]
#
#      symptoms_associated_count  gene_connections_count  final_symptom_score  \
# 0                           41                    1741            19.688964
# 27                          14                      97             7.562347
# 1                           29                    8889            10.123814
# 3                           16                    1170             9.184561
# 9                           14                     907             7.562347
# ..                         ...                     ...                  ...
# 404                          1                    2781             0.058230
# 405                          1                     356             0.058230
# 406                          1                     817             0.058230
# 407                          1                     666             0.058230
# 360                          1                    1011             0.058230
#
#      relevance_score
# 0           1.000000
# 27          0.174205
# 1           0.168681
# 3           0.161407
# 9           0.105970
# ..               ...
# 404         0.000000
# 405         0.000000
# 406         0.000000
# 407         0.000000
# 360         0.000000
#
# [593 rows x 8 columns]

# %% [markdown]
# ## Save Results

# %%
disease_df.to_csv(output_csv, index = False)
