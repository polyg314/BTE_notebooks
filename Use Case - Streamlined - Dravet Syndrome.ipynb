# %% [markdown]
# ## Imports

# %%
## main functions
import gene_symptoms_question_functions as gsf
## importlib makes sure functions from packages get refreshed
import importlib
import requests
importlib.reload(gsf)
import pandas as pd
import math
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %% [markdown]
# ## Set disease and output names

# %%
disease_name = 'Dravet Syndrome'
output_csv = "Dravet_Syndrome_2020-08-27.csv"
symptom_csv = "Dravet_Syndrome_Symptoms_2020-08-27.csv"

# %% [markdown]
# ## Get disease

# %%
disease_name = disease_name.lower()
disease = ht.query(disease_name)['Disease'][0]
disease
# Out:
# {'MONDO': 'MONDO:0100135',
#  'DOID': 'DOID:0060171',
#  'UMLS': 'C0751122',
#  'name': 'Dravet syndrome',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0100135'},
#  'display': 'MONDO(MONDO:0100135) DOID(DOID:0060171) UMLS(C0751122) name(Dravet syndrome)',
#  'type': 'Disease'}

# %% [markdown]
# ## Get disease symptoms

# %%
# get disease symptoms
disease_symptoms_list = gsf.get_disease_symptoms(disease_name)
disease_symptoms = disease_symptoms_list[0]
disease_symptom_hpids = disease_symptoms_list[1]
disease_symptom_dict = disease_symptoms_list[2]
disease_symptoms
disease_symptom_hpids
# Out:
# request url: http://mydisease.info/v1/query?q=hpo.disease_name:"dravet syndrome"&fields=hpo
# disease symptoms for:
# Dravet syndrome
# ['developmental regression', 'Loss of developmental milestones', 'Mental deterioration in childhood', 'Neurodevelopmental regression', 'Psychomotor regression', 'Psychomotor regression beginning in infancy', 'Psychomotor regression in infants', 'Psychomotor regression, progressive', 'progressive gait ataxia', 'Gait ataxia, progressive', 'focal-onset seizure', 'Focal onset seizure', 'Focal seizure', 'Focal seizures', 'Focal-onset seizures', 'Partial seizure', 'Partial seizures', 'Seizure affecting one half of brain', 'limited neck range of motion', 'Limited cervical range of motion', 'Limited neck range of motion', 'autistic behavior', 'ASD', 'Autistic behaviour', 'Pervasive developmental disorder', 'anxiety', 'Anxiety', 'Anxiousness', 'Excessive, persistent worry and fear', 'parkinsonism', 'photosensitive myoclonic seizure', 'Photically induced myoclonic seizure', 'Photomyoclonic seizure', 'Photomyoclonic seizures', 'myoclonus', 'Myoclonic jerks', 'rigidity', 'Muscle rigidity', 'Rigidity', 'bradykinesia', 'Slow movements', 'Slowness of movements', 'generalized myoclonic seizure', 'Generalised epileptic myoclonus', 'Generalised myoclonic seizure', 'Generalised myoclonic seizures', 'Generalized epileptic myoclonus', 'Generalized myoclonic seizures', 'Myoclonus seizures', 'focal aware seizure', 'Focal aware seizures', 'Focal seizure with retained awareness', 'Focal seizure without impairment of awareness', 'Focal seizure without impairment of consciousness or awareness', 'Focal seizures without impairment of consciousness or awareness', 'Partial seizure with retained awareness', 'Partial seizure without impairment of awareness', 'Simple partial seizure', 'Simple partial seizures', 'febrile seizure (within the age range of 3 months to 6 years)', 'Febrile convulsion', 'Febrile seizures', 'Fever induced seizures', 'Seizures, febrile, in early childhood', 'Seizures, generalized, associated with fever', 'focal impaired awareness seizure', 'Complex focal seizures', 'Complex partial seizure', 'Complex partial seizures', 'Dyscognitive seizures', 'Focal dyscognitive seizure', 'Focal impaired awareness seizures', 'Focal seizure with impairment of awareness', 'Focal seizure with loss of awareness', 'Focal seizures with impairment of consciousness or awareness', 'Localised dyscognitive seizure', 'Localised seizure with impaired awareness', 'Localised seizure with loss of awareness', 'Localized dyscognitive seizure', 'Localized seizure with impaired awareness', 'Localized seizure with loss of awareness', 'Partial dyscognitive seizure', 'Partial seizure with impairment of awareness', 'Partial seizure with loss of awareness', 'cogwheel rigidity', 'focal hemiclonic seizure', 'Hemiclonic seizure', 'Hemiclonic seizures', 'Unilateral clonic seizure', 'Unilateral clonic seizures', 'photosensitive tonic-clonic seizure', 'Photically induced tonic-clonic seizure', 'Photosensitive tonic-clonic seizures', 'Seizures, tonic-clonic, photosensitive', 'atypical absence seizure', 'Atypical absence', 'Atypical absence seizures', 'Atypical petit mal seizures', 'obsessive-compulsive trait', 'Obsessive-compulsive trait', 'Obsessive-compulsive traits', 'multifocal epileptiform discharges', 'Multifocal EEG abnormality', 'generalized clonic seizure', 'Generalised clonic seizure', 'Generalised clonic seizures', 'Generalised onset clonic seizure', 'Generalised-onset clonic seizure', 'Generalized clonic seizures', 'Generalized onset clonic seizure', 'Generalized-onset clonic seizure', 'complex febrile seizure', 'Complex febrile convulsion', 'Complex febrile seizures', 'Complex fever fit', 'interictal epileptiform activity', 'Epileptiform EEG discharges', 'facial tics', 'Cramping of facial muscles', 'Facial spasms', 'Facial tics', 'Jerking of facial muscles', 'Mimic spasms', 'Spasms of facial muscles', 'Twitching of facial muscles', 'epilepsia partialis continua', 'Epilepsia partialis continua of Kojevnikov', "Kojevnikov's epilepsia", "Kozhevnikov's epilepsia", 'cognitiv ...
# ['HP:0002376',
#  'HP:0007240',
#  'HP:0007359',
#  'HP:0000466',
#  'HP:0000729',
#  'HP:0000739',
#  'HP:0001300',
#  'HP:0001327',
#  'HP:0001336',
#  'HP:0002063',
#  'HP:0002067',
#  'HP:0002123',
#  'HP:0002349',
#  'HP:0002373',
#  'HP:0002384',
#  'HP:0002396',
#  'HP:0006813',
#  'HP:0007207',
#  'HP:0007270',
#  'HP:0008770',
#  'HP:0010841',
#  'HP:0011169',
#  'HP:0011172',
#  'HP:0011182',
#  'HP:0011468',
#  'HP:0012847',
#  'HP:0100543',
#  'HP:0000736',
#  'HP:0000980',
#  'HP:0001763',
#  'HP:0002283',
#  'HP:0002307',
#  'HP:0002311',
#  'HP:0002345',
#  'HP:0003066',
#  'HP:0007010',
#  'HP:0008081',
#  'HP:0008947',
#  'HP:0011185',
#  'HP:0011198',
#  'HP:0025101',
#  'HP:0031475',
#  'HP:0100694',
#  'HP:0100710',
#  'HP:0200048',
#  'HP:0010818']

# %% [markdown]
# ## Get Symptom Prevalence - based off edges out counts

# %%
disease_symptom_dict = gsf.get_symtpom_prevalence(disease_symptom_dict, disease_name) 
disease_symptoms_df = pd.DataFrame.from_dict(disease_symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptoms_df = pd.concat([disease_symptoms_df[disease_symptoms_df["frequency"] == "Very frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Occasional"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Rare"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Unknown"]
              ])
# Out:
# HP:0002376
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (236, 9)
# OKKKk
# 236
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# (311, 9)
# ok edge phen to dis
# 547
# edges out
# 547
# HP:0007240
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (31, 9)
# OKKKk
# 31
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (38, 9)
# ok edge phen to dis
# 69
# edges out
# 69
# HP:0007359
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (108, 9)
# OKKKk
# 108
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (71, 9)
# ok edge phen to dis
# 179
# edges out
# 179
# HP:0000466
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (13, 9)
# OKKKk
# 13
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (6, 9)
# ok edge phen to dis
# 19
# edges out
# 19
# HP:0000729
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (212, 9)
# OKKKk
# 212
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (268, 9)
# ok edge phen to dis
# 480
# edges out
# 522
# HP:0000739
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# gene
# (213, 9)
# OKKKk
# 213
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (272, 9)
# ok edge phen to dis
# 485
# edges out
# 485
# HP:0001300
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# gene
# (89, 9)
# OKKKk
# 89
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (178, 9)
# ok edge phen to dis
# 267
# edges out
# 267
# HP:0001327
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (8, 9)
# OKKKk
# 8
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (5, 9)
# ok edge phen to dis
# 13
# edges out
# 13
# HP:0001336
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# gene
# (199, 9)
# OKKKk
# 199
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# (323, 9)
# ok edge phen to dis
# 522
# edges out
# 522
# HP:0002063
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (160, 9)
# OKKKk
# 160
# API 1.7 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# (218, 9)
# ok edge phen to dis
# 378
# edges out
# 657
# HP:0002067
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (113, 9)
# OKKKk
# 113
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (185, 9)
# ok edge phen to dis
# 298
# edges out
# 390
# HP:0002123
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# gene
# (117, 9)
# OKKKk
# 117
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (162, 9)
# ok edge phen to dis
# 279
# edges out
# 279
# HP:0002349
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (11, 9)
# OKKKk
# 11
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# (9, 9)
# ok edge phen to dis
# 20
# edges out
# 20
# HP:0002373
# API 1.4 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (75, 9)
# OKKKk
# 75
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (117, 9)
# ok edge phen to dis
# 192
# edges out
# 192
# HP:0002384
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (36, 9)
# OKKKk
# 36
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (56, 9)
# ok edge phen to dis
# 92
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Task was destroyed but it is pending!
# task: <Task pending name='Task-9579' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:829> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/futures.py:360, <TaskWakeupMethWrapper object at 0x7ff275fcef10>()]> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-9580' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:829> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/futures.py:360, <TaskWakeupMethWrapper object at 0x7ff2731824f0>()]> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-9581' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:829> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/futures.py:360, <TaskWakeupMethWrapper object at 0x7ff273182640>()]> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# Task was destroyed but it is pending!
# task: <Task pending name='Task-9582' coro=<TCPConnector._resolve_host() running at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/aiohttp/connector.py:829> wait_for=<Future pending cb=[_chain_future.<locals>._call_check_cancel() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/futures.py:360, <TaskWakeupMethWrapper object at 0x7ff275da4700>()]> cb=[shield.<locals>._inner_done_callback() at /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/tasks.py:867]>
# edges out
# 92
# HP:0002396
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# gene
# (24, 9)
# OKKKk
# 24
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# (19, 9)
# ok edge phen to dis
# 43
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# edges out
# 57
# HP:0006813
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# gene
# (9, 9)
# OKKKk
# 9
# API 1.14 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (10, 9)
# ok edge phen to dis
# 19
# edges out
# 19
# HP:0007207
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (16, 9)
# OKKKk
# 16
# API 1.1 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# (8, 9)
# ok edge phen to dis
# 24
# edges out
# 24
# HP:0007270
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (15, 9)
# OKKKk
# 15
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (15, 9)
# ok edge phen to dis
# 30
# edges out
# 30
# HP:0008770
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (19, 9)
# OKKKk
# 19
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (17, 9)
# ok edge phen to dis
# 36
# edges out
# 36
# HP:0010841
# API 1.9 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (51, 9)
# OKKKk
# 51
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (21, 9)
# ok edge phen to dis
# 72
# edges out
# 72
# HP:0011169
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (22, 9)
# OKKKk
# 22
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (7, 9)
# ok edge phen to dis
# 29
# edges out
# 29
# HP:0011172
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (8, 9)
# OKKKk
# 8
# API 1.2 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (2, 9)
# ok edge phen to dis
# 10
# edges out
# 10
# HP:0011182
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (9, 9)
# OKKKk
# 9
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# (3, 9)
# ok edge phen to dis
# 12
# edges out
# 12
# HP:0011468
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (7, 9)
# OKKKk
# 7
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# (2, 9)
# ok edge phen to dis
# 9
# edges out
# 9
# HP:0012847
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# gene
# (9, 9)
# OKKKk
# 9
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (5, 9)
# ok edge phen to dis
# 14
# edges out
# 14
# HP:0100543
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (189, 9)
# OKKKk
# 189
# API 1.15 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (326, 9)
# ok edge phen to dis
# 515
# edges out
# 515
# HP:0000736
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (97, 9)
# OKKKk
# 97
# API 1.5 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (61, 9)
# ok edge phen to dis
# 158
# edges out
# 158
# HP:0000980
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (64, 9)
# OKKKk
# 64
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (156, 9)
# ok edge phen to dis
# 220
# edges out
# 220
# HP:0001763
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (239, 9)
# OKKKk
# 239
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (348, 9)
# ok edge phen to dis
# 587
# edges out
# 587
# HP:0002283
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (50, 9)
# OKKKk
# 50
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# (53, 9)
# ok edge phen to dis
# 103
# edges out
# 103
# HP:0002307
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# gene
# (108, 9)
# OKKKk
# 108
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# (124, 9)
# ok edge phen to dis
# 232
# edges out
# 312
# HP:0002311
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (47, 9)
# OKKKk
# 47
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (73, 9)
# ok edge phen to dis
# 120
# edges out
# 120
# HP:0002345
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (110, 9)
# OKKKk
# 110
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# (171, 9)
# ok edge phen to dis
# 281
# edges out
# 366
# HP:0003066
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (16, 9)
# OKKKk
# 16
# API 1.1 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (9, 9)
# ok edge phen to dis
# 25
# edges out
# 25
# HP:0007010
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# gene
# (37, 9)
# OKKKk
# 37
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# (33, 9)
# ok edge phen to dis
# 70
# edges out
# 70
# HP:0008081
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# gene
# (32, 9)
# OKKKk
# 32
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# (31, 9)
# ok edge phen to dis
# 63
# edges out
# 63
# HP:0008947
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# gene
# (142, 9)
# OKKKk
# 142
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# (130, 9)
# ok edge phen to dis
# 272
# edges out
# 272
# HP:0011185
# API 1.3 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (40, 9)
# OKKKk
# 40
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (3, 9)
# ok edge phen to dis
# 43
# edges out
# 43
# HP:0011198
# API 1.1 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# gene
# (44, 9)
# OKKKk
# 44
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# (6, 9)
# ok edge phen to dis
# 50
# edges out
# 50
# HP:0025101
# gene
# (12, 9)
# OKKKk
# 12
# (2, 9)
# ok edge phen to dis
# 14
# edges out
# 14
# HP:0031475
# gene
# (8, 9)
# OKKKk
# 8
# (0, 0)
# edges out
# 8
# HP:0100694
# API 1.7 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (13, 9)
# OKKKk
# 13
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# (8, 9)
# ok edge phen to dis
# 21
# edges out
# 21
# HP:0100710
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (120, 9)
# OKKKk
# 120
# API 1.6 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# (60, 9)
# ok edge phen to dis
# 180
# edges out
# 180
# HP:0200048
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# gene
# (8, 9)
# OKKKk
# 8
# API 1.2 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# (1, 9)
# ok edge phen to dis
# 9
# edges out
# 9
# HP:0010818
# API 1.4 semmed_phenotype failed
# API 1.1 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# gene
# (33, 9)
# OKKKk
# 33
# API 1.1 semmed_phenotype failed
# API 1.3 semmed_phenotype failed
# API 1.2 semmed_phenotype failed
# API 1.9 semmed_phenotype failed
# API 1.4 semmed_phenotype failed
# API 1.8 semmed_phenotype failed
# API 1.5 semmed_phenotype failed
# API 1.7 semmed_phenotype failed
# API 1.12 semmed_phenotype failed
# API 1.6 semmed_phenotype failed
# API 1.11 semmed_phenotype failed
# API 1.16 semmed_phenotype failed
# API 1.17 semmed_phenotype failed
# API 1.10 semmed_phenotype failed
# API 1.18 semmed_phenotype failed
# API 1.14 semmed_phenotype failed
# API 1.13 semmed_phenotype failed
# API 1.19 semmed_phenotype failed
# API 1.15 semmed_phenotype failed
# (31, 9)
# ok edge phen to dis
# 64
# edges out
# 64

# %% [markdown]
# ## Calculate Individual Symptom Scores

# %%
individual_symptom_scores = [];
for index,x in disease_symptoms_df.iterrows():
    if(x["frequency"] == "Very frequent"):
        score = 20 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Frequent"):
        score = 15 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Occasional"):
        score = 10 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Rare"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Unknown"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    individual_symptom_scores.append(score)

# print(len(individual_symptom_scores))
disease_symptoms_df["ISS"] = individual_symptom_scores

# %% [markdown]
# ## Symptoms Table

# %%
disease_symptoms_df
# Out:
#                                                         names      frequency  \
# HP:0007240  [progressive gait ataxia, Gait ataxia, progres...  Very frequent
# HP:0007359  [focal-onset seizure, Focal onset seizure, Foc...  Very frequent
# HP:0002376  [developmental regression, Loss of development...  Very frequent
# HP:0011468  [facial tics, Cramping of facial muscles, Faci...       Frequent
# HP:0011172  [complex febrile seizure, Complex febrile conv...       Frequent
# HP:0011182  [interictal epileptiform activity, Epileptifor...       Frequent
# HP:0001327  [photosensitive myoclonic seizure, Photically ...       Frequent
# HP:0012847  [epilepsia partialis continua, Epilepsia parti...       Frequent
# HP:0000466  [limited neck range of motion, Limited cervica...       Frequent
# HP:0006813  [focal hemiclonic seizure, Hemiclonic seizure,...       Frequent
# HP:0002349  [focal aware seizure, Focal aware seizures, Fo...       Frequent
# HP:0007207  [photosensitive tonic-clonic seizure, Photical...       Frequent
# HP:0011169  [generalized clonic seizure, Generalised cloni...       Frequent
# HP:0007270  [atypical absence seizure, Atypical absence, A...       Frequent
# HP:0008770  [obsessive-compulsive trait, Obsessive-compuls...       Frequent
# HP:0002396                                [cogwheel rigidity]       Frequent
# HP:0010841  [multifocal epileptiform discharges, Multifoca...       Frequent
# HP:0002384  [focal impaired awareness seizure, Complex foc...       Frequent
# HP:0002373  [febrile seizure (within the age range of 3 mo...       Frequent
# HP:0001300                                     [parkinsonism]       Frequent
# HP:0002123  [generalized myoclonic seizure, Generalised ep...       Frequent
# HP:0002067  [bradykinesia, Slow movements, Slowness of mov...       Frequent
# HP:0000739  [anxiety, Anxiety, Anxiousness, Excessive, per...       Frequent
# HP:0100543  [cognitive impairment, Abnormality of cognitio...       Frequent
# HP:0000729  [autistic behavior, ASD, Autistic behaviour, P...       Frequent
# HP:0001336                       [myoclonus, Myoclonic jerks]       Frequent
# HP:0002063              [rigidity, Muscle rigidity, Rigidity]       Frequent
# HP:0031475  [status epilepticus without prominent motor sy...     Occasional
# HP:0200048                                 [cyanotic episode]     Occasional
# HP:0025101  [dysgenesis of the hippocampus, Hippocampal dy...     Occasional
# HP:0100694                                   [tibial torsion]     Occasional
# HP:0003066   [limited knee extension, Limited knee extension]     Occasional
# HP:0011185  [eeg with focal epileptiform discharges, Focal...     Occasional
# HP:0011198  [eeg with generalized epileptiform discharges,...     Occasional
# HP:0008081                [pes valgus, Valgus foot deformity]     Occasional
# HP:0007010  [poor fine motor coordination, Fine motor disa...     Occasional
# HP:0002283  [global brain atrophy, Diffuse brain atrophy, ...     Occasional
# HP:0002311  [incoordination, Difficulties in coordination,...     Occasional
# HP:0000736  [short attention span, Poor attention span, Pr...     Occasional
# HP:0100710              [impulsivity, Impulsive, Impulsivity]     Occasional
# HP:0000980                                           [pallor]     Occasional
# HP:0008947  [infantile muscular hypotonia, Decreased muscl...     Occasional
# HP:0002307        [drooling, Dribbling, Drooling, Sialorrhea]     Occasional
# HP:0002345                                    [action tremor]     Occasional
# HP:0001763                 [pes planus, Flat feet, Flat foot]     Occasional
#
#             edges_out_count       ISS
# HP:0007240               69  2.407717
# HP:0007359              179  1.494870
# HP:0002376              547  0.855138
# HP:0011468                9  5.000000
# HP:0011172               10  4.743416
# HP:0011182               12  4.330127
# HP:0001327               13  4.160251
# HP:0012847               14  4.008919
# HP:0000466               19  3.441236
# HP:0006813               19  3.441236
# HP:0002349               20  3.354102
# HP:0007207               24  3.061862
# HP:0011169               29  2.785430
# HP:0007270               30  2.738613
# HP:0008770               36  2.500000
# HP:0002396               57  1.986799
# HP:0010841               72  1.767767
# HP:0002384               92  1.563858
# HP:0002373              192  1.082532
# HP:0001300              267  0.917985
# HP:0002123              279  0.898027
# HP:0002067              390  0.759555
# HP:0000739              485  0.681115
# HP:0100543              515  0.660979
# HP:0000729              522  0.656532
# HP:0001336              522  0.656532
# HP:0002063              657  0.585206
# HP:0031475                8  3.535534
# HP:0200048                9  3.333333
# HP:0025101               14  2.672612
# HP:0100694               21  2.182179
# HP:0003066               25  2.000000
# HP:0011185               43  1.524986
# HP:0011198               50  1.414214
# HP:0008081               63  1.259882
# HP:0007010               70  1.195229
# HP:0002283              103  0.985329
# HP:0002311              120  0.912871
# HP:0000736              158  0.795557
# HP:0100710              180  0.745356
# HP:0000980              220  0.674200
# HP:0008947              272  0.606339
# HP:0002307              312  0.566139
# HP:0002345              366  0.522708
# HP:0001763              587  0.412744

# %%
disease_symptoms_df.to_csv(symptom_csv, index = True)

# %% [markdown]
# ## Get Disease -> Gene (no intermediates)

# %%
disease_disease_to_genes_dict = gsf.get_disease_to_gene_results(disease)
disease_disease_to_genes_dict
# Out:
# running disease -> gene
# {'sorted_disease_to_genes': {'SCN1A': 1},
#  'one_step_genes_pub_counts': {'SCN1A': 1},
#  'disease_to_genes_list': ['SCN1A']}

# %% [markdown]
# ## Get Disease -> intermediate_node (any except those matching symptoms) -> Gene

# %%
# get results using intermediates 
node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %%
disease_disease_all_nodes_genes = gsf.predict_many(disease, node_type_list, 'Gene')

# Save an object to a file
# %store disease_disease_all_nodes_genes
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# API 6.1 pharos failed
# Intermediate Node type running:
# Disease
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature
# Stored 'disease_disease_all_nodes_genes' (DataFrame)

# %%
# Restore the object
# %store -r disease_disease_all_nodes_genes
disease_disease_all_nodes_genes
# Out:
#                 input input_type       pred1 pred1_source           pred1_api  \
# 0     DRAVET SYNDROME    Disease  treated_by       SEMMED  SEMMED Disease API
# 1     DRAVET SYNDROME    Disease  treated_by       SEMMED  SEMMED Disease API
# 2     DRAVET SYNDROME    Disease  treated_by       SEMMED  SEMMED Disease API
# 3     DRAVET SYNDROME    Disease  treated_by       SEMMED  SEMMED Disease API
# 4     DRAVET SYNDROME    Disease  treated_by       SEMMED  SEMMED Disease API
# ...               ...        ...         ...          ...                 ...
# 3748  DRAVET SYNDROME    Disease   caused_by       SEMMED  SEMMED Disease API
# 3749  DRAVET SYNDROME    Disease   caused_by       SEMMED  SEMMED Disease API
# 3750  DRAVET SYNDROME    Disease   caused_by       SEMMED  SEMMED Disease API
# 3751  DRAVET SYNDROME    Disease   caused_by       SEMMED  SEMMED Disease API
# 3752  DRAVET SYNDROME    Disease   caused_by       SEMMED  SEMMED Disease API
#
#      pred1_pubmed         node1_type node1_name       node1_id  \
# 0         8398238               Gene   C1705225  UMLS:C1705225
# 1         8398238               Gene   C1705225  UMLS:C1705225
# 2         8398238               Gene   C1705225  UMLS:C1705225
# 3         8398238               Gene   C1705225  UMLS:C1705225
# 4        11940708               Gene   C0017337  UMLS:C0017337
# ...           ...                ...        ...            ...
# 3748     19563458  BiologicalProcess   C0026882  UMLS:C0026882
# 3749     19563458  BiologicalProcess   C0026882  UMLS:C0026882
# 3750     19563458  BiologicalProcess   C0026882  UMLS:C0026882
# 3751     19563458  BiologicalProcess   C0026882  UMLS:C0026882
# 3752     19563458  BiologicalProcess   C0026882  UMLS:C0026882
#
#                           pred2 pred2_source                      pred2_api  \
# 0          negatively_regulates       SEMMED                SEMMED Gene API
# 1       positively_regulated_by       SEMMED                SEMMED Gene API
# 2     physically_interacts_with       SEMMED                SEMMED Gene API
# 3          positively_regulates       SEMMED                SEMMED Gene API
# 4       positively_regulated_by       SEMMED                SEMMED Gene API
# ...                         ...          ...                            ...
# 3748               disrupted_by       SEMMED  SEMMED Biological Process API
# 3749               disrupted_by       SEMMED  SEMMED Biological Process API
# 3750               disrupted_by       SEMMED  SEMMED Biological Process API
# 3751               disrupted_by       SEMMED  SEMMED Biological Process API
# 3752               disrupted_by       SEMMED  SEMMED Biological Process API
#
#            pred2_pubmed output_type output_name       output_id
# 0      16603724,2171516        Gene    C3539645   UMLS:C3539645
# 1               2171516        Gene    C3539645   UMLS:C3539645
# 2              12456804        Gene    C3539645   UMLS:C3539645
# 3               1705908        Gene    C3539645   UMLS:C3539645
# 4     11278817,21252239        Gene    C3539645   UMLS:C3539645
# ...                 ...         ...         ...             ...
# 3748           11298742        Gene     ARHGDIA    NCBIGene:396
# 3749           20881257        Gene      PDE11A  NCBIGene:50940
# 3750  11337501,18250084        Gene     EIF2AK2   NCBIGene:5610
# 3751            7669031        Gene        RLN1   NCBIGene:6013
# 3752           28540352        Gene       GALR3   NCBIGene:8484
#
# [51512 rows x 16 columns]

# %%
## Remove UMLS "Genes"  (not gene specific) 
disease_disease_all_nodes_genes = disease_disease_all_nodes_genes[~disease_disease_all_nodes_genes['output_id'].str.contains('UMLS')]

# %%
max_2_step_genes = 100
disease_disease_to_node_to_genes_dict = gsf.get_disease_to_node_to_gene_results(disease_disease_all_nodes_genes, max_2_step_genes, disease_symptoms, disease_symptom_hpids)
# %store disease_disease_to_node_to_genes_dict
# Out:
# finding intermediate nodes that are symptoms
# removing symptom intermediates
# getting gene counts from 28814 gene entries
# sorting counts dictionary
# top genes occurrence counts:
# CA2: 58
# TNF: 54
# ABCB1: 51
# CAT: 50
# POMC: 46
# CAMP: 46
# CYP3A4: 42
# FOS: 41
# GRK2: 41
# INS: 40
# TYMS: 38
# IFNA1: 35
# MAPK1: 35
# EGFR: 35
# AKT1: 35
# LEP: 35
# IL2: 34
# KCNH2: 34
# TP53: 33
# VEGFA: 33
# FAS: 33
# GPI: 33
# TGFB1: 33
# TRH: 33
# TH: 33
# SST: 33
# CYP2C19: 32
# KIT: 31
# ESR1: 31
# GABPA: 31
# CISH: 31
# WDTC1: 30
# BAX: 30
# MMP9: 30
# AR: 30
# MTOR: 30
# ERVK-11: 30
# ERVK-19: 30
# ERVK-9: 30
# APP: 30
# REN: 30
# CSH1: 29
# ALB: 29
# RET: 29
# PTEN: 29
# FLVCR1: 29
# ERVK-10: 29
# BCR: 29
# STAT3: 29
# CDKN1A: 29
# PTH: 29
# BMP1: 28
# DPYD: 28
# CA1: 28
# LOX: 28
# MGMT: 28
# CD4: 28
# SLC2A1: 28
# TCEAL1: 28
# H3P16: 28
# ATM: 27
# PPIG: 27
# CYP1A2: 27
# ADA: 27
# FASTK: 27
# FASN: 27
# SOD1: 27
# ADRA1D: 27
# RHO: 27
# PGPEP1: 27
# FGFR3: 27
# PRCP: 26
# HSPA9: 26
# ERCC8: 26
# CYP2D6: 26
# HPRT1: 26
# CDKN2A: 26
# CDK1: 26
# MPO: 26
# BRAF: 26
# PIK3CA: 26
# IL6: 26
# CCK: 26
# ODC1: 25
# DNAH8: 25
# MMP2: 25
# CXCR4: 25
# SNRPE: 25
# HSPA4: 25
# CRK: 25
# DLL1: 25
# MAPK8: 24
# CD44: 24
# CD40: 24
# PSMD9: 24
# PIK3CB: 24
# IFI27: 24
# ACE: 24
# ZNRD2: 24
# ZHX2: 24
# getting publicaiton counts
# Stored 'disease_disease_to_node_to_genes_dict' (dict)

# %% [markdown]
# ## Combine genes from one and two step processes then get rid of any duplicates

# %%
# %store -r disease_disease_to_node_to_genes_dict
disease_top_genes_list = disease_disease_to_genes_dict["disease_to_genes_list"] + disease_disease_to_node_to_genes_dict["top_related_genes_to_disease"]
disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
# top_genes_list

# %% [markdown]
# ## Get Genes -> Symtoms, filtered by those related to Disease

# %%
disease_relevant_genes_to_symptoms_df = gsf.determined_genes_to_symptoms(disease_top_genes_list, disease_symptoms)
# relevant_genes_to_symptoms_df
# Out:
# Genes -> PhenotypicFeatures
# APP FAILED
# Genes -> Bioprocesses
# APP FAILED
# Genes -> Diseases
# 1 mydisease.info failed
# 1 mydisease.info failed
# 1 mydisease.info failed
# 1 mydisease.info failed
# 1 mydisease.info failed
# ID resolution steps failed:
# POMC FAILED
# 1 mydisease.info failed
# 1 mydisease.info failed
# ID resolution steps failed:
# IL2 FAILED
# 1 mydisease.info failed
# 1 mydisease.info failed
# ID resolution steps failed:
# TP53 FAILED
# APP FAILED
# Cannot connect to host pending.biothings.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# 49

# %%
# %store disease_relevant_genes_to_symptoms_df
# Out:
# Stored 'disease_relevant_genes_to_symptoms_df' (DataFrame)

# %%
# %store -r disease_relevant_genes_to_symptoms_df
disease_relevant_genes_list = list(dict.fromkeys(list(disease_relevant_genes_to_symptoms_df["input"])))
# relevant_genes_list

# %%
disease_gene_to_symptom_pub_counts = gsf.get_gene_to_symptom_publication_counts(disease_relevant_genes_to_symptoms_df)
# gene_to_symptom_pub_counts

# %%
disease_causes_dict = gsf.create_causes_dict(disease_relevant_genes_to_symptoms_df)
# causes_dict

# %% [markdown]
# ## Get edges out from each gene
# For use in normalizing in relevance score

# %%
disease_connection_dict =  gsf.get_connection_normalizing_count(disease_relevant_genes_list,node_type_list)
# connection_dict
# Out:
# Cannot connect to host biothings.ncats.io:443 ssl:default [Operation timed out]
# [Errno 60] Operation timed out
# [Errno 60] Operation timed out
# [Errno 60] Operation timed out
# [Errno 60] Operation timed out
# [Errno 60] Operation timed out
# [Errno 60] Operation timed out
# [Errno 60] Operation timed out
#
# MAPK8 could not be found

# %%
# %store disease_connection_dict
# Out:
# Stored 'disease_connection_dict' (dict)

# %%
# %store -r disease_connection_dict

# %% [markdown]
# ## Assemble final results

# %%
disease_df = gsf.assemble_final_data_frame(disease_relevant_genes_to_symptoms_df, 
                                      disease_connection_dict,
                                      disease_disease_to_genes_dict['sorted_disease_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['sorted_disease_to_all_nodes_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['top_two_step_genes_pub_counts'], 
                                      disease_gene_to_symptom_pub_counts, 
                                      disease_causes_dict,
                                      disease_symptoms_df)
disease_df
# Out:
#       gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 0    SCN1A                     1                         11
# 22    GRK2                     0                         41
# 14  CYP2D6                     0                         26
# 9     BMP1                     0                         28
# 13   FGFR3                     0                         27
# 10  SLC2A1                     0                         28
# 5     MTOR                     0                         30
# 6      RET                     0                         29
# 31  PGPEP1                     0                         27
# 11     ATM                     0                         27
# 25     GPI                     0                         33
# 17   CXCR4                     0                         25
# 32    PRCP                     0                         26
# 1      INS                     0                         40
# 26     TRH                     0                         33
# 4       TH                     0                         33
# 12    SOD1                     0                         27
# 8    STAT3                     0                         29
# 30     RHO                     0                         27
# 15    BRAF                     0                         26
# 7     PTEN                     0                         29
# 2     AKT1                     0                         35
# 3     TP53                     0                         33
# 16  PIK3CA                     0                         26
# 33   HSPA4                     0                         25
# 34    CD40                     0                         24
# 28     PTH                     0                         29
# 29     CA1                     0                         28
# 18     CA2                     0                         58
# 27     SST                     0                         33
# 24     FAS                     0                         33
# 23   VEGFA                     0                         33
# 21     FOS                     0                         41
# 20     CAT                     0                         50
# 19     TNF                     0                         54
# 35  PIK3CB                     0                         24
#
#              disease_symptoms_gene_is_associated_with  \
# 0   [generalised epileptic myoclonus, generalised ...
# 22  [myoclonus, myoclonus, myoclonus, bradykinesia...
# 14  [developmental regression, myoclonus, action t...
# 9            [abnormality of cognition, bradykinesia]
# 13  [decreased muscle tone in infant, decreased mu...
# 10  [abnormality of cognition, typical absence, an...
# 5   [complex focal seizures, abnormality of cognit...
# 6   [anxiety, abnormality of cognition, non-convul...
# 31                                     [bradykinesia]
# 11  [abnormality of cognition, action tremor, non-...
# 25  [non-convulsive status epilepticus, bradykinesia]
# 17                            [fine motor disability]
# 32                                     [bradykinesia]
# 1                   [generalised epileptic myoclonus]
# 26  [non-convulsive status epilepticus, non-convul...
# 4                                      [bradykinesia]
# 12                                          [anxiety]
# 8                   [generalised epileptic myoclonus]
# 30                                          [anxiety]
# 15                         [abnormality of cognition]
# 7                          [abnormality of cognition]
# 2                          [abnormality of cognition]
# 3                          [abnormality of cognition]
# 16  [abnormality of cognition, non-convulsive stat...
# 33                [non-convulsive status epilepticus]
# 34  [non-convulsive status epilepticus, non-convul...
# 28                [non-convulsive status epilepticus]
# 29  [non-convulsive status epilepticus, non-convul...
# 18                [non-convulsive status epilepticus]
# 27                [non-convulsive status epilepticus]
# 24                [non-convulsive status epilepticus]
# 23  [non-convulsive status epilepticus, non-convul...
# 21  [non-convulsive status epilepticus, non-convul...
# 20  [non-convulsive status epilepticus, non-convul...
# 19  [non-convulsive status epilepticus, non-convul...
# 35                [non-convulsive status epilepticus]
#
#     symptoms_associated_count  gene_connections_count  final_symptom_score  \
# 0                          35                     613            74.357976
# 22                          7                    4431             3.774568
# 14                          4                    2242             4.021177
# 9                           2                    1677             1.420533
# 13                          3                    3024             1.873657
# 10                          3                    1776             1.342094
# 5                           2                    6872             2.224837
# 6                           4                    2402             1.342094
# 31                          1                    1363             0.759555
# 11                          3                    3536             1.183687
# 25                          2                    2966             0.759555
# 17                          1                    3605             1.195229
# 32                          1                    1735             0.759555
# 1                           1                    9554             0.898027
# 26                          4                    2134             0.522708
# 4                           1                    5626             0.759555
# 12                          1                    2732             0.681115
# 8                           1                    6528             0.898027
# 30                          1                    4133             0.681115
# 15                          1                    3756             0.660979
# 7                           1                    5675             0.660979
# 2                           1                   16329             0.660979
# 3                           1                   13974             0.660979
# 16                          2                    7493             0.660979
# 33                          1                    2804             0.000000
# 34                          2                    3618             0.000000
# 28                          1                    4624             0.000000
# 29                          3                    4336             0.000000
# 18                          1                   16711             0.000000
# 27                          1                    3486             0.000000
# 24                          1                    5678             0.000000
# 23                          4                   11159             0.000000
# 21                          3                    6908             0.000000
# 20                          3                    8451             0.000000
# 19                          2                   19388             0.000000
# 35                          1                    4006             0.000000
#
#     relevance_score
# 0          1.000000
# 22         0.012052
# 14         0.009025
# 9          0.004178
# 13         0.003862
# 10         0.003835
# 5          0.003613
# 6          0.003492
# 31         0.002332
# 11         0.002256
# 25         0.002174
# 17         0.001974
# 32         0.001938
# 1          0.001888
# 26         0.001764
# 4          0.001578
# 12         0.001477
# 8          0.001417
# 30         0.001201
# 15         0.001146
# 7          0.001119
# 2          0.000879
# 3          0.000871
# 16         0.000811
# 33         0.000000
# 34         0.000000
# 28         0.000000
# 29         0.000000
# 18         0.000000
# 27         0.000000
# 24         0.000000
# 23         0.000000
# 21         0.000000
# 20         0.000000
# 19         0.000000
# 35         0.000000

# %% [markdown]
# ## Save Results

# %%
disease_df.to_csv(output_csv, index = False)
