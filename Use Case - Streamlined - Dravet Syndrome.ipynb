# %% [markdown]
# ## Imports

# %%
## main functions
import gene_symptoms_question_functions as gsf
## importlib makes sure functions from packages get refreshed
import importlib
import requests
importlib.reload(gsf)
import pandas as pd
import math
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %% [markdown]
# ## Set disease and output names

# %%
disease_name = 'Dravet Syndrome'
output_csv = "Dravet_Syndrome_2020-08-27.csv"
symptom_csv = "Dravet_Syndrome_Symptoms_2020-08-27.csv"

# %% [markdown]
# ## Get disease

# %%
disease_name = disease_name.lower()
disease = ht.query(disease_name)['Disease'][0]
disease
# Out:
# {'MONDO': 'MONDO:0100135',
#  'DOID': 'DOID:0060171',
#  'UMLS': 'C0751122',
#  'name': 'Dravet syndrome',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0100135'},
#  'display': 'MONDO(MONDO:0100135) DOID(DOID:0060171) UMLS(C0751122) name(Dravet syndrome)',
#  'type': 'Disease'}

# %% [markdown]
# ## Get disease symptoms

# %%
# get disease symptoms
disease_symptoms_list = gsf.get_disease_symptoms(disease_name)
disease_symptoms = disease_symptoms_list[0]
disease_symptom_hpids = disease_symptoms_list[1]
disease_symptom_dict = disease_symptoms_list[2]
disease_symptoms
disease_symptom_hpids
# Out:
# ['developmental regression', 'Loss of developmental milestones', 'Mental deterioration in childhood', 'Neurodevelopmental regression', 'Psychomotor regression', 'Psychomotor regression beginning in infancy', 'Psychomotor regression in infants', 'Psychomotor regression, progressive', 'progressive gait ataxia', 'Gait ataxia, progressive', 'focal-onset seizure', 'Focal onset seizure', 'Focal seizure', 'Focal seizures', 'Focal-onset seizures', 'Partial seizure', 'Partial seizures', 'Seizure affecting one half of brain', 'limited neck range of motion', 'Limited cervical range of motion', 'Limited neck range of motion', 'autistic behavior', 'ASD', 'Autistic behaviour', 'Pervasive developmental disorder', 'anxiety', 'Anxiety', 'Anxiousness', 'Excessive, persistent worry and fear', 'parkinsonism', 'photosensitive myoclonic seizure', 'Photically induced myoclonic seizure', 'Photomyoclonic seizure', 'Photomyoclonic seizures', 'myoclonus', 'Myoclonic jerks', 'rigidity', 'Muscle rigidity', 'Rigidity', 'bradykinesia', 'Slow movements', 'Slowness of movements', 'generalized myoclonic seizure', 'Generalised epileptic myoclonus', 'Generalised myoclonic seizure', 'Generalised myoclonic seizures', 'Generalized epileptic myoclonus', 'Generalized myoclonic seizures', 'Myoclonus seizures', 'focal aware seizure', 'Focal aware seizures', 'Focal seizure with retained awareness', 'Focal seizure without impairment of awareness', 'Focal seizure without impairment of consciousness or awareness', 'Focal seizures without impairment of consciousness or awareness', 'Partial seizure with retained awareness', 'Partial seizure without impairment of awareness', 'Simple partial seizure', 'Simple partial seizures', 'febrile seizure (within the age range of 3 months to 6 years)', 'Febrile convulsion', 'Febrile seizures', 'Fever induced seizures', 'Seizures, febrile, in early childhood', 'Seizures, generalized, associated with fever', 'focal impaired awareness seizure', 'Complex focal seizures', 'Complex partial seizure', 'Complex partial seizures', 'Dyscognitive seizures', 'Focal dyscognitive seizure', 'Focal impaired awareness seizures', 'Focal seizure with impairment of awareness', 'Focal seizure with loss of awareness', 'Focal seizures with impairment of consciousness or awareness', 'Localised dyscognitive seizure', 'Localised seizure with impaired awareness', 'Localised seizure with loss of awareness', 'Localized dyscognitive seizure', 'Localized seizure with impaired awareness', 'Localized seizure with loss of awareness', 'Partial dyscognitive seizure', 'Partial seizure with impairment of awareness', 'Partial seizure with loss of awareness', 'cogwheel rigidity', 'focal hemiclonic seizure', 'Hemiclonic seizure', 'Hemiclonic seizures', 'Unilateral clonic seizure', 'Unilateral clonic seizures', 'photosensitive tonic-clonic seizure', 'Photically induced tonic-clonic seizure', 'Photosensitive tonic-clonic seizures', 'Seizures, tonic-clonic, photosensitive', 'atypical absence seizure', 'Atypical absence', 'Atypical absence seizures', 'Atypical petit mal seizures', 'obsessive-compulsive trait', 'Obsessive-compulsive trait', 'Obsessive-compulsive traits', 'multifocal epileptiform discharges', 'Multifocal EEG abnormality', 'generalized clonic seizure', 'Generalised clonic seizure', 'Generalised clonic seizures', 'Generalised onset clonic seizure', 'Generalised-onset clonic seizure', 'Generalized clonic seizures', 'Generalized onset clonic seizure', 'Generalized-onset clonic seizure', 'complex febrile seizure', 'Complex febrile convulsion', 'Complex febrile seizures', 'Complex fever fit', 'interictal epileptiform activity', 'Epileptiform EEG discharges', 'facial tics', 'Cramping of facial muscles', 'Facial spasms', 'Facial tics', 'Jerking of facial muscles', 'Mimic spasms', 'Spasms of facial muscles', 'Twitching of facial muscles', 'epilepsia partialis continua', 'Epilepsia partialis continua of Kojevnikov', "Kojevnikov's epilepsia", "Kozhevnikov's epilepsia", 'cognitiv ...
# ['HP:0002376',
#  'HP:0007240',
#  'HP:0007359',
#  'HP:0000466',
#  'HP:0000729',
#  'HP:0000739',
#  'HP:0001300',
#  'HP:0001327',
#  'HP:0001336',
#  'HP:0002063',
#  'HP:0002067',
#  'HP:0002123',
#  'HP:0002349',
#  'HP:0002373',
#  'HP:0002384',
#  'HP:0002396',
#  'HP:0006813',
#  'HP:0007207',
#  'HP:0007270',
#  'HP:0008770',
#  'HP:0010841',
#  'HP:0011169',
#  'HP:0011172',
#  'HP:0011182',
#  'HP:0011468',
#  'HP:0012847',
#  'HP:0100543',
#  'HP:0000736',
#  'HP:0000980',
#  'HP:0001763',
#  'HP:0002283',
#  'HP:0002307',
#  'HP:0002311',
#  'HP:0002345',
#  'HP:0003066',
#  'HP:0007010',
#  'HP:0008081',
#  'HP:0008947',
#  'HP:0011185',
#  'HP:0011198',
#  'HP:0025101',
#  'HP:0031475',
#  'HP:0100694',
#  'HP:0100710',
#  'HP:0200048',
#  'HP:0010818']

# %% [markdown]
# ## Get Symptom Prevalence - based off edges out counts

# %%
disease_symptom_dict = gsf.get_symtpom_prevalence(disease_symptom_dict, disease_name) 
disease_symptoms_df = pd.DataFrame.from_dict(disease_symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptoms_df = pd.concat([disease_symptoms_df[disease_symptoms_df["frequency"] == "Very frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Occasional"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Rare"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Unknown"]
              ])
# Out:
# HP:0002376
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# gene
# (236, 9)
# OKKKk
# 236
# API 3.10 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (311, 9)
# ok edge phen to dis
# 547
# edges out
# 547
# HP:0007240
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (31, 9)
# OKKKk
# 31
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# (38, 9)
# ok edge phen to dis
# 69
# edges out
# 69
# HP:0007359
# API 3.6 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (108, 9)
# OKKKk
# 108
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# (71, 9)
# ok edge phen to dis
# 179
# edges out
# 179
# HP:0000466
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# gene
# (13, 9)
# OKKKk
# 13
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# (6, 9)
# ok edge phen to dis
# 19
# edges out
# 19
# HP:0000729
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# gene
# (212, 9)
# OKKKk
# 212
# API 3.1 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# (268, 9)
# ok edge phen to dis
# 480
# edges out
# 522
# HP:0000739
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# gene
# (213, 9)
# OKKKk
# 213
# API 3.7 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (272, 9)
# ok edge phen to dis
# 485
# edges out
# 485
# HP:0001300
# API 3.2 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (89, 9)
# OKKKk
# 89
# API 3.7 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# (178, 9)
# ok edge phen to dis
# 267
# edges out
# 267
# HP:0001327
# API 3.9 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (8, 9)
# OKKKk
# 8
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# (5, 9)
# ok edge phen to dis
# 13
# edges out
# 13
# HP:0001336
# API 3.7 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (199, 9)
# OKKKk
# 199
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# (323, 9)
# ok edge phen to dis
# 522
# edges out
# 522
# HP:0002063
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# gene
# (160, 9)
# OKKKk
# 160
# API 3.1 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (218, 9)
# ok edge phen to dis
# 378
# edges out
# 378
# HP:0002067
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# gene
# (113, 9)
# OKKKk
# 113
# API 3.3 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# (185, 9)
# ok edge phen to dis
# 298
# edges out
# 390
# HP:0002123
# API 3.1 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (117, 9)
# OKKKk
# 117
# API 3.1 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (162, 9)
# ok edge phen to dis
# 279
# edges out
# 279
# HP:0002349
# API 3.2 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.1 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# gene
# (11, 9)
# OKKKk
# 11
# API 3.1 semmed_phenotype failed
# API 3.6 semmed_phenotype failed
# API 3.7 semmed_phenotype failed
# API 3.8 semmed_phenotype failed
# API 3.9 semmed_phenotype failed
# API 3.2 semmed_phenotype failed
# API 3.11 semmed_phenotype failed
# API 3.10 semmed_phenotype failed
# API 3.3 semmed_phenotype failed
# API 3.12 semmed_phenotype failed
# API 3.14 semmed_phenotype failed
# API 3.5 semmed_phenotype failed
# API 3.16 semmed_phenotype failed
# API 3.4 semmed_phenotype failed
# API 3.17 semmed_phenotype failed
# API 3.15 semmed_phenotype failed
# API 3.13 semmed_phenotype failed
# API 3.18 semmed_phenotype failed
# API 3.19 semmed_phenotype failed
# (9, 9)
# ok edge phen to dis
# 20
# Cannot connect to host myvariant.info:443 ssl:default [nodename nor servname provided, or not known]
# Cannot connect to host mydisease.info:80 ssl:default [nodename nor servname provided, or not known]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Too many open files]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Too many open files]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Too many open files]
# Cannot connect to host biothings.ncats.io:443 ssl:default [Too many open files]
# Cannot connect to host mygene.info:443 ssl:default [nodename nor servname provided, or not known]
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 976             conn.connect()
#     977
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     307         # Add certificate verification
# --> 308         conn = self._new_conn()
#     309         hostname = self.host
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fc3c18636d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#
# MaxRetryError: HTTPSConnectionPool(host='mychem.info', port=443): Max retries exceeded with url: /v1/query?fields=chembl.molecule_chembl_id%2Cdrugbank.xrefs.chembl%2Cdrugcentral.xrefs.chembl_id%2Cdrugcentral.xrefs.drugbank_id%2Cpharmgkb.xrefs.drugbank%2Cchebi.xrefs.drugbank%2Cdrugbank.id%2Cpubchem.cid%2Cdrugbank.xrefs.pubchem.cid%2Cdrugcentral.xrefs.pubchem_cid%2Cpharmgkb.xrefs.pubchem.cid%2Cchebi.id%2Cchembl.chebi_par_id%2Cdrugbank.xrefs.chebi%2Cdrugcentral.xrefs.chebi%2Cdrugcentral.xrefs.umlscui%2Cpharmgkb.xrefs.umls%2Cumls.cui%2Cumls.mesh%2Cdrugcentral.xrefs.mesh_descriptor_ui%2Cginas.xrefs.MESH%2Cpharmgkb.xrefs.mesh%2Cdrugcentral.xrefs.unii%2Cunii.unii%2Caeolus.unii%2Cginas.unii%2Cdrugbank.inchi_key%2Cginas.inchikey%2Cunii.inchikey%2Cchebi.inchikey%2Cdrugbank.inchi%2Cchebi.inchi%2Cchembl.inchi%2Cdrugbank.xrefs.kegg.cid%2Cchembl.pref_name%2Cdrugbank.name%2Cumls.name%2Cginas.preferred_name%2Cpharmgkb.name%2Cchebi.name%2Cdrugbank.international_brands.name%2Cchembl.molecule_synonyms.synonyms%2Cdrugbank.synonyms%2Cdrugcentral.synonyms%2Cchebi.synonyms%2Cginas.cas_primary%2Cpharmgkb.xrefs.cas%2Cchebi.xrefs.cas%2Cpubchem.iupac.traditional%2Cdrugbank.iupac%2Cchebi.formulae%2Cdrugbank.formula%2Cpubchem.molecular_formula&dotfield=true&species=human&size=5 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc3c18636d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-9-d431c1b09f32> in <module>
# ----> 1 disease_symptom_dict = gsf.get_symtpom_prevalence(disease_symptom_dict, disease_name)
#       2 disease_symptoms_df = pd.DataFrame.from_dict(disease_symptom_dict, orient='index').sort_values(by=['edges_out_count'])
#       3 disease_symptoms_df = pd.concat([disease_symptoms_df[disease_symptoms_df["frequency"] == "Very frequent"],
#       4                disease_symptoms_df[disease_symptoms_df["frequency"] == "Frequent"],
#       5                disease_symptoms_df[disease_symptoms_df["frequency"] == "Occasional"],
#
# ~/Desktop/BTE_notebooks/gene_symptoms_question_functions.py in get_symtpom_prevalence(hp_symptom_dict, disease_name)
#     248                         a = ht.query(UMLS)[y]
#     249                     else:
# --> 250                         a = ht.query(z)[y]
#     251                     # print(a)
#     252                     for b in a:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/hint.py in query(self, _input, semantic_type)
#      72         self.construct_api_calls(_input)
#      73         # make API calls asynchronously and gather all outputs
# ---> 74         self.responses, _ = self.caller.call_apis(self.api_call_inputs)
#      75         return self.parse_api_responses()
#      76
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/apicall.py in call_apis(self, inputs, verbose, loop)
#     228         if not loop:
#     229             loop = asyncio.new_event_loop()
# --> 230         return (loop.run_until_complete(self.run(inputs, verbose=verbose)), self.log)
#     231         # res = asyncio.run(self.run(inputs, verbose=verbose))
#     232         # return (res, self.log)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/asyncio/base_events.py in run_until_complete(self, future)
#     614             raise RuntimeError('Event loop stopped before Future completed.')
#     615
# --> 616         return future.result()
#     617
#     618     def stop(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/apicall.py in run(self, inputs, verbose)
#     190                 task = self.call_one_api(i, session, verbose=verbose)
#     191                 tasks.append(task)
# --> 192             responses = await asyncio.gather(*tasks)
#     193             # print(responses)
#     194             return responses
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/apicall.py in call_one_api(self, _input, session, verbose)
#     176         """
#     177         # check api type
# --> 178         res = await self.call_one_arbitrary_api(_input, session, verbose=verbose)
#     179         return res
#     180
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/biothings_explorer/apicall.py in call_one_arbitrary_api(self, _input, session, verbose)
#     151                     request_body["q"] = s.join(request_list[counter:(counter+interval)])
#     152                     # make synchronous calls
# --> 153                     res_temp = requests.post(base_url, params=parameters, data=request_body, headers=header)
#     154                     if(res_temp.status_code == 200):
#     155                         # combine responses from 1+ calls
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='mychem.info', port=443): Max retries exceeded with url: /v1/query?fields=chembl.molecule_chembl_id%2Cdrugbank.xrefs.chembl%2Cdrugcentral.xrefs.chembl_id%2Cdrugcentral.xrefs.drugbank_id%2Cpharmgkb.xrefs.drugbank%2Cchebi.xrefs.drugbank%2Cdrugbank.id%2Cpubchem.cid%2Cdrugbank.xrefs.pubchem.cid%2Cdrugcentral.xrefs.pubchem_cid%2Cpharmgkb.xrefs.pubchem.cid%2Cchebi.id%2Cchembl.chebi_par_id%2Cdrugbank.xrefs.chebi%2Cdrugcentral.xrefs.chebi%2Cdrugcentral.xrefs.umlscui%2Cpharmgkb.xrefs.umls%2Cumls.cui%2Cumls.mesh%2Cdrugcentral.xrefs.mesh_descriptor_ui%2Cginas.xrefs.MESH%2Cpharmgkb.xrefs.mesh%2Cdrugcentral.xrefs.unii%2Cunii.unii%2Caeolus.unii%2Cginas.unii%2Cdrugbank.inchi_key%2Cginas.inchikey%2Cunii.inchikey%2Cchebi.inchikey%2Cdrugbank.inchi%2Cchebi.inchi%2Cchembl.inchi%2Cdrugbank.xrefs.kegg.cid%2Cchembl.pref_name%2Cdrugbank.name%2Cumls.name%2Cginas.preferred_name%2Cpharmgkb.name%2Cchebi.name%2Cdrugbank.international_brands.name%2Cchembl.molecule_synonyms.synonyms%2Cdrugbank.synonyms%2Cdrugcentral.synonyms%2Cchebi.synonyms%2Cginas.cas_primary%2Cpharmgkb.xrefs.cas%2Cchebi.xrefs.cas%2Cpubchem.iupac.traditional%2Cdrugbank.iupac%2Cchebi.formulae%2Cdrugbank.formula%2Cpubchem.molecular_formula&dotfield=true&species=human&size=5 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fc3c18636d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# ## Calculate Individual Symptom Scores

# %%
individual_symptom_scores = [];
for index,x in disease_symptoms_df.iterrows():
    if(x["frequency"] == "Very frequent"):
        score = 20 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Frequent"):
        score = 15 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Occasional"):
        score = 10 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Rare"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Unknown"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    individual_symptom_scores.append(score)

# print(len(individual_symptom_scores))
disease_symptoms_df["ISS"] = individual_symptom_scores

# %% [markdown]
# ## Symptoms Table

# %%
disease_symptoms_df

# %%
disease_symptoms_df.to_csv(symptom_csv, index = False)

# %% [markdown]
# ## Get Disease -> Gene (no intermediates)

# %%
disease_disease_to_genes_dict = gsf.get_disease_to_gene_results(disease)
disease_disease_to_genes_dict

# %% [markdown]
# ## Get Disease -> intermediate_node (any except those matching symptoms) -> Gene

# %%
# get results using intermediates 
node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %%
disease_disease_all_nodes_genes = gsf.predict_many(disease, node_type_list, 'Gene')

# Save an object to a file
# %store disease_disease_all_nodes_genes

# %%
# Restore the object
# %store -r disease_disease_all_nodes_genes
disease_disease_all_nodes_genes

# %%
## Remove UMLS "Genes"  (not gene specific) 
disease_disease_all_nodes_genes = disease_disease_all_nodes_genes[~disease_disease_all_nodes_genes['output_id'].str.contains('UMLS')]

# %%
max_2_step_genes = 100
disease_disease_to_node_to_genes_dict = gsf.get_disease_to_node_to_gene_results(disease_disease_all_nodes_genes, max_2_step_genes, disease_symptoms, disease_symptom_hpids)
# %store disease_disease_to_node_to_genes_dict

# %% [markdown]
# ## Combine genes from one and two step processes then get rid of any duplicates

# %%
# %store -r disease_disease_to_node_to_genes_dict
disease_top_genes_list = disease_disease_to_genes_dict["disease_to_genes_list"] + disease_disease_to_node_to_genes_dict["top_related_genes_to_disease"]
disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
# top_genes_list

# %% [markdown]
# ## Get Genes -> Symtoms, filtered by those related to Disease

# %%
disease_relevant_genes_to_symptoms_df = gsf.determined_genes_to_symptoms(disease_top_genes_list, disease_symptoms)
# relevant_genes_to_symptoms_df

# %%
# %store disease_relevant_genes_to_symptoms_df

# %%
# %store -r disease_relevant_genes_to_symptoms_df
disease_relevant_genes_list = list(dict.fromkeys(list(disease_relevant_genes_to_symptoms_df["input"])))
# relevant_genes_list

# %%
disease_gene_to_symptom_pub_counts = gsf.get_gene_to_symptom_publication_counts(disease_relevant_genes_to_symptoms_df)
# gene_to_symptom_pub_counts

# %%
disease_causes_dict = gsf.create_causes_dict(disease_relevant_genes_to_symptoms_df)
# causes_dict

# %% [markdown]
# ## Get edges out from each gene
# For use in normalizing in relevance score

# %%
disease_connection_dict =  gsf.get_connection_normalizing_count(disease_relevant_genes_list,node_type_list)
# connection_dict

# %%
# %store disease_connection_dict

# %%
# %store -r disease_connection_dict

# %% [markdown]
# ## Assemble final results

# %%
disease_df = gsf.assemble_final_data_frame(disease_relevant_genes_to_symptoms_df, 
                                      disease_connection_dict,
                                      disease_disease_to_genes_dict['sorted_disease_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['sorted_disease_to_all_nodes_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['top_two_step_genes_pub_counts'], 
                                      disease_gene_to_symptom_pub_counts, 
                                      disease_causes_dict,
                                      disease_symptoms_df)
disease_df

# %% [markdown]
# ## Save Results

# %%
disease_df.to_csv(output_csv, index = False)
