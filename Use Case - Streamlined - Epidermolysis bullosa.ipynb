# %% [markdown]
# ## Imports

# %%
## main functions
import gene_symptoms_question_functions as gsf
## importlib makes sure functions from packages get refreshed
import importlib
import requests
importlib.reload(gsf)
import pandas as pd
import math
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %% [markdown]
# ## Set disease and output names

# %%
disease_name = 'epidermolysis bullosa dystrophica'
output_csv = "Epidermolysis_bullosa_2020-08-27.csv"
symptom_csv = "Epidermolysis_bullosa_symptoms_2020-08-27.csv"

# %% [markdown]
# ## Get disease

# %%
disease_name = disease_name.lower()
disease = ht.query(disease_name)['Disease'][0]
disease
# Out:
# {'MONDO': 'MONDO:0006543',
#  'DOID': 'DOID:4959',
#  'name': 'epidermolysis bullosa dystrophica',
#  'MESH': 'D016108',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0006543'},
#  'display': 'MONDO(MONDO:0006543) DOID(DOID:4959) MESH(D016108) name(epidermolysis bullosa dystrophica)',
#  'type': 'Disease'}

# %%
# fc = FindConnection(input_obj=disease, output_obj='Gene', intermediate_nodes=None)
# fc.connect(verbose=False)
# df = fc.display_table_view()
# df

# %% [markdown]
# ## Get disease symptoms

# %%
# get disease symptoms
disease_symptoms_list = gsf.get_disease_symptoms('dystrophic epidermolysis bullosa')
disease_symptoms = disease_symptoms_list[0]
disease_symptom_hpids = disease_symptoms_list[1]
disease_symptom_dict = disease_symptoms_list[2]
disease_symptoms
disease_symptom_hpids
# Out:
# request url: http://mydisease.info/v1/query?q=hpo.disease_name:"dystrophic epidermolysis bullosa"&fields=hpo
# disease symptoms for:
# Dystrophic epidermolysis bullosa
# ['urinary retention', 'Increased post-void residual urine volume', 'ureteral stenosis', 'Narrowing of the ureter', 'renal insufficiency', 'Renal failure', 'Renal failure in adulthood', 'nephrotic syndrome', 'Nephrosis', 'abnormality of the dentition', 'Abnormal dentition', 'Abnormal teeth', 'Dental abnormalities', 'Dental abnormality', 'Dental anomalies', 'furrowed tongue', 'Fissured tongue', 'Grooved tongue', 'Lingual furrow', 'Lingue plicata', 'Plicated tongue', 'Prominent tongue grooves', 'Scrotal tongue', 'hearing impairment', 'Congenital deafness', 'Congenital hearing loss', 'Deafness', 'Hearing defect', 'Hearing impairment', 'chronic otitis media', 'Chronic infections of the middle ear', 'Otitis media, chronic', 'blepharitis', 'Cellulitis of eyelids', 'Inflammation of eyelids', 'nasolacrimal duct obstruction', 'Blocked tear duct', 'Lacrimal duct obstruction', 'ectropion', 'Eyelid turned out', 'carious teeth', 'Caries', 'Cariosity of teeth', 'Dental caries', 'Dental cavities', 'Early dental caries', 'Frequent caries', 'Tooth cavities', 'Tooth decay', 'abnormality of dental enamel', 'Abnormal tooth enamel', 'Enamel abnormalities', 'Enamel abnormality', 'eczema', 'Eczema', 'hypopigmented skin patches', 'Patchy loss of skin color', 'milia', 'Milk spot', 'Millium cyst', 'abnormality of the hand', 'Abnormal hands', 'Abnormality of the hand', 'Hand anomalies', 'Hand deformities', 'stroke', 'Cerebral vascular events', 'Cerebrovascular accident', 'Stroke', 'failure to thrive', 'Faltering weight', 'Postnatal failure to thrive', 'Weight faltering', 'recurrent skin infections', 'Cutaneous infections', 'Recurrent skin infections', 'Skin infections, recurrent', 'abnormality of the nail', 'Abnormality of the nail', 'laryngeal stenosis', 'congestive heart failure', 'CHF', 'Cardiac failure', 'Cardiac failures', 'Cardiac insufficiency', 'Chronic heart failure', 'Heart failure', 'dilated cardiomyopathy', 'Cardiomyopathy, dilated', 'Congestive cardiomyopathy', 'Stretched and thinned heart muscle', 'phimosis', 'abnormal foot morphology', 'Abnormal feet structure', 'Abnormality of the feet', 'Abnormality of the foot', 'Foot deformities', 'Foot deformity', 'toe syndactyly', 'Foot syndactyly', 'Fused toes', 'Syndactyly of feet', 'Syndactyly of toes', 'Webbed toes', 'dystrophic toenail', 'Dystrophic toenail changes', 'Poor toenail formation', 'anemia', 'Anaemia', 'Low number of red blood cells or hemoglobin', 'dysphagia', 'Difficulty swallowing', 'Poor swallowing', 'Swallowing difficulties', 'Swallowing difficulty', 'constipation', 'Constipation', 'Costiveness', 'Dyschezia', 'esophageal stricture', 'Narrowing of esophagus due to inflammation and scar tissue', 'neoplasm', 'Neoplasia', 'Oncological abnormality', 'Tumor', 'Tumour', 'squamous cell carcinoma', 'abnormality of the anus', 'Abnormality of the anus', 'flexion contracture of toe', 'Contractures involving the toes', 'Contractures of the toes', 'Toe contractures', 'finger syndactyly', 'Partial syndactyly', 'interstitial pulmonary abnormality', 'Abnormal lung parenchyma morphology', 'Abnormality in area between air sacs in lung', 'Interstitial lung disease', 'Interstitial pulmonary disease', 'aplasia/hypoplasia of the skin', 'Absent/small skin', 'Absent/underdeveloped skin', 'abnormal blistering of the skin', 'Abnormal blistering of the skin', 'Blister', 'Blistering, generalized', 'Blisters', 'Skin bullae', 'dystrophic fingernails', 'Poor fingernail formation', 'nail dystrophy', 'Dystrophic nails', 'Onychodystrophy', 'Poor nail formation', 'acute constipation', 'immunologic hypersensitivity', 'camptodactyly of finger', 'Camptodactyly of hands', 'Camptodactyly of proximal interphalangeal joint', 'Contractures of the proximal interphalangeal joints of the fingers', 'Flexion contractures of proximal interphalangeal joints', 'Permanent flexion of the finger', 'Proximal interphalangeal finger joint contractures', 'scarring', 'Scarring', 'gangrene', 'Death of body tissue due to lack of blood flow  ...
# ['HP:0000016',
#  'HP:0000071',
#  'HP:0000083',
#  'HP:0000100',
#  'HP:0000164',
#  'HP:0000221',
#  'HP:0000365',
#  'HP:0000389',
#  'HP:0000498',
#  'HP:0000579',
#  'HP:0000656',
#  'HP:0000670',
#  'HP:0000682',
#  'HP:0000964',
#  'HP:0001053',
#  'HP:0001056',
#  'HP:0001155',
#  'HP:0001297',
#  'HP:0001508',
#  'HP:0001581',
#  'HP:0001597',
#  'HP:0001602',
#  'HP:0001635',
#  'HP:0001644',
#  'HP:0001741',
#  'HP:0001760',
#  'HP:0001770',
#  'HP:0001810',
#  'HP:0001903',
#  'HP:0002015',
#  'HP:0002019',
#  'HP:0002043',
#  'HP:0002664',
#  'HP:0002860',
#  'HP:0004378',
#  'HP:0005830',
#  'HP:0006101',
#  'HP:0006530',
#  'HP:0008065',
#  'HP:0008066',
#  'HP:0008391',
#  'HP:0008404',
#  'HP:0012451',
#  'HP:0100326',
#  'HP:0100490',
#  'HP:0100699',
#  'HP:0100758',
#  'HP:0100820',
#  'HP:0100825',
#  'HP:0200020']

# %% [markdown]
# ## Get Symptom Prevalence - based off edges out counts

# %%
disease_symptom_dict = gsf.get_symtpom_prevalence(disease_symptom_dict, disease_name) 
disease_symptoms_df = pd.DataFrame.from_dict(disease_symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptoms_df = pd.concat([disease_symptoms_df[disease_symptoms_df["frequency"] == "Very frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Occasional"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Rare"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Unknown"]
              ])
# Out:
# HP:0000016
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (17, 9)
# OKKKk
# 17
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (24, 9)
# ok edge phen to dis
# 41
# edges out
# 153
# HP:0000071
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (7, 9)
# OKKKk
# 7
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (17, 9)
# ok edge phen to dis
# 24
# edges out
# 24
# HP:0000083
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (172, 9)
# OKKKk
# 172
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# (321, 9)
# ok edge phen to dis
# 493
# edges out
# 493
# HP:0000100
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (118, 9)
# OKKKk
# 118
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# Cannot connect to host biothings.ncats.io:443 ssl:default [Connect call failed ('52.43.54.84', 443)]
# (168, 9)
# ok edge phen to dis
# 286
# Nope
# edges out
# 643
# HP:0000164
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (260, 9)
# OKKKk
# 260
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (376, 9)
# ok edge phen to dis
# 636
# edges out
# 636
# HP:0000221
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# gene
# (38, 9)
# OKKKk
# 38
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (42, 9)
# ok edge phen to dis
# 80
# edges out
# 80
# HP:0000365
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (288, 9)
# OKKKk
# 288
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (360, 9)
# ok edge phen to dis
# 648
# edges out
# 648
# HP:0000389
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (108, 9)
# OKKKk
# 108
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# (74, 9)
# ok edge phen to dis
# 182
# edges out
# 410
# HP:0000498
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (46, 9)
# OKKKk
# 46
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# (49, 9)
# ok edge phen to dis
# 95
# Nope
# edges out
# 131
# HP:0000579
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (18, 9)
# OKKKk
# 18
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# (27, 9)
# ok edge phen to dis
# 45
# edges out
# 45
# HP:0000656
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (52, 9)
# OKKKk
# 52
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (64, 9)
# ok edge phen to dis
# 116
# edges out
# 116
# HP:0000670
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (150, 9)
# OKKKk
# 150
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# (209, 9)
# ok edge phen to dis
# 359
# edges out
# 359
# HP:0000682
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (86, 9)
# OKKKk
# 86
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (91, 9)
# ok edge phen to dis
# 177
# edges out
# 177
# HP:0000964
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (210, 9)
# OKKKk
# 210
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# (187, 9)
# ok edge phen to dis
# 397
# edges out
# 397
# HP:0001053
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (101, 9)
# OKKKk
# 101
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (82, 9)
# ok edge phen to dis
# 183
# edges out
# 183
# HP:0001056
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (22, 9)
# OKKKk
# 22
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# (54, 9)
# ok edge phen to dis
# 76
# edges out
# 76
# HP:0001155
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (56, 9)
# OKKKk
# 56
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (73, 9)
# ok edge phen to dis
# 129
# edges out
# 129
# HP:0001297
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (81, 9)
# OKKKk
# 81
# API 2.10 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# (114, 9)
# ok edge phen to dis
# 195
# edges out
# 195
# HP:0001508
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (311, 9)
# OKKKk
# 311
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (361, 9)
# ok edge phen to dis
# 672
# edges out
# 672
# HP:0001581
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (53, 9)
# OKKKk
# 53
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (70, 9)
# ok edge phen to dis
# 123
# edges out
# 123
# HP:0001597
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (96, 9)
# OKKKk
# 96
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (131, 9)
# ok edge phen to dis
# 227
# edges out
# 227
# HP:0001602
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (15, 9)
# OKKKk
# 15
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (19, 9)
# ok edge phen to dis
# 34
# edges out
# 34
# HP:0001635
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (125, 9)
# OKKKk
# 125
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (299, 9)
# ok edge phen to dis
# 424
# edges out
# 424
# HP:0001644
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (108, 9)
# OKKKk
# 108
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (239, 9)
# ok edge phen to dis
# 347
# edges out
# 2062
# HP:0001741
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (7, 9)
# OKKKk
# 7
# API 2.9 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (15, 9)
# ok edge phen to dis
# 22
# edges out
# 22
# HP:0001760
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (132, 9)
# OKKKk
# 132
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (111, 9)
# ok edge phen to dis
# 243
# edges out
# 243
# HP:0001770
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (138, 9)
# OKKKk
# 138
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (179, 9)
# ok edge phen to dis
# 317
# edges out
# 317
# HP:0001810
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (19, 9)
# OKKKk
# 19
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# (40, 9)
# ok edge phen to dis
# 59
# edges out
# 59
# HP:0001903
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (188, 9)
# OKKKk
# 188
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (361, 9)
# ok edge phen to dis
# 549
# edges out
# 3709
# HP:0002015
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (239, 9)
# OKKKk
# 239
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (352, 9)
# ok edge phen to dis
# 591
# edges out
# 591
# HP:0002019
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (238, 9)
# OKKKk
# 238
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (326, 9)
# ok edge phen to dis
# 564
# edges out
# 564
# HP:0002043
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (21, 9)
# OKKKk
# 21
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (25, 9)
# ok edge phen to dis
# 46
# edges out
# 46
# HP:0002664
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (71, 9)
# OKKKk
# 71
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (159, 9)
# ok edge phen to dis
# 230
# edges out
# 230
# HP:0002860
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (46, 9)
# OKKKk
# 46
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (55, 9)
# ok edge phen to dis
# 101
# Nope
# edges out
# 3245
# HP:0004378
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# gene
# (10, 9)
# OKKKk
# 10
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (18, 9)
# ok edge phen to dis
# 28
# edges out
# 28
# HP:0005830
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (14, 9)
# OKKKk
# 14
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (20, 9)
# ok edge phen to dis
# 34
# edges out
# 34
# HP:0006101
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (170, 9)
# OKKKk
# 170
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (184, 9)
# ok edge phen to dis
# 354
# edges out
# 354
# HP:0006530
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (16, 9)
# OKKKk
# 16
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# (50, 9)
# ok edge phen to dis
# 66
# edges out
# 66
# HP:0008065
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (48, 9)
# OKKKk
# 48
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (48, 9)
# ok edge phen to dis
# 96
# edges out
# 96
# HP:0008066
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (61, 9)
# OKKKk
# 61
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (115, 9)
# ok edge phen to dis
# 176
# edges out
# 176
# HP:0008391
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (30, 9)
# OKKKk
# 30
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (35, 9)
# ok edge phen to dis
# 65
# edges out
# 65
# HP:0008404
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (99, 9)
# OKKKk
# 99
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (224, 9)
# ok edge phen to dis
# 323
# edges out
# 323
# HP:0012451
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (0, 0)
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# (1, 9)
# ok edge phen to dis
# 1
# edges out
# 1
# HP:0100326
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (7, 9)
# OKKKk
# 7
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (17, 9)
# ok edge phen to dis
# 24
# edges out
# 24
# HP:0100490
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (168, 9)
# OKKKk
# 168
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (235, 9)
# ok edge phen to dis
# 403
# edges out
# 403
# HP:0100699
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (12, 9)
# OKKKk
# 12
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (19, 9)
# ok edge phen to dis
# 31
# edges out
# 31
# HP:0100758
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (18, 9)
# OKKKk
# 18
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (30, 9)
# ok edge phen to dis
# 48
# edges out
# 567
# HP:0100820
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (32, 9)
# OKKKk
# 32
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (45, 9)
# ok edge phen to dis
# 77
# edges out
# 77
# HP:0100825
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (11, 9)
# OKKKk
# 11
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (20, 9)
# ok edge phen to dis
# 31
# edges out
# 80
# HP:0200020
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (42, 9)
# OKKKk
# 42
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (44, 9)
# ok edge phen to dis
# 86
# edges out
# 86

# %% [markdown]
# ## Calculate Individual Symptom Scores

# %%
individual_symptom_scores = [];
for index,x in disease_symptoms_df.iterrows():
    if(x["frequency"] == "Very frequent"):
        score = 20 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Frequent"):
        score = 15 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Occasional"):
        score = 10 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Rare"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Unknown"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    individual_symptom_scores.append(score)

# print(len(individual_symptom_scores))
disease_symptoms_df["ISS"] = individual_symptom_scores

# %% [markdown]
# ## Symptoms Table

# %%
disease_symptoms_df
# Out:
#                                                         names      frequency  \
# HP:0001810  [dystrophic toenail, Dystrophic toenail change...  Very frequent
# HP:0008391  [dystrophic fingernails, Poor fingernail forma...  Very frequent
# HP:0100825              [cheilitis, Inflammation of the lips]  Very frequent
# HP:0008065  [aplasia/hypoplasia of the skin, Absent/small ...  Very frequent
# HP:0008066  [abnormal blistering of the skin, Abnormal bli...  Very frequent
# HP:0001597  [abnormality of the nail, Abnormality of the n...  Very frequent
# HP:0008404  [nail dystrophy, Dystrophic nails, Onychodystr...  Very frequent
# HP:0005830  [flexion contracture of toe, Contractures invo...       Frequent
# HP:0001602                               [laryngeal stenosis]       Frequent
# HP:0002043  [esophageal stricture, Narrowing of esophagus ...       Frequent
# HP:0001056                   [milia, Milk spot, Millium cyst]       Frequent
# HP:0000221  [furrowed tongue, Fissured tongue, Grooved ton...       Frequent
# HP:0001581  [recurrent skin infections, Cutaneous infectio...       Frequent
# HP:0001155  [abnormality of the hand, Abnormal hands, Abno...       Frequent
# HP:0000682  [abnormality of dental enamel, Abnormal tooth ...       Frequent
# HP:0001053  [hypopigmented skin patches, Patchy loss of sk...       Frequent
# HP:0002664  [neoplasm, Neoplasia, Oncological abnormality,...       Frequent
# HP:0001760  [abnormal foot morphology, Abnormal feet struc...       Frequent
# HP:0001770  [toe syndactyly, Foot syndactyly, Fused toes, ...       Frequent
# HP:0006101            [finger syndactyly, Partial syndactyly]       Frequent
# HP:0000670  [carious teeth, Caries, Cariosity of teeth, De...       Frequent
# HP:0100490  [camptodactyly of finger, Camptodactyly of han...       Frequent
# HP:0002019  [constipation, Constipation, Costiveness, Dysc...       Frequent
# HP:0100758  [gangrene, Death of body tissue due to lack of...       Frequent
# HP:0002015  [dysphagia, Difficulty swallowing, Poor swallo...       Frequent
# HP:0000164  [abnormality of the dentition, Abnormal dentit...       Frequent
# HP:0012451                               [acute constipation]     Occasional
# HP:0001741                                         [phimosis]     Occasional
# HP:0000071       [ureteral stenosis, Narrowing of the ureter]     Occasional
# HP:0100326                     [immunologic hypersensitivity]     Occasional
# HP:0004378  [abnormality of the anus, Abnormality of the a...     Occasional
# HP:0100699                               [scarring, Scarring]     Occasional
# HP:0000579  [nasolacrimal duct obstruction, Blocked tear d...     Occasional
# HP:0006530  [interstitial pulmonary abnormality, Abnormal ...     Occasional
# HP:0100820               [glomerulopathy, Diseased glomeruli]     Occasional
# HP:0200020  [corneal erosion, Damage to outer layer of the...     Occasional
# HP:0000656                     [ectropion, Eyelid turned out]     Occasional
# HP:0000498  [blepharitis, Cellulitis of eyelids, Inflammat...     Occasional
# HP:0000016  [urinary retention, Increased post-void residu...     Occasional
# HP:0001297  [stroke, Cerebral vascular events, Cerebrovasc...     Occasional
# HP:0000964                                   [eczema, Eczema]     Occasional
# HP:0000389  [chronic otitis media, Chronic infections of t...     Occasional
# HP:0001635  [congestive heart failure, CHF, Cardiac failur...     Occasional
# HP:0000083  [renal insufficiency, Renal failure, Renal fai...     Occasional
# HP:0000100                    [nephrotic syndrome, Nephrosis]     Occasional
# HP:0000365  [hearing impairment, Congenital deafness, Cong...     Occasional
# HP:0001508  [failure to thrive, Faltering weight, Postnata...     Occasional
# HP:0001644  [dilated cardiomyopathy, Cardiomyopathy, dilat...     Occasional
# HP:0002860                          [squamous cell carcinoma]     Occasional
# HP:0001903  [anemia, Anaemia, Low number of red blood cell...     Occasional
#
#             edges_out_count        ISS
# HP:0001810               59   2.603778
# HP:0008391               65   2.480695
# HP:0100825               80   2.236068
# HP:0008065               96   2.041241
# HP:0008066              176   1.507557
# HP:0001597              227   1.327447
# HP:0008404              323   1.112830
# HP:0005830               34   2.572479
# HP:0001602               34   2.572479
# HP:0002043               46   2.211629
# HP:0001056               76   1.720618
# HP:0000221               80   1.677051
# HP:0001581              123   1.352504
# HP:0001155              129   1.320676
# HP:0000682              177   1.127469
# HP:0001053              183   1.108832
# HP:0002664              230   0.989071
# HP:0001760              243   0.962250
# HP:0001770              317   0.842484
# HP:0006101              354   0.797241
# HP:0000670              359   0.791670
# HP:0100490              403   0.747203
# HP:0002019              564   0.631614
# HP:0100758              567   0.629941
# HP:0002015              591   0.617018
# HP:0000164              636   0.594789
# HP:0012451                1  10.000000
# HP:0001741               22   2.132007
# HP:0000071               24   2.041241
# HP:0100326               24   2.041241
# HP:0004378               28   1.889822
# HP:0100699               31   1.796053
# HP:0000579               45   1.490712
# HP:0006530               66   1.230915
# HP:0100820               77   1.139606
# HP:0200020               86   1.078328
# HP:0000656              116   0.928477
# HP:0000498              131   0.873704
# HP:0000016              153   0.808452
# HP:0001297              195   0.716115
# HP:0000964              397   0.501886
# HP:0000389              410   0.493865
# HP:0001635              424   0.485643
# HP:0000083              493   0.450377
# HP:0000100              643   0.394362
# HP:0000365              648   0.392837
# HP:0001508              672   0.385758
# HP:0001644             2062   0.220219
# HP:0002860             3245   0.175547
# HP:0001903             3709   0.164199

# %%
disease_symptoms_df.to_csv(symptom_csv)

# %% [markdown]
# ## Get Disease -> Gene (no intermediates)

# %%
disease_disease_to_genes_dict = gsf.get_disease_to_gene_results(disease)
disease_disease_to_genes_dict
# Out:
# running disease -> gene
# {'sorted_disease_to_genes': {'RNF103': 1,
#   'FREM2': 1,
#   'FREM3': 1,
#   'DR1': 1,
#   'MATN1': 1,
#   'MMP1': 1,
#   'NAA15': 2,
#   'COL7A1': 3},
#  'one_step_genes_pub_counts': {'RNF103': 0,
#   'FREM2': 0,
#   'NAA15': 0,
#   'FREM3': 0,
#   'DR1': 0,
#   'MATN1': 0,
#   'COL7A1': 0,
#   'MMP1': 0},
#  'disease_to_genes_list': ['COL7A1',
#   'NAA15',
#   'MMP1',
#   'MATN1',
#   'DR1',
#   'FREM3',
#   'FREM2',
#   'RNF103']}

# %% [markdown]
# ## Get Disease -> intermediate_node (any except those matching symptoms) -> Gene

# %%
# get results using intermediates 
node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %%
disease_disease_all_nodes_genes = gsf.predict_many(disease, node_type_list, 'Gene')

# Save an object to a file
# %store disease_disease_all_nodes_genes
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# API 6.1 pharos failed
# Intermediate Node type running:
# Disease
# Intermediate Node type running:
# MolecularActivity
# Intermediate Node type running:
# BiologicalProcess
# Intermediate Node type running:
# CellularComponent
# Intermediate Node type running:
# Pathway
# Intermediate Node type running:
# AnatomicalEntity
# Intermediate Node type running:
# PhenotypicFeature
# Stored 'disease_disease_all_nodes_genes' (DataFrame)

# %%
# Restore the object
# %store -r disease_disease_all_nodes_genes
disease_disease_all_nodes_genes
# Out:
#                                  input input_type       pred1  \
# 0    EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
# 1    EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
# 2    EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
# 3    EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
# 4    EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
# ..                                 ...        ...         ...
# 942  EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
# 943  EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
# 944  EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
# 945  EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
# 946  EPIDERMOLYSIS BULLOSA DYSTROPHICA    Disease  related_to
#
#                         pred1_source         pred1_api pred1_pubmed  \
# 0                            DISEASE      DISEASES API         None
# 1                            DISEASE      DISEASES API         None
# 2                            DISEASE      DISEASES API         None
# 3                            DISEASE      DISEASES API         None
# 4                            DISEASE      DISEASES API         None
# ..                               ...               ...          ...
# 942  Translator Text Mining Provider  CORD Disease API         None
# 943  Translator Text Mining Provider  CORD Disease API         None
# 944  Translator Text Mining Provider  CORD Disease API         None
# 945  Translator Text Mining Provider  CORD Disease API         None
# 946  Translator Text Mining Provider  CORD Disease API         None
#
#            node1_type       node1_name               node1_id  \
# 0                Gene           RNF103          NCBIGene:7844
# 1                Gene           RNF103          NCBIGene:7844
# 2                Gene           RNF103          NCBIGene:7844
# 3                Gene           RNF103          NCBIGene:7844
# 4                Gene           RNF103          NCBIGene:7844
# ..                ...              ...                    ...
# 942  AnatomicalEntity  PORTION OF SKIN  UBERON:UBERON:0000014
# 943  AnatomicalEntity  PORTION OF SKIN  UBERON:UBERON:0000014
# 944  AnatomicalEntity  PORTION OF SKIN  UBERON:UBERON:0000014
# 945  AnatomicalEntity  PORTION OF SKIN  UBERON:UBERON:0000014
# 946  AnatomicalEntity  PORTION OF SKIN  UBERON:UBERON:0000014
#
#                          pred2                     pred2_source  \
# 0      positively_regulated_by                           SEMMED
# 1                homologous_to                             None
# 2      positively_regulated_by                           SEMMED
# 3    physically_interacts_with                           SEMMED
# 4    physically_interacts_with                             None
# ..                         ...                              ...
# 942                 related_to  Translator Text Mining Provider
# 943                 related_to  Translator Text Mining Provider
# 944                 related_to  Translator Text Mining Provider
# 945                 related_to  Translator Text Mining Provider
# 946                 related_to  Translator Text Mining Provider
#
#             pred2_api pred2_pubmed output_type output_name       output_id
# 0     SEMMED Gene API     28727979        Gene    C0536678   UMLS:C0536678
# 1     MyGene.info API         None        Gene      109483      MGI:109483
# 2     SEMMED Gene API     28727979        Gene     PLA2G2A   NCBIGene:5320
# 3     SEMMED Gene API      9070305        Gene       RAPSN   NCBIGene:5913
# 4         BioLink API         None        Gene       RAPSN   NCBIGene:5913
# ..                ...          ...         ...         ...             ...
# 942  CORD Anatomy API         None        Gene        IL18   NCBIGene:3606
# 943  CORD Anatomy API         None        Gene        PON1   NCBIGene:5444
# 944  CORD Anatomy API         None        Gene       CLIC4  NCBIGene:25932
# 945  CORD Anatomy API         None        Gene       NR1I2   NCBIGene:8856
# 946  CORD Anatomy API         None        Gene        FLT1   NCBIGene:2321
#
# [17585 rows x 16 columns]

# %%
## Remove UMLS "Genes"  (not gene specific) 
disease_disease_all_nodes_genes = disease_disease_all_nodes_genes[~disease_disease_all_nodes_genes['output_id'].str.contains('UMLS')]

# %%
max_2_step_genes = 100
disease_disease_to_node_to_genes_dict = gsf.get_disease_to_node_to_gene_results(disease_disease_all_nodes_genes, max_2_step_genes, disease_symptoms, disease_symptom_hpids)
# %store disease_disease_to_node_to_genes_dict
# Out:
# finding intermediate nodes that are symptoms
# removing symptom intermediates
# getting gene counts from 12075 gene entries
# sorting counts dictionary
# top genes occurrence counts:
# TNF: 34
# MAPK1: 23
# MMP9: 23
# REN: 22
# MMP2: 21
# AGTR1: 20
# TGFB1: 20
# ANG: 20
# IL6: 19
# VEGFA: 18
# IL10: 17
# AKT1: 17
# CAT: 17
# MAPK8: 16
# TIMP1: 16
# STAT3: 16
# TLR4: 15
# PTGS2: 15
# CCL2: 15
# IL2: 14
# EGFR: 14
# CA2: 13
# LOX: 13
# ACE: 13
# TP53: 13
# AHSA1: 13
# CRK: 13
# MTOR: 12
# ALB: 12
# INS: 12
# RELA: 12
# MMP1: 12
# SYK: 11
# MPO: 11
# GABPA: 11
# IL1B: 11
# FOS: 11
# MAPK14: 11
# CAMP: 11
# IFNA1: 11
# SOD1: 11
# FN1: 11
# C5AR1: 10
# MAPK3: 10
# TH: 10
# CSH1: 10
# ERCC8: 10
# BAX: 10
# ACE2: 10
# KL: 10
# ATM: 10
# CYP2C9: 10
# EGF: 10
# PIK3CA: 10
# LEP: 10
# CXCR4: 10
# SDC1: 10
# COL1A1: 10
# GRAP2: 10
# CD4: 10
# VCAM1: 10
# ADA: 9
# KIT: 9
# CCR2: 9
# CDKN1A: 9
# PPARA: 9
# PLA2G4A: 9
# POLDIP2: 9
# SST: 9
# CYP3A4: 9
# KDR: 9
# JAK2: 9
# MICE: 9
# TYMS: 9
# SIRT1: 9
# ETS1: 9
# BRAF: 9
# COL17A1: 9
# COL3A1: 9
# GORASP1: 9
# PPIB: 9
# SNCA: 9
# COL2A1: 9
# PTHLH: 9
# POMC: 9
# TP63: 8
# FGFR1: 8
# OXER1: 8
# RPSA: 8
# ISG20: 8
# IL2RA: 8
# CISH: 8
# BCR: 8
# HPSE: 8
# GBA: 8
# TLR3: 8
# GPI: 8
# ITGAM: 8
# CD44: 8
# IL12A: 8
# getting publicaiton counts
# Stored 'disease_disease_to_node_to_genes_dict' (dict)

# %% [markdown]
# ## Combine genes from one and two step processes then get rid of any duplicates

# %%
# %store -r disease_disease_to_node_to_genes_dict
disease_top_genes_list = disease_disease_to_genes_dict["disease_to_genes_list"] + disease_disease_to_node_to_genes_dict["top_related_genes_to_disease"]
disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
# top_genes_list

# %% [markdown]
# ## Get Genes -> Symtoms, filtered by those related to Disease

# %%
disease_relevant_genes_to_symptoms_df = gsf.determined_genes_to_symptoms(disease_top_genes_list, disease_symptoms)
# relevant_genes_to_symptoms_df
# Out:
# Genes -> PhenotypicFeatures
# Genes -> Bioprocesses
# Genes -> Diseases
# 351

# %%
# %store disease_relevant_genes_to_symptoms_df
# Out:
# Stored 'disease_relevant_genes_to_symptoms_df' (DataFrame)

# %%
# %store -r disease_relevant_genes_to_symptoms_df
disease_relevant_genes_list = list(dict.fromkeys(list(disease_relevant_genes_to_symptoms_df["input"])))
# relevant_genes_list

# %%
disease_gene_to_symptom_pub_counts = gsf.get_gene_to_symptom_publication_counts(disease_relevant_genes_to_symptoms_df)
# gene_to_symptom_pub_counts

# %%
disease_causes_dict = gsf.create_causes_dict(disease_relevant_genes_to_symptoms_df)
# causes_dict

# %% [markdown]
# ## Get edges out from each gene
# For use in normalizing in relevance score

# %%
disease_connection_dict =  gsf.get_connection_normalizing_count(disease_relevant_genes_list,node_type_list)
# connection_dict

# %%
# %store disease_connection_dict
# Out:
# Stored 'disease_connection_dict' (dict)

# %%
# %store -r disease_connection_dict

# %% [markdown]
# ## Assemble final results

# %%
disease_df = gsf.assemble_final_data_frame(disease_relevant_genes_to_symptoms_df, 
                                      disease_connection_dict,
                                      disease_disease_to_genes_dict['sorted_disease_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['sorted_disease_to_all_nodes_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['top_two_step_genes_pub_counts'], 
                                      disease_gene_to_symptom_pub_counts, 
                                      disease_causes_dict,
                                      disease_symptoms_df)
disease_df
# Out:
#        gene  direct_disease_assoc  two_step_assoc_to_disease  \
# 0    COL7A1                     3                          8
# 1      MMP1                     1                         12
# 22  COL17A1                     0                          9
# 2     FREM2                     1                          0
# 32      TNF                     0                         34
# ..      ...                   ...                        ...
# 83     HPSE                     0                          8
# 82      BCR                     0                          8
# 74     TYMS                     0                          9
# 55    GABPA                     0                         11
# 64      EGF                     0                         10
#
#              disease_symptoms_gene_is_associated_with  \
# 0   [milia, abnormal blistering of the skin, corne...
# 1   [abnormality of the anus, corneal erosion, con...
# 22  [corneal erosion, abnormal blistering of the s...
# 2   [laryngeal stenosis, laryngeal stenosis, abnor...
# 32  [anemia, anemia, anemia, anemia, anemia, anemi...
# ..                                                ...
# 83                               [nephrotic syndrome]
# 82                   [dilated cardiomyopathy, anemia]
# 74                                           [anemia]
# 55                                           [anemia]
# 64                                           [anemia]
#
#     symptoms_associated_count  gene_connections_count  final_symptom_score  \
# 0                          15                     377            20.685552
# 1                          11                    2365            12.033254
# 22                          9                     381            12.080976
# 2                           4                     256             7.832021
# 32                         23                   19388            11.488855
# ..                        ...                     ...                  ...
# 83                          1                    1584             0.394362
# 82                          2                    2704             0.384419
# 74                          1                    2948             0.164199
# 55                          1                    4112             0.164199
# 64                          1                    3542             0.164199
#
#     relevance_score
# 0          1.000000
# 1          0.128290
# 22         0.123781
# 2          0.122356
# 32         0.062295
# ..              ...
# 83         0.001042
# 82         0.000763
# 74         0.000000
# 55         0.000000
# 64         0.000000
#
# [86 rows x 8 columns]

# %% [markdown]
# ## Save Results

# %%
disease_df.to_csv(output_csv, index = False)
