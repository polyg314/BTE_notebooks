# %% [markdown]
# ## Imports

# %%
## main functions
import gene_symptoms_question_functions as gsf
## importlib makes sure functions from packages get refreshed
import importlib
import requests
importlib.reload(gsf)
import pandas as pd
import math
from biothings_explorer.user_query_dispatcher import FindConnection
from biothings_explorer.hint import Hint
ht = Hint()

# %% [markdown]
# ## Set disease and output names

# %%
disease_name = 'xeroderma pigmentosum'
output_csv = "xeroderma_pigmentosum_2020-08-27.csv"
symptom_csv = "xeroderma_pigmentosum_symptoms_2020-08-27.csv"

# %% [markdown]
# ## Get disease

# %%
disease_name = disease_name.lower()
disease = ht.query(disease_name)['Disease'][0]
disease
# Out:
# {'MONDO': 'MONDO:0019600',
#  'DOID': 'DOID:0050427',
#  'UMLS': 'C0043346',
#  'name': 'xeroderma pigmentosum',
#  'MESH': 'D014983',
#  'ORPHANET': '910',
#  'primary': {'identifier': 'MONDO',
#   'cls': 'Disease',
#   'value': 'MONDO:0019600'},
#  'display': 'MONDO(MONDO:0019600) DOID(DOID:0050427) ORPHANET(910) UMLS(C0043346) MESH(D014983) name(xeroderma pigmentosum)',
#  'type': 'Disease'}

# %% [markdown]
# ## Get disease symptoms

# %%
# get disease symptoms
disease_symptoms_list = gsf.get_disease_symptoms(disease_name)
disease_symptoms = disease_symptoms_list[0]
disease_symptom_hpids = disease_symptoms_list[1]
disease_symptom_dict = disease_symptoms_list[2]
disease_symptoms
disease_symptom_hpids
# Out:
# Cryptorchism
# Undescended testes
# Undescended testis
# Decreased activity of gonads
# Abnormal dentition
# Abnormal teeth
# Dental abnormalities
# Dental abnormality
# Dental anomalies
# Abnormally small cranium
# Abnormally small skull
# Decreased circumference of cranium
# Decreased size of cranium
# Decreased size of skull
# Reduced head circumference
# Small head circumference
# small calvarium
# small cranium
# Congenital deafness
# Congenital hearing loss
# Deafness
# Hearing defect
# Hearing impairment
# Hearing loss, sensorineural
# Sensorineural deafness
# Sensorineural hearing loss
# Cross-eyed
# Squint
# Squint eyes
# Corneal inflammation
# Cellulitis of eyelids
# Inflammation of eyelids
# Cataracts
# Clouding of the lens of the eye
# Cloudy lens
# Lens opacities
# Lens opacity
# Conjunctival telangiectases
# Small dilated blood vessels near membrane covering front of eye and eyelids
# Telangiectasia, conjunctival
# Extreme sensitivity of the eyes to light
# Light hypersensitivity
# Eyelid turned in
# Optic nerve atrophy
# Optic-nerve degeneration
# Eyelid turned out
# Dry skin
# Xerosis
# Thin skin
# Photosensitive skin
# Photosensitive skin rashes
# Photosensitivity
# Sensitivity to sunlight
# Skin photosensitivity
# Sun sensitivity
# Beauty mark
# Melanocytic naevus
# Melanocytic nevi
# Nevocellular nevi
# Pigmented naevi
# Pigmented nevi
# Cutaneous telangiectasia
# Telangiectases
# Hyperpigmented macules
# Hyperpigmented spots
# Patchy loss of skin color
# Pachydermia
# Thick skin
# Thickened skin
# Epileptic seizure
# Seizures
# Cerebellar ataxia
# Involuntary muscle stiffness, contraction, or spasm
# Muscle spasticity
# Muscular spasticity
# Absent or decreased deep tendon reflexes
# Decreased deep tendon reflexes
# Decreased tendon reflexes
# Decreased to absent deep tendon reflexes
# Decreased/absent deep tendon reflexes
# Depressed tendon reflexes
# Diminished deep tendon reflexes
# Diminished or absent deep tendon reflexes
# Diminished or absent tendon reflexes
# Hypoactive to absent deep tendon reflexes
# Impaired tendon reflexes
# Reduced/absent deep tendon reflexes
# Weak or absent deep tendon reflexes
# Freckling
# Faltering weight
# Postnatal failure to thrive
# Weight faltering
# Hair loss
# Fever
# Hyperthermia
# Pyrexia
# Extrapyramidal dysfunction
# Extrapyramidal signs
# Extrapyramidal symptoms
# Extrapyramidal syndrome
# Extrapyramidal tract signs
# Cerebral cortex atrophy
# Cortical atrophy
# Decrease in size of the outer layer of the brain due to loss of brain cells
# Abnormal EEG
# Abnormal electroencephalogram
# EEG abnormalities
# Electroencephalogram abnormal
# Electroencephalogram abnormalities
# Loss of developmental milestones
# Mental deterioration in childhood
# Neurodevelopmental regression
# Psychomotor regression
# Psychomotor regression beginning in infancy
# Psychomotor regression in infants
# Psychomotor regression, progressive
# Neoplasia
# Oncological abnormality
# Tumor
# Tumour
# Delayed bone age
# Delayed bone age before puberty
# Delayed bone maturation
# Delayed skeletal development
# Retarded bone age
# Skeletal maturation retardation
# Arthralgias
# Joint pain
# Malignant melanoma
# High urine amino acid levels
# Hyperaminoaciduria
# Increased levels of animo acids in urine
# Decreased body height
# Height less than 3rd percentile
# Short stature
# Small stature
# Stature below 3rd percentile
# Atrophic skin
# Skin atrophy
# Skin degeneration
# Excessive bone growth of the skull and face
# Hyperostosis of craniofacial bones
# Increased ossification of craniofacial bones
# Intellectual disability, progressive
# Mental retardation, progressive
# Progressive mental retardation
# Cloudy cornea
# Corneal stromal opacity
# Decreased testicular size
# Hypoplastic testes
# Small testes
# Small testis
# Testicular hypoplasia
# Adhesion of eyelids
# Ankyloblepharon filiforme adnatum
# Eyelid synechiae
# Eyelids stuck together
# Peripheral nerve damage
# Peripheral neuritis
# Depressed nasal alae
# Redness of skin or mucous membrane
# Fatigue
# Tired
# Tiredness
# Flat, discolored area of skin
# Eye tumor
# Abnormality of cognition
# Cognitive abnormality
# Cognitive defects
# Cognitive deficits
# Cognitive impairment
# Intellectual impairment
# Mental impairment
# Teleangiectasia of the skin
# ['cryptorchidism', 'Cryptorchism', 'Undescended testes', 'Undescended testis', 'hypogonadism', 'Decreased activity of gonads', 'abnormality of the dentition', 'Abnormal dentition', 'Abnormal teeth', 'Dental abnormalities', 'Dental abnormality', 'Dental anomalies', 'microcephaly', 'Abnormally small cranium', 'Abnormally small skull', 'Decreased circumference of cranium', 'Decreased size of cranium', 'Decreased size of skull', 'Reduced head circumference', 'Small head circumference', 'small calvarium', 'small cranium', 'hearing impairment', 'Congenital deafness', 'Congenital hearing loss', 'Deafness', 'Hearing defect', 'Hearing impairment', 'sensorineural hearing impairment', 'Hearing loss, sensorineural', 'Sensorineural deafness', 'Sensorineural hearing loss', 'strabismus', 'Cross-eyed', 'Squint', 'Squint eyes', 'keratitis', 'Corneal inflammation', 'blepharitis', 'Cellulitis of eyelids', 'Inflammation of eyelids', 'cataract', 'Cataracts', 'Clouding of the lens of the eye', 'Cloudy lens', 'Lens opacities', 'Lens opacity', 'conjunctival telangiectasia', 'Conjunctival telangiectases', 'Small dilated blood vessels near membrane covering front of eye and eyelids', 'Telangiectasia, conjunctival', 'photophobia', 'Extreme sensitivity of the eyes to light', 'Light hypersensitivity', 'entropion', 'Eyelid turned in', 'optic atrophy', 'Optic nerve atrophy', 'Optic-nerve degeneration', 'ectropion', 'Eyelid turned out', 'dry skin', 'Dry skin', 'Xerosis', 'hyperkeratosis', 'thin skin', 'Thin skin', 'cutaneous photosensitivity', 'Photosensitive skin', 'Photosensitive skin rashes', 'Photosensitivity', 'Sensitivity to sunlight', 'Skin photosensitivity', 'Sun sensitivity', 'melanocytic nevus', 'Beauty mark', 'Melanocytic naevus', 'Melanocytic nevi', 'Nevocellular nevi', 'Pigmented naevi', 'Pigmented nevi', 'telangiectasia', 'Cutaneous telangiectasia', 'Telangiectases', 'poikiloderma', 'hypermelanotic macule', 'Hyperpigmented macules', 'Hyperpigmented spots', 'hypopigmented skin patches', 'Patchy loss of skin color', 'pterygium', 'thickened skin', 'Pachydermia', 'Thick skin', 'Thickened skin', 'seizure', 'Epileptic seizure', 'Seizures', 'ataxia', 'Cerebellar ataxia', 'spasticity', 'Involuntary muscle stiffness, contraction, or spasm', 'Muscle spasticity', 'Muscular spasticity', 'reduced tendon reflexes', 'Absent or decreased deep tendon reflexes', 'Decreased deep tendon reflexes', 'Decreased tendon reflexes', 'Decreased to absent deep tendon reflexes', 'Decreased/absent deep tendon reflexes', 'Depressed tendon reflexes', 'Diminished deep tendon reflexes', 'Diminished or absent deep tendon reflexes', 'Diminished or absent tendon reflexes', 'Hypoactive to absent deep tendon reflexes', 'Impaired tendon reflexes', 'Reduced/absent deep tendon reflexes', 'Weak or absent deep tendon reflexes', 'freckling', 'Freckling', 'failure to thrive', 'Faltering weight', 'Postnatal failure to thrive', 'Weight faltering', 'alopecia', 'Hair loss', 'fever', 'Fever', 'Hyperthermia', 'Pyrexia', 'abnormality of extrapyramidal motor function', 'Extrapyramidal dysfunction', 'Extrapyramidal signs', 'Extrapyramidal symptoms', 'Extrapyramidal syndrome', 'Extrapyramidal tract signs', 'cerebral cortical atrophy', 'Cerebral cortex atrophy', 'Cortical atrophy', 'Decrease in size of the outer layer of the brain due to loss of brain cells', 'eeg abnormality', 'Abnormal EEG', 'Abnormal electroencephalogram', 'EEG abnormalities', 'Electroencephalogram abnormal', 'Electroencephalogram abnormalities', 'developmental regression', 'Loss of developmental milestones', 'Mental deterioration in childhood', 'Neurodevelopmental regression', 'Psychomotor regression', 'Psychomotor regression beginning in infancy', 'Psychomotor regression in infants', 'Psychomotor regression, progressive', 'neoplasm', 'Neoplasia', 'Oncological abnormality', 'Tumor', 'Tumour', 'delayed skeletal maturation', 'Delayed bone age', 'Delayed bone age before puberty', 'Delayed bone maturation', 'Delayed skeletal developme ...
# ['HP:0000028',
#  'HP:0000135',
#  'HP:0000164',
#  'HP:0000252',
#  'HP:0000365',
#  'HP:0000407',
#  'HP:0000486',
#  'HP:0000491',
#  'HP:0000498',
#  'HP:0000518',
#  'HP:0000524',
#  'HP:0000613',
#  'HP:0000621',
#  'HP:0000648',
#  'HP:0000656',
#  'HP:0000958',
#  'HP:0000962',
#  'HP:0000963',
#  'HP:0000992',
#  'HP:0000995',
#  'HP:0001009',
#  'HP:0001029',
#  'HP:0001034',
#  'HP:0001053',
#  'HP:0001059',
#  'HP:0001072',
#  'HP:0001250',
#  'HP:0001251',
#  'HP:0001257',
#  'HP:0001315',
#  'HP:0001480',
#  'HP:0001508',
#  'HP:0001596',
#  'HP:0001945',
#  'HP:0002071',
#  'HP:0002120',
#  'HP:0002353',
#  'HP:0002376',
#  'HP:0002664',
#  'HP:0002750',
#  'HP:0002829',
#  'HP:0002861',
#  'HP:0003355',
#  'HP:0004322',
#  'HP:0004334',
#  'HP:0004493',
#  'HP:0006887',
#  'HP:0007759',
#  'HP:0008734',
#  'HP:0009755',
#  'HP:0009830',
#  'HP:0010649',
#  'HP:0010783',
#  'HP:0012378',
#  'HP:0012733',
#  'HP:0012740',
#  'HP:0100012',
#  'HP:0100543',
#  'HP:0100585']

# %% [markdown]
# ## Get Symptom Prevalence - based off edges out counts

# %%
disease_symptom_dict = gsf.get_symtpom_prevalence(disease_symptom_dict, disease_name) 
disease_symptoms_df = pd.DataFrame.from_dict(disease_symptom_dict, orient='index').sort_values(by=['edges_out_count'])
disease_symptoms_df = pd.concat([disease_symptoms_df[disease_symptoms_df["frequency"] == "Very frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Frequent"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Occasional"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Rare"],
               disease_symptoms_df[disease_symptoms_df["frequency"] == "Unknown"]
              ])
# Out:
# HP:0000028
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# gene
# (331, 9)
# OKKKk
# 331
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (365, 9)
# ok edge phen to dis
# 696
# edges out
# 696
# HP:0000135
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (213, 9)
# OKKKk
# 213
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (215, 9)
# ok edge phen to dis
# 428
# edges out
# 1228
# HP:0000164
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (260, 9)
# OKKKk
# 260
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (376, 9)
# ok edge phen to dis
# 636
# edges out
# 636
# HP:0000252
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# gene
# (432, 9)
# OKKKk
# 432
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (383, 9)
# ok edge phen to dis
# 815
# edges out
# 815
# HP:0000365
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (288, 9)
# OKKKk
# 288
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (360, 9)
# ok edge phen to dis
# 648
# edges out
# 648
# HP:0000407
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (325, 9)
# OKKKk
# 325
# API 2.14 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (354, 9)
# ok edge phen to dis
# 679
# edges out
# 679
# HP:0000486
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (340, 9)
# OKKKk
# 340
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# (372, 9)
# ok edge phen to dis
# 712
# Nope
# edges out
# 754
# HP:0000491
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (45, 9)
# OKKKk
# 45
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (64, 9)
# ok edge phen to dis
# 109
# Nope
# edges out
# 351
# HP:0000498
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (46, 9)
# OKKKk
# 46
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (49, 9)
# ok edge phen to dis
# 95
# Nope
# edges out
# 131
# HP:0000518
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (283, 9)
# OKKKk
# 283
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (372, 9)
# ok edge phen to dis
# 655
# edges out
# 2104
# HP:0000524
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (24, 9)
# OKKKk
# 24
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (28, 9)
# ok edge phen to dis
# 52
# edges out
# 52
# HP:0000613
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (219, 9)
# OKKKk
# 219
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (329, 9)
# ok edge phen to dis
# 548
# edges out
# 760
# HP:0000621
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (23, 9)
# OKKKk
# 23
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (36, 9)
# ok edge phen to dis
# 59
# edges out
# 59
# HP:0000648
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (285, 9)
# OKKKk
# 285
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (387, 9)
# ok edge phen to dis
# 672
# Nope
# edges out
# 774
# HP:0000656
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (52, 9)
# OKKKk
# 52
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (64, 9)
# ok edge phen to dis
# 116
# edges out
# 116
# HP:0000958
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (147, 9)
# OKKKk
# 147
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (221, 9)
# ok edge phen to dis
# 368
# edges out
# 368
# HP:0000962
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (81, 9)
# OKKKk
# 81
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (230, 9)
# ok edge phen to dis
# 311
# edges out
# 636
# HP:0000963
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (89, 9)
# OKKKk
# 89
# API 2.9 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (132, 9)
# ok edge phen to dis
# 221
# edges out
# 221
# HP:0000992
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (84, 9)
# OKKKk
# 84
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (138, 9)
# ok edge phen to dis
# 222
# edges out
# 222
# HP:0000995
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (81, 9)
# OKKKk
# 81
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (112, 9)
# ok edge phen to dis
# 193
# edges out
# 193
# HP:0001009
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (55, 9)
# OKKKk
# 55
# API 2.14 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (76, 9)
# ok edge phen to dis
# 131
# edges out
# 131
# HP:0001029
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (23, 9)
# OKKKk
# 23
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (36, 9)
# ok edge phen to dis
# 59
# edges out
# 59
# HP:0001034
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (64, 9)
# OKKKk
# 64
# API 2.11 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (55, 9)
# ok edge phen to dis
# 119
# edges out
# 119
# HP:0001053
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (101, 9)
# OKKKk
# 101
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (82, 9)
# ok edge phen to dis
# 183
# edges out
# 183
# HP:0001059
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# gene
# (29, 9)
# OKKKk
# 29
# API 2.11 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (26, 9)
# ok edge phen to dis
# 55
# edges out
# 373
# HP:0001072
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (69, 9)
# OKKKk
# 69
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (97, 9)
# ok edge phen to dis
# 166
# edges out
# 166
# HP:0001250
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (546, 9)
# OKKKk
# 546
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (399, 9)
# ok edge phen to dis
# 945
# edges out
# 945
# HP:0001251
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (317, 9)
# OKKKk
# 317
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# (368, 9)
# ok edge phen to dis
# 685
# edges out
# 685
# HP:0001257
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (300, 9)
# OKKKk
# 300
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (377, 9)
# ok edge phen to dis
# 677
# edges out
# 677
# HP:0001315
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (149, 9)
# OKKKk
# 149
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (103, 9)
# ok edge phen to dis
# 252
# edges out
# 252
# HP:0001480
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (33, 9)
# OKKKk
# 33
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (45, 9)
# ok edge phen to dis
# 78
# edges out
# 78
# HP:0001508
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (311, 9)
# OKKKk
# 311
# API 2.1 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (361, 9)
# ok edge phen to dis
# 672
# edges out
# 672
# HP:0001596
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (119, 9)
# OKKKk
# 119
# API 2.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (316, 9)
# ok edge phen to dis
# 435
# Nope
# edges out
# 988
# HP:0001945
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (190, 9)
# OKKKk
# 190
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (277, 9)
# ok edge phen to dis
# 467
# edges out
# 2587
# HP:0002071
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (98, 9)
# OKKKk
# 98
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (139, 9)
# ok edge phen to dis
# 237
# edges out
# 237
# HP:0002120
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (517, 9)
# OKKKk
# 517
# API 2.1 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# (788, 9)
# ok edge phen to dis
# 1305
# edges out
# 1305
# HP:0002353
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (225, 9)
# OKKKk
# 225
# API 2.1 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (310, 9)
# ok edge phen to dis
# 535
# edges out
# 535
# HP:0002376
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# gene
# (236, 9)
# OKKKk
# 236
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (311, 9)
# ok edge phen to dis
# 547
# edges out
# 547
# HP:0002664
# API 2.2 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# gene
# (71, 9)
# OKKKk
# 71
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (159, 9)
# ok edge phen to dis
# 230
# edges out
# 230
# HP:0002750
# API 2.1 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (267, 9)
# OKKKk
# 267
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (356, 9)
# ok edge phen to dis
# 623
# edges out
# 623
# HP:0002829
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# gene
# (128, 9)
# OKKKk
# 128
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (268, 9)
# ok edge phen to dis
# 396
# edges out
# 902
# HP:0002861
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (56, 9)
# OKKKk
# 56
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# (61, 9)
# ok edge phen to dis
# 117
# edges out
# 117
# HP:0003355
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (98, 9)
# OKKKk
# 98
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# ...
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (73, 9)
# ok edge phen to dis
# 131
# edges out
# 131
# HP:0004493
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (27, 9)
# OKKKk
# 27
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (29, 9)
# ok edge phen to dis
# 56
# edges out
# 56
# HP:0006887
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (103, 9)
# OKKKk
# 103
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (132, 9)
# ok edge phen to dis
# 235
# edges out
# 235
# HP:0007759
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (91, 9)
# OKKKk
# 91
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# (140, 9)
# ok edge phen to dis
# 231
# edges out
# 231
# HP:0008734
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (94, 9)
# OKKKk
# 94
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (174, 9)
# ok edge phen to dis
# 268
# edges out
# 268
# HP:0009755
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (20, 9)
# OKKKk
# 20
# API 2.12 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (21, 9)
# ok edge phen to dis
# 41
# edges out
# 41
# HP:0009830
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (255, 9)
# OKKKk
# 255
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (395, 9)
# ok edge phen to dis
# 650
# edges out
# 2024
# HP:0010649
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (9, 9)
# OKKKk
# 9
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (3, 9)
# ok edge phen to dis
# 12
# edges out
# 12
# HP:0010783
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (102, 9)
# OKKKk
# 102
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# (180, 9)
# ok edge phen to dis
# 282
# edges out
# 282
# HP:0012378
# API 2.6 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (188, 9)
# OKKKk
# 188
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (241, 9)
# ok edge phen to dis
# 429
# edges out
# 1734
# HP:0012733
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (59, 9)
# OKKKk
# 59
# API 2.4 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# (47, 9)
# ok edge phen to dis
# 106
# edges out
# 536
# HP:0012740
# API 2.3 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (22, 9)
# OKKKk
# 22
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# (20, 9)
# ok edge phen to dis
# 42
# Nope
# edges out
# 440
# HP:0100012
# API 2.2 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# gene
# (8, 9)
# OKKKk
# 8
# API 2.5 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (3, 9)
# ok edge phen to dis
# 11
# edges out
# 11
# HP:0100543
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# gene
# (189, 9)
# OKKKk
# 189
# API 2.7 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# (326, 9)
# ok edge phen to dis
# 515
# edges out
# 515
# HP:0100585
# API 2.1 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# gene
# (50, 9)
# OKKKk
# 50
# API 2.5 semmed_phenotype failed
# API 2.7 semmed_phenotype failed
# API 2.4 semmed_phenotype failed
# API 2.8 semmed_phenotype failed
# API 2.2 semmed_phenotype failed
# API 2.6 semmed_phenotype failed
# API 2.11 semmed_phenotype failed
# API 2.13 semmed_phenotype failed
# API 2.10 semmed_phenotype failed
# API 2.9 semmed_phenotype failed
# API 2.1 semmed_phenotype failed
# API 2.3 semmed_phenotype failed
# API 2.14 semmed_phenotype failed
# API 2.12 semmed_phenotype failed
# API 2.17 semmed_phenotype failed
# API 2.19 semmed_phenotype failed
# API 2.15 semmed_phenotype failed
# API 2.18 semmed_phenotype failed
# API 2.16 semmed_phenotype failed
# (53, 9)
# ok edge phen to dis
# 103
# edges out
# 103

# %% [markdown]
# ## Calculate Individual Symptom Scores

# %%
individual_symptom_scores = [];
for index,x in disease_symptoms_df.iterrows():
    if(x["frequency"] == "Very frequent"):
        score = 20 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Frequent"):
        score = 15 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Occasional"):
        score = 10 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Rare"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    elif(x["frequency"] == "Unknown"):
        score = 5 / math.sqrt(int(x["edges_out_count"]))
    individual_symptom_scores.append(score)

# print(len(individual_symptom_scores))
disease_symptoms_df["ISS"] = individual_symptom_scores

# %% [markdown]
# ## Symptoms Table

# %%
disease_symptoms_df
# Out:
#                                                      names      frequency  \
# HP:0000524                   [conjunctival telangiectasia]  Very frequent
# HP:0001029                                  [poikiloderma]  Very frequent
# HP:0001480                                     [freckling]  Very frequent
# HP:0100585                    [telangiectasia of the skin]  Very frequent
# HP:0001009                                [telangiectasia]  Very frequent
# HP:0001072                                [thickened skin]  Very frequent
# HP:0000963                                     [thin skin]  Very frequent
# HP:0000992                    [cutaneous photosensitivity]  Very frequent
# HP:0006887          [intellectual disability, progressive]  Very frequent
# HP:0000958                                      [dry skin]  Very frequent
# HP:0100543                          [cognitive impairment]  Very frequent
# HP:0002353                               [eeg abnormality]  Very frequent
# HP:0002376                      [developmental regression]  Very frequent
# HP:0000164                  [abnormality of the dentition]  Very frequent
# HP:0001508                             [failure to thrive]  Very frequent
# HP:0000648                                 [optic atrophy]  Very frequent
# HP:0002829                                    [arthralgia]  Very frequent
# HP:0000135                                  [hypogonadism]  Very frequent
# HP:0012378                                       [fatigue]  Very frequent
# HP:0001945                                         [fever]  Very frequent
# HP:0002861                                      [melanoma]       Frequent
# HP:0001034                         [hypermelanotic macule]       Frequent
# HP:0004334                                [dermal atrophy]       Frequent
# HP:0001053                    [hypopigmented skin patches]       Frequent
# HP:0010783                                      [erythema]       Frequent
# HP:0000491                                     [keratitis]       Frequent
# HP:0012740                                     [papilloma]       Frequent
# HP:0012733                                        [macule]       Frequent
# HP:0000962                                [hyperkeratosis]       Frequent
# HP:0000407              [sensorineural hearing impairment]       Frequent
# HP:0000028                                [cryptorchidism]       Frequent
# HP:0000486                                    [strabismus]       Frequent
# HP:0000518                                      [cataract]       Frequent
# HP:0100012                           [neoplasm of the eye]     Occasional
# HP:0010649                               [flat nasal alae]     Occasional
# HP:0009755                               [ankyloblepharon]     Occasional
# HP:0004493                     [craniofacial hyperostosis]     Occasional
# HP:0000621                                     [entropion]     Occasional
# HP:0000656                                     [ectropion]     Occasional
# HP:0000498                                   [blepharitis]     Occasional
# HP:0000995                             [melanocytic nevus]     Occasional
# HP:0003355                                 [aminoaciduria]     Occasional
# HP:0002664                                      [neoplasm]     Occasional
# HP:0007759           [opacification of the corneal stroma]     Occasional
# HP:0002071  [abnormality of extrapyramidal motor function]     Occasional
# HP:0001315                       [reduced tendon reflexes]     Occasional
# HP:0008734                     [decreased testicular size]     Occasional
# HP:0001059                                     [pterygium]     Occasional
# HP:0002750                   [delayed skeletal maturation]     Occasional
# HP:0000365                            [hearing impairment]     Occasional
# HP:0001257                                    [spasticity]     Occasional
# HP:0001251                                        [ataxia]     Occasional
# HP:0000613                                   [photophobia]     Occasional
# HP:0000252                                  [microcephaly]     Occasional
# HP:0001250                                       [seizure]     Occasional
# HP:0001596                                      [alopecia]     Occasional
# HP:0004322                                 [short stature]     Occasional
# HP:0002120                     [cerebral cortical atrophy]     Occasional
# HP:0009830                         [peripheral neuropathy]     Occasional
#
#             edges_out_count       ISS
# HP:0000524               52  2.773501
# HP:0001029               59  2.603778
# HP:0001480               78  2.264554
# HP:0100585              103  1.970659
# HP:0001009              131  1.747408
# HP:0001072              166  1.552301
# HP:0000963              221  1.345346
# HP:0000992              222  1.342312
# HP:0006887              235  1.304656
# HP:0000958              368  1.042572
# HP:0100543              515  0.881305
# HP:0002353              535  0.864675
# HP:0002376              547  0.855138
# HP:0000164              636  0.793052
# HP:0001508              672  0.771517
# HP:0000648              774  0.718885
# HP:0002829              902  0.665927
# HP:0000135             1228  0.570730
# HP:0012378             1734  0.480292
# HP:0001945             2587  0.393217
# HP:0002861              117  1.386750
# HP:0001034              119  1.375048
# HP:0004334              131  1.310556
# HP:0001053              183  1.108832
# HP:0010783              282  0.893237
# HP:0000491              351  0.800641
# HP:0012740              440  0.715097
# HP:0012733              536  0.647901
# HP:0000962              636  0.594789
# HP:0000407              679  0.575647
# HP:0000028              696  0.568574
# HP:0000486              754  0.546268
# HP:0000518             2104  0.327016
# HP:0100012               11  3.015113
# HP:0010649               12  2.886751
# HP:0009755               41  1.561738
# HP:0004493               56  1.336306
# HP:0000621               59  1.301889
# HP:0000656              116  0.928477
# HP:0000498              131  0.873704
# HP:0000995              193  0.719816
# HP:0003355              218  0.677285
# HP:0002664              230  0.659380
# HP:0007759              231  0.657952
# HP:0002071              237  0.649570
# HP:0001315              252  0.629941
# HP:0008734              268  0.610847
# HP:0001059              373  0.517780
# HP:0002750              623  0.400642
# HP:0000365              648  0.392837
# HP:0001257              677  0.384331
# HP:0001251              685  0.382080
# HP:0000613              760  0.362738
# HP:0000252              815  0.350285
# HP:0001250              945  0.325300
# HP:0001596              988  0.318142
# HP:0004322             1148  0.295141
# HP:0002120             1305  0.276818
# HP:0009830             2024  0.222277

# %%
disease_symptoms_df.to_csv(symptom_csv, index = False)

# %% [markdown]
# ## Get Disease -> Gene (no intermediates)

# %%
disease_disease_to_genes_dict = gsf.get_disease_to_gene_results(disease)
disease_disease_to_genes_dict
# Out:
# running disease -> gene
# {'sorted_disease_to_genes': {'MGI:6258233': 1,
#   'MGI:6258236': 1,
#   'MGI:1195972': 1,
#   'RFC2': 1,
#   'AQR': 1,
#   'PSMD5': 1,
#   'SIRT1': 1,
#   'RBX1': 1,
#   'SUPT16H': 1,
#   'ALKBH1': 1,
#   'POLR2I': 1,
#   'RPA3': 1,
#   'SETX': 1,
#   'OBFC1': 1,
#   'SUPT4H1': 1,
#   'KAT2A': 1,
#   'CCND1': 1,
#   'PRPF19': 1,
#   'GAPDH': 1,
#   'PAPD7': 1,
#   'MLH1': 1,
#   'MSH2': 1,
#   'MSH6': 1,
#   'MAD2L2': 1,
#   'CAT': 1,
#   'POLK': 1,
#   'UNG': 1,
#   'SIRT2': 1,
#   'PARP2': 1,
#   'NEDD8': 1,
#   'SLX1A': 1,
#   'CDK4': 1,
#   'MDM2': 1,
#   'REV1': 1,
#   'HUS1': 1,
#   'TOPBP1': 1,
#   'BARD1': 1,
#   'PSMA6': 1,
#   'PALB2': 1,
#   'TIPIN': 1,
#   'CHTF18': 1,
#   'EP300': 1,
#   'TYR': 1,
#   'POLD3': 1,
#   'NEIL3': 1,
#   'GPN1': 1,
#   'RAD18': 1,
#   'MSH3': 1,
#   'POLB': 1,
#   'NBN': 1,
#   'SMARCA2': 1,
#   'PMS2': 1,
#   'CDK2': 1,
#   'FANCM': 1,
#   'TERF1': 1,
#   'ATM': 1,
#   'NEIL2': 1,
#   'FANCD2': 1,
#   'FANCC': 1,
#   'SLX4': 1,
#   'SPRTN': 1,
#   'ALB': 1,
#   'WRN': 1,
#   'HPRT1': 1,
#   'CDT1': 1,
#   'DDB1': 1,
#   'ALKBH3': 1,
#   'CDC25A': 1,
#   'PPM1D': 1,
#   'APLF': 1,
#   'MCM7': 1,
#   'MUS81': 1,
#   'HLTF': 1,
#   'TERT': 1,
#   'RMI2': 1,
#   'PSMC5': 1,
#   'FANCI': 1,
#   'RAD9A': 1,
#   'CLSPN': 1,
#   'ATAD5': 1,
#   'PRKDC': 1,
#   'PRIMPOL': 1,
#   'UBE2N': 1,
#   'WDTC1': 1,
#   'RNF168': 1,
#   'ATRIP': 1,
#   'PNKP': 1,
#   'TCHP': 1,
#   'MRE11A': 1,
#   'SLX1B': 1,
#   'FANCF': 1,
#   'HIST2H2AC': 1,
#   'C17orf70': 1,
#   'RAD54B': 1,
#   'RAD51C': 1,
#   'SIRT6': 1,
#   'TDP1': 1,
#   'KAT5': 1,
#   'TCEA2': 1,
#   'USP1': 1,
#   'USP7': 1,
#   'ATR': 1,
#   'H1F0': 1,
#   'RPS3A': 1,
#   'NEIL1': 1,
#   'UBE2I': 1,
#   'NHEJ1': 1,
#   'XAB2': 1,
#   'DNA2': 1,
#   'RAD52': 1,
#   'PRDM10': 1,
#   'REV3L': 1,
#   'XRCC6': 1,
#   'ZNF830': 1,
#   'TOP1': 1,
#   'DCLRE1A': 1,
#   'PARP1': 1,
#   'DTL': 1,
#   'SHPRH': 1,
#   'PSMD4': 1,
#   'HIST2H2BE': 1,
#   'HIST2H2AA': 1,
#   'PHGDH': 1,
#   'DCLRE1B': 1,
#   'POLL': 1,
#   'SMARCA1': 1,
#   'JUN': 1,
#   'PTEN': 1,
#   'MUTYH': 1,
#   'CDK9': 1,
#   'ATRX': 1,
#   'RNF8': 1,
#   'RPA2': 1,
#   'CDA': 1,
#   'CUL4A': 1,
#   'MDC1': 1,
#   'APRT': 1,
#   'LIG3': 1,
#   'FANCG': 1,
#   'FBXO18': 1,
#   'BRCA2': 1,
#   'HMGN1': 1,
#   'POLR2B': 1,
#   'RFC1': 1,
#   'TP53BP1': 1,
#   'CHEK2': 1,
#   'RAD51': 1,
#   'FANCA': 1,
#   'XRCC5': 1,
#   'TDG': 1,
#   'EME1': 1,
#   'CDK1': 1,
#   'GLI3': 1,
#   'RBBP8': 1,
#   'CUL4B': 1,
#   'PARG': 1,
#   'FANCL': 1,
#   'CHEK1': 1,
#   'SMARCA4': 1,
#   'DHFR': 1,
#   'ALKBH2': 1,
#   'APTX': 1,
#   'WEE1': 1,
#   'CLMP': 1,
#   'CDC45': 1,
#   'POLD1': 1,
#   'TCEA3': 1,
#   'PMS1': 1,
#   'TAF1': 1,
#   'HRAS': 1,
#   'TAF1L': 1,
#   'CDKN2A': 1,
#   'BRCA1': 1,
#   'RAD51B': 1,
#   'SMUG1': 1,
#   'RAD17': 1,
#   'UBE2V2': 1,
#   'TCEA1': 1,
#   'H2AFX': 1,
#   'POLN': 1,
#   'TIMELESS': 1,
#   'MC1R': 1,
#   'AKT1': 1,
#   'EME2': 1,
#   'POLI': 1,
#   'C19orf40': 1,
#   'RAD51D': 1,
#   'ENSP00000466834': 1,
#   'RAD23A': 1,
#   'SUPT5H': 1,
#   'HIST2H2AA3': 1,
#   'HIST2H3PS2': 1,
#   'POLD2': 1,
#   'RECQL4': 1,
#   'LIG4': 1,
#   'APAF1': 1,
#   'BAX': 1,
#   'BCL2': 1,
#   'BTG2': 1,
#   'AEN': 1,
#   'SUSD6': 1,
#   'SFN': 1,
#   'TRIAP1': 1,
#   'FAS': 1,
#   'FASN': 1,
#   'FXN': 1,
#   'PCNA': 1,
#   'RRM2B': 1,
#   'PERP': 1,
#   'REXO2': 1,
#   'BBC3': 1,
#   'PMAIP1': 1,
#   'FASTK': 1,
#   'ERVK-9': 1,
#   'ERVK-19': 1,
#   'ERVK-11': 1,
#   'CPD': 1,
#   'DDX11': 1,
#   'FOS': 1,
#   'HSPA1A': 1,
#   'IFNA1': 1,
#   'TERF2': 1,
#   'TNFRSF10B': 1,
#   'NRAS': 1,
#   'ERCC6': 1,
#   'ERCC8': 1,
#   'CSH1': 1,
#   'HSPA9': 1,
#   'ZC3H12D': 1,
#   'LRRC59': 1,
#   'PSMC6': 1,
#   'NR1H2': 1,
#   'WDR77': 1,
#   'AAGAB': 1,
#   'CCNH': 1,
#   'GTF2H1': 1,
#   'MMS19': 1,
#   'DCTPP1': 1,
#   'RPA1': 2,
#   'POLQ': 2,
#   'TP53': 2,
#   'EGFR': 2,
#   'WDR48': 2,
#   'PTCH1': 2,
#   'BLM': 2,
#   'CETN2': 2,
#   'GADD45A': 2,
#   'MAPK8': 2,
#   'POLM': 2,
#   'CDKN1A': 2,
#   'ENDOV': 2,
#   'MYC': 2,
#   'ERCC1': 2,
#   'HFM1': 2,
#   'GTF2H4': 2,
#   'EDNRA': 3,
#   'DDB2': 4,
#   'XPC': 4,
#   'ERCC4': 5,
#   'POLH': 5,
#   'XPA': 5,
#   'ERCC5': 5,
#   'ERCC2': 5,
#   'ERCC3': 6},
#  'one_step_genes_pub_counts': {'MGI:6258233': 0,
#   'MGI:6258236': 0,
#   'MGI:1195972': 0,
#   'RFC2': 0,
#   'AQR': 0,
#   'PSMD5': 0,
#   'SIRT1': 0,
#   'RBX1': 0,
#   'SUPT16H': 0,
#   'ALKBH1': 0,
#   'POLR2I': 0,
#   'RPA3': 0,
#   'SETX': 0,
#   'OBFC1': 0,
#   'SUPT4H1': 0,
#   'KAT2A': 0,
#   'CCND1': 0,
#   'PRPF19': 0,
#   'GAPDH': 0,
#   'PAPD7': 0,
#   'MLH1': 0,
#   'MSH2': 0,
#   'MSH6': 0,
#   'MAD2L2': 0,
#   'CAT': 0,
#   'POLK': 0,
#   'UNG': 0,
#   'SIRT2': 0,
#   'PARP2': 0,
#   'NEDD8': 0,
#   'SLX1A': 0,
#   'RPA1': 0,
#   'DDB2': 0,
#   'CDK4': 0,
#   'MDM2': 0,
#   'REV1': 0,
#   'HUS1': 0,
#   'TOPBP1': 0,
#   'BARD1': 0,
#   'PSMA6': 0,
#   'PALB2': 0,
#   'TIPIN': 0,
#   'CHTF18': 0,
#   'EP300': 0,
#   'TYR': 0,
#   'POLD3': 0,
#   'POLQ': 0,
#   'NEIL3': 0,
#   'GPN1': 0,
#   'RAD18': 0,
#   'MSH3': 0,
#   'POLB': 0,
#   'NBN': 0,
#   'SMARCA2': 0,
#   'PMS2': 0,
#   'CDK2': 0,
#   'FANCM': 0,
#   'TP53': 1,
#   'EGFR': 1,
#   'TERF1': 0,
#   'ATM': 0,
#   'NEIL2': 0,
#   'XPC': 0,
#   'FANCD2': 0,
#   'FANCC': 0,
#   'SLX4': 0,
#   'SPRTN': 0,
#   'ALB': 0,
#   'WRN': 0,
#   'HPRT1': 0,
#   'CDT1': 0,
#   'DDB1': 0,
#   'ALKBH3': 0,
#   'CDC25A': 0,
#   'PPM1D': 0,
#   'APLF': 0,
#   'MCM7': 0,
#   'WDR48': 1,
#   'MUS81': 0,
#   'HLTF': 0,
#   'TERT': 0,
#   'RMI2': 0,
#   'ERCC4': 5,
#   'PSMC5': 0,
#   'FANCI': 0,
#   'RAD9A': 0,
#   'CLSPN': 0,
#   'ATAD5': 0,
#   'PRKDC': 0,
#   'PRIMPOL': 0,
#   'UBE2N': 0,
#   'WDTC1': 0,
#   'RNF168': 0,
#   'ATRIP': 0,
#   'PNKP': 0,
#   'TCHP': 0,
#   'MRE11A': 0,
#   'SLX1B': 0,
#   'FANCF': 0,
#   'HIST2H2AC': 0,
#   'PTCH1': 1,
#   'C17orf70': 0,
#   'RAD54B': 0,
#   'RAD51C': 0,
#   'SIRT6': 0,
#   'TDP1': 0,
#   'KAT5': 0,
#   'TCEA2': 0,
#   'USP1': 0,
#   'USP7': 0,
#   'ATR': 0,
#   'H1F0': 0,
#   'RPS3A': 0,
#   'NEIL1': 0,
#   'BLM': 2,
#   'UBE2I': 0,
#   'NHEJ1': 0,
#   'XAB2': 0,
#   'DNA2': 0,
#   'RAD52': 0,
#   'PRDM10': 0,
#   'REV3L': 0,
#   'XRCC6': 0,
#   'ZNF830': 0,
#   'TOP1': 0,
#   'DCLRE1A': 0,
#   'PARP1': 0,
#   'DTL': 0,
#   'SHPRH': 0,
#   'PSMD4': 0,
#   'HIST2H2BE': 0,
#   'HIST2H2AA': 0,
#   'PHGDH': 0,
#   'DCLRE1B': 0,
#   'POLL': 0,
#   'CETN2': 0,
#   'GADD45A': 0,
#   'SMARCA1': 0,
#   'JUN': 0,
#   'PTEN': 0,
#   'MUTYH': 0,
#   'POLH': 7,
#   'CDK9': 0,
#   'ATRX': 0,
#   'RNF8': 0,
#   'RPA2': 0,
#   'CDA': 0,
#   'XPA': 4,
#   'CUL4A': 0,
#   'MDC1': 0,
#   'APRT': 0,
#   'LIG3': 0,
#   'FANCG': 0,
#   'FBXO18': 0,
#   'BRCA2': 0,
#   'HMGN1': 0,
#   'POLR2B': 0,
#   'RFC1': 0,
#   'TP53BP1': 0,
#   'CHEK2': 0,
#   'RAD51': 0,
#   'FANCA': 0,
#   'XRCC5': 0,
#   'TDG': 0,
#   'EME1': 0,
#   'CDK1': 0,
#   'MAPK8': 1,
#   'POLM': 0,
#   'GLI3': 0,
#   'RBBP8': 0,
#   'CUL4B': 0,
#   'PARG': 0,
#   'CDKN1A': 0,
#   'FANCL': 0,
#   'CHEK1': 0,
#   'SMARCA4': 0,
#   'DHFR': 0,
#   'ALKBH2': 0,
#   'APTX': 0,
#   'WEE1': 0,
#   'CLMP': 0,
#   'CDC45': 0,
#   'POLD1': 0,
#   'TCEA3': 0,
#   'PMS1': 0,
#   'TAF1': 0,
#   'HRAS': 0,
#   'TAF1L': 0,
#   'CDKN2A': 0,
#   'BRCA1': 0,
#   'RAD51B': 0,
#   'SMUG1': 0,
#   'RAD17': 0,
#   'UBE2V2': 0,
#   'TCEA1': 0,
#   'ENDOV': 1,
#   'H2AFX': 0,
#   'POLN': 0,
#   'TIMELESS': 0,
#   'MC1R': 0,
#   'AKT1': 0,
#   'EME2': 0,
#   'POLI': 0,
#   'C19orf40': 0,
#   'RAD51D': 0,
#   'ENSP00000466834': 0,
#   'RAD23A': 0,
#   'SUPT5H': 0,
#   'HIST2H2AA3': 0,
#   'HIST2H3PS2': 0,
#   'MYC': 1,
#   'POLD2': 0,
#   'RECQL4': 0,
#   'LIG4': 0,
#   'ERCC3': 13,
#   'ERCC5': 10,
#   'ERCC2': 14,
#   'APAF1': 0,
#   'BAX': 0,
#   'BCL2': 0,
#   'BTG2': 0,
#   'AEN': 0,
#   'SUSD6': 0,
#   'SFN': 0,
#   'TRIAP1': 0,
#   'FAS': 0,
#   'FASN': 0,
#   'FXN': 0,
#   'PCNA': 0,
#   'RRM2B': 0,
#   'PERP': 0,
#   'REXO2': 0,
#   'BBC3': 0,
#   'PMAIP1': 0,
#   'EDNRA': 8,
#   'ERCC1': 2,
#   'FASTK': 1,
#   'HFM1': 3,
#   'ERVK-9': 2,
#   'ERVK-19': 2,
#   'ERVK-11': 2,
#   'CPD': 1,
#   'DDX11': 1,
#   'FOS': 1,
#   'GTF2H4': 2,
#   'HSPA1A': 1,
#   'IFNA1': 1,
#   'TERF2': 1,
#   'TNFRSF10B': 1,
#   'NRAS': 1,
#   'ERCC6': 1,
#   'ERCC8': 1,
#   'CSH1': 1,
#   'HSPA9': 1,
#   'ZC3H12D': 1,
#   'LRRC59': 1,
#   'PSMC6': 1,
#   'NR1H2': 1,
#   'WDR77': 1,
#   'AAGAB': 1,
#   'CCNH': 1,
#   'GTF2H1': 0,
#   'MMS19': 0,
#   'DCTPP1': 0},
#  'disease_to_genes_list': ['ERCC3',
#   'ERCC2',
#   'ERCC5',
#   'XPA',
#   'POLH',
#   'ERCC4',
#   'XPC',
#   'DDB2',
#   'EDNRA',
#   'GTF2H4',
#   'HFM1',
#   'ERCC1',
#   'MYC',
#   'ENDOV',
#   'CDKN1A',
#   'POLM',
#   'MAPK8',
#   'GADD45A',
#   'CETN2',
#   'BLM',
#   'PTCH1',
#   'WDR48',
#   'EGFR',
#   'TP53',
#   'POLQ',
#   'RPA1',
#   'DCTPP1',
#   'MMS19',
#   'GTF2H1',
#   'CCNH',
#   'AAGAB',
#   'WDR77',
#   'NR1H2',
#   'PSMC6',
#   'LRRC59',
#   'ZC3H12D',
#   'HSPA9',
#   'CSH1',
#   'ERCC8',
#   'ERCC6',
#   'NRAS',
#   'TNFRSF10B',
#   'TERF2',
#   'IFNA1',
#   'HSPA1A',
#   'FOS',
#   'DDX11',
#   'CPD',
#   'ERVK-11',
#   'ERVK-19',
#   'ERVK-9',
#   'FASTK',
#   'PMAIP1',
#   'BBC3',
#   'REXO2',
#   'PERP',
#   'RRM2B',
#   'PCNA',
#   'FXN',
#   'FASN',
#   'FAS',
#   'TRIAP1',
#   'SFN',
#   'SUSD6',
#   'AEN',
#   'BTG2',
#   'BCL2',
#   'BAX',
#   'APAF1',
#   'LIG4',
#   'RECQL4',
#   'POLD2',
#   'HIST2H3PS2',
#   'HIST2H2AA3',
#   'SUPT5H',
#   'RAD23A',
#   'ENSP00000466834',
#   'RAD51D',
#   'C19orf40',
#   'POLI',
#   'EME2',
#   'AKT1',
#   'MC1R',
#   'TIMELESS',
#   'POLN',
#   'H2AFX',
#   'TCEA1',
#   'UBE2V2',
#   'RAD17',
#   'SMUG1',
#   'RAD51B',
#   'BRCA1',
#   'CDKN2A',
#   'TAF1L',
#   'HRAS',
#   'TAF1',
#   'PMS1',
#   'TCEA3',
#   'POLD1',
#   'CDC45',
#   'CLMP',
#   'WEE1',
#   'APTX',
#   'ALKBH2',
#   'DHFR',
#   'SMARCA4',
#   'CHEK1',
#   'FANCL',
#   'PARG',
#   'CUL4B',
#   'RBBP8',
#   'GLI3',
#   'CDK1',
#   'EME1',
#   'TDG',
#   'XRCC5',
#   'FANCA',
#   'RAD51',
#   'CHEK2',
#   'TP53BP1',
#   'RFC1',
#   'POLR2B',
#   'HMGN1',
#   'BRCA2',
#   'FBXO18',
#   'FANCG',
#   'LIG3',
#   'APRT',
#   'MDC1',
#   'CUL4A',
#   'CDA',
#   'RPA2',
#   'RNF8',
#   'ATRX',
#   'CDK9',
#   'MUTYH',
#   'PTEN',
#   'JUN',
#   'SMARCA1',
#   'POLL',
#   'DCLRE1B',
#   'PHGDH',
#   'HIST2H2AA',
#   'HIST2H2BE',
#   'PSMD4',
#   'SHPRH',
#   'DTL',
#   'PARP1',
#   'DCLRE1A',
#   'TOP1',
#   'ZNF830',
#   'XRCC6',
#   'REV3L',
#   'PRDM10',
#   'RAD52',
#   'DNA2',
#   'XAB2',
#   'NHEJ1',
#   'UBE2I',
#   'NEIL1',
#   'RPS3A',
#   'H1F0',
#   'ATR',
#   'USP7',
#   'USP1',
#   'TCEA2',
#   'KAT5',
#   'TDP1',
#   'SIRT6',
#   'RAD51C',
#   'RAD54B',
#   'C17orf70',
#   'HIST2H2AC',
#   'FANCF',
#   'SLX1B',
#   'MRE11A',
#   'TCHP',
#   'PNKP',
#   'ATRIP',
#   'RNF168',
#   'WDTC1',
#   'UBE2N',
#   'PRIMPOL',
#   'PRKDC',
#   'ATAD5',
#   'CLSPN',
#   'RAD9A',
#   'FANCI',
#   'PSMC5',
#   'RMI2',
#   'TERT',
#   'HLTF',
#   'MUS81',
#   'MCM7',
#   'APLF',
#   'PPM1D',
#   'CDC25A',
#   'ALKBH3',
#   'DDB1',
#   'CDT1',
#   'HPRT1',
#   'WRN',
#   'ALB',
#   'SPRTN',
#   'SLX4',
#   'FANCC',
#   'FANCD2',
#   'NEIL2',
#   'ATM',
#   'TERF1',
#   'FANCM',
#   'CDK2',
#   'PMS2',
#   'SMARCA2',
#   'NBN',
#   'POLB',
#   'MSH3',
#   'RAD18',
#   'GPN1',
#   'NEIL3',
#   'POLD3',
#   'TYR',
#   'EP300',
#   'CHTF18',
#   'TIPIN',
#   'PALB2',
#   'PSMA6',
#   'BARD1',
#   'TOPBP1',
#   'HUS1',
#   'REV1',
#   'MDM2',
#   'CDK4',
#   'SLX1A',
#   'NEDD8',
#   'PARP2',
#   'SIRT2',
#   'UNG',
#   'POLK',
#   'CAT',
#   'MAD2L2',
#   'MSH6',
#   'MSH2',
#   'MLH1',
#   'PAPD7',
#   'GAPDH',
#   'PRPF19',
#   'CCND1',
#   'KAT2A',
#   'SUPT4H1',
#   'OBFC1',
#   'SETX',
#   'RPA3',
#   'POLR2I',
#   'ALKBH1',
#   'SUPT16H',
#   'RBX1',
#   'SIRT1',
#   'PSMD5',
#   'AQR',
#   'RFC2',
#   'MGI:1195972',
#   'MGI:6258236',
#   'MGI:6258233']}

# %% [markdown]
# ## Get Disease -> intermediate_node (any except those matching symptoms) -> Gene

# %%
# get results using intermediates 
node_type_list = (['Gene', 'SequenceVariant', 'ChemicalSubstance', 'Disease', 
                'MolecularActivity', 'BiologicalProcess', 'CellularComponent', 
                'Pathway', 'AnatomicalEntity', 'PhenotypicFeature'])

# %%
disease_disease_all_nodes_genes = gsf.predict_many(disease, node_type_list, 'Gene')

# Save an object to a file
# %store disease_disease_all_nodes_genes
# Out:
# Intermediate Node type running:
# Gene
# Intermediate Node type running:
# SequenceVariant
# Intermediate Node type running:
# ChemicalSubstance
# API 1.1 pharos failed
# Intermediate Node type running:
# Disease

# %%
# Restore the object
# %store -r disease_disease_all_nodes_genes
disease_disease_all_nodes_genes

# %%
## Remove UMLS "Genes"  (not gene specific) 
disease_disease_all_nodes_genes = disease_disease_all_nodes_genes[~disease_disease_all_nodes_genes['output_id'].str.contains('UMLS')]

# %%
max_2_step_genes = 100
disease_disease_to_node_to_genes_dict = gsf.get_disease_to_node_to_gene_results(disease_disease_all_nodes_genes, max_2_step_genes, disease_symptoms, disease_symptom_hpids)
# %store disease_disease_to_node_to_genes_dict

# %% [markdown]
# ## Combine genes from one and two step processes then get rid of any duplicates

# %%
# %store -r disease_disease_to_node_to_genes_dict
disease_top_genes_list = disease_disease_to_genes_dict["disease_to_genes_list"] + disease_disease_to_node_to_genes_dict["top_related_genes_to_disease"]
disease_top_genes_list = list(dict.fromkeys(disease_top_genes_list))
# top_genes_list

# %% [markdown]
# ## Get Genes -> Symtoms, filtered by those related to Disease

# %%
disease_relevant_genes_to_symptoms_df = gsf.determined_genes_to_symptoms(disease_top_genes_list, disease_symptoms)
# relevant_genes_to_symptoms_df

# %%
# %store disease_relevant_genes_to_symptoms_df

# %%
# %store -r disease_relevant_genes_to_symptoms_df
disease_relevant_genes_list = list(dict.fromkeys(list(disease_relevant_genes_to_symptoms_df["input"])))
# relevant_genes_list

# %%
disease_gene_to_symptom_pub_counts = gsf.get_gene_to_symptom_publication_counts(disease_relevant_genes_to_symptoms_df)
# gene_to_symptom_pub_counts

# %%
disease_causes_dict = gsf.create_causes_dict(disease_relevant_genes_to_symptoms_df)
# causes_dict

# %% [markdown]
# ## Get edges out from each gene
# For use in normalizing in relevance score

# %%
disease_connection_dict =  gsf.get_connection_normalizing_count(disease_relevant_genes_list,node_type_list)
# connection_dict

# %%
# %store disease_connection_dict

# %%
# %store -r disease_connection_dict

# %% [markdown]
# ## Assemble final results

# %%
disease_df = gsf.assemble_final_data_frame(disease_relevant_genes_to_symptoms_df, 
                                      disease_connection_dict,
                                      disease_disease_to_genes_dict['sorted_disease_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['sorted_disease_to_all_nodes_to_genes'], 
                                      disease_disease_to_node_to_genes_dict['top_two_step_genes_pub_counts'], 
                                      disease_gene_to_symptom_pub_counts, 
                                      disease_causes_dict,
                                      disease_symptoms_df)
disease_df

# %% [markdown]
# ## Save Results

# %%
disease_df.to_csv(output_csv, index = False)
